# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(.1)(last_state) 
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('sigmoid', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_state) 
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('sigmoid', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    batch_size=config['BATCH_SIZE'], 
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 289s - loss: 0.0461 - y_start_loss: 0.0228 - y_end_loss: 0.0233 - y_start_binary_accuracy: 0.9918 - y_end_binary_accuracy: 0.9910 - val_loss: 0.0277 - val_y_start_loss: 0.0139 - val_y_end_loss: 0.0137 - val_y_start_binary_accuracy: 0.9945 - val_y_end_binary_accuracy: 0.9946
# Epoch 2/5
# 21984/21984 - 271s - loss: 0.0277 - y_start_loss: 0.0141 - y_end_loss: 0.0135 - y_start_binary_accuracy: 0.9945 - y_end_binary_accuracy: 0.9946 - val_loss: 0.0266 - val_y_start_loss: 0.0134 - val_y_end_loss: 0.0132 - val_y_start_binary_accuracy: 0.9945 - val_y_end_binary_accuracy: 0.9946
# Epoch 3/5
# 21984/21984 - 271s - loss: 0.0253 - y_start_loss: 0.0130 - y_end_loss: 0.0123 - y_start_binary_accuracy: 0.9947 - y_end_binary_accuracy: 0.9950 - val_loss: 0.0260 - val_y_start_loss: 0.0133 - val_y_end_loss: 0.0126 - val_y_start_binary_accuracy: 0.9946 - val_y_end_binary_accuracy: 0.9947
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 269s - loss: 0.0235 - y_start_loss: 0.0121 - y_end_loss: 0.0114 - y_start_binary_accuracy: 0.9950 - y_end_binary_accuracy: 0.9953 - val_loss: 0.0264 - val_y_start_loss: 0.0137 - val_y_end_loss: 0.0127 - val_y_start_binary_accuracy: 0.9945 - val_y_end_binary_accuracy: 0.9948
# Epoch 00004: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 287s - loss: 0.0451 - y_start_loss: 0.0217 - y_end_loss: 0.0234 - y_start_binary_accuracy: 0.9922 - y_end_binary_accuracy: 0.9919 - val_loss: 0.0299 - val_y_start_loss: 0.0149 - val_y_end_loss: 0.0150 - val_y_start_binary_accuracy: 0.9942 - val_y_end_binary_accuracy: 0.9941
# Epoch 2/5
# 21984/21984 - 272s - loss: 0.0278 - y_start_loss: 0.0141 - y_end_loss: 0.0137 - y_start_binary_accuracy: 0.9945 - y_end_binary_accuracy: 0.9946 - val_loss: 0.0279 - val_y_start_loss: 0.0142 - val_y_end_loss: 0.0137 - val_y_start_binary_accuracy: 0.9941 - val_y_end_binary_accuracy: 0.9943
# Epoch 3/5
# 21984/21984 - 271s - loss: 0.0255 - y_start_loss: 0.0131 - y_end_loss: 0.0123 - y_start_binary_accuracy: 0.9947 - y_end_binary_accuracy: 0.9949 - val_loss: 0.0267 - val_y_start_loss: 0.0136 - val_y_end_loss: 0.0131 - val_y_start_binary_accuracy: 0.9945 - val_y_end_binary_accuracy: 0.9947
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 0.0237 - y_start_loss: 0.0122 - y_end_loss: 0.0114 - y_start_binary_accuracy: 0.9949 - y_end_binary_accuracy: 0.9952 - val_loss: 0.0272 - val_y_start_loss: 0.0140 - val_y_end_loss: 0.0131 - val_y_start_binary_accuracy: 0.9942 - val_y_end_binary_accuracy: 0.9946
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 285s - loss: 0.0479 - y_start_loss: 0.0239 - y_end_loss: 0.0240 - y_start_binary_accuracy: 0.9904 - y_end_binary_accuracy: 0.9911 - val_loss: 0.0284 - val_y_start_loss: 0.0143 - val_y_end_loss: 0.0141 - val_y_start_binary_accuracy: 0.9944 - val_y_end_binary_accuracy: 0.9945
# Epoch 2/5
# 21984/21984 - 271s - loss: 0.0280 - y_start_loss: 0.0142 - y_end_loss: 0.0138 - y_start_binary_accuracy: 0.9944 - y_end_binary_accuracy: 0.9945 - val_loss: 0.0268 - val_y_start_loss: 0.0136 - val_y_end_loss: 0.0132 - val_y_start_binary_accuracy: 0.9945 - val_y_end_binary_accuracy: 0.9947
# Epoch 3/5
# 21984/21984 - 271s - loss: 0.0258 - y_start_loss: 0.0133 - y_end_loss: 0.0125 - y_start_binary_accuracy: 0.9946 - y_end_binary_accuracy: 0.9949 - val_loss: 0.0262 - val_y_start_loss: 0.0133 - val_y_end_loss: 0.0129 - val_y_start_binary_accuracy: 0.9946 - val_y_end_binary_accuracy: 0.9949
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 0.0239 - y_start_loss: 0.0124 - y_end_loss: 0.0115 - y_start_binary_accuracy: 0.9949 - y_end_binary_accuracy: 0.9952 - val_loss: 0.0264 - val_y_start_loss: 0.0134 - val_y_end_loss: 0.0130 - val_y_start_binary_accuracy: 0.9945 - val_y_end_binary_accuracy: 0.9949
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8b173cb8_8259_11ea_8f81_136363828586row0_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row0_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col0 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col1 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col3 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col4 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col5 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col6 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col7 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row1_col8 {
#             color:  green;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row2_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row3_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row4_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row5_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row6_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col6 {
#             color:  orange;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row7_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col6 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col7 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row8_col8 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col0 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col1 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col2 {
#             color:  red;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col3 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col4 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col5 {
#             color:  black;
#         }    #T_8b173cb8_8259_11ea_8f81_136363828586row9_col6 {
#             color:  b

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        0.200000
# 2                                      bullying me...        0.400000
# 3                                      leave me alone        0.600000
# 4                                       sons of ****,        0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        0.500000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                             dangerously low on ink        0.500000
# 13                                     lost my voice.        0.300000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        0.200000
# 2                                      bullying me...        0.400000
# 3                                      leave me alone        0.600000
# 4                                       sons of ****,        0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.100000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                             dangerously low on ink        0.500000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        0.200000
# 2                                            bullying        0.200000
# 3                                      leave me alone        0.600000
# 4                                               ****,        0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                             cooler.        0.100000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                             dangerously low on ink        0.500000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
