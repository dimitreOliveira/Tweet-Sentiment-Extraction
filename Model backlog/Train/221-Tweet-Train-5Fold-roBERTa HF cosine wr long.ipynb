# %%
# !nvidia-smi
# Out:
# Thu Jun  4 13:48:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 675kB 8.4MB/s
#      |████████████████████████████████| 1.1MB 23.4MB/s
#      |████████████████████████████████| 890kB 52.4MB/s
#      |████████████████████████████████| 3.8MB 56.4MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/221-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 10,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size # total_steps * 0.1
num_cycles = 9

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [cosine_with_hard_restarts_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                                    warmup_steps=warmup_steps, lr_start=lr_start, 
                                                    lr_max=lr_max, lr_min=lr_min, num_cycles=num_cycles) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, name="qa_outputs", use_bias=False)(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: cosine_with_hard_restarts_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                                     total_steps=total_steps, warmup_steps=warmup_steps, 
                                                                                                     lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, 
                                                                                                     num_cycles=num_cycles))

    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    # model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 174s - loss: 4.7686 - tf_op_layer_Squeeze_2_loss: 2.3303 - tf_op_layer_Squeeze_3_loss: 2.4383 - val_loss: 3.9023 - val_tf_op_layer_Squeeze_2_loss: 1.9754 - val_tf_op_layer_Squeeze_3_loss: 1.9269
# Epoch 2/10
# 672/672 - 183s - loss: 3.8332 - tf_op_layer_Squeeze_2_loss: 1.9149 - tf_op_layer_Squeeze_3_loss: 1.9184 - val_loss: 3.8113 - val_tf_op_layer_Squeeze_2_loss: 1.9247 - val_tf_op_layer_Squeeze_3_loss: 1.8866
# Epoch 3/10
# 672/672 - 175s - loss: 3.7325 - tf_op_layer_Squeeze_2_loss: 1.8793 - tf_op_layer_Squeeze_3_loss: 1.8532 - val_loss: 3.7692 - val_tf_op_layer_Squeeze_2_loss: 1.9105 - val_tf_op_layer_Squeeze_3_loss: 1.8587
# Epoch 4/10
# 672/672 - 170s - loss: 3.6589 - tf_op_layer_Squeeze_2_loss: 1.8455 - tf_op_layer_Squeeze_3_loss: 1.8134 - val_loss: 3.7732 - val_tf_op_layer_Squeeze_2_loss: 1.9139 - val_tf_op_layer_Squeeze_3_loss: 1.8593
# Epoch 5/10
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 3.5911 - tf_op_layer_Squeeze_2_loss: 1.8128 - tf_op_layer_Squeeze_3_loss: 1.7782 - val_loss: 3.7910 - val_tf_op_layer_Squeeze_2_loss: 1.9242 - val_tf_op_layer_Squeeze_3_loss: 1.8667
# Epoch 00005: early stopping
#
# FOLD: 2
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 4.7863 - tf_op_layer_Squeeze_4_loss: 2.3275 - tf_op_layer_Squeeze_5_loss: 2.4587 - val_loss: 3.8715 - val_tf_op_layer_Squeeze_4_loss: 1.9412 - val_tf_op_layer_Squeeze_5_loss: 1.9303
# Epoch 2/10
# 672/672 - 176s - loss: 3.8240 - tf_op_layer_Squeeze_4_loss: 1.9176 - tf_op_layer_Squeeze_5_loss: 1.9063 - val_loss: 3.7990 - val_tf_op_layer_Squeeze_4_loss: 1.9096 - val_tf_op_layer_Squeeze_5_loss: 1.8894
# Epoch 3/10
# 672/672 - 177s - loss: 3.7431 - tf_op_layer_Squeeze_4_loss: 1.8800 - tf_op_layer_Squeeze_5_loss: 1.8631 - val_loss: 3.7767 - val_tf_op_layer_Squeeze_4_loss: 1.9035 - val_tf_op_layer_Squeeze_5_loss: 1.8733
# Epoch 4/10
# 672/672 - 171s - loss: 3.6762 - tf_op_layer_Squeeze_4_loss: 1.8493 - tf_op_layer_Squeeze_5_loss: 1.8269 - val_loss: 3.7820 - val_tf_op_layer_Squeeze_4_loss: 1.9115 - val_tf_op_layer_Squeeze_5_loss: 1.8705
# Epoch 5/10
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 3.6010 - tf_op_layer_Squeeze_4_loss: 1.8146 - tf_op_layer_Squeeze_5_loss: 1.7864 - val_loss: 3.7869 - val_tf_op_layer_Squeeze_4_loss: 1.9128 - val_tf_op_layer_Squeeze_5_loss: 1.8741
# Epoch 00005: early stopping
#
# FOLD: 3
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 174s - loss: 4.7889 - tf_op_layer_Squeeze_6_loss: 2.3608 - tf_op_layer_Squeeze_7_loss: 2.4280 - val_loss: 3.8437 - val_tf_op_layer_Squeeze_6_loss: 1.9390 - val_tf_op_layer_Squeeze_7_loss: 1.9048
# Epoch 2/10
# 672/672 - 175s - loss: 3.7915 - tf_op_layer_Squeeze_6_loss: 1.9151 - tf_op_layer_Squeeze_7_loss: 1.8764 - val_loss: 3.7526 - val_tf_op_layer_Squeeze_6_loss: 1.9030 - val_tf_op_layer_Squeeze_7_loss: 1.8496
# Epoch 3/10
# 672/672 - 175s - loss: 3.7146 - tf_op_layer_Squeeze_6_loss: 1.8784 - tf_op_layer_Squeeze_7_loss: 1.8362 - val_loss: 3.7344 - val_tf_op_layer_Squeeze_6_loss: 1.8949 - val_tf_op_layer_Squeeze_7_loss: 1.8395
# Epoch 4/10
# 672/672 - 171s - loss: 3.6435 - tf_op_layer_Squeeze_6_loss: 1.8413 - tf_op_layer_Squeeze_7_loss: 1.8022 - val_loss: 3.7482 - val_tf_op_layer_Squeeze_6_loss: 1.9011 - val_tf_op_layer_Squeeze_7_loss: 1.8470
# Epoch 5/10
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 3.6140 - tf_op_layer_Squeeze_6_loss: 1.8165 - tf_op_layer_Squeeze_7_loss: 1.7975 - val_loss: 3.7677 - val_tf_op_layer_Squeeze_6_loss: 1.9078 - val_tf_op_layer_Squeeze_7_loss: 1.8600
# Epoch 00005: early stopping
#
# FOLD: 4
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 174s - loss: 4.8536 - tf_op_layer_Squeeze_8_loss: 2.3594 - tf_op_layer_Squeeze_9_loss: 2.4942 - val_loss: 4.1475 - val_tf_op_layer_Squeeze_8_loss: 2.0367 - val_tf_op_layer_Squeeze_9_loss: 2.1107
# Epoch 2/10
# 672/672 - 175s - loss: 3.9444 - tf_op_layer_Squeeze_8_loss: 1.9628 - tf_op_layer_Squeeze_9_loss: 1.9816 - val_loss: 3.7988 - val_tf_op_layer_Squeeze_8_loss: 1.9020 - val_tf_op_layer_Squeeze_9_loss: 1.8968
# Epoch 3/10
# 672/672 - 176s - loss: 3.7811 - tf_op_layer_Squeeze_8_loss: 1.9035 - tf_op_layer_Squeeze_9_loss: 1.8776 - val_loss: 3.7519 - val_tf_op_layer_Squeeze_8_loss: 1.8879 - val_tf_op_layer_Squeeze_9_loss: 1.8639
# Epoch 4/10
# 672/672 - 175s - loss: 3.7409 - tf_op_layer_Squeeze_8_loss: 1.8900 - tf_op_layer_Squeeze_9_loss: 1.8509 - val_loss: 3.7470 - val_tf_op_layer_Squeeze_8_loss: 1.8873 - val_tf_op_layer_Squeeze_9_loss: 1.8597
# Epoch 5/10
# 672/672 - 175s - loss: 3.6828 - tf_op_layer_Squeeze_8_loss: 1.8615 - tf_op_layer_Squeeze_9_loss: 1.8213 - val_loss: 3.7336 - val_tf_op_layer_Squeeze_8_loss: 1.8831 - val_tf_op_layer_Squeeze_9_loss: 1.8505
# Epoch 6/10
# 672/672 - 171s - loss: 3.6279 - tf_op_layer_Squeeze_8_loss: 1.8357 - tf_op_layer_Squeeze_9_loss: 1.7922 - val_loss: 3.7383 - val_tf_op_layer_Squeeze_8_loss: 1.8882 - val_tf_op_layer_Squeeze_9_loss: 1.8501
# Epoch 7/10
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 3.5903 - tf_op_layer_Squeeze_8_loss: 1.8130 - tf_op_layer_Squeeze_9_loss: 1.7773 - val_loss: 3.7553 - val_tf_op_layer_Squeeze_8_loss: 1.8910 - val_tf_op_layer_Squeeze_9_loss: 1.8643
# Epoch 00007: early stopping
#
# FOLD: 5
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 4.7330 - tf_op_layer_Squeeze_10_loss: 2.3393 - tf_op_layer_Squeeze_11_loss: 2.3937 - val_loss: 3.9294 - val_tf_op_layer_Squeeze_10_loss: 1.9586 - val_tf_op_layer_Squeeze_11_loss: 1.9707
# Epoch 2/10
# 672/672 - 175s - loss: 3.8268 - tf_op_layer_Squeeze_10_loss: 1.9345 - tf_op_layer_Squeeze_11_loss: 1.8923 - val_loss: 3.7490 - val_tf_op_layer_Squeeze_10_loss: 1.8873 - val_tf_op_layer_Squeeze_11_loss: 1.8618
# Epoch 3/10
# 672/672 - 175s - loss: 3.7320 - tf_op_layer_Squeeze_10_loss: 1.8900 - tf_op_layer_Squeeze_11_loss: 1.8421 - val_loss: 3.7322 - val_tf_op_layer_Squeeze_10_loss: 1.8826 - val_tf_op_layer_Squeeze_11_loss: 1.8496
# Epoch 4/10
# 672/672 - 171s - loss: 3.6620 - tf_op_layer_Squeeze_10_loss: 1.8512 - tf_op_layer_Squeeze_11_loss: 1.8108 - val_loss: 3.7364 - val_tf_op_layer_Squeeze_10_loss: 1.8852 - val_tf_op_layer_Squeeze_11_loss: 1.8511
# Epoch 5/10
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 3.6057 - tf_op_layer_Squeeze_10_loss: 1.8275 - tf_op_layer_Squeeze_11_loss: 1.7782 - val_loss: 3.7460 - val_tf_op_layer_Squeeze_10_loss: 1.8878 - val_tf_op_layer_Squeeze_11_loss: 1.8583
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_14f45d94_a677_11ea_86fc_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_5
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                              bullying me...
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                        i really really like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                      dangerously low on ink
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                                        lost
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
