# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers|
# Out:
#      |████████████████████████████████| 573kB 2.8MB/s
#      |████████████████████████████████| 1.0MB 13.7MB/s
#      |████████████████████████████████| 3.7MB 22.1MB/s
#      |████████████████████████████████| 890kB 31.5MB/s
#   Building wheel for sacremoses (setup.py) ... done
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/110-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7f08b9aa77b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function lrfn at 0x7f08b9aa77b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False, 
                                              attention_probs_dropout_prob=0.2, hidden_dropout_prob=0.2)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 803s - loss: 4.6508 - y_start_loss: 2.2925 - y_end_loss: 2.3582 - y_start_categorical_accuracy: 0.6316 - y_end_categorical_accuracy: 0.6132 - val_loss: 4.0606 - val_y_start_loss: 2.0453 - val_y_end_loss: 2.0153 - val_y_start_categorical_accuracy: 0.7031 - val_y_end_categorical_accuracy: 0.7216 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 - 797s - loss: 4.1079 - y_start_loss: 2.0707 - y_end_loss: 2.0372 - y_start_categorical_accuracy: 0.6875 - y_end_categorical_accuracy: 0.7108 - val_loss: 4.0193 - val_y_start_loss: 2.0258 - val_y_end_loss: 1.9935 - val_y_start_categorical_accuracy: 0.7103 - val_y_end_categorical_accuracy: 0.7191 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 - 797s - loss: 4.0140 - y_start_loss: 2.0279 - y_end_loss: 1.9861 - y_start_categorical_accuracy: 0.7041 - y_end_categorical_accuracy: 0.7258 - val_loss: 3.9807 - val_y_start_loss: 2.0104 - val_y_end_loss: 1.9703 - val_y_start_categorical_accuracy: 0.7136 - val_y_end_categorical_accuracy: 0.7273 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 - 795s - loss: 3.9718 - y_start_loss: 2.0083 - y_end_loss: 1.9636 - y_start_categorical_accuracy: 0.7091 - y_end_categorical_accuracy: 0.7330 - val_loss: 3.9593 - val_y_start_loss: 2.0030 - val_y_end_loss: 1.9562 - val_y_start_categorical_accuracy: 0.7147 - val_y_end_categorical_accuracy: 0.7285 - lr: 3.7500e-06
# Epoch 5/6
# 687/687 - 795s - loss: 3.9467 - y_start_loss: 1.9956 - y_end_loss: 1.9511 - y_start_categorical_accuracy: 0.7130 - y_end_categorical_accuracy: 0.7382 - val_loss: 3.9570 - val_y_start_loss: 2.0000 - val_y_end_loss: 1.9570 - val_y_start_categorical_accuracy: 0.7147 - val_y_end_categorical_accuracy: 0.7280 - lr: 1.8750e-06
# Epoch 6/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 790s - loss: 3.9328 - y_start_loss: 1.9887 - y_end_loss: 1.9441 - y_start_categorical_accuracy: 0.7165 - y_end_categorical_accuracy: 0.7400 - val_loss: 3.9615 - val_y_start_loss: 2.0022 - val_y_end_loss: 1.9594 - val_y_start_categorical_accuracy: 0.7129 - val_y_end_categorical_accuracy: 0.7278 - lr: 1.0000e-06
# Epoch 00006: early stopping
#
# FOLD: 2
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 797s - loss: 4.6460 - y_start_loss: 2.3132 - y_end_loss: 2.3327 - y_start_categorical_accuracy: 0.6195 - y_end_categorical_accuracy: 0.6163 - val_loss: 4.1382 - val_y_start_loss: 2.0641 - val_y_end_loss: 2.0741 - val_y_start_categorical_accuracy: 0.6930 - val_y_end_categorical_accuracy: 0.7080 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 - 795s - loss: 4.0868 - y_start_loss: 2.0651 - y_end_loss: 2.0217 - y_start_categorical_accuracy: 0.6924 - y_end_categorical_accuracy: 0.7155 - val_loss: 4.0435 - val_y_start_loss: 2.0419 - val_y_end_loss: 2.0017 - val_y_start_categorical_accuracy: 0.6963 - val_y_end_categorical_accuracy: 0.7202 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 - 795s - loss: 4.0088 - y_start_loss: 2.0283 - y_end_loss: 1.9806 - y_start_categorical_accuracy: 0.7034 - y_end_categorical_accuracy: 0.7268 - val_loss: 4.0336 - val_y_start_loss: 2.0371 - val_y_end_loss: 1.9965 - val_y_start_categorical_accuracy: 0.7038 - val_y_end_categorical_accuracy: 0.7238 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 - 795s - loss: 3.9609 - y_start_loss: 2.0047 - y_end_loss: 1.9562 - y_start_categorical_accuracy: 0.7097 - y_end_categorical_accuracy: 0.7370 - val_loss: 4.0251 - val_y_start_loss: 2.0273 - val_y_end_loss: 1.9978 - val_y_start_categorical_accuracy: 0.7009 - val_y_end_categorical_accuracy: 0.7234 - lr: 3.7500e-06
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 792s - loss: 3.9465 - y_start_loss: 1.9960 - y_end_loss: 1.9505 - y_start_categorical_accuracy: 0.7138 - y_end_categorical_accuracy: 0.7388 - val_loss: 4.0259 - val_y_start_loss: 2.0294 - val_y_end_loss: 1.9966 - val_y_start_categorical_accuracy: 0.7034 - val_y_end_categorical_accuracy: 0.7227 - lr: 1.8750e-06
# Epoch 00005: early stopping
#
# FOLD: 3
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 796s - loss: 4.6844 - y_start_loss: 2.3499 - y_end_loss: 2.3345 - y_start_categorical_accuracy: 0.6089 - y_end_categorical_accuracy: 0.6103 - val_loss: 4.0615 - val_y_start_loss: 2.0466 - val_y_end_loss: 2.0149 - val_y_start_categorical_accuracy: 0.7051 - val_y_end_categorical_accuracy: 0.7236 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 - 797s - loss: 4.1044 - y_start_loss: 2.0818 - y_end_loss: 2.0227 - y_start_categorical_accuracy: 0.6831 - y_end_categorical_accuracy: 0.7147 - val_loss: 4.0095 - val_y_start_loss: 2.0184 - val_y_end_loss: 1.9911 - val_y_start_categorical_accuracy: 0.7122 - val_y_end_categorical_accuracy: 0.7305 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 - 795s - loss: 4.0133 - y_start_loss: 2.0336 - y_end_loss: 1.9797 - y_start_categorical_accuracy: 0.7014 - y_end_categorical_accuracy: 0.7265 - val_loss: 3.9849 - val_y_start_loss: 2.0108 - val_y_end_loss: 1.9741 - val_y_start_categorical_accuracy: 0.7147 - val_y_end_categorical_accuracy: 0.7342 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 - 797s - loss: 3.9678 - y_start_loss: 2.0118 - y_end_loss: 1.9560 - y_start_categorical_accuracy: 0.7103 - y_end_categorical_accuracy: 0.7347 - val_loss: 3.9702 - val_y_start_loss: 2.0068 - val_y_end_loss: 1.9634 - val_y_start_categorical_accuracy: 0.7132 - val_y_end_categorical_accuracy: 0.7411 - lr: 3.7500e-06
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 793s - loss: 3.9467 - y_start_loss: 2.0018 - y_end_loss: 1.9449 - y_start_categorical_accuracy: 0.7130 - y_end_categorical_accuracy: 0.7387 - val_loss: 3.9828 - val_y_start_loss: 2.0099 - val_y_end_loss: 1.9729 - val_y_start_categorical_accuracy: 0.7112 - val_y_end_categorical_accuracy: 0.7380 - lr: 1.8750e-06
# Epoch 00005: early stopping
#
# FOLD: 4
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 799s - loss: 4.7161 - y_start_loss: 2.3227 - y_end_loss: 2.3934 - y_start_categorical_accuracy: 0.6190 - y_end_categorical_accuracy: 0.6031 - val_loss: 4.1379 - val_y_start_loss: 2.0865 - val_y_end_loss: 2.0514 - val_y_start_categorical_accuracy: 0.6920 - val_y_end_categorical_accuracy: 0.7223 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 - 797s - loss: 4.1092 - y_start_loss: 2.0695 - y_end_loss: 2.0396 - y_start_categorical_accuracy: 0.6912 - y_end_categorical_accuracy: 0.7189 - val_loss: 4.0891 - val_y_start_loss: 2.0772 - val_y_end_loss: 2.0119 - val_y_start_categorical_accuracy: 0.6972 - val_y_end_categorical_accuracy: 0.7223 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 - 794s - loss: 4.0281 - y_start_loss: 2.0299 - y_end_loss: 1.9983 - y_start_categorical_accuracy: 0.7072 - y_end_categorical_accuracy: 0.7292 - val_loss: 4.0372 - val_y_start_loss: 2.0482 - val_y_end_loss: 1.9890 - val_y_start_categorical_accuracy: 0.7027 - val_y_end_categorical_accuracy: 0.7309 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 - 799s - loss: 3.9847 - y_start_loss: 2.0092 - y_end_loss: 1.9755 - y_start_categorical_accuracy: 0.7099 - y_end_categorical_accuracy: 0.7325 - val_loss: 4.0334 - val_y_start_loss: 2.0420 - val_y_end_loss: 1.9914 - val_y_start_categorical_accuracy: 0.6985 - val_y_end_categorical_accuracy: 0.7287 - lr: 3.7500e-06
# Epoch 5/6
# 687/687 - 796s - loss: 3.9614 - y_start_loss: 1.9993 - y_end_loss: 1.9621 - y_start_categorical_accuracy: 0.7112 - y_end_categorical_accuracy: 0.7372 - val_loss: 4.0294 - val_y_start_loss: 2.0422 - val_y_end_loss: 1.9872 - val_y_start_categorical_accuracy: 0.7005 - val_y_end_categorical_accuracy: 0.7305 - lr: 1.8750e-06
# Epoch 6/6
# 687/687 - 795s - loss: 3.9465 - y_start_loss: 1.9906 - y_end_loss: 1.9559 - y_start_categorical_accuracy: 0.7178 - y_end_categorical_accuracy: 0.7403 - val_loss: 4.0227 - val_y_start_loss: 2.0371 - val_y_end_loss: 1.9855 - val_y_start_categorical_accuracy: 0.7016 - val_y_end_categorical_accuracy: 0.7316 - lr: 1.0000e-06
#
# FOLD: 5
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 796s - loss: 4.7205 - y_start_loss: 2.3361 - y_end_loss: 2.3845 - y_start_categorical_accuracy: 0.6100 - y_end_categorical_accuracy: 0.5939 - val_loss: 4.0956 - val_y_start_loss: 2.0533 - val_y_end_loss: 2.0423 - val_y_start_categorical_accuracy: 0.6989 - val_y_end_categorical_accuracy: 0.7274 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 - 793s - loss: 4.1011 - y_start_loss: 2.0714 - y_end_loss: 2.0297 - y_start_categorical_accuracy: 0.6924 - y_end_categorical_accuracy: 0.7121 - val_loss: 4.0299 - val_y_start_loss: 2.0288 - val_y_end_loss: 2.0011 - val_y_start_categorical_accuracy: 0.7038 - val_y_end_categorical_accuracy: 0.7329 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 - 794s - loss: 4.0076 - y_start_loss: 2.0252 - y_end_loss: 1.9824 - y_start_categorical_accuracy: 0.7079 - y_end_categorical_accuracy: 0.7270 - val_loss: 4.0083 - val_y_start_loss: 2.0205 - val_y_end_loss: 1.9878 - val_y_start_categorical_accuracy: 0.7076 - val_y_end_categorical_accuracy: 0.7298 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 - 794s - loss: 3.9655 - y_start_loss: 2.0063 - y_end_loss: 1.9592 - y_start_categorical_accuracy: 0.7115 - y_end_categorical_accuracy: 0.7329 - val_loss: 3.9990 - val_y_start_loss: 2.0143 - val_y_end_loss: 1.9847 - val_y_start_categorical_accuracy: 0.7112 - val_y_end_categorical_accuracy: 0.7283 - lr: 3.7500e-06
# Epoch 5/6
# 687/687 - 791s - loss: 3.9420 - y_start_loss: 1.9942 - y_end_loss: 1.9478 - y_start_categorical_accuracy: 0.7162 - y_end_categorical_accuracy: 0.7384 - val_loss: 3.9892 - val_y_start_loss: 2.0122 - val_y_end_loss: 1.9770 - val_y_start_categorical_accuracy: 0.7112 - val_y_end_categorical_accuracy: 0.7273 - lr: 1.8750e-06
# Epoch 6/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 777s - loss: 3.9316 - y_start_loss: 1.9895 - y_end_loss: 1.9421 - y_start_categorical_accuracy: 0.7158 - y_end_categorical_accuracy: 0.7404 - val_loss: 3.9894 - val_y_start_loss: 2.0114 - val_y_end_loss: 1.9780 - val_y_start_categorical_accuracy: 0.7138 - val_y_end_categorical_accuracy: 0.7294 - lr: 1.0000e-06
# Epoch 00006: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col4 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col5 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col6 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col7 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col8 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col11 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row1_col12 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col9 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col10 {
#             color:  green;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_a792e71e_9098_11ea_82af_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       1.000000
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       1.000000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       0.333333
# 12       my sharpie is running dangerously low on ink  ...       0.250000
# 13  i want to go to music tonight but i lost my vo...  ...       0.333333
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 13 columns]
