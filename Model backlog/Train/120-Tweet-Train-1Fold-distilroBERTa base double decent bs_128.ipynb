# %%
# !nvidia-smi

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 645kB 9.7MB/s
#      |████████████████████████████████| 1.0MB 59.8MB/s
#      |████████████████████████████████| 890kB 27.2MB/s
#      |████████████████████████████████| 3.8MB 55.2MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/120-distilroBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/distilroberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/distilroberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 128,
  "EPOCHS": 70,
  "LEARNING_RATE": 1e-4,
  "ES_PATIENCE": None,
  "question_size": 4,
  "N_FOLDS": 1,
  "base_model_path": base_path + 'distilroberta-base-tf_model.h5',
  "config_path": base_path + 'distilroberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-7
LR_MAX = config['LEARNING_RATE']
lr_start=1e-4
warmup_epochs=0
hold_max_epochs=0
num_cycles=config['EPOCHS'] // 10
total_epochs = config['EPOCHS']

@tf.function()
def lrfn(epoch):
    if epoch < warmup_epochs:
        lr = (LR_MAX - lr_start) / (warmup_epochs * epoch + lr_start)
    else:
        progress = (epoch - warmup_epochs) / (total_epochs - warmup_epochs)
        lr = LR_MAX * (0.5 * (1.0 + tf.math.cos(np.pi * ((num_cycles * progress) % 1.0))))
        # if LR_MIN is not None:
        #     lr = max(LR_MIN, lr)
            
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:7 out of the last 7 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:9 out of the last 9 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function lrfn at 0x7f51888fa6a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Learning rate schedule: 0.0001 to 0.0001 to 2.45e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0])
                loss_end = loss_fn_end(y['y_end'], probabilities[1])
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_acc_start.update_state(y['y_start'], probabilities)
            train_acc_end.update_state(y['y_end'], probabilities)
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_acc_start.update_state(y['y_start'], probabilities)
            valid_acc_end.update_state(y['y_end'], probabilities)
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32)//step_size))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy

    train_acc_start = metrics.CategoricalAccuracy()
    valid_acc_start = metrics.CategoricalAccuracy()
    train_acc_end = metrics.CategoricalAccuracy()
    valid_acc_end = metrics.CategoricalAccuracy()
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'acc_start': train_acc_start, 'acc_end': train_acc_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end, 
                    'val_acc_start': valid_acc_start, 'val_acc_end': valid_acc_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    history_list.append(history)
    # model.load_weights(model_path)

    
    # Make predictions
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 171 steps, validate for 42 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/70
# time: 128.0s loss: 2.3083 loss_start: 1.1407 loss_end: 1.1676 acc_start: 0.3717 acc_end: 0.3714 val_loss: 1.6934 val_loss_start: 0.8743 val_loss_end: 0.8191 val_acc_start: 0.4195 val_acc_end: 0.4272
#
# EPOCH 2/70
# time: 121.8s loss: 1.6455 loss_start: 0.8488 loss_end: 0.7966 acc_start: 0.4157 acc_end: 0.4289 val_loss: 1.6299 val_loss_start: 0.8624 val_loss_end: 0.7675 val_acc_start: 0.4039 val_acc_end: 0.4168
#
# EPOCH 3/70
# time: 121.8s loss: 1.4209 loss_start: 0.7428 loss_end: 0.6781 acc_start: 0.4307 acc_end: 0.4472 val_loss: 1.7077 val_loss_start: 0.8911 val_loss_end: 0.8166 val_acc_start: 0.4212 val_acc_end: 0.4233
#
# EPOCH 4/70
# time: 121.8s loss: 1.2164 loss_start: 0.6454 loss_end: 0.5710 acc_start: 0.4510 acc_end: 0.4652 val_loss: 1.9591 val_loss_start: 1.0052 val_loss_end: 0.9540 val_acc_start: 0.4161 val_acc_end: 0.4249
#
# EPOCH 5/70
# time: 121.8s loss: 1.0118 loss_start: 0.5426 loss_end: 0.4691 acc_start: 0.4670 acc_end: 0.4831 val_loss: 2.1722 val_loss_start: 1.0558 val_loss_end: 1.1165 val_acc_start: 0.4181 val_acc_end: 0.4088
#
# EPOCH 6/70
# time: 121.8s loss: 0.7869 loss_start: 0.4308 loss_end: 0.3562 acc_start: 0.4915 acc_end: 0.5058 val_loss: 2.3963 val_loss_start: 1.2162 val_loss_end: 1.1801 val_acc_start: 0.4045 val_acc_end: 0.4156
#
# EPOCH 7/70
# time: 121.9s loss: 0.6074 loss_start: 0.3367 loss_end: 0.2707 acc_start: 0.5095 acc_end: 0.5241 val_loss: 2.7834 val_loss_start: 1.4658 val_loss_end: 1.3176 val_acc_start: 0.4009 val_acc_end: 0.4057
#
# EPOCH 8/70
# time: 121.9s loss: 0.4710 loss_start: 0.2635 loss_end: 0.2075 acc_start: 0.5280 acc_end: 0.5395 val_loss: 3.3224 val_loss_start: 1.7165 val_loss_end: 1.6059 val_acc_start: 0.4006 val_acc_end: 0.4048
#
# EPOCH 9/70
# time: 121.8s loss: 0.3885 loss_start: 0.2199 loss_end: 0.1685 acc_start: 0.5359 acc_end: 0.5464 val_loss: 3.4615 val_loss_start: 1.7296 val_loss_end: 1.7319 val_acc_start: 0.3953 val_acc_end: 0.3990
#
# EPOCH 10/70
# time: 121.9s loss: 0.3457 loss_start: 0.1987 loss_end: 0.1471 acc_start: 0.5407 acc_end: 0.5507 val_loss: 3.4558 val_loss_start: 1.7605 val_loss_end: 1.6953 val_acc_start: 0.3973 val_acc_end: 0.4000
#
# EPOCH 11/70
# time: 121.9s loss: 0.6102 loss_start: 0.3369 loss_end: 0.2733 acc_start: 0.5118 acc_end: 0.5248 val_loss: 2.7979 val_loss_start: 1.4115 val_loss_end: 1.3864 val_acc_start: 0.3995 val_acc_end: 0.4034
#
# EPOCH 12/70
# time: 121.8s loss: 0.5255 loss_start: 0.2872 loss_end: 0.2383 acc_start: 0.5224 acc_end: 0.5344 val_loss: 3.5739 val_loss_start: 1.8272 val_loss_end: 1.7468 val_acc_start: 0.4005 val_acc_end: 0.4105
#
# EPOCH 13/70
# time: 121.9s loss: 0.4212 loss_start: 0.2314 loss_end: 0.1898 acc_start: 0.5356 acc_end: 0.5438 val_loss: 3.3910 val_loss_start: 1.7921 val_loss_end: 1.5989 val_acc_start: 0.4060 val_acc_end: 0.4076
#
# EPOCH 14/70
# time: 121.8s loss: 0.3153 loss_start: 0.1756 loss_end: 0.1398 acc_start: 0.5481 acc_end: 0.5551 val_loss: 3.7697 val_loss_start: 1.9840 val_loss_end: 1.7857 val_acc_start: 0.3863 val_acc_end: 0.3912
#
# EPOCH 15/70
# time: 121.9s loss: 0.2332 loss_start: 0.1258 loss_end: 0.1074 acc_start: 0.5570 acc_end: 0.5613 val_loss: 3.6654 val_loss_start: 1.8687 val_loss_end: 1.7967 val_acc_start: 0.3903 val_acc_end: 0.3933
#
# EPOCH 16/70
# time: 121.9s loss: 0.1666 loss_start: 0.0897 loss_end: 0.0770 acc_start: 0.5652 acc_end: 0.5672 val_loss: 4.3668 val_loss_start: 2.3031 val_loss_end: 2.0637 val_acc_start: 0.3818 val_acc_end: 0.3951
#
# EPOCH 17/70
# time: 121.8s loss: 0.1243 loss_start: 0.0670 loss_end: 0.0573 acc_start: 0.5703 acc_end: 0.5721 val_loss: 4.6643 val_loss_start: 2.4071 val_loss_end: 2.2573 val_acc_start: 0.4000 val_acc_end: 0.4013
#
# EPOCH 18/70
# time: 121.8s loss: 0.0974 loss_start: 0.0505 loss_end: 0.0468 acc_start: 0.5722 acc_end: 0.5727 val_loss: 4.8793 val_loss_start: 2.4800 val_loss_end: 2.3993 val_acc_start: 0.3903 val_acc_end: 0.4020
#
# EPOCH 19/70
# time: 121.8s loss: 0.0738 loss_start: 0.0387 loss_end: 0.0351 acc_start: 0.5753 acc_end: 0.5757 val_loss: 4.9343 val_loss_start: 2.4676 val_loss_end: 2.4668 val_acc_start: 0.3967 val_acc_end: 0.4026
#
# EPOCH 20/70
# time: 121.9s loss: 0.0661 loss_start: 0.0334 loss_end: 0.0327 acc_start: 0.5776 acc_end: 0.5774 val_loss: 4.9215 val_loss_start: 2.5012 val_loss_end: 2.4203 val_acc_start: 0.4008 val_acc_end: 0.4122
#
# EPOCH 21/70
# time: 121.9s loss: 0.2134 loss_start: 0.1120 loss_end: 0.1014 acc_start: 0.5611 acc_end: 0.5623 val_loss: 3.6016 val_loss_start: 1.8476 val_loss_end: 1.7540 val_acc_start: 0.3941 val_acc_end: 0.3952
#
# EPOCH 22/70
# time: 121.9s loss: 0.2386 loss_start: 0.1258 loss_end: 0.1128 acc_start: 0.5575 acc_end: 0.5606 val_loss: 4.3167 val_loss_start: 2.2060 val_loss_end: 2.1107 val_acc_start: 0.3875 val_acc_end: 0.3810
#
# EPOCH 23/70
# time: 121.9s loss: 0.1992 loss_start: 0.1052 loss_end: 0.0940 acc_start: 0.5622 acc_end: 0.5645 val_loss: 4.2559 val_loss_start: 2.2305 val_loss_end: 2.0254 val_acc_start: 0.3978 val_acc_end: 0.4039
#
# EPOCH 24/70
# time: 121.8s loss: 0.1578 loss_start: 0.0818 loss_end: 0.0760 acc_start: 0.5672 acc_end: 0.5681 val_loss: 4.3206 val_loss_start: 2.3202 val_loss_end: 2.0003 val_acc_start: 0.4017 val_acc_end: 0.4023
#
# EPOCH 25/70
# time: 121.9s loss: 0.1181 loss_start: 0.0621 loss_end: 0.0559 acc_start: 0.5706 acc_end: 0.5716 val_loss: 4.3446 val_loss_start: 2.1849 val_loss_end: 2.1597 val_acc_start: 0.4073 val_acc_end: 0.4085
#
# EPOCH 26/70
# time: 121.8s loss: 0.0840 loss_start: 0.0446 loss_end: 0.0393 acc_start: 0.5747 acc_end: 0.5749 val_loss: 4.9353 val_loss_start: 2.5397 val_loss_end: 2.3955 val_acc_start: 0.3962 val_acc_end: 0.4020
#
# EPOCH 27/70
# time: 121.8s loss: 0.0630 loss_start: 0.0316 loss_end: 0.0314 acc_start: 0.5755 acc_end: 0.5759 val_loss: 4.9923 val_loss_start: 2.4771 val_loss_end: 2.5152 val_acc_start: 0.4023 val_acc_end: 0.4036
#
# EPOCH 28/70
# time: 121.8s loss: 0.0418 loss_start: 0.0207 loss_end: 0.0210 acc_start: 0.5784 acc_end: 0.5782 val_loss: 5.5229 val_loss_start: 2.8494 val_loss_end: 2.6736 val_acc_start: 0.3962 val_acc_end: 0.4042
#
# EPOCH 29/70
# time: 121.8s loss: 0.0360 loss_start: 0.0177 loss_end: 0.0183 acc_start: 0.5795 acc_end: 0.5792 val_loss: 5.5172 val_loss_start: 2.8208 val_loss_end: 2.6964 val_acc_start: 0.3966 val_acc_end: 0.4047
#
# EPOCH 30/70
# time: 121.8s loss: 0.0292 loss_start: 0.0141 loss_end: 0.0152 acc_start: 0.5798 acc_end: 0.5799 val_loss: 5.3210 val_loss_start: 2.7111 val_loss_end: 2.6100 val_acc_start: 0.4009 val_acc_end: 0.4076
#
# EPOCH 31/70
# time: 121.8s loss: 0.1304 loss_start: 0.0676 loss_end: 0.0628 acc_start: 0.5702 acc_end: 0.5705 val_loss: 4.2596 val_loss_start: 2.2691 val_loss_end: 1.9905 val_acc_start: 0.3971 val_acc_end: 0.3931
#
# EPOCH 32/70
# time: 121.8s loss: 0.1567 loss_start: 0.0804 loss_end: 0.0763 acc_start: 0.5672 acc_end: 0.5674 val_loss: 4.7063 val_loss_start: 2.3945 val_loss_end: 2.3118 val_acc_start: 0.3978 val_acc_end: 0.4039
#
# EPOCH 33/70
# time: 121.8s loss: 0.1327 loss_start: 0.0694 loss_end: 0.0634 acc_start: 0.5697 acc_end: 0.5706 val_loss: 4.4638 val_loss_start: 2.3147 val_loss_end: 2.1490 val_acc_start: 0.4005 val_acc_end: 0.4028
#
# EPOCH 34/70
# time: 121.8s loss: 0.1046 loss_start: 0.0532 loss_end: 0.0514 acc_start: 0.5729 acc_end: 0.5736 val_loss: 4.9384 val_loss_start: 2.4787 val_loss_end: 2.4598 val_acc_start: 0.3988 val_acc_end: 0.4056
#
# EPOCH 35/70
# time: 121.8s loss: 0.0785 loss_start: 0.0415 loss_end: 0.0370 acc_start: 0.5751 acc_end: 0.5756 val_loss: 4.8292 val_loss_start: 2.4020 val_loss_end: 2.4272 val_acc_start: 0.4155 val_acc_end: 0.4062
#
# EPOCH 36/70
# time: 121.9s loss: 0.0578 loss_start: 0.0294 loss_end: 0.0284 acc_start: 0.5771 acc_end: 0.5770 val_loss: 5.2623 val_loss_start: 2.7546 val_loss_end: 2.5077 val_acc_start: 0.3939 val_acc_end: 0.3961
#
# EPOCH 37/70
# time: 121.9s loss: 0.0449 loss_start: 0.0212 loss_end: 0.0237 acc_start: 0.5784 acc_end: 0.5784 val_loss: 5.4562 val_loss_start: 2.7909 val_loss_end: 2.6653 val_acc_start: 0.3959 val_acc_end: 0.4114
#
# EPOCH 38/70
# time: 121.8s loss: 0.0286 loss_start: 0.0141 loss_end: 0.0146 acc_start: 0.5802 acc_end: 0.5798 val_loss: 5.5862 val_loss_start: 2.7899 val_loss_end: 2.7964 val_acc_start: 0.3974 val_acc_end: 0.4024
#
# EPOCH 39/70
# time: 121.8s loss: 0.0245 loss_start: 0.0102 loss_end: 0.0143 acc_start: 0.5802 acc_end: 0.5796 val_loss: 5.6385 val_loss_start: 2.8929 val_loss_end: 2.7456 val_acc_start: 0.4023 val_acc_end: 0.4076
#
# EPOCH 40/70
# time: 121.9s loss: 0.0225 loss_start: 0.0106 loss_end: 0.0119 acc_start: 0.5810 acc_end: 0.5803 val_loss: 5.5926 val_loss_start: 2.8735 val_loss_end: 2.7191 val_acc_start: 0.4030 val_acc_end: 0.4120
#
# EPOCH 41/70
# time: 121.9s loss: 0.0909 loss_start: 0.0452 loss_end: 0.0457 acc_start: 0.5737 acc_end: 0.5740 val_loss: 4.1512 val_loss_start: 2.1882 val_loss_end: 1.9631 val_acc_start: 0.3863 val_acc_end: 0.3943
#
# EPOCH 42/70
# time: 121.9s loss: 0.1215 loss_start: 0.0639 loss_end: 0.0576 acc_start: 0.5715 acc_end: 0.5726 val_loss: 5.2788 val_loss_start: 2.6971 val_loss_end: 2.5817 val_acc_start: 0.3875 val_acc_end: 0.3947
#
# EPOCH 43/70
# time: 121.9s loss: 0.1110 loss_start: 0.0562 loss_end: 0.0548 acc_start: 0.5720 acc_end: 0.5720 val_loss: 4.3279 val_loss_start: 2.2599 val_loss_end: 2.0681 val_acc_start: 0.3986 val_acc_end: 0.4050
#
# EPOCH 44/70
# time: 121.9s loss: 0.0811 loss_start: 0.0425 loss_end: 0.0387 acc_start: 0.5751 acc_end: 0.5758 val_loss: 4.7171 val_loss_start: 2.4825 val_loss_end: 2.2345 val_acc_start: 0.4073 val_acc_end: 0.4098
#
# EPOCH 45/70
# time: 121.8s loss: 0.0560 loss_start: 0.0266 loss_end: 0.0294 acc_start: 0.5777 acc_end: 0.5774 val_loss: 5.3534 val_loss_start: 2.9294 val_loss_end: 2.4241 val_acc_start: 0.3983 val_acc_end: 0.4112
#
# EPOCH 46/70
# time: 121.9s loss: 0.0461 loss_start: 0.0230 loss_end: 0.0231 acc_start: 0.5777 acc_end: 0.5785 val_loss: 5.2085 val_loss_start: 2.5720 val_loss_end: 2.6365 val_acc_start: 0.4048 val_acc_end: 0.4106
#
# EPOCH 47/70
# time: 121.9s loss: 0.0308 loss_start: 0.0152 loss_end: 0.0156 acc_start: 0.5796 acc_end: 0.5792 val_loss: 5.7752 val_loss_start: 2.7752 val_loss_end: 3.0000 val_acc_start: 0.3987 val_acc_end: 0.4038
#
# EPOCH 48/70
# time: 121.8s loss: 0.0196 loss_start: 0.0081 loss_end: 0.0115 acc_start: 0.5810 acc_end: 0.5802 val_loss: 5.8719 val_loss_start: 3.0058 val_loss_end: 2.8661 val_acc_start: 0.3989 val_acc_end: 0.4077
#
# EPOCH 49/70
# time: 121.9s loss: 0.0185 loss_start: 0.0081 loss_end: 0.0103 acc_start: 0.5810 acc_end: 0.5805 val_loss: 5.9813 val_loss_start: 2.9881 val_loss_end: 2.9932 val_acc_start: 0.3994 val_acc_end: 0.4028
#
# EPOCH 50/70
# time: 121.9s loss: 0.0143 loss_start: 0.0060 loss_end: 0.0083 acc_start: 0.5813 acc_end: 0.5808 val_loss: 5.8969 val_loss_start: 3.0536 val_loss_end: 2.8433 val_acc_start: 0.3969 val_acc_end: 0.4049
#
# EPOCH 51/70
# time: 121.9s loss: 0.0756 loss_start: 0.0390 loss_end: 0.0366 acc_start: 0.5752 acc_end: 0.5756 val_loss: 4.9907 val_loss_start: 2.5320 val_loss_end: 2.4586 val_acc_start: 0.4050 val_acc_end: 0.4151
#
# EPOCH 52/70
# time: 121.9s loss: 0.1104 loss_start: 0.0582 loss_end: 0.0522 acc_start: 0.5713 acc_end: 0.5715 val_loss: 4.2823 val_loss_start: 2.0662 val_loss_end: 2.2160 val_acc_start: 0.3888 val_acc_end: 0.3953
#
# EPOCH 53/70
# time: 121.9s loss: 0.0953 loss_start: 0.0492 loss_end: 0.0461 acc_start: 0.5736 acc_end: 0.5743 val_loss: 4.6944 val_loss_start: 2.1701 val_loss_end: 2.5244 val_acc_start: 0.3928 val_acc_end: 0.4044
#
# EPOCH 54/70
# time: 121.9s loss: 0.0754 loss_start: 0.0379 loss_end: 0.0375 acc_start: 0.5762 acc_end: 0.5755 val_loss: 4.6661 val_loss_start: 2.4168 val_loss_end: 2.2493 val_acc_start: 0.3928 val_acc_end: 0.4024
#
# EPOCH 55/70
# time: 121.8s loss: 0.0509 loss_start: 0.0254 loss_end: 0.0255 acc_start: 0.5780 acc_end: 0.5779 val_loss: 5.2737 val_loss_start: 2.6640 val_loss_end: 2.6097 val_acc_start: 0.4011 val_acc_end: 0.4085
#
# EPOCH 56/70
# time: 121.9s loss: 0.0328 loss_start: 0.0180 loss_end: 0.0148 acc_start: 0.5795 acc_end: 0.5799 val_loss: 6.0821 val_loss_start: 3.0428 val_loss_end: 3.0393 val_acc_start: 0.3892 val_acc_end: 0.3975
#
# EPOCH 57/70
# time: 121.9s loss: 0.0242 loss_start: 0.0103 loss_end: 0.0139 acc_start: 0.5799 acc_end: 0.5794 val_loss: 5.7499 val_loss_start: 2.9663 val_loss_end: 2.7836 val_acc_start: 0.4076 val_acc_end: 0.4089
#
# EPOCH 58/70
# time: 121.9s loss: 0.0181 loss_start: 0.0078 loss_end: 0.0103 acc_start: 0.5810 acc_end: 0.5806 val_loss: 6.0941 val_loss_start: 3.1759 val_loss_end: 2.9181 val_acc_start: 0.3919 val_acc_end: 0.3988
#
# EPOCH 59/70
# time: 121.8s loss: 0.0154 loss_start: 0.0082 loss_end: 0.0073 acc_start: 0.5809 acc_end: 0.5808 val_loss: 6.1271 val_loss_start: 3.1033 val_loss_end: 3.0239 val_acc_start: 0.4024 val_acc_end: 0.4086
#
# EPOCH 60/70
# time: 121.9s loss: 0.0108 loss_start: 0.0053 loss_end: 0.0055 acc_start: 0.5816 acc_end: 0.5816 val_loss: 6.2975 val_loss_start: 3.1416 val_loss_end: 3.1559 val_acc_start: 0.3985 val_acc_end: 0.4053
#
# EPOCH 61/70
# time: 121.9s loss: 0.0648 loss_start: 0.0343 loss_end: 0.0306 acc_start: 0.5760 acc_end: 0.5767 val_loss: 4.7748 val_loss_start: 2.3038 val_loss_end: 2.4710 val_acc_start: 0.4012 val_acc_end: 0.4049
#
# EPOCH 62/70
# time: 122.0s loss: 0.0985 loss_start: 0.0483 loss_end: 0.0502 acc_start: 0.5732 acc_end: 0.5731 val_loss: 5.2236 val_loss_start: 2.6449 val_loss_end: 2.5786 val_acc_start: 0.3955 val_acc_end: 0.4020
#
# EPOCH 63/70
# time: 121.9s loss: 0.0873 loss_start: 0.0451 loss_end: 0.0422 acc_start: 0.5745 acc_end: 0.5742 val_loss: 4.2174 val_loss_start: 2.0033 val_loss_end: 2.2140 val_acc_start: 0.3980 val_acc_end: 0.4019
#
# EPOCH 64/70
# time: 121.9s loss: 0.0618 loss_start: 0.0311 loss_end: 0.0307 acc_start: 0.5772 acc_end: 0.5767 val_loss: 5.0612 val_loss_start: 2.4818 val_loss_end: 2.5794 val_acc_start: 0.4002 val_acc_end: 0.4081
#
# EPOCH 65/70
# time: 121.9s loss: 0.0454 loss_start: 0.0231 loss_end: 0.0223 acc_start: 0.5782 acc_end: 0.5780 val_loss: 5.2942 val_loss_start: 2.7162 val_loss_end: 2.5780 val_acc_start: 0.4030 val_acc_end: 0.4038
#
# EPOCH 66/70
# time: 121.9s loss: 0.0326 loss_start: 0.0153 loss_end: 0.0174 acc_start: 0.5792 acc_end: 0.5792 val_loss: 5.5775 val_loss_start: 2.8588 val_loss_end: 2.7187 val_acc_start: 0.4007 val_acc_end: 0.4093
#
# EPOCH 67/70
# time: 121.8s loss: 0.0209 loss_start: 0.0094 loss_end: 0.0116 acc_start: 0.5807 acc_end: 0.5805 val_loss: 6.1640 val_loss_start: 3.1373 val_loss_end: 3.0267 val_acc_start: 0.4074 val_acc_end: 0.4052
#
# EPOCH 68/70
# time: 121.9s loss: 0.0160 loss_start: 0.0073 loss_end: 0.0086 acc_start: 0.5809 acc_end: 0.5806 val_loss: 6.0592 val_loss_start: 3.1918 val_loss_end: 2.8674 val_acc_start: 0.3969 val_acc_end: 0.4045
#
# EPOCH 69/70
# time: 121.9s loss: 0.0111 loss_start: 0.0045 loss_end: 0.0066 acc_start: 0.5818 acc_end: 0.5815 val_loss: 6.2691 val_loss_start: 3.3234 val_loss_end: 2.9457 val_acc_start: 0.4013 val_acc_end: 0.4071
#
# EPOCH 70/70
# time: 121.9s loss: 0.0088 loss_start: 0.0035 loss_end: 0.0053 acc_start: 0.5818 acc_end: 0.5814 val_loss: 6.2783 val_loss_start: 3.2491 val_loss_end: 3.0292 val_acc_start: 0.4035 val_acc_end: 0.4049
# Training finished saved model weights at "model_fold_1.h5"
# Saved last model weights at "last_model_fold_1.h5"

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col1 {
#             color:  orange;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col2 {
#             color:  orange;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row3_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row3_col1 {
#             color:  orange;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row3_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row6_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row6_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row7_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row7_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row7_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row7_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row7_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row8_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row8_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row8_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row8_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row8_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row9_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row9_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row9_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row9_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row9_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row10_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row10_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row10_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row10_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row10_col4 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row11_col0 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row11_col1 {
#             color:  black;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row11_col2 {
#             color:  red;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row11_col3 {
#             color:  green;
#         }    #T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row11_col4 {
#             color:  black;
#         }</style><table id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col0" class="data row0 col0" >0.950215</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col1" class="data row0 col1" >0.678692</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col2" class="data row0 col2" >0.271522</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col3" class="data row0 col3" >0.950215</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row0_col4" class="data row0 col4" >0.678692</td>
#             </tr>
#             <tr>
#                         <th id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002level0_row1" class="row_heading level0 row1" >Sentiment negative</th>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col0" class="data row1 col0" >0.924290</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col1" class="data row1 col1" >0.481414</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col2" class="data row1 col2" >0.442876</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col3" class="data row1 col3" >0.924290</td>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row1_col4" class="data row1 col4" >0.481414</td>
#             </tr>
#             <tr>
#                         <th id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002level0_row2" class="row_heading level0 row2" >Sentiment neutral</th>
#                         <td id="T_d1354a02_92e2_11ea_8bb8_0242ac1c0002row2_col0" class="data row2 col0" >0.991970</td>
#                         <td id="T_d1354a02_92e2_1

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_1
# 0                 i`d have responded, if i were going  ...            1.0
# 1       sooo sad i will miss you here in san diego!!!  ...            1.0
# 2                           my boss is bullying me...  ...            1.0
# 3                      what interview! leave me alone  ...            1.0
# 4   sons of ****, why couldn`t they put them on th...  ...            1.0
# 5   http://www.dothebouncy.com/smf - some shameles...  ...            1.0
# 6   2am feedings for the baby are fun when he is a...  ...            1.0
# 7                                          soooo high  ...            1.0
# 8                                         both of you  ...            1.0
# 9   journey!? wow... u just became cooler.  hehe.....  ...            1.0
# 10  as much as i love to be hopeful, i reckon the ...  ...            1.0
# 11  i really really like the song love story by ta...  ...            1.0
# 12       my sharpie is running dangerously low on ink  ...            1.0
# 13  i want to go to music tonight but i lost my vo...  ...            1.0
# 14                         test test from the lg env2  ...            1.0
#
# [15 rows x 5 columns]
