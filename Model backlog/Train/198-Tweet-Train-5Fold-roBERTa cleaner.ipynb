# %%
# !nvidia-smi
# Out:
# Tue May 26 21:54:41 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 8.0MB/s
#      |████████████████████████████████| 1.1MB 23.3MB/s
#      |████████████████████████████████| 890kB 42.5MB/s
#      |████████████████████████████████| 3.8MB 50.7MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/198-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26891
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size * 1
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]
    
    x = layers.Dropout(.1)(h11)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True, verbose=1)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 3.98233, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_1.h5
# 672/672 - 170s - loss: 4.8543 - y_start_loss: 2.3513 - y_end_loss: 2.5030 - val_loss: 3.9823 - val_y_start_loss: 1.9883 - val_y_end_loss: 1.9940
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.98233 to 3.81200, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_1.h5
# 672/672 - 161s - loss: 3.8412 - y_start_loss: 1.9278 - y_end_loss: 1.9134 - val_loss: 3.8120 - val_y_start_loss: 1.9350 - val_y_end_loss: 1.8770
# Epoch 3/7
#
# Epoch 00003: val_loss improved from 3.81200 to 3.77879, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_1.h5
# 672/672 - 161s - loss: 3.6926 - y_start_loss: 1.8596 - y_end_loss: 1.8330 - val_loss: 3.7788 - val_y_start_loss: 1.9224 - val_y_end_loss: 1.8564
# Epoch 4/7
#
# Epoch 00004: val_loss improved from 3.77879 to 3.77403, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_1.h5
# 672/672 - 161s - loss: 3.6110 - y_start_loss: 1.8211 - y_end_loss: 1.7899 - val_loss: 3.7740 - val_y_start_loss: 1.9193 - val_y_end_loss: 1.8547
# Epoch 5/7
#
# Epoch 00005: val_loss did not improve from 3.77403
# 672/672 - 157s - loss: 3.5604 - y_start_loss: 1.7969 - y_end_loss: 1.7636 - val_loss: 3.7920 - val_y_start_loss: 1.9323 - val_y_end_loss: 1.8597
# Epoch 6/7
#
# Epoch 00006: val_loss did not improve from 3.77403
# 672/672 - 157s - loss: 3.5274 - y_start_loss: 1.7809 - y_end_loss: 1.7464 - val_loss: 3.8077 - val_y_start_loss: 1.9415 - val_y_end_loss: 1.8663
# Epoch 00006: early stopping
#
# FOLD: 2
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 3.83044, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_2.h5
# 672/672 - 168s - loss: 4.7767 - y_start_loss: 2.3458 - y_end_loss: 2.4309 - val_loss: 3.8304 - val_y_start_loss: 1.9308 - val_y_end_loss: 1.8996
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.83044 to 3.76841, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_2.h5
# 672/672 - 162s - loss: 3.8402 - y_start_loss: 1.9323 - y_end_loss: 1.9079 - val_loss: 3.7684 - val_y_start_loss: 1.9063 - val_y_end_loss: 1.8621
# Epoch 3/7
#
# Epoch 00003: val_loss improved from 3.76841 to 3.74112, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_2.h5
# 672/672 - 162s - loss: 3.7017 - y_start_loss: 1.8684 - y_end_loss: 1.8333 - val_loss: 3.7411 - val_y_start_loss: 1.8961 - val_y_end_loss: 1.8450
# Epoch 4/7
#
# Epoch 00004: val_loss did not improve from 3.74112
# 672/672 - 158s - loss: 3.6110 - y_start_loss: 1.8251 - y_end_loss: 1.7859 - val_loss: 3.7521 - val_y_start_loss: 1.8953 - val_y_end_loss: 1.8567
# Epoch 5/7
#
# Epoch 00005: val_loss did not improve from 3.74112
# 672/672 - 157s - loss: 3.5583 - y_start_loss: 1.8004 - y_end_loss: 1.7579 - val_loss: 3.7469 - val_y_start_loss: 1.8998 - val_y_end_loss: 1.8470
# Epoch 00005: early stopping
#
# FOLD: 3
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 3.83841, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_3.h5
# 672/672 - 167s - loss: 4.8389 - y_start_loss: 2.3902 - y_end_loss: 2.4488 - val_loss: 3.8384 - val_y_start_loss: 1.9414 - val_y_end_loss: 1.8970
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.83841 to 3.76645, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_3.h5
# 672/672 - 162s - loss: 3.8382 - y_start_loss: 1.9512 - y_end_loss: 1.8871 - val_loss: 3.7665 - val_y_start_loss: 1.9099 - val_y_end_loss: 1.8566
# Epoch 3/7
#
# Epoch 00003: val_loss did not improve from 3.76645
# 672/672 - 157s - loss: 3.6993 - y_start_loss: 1.8821 - y_end_loss: 1.8172 - val_loss: 3.7712 - val_y_start_loss: 1.9003 - val_y_end_loss: 1.8710
# Epoch 4/7
#
# Epoch 00004: val_loss did not improve from 3.76645
# 672/672 - 157s - loss: 3.6115 - y_start_loss: 1.8342 - y_end_loss: 1.7773 - val_loss: 3.7899 - val_y_start_loss: 1.9145 - val_y_end_loss: 1.8754
# Epoch 00004: early stopping
#
# FOLD: 4
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 3.89554, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_4.h5
# 672/672 - 168s - loss: 4.9638 - y_start_loss: 2.3980 - y_end_loss: 2.5658 - val_loss: 3.8955 - val_y_start_loss: 1.9523 - val_y_end_loss: 1.9432
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.89554 to 3.78071, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_4.h5
# 672/672 - 163s - loss: 3.9128 - y_start_loss: 1.9633 - y_end_loss: 1.9495 - val_loss: 3.7807 - val_y_start_loss: 1.9052 - val_y_end_loss: 1.8755
# Epoch 3/7
#
# Epoch 00003: val_loss improved from 3.78071 to 3.76262, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_4.h5
# 672/672 - 162s - loss: 3.7509 - y_start_loss: 1.8979 - y_end_loss: 1.8530 - val_loss: 3.7626 - val_y_start_loss: 1.8901 - val_y_end_loss: 1.8725
# Epoch 4/7
#
# Epoch 00004: val_loss improved from 3.76262 to 3.75587, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_4.h5
# 672/672 - 162s - loss: 3.6737 - y_start_loss: 1.8566 - y_end_loss: 1.8171 - val_loss: 3.7559 - val_y_start_loss: 1.8905 - val_y_end_loss: 1.8653
# Epoch 5/7
#
# Epoch 00005: val_loss did not improve from 3.75587
# 672/672 - 158s - loss: 3.6358 - y_start_loss: 1.8374 - y_end_loss: 1.7984 - val_loss: 3.7637 - val_y_start_loss: 1.8909 - val_y_end_loss: 1.8728
# Epoch 6/7
#
# Epoch 00006: val_loss improved from 3.75587 to 3.74810, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_4.h5
# 672/672 - 163s - loss: 3.6033 - y_start_loss: 1.8197 - y_end_loss: 1.7836 - val_loss: 3.7481 - val_y_start_loss: 1.8921 - val_y_end_loss: 1.8560
# Epoch 7/7
#
# Epoch 00007: val_loss did not improve from 3.74810
# 672/672 - 158s - loss: 3.5860 - y_start_loss: 1.8166 - y_end_loss: 1.7695 - val_loss: 3.7580 - val_y_start_loss: 1.8922 - val_y_end_loss: 1.8659
#
# FOLD: 5
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 3.85131, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_5.h5
# 672/672 - 169s - loss: 4.8064 - y_start_loss: 2.3538 - y_end_loss: 2.4526 - val_loss: 3.8513 - val_y_start_loss: 1.9462 - val_y_end_loss: 1.9051
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.85131 to 3.75969, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/198-roBERTa_base/model_fold_5.h5
# 672/672 - 163s - loss: 3.8179 - y_start_loss: 1.9292 - y_end_loss: 1.8888 - val_loss: 3.7597 - val_y_start_loss: 1.8950 - val_y_end_loss: 1.8647
# Epoch 3/7
#
# Epoch 00003: val_loss did not improve from 3.75969
# 672/672 - 158s - loss: 3.6922 - y_start_loss: 1.8683 - y_end_loss: 1.8239 - val_loss: 3.7764 - val_y_start_loss: 1.9011 - val_y_end_loss: 1.8753
# Epoch 4/7
#
# Epoch 00004: val_loss did not improve from 3.75969
# 672/672 - 158s - loss: 3.6042 - y_start_loss: 1.8254 - y_end_loss: 1.7788 - val_loss: 3.7857 - val_y_start_loss: 1.9068 - val_y_end_loss: 1.8789
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_06c18066_9fa7_11ea_b854_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... imputed
# 0                 i`d have responded, if i were going  ...   False
# 1       sooo sad i will miss you here in san diego!!!  ...   False
# 2                           my boss is bullying me...  ...   False
# 3                      what interview! leave me alone  ...   False
# 4   sons of ****, why couldn`t they put them on th...  ...   False
# 5   http://www.dothebouncy.com/smf - some shameles...  ...   False
# 6   2am feedings for the baby are fun when he is a...  ...   False
# 7                                          soooo high  ...   False
# 8                                         both of you  ...   False
# 9   journey!? wow... u just became cooler.  hehe.....  ...   False
# 10  as much as i love to be hopeful, i reckon the ...  ...   False
# 11  i really really like the song love story by ta...  ...   False
# 12       my sharpie is running dangerously low on ink  ...   False
# 13  i want to go to music tonight but i lost my vo...  ...   False
# 14                         test test from the lg env2  ...   False
#
# [15 rows x 7 columns]
