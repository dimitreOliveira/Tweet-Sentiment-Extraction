# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN, dropout_ratio=.1):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(dropout_ratio)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(dropout_ratio)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Train

# %%
base_data_path = 'fold_1/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
#     base_data_path = 'fold_%d/' % (n_fold)
#     x_train = np.load(base_data_path + 'x_train.npy')
#     y_train = np.load(base_data_path + 'y_train.npy')
#     x_valid = np.load(base_data_path + 'x_valid.npy')
#     y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
#     shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    print('Experiment %d' % n_fold)
    dropout_ratio = .1 * n_fold
    print(base_data_path, dropout_ratio)
    
    model = model_fn(config['MAX_LEN'], dropout_ratio)
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Experiment 1
# fold_1/ 0.1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 287s - loss: 4.4587 - y_start_loss: 2.2138 - y_end_loss: 2.2449 - y_start_categorical_accuracy: 0.6482 - y_end_categorical_accuracy: 0.6471 - val_loss: 4.0409 - val_y_start_loss: 2.0341 - val_y_end_loss: 2.0064 - val_y_start_categorical_accuracy: 0.7096 - val_y_end_categorical_accuracy: 0.7172
# Epoch 2/6
# 21984/21984 - 272s - loss: 4.0110 - y_start_loss: 2.0138 - y_end_loss: 1.9972 - y_start_categorical_accuracy: 0.7089 - y_end_categorical_accuracy: 0.7234 - val_loss: 3.9786 - val_y_start_loss: 2.0048 - val_y_end_loss: 1.9734 - val_y_start_categorical_accuracy: 0.7096 - val_y_end_categorical_accuracy: 0.7285
# Epoch 3/6
# 21984/21984 - 272s - loss: 3.8970 - y_start_loss: 1.9672 - y_end_loss: 1.9298 - y_start_categorical_accuracy: 0.7256 - y_end_categorical_accuracy: 0.7457 - val_loss: 3.9673 - val_y_start_loss: 1.9998 - val_y_end_loss: 1.9671 - val_y_start_categorical_accuracy: 0.7189 - val_y_end_categorical_accuracy: 0.7287
# Epoch 4/6
# 21984/21984 - 272s - loss: 3.8333 - y_start_loss: 1.9364 - y_end_loss: 1.8969 - y_start_categorical_accuracy: 0.7389 - y_end_categorical_accuracy: 0.7601 - val_loss: 3.9536 - val_y_start_loss: 1.9960 - val_y_end_loss: 1.9573 - val_y_start_categorical_accuracy: 0.7158 - val_y_end_categorical_accuracy: 0.7325
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.7996 - y_start_loss: 1.9199 - y_end_loss: 1.8797 - y_start_categorical_accuracy: 0.7400 - y_end_categorical_accuracy: 0.7714 - val_loss: 3.9690 - val_y_start_loss: 2.0034 - val_y_end_loss: 1.9652 - val_y_start_categorical_accuracy: 0.7176 - val_y_end_categorical_accuracy: 0.7334
# Epoch 00005: early stopping
#
# FOLD: 2
# Experiment 2
# fold_1/ 0.2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 285s - loss: 4.4485 - y_start_loss: 2.2133 - y_end_loss: 2.2353 - y_start_categorical_accuracy: 0.6501 - y_end_categorical_accuracy: 0.6514 - val_loss: 4.0142 - val_y_start_loss: 2.0273 - val_y_end_loss: 1.9864 - val_y_start_categorical_accuracy: 0.7098 - val_y_end_categorical_accuracy: 0.7229
# Epoch 2/6
# 21984/21984 - 271s - loss: 3.9781 - y_start_loss: 2.0118 - y_end_loss: 1.9663 - y_start_categorical_accuracy: 0.7096 - y_end_categorical_accuracy: 0.7298 - val_loss: 3.9593 - val_y_start_loss: 1.9998 - val_y_end_loss: 1.9592 - val_y_start_categorical_accuracy: 0.7138 - val_y_end_categorical_accuracy: 0.7269
# Epoch 3/6
# 21984/21984 - 272s - loss: 3.8745 - y_start_loss: 1.9627 - y_end_loss: 1.9118 - y_start_categorical_accuracy: 0.7231 - y_end_categorical_accuracy: 0.7530 - val_loss: 3.9459 - val_y_start_loss: 1.9946 - val_y_end_loss: 1.9510 - val_y_start_categorical_accuracy: 0.7162 - val_y_end_categorical_accuracy: 0.7318
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 3.8068 - y_start_loss: 1.9277 - y_end_loss: 1.8791 - y_start_categorical_accuracy: 0.7403 - y_end_categorical_accuracy: 0.7680 - val_loss: 3.9493 - val_y_start_loss: 1.9969 - val_y_end_loss: 1.9520 - val_y_start_categorical_accuracy: 0.7114 - val_y_end_categorical_accuracy: 0.7351
# Epoch 00004: early stopping
#
# FOLD: 3
# Experiment 3
# fold_1/ 0.30000000000000004
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 287s - loss: 4.5679 - y_start_loss: 2.2897 - y_end_loss: 2.2782 - y_start_categorical_accuracy: 0.6363 - y_end_categorical_accuracy: 0.6388 - val_loss: 4.0439 - val_y_start_loss: 2.0479 - val_y_end_loss: 1.9955 - val_y_start_categorical_accuracy: 0.7089 - val_y_end_categorical_accuracy: 0.7223
# Epoch 2/6
# 21984/21984 - 273s - loss: 4.0319 - y_start_loss: 2.0455 - y_end_loss: 1.9864 - y_start_categorical_accuracy: 0.6985 - y_end_categorical_accuracy: 0.7248 - val_loss: 3.9765 - val_y_start_loss: 2.0062 - val_y_end_loss: 1.9698 - val_y_start_categorical_accuracy: 0.7200 - val_y_end_categorical_accuracy: 0.7282
# Epoch 3/6
# 21984/21984 - 272s - loss: 3.9128 - y_start_loss: 1.9853 - y_end_loss: 1.9275 - y_start_categorical_accuracy: 0.7166 - y_end_categorical_accuracy: 0.7477 - val_loss: 3.9598 - val_y_start_loss: 2.0029 - val_y_end_loss: 1.9565 - val_y_start_categorical_accuracy: 0.7167 - val_y_end_categorical_accuracy: 0.7302
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.8472 - y_start_loss: 1.9523 - y_end_loss: 1.8949 - y_start_categorical_accuracy: 0.7317 - y_end_categorical_accuracy: 0.7619 - val_loss: 3.9638 - val_y_start_loss: 2.0065 - val_y_end_loss: 1.9568 - val_y_start_categorical_accuracy: 0.7167 - val_y_end_categorical_accuracy: 0.7324
# Epoch 00004: early stopping
#
# FOLD: 4
# Experiment 4
# fold_1/ 0.4
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 286s - loss: 4.7002 - y_start_loss: 2.3131 - y_end_loss: 2.3871 - y_start_categorical_accuracy: 0.6323 - y_end_categorical_accuracy: 0.6152 - val_loss: 4.1042 - val_y_start_loss: 2.0490 - val_y_end_loss: 2.0548 - val_y_start_categorical_accuracy: 0.7100 - val_y_end_categorical_accuracy: 0.6960
# Epoch 2/6
# 21984/21984 - 272s - loss: 4.0869 - y_start_loss: 2.0499 - y_end_loss: 2.0370 - y_start_categorical_accuracy: 0.7006 - y_end_categorical_accuracy: 0.7107 - val_loss: 4.0041 - val_y_start_loss: 2.0171 - val_y_end_loss: 1.9867 - val_y_start_categorical_accuracy: 0.7162 - val_y_end_categorical_accuracy: 0.7265
# Epoch 3/6
# 21984/21984 - 272s - loss: 3.9678 - y_start_loss: 1.9985 - y_end_loss: 1.9693 - y_start_categorical_accuracy: 0.7178 - y_end_categorical_accuracy: 0.7334 - val_loss: 3.9937 - val_y_start_loss: 2.0083 - val_y_end_loss: 1.9850 - val_y_start_categorical_accuracy: 0.7169 - val_y_end_categorical_accuracy: 0.7198
# Epoch 4/6
# 21984/21984 - 271s - loss: 3.9054 - y_start_loss: 1.9696 - y_end_loss: 1.9358 - y_start_categorical_accuracy: 0.7270 - y_end_categorical_accuracy: 0.7458 - val_loss: 3.9738 - val_y_start_loss: 2.0043 - val_y_end_loss: 1.9692 - val_y_start_categorical_accuracy: 0.7194 - val_y_end_categorical_accuracy: 0.7240
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.8727 - y_start_loss: 1.9551 - y_end_loss: 1.9176 - y_start_categorical_accuracy: 0.7313 - y_end_categorical_accuracy: 0.7525 - val_loss: 3.9914 - val_y_start_loss: 2.0148 - val_y_end_loss: 1.9762 - val_y_start_categorical_accuracy: 0.7169 - val_y_end_categorical_accuracy: 0.7258
# Epoch 00005: early stopping
#
# FOLD: 5
# Experiment 5
# fold_1/ 0.5
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 285s - loss: 4.5384 - y_start_loss: 2.2508 - y_end_loss: 2.2876 - y_start_categorical_accuracy: 0.6459 - y_end_categorical_accuracy: 0.6421 - val_loss: 4.0266 - val_y_start_loss: 2.0268 - val_y_end_loss: 1.9994 - val_y_start_categorical_accuracy: 0.7089 - val_y_end_categorical_accuracy: 0.7213
# Epoch 2/6
# 21984/21984 - 272s - loss: 4.0598 - y_start_loss: 2.0369 - y_end_loss: 2.0229 - y_start_categorical_accuracy: 0.7010 - y_end_categorical_accuracy: 0.7157 - val_loss: 3.9804 - val_y_start_loss: 2.0043 - val_y_end_loss: 1.9756 - val_y_start_categorical_accuracy: 0.7134 - val_y_end_categorical_accuracy: 0.7265
# Epoch 3/6
# 21984/21984 - 271s - loss: 3.9452 - y_start_loss: 1.9887 - y_end_loss: 1.9565 - y_start_categorical_accuracy: 0.7186 - y_end_categorical_accuracy: 0.7394 - val_loss: 3.9676 - val_y_start_loss: 2.0004 - val_y_end_loss: 1.9667 - val_y_start_categorical_accuracy: 0.7158 - val_y_end_categorical_accuracy: 0.7289
# Epoch 4/6
# 21984/21984 - 272s - loss: 3.8816 - y_start_loss: 1.9586 - y_end_loss: 1.9231 - y_start_categorical_accuracy: 0.7332 - y_end_categorical_accuracy: 0.7518 - val_loss: 3.9557 - val_y_start_loss: 1.9986 - val_y_end_loss: 1.9567 - val_y_start_categorical_accuracy: 0.7154 - val_y_end_categorical_accuracy: 0.7314
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 3.8424 - y_start_loss: 1.9394 - y_end_loss: 1.9030 - y_start_categorical_accuracy: 0.7346 - y_end_categorical_accuracy: 0.7571 - val_loss: 3.9767 - val_y_start_loss: 2.0081 - val_y_end_loss: 1.9681 - val_y_start_categorical_accuracy: 0.7136 - val_y_end_categorical_accuracy: 0.7269
# Epoch 00005: early stopping

# %%
shutil.rmtree(base_data_path)

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col0 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col1 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col5 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col6 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col7 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col8 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col9 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col10 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col11 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row0_col12 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col0 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col1 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col4 {
#             color:  green;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col5 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col6 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col7 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col8 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col9 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col10 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col11 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row1_col12 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col0 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col5 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col7 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col9 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col11 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col0 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col1 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col5 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col6 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col7 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col8 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col9 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col10 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col11 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row3_col12 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col5 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col6 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col7 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col8 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col9 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col10 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col11 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row4_col12 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col0 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col1 {
#             color:  orange;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col5 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col6 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col7 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col8 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col9 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col10 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col11 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row5_col12 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col0 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col1 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col5 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col6 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col7 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col8 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0242ac130202row6_col9 {
#             color:  red;
#         }    #T_cab09378_8bc9_11ea_a7c0_0

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going            1.00
# 1                                                 sad            0.50
# 2                                            bullying            0.50
# 3                                      leave me alone            1.00
# 4                                       sons of ****,            1.00
# 5   http://www.dothebouncy.com/smf - some shameles...            1.00
# 6                                                 fun            1.00
# 7                                          soooo high            1.00
# 8                                         both of you            1.00
# 9                                              wow...            0.20
# 10  as much as i love to be hopeful, i reckon the ...            1.00
# 11                                               like            1.00
# 12                             dangerously low on ink            0.25
# 13                                               lost            1.00
# 14                         test test from the lg env2            1.00
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                         i will miss        0.000000
# 2                                          my boss is        0.000000
# 3                                               alone        0.333333
# 4                                          why couldn        0.000000
# 5                                         http://www.        0.000000
# 6   2am feedings for the baby are fun when he is a...        0.071429
# 7                                                            0.000000
# 8                                                            0.000000
# 9   journey!? wow... u just became cooler.  hehe.....        0.500000
# 10                                                           0.000000
# 11                                    i really really        0.000000
# 12                                         my sharpie        0.000000
# 13                       to go to music tonight but i        0.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                         i will miss        0.000000
# 2                                      bullying me...        0.333333
# 3                               what interview! leave        0.200000
# 4                                        sons of ****        0.500000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                                               env2        0.200000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                                                 i`d        0.142857
# 1                sooo sad i will miss you here in san        0.222222
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5                                             theboun        0.000000
# 6   2am feedings for the baby are fun when he is a...        0.071429
# 7                                                            0.000000
# 8                                         both of you        1.000000
# 9                                       journey!? wow        0.000000
# 10                                               as i        0.095238
# 11                                              swift        0.000000
# 12       my sharpie is running dangerously low on ink        0.125000
# 13                                                           0.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                         i will miss        0.000000
# 2                                      bullying me...        0.333333
# 3                               what interview! leave        0.200000
# 4   sons of ****, why couldn`t they put them on th...        0.214286
# 5                                                   y        0.000000
# 6                                            2am feed        0.000000
# 7                                                            0.000000
# 8                                         both of you        1.000000
# 9                                       journey!? wow        0.000000
# 10                                               as i        0.095238
# 11  i really really like the song love story by ta...        0.100000
# 12                                      my sharpie is        0.000000
# 13                                music tonight but i        0.000000
# 14                                                           0.000000
