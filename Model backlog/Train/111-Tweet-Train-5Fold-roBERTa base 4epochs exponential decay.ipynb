# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers|
# Out:
#      |████████████████████████████████| 645kB 9.2MB/s
#      |████████████████████████████████| 3.8MB 45.0MB/s
#      |████████████████████████████████| 1.0MB 50.0MB/s
#      |████████████████████████████████| 890kB 62.1MB/s
#   Building wheel for sacremoses (setup.py) ... done
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/111-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 4,
  "LEARNING_RATE": 3e-5,
  # "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 3.75e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    # es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
    #                    restore_best_weights=True, verbose=1)
    # checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
    #                              save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        # callbacks=[checkpoint, es, lr_schedule],
                        callbacks=[lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH + model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 268s - loss: 4.4455 - y_start_loss: 2.2089 - y_end_loss: 2.2366 - y_start_categorical_accuracy: 0.6543 - y_end_categorical_accuracy: 0.6545 - val_loss: 4.0371 - val_y_start_loss: 2.0362 - val_y_end_loss: 2.0009 - val_y_start_categorical_accuracy: 0.7029 - val_y_end_categorical_accuracy: 0.7187 - lr: 3.0000e-05
# Epoch 2/4
# 687/687 - 266s - loss: 4.0098 - y_start_loss: 2.0228 - y_end_loss: 1.9871 - y_start_categorical_accuracy: 0.7051 - y_end_categorical_accuracy: 0.7258 - val_loss: 4.0086 - val_y_start_loss: 2.0256 - val_y_end_loss: 1.9830 - val_y_start_categorical_accuracy: 0.7083 - val_y_end_categorical_accuracy: 0.7236 - lr: 1.5000e-05
# Epoch 3/4
# 687/687 - 266s - loss: 3.8975 - y_start_loss: 1.9686 - y_end_loss: 1.9289 - y_start_categorical_accuracy: 0.7253 - y_end_categorical_accuracy: 0.7499 - val_loss: 3.9968 - val_y_start_loss: 2.0104 - val_y_end_loss: 1.9864 - val_y_start_categorical_accuracy: 0.7163 - val_y_end_categorical_accuracy: 0.7274 - lr: 7.5000e-06
# Epoch 4/4
# 687/687 - 266s - loss: 3.8383 - y_start_loss: 1.9415 - y_end_loss: 1.8968 - y_start_categorical_accuracy: 0.7371 - y_end_categorical_accuracy: 0.7644 - val_loss: 3.9738 - val_y_start_loss: 2.0046 - val_y_end_loss: 1.9693 - val_y_start_categorical_accuracy: 0.7178 - val_y_end_categorical_accuracy: 0.7287 - lr: 3.7500e-06
#
# FOLD: 2
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 269s - loss: 4.4406 - y_start_loss: 2.2041 - y_end_loss: 2.2365 - y_start_categorical_accuracy: 0.6541 - y_end_categorical_accuracy: 0.6519 - val_loss: 4.0736 - val_y_start_loss: 2.0484 - val_y_end_loss: 2.0252 - val_y_start_categorical_accuracy: 0.6949 - val_y_end_categorical_accuracy: 0.7107 - lr: 3.0000e-05
# Epoch 2/4
# 687/687 - 266s - loss: 4.0027 - y_start_loss: 2.0153 - y_end_loss: 1.9874 - y_start_categorical_accuracy: 0.7074 - y_end_categorical_accuracy: 0.7253 - val_loss: 4.0343 - val_y_start_loss: 2.0353 - val_y_end_loss: 1.9990 - val_y_start_categorical_accuracy: 0.7001 - val_y_end_categorical_accuracy: 0.7189 - lr: 1.5000e-05
# Epoch 3/4
# 687/687 - 266s - loss: 3.8990 - y_start_loss: 1.9670 - y_end_loss: 1.9320 - y_start_categorical_accuracy: 0.7267 - y_end_categorical_accuracy: 0.7481 - val_loss: 4.0376 - val_y_start_loss: 2.0370 - val_y_end_loss: 2.0006 - val_y_start_categorical_accuracy: 0.7060 - val_y_end_categorical_accuracy: 0.7227 - lr: 7.5000e-06
# Epoch 4/4
# 687/687 - 266s - loss: 3.8365 - y_start_loss: 1.9392 - y_end_loss: 1.8973 - y_start_categorical_accuracy: 0.7325 - y_end_categorical_accuracy: 0.7557 - val_loss: 4.0369 - val_y_start_loss: 2.0289 - val_y_end_loss: 2.0080 - val_y_start_categorical_accuracy: 0.7105 - val_y_end_categorical_accuracy: 0.7269 - lr: 3.7500e-06
#
# FOLD: 3
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 268s - loss: 4.4472 - y_start_loss: 2.2226 - y_end_loss: 2.2247 - y_start_categorical_accuracy: 0.6486 - y_end_categorical_accuracy: 0.6542 - val_loss: 4.0073 - val_y_start_loss: 2.0190 - val_y_end_loss: 1.9882 - val_y_start_categorical_accuracy: 0.7118 - val_y_end_categorical_accuracy: 0.7354 - lr: 3.0000e-05
# Epoch 2/4
# 687/687 - 266s - loss: 3.9835 - y_start_loss: 2.0131 - y_end_loss: 1.9704 - y_start_categorical_accuracy: 0.7051 - y_end_categorical_accuracy: 0.7284 - val_loss: 3.9642 - val_y_start_loss: 2.0015 - val_y_end_loss: 1.9627 - val_y_start_categorical_accuracy: 0.7123 - val_y_end_categorical_accuracy: 0.7414 - lr: 1.5000e-05
# Epoch 3/4
# 687/687 - 266s - loss: 3.8620 - y_start_loss: 1.9557 - y_end_loss: 1.9063 - y_start_categorical_accuracy: 0.7299 - y_end_categorical_accuracy: 0.7545 - val_loss: 3.9640 - val_y_start_loss: 2.0067 - val_y_end_loss: 1.9573 - val_y_start_categorical_accuracy: 0.7171 - val_y_end_categorical_accuracy: 0.7378 - lr: 7.5000e-06
# Epoch 4/4
# 687/687 - 266s - loss: 3.7960 - y_start_loss: 1.9225 - y_end_loss: 1.8735 - y_start_categorical_accuracy: 0.7434 - y_end_categorical_accuracy: 0.7682 - val_loss: 3.9815 - val_y_start_loss: 2.0154 - val_y_end_loss: 1.9662 - val_y_start_categorical_accuracy: 0.7183 - val_y_end_categorical_accuracy: 0.7404 - lr: 3.7500e-06
#
# FOLD: 4
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 269s - loss: 4.4393 - y_start_loss: 2.2115 - y_end_loss: 2.2278 - y_start_categorical_accuracy: 0.6507 - y_end_categorical_accuracy: 0.6524 - val_loss: 4.0498 - val_y_start_loss: 2.0483 - val_y_end_loss: 2.0014 - val_y_start_categorical_accuracy: 0.6994 - val_y_end_categorical_accuracy: 0.7253 - lr: 3.0000e-05
# Epoch 2/4
# 687/687 - 266s - loss: 3.9860 - y_start_loss: 2.0129 - y_end_loss: 1.9731 - y_start_categorical_accuracy: 0.7070 - y_end_categorical_accuracy: 0.7321 - val_loss: 4.0328 - val_y_start_loss: 2.0495 - val_y_end_loss: 1.9834 - val_y_start_categorical_accuracy: 0.6994 - val_y_end_categorical_accuracy: 0.7276 - lr: 1.5000e-05
# Epoch 3/4
# 687/687 - 266s - loss: 3.8856 - y_start_loss: 1.9605 - y_end_loss: 1.9250 - y_start_categorical_accuracy: 0.7272 - y_end_categorical_accuracy: 0.7470 - val_loss: 3.9897 - val_y_start_loss: 2.0273 - val_y_end_loss: 1.9624 - val_y_start_categorical_accuracy: 0.6994 - val_y_end_categorical_accuracy: 0.7309 - lr: 7.5000e-06
# Epoch 4/4
# 687/687 - 266s - loss: 3.8243 - y_start_loss: 1.9300 - y_end_loss: 1.8944 - y_start_categorical_accuracy: 0.7402 - y_end_categorical_accuracy: 0.7568 - val_loss: 3.9981 - val_y_start_loss: 2.0291 - val_y_end_loss: 1.9690 - val_y_start_categorical_accuracy: 0.7034 - val_y_end_categorical_accuracy: 0.7283 - lr: 3.7500e-06
#
# FOLD: 5
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 269s - loss: 4.3995 - y_start_loss: 2.1954 - y_end_loss: 2.2041 - y_start_categorical_accuracy: 0.6553 - y_end_categorical_accuracy: 0.6545 - val_loss: 4.0225 - val_y_start_loss: 2.0232 - val_y_end_loss: 1.9993 - val_y_start_categorical_accuracy: 0.7007 - val_y_end_categorical_accuracy: 0.7205 - lr: 3.0000e-05
# Epoch 2/4
# 687/687 - 267s - loss: 3.9809 - y_start_loss: 2.0090 - y_end_loss: 1.9719 - y_start_categorical_accuracy: 0.7114 - y_end_categorical_accuracy: 0.7279 - val_loss: 3.9983 - val_y_start_loss: 2.0086 - val_y_end_loss: 1.9896 - val_y_start_categorical_accuracy: 0.7094 - val_y_end_categorical_accuracy: 0.7313 - lr: 1.5000e-05
# Epoch 3/4
# 687/687 - 267s - loss: 3.8693 - y_start_loss: 1.9566 - y_end_loss: 1.9127 - y_start_categorical_accuracy: 0.7290 - y_end_categorical_accuracy: 0.7542 - val_loss: 3.9721 - val_y_start_loss: 2.0058 - val_y_end_loss: 1.9663 - val_y_start_categorical_accuracy: 0.7134 - val_y_end_categorical_accuracy: 0.7287 - lr: 7.5000e-06
# Epoch 4/4
# 687/687 - 268s - loss: 3.8072 - y_start_loss: 1.9261 - y_end_loss: 1.8810 - y_start_categorical_accuracy: 0.7404 - y_end_categorical_accuracy: 0.7675 - val_loss: 3.9724 - val_y_start_loss: 2.0048 - val_y_end_loss: 1.9677 - val_y_start_categorical_accuracy: 0.7127 - val_y_end_categorical_accuracy: 0.7345 - lr: 3.7500e-06

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col4 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col5 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col6 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col7 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col8 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col11 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row1_col12 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col9 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col10 {
#             color:  green;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_c12c576e_916a_11ea_990c_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       0.333333
# 12       my sharpie is running dangerously low on ink  ...       0.250000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 13 columns]
