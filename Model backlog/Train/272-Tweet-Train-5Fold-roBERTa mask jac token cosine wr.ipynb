# %%
# !nvidia-smi
# Out:
# Thu Jun 11 17:42:15 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 675kB 4.6MB/s
#      |████████████████████████████████| 890kB 20.8MB/s
#      |████████████████████████████████| 3.8MB 36.7MB/s
#      |████████████████████████████████| 1.1MB 39.5MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/272-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size
num_cycles = 6

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [cosine_with_hard_restarts_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                                    warmup_steps=warmup_steps, lr_start=lr_start, 
                                                    lr_max=lr_max, lr_min=lr_min, num_cycles=num_cycles) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 5e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(3, use_bias=False, name='qa_outputs')(last_hidden_state)

    start_logits, end_logits, mask_logits = tf.split(logits, 3, axis=-1, name='logits')
    start_logits = tf.squeeze(start_logits, axis=-1, name='y_start')
    end_logits = tf.squeeze(end_logits, axis=-1, name='y_end')
    mask_logits = tf.squeeze(mask_logits, axis=-1, name='y_mask')

    x_aux = layers.GlobalAveragePooling1D()(last_hidden_state)

    y_jaccard = layers.Dense(1, activation='linear', name='y_jaccard')(x_aux)
    y_tokenCnt = layers.Dense(1, activation='linear', name='y_tokenCnt')(x_aux)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits, mask_logits, y_jaccard, y_tokenCnt])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1], y_train[2], y_train[3], y_train[4])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1], y_valid[2], y_valid[3], y_valid[4])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print(f'\nFOLD: {n_fold}')
    
    # Load data
    base_data_path = f'fold_{n_fold}/'
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    y_train_mask = np.load(base_data_path + 'y_train_mask.npy')
    y_train_aux = np.load(base_data_path + 'y_train_aux.npy')
    y_train_jaccard = y_train_aux[0]
    y_train_token = y_train_aux[2]

    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    y_valid_mask = np.load(base_data_path + 'y_valid_mask.npy')
    y_valid_aux = np.load(base_data_path + 'y_valid_aux.npy')
    y_valid_jaccard = y_valid_aux[0]
    y_valid_token = y_valid_aux[2]
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = f'model_fold_{n_fold}.h5'
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                      restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                save_best_only=True, save_weights_only=True)
    
    lr = lambda: cosine_with_hard_restarts_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                total_steps=total_steps, warmup_steps=warmup_steps, 
                                                                lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, 
                                                                num_cycles=num_cycles)
    
    optimizer = optimizers.Adam(learning_rate=lr)
    
    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.BinaryCrossentropy(from_logits=True),
                                   losses.MeanAbsoluteError(),
                                   losses.MeanAbsoluteError()],
                             loss_weights=[1., 1., 1., 0.25, 0.25])
    
    history = model.fit(get_training_dataset(x_train, (*y_train, y_train_mask, y_train_jaccard, y_train_token), 
                                             config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, (*y_valid, y_valid_mask, y_valid_jaccard, y_valid_token), 
                                                                config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 180s - loss: 6.1388 - tf_op_layer_y_start_2_loss: 2.3019 - tf_op_layer_y_end_2_loss: 2.3548 - tf_op_layer_y_mask_2_loss: 0.2339 - y_jaccard_loss: 0.2498 - y_tokenCnt_loss: 4.7434 - val_loss: 4.7590 - val_tf_op_layer_y_start_2_loss: 1.9702 - val_tf_op_layer_y_end_2_loss: 1.9524 - val_tf_op_layer_y_mask_2_loss: 0.1032 - val_y_jaccard_loss: 0.1815 - val_y_tokenCnt_loss: 2.7514
# Epoch 2/7
# 672/672 - 178s - loss: 4.5985 - tf_op_layer_y_start_2_loss: 1.9193 - tf_op_layer_y_end_2_loss: 1.8996 - tf_op_layer_y_mask_2_loss: 0.0990 - y_jaccard_loss: 0.1585 - y_tokenCnt_loss: 2.5638 - val_loss: 4.5418 - val_tf_op_layer_y_start_2_loss: 1.9202 - val_tf_op_layer_y_end_2_loss: 1.8628 - val_tf_op_layer_y_mask_2_loss: 0.0946 - val_y_jaccard_loss: 0.1576 - val_y_tokenCnt_loss: 2.4991
# Epoch 3/7
# 672/672 - 177s - loss: 4.4456 - tf_op_layer_y_start_2_loss: 1.8711 - tf_op_layer_y_end_2_loss: 1.8349 - tf_op_layer_y_mask_2_loss: 0.0923 - y_jaccard_loss: 0.1515 - y_tokenCnt_loss: 2.4378 - val_loss: 4.4992 - val_tf_op_layer_y_start_2_loss: 1.9088 - val_tf_op_layer_y_end_2_loss: 1.8503 - val_tf_op_layer_y_mask_2_loss: 0.0928 - val_y_jaccard_loss: 0.1523 - val_y_tokenCnt_loss: 2.4369
# Epoch 4/7
# 672/672 - 173s - loss: 4.3682 - tf_op_layer_y_start_2_loss: 1.8436 - tf_op_layer_y_end_2_loss: 1.8105 - tf_op_layer_y_mask_2_loss: 0.0896 - y_jaccard_loss: 0.1479 - y_tokenCnt_loss: 2.3500 - val_loss: 4.5081 - val_tf_op_layer_y_start_2_loss: 1.9181 - val_tf_op_layer_y_end_2_loss: 1.8594 - val_tf_op_layer_y_mask_2_loss: 0.0924 - val_y_jaccard_loss: 0.1519 - val_y_tokenCnt_loss: 2.4004
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 173s - loss: 4.2831 - tf_op_layer_y_start_2_loss: 1.8180 - tf_op_layer_y_end_2_loss: 1.7776 - tf_op_layer_y_mask_2_loss: 0.0864 - y_jaccard_loss: 0.1433 - y_tokenCnt_loss: 2.2615 - val_loss: 4.5233 - val_tf_op_layer_y_start_2_loss: 1.9212 - val_tf_op_layer_y_end_2_loss: 1.8671 - val_tf_op_layer_y_mask_2_loss: 0.0927 - val_y_jaccard_loss: 0.1486 - val_y_tokenCnt_loss: 2.4206
# Epoch 00005: early stopping
#
# FOLD: 2
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 177s - loss: 6.0642 - tf_op_layer_y_start_3_loss: 2.2844 - tf_op_layer_y_end_3_loss: 2.3332 - tf_op_layer_y_mask_3_loss: 0.1958 - y_jaccard_loss: 0.2543 - y_tokenCnt_loss: 4.7489 - val_loss: 4.6761 - val_tf_op_layer_y_start_3_loss: 1.9447 - val_tf_op_layer_y_end_3_loss: 1.9089 - val_tf_op_layer_y_mask_3_loss: 0.0982 - val_y_jaccard_loss: 0.1651 - val_y_tokenCnt_loss: 2.7323
# Epoch 2/7
# 672/672 - 178s - loss: 4.5696 - tf_op_layer_y_start_3_loss: 1.9184 - tf_op_layer_y_end_3_loss: 1.8737 - tf_op_layer_y_mask_3_loss: 0.0956 - y_jaccard_loss: 0.1562 - y_tokenCnt_loss: 2.5717 - val_loss: 4.5037 - val_tf_op_layer_y_start_3_loss: 1.9061 - val_tf_op_layer_y_end_3_loss: 1.8562 - val_tf_op_layer_y_mask_3_loss: 0.0928 - val_y_jaccard_loss: 0.1482 - val_y_tokenCnt_loss: 2.4460
# Epoch 3/7
# 672/672 - 178s - loss: 4.4601 - tf_op_layer_y_start_3_loss: 1.8842 - tf_op_layer_y_end_3_loss: 1.8376 - tf_op_layer_y_mask_3_loss: 0.0919 - y_jaccard_loss: 0.1510 - y_tokenCnt_loss: 2.4345 - val_loss: 4.4879 - val_tf_op_layer_y_start_3_loss: 1.9001 - val_tf_op_layer_y_end_3_loss: 1.8525 - val_tf_op_layer_y_mask_3_loss: 0.0922 - val_y_jaccard_loss: 0.1454 - val_y_tokenCnt_loss: 2.4270
# Epoch 4/7
# 672/672 - 173s - loss: 4.3664 - tf_op_layer_y_start_3_loss: 1.8463 - tf_op_layer_y_end_3_loss: 1.8040 - tf_op_layer_y_mask_3_loss: 0.0885 - y_jaccard_loss: 0.1499 - y_tokenCnt_loss: 2.3604 - val_loss: 4.5049 - val_tf_op_layer_y_start_3_loss: 1.9116 - val_tf_op_layer_y_end_3_loss: 1.8623 - val_tf_op_layer_y_mask_3_loss: 0.0918 - val_y_jaccard_loss: 0.1478 - val_y_tokenCnt_loss: 2.4088
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 173s - loss: 4.2753 - tf_op_layer_y_start_3_loss: 1.8172 - tf_op_layer_y_end_3_loss: 1.7711 - tf_op_layer_y_mask_3_loss: 0.0847 - y_jaccard_loss: 0.1424 - y_tokenCnt_loss: 2.2663 - val_loss: 4.5333 - val_tf_op_layer_y_start_3_loss: 1.9226 - val_tf_op_layer_y_end_3_loss: 1.8717 - val_tf_op_layer_y_mask_3_loss: 0.0921 - val_y_jaccard_loss: 0.1434 - val_y_tokenCnt_loss: 2.4441
# Epoch 00005: early stopping
#
# FOLD: 3
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 178s - loss: 6.1770 - tf_op_layer_y_start_4_loss: 2.3215 - tf_op_layer_y_end_4_loss: 2.3532 - tf_op_layer_y_mask_4_loss: 0.1988 - y_jaccard_loss: 0.2714 - y_tokenCnt_loss: 4.9429 - val_loss: 4.7149 - val_tf_op_layer_y_start_4_loss: 1.9498 - val_tf_op_layer_y_end_4_loss: 1.9457 - val_tf_op_layer_y_mask_4_loss: 0.1062 - val_y_jaccard_loss: 0.1755 - val_y_tokenCnt_loss: 2.6770
# Epoch 2/7
# 672/672 - 178s - loss: 4.5812 - tf_op_layer_y_start_4_loss: 1.9142 - tf_op_layer_y_end_4_loss: 1.8840 - tf_op_layer_y_mask_4_loss: 0.0975 - y_jaccard_loss: 0.1611 - y_tokenCnt_loss: 2.5809 - val_loss: 4.5028 - val_tf_op_layer_y_start_4_loss: 1.9062 - val_tf_op_layer_y_end_4_loss: 1.8548 - val_tf_op_layer_y_mask_4_loss: 0.0936 - val_y_jaccard_loss: 0.1502 - val_y_tokenCnt_loss: 2.4425
# Epoch 3/7
# 672/672 - 173s - loss: 4.4593 - tf_op_layer_y_start_4_loss: 1.8745 - tf_op_layer_y_end_4_loss: 1.8351 - tf_op_layer_y_mask_4_loss: 0.0926 - y_jaccard_loss: 0.1557 - y_tokenCnt_loss: 2.4728 - val_loss: 4.5100 - val_tf_op_layer_y_start_4_loss: 1.9076 - val_tf_op_layer_y_end_4_loss: 1.8505 - val_tf_op_layer_y_mask_4_loss: 0.0926 - val_y_jaccard_loss: 0.1464 - val_y_tokenCnt_loss: 2.4906
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 173s - loss: 4.3548 - tf_op_layer_y_start_4_loss: 1.8386 - tf_op_layer_y_end_4_loss: 1.7985 - tf_op_layer_y_mask_4_loss: 0.0884 - y_jaccard_loss: 0.1497 - y_tokenCnt_loss: 2.3673 - val_loss: 4.5140 - val_tf_op_layer_y_start_4_loss: 1.9210 - val_tf_op_layer_y_end_4_loss: 1.8569 - val_tf_op_layer_y_mask_4_loss: 0.0927 - val_y_jaccard_loss: 0.1455 - val_y_tokenCnt_loss: 2.4282
# Epoch 00004: early stopping
#
# FOLD: 4
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 177s - loss: 6.2513 - tf_op_layer_y_start_5_loss: 2.3174 - tf_op_layer_y_end_5_loss: 2.4090 - tf_op_layer_y_mask_5_loss: 0.1905 - y_jaccard_loss: 0.2630 - y_tokenCnt_loss: 5.0748 - val_loss: 4.6928 - val_tf_op_layer_y_start_5_loss: 1.9430 - val_tf_op_layer_y_end_5_loss: 1.9500 - val_tf_op_layer_y_mask_5_loss: 0.1000 - val_y_jaccard_loss: 0.1613 - val_y_tokenCnt_loss: 2.6380
# Epoch 2/7
# 672/672 - 178s - loss: 4.6338 - tf_op_layer_y_start_5_loss: 1.9273 - tf_op_layer_y_end_5_loss: 1.9201 - tf_op_layer_y_mask_5_loss: 0.0995 - y_jaccard_loss: 0.1630 - y_tokenCnt_loss: 2.5845 - val_loss: 4.5265 - val_tf_op_layer_y_start_5_loss: 1.8955 - val_tf_op_layer_y_end_5_loss: 1.8736 - val_tf_op_layer_y_mask_5_loss: 0.0940 - val_y_jaccard_loss: 0.1407 - val_y_tokenCnt_loss: 2.5127
# Epoch 3/7
# 672/672 - 178s - loss: 4.4887 - tf_op_layer_y_start_5_loss: 1.8831 - tf_op_layer_y_end_5_loss: 1.8601 - tf_op_layer_y_mask_5_loss: 0.0943 - y_jaccard_loss: 0.1538 - y_tokenCnt_loss: 2.4507 - val_loss: 4.4792 - val_tf_op_layer_y_start_5_loss: 1.8873 - val_tf_op_layer_y_end_5_loss: 1.8576 - val_tf_op_layer_y_mask_5_loss: 0.0912 - val_y_jaccard_loss: 0.1415 - val_y_tokenCnt_loss: 2.4310
# Epoch 4/7
# 672/672 - 178s - loss: 4.4113 - tf_op_layer_y_start_5_loss: 1.8595 - tf_op_layer_y_end_5_loss: 1.8237 - tf_op_layer_y_mask_5_loss: 0.0918 - y_jaccard_loss: 0.1521 - y_tokenCnt_loss: 2.3930 - val_loss: 4.4719 - val_tf_op_layer_y_start_5_loss: 1.8837 - val_tf_op_layer_y_end_5_loss: 1.8547 - val_tf_op_layer_y_mask_5_loss: 0.0905 - val_y_jaccard_loss: 0.1385 - val_y_tokenCnt_loss: 2.4337
# Epoch 5/7
# 672/672 - 173s - loss: 4.3074 - tf_op_layer_y_start_5_loss: 1.8248 - tf_op_layer_y_end_5_loss: 1.7860 - tf_op_layer_y_mask_5_loss: 0.0883 - y_jaccard_loss: 0.1473 - y_tokenCnt_loss: 2.2857 - val_loss: 4.4924 - val_tf_op_layer_y_start_5_loss: 1.8924 - val_tf_op_layer_y_end_5_loss: 1.8633 - val_tf_op_layer_y_mask_5_loss: 0.0917 - val_y_jaccard_loss: 0.1370 - val_y_tokenCnt_loss: 2.4431
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 173s - loss: 4.2438 - tf_op_layer_y_start_5_loss: 1.8071 - tf_op_layer_y_end_5_loss: 1.7707 - tf_op_layer_y_mask_5_loss: 0.0849 - y_jaccard_loss: 0.1386 - y_tokenCnt_loss: 2.1855 - val_loss: 4.5013 - val_tf_op_layer_y_start_5_loss: 1.9017 - val_tf_op_layer_y_end_5_loss: 1.8663 - val_tf_op_layer_y_mask_5_loss: 0.0921 - val_y_jaccard_loss: 0.1358 - val_y_tokenCnt_loss: 2.4290
# Epoch 00006: early stopping
#
# FOLD: 5
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 178s - loss: 6.0030 - tf_op_layer_y_start_6_loss: 2.2548 - tf_op_layer_y_end_6_loss: 2.3253 - tf_op_layer_y_mask_6_loss: 0.1805 - y_jaccard_loss: 0.3511 - y_tokenCnt_loss: 4.6186 - val_loss: 4.7244 - val_tf_op_layer_y_start_6_loss: 1.9417 - val_tf_op_layer_y_end_6_loss: 1.9519 - val_tf_op_layer_y_mask_6_loss: 0.0973 - val_y_jaccard_loss: 0.1915 - val_y_tokenCnt_loss: 2.7423
# Epoch 2/7
# 672/672 - 178s - loss: 4.5951 - tf_op_layer_y_start_6_loss: 1.9218 - tf_op_layer_y_end_6_loss: 1.8782 - tf_op_layer_y_mask_6_loss: 0.0980 - y_jaccard_loss: 0.1620 - y_tokenCnt_loss: 2.6265 - val_loss: 4.4587 - val_tf_op_layer_y_start_6_loss: 1.8872 - val_tf_op_layer_y_end_6_loss: 1.8618 - val_tf_op_layer_y_mask_6_loss: 0.0883 - val_y_jaccard_loss: 0.1472 - val_y_tokenCnt_loss: 2.3379
# Epoch 3/7
# 672/672 - 178s - loss: 4.4681 - tf_op_layer_y_start_6_loss: 1.8798 - tf_op_layer_y_end_6_loss: 1.8312 - tf_op_layer_y_mask_6_loss: 0.0933 - y_jaccard_loss: 0.1559 - y_tokenCnt_loss: 2.4991 - val_loss: 4.4414 - val_tf_op_layer_y_start_6_loss: 1.8866 - val_tf_op_layer_y_end_6_loss: 1.8564 - val_tf_op_layer_y_mask_6_loss: 0.0876 - val_y_jaccard_loss: 0.1519 - val_y_tokenCnt_loss: 2.2914
# Epoch 4/7
# 672/672 - 173s - loss: 4.3671 - tf_op_layer_y_start_6_loss: 1.8443 - tf_op_layer_y_end_6_loss: 1.8004 - tf_op_layer_y_mask_6_loss: 0.0890 - y_jaccard_loss: 0.1502 - y_tokenCnt_loss: 2.3832 - val_loss: 4.4570 - val_tf_op_layer_y_start_6_loss: 1.8985 - val_tf_op_layer_y_end_6_loss: 1.8675 - val_tf_op_layer_y_mask_6_loss: 0.0879 - val_y_jaccard_loss: 0.1457 - val_y_tokenCnt_loss: 2.2672
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 173s - loss: 4.2745 - tf_op_layer_y_start_6_loss: 1.8150 - tf_op_layer_y_end_6_loss: 1.7674 - tf_op_layer_y_mask_6_loss: 0.0855 - y_jaccard_loss: 0.1467 - y_tokenCnt_loss: 2.2800 - val_loss: 4.4820 - val_tf_op_layer_y_start_6_loss: 1.9037 - val_tf_op_layer_y_end_6_loss: 1.8794 - val_tf_op_layer_y_mask_6_loss: 0.0886 - val_y_jaccard_loss: 0.1481 - val_y_tokenCnt_loss: 2.2928
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_7ebd05b2_ac19_11ea_9382_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_5
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                              bullying me...
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                                        like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                             dangerously low
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                                        lost
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
