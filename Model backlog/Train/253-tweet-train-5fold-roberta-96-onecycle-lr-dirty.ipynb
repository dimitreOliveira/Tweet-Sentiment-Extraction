# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 2,
  "LEARNING_RATE": 1e-4,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %%
# pre-process
k_fold['jaccard'] = k_fold.apply(lambda x: jaccard(x['text'], x['selected_text']), axis=1)
k_fold['text_tokenCnt'] = k_fold['text'].apply(lambda x : len(tokenizer.encode(x).ids))
k_fold['selected_text_tokenCnt'] = k_fold['selected_text'].apply(lambda x : len(tokenizer.encode(x).ids))

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size # total_steps * 0.1

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [one_cycle(tf.cast(x, tf.float32), total_steps=total_steps, 
               lr_start=lr_start, lr_max=lr_max) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 9.78e-05 to 3.06e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, use_bias=False, name='qa_outputs')(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    lr = lambda: one_cycle(tf.cast(optimizer.iterations, tf.float32), 
                           total_steps=total_steps, lr_start=lr_start, 
                           lr_max=lr_max)
    
    optimizer = optimizers.Adam(learning_rate=lr)
    
    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/2
# 687/687 - 282s - loss: 4.6951 - tf_op_layer_Squeeze_loss: 2.3322 - tf_op_layer_Squeeze_1_loss: 2.3628 - val_loss: 4.0702 - val_tf_op_layer_Squeeze_loss: 2.0287 - val_tf_op_layer_Squeeze_1_loss: 2.0415
# Epoch 2/2
# 687/687 - 269s - loss: 3.9745 - tf_op_layer_Squeeze_loss: 2.0032 - tf_op_layer_Squeeze_1_loss: 1.9713 - val_loss: 3.9389 - val_tf_op_layer_Squeeze_loss: 1.9928 - val_tf_op_layer_Squeeze_1_loss: 1.9461
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/2
# 687/687 - 282s - loss: 4.7279 - tf_op_layer_Squeeze_2_loss: 2.3415 - tf_op_layer_Squeeze_3_loss: 2.3864 - val_loss: 4.0853 - val_tf_op_layer_Squeeze_2_loss: 2.0626 - val_tf_op_layer_Squeeze_3_loss: 2.0227
# Epoch 2/2
# 687/687 - 268s - loss: 3.9589 - tf_op_layer_Squeeze_2_loss: 2.0041 - tf_op_layer_Squeeze_3_loss: 1.9548 - val_loss: 4.0076 - val_tf_op_layer_Squeeze_2_loss: 2.0207 - val_tf_op_layer_Squeeze_3_loss: 1.9869
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/2
# 687/687 - 282s - loss: 4.7286 - tf_op_layer_Squeeze_4_loss: 2.3318 - tf_op_layer_Squeeze_5_loss: 2.3968 - val_loss: 4.1029 - val_tf_op_layer_Squeeze_4_loss: 2.0527 - val_tf_op_layer_Squeeze_5_loss: 2.0502
# Epoch 2/2
# 687/687 - 270s - loss: 3.9957 - tf_op_layer_Squeeze_4_loss: 2.0207 - tf_op_layer_Squeeze_5_loss: 1.9750 - val_loss: 3.9399 - val_tf_op_layer_Squeeze_4_loss: 1.9890 - val_tf_op_layer_Squeeze_5_loss: 1.9509
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/2
# 687/687 - 283s - loss: 4.7416 - tf_op_layer_Squeeze_6_loss: 2.3464 - tf_op_layer_Squeeze_7_loss: 2.3952 - val_loss: 4.0687 - val_tf_op_layer_Squeeze_6_loss: 2.0598 - val_tf_op_layer_Squeeze_7_loss: 2.0089
# Epoch 2/2
# 687/687 - 269s - loss: 3.9785 - tf_op_layer_Squeeze_6_loss: 2.0070 - tf_op_layer_Squeeze_7_loss: 1.9715 - val_loss: 3.9728 - val_tf_op_layer_Squeeze_6_loss: 2.0178 - val_tf_op_layer_Squeeze_7_loss: 1.9549
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/2
# 687/687 - 283s - loss: 4.7327 - tf_op_layer_Squeeze_8_loss: 2.3364 - tf_op_layer_Squeeze_9_loss: 2.3962 - val_loss: 4.1303 - val_tf_op_layer_Squeeze_8_loss: 2.0492 - val_tf_op_layer_Squeeze_9_loss: 2.0811
# Epoch 2/2
# 687/687 - 269s - loss: 4.0486 - tf_op_layer_Squeeze_8_loss: 2.0328 - tf_op_layer_Squeeze_9_loss: 2.0158 - val_loss: 3.9750 - val_tf_op_layer_Squeeze_8_loss: 2.0115 - val_tf_op_layer_Squeeze_9_loss: 1.9634

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col10 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_8124f43e_a842_11ea_95a0_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              10                      10  1.000000      1.000000
# 1              13                       3  0.200000      1.000000
# 2               6                       2  0.166667      0.400000
# 3               6                       3  0.600000      1.000000
# 4              17                       4  0.214286      1.000000
# 5              27                      27  1.000000      0.900000
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              19                       7  0.500000      0.520000
# 10             27                      27  1.000000      1.000000
# 11             12                       1  0.100000      0.466667
# 12              9                       1  0.125000      0.550000
# 13             13                       1  0.100000      0.600000
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_2  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_3  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_4  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                             dangerously low on ink
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_5
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                             cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                               lost
# 14                         test test from the lg env2
