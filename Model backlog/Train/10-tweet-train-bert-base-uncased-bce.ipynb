# %% [markdown]
# ## Dependencies

# %%
from tweet_utility_scripts import *
from transformers import TFBertModel
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-bert-base-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-base-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  69a4e7a6f5                               ouch, i'm sorry then
# 1  8022534fc2     thankyou, yes. off to a pre-wedding party now.
# 2  f7beb13214                            this is how we do itttt
# 3  89cdcbfb73  everyone's abandoning the office... i still ha...
# 4  29a4bb11d9  acquiring a centos live cd, now where did i pu...
#
#                                        selected_text sentiment  text_len  \
# 0                                              sorry  negative        21
# 1                                          Thankyou,  positive        47
# 2                            this is how we do itttt   neutral        23
# 3  everyone's abandoning the office... I still ha...   neutral        62
# 4  I would like to boot from that. I wonder if I ...   neutral       126
#
#    selected_text_len    set
# 0                  5  train
# 1                  9  train
# 2                 23  train
# 3                 62  train
# 4                 61  train
# hold_out/
# hold_out/x_train.npy
# hold_out/y_valid.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 128
BATCH_SIZE = 64
EPOCHS = 10
LEARNING_RATE = 1e-5
ES_PATIENCE = 2

tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/bert/'
base_model_path = base_path + 'bert-base-uncased-tf_model.h5'
config_path = base_path + 'bert-base-uncased-config.json'
model_path = 'model.h5'
log_path = './'

# %% [markdown]
# # Model

# %%
def model_fn():
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFBertModel.from_pretrained(base_model_path, config=config_path, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='sigmoid', name='y_start')(x)
    y_end = Dense(MAX_LEN, activation='sigmoid', name='y_end')(x)
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

model = model_fn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFBertModel)        ((None, 128, 768), ( 109482240   attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 109,679,104
# Trainable params: 109,679,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir=log_path)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=EPOCHS, 
                    verbose=1).history

model.save_weights(model_path)
# Out:
# Train on 21988 samples, validate on 5497 samples
# Epoch 1/10
# 21988/21988 [==============================] - 379s 17ms/sample - loss: 0.2584 - y_start_loss: 0.1240 - y_end_loss: 0.1342 - y_start_binary_accuracy: 0.9875 - y_end_binary_accuracy: 0.9838 - val_loss: 0.0970 - val_y_start_loss: 0.0466 - val_y_end_loss: 0.0505 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 2/10
# 21988/21988 [==============================] - 358s 16ms/sample - loss: 0.0716 - y_start_loss: 0.0341 - y_end_loss: 0.0375 - y_start_binary_accuracy: 0.9962 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0544 - val_y_start_loss: 0.0257 - val_y_end_loss: 0.0287 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 3/10
# 21988/21988 [==============================] - 357s 16ms/sample - loss: 0.0482 - y_start_loss: 0.0225 - y_end_loss: 0.0257 - y_start_binary_accuracy: 0.9962 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0433 - val_y_start_loss: 0.0201 - val_y_end_loss: 0.0232 - val_y_start_binary_accuracy: 0.9960 - val_y_end_binary_accuracy: 0.9961
# Epoch 4/10
# 21988/21988 [==============================] - 357s 16ms/sample - loss: 0.0406 - y_start_loss: 0.0187 - y_end_loss: 0.0219 - y_start_binary_accuracy: 0.9962 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0386 - val_y_start_loss: 0.0177 - val_y_end_loss: 0.0208 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 5/10
# 21988/21988 [==============================] - 357s 16ms/sample - loss: 0.0368 - y_start_loss: 0.0169 - y_end_loss: 0.0199 - y_start_binary_accuracy: 0.9962 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0355 - val_y_start_loss: 0.0163 - val_y_end_loss: 0.0192 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 6/10
# 21988/21988 [==============================] - 358s 16ms/sample - loss: 0.0332 - y_start_loss: 0.0151 - y_end_loss: 0.0180 - y_start_binary_accuracy: 0.9962 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0315 - val_y_start_loss: 0.0144 - val_y_end_loss: 0.0171 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 7/10
# 21988/21988 [==============================] - 358s 16ms/sample - loss: 0.0296 - y_start_loss: 0.0135 - y_end_loss: 0.0160 - y_start_binary_accuracy: 0.9963 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0295 - val_y_start_loss: 0.0135 - val_y_end_loss: 0.0160 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 8/10
# 21988/21988 [==============================] - 358s 16ms/sample - loss: 0.0270 - y_start_loss: 0.0124 - y_end_loss: 0.0146 - y_start_binary_accuracy: 0.9964 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0281 - val_y_start_loss: 0.0130 - val_y_end_loss: 0.0151 - val_y_start_binary_accuracy: 0.9961 - val_y_end_binary_accuracy: 0.9961
# Epoch 9/10
# 21988/21988 [==============================] - 359s 16ms/sample - loss: 0.0248 - y_start_loss: 0.0115 - y_end_loss: 0.0133 - y_start_binary_accuracy: 0.9965 - y_end_binary_accuracy: 0.9963 - val_loss: 0.0280 - val_y_start_loss: 0.0130 - val_y_end_loss: 0.0149 - val_y_start_binary_accuracy: 0.9959 - val_y_end_binary_accuracy: 0.9959
# Epoch 10/10
# 21988/21988 [==============================] - 359s 16ms/sample - loss: 0.0230 - y_start_loss: 0.0107 - y_end_loss: 0.0123 - y_start_binary_accuracy: 0.9966 - y_end_binary_accuracy: 0.9964 - val_loss: 0.0274 - val_y_start_loss: 0.0128 - val_y_end_loss: 0.0146 - val_y_start_binary_accuracy: 0.9960 - val_y_end_binary_accuracy: 0.9959

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586222710.b1716faed8b4.profile-empty
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-07_01-25-10/
# train/plugins/profile/2020-04-07_01-25-10/local.trace
# train/events.out.tfevents.1586222691.b1716faed8b4.12.10651.v2
# validation/
# validation/events.out.tfevents.1586223070.b1716faed8b4.12.46967.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4f8c4c1d607e> in <module>
#       1 sns.set(style="whitegrid")
# ----> 2 plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
#
# /kaggle/usr/lib/tweet_utility_scripts/tweet_utility_scripts.py in plot_metrics(history, metric_list)
#      20
#      21     for index, metric in enumerate(metric_list):
# ---> 22         axes[index].plot(history[metric], label='Train %s' % metric)
#      23         axes[index].plot(history['val_%s' % metric], label='Validation %s' % metric)
#      24         axes[index].legend(loc='best', fontsize=16)
#
# KeyError: 'y_start_categorical_accuracy'

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], tokenizer), axis=1)
train["prediction"] = train["prediction"].apply(lambda x: '.' if x.strip() == '' else x)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], tokenizer), axis=1)
validation["prediction"] = validation["prediction"].apply(lambda x: '.' if x.strip() == '' else x)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.638644    0.580736          21988
# Sentiment negative           0.449076    0.355530           6142
# Sentiment positive           0.463120    0.371530           6948
# Sentiment neutral            0.906554    0.901637           8898
# 0 <= text < 50               0.757916    0.700555           7968
# 50 <= text < 100             0.603483    0.537555           8816
# 100 <= text < 150            0.515899    0.471013           5195
# 150 <= text < 200            0.335450    0.000000              9
# 0 <= selected text < 50      0.589911    0.511380          15902
# 50 <= selected text < 100    0.771149    0.755586           4084
# 100 <= selected text < 150   0.755428    0.760846           2002
# 150 <= selected text < 200        NaN         NaN              0
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5497
# Sentiment negative                         1644
# Sentiment positive                         1634
# Sentiment neutral                          2219
# 0 <= text < 50                             1998
# 50 <= text < 100                           2186
# 100 <= text < 150                          1311
# 150 <= text < 200                             2
# 0 <= selected text < 50                    3947
# 50 <= selected text < 100                  1031
# 100 <= selected text < 150                  519
# 150 <= selected text < 200                    0

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  69a4e7a6f5                               ouch, i'm sorry then
# 1  8022534fc2     thankyou, yes. off to a pre-wedding party now.
# 2  f7beb13214                            this is how we do itttt
# 3  89cdcbfb73  everyone's abandoning the office... i still ha...
# 4  29a4bb11d9  acquiring a centos live cd, now where did i pu...
# 5  b456369c87   alough i will hold you to your word now for w...
# 6  4e815dd602                       im not at litle oven tonight
# 7  3ef24ff6fa                           tgif. i don't feel good.
# 8  f3b0e2db98  twenty20 cricket, beer and sunshine very good....
# 9  bb97edb997                       off to bed, night every onee
#
#                                        selected_text sentiment  text_len  \
# 0                                              sorry  negative        21
# 1                                          Thankyou,  positive        47
# 2                            this is how we do itttt   neutral        23
# 3  everyone's abandoning the office... I still ha...   neutral        62
# 4  I would like to boot from that. I wonder if I ...   neutral       126
# 5  Alough I will hold you to your word now for wh...   neutral        61
# 6                       im not at litle oven tonight   neutral        29
# 7                                   don't feel good.  negative        24
# 8  Twenty20 cricket, beer and sunshine very good....  positive        93
# 9                       off to bed, night every onee   neutral        28
#
#    selected_text_len    set  start  end  \
# 0                  5  train      7    7
# 1                  9  train      1    2
# 2                 23  train      1    8
# 3                 62  train      1   15
# 4                 61  train      1   33
# 5                 60  train      1   15
# 6                 28  train      1    7
# 7                 16  train      1   11
# 8                 93  train      8    9
# 9                 28  train      1    8
#
#                                           prediction   jaccard
# 0                                             sorry   1.000000
# 1                                           thankyou  0.000000
# 2                            this is how we do itttt  1.000000
# 3  everyone's abandoning the office... i still ha...  0.909091
# 4  acquiring a centos live cd, now where did i pu...  0.520000
# 5  alough i will hold you to your word now for wh...  1.000000
# 6                       im not at litle oven tonight  1.000000
# 7                           tgif. i don't feel good.  0.600000
# 8                                             good.   0.066667
# 9                       off to bed, night every onee  1.000000
# Validation set
#            textID                                               text  \
# 21988  e45d640ba0     is sooo stressed about everything i have to do
# 21989  dfa0d5ca14                            i just dyededed my hair
# 21990  051f106b59  at the pub with the dog but seems to have misp...
# 21991  4c1897aa51  ugh, still sick. this calgary cold has lasted ...
# 21992  daf57be394  rt  #barcampbkk3 for entertainment at night, b...
# 21993  1381ed35a5    you two are hilaaaaarious, i love it. vernae...
# 21994  424754c08d                        _iain well my team couldn't
# 21995  981713769d  gotta drop off some car parts for a buddy to p...
# 21996  8aef9288d8       just read up on your mom   hope she's okay!!
# 21997  db5005c4d5      that's sad. trauma... future serial killer...
#
#                                            selected_text sentiment  text_len  \
# 21988     is sooo stressed about everything I have to do  negative        46
# 21989                            I just dyededed my hair   neutral        23
# 21990  At the pub with the dog but seems to have misp...   neutral        70
# 21991  Ugh, still sick. This Calgary cold has lasted ...  negative        54
# 21992                                              enjoy  positive       123
# 21993              you two are hilaaaaarious, I love it.  positive        69
# 21994                        _iain well my team couldn't   neutral        27
# 21995  Gotta drop off some car parts for a buddy to p...   neutral       103
# 21996                                   Hope she's okay!  positive        45
# 21997                                              s sad  negative        47
#
#        selected_text_len         set  start  end  \
# 21988                 46  validation      4    4
# 21989                 23  validation      1    6
# 21990                 70  validation      1   15
# 21991                 54  validation      5    6
# 21992                  5  validation     13   14
# 21993                 37  validation     11   12
# 21994                 27  validation      1    8
# 21995                103  validation      1   27
# 21996                 16  validation      9   12
# 21997                  5  validation      1    5
#
#                                               prediction   jaccard
# 21988                                          stressed   0.111111
# 21989                            i just dyededed my hair  1.000000
# 21990  at the pub with the dog but seems to have misp...  1.000000
# 21991                                             sick.   0.111111
# 21992                                        bring your   0.000000
# 21993                                            love it  0.125000
# 21994                        _iain well my team couldn't  1.000000
# 21995  gotta drop off some car parts for a buddy to p...  0.882353
# 21996                                           's okay!  0.250000
# 21997                                       that's sad.   0.000000
