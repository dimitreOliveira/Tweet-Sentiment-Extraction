# %%
# !nvidia-smi
# Out:
# Fri May 22 19:14:02 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 9.1MB/s
#      |████████████████████████████████| 3.8MB 62.2MB/s
#      |████████████████████████████████| 890kB 58.6MB/s
#      |████████████████████████████████| 1.1MB 45.5MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/170-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
import tweet_utility_preprocess_roberta_scripts_text as preprocess_text
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 16 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 4,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 4,
  "question_size": 0,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9987

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    input_sentiment = layers.Input(shape=(3,), dtype=tf.float32, name='input_sentiment')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Dropout(.1)(last_hidden_state)

    x_start_negative = layers.Dense(1)(x)
    x_start_negative = layers.Flatten()(x_start_negative)
    y_start_negative = layers.Activation('softmax', name='y_start_negative')(x_start_negative)
    y_start_negative = layers.Multiply()([y_start_negative, input_sentiment[:,0]])
    
    x_start_neutral = layers.Dense(1)(x)
    x_start_neutral = layers.Flatten()(x_start_neutral)
    y_start_neutral = layers.Activation('softmax', name='y_start_neutral')(x_start_neutral)
    y_start_neutral = layers.Multiply()([y_start_neutral, input_sentiment[:,1]])
    
    x_start_positive = layers.Dense(1)(x)
    x_start_positive = layers.Flatten()(x_start_positive)
    y_start_positive = layers.Activation('softmax', name='y_start_positive')(x_start_positive)
    y_start_positive = layers.Multiply()([y_start_positive, input_sentiment[:,2]])

    y_start = layers.Add(name='y_start')([y_start_negative, y_start_neutral, y_start_positive])

    x_end_negative = layers.Dense(1)(x)
    x_end_negative = layers.Flatten()(x_end_negative)
    y_end_negative = layers.Activation('softmax', name='y_end_negative')(x_end_negative)
    y_end_negative = layers.Multiply()([y_end_negative, input_sentiment[:,0]])

    x_end_neutral = layers.Dense(1)(x)
    x_end_neutral = layers.Flatten()(x_end_neutral)
    y_end_neutral = layers.Activation('softmax', name='y_end_neutral')(x_end_neutral)
    y_end_neutral = layers.Multiply()([y_end_neutral, input_sentiment[:,1]])

    x_end_positive = layers.Dense(1)(x)
    x_end_positive = layers.Flatten()(x_end_positive)
    y_end_positive = layers.Activation('softmax', name='y_end_positive')(x_end_positive)
    y_end_positive = layers.Multiply()([y_end_positive, input_sentiment[:,2]])

    y_end = layers.Add(name='y_end')([y_end_negative, y_end_neutral, y_end_positive])
    
    model = Model(inputs=[input_ids, attention_mask, input_sentiment], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1], 'input_sentiment': x_train[2]}, 
                                                  {'y_start': y_train[0],'y_end': y_train[1]}))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1], 'input_sentiment': x_valid[2]}, 
                                                  {'y_start': y_valid[0],'y_end': y_valid[1]}))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_test_dataset(x_test, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices({'input_ids': x_test[0], 'attention_mask': x_test[1], 'input_sentiment': x_test[2]})
    dataset = dataset.batch(batch_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    base_data_path = 'no_qa_fold_%d/' % (n_fold)

    # Load data
    x_train = np.load(base_data_path + 'x_train.npy')
    x_train_aux2 = np.load(base_data_path + 'x_train_aux2.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    x_valid_aux2 = np.load(base_data_path + 'x_valid_aux2.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset((*x_train, x_train_aux2), y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset((*x_valid, x_valid_aux2), y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0])
                loss_end = loss_fn(y['y_end'], probabilities[1])
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32)//step_size, warmup_steps=1, 
                                                                                       lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         (MODEL_BASE_PATH + model_path), save_last=False)
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions (last model)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset((*x_train, x_train_aux2), config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset((*x_valid, x_valid_aux2), config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: preprocess_text.decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(MODEL_BASE_PATH + model_path)
    train_preds = model.predict(get_test_dataset((*x_train, x_train_aux2), config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset((*x_valid, x_valid_aux2), config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: preprocess_text.decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.2s loss: 2.3050 loss_start: 1.1406 loss_end: 1.1644 val_loss: 1.7742 val_loss_start: 0.9137 val_loss_end: 0.8605
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_1.h5"
#
# EPOCH 2/4
# time: 266.0s loss: 1.7446 loss_start: 0.8916 loss_end: 0.8530 val_loss: 1.6978 val_loss_start: 0.8779 val_loss_end: 0.8199
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_1.h5"
#
# EPOCH 3/4
# time: 268.1s loss: 1.5439 loss_start: 0.7974 loss_end: 0.7465 val_loss: 1.6882 val_loss_start: 0.8684 val_loss_end: 0.8198
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_1.h5"
#
# EPOCH 4/4
# time: 268.1s loss: 1.3598 loss_start: 0.7140 loss_end: 0.6457 val_loss: 1.7340 val_loss_start: 0.8874 val_loss_end: 0.8466
# Training finished
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 275.6s loss: 2.2160 loss_start: 1.1080 loss_end: 1.1080 val_loss: 1.8467 val_loss_start: 0.9433 val_loss_end: 0.9034
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_2.h5"
#
# EPOCH 2/4
# time: 265.8s loss: 1.7099 loss_start: 0.8899 loss_end: 0.8200 val_loss: 1.7902 val_loss_start: 0.9200 val_loss_end: 0.8701
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_2.h5"
#
# EPOCH 3/4
# time: 268.5s loss: 1.5145 loss_start: 0.7889 loss_end: 0.7256 val_loss: 1.7819 val_loss_start: 0.9281 val_loss_end: 0.8538
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_2.h5"
#
# EPOCH 4/4
# time: 268.3s loss: 1.3309 loss_start: 0.7036 loss_end: 0.6273 val_loss: 1.8660 val_loss_start: 0.9382 val_loss_end: 0.9278
# Training finished
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 275.3s loss: 2.2377 loss_start: 1.1257 loss_end: 1.1119 val_loss: 1.8364 val_loss_start: 0.9161 val_loss_end: 0.9204
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_3.h5"
#
# EPOCH 2/4
# time: 264.8s loss: 1.7243 loss_start: 0.8932 loss_end: 0.8311 val_loss: 1.6605 val_loss_start: 0.8466 val_loss_end: 0.8139
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_3.h5"
#
# EPOCH 3/4
# time: 268.0s loss: 1.5008 loss_start: 0.7826 loss_end: 0.7182 val_loss: 1.6767 val_loss_start: 0.8736 val_loss_end: 0.8032
#
# EPOCH 4/4
# time: 263.0s loss: 1.3218 loss_start: 0.6952 loss_end: 0.6266 val_loss: 1.8646 val_loss_start: 0.9472 val_loss_end: 0.9174
# Training finished
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.3s loss: 2.2456 loss_start: 1.1216 loss_end: 1.1240 val_loss: 1.8160 val_loss_start: 0.9457 val_loss_end: 0.8703
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_4.h5"
#
# EPOCH 2/4
# time: 266.1s loss: 1.7391 loss_start: 0.8883 loss_end: 0.8508 val_loss: 1.7521 val_loss_start: 0.9161 val_loss_end: 0.8359
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_4.h5"
#
# EPOCH 3/4
# time: 267.9s loss: 1.5294 loss_start: 0.7934 loss_end: 0.7359 val_loss: 1.7325 val_loss_start: 0.9193 val_loss_end: 0.8132
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_4.h5"
#
# EPOCH 4/4
# time: 267.7s loss: 1.3413 loss_start: 0.7038 loss_end: 0.6376 val_loss: 1.7402 val_loss_start: 0.9315 val_loss_end: 0.8087
# Training finished
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.7s loss: 2.2890 loss_start: 1.1383 loss_end: 1.1507 val_loss: 1.7575 val_loss_start: 0.8941 val_loss_end: 0.8634
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_5.h5"
#
# EPOCH 2/4
# time: 265.9s loss: 1.7147 loss_start: 0.8805 loss_end: 0.8342 val_loss: 1.7230 val_loss_start: 0.8927 val_loss_end: 0.8304
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/168-roBERTa_base/model_fold_5.h5"
#
# EPOCH 3/4
# time: 268.6s loss: 1.5226 loss_start: 0.7870 loss_end: 0.7356 val_loss: 1.7501 val_loss_start: 0.9264 val_loss_end: 0.8238
#
# EPOCH 4/4
# time: 264.0s loss: 1.3367 loss_start: 0.7018 loss_end: 0.6350 val_loss: 1.7621 val_loss_start: 0.9244 val_loss_end: 0.8377
# Training finished

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col6 {
#             color:  orange;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_234892d0_9c71_11ea_a677_0242ac1c0002row6_c

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col1 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col6 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col10 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col1 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col6 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_259103e2_9c71_11ea_a677_0242ac1c0002ro

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       0.500000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       1.000000
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       1.000000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 16 columns]
