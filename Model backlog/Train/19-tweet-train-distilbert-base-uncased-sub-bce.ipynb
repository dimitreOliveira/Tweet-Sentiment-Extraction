# %% [markdown]
# ## Dependencies

# %%
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate, Subtract, Multiply


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
#
#    selected_text_len    set
# 0                 95  train
# 1                 10  train
# 2                 23  train
# 3                  9  train
# 4                 41  train
# hold_out/
# hold_out/y_valid.npy
# hold_out/x_train.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 128
BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 1e-5
ES_PATIENCE = 3
question_size = 3

tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
base_model_path = base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5'
config_path = base_path + 'distilbert-base-uncased-distilled-squad-config.json'
model_path = 'model.h5'
log_path = './'

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config_path, output_hidden_states=False)

def model_fn():
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(base_model_path, config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    start = Dense(MAX_LEN, activation='sigmoid')(x)        
    end = Dense(MAX_LEN, activation='sigmoid')(x)
    
    y_start = Subtract(name='y_start')([start, end])
    y_end = Subtract(name='y_end')([end, start])
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

model = model_fn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_start (Subtract)              (None, 128)          0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# y_end (Subtract)                (None, 128)          0           dense_1[0][0]
#                                                                  dense[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir=log_path)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=EPOCHS, 
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/20
# 21984/21984 - 179s - loss: 0.1550 - y_start_loss: 0.0741 - y_end_loss: 0.0809 - y_start_binary_accuracy: 0.9859 - y_end_binary_accuracy: 0.9919 - val_loss: 0.1401 - val_y_start_loss: 0.0745 - val_y_end_loss: 0.0656 - val_y_start_binary_accuracy: 0.9857 - val_y_end_binary_accuracy: 0.9922
# Epoch 2/20
# 21984/21984 - 171s - loss: 0.1363 - y_start_loss: 0.0672 - y_end_loss: 0.0691 - y_start_binary_accuracy: 0.9858 - y_end_binary_accuracy: 0.9867 - val_loss: 0.1344 - val_y_start_loss: 0.0670 - val_y_end_loss: 0.0674 - val_y_start_binary_accuracy: 0.9857 - val_y_end_binary_accuracy: 0.9917
# Epoch 3/20
# 21984/21984 - 171s - loss: 0.1242 - y_start_loss: 0.0646 - y_end_loss: 0.0596 - y_start_binary_accuracy: 0.9897 - y_end_binary_accuracy: 0.9903 - val_loss: 0.1222 - val_y_start_loss: 0.0629 - val_y_end_loss: 0.0593 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9847
# Epoch 4/20
# 21984/21984 - 171s - loss: 0.1142 - y_start_loss: 0.0609 - y_end_loss: 0.0534 - y_start_binary_accuracy: 0.9934 - y_end_binary_accuracy: 0.9913 - val_loss: 0.1157 - val_y_start_loss: 0.0572 - val_y_end_loss: 0.0584 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9922
# Epoch 5/20
# 21984/21984 - 170s - loss: 0.1128 - y_start_loss: 0.0589 - y_end_loss: 0.0538 - y_start_binary_accuracy: 0.9924 - y_end_binary_accuracy: 0.9906 - val_loss: 0.1274 - val_y_start_loss: 0.0655 - val_y_end_loss: 0.0619 - val_y_start_binary_accuracy: 0.9858 - val_y_end_binary_accuracy: 0.9861
# Epoch 6/20
# 21984/21984 - 170s - loss: 0.1185 - y_start_loss: 0.0607 - y_end_loss: 0.0578 - y_start_binary_accuracy: 0.9908 - y_end_binary_accuracy: 0.9911 - val_loss: 0.1251 - val_y_start_loss: 0.0575 - val_y_end_loss: 0.0677 - val_y_start_binary_accuracy: 0.9935 - val_y_end_binary_accuracy: 0.9851
# Epoch 7/20
# 21984/21984 - 171s - loss: 0.1118 - y_start_loss: 0.0564 - y_end_loss: 0.0554 - y_start_binary_accuracy: 0.9935 - y_end_binary_accuracy: 0.9884 - val_loss: 0.1023 - val_y_start_loss: 0.0568 - val_y_end_loss: 0.0454 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9922
# Epoch 8/20
# 21984/21984 - 171s - loss: 0.1010 - y_start_loss: 0.0569 - y_end_loss: 0.0441 - y_start_binary_accuracy: 0.9934 - y_end_binary_accuracy: 0.9922 - val_loss: 0.0981 - val_y_start_loss: 0.0553 - val_y_end_loss: 0.0428 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9922
# Epoch 9/20
# 21984/21984 - 171s - loss: 0.1013 - y_start_loss: 0.0565 - y_end_loss: 0.0448 - y_start_binary_accuracy: 0.9935 - y_end_binary_accuracy: 0.9921 - val_loss: 0.0972 - val_y_start_loss: 0.0570 - val_y_end_loss: 0.0402 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9922
# Epoch 10/20
# 21984/21984 - 171s - loss: 0.1059 - y_start_loss: 0.0568 - y_end_loss: 0.0491 - y_start_binary_accuracy: 0.9930 - y_end_binary_accuracy: 0.9922 - val_loss: 0.1018 - val_y_start_loss: 0.0554 - val_y_end_loss: 0.0464 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9922
# Epoch 11/20
# 21984/21984 - 170s - loss: 0.1048 - y_start_loss: 0.0536 - y_end_loss: 0.0512 - y_start_binary_accuracy: 0.9935 - y_end_binary_accuracy: 0.9919 - val_loss: 0.1010 - val_y_start_loss: 0.0540 - val_y_end_loss: 0.0470 - val_y_start_binary_accuracy: 0.9934 - val_y_end_binary_accuracy: 0.9922
# Epoch 12/20
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 171s - loss: 0.1002 - y_start_loss: 0.0555 - y_end_loss: 0.0448 - y_start_binary_accuracy: 0.9934 - y_end_binary_accuracy: 0.9922 - val_loss: 0.1104 - val_y_start_loss: 0.0568 - val_y_end_loss: 0.0536 - val_y_start_binary_accuracy: 0.9863 - val_y_end_binary_accuracy: 0.9922
# Epoch 00012: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586536115.19f6466d2c03.profile-empty
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-10_16-28-35/
# train/plugins/profile/2020-04-10_16-28-35/local.trace
# train/events.out.tfevents.1586536109.19f6466d2c03.13.5435.v2
# validation/
# validation/events.out.tfevents.1586536287.19f6466d2c03.13.24688.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_binary_accuracy', 'y_end_binary_accuracy'])

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], question_size, tokenizer), axis=1)
train["prediction"] = train["prediction"].apply(lambda x: '.' if x.strip() == '' else x)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], question_size, tokenizer), axis=1)
validation["prediction"] = validation["prediction"].apply(lambda x: '.' if x.strip() == '' else x)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.374689    0.368349          21984
# Sentiment neutral            0.567420    0.558703           8842
# Sentiment negative           0.247318    0.238128           6258
# Sentiment positive           0.242930    0.230112           6884
# 0 <= text < 10               0.977833    0.962500            203
# 10 <= text < 50              0.556827    0.552689           7823
# 50 <= text < 100             0.304412    0.299324           8858
# 100 <= text < 200            0.193359    0.192484           5100
# 0 <= selected text < 10      0.140874    0.130587           6326
# 10 <= selected text < 50     0.505977    0.487443           9575
# 50 <= selected text < 100    0.463172    0.458481           4075
# 100 <= selected text < 200   0.305700    0.306120           2008
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5496
# Sentiment neutral                          2275
# Sentiment negative                         1523
# Sentiment positive                         1698
# 0 <= text < 10                               40
# 10 <= text < 50                            1945
# 50 <= text < 100                           2201
# 100 <= text < 200                          1310
# 0 <= selected text < 10                    1492
# 10 <= selected text < 50                   2455
# 50 <= selected text < 100                  1042
# 100 <= selected text < 200                  507

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
# 5  cb280b3adb  _ kk`s  have fun eating lol, remember shaun lo...
# 6  8dd41515ff                                   definitley miley
# 7  60fa8ea66e         just going to shower. brb in 10 mins or so
# 8  bb4ac6eb31              back to work.. with no distractions..
# 9  2f858c20c3   cool, i used to live 5 houses to the left of ...
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
# 5                                                fun  positive        58
# 6                                   definitley miley   neutral        17
# 7         just going to shower. brb in 10 mins or so   neutral        42
# 8              back to work.. with no distractions..  positive        37
# 9                                              cool,  positive        86
#
#    selected_text_len    set  start  end                           prediction  \
# 0                 95  train      4   12         cant stop playin` in my head
# 1                 10  train      4   12                           i hate you
# 2                 23  train      4   12                                    .
# 3                  9  train      4   12              ben and jerry...yummmmy
# 4                 41  train      4   12     wow.. purple leopard skin.  fiee
# 5                  3  train      4   12           _ kk`s  have fun eating lo
# 6                 16  train      4   12                     definitley miley
# 7                 42  train      4   12      just going to shower. brb in 10
# 8                 37  train      4   12  back to work.. with no distractions
# 9                  5  train      4   12     cool, i used to live 5 houses to
#
#     jaccard
# 0  0.400000
# 1  1.000000
# 2  0.000000
# 3  0.000000
# 4  0.666667
# 5  0.166667
# 6  1.000000
# 7  0.700000
# 8  0.714286
# 9  0.142857
# Validation set
#            textID                                               text  \
# 21984  3391184efc              loves the nice weather and 7:30 exams
# 21985  b35daf9677  okay, this weather isn`t 'cute sundress' frien...
# 21986  06e5249859                          woo hoo!! congratulations
# 21987  3cd4960670   thanks   got a hold of someone there who knew...
# 21988  92b75314ca  got back and putting in the laundry. we got in...
# 21989  7438c9c09a                    congrats on graduating college!
# 21990  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 21991  a4ede54987  it`s the weekend but 9 year old is grounded wh...
# 21992  35124a7481   it`s been fine for me for like, a week, but n...
# 21993  e4b6c9a295                      ntah, i really wanna be there
#
#                                            selected_text sentiment  text_len  \
# 21984                                              loves  positive        37
# 21985  okay, this weather isn`t 'cute sundress' frien...   neutral       130
# 21986                                    congratulations  positive        26
# 21987                                             thanks  positive        68
# 21988  got back and putting in the laundry. we got in...   neutral        95
# 21989                                           congrats  positive        32
# 21990  can you get me a sub from subway when ur on yo...   neutral        58
# 21991  it`s the weekend but 9 year old is grounded wh...   neutral        71
# 21992  it`s been fine for me for like, a week, but no...   neutral        68
# 21993                                              wanna  positive        30
#
#        selected_text_len         set  start  end  \
# 21984                  5  validation      4   12
# 21985                130  validation      4   12
# 21986                 15  validation      4   12
# 21987                  6  validation      4   12
# 21988                 95  validation      4   12
# 21989                  8  validation      4   12
# 21990                 58  validation      4   12
# 21991                 71  validation      4   12
# 21992                 67  validation      4   12
# 21993                  5  validation      4   12
#
#                                           prediction   jaccard
# 21984          loves the nice weather and 7:30 exams  0.142857
# 21985                 okay, this weather isn`t 'cute  0.208333
# 21986                      woo hoo!! congratulations  0.333333
# 21987  thanks   got a hold of someone there who knew  0.111111
# 21988        got back and putting in the laundry. we  0.470588
# 21989                congrats on graduating college!  0.250000
# 21990          can you get me a sub from subway when  0.642857
# 21991                it`s the weekend but 9 year old  0.538462
# 21992                 it`s been fine for me for like  0.333333
# 21993                                              .  0.000000
