# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 26882
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2 fold_3      fold_4 fold_5  \
# 0                      10       train  validation  train       train  train
# 1                       3  validation       train  train       train  train
# 2                       2       train       train  train  validation  train
# 3                       3       train       train  train  validation  train
# 4                       4       train       train  train  validation  train
#
#    imputed
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.96e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]

    x = layers.Dropout(.1)(h11)
    
    mask_logits = layers.Dense(1, name="mask_logit", use_bias=False)(x)
    mask_logits = layers.Flatten()(mask_logits)
    
    start_logits = layers.Dense(1, name="start_logit", use_bias=False)(x)
    start_logits = layers.Flatten()(start_logits)

    end_logits = layers.Dense(1, name="end_logit", use_bias=False)(x)
    end_logits = layers.Flatten()(end_logits)
    

    start_probs = layers.Activation('softmax', name='y_start')(start_logits)
    end_probs = layers.Activation('softmax', name='y_end')(end_logits)
    mask_probs = layers.Activation('sigmoid', name='y_mask')(mask_logits)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_probs, end_probs, mask_probs])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  {'y_start': y_train[0], 'y_end': y_train[1], 'y_mask': y_train[2]}))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  {'y_start': y_valid[0], 'y_end': y_valid[1], 'y_mask': y_valid[2]}))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    y_train_mask = np.load(base_data_path + 'y_train_mask.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    y_valid_mask = np.load(base_data_path + 'y_valid_mask.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_mask': losses.BinaryCrossentropy(label_smoothing=0.2)})
    
    history = model.fit(get_training_dataset(x_train, (*y_train, y_train_mask), config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, (*y_valid, y_valid_mask), config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 177s - loss: 5.3271 - y_start_loss: 2.4017 - y_end_loss: 2.4668 - y_mask_loss: 0.4587 - val_loss: 4.2405 - val_y_start_loss: 1.9522 - val_y_end_loss: 1.9127 - val_y_mask_loss: 0.3757
# Epoch 2/7
# 672/672 - 164s - loss: 4.2269 - y_start_loss: 1.9277 - y_end_loss: 1.9234 - y_mask_loss: 0.3758 - val_loss: 4.1652 - val_y_start_loss: 1.9226 - val_y_end_loss: 1.8703 - val_y_mask_loss: 0.3723
# Epoch 3/7
# 672/672 - 162s - loss: 4.1072 - y_start_loss: 1.8756 - y_end_loss: 1.8586 - y_mask_loss: 0.3730 - val_loss: 4.1661 - val_y_start_loss: 1.9218 - val_y_end_loss: 1.8725 - val_y_mask_loss: 0.3718
# Epoch 4/7
# 672/672 - 164s - loss: 4.0601 - y_start_loss: 1.8556 - y_end_loss: 1.8327 - y_mask_loss: 0.3718 - val_loss: 4.1635 - val_y_start_loss: 1.9202 - val_y_end_loss: 1.8716 - val_y_mask_loss: 0.3716
# Epoch 5/7
# 672/672 - 162s - loss: 4.0420 - y_start_loss: 1.8447 - y_end_loss: 1.8260 - y_mask_loss: 0.3713 - val_loss: 4.1654 - val_y_start_loss: 1.9207 - val_y_end_loss: 1.8732 - val_y_mask_loss: 0.3715
# Epoch 6/7
# 672/672 - 163s - loss: 4.0334 - y_start_loss: 1.8426 - y_end_loss: 1.8197 - y_mask_loss: 0.3712 - val_loss: 4.1620 - val_y_start_loss: 1.9208 - val_y_end_loss: 1.8698 - val_y_mask_loss: 0.3714
# Epoch 7/7
# 672/672 - 164s - loss: 4.0131 - y_start_loss: 1.8339 - y_end_loss: 1.8086 - y_mask_loss: 0.3705 - val_loss: 4.1567 - val_y_start_loss: 1.9189 - val_y_end_loss: 1.8664 - val_y_mask_loss: 0.3713
#
# FOLD: 2
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 176s - loss: 5.2398 - y_start_loss: 2.3779 - y_end_loss: 2.4249 - y_mask_loss: 0.4371 - val_loss: 4.2192 - val_y_start_loss: 1.9451 - val_y_end_loss: 1.8987 - val_y_mask_loss: 0.3754
# Epoch 2/7
# 672/672 - 164s - loss: 4.2186 - y_start_loss: 1.9442 - y_end_loss: 1.8951 - y_mask_loss: 0.3793 - val_loss: 4.1668 - val_y_start_loss: 1.9181 - val_y_end_loss: 1.8763 - val_y_mask_loss: 0.3724
# Epoch 3/7
# 672/672 - 164s - loss: 4.1017 - y_start_loss: 1.8862 - y_end_loss: 1.8401 - y_mask_loss: 0.3754 - val_loss: 4.1599 - val_y_start_loss: 1.9199 - val_y_end_loss: 1.8685 - val_y_mask_loss: 0.3715
# Epoch 4/7
# 672/672 - 162s - loss: 4.0503 - y_start_loss: 1.8633 - y_end_loss: 1.8127 - y_mask_loss: 0.3743 - val_loss: 4.1721 - val_y_start_loss: 1.9293 - val_y_end_loss: 1.8707 - val_y_mask_loss: 0.3721
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 4.0357 - y_start_loss: 1.8559 - y_end_loss: 1.8063 - y_mask_loss: 0.3736 - val_loss: 4.1671 - val_y_start_loss: 1.9271 - val_y_end_loss: 1.8683 - val_y_mask_loss: 0.3717
# Epoch 00005: early stopping
#
# FOLD: 3
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 175s - loss: 5.1360 - y_start_loss: 2.2995 - y_end_loss: 2.3923 - y_mask_loss: 0.4442 - val_loss: 4.1832 - val_y_start_loss: 1.9258 - val_y_end_loss: 1.8818 - val_y_mask_loss: 0.3755
# Epoch 2/7
# 672/672 - 164s - loss: 4.1739 - y_start_loss: 1.9121 - y_end_loss: 1.8840 - y_mask_loss: 0.3778 - val_loss: 4.1089 - val_y_start_loss: 1.8924 - val_y_end_loss: 1.8456 - val_y_mask_loss: 0.3709
# Epoch 3/7
# 672/672 - 163s - loss: 4.0623 - y_start_loss: 1.8623 - y_end_loss: 1.8258 - y_mask_loss: 0.3742 - val_loss: 4.1067 - val_y_start_loss: 1.8887 - val_y_end_loss: 1.8477 - val_y_mask_loss: 0.3702
# Epoch 4/7
# 672/672 - 162s - loss: 4.0158 - y_start_loss: 1.8393 - y_end_loss: 1.8039 - y_mask_loss: 0.3726 - val_loss: 4.1080 - val_y_start_loss: 1.8924 - val_y_end_loss: 1.8457 - val_y_mask_loss: 0.3700
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 3.9897 - y_start_loss: 1.8273 - y_end_loss: 1.7909 - y_mask_loss: 0.3716 - val_loss: 4.1119 - val_y_start_loss: 1.8931 - val_y_end_loss: 1.8488 - val_y_mask_loss: 0.3701
# Epoch 00005: early stopping
#
# FOLD: 4
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 175s - loss: 5.1205 - y_start_loss: 2.2984 - y_end_loss: 2.3913 - y_mask_loss: 0.4308 - val_loss: 4.1785 - val_y_start_loss: 1.9212 - val_y_end_loss: 1.8833 - val_y_mask_loss: 0.3740
# Epoch 2/7
# 672/672 - 164s - loss: 4.2062 - y_start_loss: 1.9220 - y_end_loss: 1.8998 - y_mask_loss: 0.3844 - val_loss: 4.1122 - val_y_start_loss: 1.8882 - val_y_end_loss: 1.8527 - val_y_mask_loss: 0.3712
# Epoch 3/7
# 672/672 - 164s - loss: 4.0929 - y_start_loss: 1.8693 - y_end_loss: 1.8438 - y_mask_loss: 0.3798 - val_loss: 4.1076 - val_y_start_loss: 1.8851 - val_y_end_loss: 1.8531 - val_y_mask_loss: 0.3694
# Epoch 4/7
# 672/672 - 164s - loss: 4.0488 - y_start_loss: 1.8522 - y_end_loss: 1.8181 - y_mask_loss: 0.3785 - val_loss: 4.1034 - val_y_start_loss: 1.8822 - val_y_end_loss: 1.8517 - val_y_mask_loss: 0.3694
# Epoch 5/7
# 672/672 - 162s - loss: 4.0252 - y_start_loss: 1.8378 - y_end_loss: 1.8100 - y_mask_loss: 0.3774 - val_loss: 4.1094 - val_y_start_loss: 1.8844 - val_y_end_loss: 1.8557 - val_y_mask_loss: 0.3692
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 4.0133 - y_start_loss: 1.8331 - y_end_loss: 1.8036 - y_mask_loss: 0.3767 - val_loss: 4.1090 - val_y_start_loss: 1.8858 - val_y_end_loss: 1.8540 - val_y_mask_loss: 0.3692
# Epoch 00006: early stopping
#
# FOLD: 5
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 174s - loss: 5.1338 - y_start_loss: 2.3338 - y_end_loss: 2.3651 - y_mask_loss: 0.4350 - val_loss: 4.2856 - val_y_start_loss: 1.9409 - val_y_end_loss: 1.9676 - val_y_mask_loss: 0.3771
# Epoch 2/7
# 672/672 - 164s - loss: 4.2218 - y_start_loss: 1.9376 - y_end_loss: 1.9022 - y_mask_loss: 0.3821 - val_loss: 4.1484 - val_y_start_loss: 1.8959 - val_y_end_loss: 1.8815 - val_y_mask_loss: 0.3710
# Epoch 3/7
# 672/672 - 163s - loss: 4.1012 - y_start_loss: 1.8826 - y_end_loss: 1.8407 - y_mask_loss: 0.3779 - val_loss: 4.1447 - val_y_start_loss: 1.8982 - val_y_end_loss: 1.8757 - val_y_mask_loss: 0.3708
# Epoch 4/7
# 672/672 - 163s - loss: 4.0502 - y_start_loss: 1.8596 - y_end_loss: 1.8147 - y_mask_loss: 0.3758 - val_loss: 4.1423 - val_y_start_loss: 1.8988 - val_y_end_loss: 1.8743 - val_y_mask_loss: 0.3692
# Epoch 5/7
# 672/672 - 163s - loss: 4.0263 - y_start_loss: 1.8516 - y_end_loss: 1.8000 - y_mask_loss: 0.3747 - val_loss: 4.1354 - val_y_start_loss: 1.8954 - val_y_end_loss: 1.8710 - val_y_mask_loss: 0.3690
# Epoch 6/7
# 672/672 - 161s - loss: 4.0139 - y_start_loss: 1.8429 - y_end_loss: 1.7965 - y_mask_loss: 0.3744 - val_loss: 4.1403 - val_y_start_loss: 1.9006 - val_y_end_loss: 1.8705 - val_y_mask_loss: 0.3691
# Epoch 7/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 161s - loss: 4.0085 - y_start_loss: 1.8417 - y_end_loss: 1.7924 - y_mask_loss: 0.3744 - val_loss: 4.1386 - val_y_start_loss: 1.8996 - val_y_end_loss: 1.8702 - val_y_mask_loss: 0.3687
# Epoch 00007: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col10 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_b8f8c26a_a2c4_11ea_ac0e_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  imputed  \
# 0              10                      10    False
# 1              13                       3    False
# 2               6                       2    False
# 3               6                       3    False
# 4              17                       4    False
# 5              27                      27    False
# 6              17                       1    False
# 7               3                       3    False
# 8               3                       3    False
# 9              19                       7    False
# 10             27                      27    False
# 11             12                       1    False
# 12              9                       1    False
# 13             13                       1    False
# 14              8                       8    False
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
