# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_5.tar.gz

# balanced files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 2,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .998

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 2.04e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    #################### Fine-tune on balanced set ####################
    # Load data
    x_train_fine = np.load('balanced_' + base_data_path + 'x_train.npy')
    y_train_fine = np.load('balanced_' + base_data_path + 'y_train.npy')
    
    step_size_fine = x_train_fine.shape[1] // config['BATCH_SIZE']
    
    # Build TF datasets
    train_dist_ds_fine = strategy.experimental_distribute_dataset(get_training_dataset(x_train_fine, y_train_fine, config['BATCH_SIZE'], AUTO, seed=SEED))
    train_data_iter_fine = iter(train_dist_ds_fine)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))
            
    # New optimizer
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))

    history_fine = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter_fine, valid_data_iter, 
                              step_size_fine, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                              model_path, save_last=True)
    # Join history
    for key in history_fine.keys():
        history[key] += history_fine[key]
    history_list.append(history)
    
    # Make predictions (last model)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(model_path)
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
    shutil.rmtree('balanced_' + base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 281.4s loss: 4.4249 loss_start: 2.2136 loss_end: 2.2113 val_loss: 1.9108 val_loss_start: 0.9943 val_loss_end: 0.9165
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/2
# time: 267.4s loss: 4.0456 loss_start: 2.0410 loss_end: 2.0045 val_loss: 1.8546 val_loss_start: 0.9697 val_loss_end: 0.8850
# Saved model weights at "model_fold_1.h5"
# Training finished saved model weights at "last_model_fold_1.h5"
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 280.0s loss: 4.8484 loss_start: 2.4549 loss_end: 2.3935 val_loss: 1.8320 val_loss_start: 0.9458 val_loss_end: 0.8862
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/2
# time: 268.0s loss: 4.6554 loss_start: 2.3607 loss_end: 2.2948 val_loss: 1.8331 val_loss_start: 0.9484 val_loss_end: 0.8847
# Training finished saved model weights at "last_model_fold_1.h5"
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 281.8s loss: 4.4926 loss_start: 2.2266 loss_end: 2.2660 val_loss: 2.0384 val_loss_start: 1.0352 val_loss_end: 1.0032
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/2
# time: 268.2s loss: 4.0406 loss_start: 2.0372 loss_end: 2.0034 val_loss: 1.9247 val_loss_start: 0.9895 val_loss_end: 0.9352
# Saved model weights at "model_fold_2.h5"
# Training finished saved model weights at "last_model_fold_2.h5"
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 278.9s loss: 4.8550 loss_start: 2.4528 loss_end: 2.4021 val_loss: 2.0067 val_loss_start: 1.0377 val_loss_end: 0.9690
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/2
# time: 267.8s loss: 4.6652 loss_start: 2.3671 loss_end: 2.2981 val_loss: 1.9661 val_loss_start: 0.9973 val_loss_end: 0.9689
# Saved model weights at "model_fold_2.h5"
# Training finished saved model weights at "last_model_fold_2.h5"
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 282.5s loss: 4.4730 loss_start: 2.2300 loss_end: 2.2430 val_loss: 1.9733 val_loss_start: 0.9893 val_loss_end: 0.9840
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/2
# time: 268.2s loss: 4.0822 loss_start: 2.0639 loss_end: 2.0183 val_loss: 1.9071 val_loss_start: 0.9770 val_loss_end: 0.9302
# Saved model weights at "model_fold_3.h5"
# Training finished saved model weights at "last_model_fold_3.h5"
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 281.0s loss: 4.8716 loss_start: 2.4705 loss_end: 2.4011 val_loss: 1.8439 val_loss_start: 0.9398 val_loss_end: 0.9041
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/2
# time: 268.8s loss: 4.6816 loss_start: 2.3766 loss_end: 2.3050 val_loss: 1.8835 val_loss_start: 0.9701 val_loss_end: 0.9134
# Training finished saved model weights at "last_model_fold_3.h5"
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 283.0s loss: 4.4857 loss_start: 2.2088 loss_end: 2.2769 val_loss: 1.9395 val_loss_start: 0.9912 val_loss_end: 0.9483
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/2
# time: 267.6s loss: 4.0778 loss_start: 2.0393 loss_end: 2.0385 val_loss: 1.9130 val_loss_start: 0.9868 val_loss_end: 0.9263
# Saved model weights at "model_fold_4.h5"
# Training finished saved model weights at "last_model_fold_4.h5"
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 281.4s loss: 4.8901 loss_start: 2.4547 loss_end: 2.4354 val_loss: 1.9237 val_loss_start: 0.9944 val_loss_end: 0.9293
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/2
# time: 268.2s loss: 4.6864 loss_start: 2.3550 loss_end: 2.3314 val_loss: 1.8802 val_loss_start: 1.0005 val_loss_end: 0.8796
# Saved model weights at "model_fold_4.h5"
# Training finished saved model weights at "last_model_fold_4.h5"
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 283.6s loss: 4.4208 loss_start: 2.2052 loss_end: 2.2156 val_loss: 1.9338 val_loss_start: 0.9939 val_loss_end: 0.9399
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/2
# time: 268.8s loss: 4.0235 loss_start: 2.0263 loss_end: 1.9971 val_loss: 1.9030 val_loss_start: 0.9744 val_loss_end: 0.9286
# Saved model weights at "model_fold_5.h5"
# Training finished saved model weights at "last_model_fold_5.h5"
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 280.8s loss: 4.8284 loss_start: 2.4444 loss_end: 2.3840 val_loss: 1.9208 val_loss_start: 0.9902 val_loss_end: 0.9306
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/2
# time: 268.4s loss: 4.6407 loss_start: 2.3527 loss_end: 2.2879 val_loss: 1.8669 val_loss_start: 0.9626 val_loss_end: 0.9043
# Saved model weights at "model_fold_5.h5"
# Training finished saved model weights at "last_model_fold_5.h5"

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_097ee048_9b72_11ea_a06e_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_0d924ca6_9b72_11ea_a06e_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  \
# 0              10                      10
# 1              13                       3
# 2               6                       2
# 3               6                       3
# 4              17                       4
# 5              27                      27
# 6              17                       1
# 7               3                       3
# 8               3                       3
# 9              19                       7
# 10             27                      27
# 11             12                       1
# 12              9                       1
# 13             13                       1
# 14              8                       8
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
