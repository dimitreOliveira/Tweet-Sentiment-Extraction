# %%
# !nvidia-smi

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 645kB 3.4MB/s
#      |████████████████████████████████| 3.8MB 15.8MB/s
#      |████████████████████████████████| 1.1MB 46.3MB/s
#      |████████████████████████████████| 890kB 58.1MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/160-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 14 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 4,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 4,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
lr_start=1e-4
warmup_epochs=0
hold_max_epochs=0
num_cycles=0.5
total_epochs = config['EPOCHS']

@tf.function
def lrfn(epoch):
    if epoch < warmup_epochs:
        lr = (LR_MAX - lr_start) / (warmup_epochs * epoch) + lr_start
    elif epoch < warmup_epochs + hold_max_epochs:
        lr = LR_MAX
    else:
        progress = (epoch - warmup_epochs - hold_max_epochs) / (total_epochs - warmup_epochs - hold_max_epochs)
        lr = LR_MAX * (0.5 * (1.0 + tf.math.cos(np.pi * num_cycles * 2.0 * progress)))
        if LR_MIN is not None:
            lr = tf.math.maximum(LR_MIN, lr)
            
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 4.39e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    base_data_path = 'fold_%d/' % (n_fold)

    # Load data
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32)//step_size))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         (MODEL_BASE_PATH + model_path), save_last=False)
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions (last model)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(MODEL_BASE_PATH + model_path)
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7f8be027f7b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.5s loss: 4.4700 loss_start: 2.2294 loss_end: 2.2407 val_loss: 1.9277 val_loss_start: 0.9744 val_loss_end: 0.9533
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_1.h5"
#
# EPOCH 2/4
# time: 266.5s loss: 4.0381 loss_start: 2.0311 loss_end: 2.0069 val_loss: 1.9731 val_loss_start: 1.0211 val_loss_end: 0.9521
#
# EPOCH 3/4
# time: 264.5s loss: 3.8890 loss_start: 1.9560 loss_end: 1.9330 val_loss: 1.9479 val_loss_start: 0.9786 val_loss_end: 0.9693
#
# EPOCH 4/4
# time: 265.6s loss: 3.7758 loss_start: 1.9023 loss_end: 1.8736 val_loss: 1.9622 val_loss_start: 1.0060 val_loss_end: 0.9562
# Training finished
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.8s loss: 4.4335 loss_start: 2.1976 loss_end: 2.2359 val_loss: 1.9654 val_loss_start: 1.0152 val_loss_end: 0.9501
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_2.h5"
#
# EPOCH 2/4
# time: 266.9s loss: 3.9766 loss_start: 2.0103 loss_end: 1.9663 val_loss: 1.8600 val_loss_start: 0.9526 val_loss_end: 0.9074
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_2.h5"
#
# EPOCH 3/4
# time: 269.1s loss: 3.8366 loss_start: 1.9415 loss_end: 1.8952 val_loss: 1.9857 val_loss_start: 1.0356 val_loss_end: 0.9501
#
# EPOCH 4/4
# time: 265.2s loss: 3.7221 loss_start: 1.8831 loss_end: 1.8390 val_loss: 1.9782 val_loss_start: 1.0035 val_loss_end: 0.9747
# Training finished
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.0s loss: 4.3996 loss_start: 2.1938 loss_end: 2.2058 val_loss: 2.0166 val_loss_start: 1.0189 val_loss_end: 0.9977
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_3.h5"
#
# EPOCH 2/4
# time: 266.5s loss: 3.9861 loss_start: 2.0196 loss_end: 1.9665 val_loss: 1.8924 val_loss_start: 0.9780 val_loss_end: 0.9144
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_3.h5"
#
# EPOCH 3/4
# time: 268.5s loss: 3.8459 loss_start: 1.9474 loss_end: 1.8985 val_loss: 1.8738 val_loss_start: 0.9711 val_loss_end: 0.9027
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_3.h5"
#
# EPOCH 4/4
# time: 268.6s loss: 3.7452 loss_start: 1.8963 loss_end: 1.8489 val_loss: 1.9271 val_loss_start: 0.9977 val_loss_end: 0.9294
# Training finished
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.6s loss: 4.4887 loss_start: 2.2119 loss_end: 2.2768 val_loss: 1.9522 val_loss_start: 1.0029 val_loss_end: 0.9493
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_4.h5"
#
# EPOCH 2/4
# time: 267.7s loss: 4.0387 loss_start: 2.0210 loss_end: 2.0177 val_loss: 1.8901 val_loss_start: 0.9824 val_loss_end: 0.9078
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_4.h5"
#
# EPOCH 3/4
# time: 269.2s loss: 3.8870 loss_start: 1.9570 loss_end: 1.9299 val_loss: 1.8618 val_loss_start: 0.9802 val_loss_end: 0.8816
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_4.h5"
#
# EPOCH 4/4
# time: 269.9s loss: 3.7817 loss_start: 1.9078 loss_end: 1.8740 val_loss: 1.8511 val_loss_start: 0.9811 val_loss_end: 0.8701
# Training finished
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/4
# time: 276.0s loss: 4.4110 loss_start: 2.2047 loss_end: 2.2063 val_loss: 1.8955 val_loss_start: 0.9683 val_loss_end: 0.9272
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_5.h5"
#
# EPOCH 2/4
# time: 266.9s loss: 4.0029 loss_start: 2.0204 loss_end: 1.9825 val_loss: 1.8804 val_loss_start: 0.9804 val_loss_end: 0.9000
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/160-roBERTa_base/model_fold_5.h5"
#
# EPOCH 3/4
# time: 269.1s loss: 3.8617 loss_start: 1.9490 loss_end: 1.9127 val_loss: 1.9060 val_loss_start: 0.9869 val_loss_end: 0.9191
#
# EPOCH 4/4
# time: 264.8s loss: 3.7424 loss_start: 1.8925 loss_end: 1.8498 val_loss: 1.8987 val_loss_start: 0.9855 val_loss_end: 0.9132
# Training finished

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_71cfad2e_9a2a_11ea_8839_0242ac1c0002row6_col9

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_7427a7fc_9a2a_11ea_8839_0242ac1c0002row6_col

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       1.000000
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       1.000000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       1.000000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 14 columns]
