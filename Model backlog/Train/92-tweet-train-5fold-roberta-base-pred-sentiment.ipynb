# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_aux.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_aux.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_aux.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_train_aux.npy
# fold_4/y_valid_aux.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_train_aux.npy
# fold_5/y_valid_aux.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    cls_token = last_hidden_state[:, 0, :]
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
#     x_sentiment = layers.GlobalAveragePooling1D()(last_hidden_state)
    x_sentiment = layers.Dropout(.1)(cls_token) 
    y_sentiment = layers.Dense(3, activation='softmax', name='y_sentiment')(x_sentiment) 
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end, y_sentiment])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy(),
                                   'y_sentiment': losses.SparseCategoricalCrossentropy()}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy(),
                                      'y_sentiment': metrics.SparseCategoricalCrossentropy()})
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    y_train_aux = np.load(base_data_path + 'y_train_aux.npy')[1]
    y_valid_aux = np.load(base_data_path + 'y_valid_aux.npy')[1]
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list([y_train[0], y_train[1], y_train_aux]),
                        validation_data=(list(x_valid),  list([y_valid[0], y_valid[1], y_valid_aux])),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 288s - loss: 2.3470 - y_start_loss: 1.0726 - y_end_loss: 1.0906 - y_sentiment_loss: 0.1838 - y_start_categorical_accuracy: 0.6496 - y_end_categorical_accuracy: 0.6517 - y_sentiment_sparse_categorical_crossentropy: 0.1838 - val_loss: 1.6725 - val_y_start_loss: 0.8667 - val_y_end_loss: 0.8051 - val_y_sentiment_loss: 2.8075e-06 - val_y_start_categorical_accuracy: 0.7047 - val_y_end_categorical_accuracy: 0.7243 - val_y_sentiment_sparse_categorical_crossentropy: 2.8080e-06
# Epoch 2/5
# 21984/21984 - 273s - loss: 1.6024 - y_start_loss: 0.8287 - y_end_loss: 0.7730 - y_sentiment_loss: 6.7190e-04 - y_start_categorical_accuracy: 0.7013 - y_end_categorical_accuracy: 0.7252 - y_sentiment_sparse_categorical_crossentropy: 6.7190e-04 - val_loss: 1.5355 - val_y_start_loss: 0.7990 - val_y_end_loss: 0.7360 - val_y_sentiment_loss: 8.2496e-07 - val_y_start_categorical_accuracy: 0.7143 - val_y_end_categorical_accuracy: 0.7289 - val_y_sentiment_sparse_categorical_crossentropy: 8.2523e-07
# Epoch 3/5
# 21984/21984 - 272s - loss: 1.4618 - y_start_loss: 0.7633 - y_end_loss: 0.6981 - y_sentiment_loss: 4.4451e-04 - y_start_categorical_accuracy: 0.7221 - y_end_categorical_accuracy: 0.7436 - y_sentiment_sparse_categorical_crossentropy: 4.4451e-04 - val_loss: 1.5189 - val_y_start_loss: 0.7940 - val_y_end_loss: 0.7243 - val_y_sentiment_loss: 1.8822e-06 - val_y_start_categorical_accuracy: 0.7132 - val_y_end_categorical_accuracy: 0.7291 - val_y_sentiment_sparse_categorical_crossentropy: 1.8844e-06
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.3761 - y_start_loss: 0.7200 - y_end_loss: 0.6558 - y_sentiment_loss: 2.6767e-04 - y_start_categorical_accuracy: 0.7310 - y_end_categorical_accuracy: 0.7555 - y_sentiment_sparse_categorical_crossentropy: 2.6767e-04 - val_loss: 1.5251 - val_y_start_loss: 0.7987 - val_y_end_loss: 0.7257 - val_y_sentiment_loss: 9.1891e-07 - val_y_start_categorical_accuracy: 0.7138 - val_y_end_categorical_accuracy: 0.7344 - val_y_sentiment_sparse_categorical_crossentropy: 9.1982e-07
# Epoch 00004: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 287s - loss: 2.3380 - y_start_loss: 1.0544 - y_end_loss: 1.0935 - y_sentiment_loss: 0.1901 - y_start_categorical_accuracy: 0.6523 - y_end_categorical_accuracy: 0.6469 - y_sentiment_sparse_categorical_crossentropy: 0.1901 - val_loss: 1.7399 - val_y_start_loss: 0.8990 - val_y_end_loss: 0.8403 - val_y_sentiment_loss: 2.3868e-05 - val_y_start_categorical_accuracy: 0.6954 - val_y_end_categorical_accuracy: 0.7149 - val_y_sentiment_sparse_categorical_crossentropy: 2.3881e-05
# Epoch 2/5
# 21984/21984 - 273s - loss: 1.5674 - y_start_loss: 0.8088 - y_end_loss: 0.7579 - y_sentiment_loss: 7.0435e-04 - y_start_categorical_accuracy: 0.7082 - y_end_categorical_accuracy: 0.7283 - y_sentiment_sparse_categorical_crossentropy: 7.0435e-04 - val_loss: 1.6487 - val_y_start_loss: 0.8410 - val_y_end_loss: 0.8073 - val_y_sentiment_loss: 4.5795e-06 - val_y_start_categorical_accuracy: 0.6945 - val_y_end_categorical_accuracy: 0.7236 - val_y_sentiment_sparse_categorical_crossentropy: 4.5808e-06
# Epoch 3/5
# 21984/21984 - 272s - loss: 1.4239 - y_start_loss: 0.7437 - y_end_loss: 0.6797 - y_sentiment_loss: 4.0883e-04 - y_start_categorical_accuracy: 0.7238 - y_end_categorical_accuracy: 0.7520 - y_sentiment_sparse_categorical_crossentropy: 4.0883e-04 - val_loss: 1.6138 - val_y_start_loss: 0.8269 - val_y_end_loss: 0.7865 - val_y_sentiment_loss: 1.4534e-06 - val_y_start_categorical_accuracy: 0.7031 - val_y_end_categorical_accuracy: 0.7202 - val_y_sentiment_sparse_categorical_crossentropy: 1.4539e-06
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.3383 - y_start_loss: 0.6986 - y_end_loss: 0.6394 - y_sentiment_loss: 2.3362e-04 - y_start_categorical_accuracy: 0.7394 - y_end_categorical_accuracy: 0.7601 - y_sentiment_sparse_categorical_crossentropy: 2.3362e-04 - val_loss: 1.6483 - val_y_start_loss: 0.8447 - val_y_end_loss: 0.8031 - val_y_sentiment_loss: 1.7870e-06 - val_y_start_categorical_accuracy: 0.7031 - val_y_end_categorical_accuracy: 0.7213 - val_y_sentiment_sparse_categorical_crossentropy: 1.7875e-06
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 287s - loss: 2.2372 - y_start_loss: 1.0464 - y_end_loss: 1.0462 - y_sentiment_loss: 0.1445 - y_start_categorical_accuracy: 0.6574 - y_end_categorical_accuracy: 0.6638 - y_sentiment_sparse_categorical_crossentropy: 0.1445 - val_loss: 1.6670 - val_y_start_loss: 0.8684 - val_y_end_loss: 0.7981 - val_y_sentiment_loss: 2.6637e-05 - val_y_start_categorical_accuracy: 0.7063 - val_y_end_categorical_accuracy: 0.7254 - val_y_sentiment_sparse_categorical_crossentropy: 2.6639e-05
# Epoch 2/5
# 21984/21984 - 272s - loss: 1.5331 - y_start_loss: 0.7992 - y_end_loss: 0.7334 - y_sentiment_loss: 5.1771e-04 - y_start_categorical_accuracy: 0.7096 - y_end_categorical_accuracy: 0.7349 - y_sentiment_sparse_categorical_crossentropy: 5.1771e-04 - val_loss: 1.5431 - val_y_start_loss: 0.8065 - val_y_end_loss: 0.7361 - val_y_sentiment_loss: 4.9752e-06 - val_y_start_categorical_accuracy: 0.7120 - val_y_end_categorical_accuracy: 0.7371 - val_y_sentiment_sparse_categorical_crossentropy: 4.9752e-06
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.3756 - y_start_loss: 0.7185 - y_end_loss: 0.6568 - y_sentiment_loss: 2.6693e-04 - y_start_categorical_accuracy: 0.7310 - y_end_categorical_accuracy: 0.7562 - y_sentiment_sparse_categorical_crossentropy: 2.6693e-04 - val_loss: 1.5740 - val_y_start_loss: 0.8106 - val_y_end_loss: 0.7626 - val_y_sentiment_loss: 5.0641e-06 - val_y_start_categorical_accuracy: 0.7154 - val_y_end_categorical_accuracy: 0.7344 - val_y_sentiment_sparse_categorical_crossentropy: 5.0645e-06
# Epoch 00003: early stopping
#
# FOLD: 4
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 286s - loss: 2.2605 - y_start_loss: 1.0438 - y_end_loss: 1.0295 - y_sentiment_loss: 0.1872 - y_start_categorical_accuracy: 0.6555 - y_end_categorical_accuracy: 0.6660 - y_sentiment_sparse_categorical_crossentropy: 0.1872 - val_loss: 1.6809 - val_y_start_loss: 0.8917 - val_y_end_loss: 0.7886 - val_y_sentiment_loss: 6.6782e-06 - val_y_start_categorical_accuracy: 0.6996 - val_y_end_categorical_accuracy: 0.7291 - val_y_sentiment_sparse_categorical_crossentropy: 6.6778e-06
# Epoch 2/5
# 21984/21984 - 272s - loss: 1.5497 - y_start_loss: 0.8010 - y_end_loss: 0.7483 - y_sentiment_loss: 4.5588e-04 - y_start_categorical_accuracy: 0.7096 - y_end_categorical_accuracy: 0.7311 - y_sentiment_sparse_categorical_crossentropy: 4.5588e-04 - val_loss: 1.6206 - val_y_start_loss: 0.8275 - val_y_end_loss: 0.7927 - val_y_sentiment_loss: 5.0860e-06 - val_y_start_categorical_accuracy: 0.6994 - val_y_end_categorical_accuracy: 0.7200 - val_y_sentiment_sparse_categorical_crossentropy: 5.0840e-06
# Epoch 3/5
# 21984/21984 - 272s - loss: 1.4342 - y_start_loss: 0.7298 - y_end_loss: 0.7036 - y_sentiment_loss: 8.5392e-04 - y_start_categorical_accuracy: 0.7288 - y_end_categorical_accuracy: 0.7440 - y_sentiment_sparse_categorical_crossentropy: 8.5392e-04 - val_loss: 1.6162 - val_y_start_loss: 0.8295 - val_y_end_loss: 0.7860 - val_y_sentiment_loss: 2.8587e-06 - val_y_start_categorical_accuracy: 0.7014 - val_y_end_categorical_accuracy: 0.7242 - val_y_sentiment_sparse_categorical_crossentropy: 2.8594e-06
# Epoch 4/5
# 21984/21984 - 272s - loss: 1.3336 - y_start_loss: 0.6890 - y_end_loss: 0.6441 - y_sentiment_loss: 5.1601e-04 - y_start_categorical_accuracy: 0.7400 - y_end_categorical_accuracy: 0.7593 - y_sentiment_sparse_categorical_crossentropy: 5.1601e-04 - val_loss: 1.5801 - val_y_start_loss: 0.8292 - val_y_end_loss: 0.7503 - val_y_sentiment_loss: 3.8691e-06 - val_y_start_categorical_accuracy: 0.7040 - val_y_end_categorical_accuracy: 0.7296 - val_y_sentiment_sparse_categorical_crossentropy: 3.8699e-06
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.2831 - y_start_loss: 0.6681 - y_end_loss: 0.6144 - y_sentiment_loss: 5.3269e-04 - y_start_categorical_accuracy: 0.7455 - y_end_categorical_accuracy: 0.7670 - y_sentiment_sparse_categorical_crossentropy: 5.3269e-04 - val_loss: 1.6135 - val_y_start_loss: 0.8505 - val_y_end_loss: 0.7625 - val_y_sentiment_loss: 3.9711e-06 - val_y_start_categorical_accuracy: 0.6998 - val_y_end_categorical_accuracy: 0.7302 - val_y_sentiment_sparse_categorical_crossentropy: 3.9726e-06
# Epoch 00005: early stopping
#
# FOLD: 5
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 287s - loss: 2.4666 - y_start_loss: 1.0949 - y_end_loss: 1.1385 - y_sentiment_loss: 0.2332 - y_start_categorical_accuracy: 0.6454 - y_end_categorical_accuracy: 0.6345 - y_sentiment_sparse_categorical_crossentropy: 0.2332 - val_loss: 1.6947 - val_y_start_loss: 0.8693 - val_y_end_loss: 0.8259 - val_y_sentiment_loss: 2.9100e-04 - val_y_start_categorical_accuracy: 0.7060 - val_y_end_categorical_accuracy: 0.7216 - val_y_sentiment_sparse_categorical_crossentropy: 2.9116e-04
# Epoch 2/5
# 21984/21984 - 272s - loss: 1.6149 - y_start_loss: 0.8325 - y_end_loss: 0.7813 - y_sentiment_loss: 0.0011 - y_start_categorical_accuracy: 0.7020 - y_end_categorical_accuracy: 0.7234 - y_sentiment_sparse_categorical_crossentropy: 0.0011 - val_loss: 1.6131 - val_y_start_loss: 0.8233 - val_y_end_loss: 0.7907 - val_y_sentiment_loss: 1.0209e-04 - val_y_start_categorical_accuracy: 0.7060 - val_y_end_categorical_accuracy: 0.7247 - val_y_sentiment_sparse_categorical_crossentropy: 1.0223e-04
# Epoch 3/5
# 21984/21984 - 272s - loss: 1.5271 - y_start_loss: 0.7748 - y_end_loss: 0.7515 - y_sentiment_loss: 7.2857e-04 - y_start_categorical_accuracy: 0.7163 - y_end_categorical_accuracy: 0.7220 - y_sentiment_sparse_categorical_crossentropy: 7.2857e-04 - val_loss: 1.6014 - val_y_start_loss: 0.8153 - val_y_end_loss: 0.7872 - val_y_sentiment_loss: 3.1117e-05 - val_y_start_categorical_accuracy: 0.7112 - val_y_end_categorical_accuracy: 0.7273 - val_y_sentiment_sparse_categorical_crossentropy: 3.1151e-05
# Epoch 4/5
# 21984/21984 - 272s - loss: 1.4019 - y_start_loss: 0.7274 - y_end_loss: 0.6740 - y_sentiment_loss: 4.7092e-04 - y_start_categorical_accuracy: 0.7281 - y_end_categorical_accuracy: 0.7524 - y_sentiment_sparse_categorical_crossentropy: 4.7092e-04 - val_loss: 1.5880 - val_y_start_loss: 0.8168 - val_y_end_loss: 0.7723 - val_y_sentiment_loss: 5.1436e-05 - val_y_start_categorical_accuracy: 0.7134 - val_y_end_categorical_accuracy: 0.7305 - val_y_sentiment_sparse_categorical_crossentropy: 5.1503e-05
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 1.3563 - y_start_loss: 0.7052 - y_end_loss: 0.6508 - y_sentiment_loss: 3.8073e-04 - y_start_categorical_accuracy: 0.7356 - y_end_categorical_accuracy: 0.7569 - y_sentiment_sparse_categorical_crossentropy: 3.8073e-04 - val_loss: 1.5967 - val_y_start_loss: 0.8234 - val_y_end_loss: 0.7743 - val_y_sentiment_loss: 5.0780e-05 - val_y_start_categorical_accuracy: 0.7091 - val_y_end_categorical_accuracy: 0.7325 - val_y_sentiment_sparse_categorical_crossentropy: 5.0846e-05
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col0 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col4 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col6 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col8 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col11 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row1_col12 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col9 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col10 {
#             color:  green;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_c67338f6_8bf6_11ea_a916_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going             1.0
# 1                                            sooo sad             1.0
# 2                                            bullying             0.5
# 3                                      leave me alone             1.0
# 4                                       sons of ****,             1.0
# 5   http://www.dothebouncy.com/smf - some shameles...             1.0
# 6                                                 fun             1.0
# 7                                          soooo high             1.0
# 8                                         both of you             1.0
# 9                        wow... u just became cooler.             1.0
# 10  as much as i love to be hopeful, i reckon the ...             1.0
# 11                                               like             1.0
# 12                                    dangerously low             0.5
# 13                                               lost             1.0
# 14                         test test from the lg env2             1.0
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                           my boss is bullying me...        0.166667
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12              my sharpie is running dangerously low        0.166667
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
