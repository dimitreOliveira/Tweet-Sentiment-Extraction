# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
import tweet_utility_preprocess_roberta_scripts_text as preprocess_text
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/no_qa_fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/no_qa_fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/no_qa_fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/no_qa_fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/no_qa_fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9987

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    input_sentiment = layers.Input(shape=(3,), dtype=tf.float32, name='input_sentiment')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    x_start = layers.Activation('softmax')(x_start)
    
    y_start_negative = layers.Multiply(name='y_start_negative')([x_start, input_sentiment[: ,0]])
    y_start_neutral = layers.Multiply(name='y_start_neutral')([x_start, input_sentiment[: ,1]])
    y_start_positive = layers.Multiply(name='y_start_positive')([x_start, input_sentiment[: ,2]])
    y_start = layers.Add(name='y_start')([y_start_negative, y_start_neutral, y_start_positive])
    
    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    x_end = layers.Activation('softmax')(x_end)

    y_end_negative = layers.Multiply(name='y_end_negative')([x_end, input_sentiment[: ,0]])
    y_end_neutral = layers.Multiply(name='y_end_neutral')([x_end, input_sentiment[: ,1]])
    y_end_positive = layers.Multiply(name='y_end_positive')([x_end, input_sentiment[: ,2]])
    y_end = layers.Add(name='y_end')([y_end_negative, y_end_neutral, y_end_positive])
    
    model = Model(inputs=[input_ids, attention_mask, input_sentiment], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1], 'input_sentiment': x_train[2]}, 
                                                  {'y_start': y_train[0],'y_end': y_train[1]}))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1], 'input_sentiment': x_valid[2]}, 
                                                  {'y_start': y_valid[0],'y_end': y_valid[1]}))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_test_dataset(x_test, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices({'input_ids': x_test[0], 'attention_mask': x_test[1], 'input_sentiment': x_test[2]})
    dataset = dataset.batch(batch_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'no_qa_fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_train_aux2 = np.load(base_data_path + 'x_train_aux2.npy').astype(np.float32)
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    x_valid_aux2 = np.load(base_data_path + 'x_valid_aux2.npy').astype(np.float32)
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset((*x_train, x_train_aux2), y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset((*x_valid, x_valid_aux2), y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0])
                loss_end = loss_fn(y['y_end'], probabilities[1])
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    history_list.append(history)
    
    # Make predictions (last model)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset((*x_train, x_train_aux2), config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset((*x_valid, x_valid_aux2), config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: preprocess_text.decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(model_path)
    train_preds = model.predict(get_test_dataset((*x_train, x_train_aux2), config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset((*x_valid, x_valid_aux2), config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: preprocess_text.decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 278.9s loss: 2.6339 loss_start: 1.2878 loss_end: 1.3461 val_loss: 2.1642 val_loss_start: 1.0886 val_loss_end: 1.0756
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/4
# time: 264.6s loss: 2.1208 loss_start: 1.0616 loss_end: 1.0592 val_loss: 2.0795 val_loss_start: 1.0611 val_loss_end: 1.0184
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/4
# time: 265.0s loss: 1.9821 loss_start: 0.9937 loss_end: 0.9884 val_loss: 2.1026 val_loss_start: 1.0605 val_loss_end: 1.0421
#
# EPOCH 4/4
# time: 263.5s loss: 1.9108 loss_start: 0.9657 loss_end: 0.9451 val_loss: 2.0863 val_loss_start: 1.0588 val_loss_end: 1.0276
# Training finished saved model weights at "last_model_fold_1.h5"
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 278.6s loss: 2.5276 loss_start: 1.2479 loss_end: 1.2797 val_loss: 2.2158 val_loss_start: 1.1254 val_loss_end: 1.0904
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/4
# time: 264.3s loss: 2.0545 loss_start: 1.0419 loss_end: 1.0126 val_loss: 2.1719 val_loss_start: 1.1010 val_loss_end: 1.0709
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 3/4
# time: 264.7s loss: 1.9198 loss_start: 0.9728 loss_end: 0.9470 val_loss: 2.1757 val_loss_start: 1.1138 val_loss_end: 1.0619
#
# EPOCH 4/4
# time: 263.3s loss: 1.8445 loss_start: 0.9378 loss_end: 0.9067 val_loss: 2.1664 val_loss_start: 1.0815 val_loss_end: 1.0850
# Saved model weights at "model_fold_2.h5"
# Training finished saved model weights at "last_model_fold_2.h5"
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 278.3s loss: 2.6597 loss_start: 1.3022 loss_end: 1.3575 val_loss: 2.1902 val_loss_start: 1.0746 val_loss_end: 1.1156
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/4
# time: 264.2s loss: 2.1243 loss_start: 1.0785 loss_end: 1.0458 val_loss: 2.0924 val_loss_start: 1.0446 val_loss_end: 1.0477
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/4
# time: 264.5s loss: 1.9697 loss_start: 1.0057 loss_end: 0.9640 val_loss: 2.0610 val_loss_start: 1.0363 val_loss_end: 1.0247
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 4/4
# time: 264.5s loss: 1.9082 loss_start: 0.9728 loss_end: 0.9354 val_loss: 2.0897 val_loss_start: 1.0507 val_loss_end: 1.0390
# Training finished saved model weights at "last_model_fold_3.h5"
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 278.1s loss: 2.5456 loss_start: 1.2448 loss_end: 1.3007 val_loss: 2.1841 val_loss_start: 1.1159 val_loss_end: 1.0682
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/4
# time: 264.3s loss: 2.0861 loss_start: 1.0423 loss_end: 1.0438 val_loss: 2.0987 val_loss_start: 1.0745 val_loss_end: 1.0243
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 3/4
# time: 264.5s loss: 1.9343 loss_start: 0.9776 loss_end: 0.9567 val_loss: 2.0901 val_loss_start: 1.0721 val_loss_end: 1.0179
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 4/4
# time: 264.5s loss: 1.8659 loss_start: 0.9454 loss_end: 0.9204 val_loss: 2.0965 val_loss_start: 1.0884 val_loss_end: 1.0081
# Training finished saved model weights at "last_model_fold_4.h5"
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 276.7s loss: 2.5743 loss_start: 1.2618 loss_end: 1.3125 val_loss: 2.1360 val_loss_start: 1.0651 val_loss_end: 1.0708
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/4
# time: 263.7s loss: 2.0931 loss_start: 1.0496 loss_end: 1.0435 val_loss: 2.0848 val_loss_start: 1.0444 val_loss_end: 1.0405
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 3/4
# time: 263.9s loss: 1.9500 loss_start: 0.9824 loss_end: 0.9676 val_loss: 2.0697 val_loss_start: 1.0481 val_loss_end: 1.0217
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 4/4
# time: 264.0s loss: 1.8720 loss_start: 0.9455 loss_end: 0.9265 val_loss: 2.0588 val_loss_start: 1.0391 val_loss_end: 1.0197
# Saved model weights at "model_fold_5.h5"
# Training finished saved model weights at "last_model_fold_5.h5"

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col1 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col4 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col6 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col8 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col10 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row1_col12 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col1 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col3 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col4 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col6 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col7 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col8 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col10 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row3_col12 {
#             color:  orange;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_7337903e_9c94_11ea_afc2_0242ac13

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col1 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col3 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col4 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col6 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col8 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col10 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row1_col12 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col0 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col1 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col3 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col4 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col6 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col7 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col8 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col10 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row3_col12 {
#             color:  orange;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_76eb585a_9c94_11ea_afc2_0242ac

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  \
# 0              10                      10
# 1              13                       3
# 2               6                       2
# 3               6                       3
# 4              17                       4
# 5              27                      27
# 6              17                       1
# 7               3                       3
# 8               3                       3
# 9              19                       7
# 10             27                      27
# 11             12                       1
# 12              9                       1
# 13             13                       1
# 14              8                       8
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                           my boss is bullying me...        0.166667
# 3                      what interview! leave me alone        0.600000
# 4                                       sons of ****,        1.000000
# 5                         best rangers forum on earth        0.416667
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9              journey!? wow... u just became cooler.        0.833333
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                           my boss is bullying me...        0.166667
# 3                      what interview! leave me alone        0.600000
# 4                                       sons of ****,        1.000000
# 5                                                best        0.083333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                    journey!? wow...        0.166667
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                      what interview! leave me alone        0.600000
# 4                                       sons of ****,        1.000000
# 5                                                best        0.083333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9              journey!? wow... u just became cooler.        0.833333
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                      what interview! leave me alone        0.600000
# 4                                       sons of ****,        1.000000
# 5                                                best        0.083333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                      what interview! leave me alone        0.600000
# 4                                       sons of ****,        1.000000
# 5                                                best        0.083333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9              journey!? wow... u just became cooler.        0.833333
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
