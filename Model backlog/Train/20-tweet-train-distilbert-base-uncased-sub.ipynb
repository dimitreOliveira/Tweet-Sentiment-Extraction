# %% [markdown]
# ## Dependencies

# %%
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

y_train = y_train.argmax(-1)
y_valid = y_valid.argmax(-1)

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
#
#    selected_text_len    set
# 0                 95  train
# 1                 10  train
# 2                 23  train
# 3                  9  train
# 4                 41  train
# hold_out/
# hold_out/y_valid.npy
# hold_out/x_train.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 128
BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 1e-5
ES_PATIENCE = 3
question_size = 3

tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
base_model_path = base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5'
config_path = base_path + 'distilbert-base-uncased-distilled-squad-config.json'
model_path = 'model.h5'
log_path = './'

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config_path, output_hidden_states=False)

def model_fn():
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(base_model_path, config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(1, activation='linear', name='y_start')(x)     
    y_end = Dense(1, activation='linear', name='y_end')(x)        
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
                  loss=losses.MeanSquaredError(), 
                  metrics=[metrics.MeanAbsoluteError(), metrics.MeanSquaredError()])
    
    return model

model = model_fn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 1)            769         global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 1)            769         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,364,418
# Trainable params: 66,364,418
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir=log_path)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=EPOCHS, 
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/20
# 21984/21984 - 179s - loss: 91.7765 - y_start_loss: 34.1383 - y_end_loss: 57.6381 - y_start_mean_absolute_error: 3.5656 - y_start_mean_squared_error: 34.1383 - y_end_mean_absolute_error: 5.2094 - y_end_mean_squared_error: 57.6381 - val_loss: 64.5879 - val_y_start_loss: 25.3066 - val_y_end_loss: 39.3331 - val_y_start_mean_absolute_error: 2.8624 - val_y_start_mean_squared_error: 25.2787 - val_y_end_mean_absolute_error: 4.1480 - val_y_end_mean_squared_error: 39.3092
# Epoch 2/20
# 21984/21984 - 171s - loss: 58.6567 - y_start_loss: 23.1245 - y_end_loss: 35.5322 - y_start_mean_absolute_error: 2.7474 - y_start_mean_squared_error: 23.1245 - y_end_mean_absolute_error: 3.9056 - y_end_mean_squared_error: 35.5322 - val_loss: 51.8775 - val_y_start_loss: 21.0106 - val_y_end_loss: 30.9082 - val_y_start_mean_absolute_error: 2.6080 - val_y_start_mean_squared_error: 20.9902 - val_y_end_mean_absolute_error: 3.4800 - val_y_end_mean_squared_error: 30.8873
# Epoch 3/20
# 21984/21984 - 171s - loss: 48.0536 - y_start_loss: 19.8083 - y_end_loss: 28.2453 - y_start_mean_absolute_error: 2.5148 - y_start_mean_squared_error: 19.8083 - y_end_mean_absolute_error: 3.3790 - y_end_mean_squared_error: 28.2453 - val_loss: 46.8532 - val_y_start_loss: 19.8289 - val_y_end_loss: 27.0569 - val_y_start_mean_absolute_error: 2.5214 - val_y_start_mean_squared_error: 19.8135 - val_y_end_mean_absolute_error: 3.1433 - val_y_end_mean_squared_error: 27.0397
# Epoch 4/20
# 21984/21984 - 171s - loss: 40.7375 - y_start_loss: 17.3858 - y_end_loss: 23.3516 - y_start_mean_absolute_error: 2.3453 - y_start_mean_squared_error: 17.3858 - y_end_mean_absolute_error: 3.0463 - y_end_mean_squared_error: 23.3516 - val_loss: 44.8579 - val_y_start_loss: 18.7210 - val_y_end_loss: 26.1621 - val_y_start_mean_absolute_error: 2.4691 - val_y_start_mean_squared_error: 18.7141 - val_y_end_mean_absolute_error: 3.1066 - val_y_end_mean_squared_error: 26.1438
# Epoch 5/20
# 21984/21984 - 171s - loss: 34.7610 - y_start_loss: 15.2931 - y_end_loss: 19.4679 - y_start_mean_absolute_error: 2.1778 - y_start_mean_squared_error: 15.2931 - y_end_mean_absolute_error: 2.7345 - y_end_mean_squared_error: 19.4679 - val_loss: 41.6217 - val_y_start_loss: 17.7711 - val_y_end_loss: 23.8798 - val_y_start_mean_absolute_error: 2.2381 - val_y_start_mean_squared_error: 17.7616 - val_y_end_mean_absolute_error: 2.7769 - val_y_end_mean_squared_error: 23.8601
# Epoch 6/20
# 21984/21984 - 171s - loss: 30.3863 - y_start_loss: 13.6465 - y_end_loss: 16.7399 - y_start_mean_absolute_error: 2.0519 - y_start_mean_squared_error: 13.6465 - y_end_mean_absolute_error: 2.5197 - y_end_mean_squared_error: 16.7399 - val_loss: 41.7978 - val_y_start_loss: 17.8823 - val_y_end_loss: 23.9475 - val_y_start_mean_absolute_error: 2.2693 - val_y_start_mean_squared_error: 17.8751 - val_y_end_mean_absolute_error: 3.0184 - val_y_end_mean_squared_error: 23.9227
# Epoch 7/20
# 21984/21984 - 171s - loss: 26.4829 - y_start_loss: 12.1730 - y_end_loss: 14.3099 - y_start_mean_absolute_error: 1.9363 - y_start_mean_squared_error: 12.1730 - y_end_mean_absolute_error: 2.3090 - y_end_mean_squared_error: 14.3099 - val_loss: 42.6628 - val_y_start_loss: 18.6299 - val_y_end_loss: 24.0630 - val_y_start_mean_absolute_error: 2.2984 - val_y_start_mean_squared_error: 18.6183 - val_y_end_mean_absolute_error: 2.6621 - val_y_end_mean_squared_error: 24.0445
# Epoch 8/20
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 171s - loss: 23.6695 - y_start_loss: 10.8758 - y_end_loss: 12.7937 - y_start_mean_absolute_error: 1.8345 - y_start_mean_squared_error: 10.8758 - y_end_mean_absolute_error: 2.1770 - y_end_mean_squared_error: 12.7937 - val_loss: 41.6869 - val_y_start_loss: 18.0785 - val_y_end_loss: 23.6374 - val_y_start_mean_absolute_error: 2.1789 - val_y_start_mean_squared_error: 18.0679 - val_y_end_mean_absolute_error: 2.6827 - val_y_end_mean_squared_error: 23.6190
# Epoch 00008: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-10_21-02-15/
# train/plugins/profile/2020-04-10_21-02-15/local.trace
# train/events.out.tfevents.1586552529.5a3245e87f71.13.5441.v2
# train/events.out.tfevents.1586552535.5a3245e87f71.profile-empty
# validation/
# validation/events.out.tfevents.1586552708.5a3245e87f71.13.26298.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_mean_squared_error', 'y_end_mean_absolute_error'])

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

# # train['start'] = train_preds[0].argmax(axis=-1)
# # train['end'] = train_preds[1].argmax(axis=-1)
train['start'] = train_preds[0].astype(int)
train['end'] = train_preds[1].astype(int)
train["end"].clip(0, train["text_len"], inplace=True)
train["start"].clip(0, train["end"], inplace=True)

train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], question_size, tokenizer), axis=1)
train["prediction"].fillna('', inplace=True)

# validation['start'] = valid_preds[0].argmax(axis=-1)
# validation['end'] = valid_preds[1].argmax(axis=-1)
validation['start'] = valid_preds[0].astype(int)
validation['end'] = valid_preds[1].astype(int)
validation["end"].clip(0, validation["text_len"], inplace=True)
validation["start"].clip(0, validation["end"], inplace=True)

validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], question_size, tokenizer), axis=1)
validation["prediction"].fillna('', inplace=True)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.540277    0.517338          21984
# Sentiment neutral            0.866582    0.858554           8842
# Sentiment negative           0.320948    0.284111           6258
# Sentiment positive           0.320548    0.269364           6884
# 0 <= text < 10               0.794745    0.737500            203
# 10 <= text < 50              0.610557    0.602608           7823
# 50 <= text < 100             0.515348    0.492522           8858
# 100 <= text < 200            0.465644    0.425708           5100
# 0 <= selected text < 10      0.247990    0.214294           6326
# 10 <= selected text < 50     0.584081    0.546401           9575
# 50 <= selected text < 100    0.763427    0.754601           4075
# 100 <= selected text < 200   0.799371    0.780779           2008
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5496
# Sentiment neutral                          2275
# Sentiment negative                         1523
# Sentiment positive                         1698
# 0 <= text < 10                               40
# 10 <= text < 50                            1945
# 50 <= text < 100                           2201
# 100 <= text < 200                          1310
# 0 <= selected text < 10                    1492
# 10 <= selected text < 50                   2455
# 50 <= selected text < 100                  1042
# 100 <= selected text < 200                  507

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
# 5  cb280b3adb  _ kk`s  have fun eating lol, remember shaun lo...
# 6  8dd41515ff                                   definitley miley
# 7  60fa8ea66e         just going to shower. brb in 10 mins or so
# 8  bb4ac6eb31              back to work.. with no distractions..
# 9  2f858c20c3   cool, i used to live 5 houses to the left of ...
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
# 5                                                fun  positive        58
# 6                                   definitley miley   neutral        17
# 7         just going to shower. brb in 10 mins or so   neutral        42
# 8              back to work.. with no distractions..  positive        37
# 9                                              cool,  positive        86
#
#    selected_text_len    set  start  end  \
# 0                 95  train      3   32
# 1                 10  train      4    6
# 2                 23  train      6   10
# 3                  9  train      9   13
# 4                 41  train      3   17
# 5                  3  train     11   14
# 6                 16  train      4    8
# 7                 42  train      3   16
# 8                 37  train      8   11
# 9                  5  train      4    8
#
#                                           prediction  jaccard
# 0  cant stop playin` in my head  -- pussycat doll...    0.875
# 1                                         i hate you    1.000
# 2                                          `m lovin`    0.200
# 3                                          .yummmmy!    1.000
# 4          wow.. purple leopard skin.  fieeerrceee..    1.000
# 5                                        eating lol,    0.000
# 6                                   definitley miley    1.000
# 7         just going to shower. brb in 10 mins or so    1.000
# 8                              . with no distraction    0.250
# 9                                    cool, i used to    0.250
# Validation set
#            textID                                               text  \
# 21984  3391184efc              loves the nice weather and 7:30 exams
# 21985  b35daf9677  okay, this weather isn`t 'cute sundress' frien...
# 21986  06e5249859                          woo hoo!! congratulations
# 21987  3cd4960670   thanks   got a hold of someone there who knew...
# 21988  92b75314ca  got back and putting in the laundry. we got in...
# 21989  7438c9c09a                    congrats on graduating college!
# 21990  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 21991  a4ede54987  it`s the weekend but 9 year old is grounded wh...
# 21992  35124a7481   it`s been fine for me for like, a week, but n...
# 21993  e4b6c9a295                      ntah, i really wanna be there
#
#                                            selected_text sentiment  text_len  \
# 21984                                              loves  positive        37
# 21985  okay, this weather isn`t 'cute sundress' frien...   neutral       130
# 21986                                    congratulations  positive        26
# 21987                                             thanks  positive        68
# 21988  got back and putting in the laundry. we got in...   neutral        95
# 21989                                           congrats  positive        32
# 21990  can you get me a sub from subway when ur on yo...   neutral        58
# 21991  it`s the weekend but 9 year old is grounded wh...   neutral        71
# 21992  it`s been fine for me for like, a week, but no...   neutral        68
# 21993                                              wanna  positive        30
#
#        selected_text_len         set  start  end  \
# 21984                  5  validation      4    6
# 21985                130  validation      4   33
# 21986                 15  validation      6    8
# 21987                  6  validation      3    5
# 21988                 95  validation      3   28
# 21989                  8  validation      4    6
# 21990                 58  validation      3   18
# 21991                 71  validation      4   19
# 21992                 67  validation      4   24
# 21993                  5  validation      6    9
#
#                                               prediction   jaccard
# 21984                                     loves the nice  0.333333
# 21985  okay, this weather isn`t 'cute sundress' frien...  0.875000
# 21986                                                o!!  0.000000
# 21987                                       thanks   got  0.500000
# 21988  got back and putting in the laundry. we got in...  0.888889
# 21989                                           congrats  1.000000
# 21990  can you get me a sub from subway when ur on yo...  1.000000
# 21991  it`s the weekend but 9 year old is grounded wh...  1.000000
# 21992  it`s been fine for me for like, a week, but no...  0.866667
# 21993                                   , i really wanna  0.250000
