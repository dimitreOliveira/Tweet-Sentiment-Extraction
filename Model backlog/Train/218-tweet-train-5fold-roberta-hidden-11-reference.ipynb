# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 26882
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2 fold_3      fold_4 fold_5  \
# 0                      10       train  validation  train       train  train
# 1                       3  validation       train  train       train  train
# 2                       2       train       train  train  validation  train
# 3                       3       train       train  train  validation  train
# 4                       4       train       train  train  validation  train
#
#    imputed
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.96e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]
    
    start_logits = layers.Dense(1, name="start_logit", use_bias=False)(h11)
    start_logits = layers.Flatten()(start_logits)

    end_logits = layers.Dense(1, name="end_logit", use_bias=False)(h11)
    end_logits = layers.Flatten()(end_logits)

    start_probs = layers.Activation('softmax', name='y_start')(start_logits)
    end_probs = layers.Activation('softmax', name='y_end')(end_logits)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_probs, end_probs])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 175s - loss: 4.6513 - y_start_loss: 2.2740 - y_end_loss: 2.3773 - val_loss: 3.8394 - val_y_start_loss: 1.9411 - val_y_end_loss: 1.8983
# Epoch 2/7
# 672/672 - 163s - loss: 3.7998 - y_start_loss: 1.9021 - y_end_loss: 1.8977 - val_loss: 3.7876 - val_y_start_loss: 1.9164 - val_y_end_loss: 1.8712
# Epoch 3/7
# 672/672 - 163s - loss: 3.6798 - y_start_loss: 1.8524 - y_end_loss: 1.8274 - val_loss: 3.7810 - val_y_start_loss: 1.9135 - val_y_end_loss: 1.8675
# Epoch 4/7
# 672/672 - 163s - loss: 3.6437 - y_start_loss: 1.8372 - y_end_loss: 1.8065 - val_loss: 3.7759 - val_y_start_loss: 1.9129 - val_y_end_loss: 1.8630
# Epoch 5/7
# 672/672 - 163s - loss: 3.6253 - y_start_loss: 1.8280 - y_end_loss: 1.7974 - val_loss: 3.7737 - val_y_start_loss: 1.9112 - val_y_end_loss: 1.8624
# Epoch 6/7
# 672/672 - 161s - loss: 3.6213 - y_start_loss: 1.8282 - y_end_loss: 1.7932 - val_loss: 3.7749 - val_y_start_loss: 1.9123 - val_y_end_loss: 1.8627
# Epoch 7/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 3.6058 - y_start_loss: 1.8173 - y_end_loss: 1.7885 - val_loss: 3.7766 - val_y_start_loss: 1.9127 - val_y_end_loss: 1.8639
# Epoch 00007: early stopping
#
# FOLD: 2
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 175s - loss: 4.5849 - y_start_loss: 2.2613 - y_end_loss: 2.3236 - val_loss: 3.8168 - val_y_start_loss: 1.9302 - val_y_end_loss: 1.8866
# Epoch 2/7
# 672/672 - 163s - loss: 3.7565 - y_start_loss: 1.9002 - y_end_loss: 1.8563 - val_loss: 3.7548 - val_y_start_loss: 1.8993 - val_y_end_loss: 1.8555
# Epoch 3/7
# 672/672 - 162s - loss: 3.6541 - y_start_loss: 1.8492 - y_end_loss: 1.8049 - val_loss: 3.7629 - val_y_start_loss: 1.9046 - val_y_end_loss: 1.8583
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 3.5998 - y_start_loss: 1.8228 - y_end_loss: 1.7770 - val_loss: 3.7678 - val_y_start_loss: 1.9076 - val_y_end_loss: 1.8602
# Epoch 00004: early stopping
#
# FOLD: 3
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 174s - loss: 4.7295 - y_start_loss: 2.2856 - y_end_loss: 2.4439 - val_loss: 4.1675 - val_y_start_loss: 1.9905 - val_y_end_loss: 2.1770
# Epoch 2/7
# 672/672 - 163s - loss: 3.9245 - y_start_loss: 1.9581 - y_end_loss: 1.9664 - val_loss: 3.8185 - val_y_start_loss: 1.9238 - val_y_end_loss: 1.8948
# Epoch 3/7
# 672/672 - 163s - loss: 3.7880 - y_start_loss: 1.9065 - y_end_loss: 1.8815 - val_loss: 3.7725 - val_y_start_loss: 1.9080 - val_y_end_loss: 1.8645
# Epoch 4/7
# 672/672 - 163s - loss: 3.7448 - y_start_loss: 1.8868 - y_end_loss: 1.8580 - val_loss: 3.7700 - val_y_start_loss: 1.9089 - val_y_end_loss: 1.8611
# Epoch 5/7
# 672/672 - 163s - loss: 3.7142 - y_start_loss: 1.8739 - y_end_loss: 1.8403 - val_loss: 3.7656 - val_y_start_loss: 1.9064 - val_y_end_loss: 1.8592
# Epoch 6/7
# 672/672 - 163s - loss: 3.7196 - y_start_loss: 1.8767 - y_end_loss: 1.8429 - val_loss: 3.7628 - val_y_start_loss: 1.9048 - val_y_end_loss: 1.8580
# Epoch 7/7
# 672/672 - 163s - loss: 3.7112 - y_start_loss: 1.8702 - y_end_loss: 1.8410 - val_loss: 3.7624 - val_y_start_loss: 1.9042 - val_y_end_loss: 1.8582
#
# FOLD: 4
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 175s - loss: 4.6460 - y_start_loss: 2.2873 - y_end_loss: 2.3587 - val_loss: 3.8305 - val_y_start_loss: 1.9315 - val_y_end_loss: 1.8990
# Epoch 2/7
# 672/672 - 163s - loss: 3.7781 - y_start_loss: 1.9106 - y_end_loss: 1.8675 - val_loss: 3.7568 - val_y_start_loss: 1.8928 - val_y_end_loss: 1.8640
# Epoch 3/7
# 672/672 - 163s - loss: 3.6764 - y_start_loss: 1.8584 - y_end_loss: 1.8180 - val_loss: 3.7417 - val_y_start_loss: 1.8905 - val_y_end_loss: 1.8512
# Epoch 4/7
# 672/672 - 163s - loss: 3.6319 - y_start_loss: 1.8413 - y_end_loss: 1.7906 - val_loss: 3.7389 - val_y_start_loss: 1.8881 - val_y_end_loss: 1.8508
# Epoch 5/7
# 672/672 - 162s - loss: 3.6104 - y_start_loss: 1.8293 - y_end_loss: 1.7811 - val_loss: 3.7417 - val_y_start_loss: 1.8906 - val_y_end_loss: 1.8511
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 3.5987 - y_start_loss: 1.8247 - y_end_loss: 1.7741 - val_loss: 3.7421 - val_y_start_loss: 1.8912 - val_y_end_loss: 1.8509
# Epoch 00006: early stopping
#
# FOLD: 5
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 174s - loss: 4.6422 - y_start_loss: 2.2764 - y_end_loss: 2.3658 - val_loss: 3.8511 - val_y_start_loss: 1.9357 - val_y_end_loss: 1.9153
# Epoch 2/7
# 672/672 - 164s - loss: 3.7959 - y_start_loss: 1.9160 - y_end_loss: 1.8800 - val_loss: 3.7496 - val_y_start_loss: 1.8891 - val_y_end_loss: 1.8606
# Epoch 3/7
# 672/672 - 163s - loss: 3.6822 - y_start_loss: 1.8636 - y_end_loss: 1.8186 - val_loss: 3.7467 - val_y_start_loss: 1.8875 - val_y_end_loss: 1.8592
# Epoch 4/7
# 672/672 - 163s - loss: 3.6499 - y_start_loss: 1.8395 - y_end_loss: 1.8104 - val_loss: 3.7449 - val_y_start_loss: 1.8860 - val_y_end_loss: 1.8589
# Epoch 5/7
# 672/672 - 161s - loss: 3.6267 - y_start_loss: 1.8334 - y_end_loss: 1.7934 - val_loss: 3.7457 - val_y_start_loss: 1.8844 - val_y_end_loss: 1.8613
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 162s - loss: 3.6165 - y_start_loss: 1.8252 - y_end_loss: 1.7913 - val_loss: 3.7512 - val_y_start_loss: 1.8881 - val_y_end_loss: 1.8631
# Epoch 00006: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col10 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_c5dfcf8a_a2bc_11ea_853c_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  imputed  \
# 0              10                      10    False
# 1              13                       3    False
# 2               6                       2    False
# 3               6                       3    False
# 4              17                       4    False
# 5              27                      27    False
# 6              17                       1    False
# 7               3                       3    False
# 8               3                       3    False
# 9              19                       7    False
# 10             27                      27    False
# 11             12                       1    False
# 12              9                       1    False
# 13             13                       1    False
# 14              8                       8    False
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
