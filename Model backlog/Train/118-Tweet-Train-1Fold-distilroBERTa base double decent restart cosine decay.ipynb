# %%
# !nvidia-smi

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 645kB 2.9MB/s
#      |████████████████████████████████| 3.8MB 16.0MB/s
#      |████████████████████████████████| 1.0MB 38.5MB/s
#      |████████████████████████████████| 890kB 43.3MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/118-distilroBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/distilroberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/distilroberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 70,
  "LEARNING_RATE": 3e-5,
  # "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 1,
  "base_model_path": base_path + 'distilroberta-base-tf_model.h5',
  "config_path": base_path + 'distilroberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-7
LR_MAX = config['LEARNING_RATE']
lr_start=1e-4
warmup_epochs=0
hold_max_epochs=0
num_cycles=config['EPOCHS'] // 5
total_epochs = config['EPOCHS']

# @tf.function
def lrfn(epoch):
    if epoch < warmup_epochs:
        lr = (LR_MAX - lr_start) / warmup_epochs * epoch + lr_start
    else:
        progress = (epoch - warmup_epochs) / (total_epochs - warmup_epochs)
        lr = LR_MAX * (0.5 * (1.0 + np.cos(np.pi * ((num_cycles * progress) % 1.0))))
        if LR_MIN is not None:
            lr = max(LR_MIN, lr)
            
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 2.86e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model_path_chk = 'model_fold_%d_{epoch:02d}.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    # es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
    #                    restore_best_weights=True, verbose=1)
    # checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
    #                              save_best_only=True, save_weights_only=True)
    checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path_chk, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        # callbacks=[checkpoint, es, lr_schedule],
                        callbacks=[checkpoint, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH + model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Epoch 1/70
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 142s - loss: 2.2053 - y_start_loss: 1.1044 - y_end_loss: 1.1008 - y_start_categorical_accuracy: 0.6421 - y_end_categorical_accuracy: 0.6468 - val_loss: 1.6364 - val_y_start_loss: 0.8487 - val_y_end_loss: 0.7876 - val_y_start_categorical_accuracy: 0.6965 - val_y_end_categorical_accuracy: 0.7243 - lr: 3.0000e-05
# Epoch 2/70
# 687/687 - 140s - loss: 1.6423 - y_start_loss: 0.8495 - y_end_loss: 0.7928 - y_start_categorical_accuracy: 0.6998 - y_end_categorical_accuracy: 0.7238 - val_loss: 1.5938 - val_y_start_loss: 0.8266 - val_y_end_loss: 0.7671 - val_y_start_categorical_accuracy: 0.7065 - val_y_end_categorical_accuracy: 0.7229 - lr: 2.7135e-05
# Epoch 3/70
# 687/687 - 140s - loss: 1.4542 - y_start_loss: 0.7603 - y_end_loss: 0.6939 - y_start_categorical_accuracy: 0.7190 - y_end_categorical_accuracy: 0.7463 - val_loss: 1.5824 - val_y_start_loss: 0.8182 - val_y_end_loss: 0.7642 - val_y_start_categorical_accuracy: 0.7060 - val_y_end_categorical_accuracy: 0.7256 - lr: 1.9635e-05
# Epoch 4/70
# 687/687 - 139s - loss: 1.2853 - y_start_loss: 0.6764 - y_end_loss: 0.6089 - y_start_categorical_accuracy: 0.7429 - y_end_categorical_accuracy: 0.7713 - val_loss: 1.5860 - val_y_start_loss: 0.8362 - val_y_end_loss: 0.7498 - val_y_start_categorical_accuracy: 0.7058 - val_y_end_categorical_accuracy: 0.7309 - lr: 1.0365e-05
# Epoch 5/70
# 687/687 - 139s - loss: 1.1641 - y_start_loss: 0.6177 - y_end_loss: 0.5464 - y_start_categorical_accuracy: 0.7635 - y_end_categorical_accuracy: 0.7928 - val_loss: 1.6491 - val_y_start_loss: 0.8612 - val_y_end_loss: 0.7879 - val_y_start_categorical_accuracy: 0.7089 - val_y_end_categorical_accuracy: 0.7291 - lr: 2.8647e-06
# Epoch 6/70
# 687/687 - 139s - loss: 1.2571 - y_start_loss: 0.6606 - y_end_loss: 0.5965 - y_start_categorical_accuracy: 0.7451 - y_end_categorical_accuracy: 0.7757 - val_loss: 1.7201 - val_y_start_loss: 0.9012 - val_y_end_loss: 0.8189 - val_y_start_categorical_accuracy: 0.6947 - val_y_end_categorical_accuracy: 0.7162 - lr: 3.0000e-05
# Epoch 7/70
# 687/687 - 139s - loss: 1.0896 - y_start_loss: 0.5789 - y_end_loss: 0.5108 - y_start_categorical_accuracy: 0.7759 - y_end_categorical_accuracy: 0.8044 - val_loss: 1.7669 - val_y_start_loss: 0.8998 - val_y_end_loss: 0.8671 - val_y_start_categorical_accuracy: 0.6958 - val_y_end_categorical_accuracy: 0.7193 - lr: 2.7135e-05
# Epoch 8/70
# 687/687 - 139s - loss: 0.8718 - y_start_loss: 0.4689 - y_end_loss: 0.4029 - y_start_categorical_accuracy: 0.8159 - y_end_categorical_accuracy: 0.8434 - val_loss: 2.0616 - val_y_start_loss: 1.0927 - val_y_end_loss: 0.9690 - val_y_start_categorical_accuracy: 0.6987 - val_y_end_categorical_accuracy: 0.7158 - lr: 1.9635e-05
# Epoch 9/70
# 687/687 - 139s - loss: 0.6820 - y_start_loss: 0.3740 - y_end_loss: 0.3080 - y_start_categorical_accuracy: 0.8514 - y_end_categorical_accuracy: 0.8808 - val_loss: 2.3500 - val_y_start_loss: 1.2067 - val_y_end_loss: 1.1434 - val_y_start_categorical_accuracy: 0.6852 - val_y_end_categorical_accuracy: 0.7094 - lr: 1.0365e-05
# Epoch 10/70
# 687/687 - 139s - loss: 0.5562 - y_start_loss: 0.3110 - y_end_loss: 0.2452 - y_start_categorical_accuracy: 0.8769 - y_end_categorical_accuracy: 0.9043 - val_loss: 2.5122 - val_y_start_loss: 1.2923 - val_y_end_loss: 1.2199 - val_y_start_categorical_accuracy: 0.6887 - val_y_end_categorical_accuracy: 0.7089 - lr: 2.8647e-06
# Epoch 11/70
# 687/687 - 139s - loss: 0.7052 - y_start_loss: 0.3879 - y_end_loss: 0.3173 - y_start_categorical_accuracy: 0.8482 - y_end_categorical_accuracy: 0.8762 - val_loss: 2.3921 - val_y_start_loss: 1.2341 - val_y_end_loss: 1.1580 - val_y_start_categorical_accuracy: 0.6991 - val_y_end_categorical_accuracy: 0.7038 - lr: 3.0000e-05
# Epoch 12/70
# 687/687 - 139s - loss: 0.5875 - y_start_loss: 0.3219 - y_end_loss: 0.2656 - y_start_categorical_accuracy: 0.8741 - y_end_categorical_accuracy: 0.8981 - val_loss: 2.7712 - val_y_start_loss: 1.4371 - val_y_end_loss: 1.3341 - val_y_start_categorical_accuracy: 0.6892 - val_y_end_categorical_accuracy: 0.7043 - lr: 2.7135e-05
# Epoch 13/70
# 687/687 - 139s - loss: 0.4364 - y_start_loss: 0.2437 - y_end_loss: 0.1927 - y_start_categorical_accuracy: 0.9047 - y_end_categorical_accuracy: 0.9272 - val_loss: 2.8462 - val_y_start_loss: 1.4711 - val_y_end_loss: 1.3751 - val_y_start_categorical_accuracy: 0.6796 - val_y_end_categorical_accuracy: 0.6991 - lr: 1.9635e-05
# Epoch 14/70
# 687/687 - 139s - loss: 0.3231 - y_start_loss: 0.1816 - y_end_loss: 0.1415 - y_start_categorical_accuracy: 0.9280 - y_end_categorical_accuracy: 0.9455 - val_loss: 3.2807 - val_y_start_loss: 1.6894 - val_y_end_loss: 1.5914 - val_y_start_categorical_accuracy: 0.6812 - val_y_end_categorical_accuracy: 0.7014 - lr: 1.0365e-05
# Epoch 15/70
# 687/687 - 139s - loss: 0.2442 - y_start_loss: 0.1361 - y_end_loss: 0.1081 - y_start_categorical_accuracy: 0.9479 - y_end_categorical_accuracy: 0.9593 - val_loss: 3.4297 - val_y_start_loss: 1.7809 - val_y_end_loss: 1.6487 - val_y_start_categorical_accuracy: 0.6829 - val_y_end_categorical_accuracy: 0.6991 - lr: 2.8647e-06
# Epoch 16/70
# 687/687 - 139s - loss: 0.3841 - y_start_loss: 0.2110 - y_end_loss: 0.1731 - y_start_categorical_accuracy: 0.9178 - y_end_categorical_accuracy: 0.9340 - val_loss: 3.0562 - val_y_start_loss: 1.6299 - val_y_end_loss: 1.4263 - val_y_start_categorical_accuracy: 0.6805 - val_y_end_categorical_accuracy: 0.6992 - lr: 3.0000e-05
# Epoch 17/70
# 687/687 - 139s - loss: 0.3306 - y_start_loss: 0.1828 - y_end_loss: 0.1478 - y_start_categorical_accuracy: 0.9300 - y_end_categorical_accuracy: 0.9436 - val_loss: 3.2243 - val_y_start_loss: 1.6098 - val_y_end_loss: 1.6145 - val_y_start_categorical_accuracy: 0.6812 - val_y_end_categorical_accuracy: 0.6985 - lr: 2.7135e-05
# Epoch 18/70
# 687/687 - 139s - loss: 0.2478 - y_start_loss: 0.1332 - y_end_loss: 0.1147 - y_start_categorical_accuracy: 0.9493 - y_end_categorical_accuracy: 0.9576 - val_loss: 3.5273 - val_y_start_loss: 1.8748 - val_y_end_loss: 1.6525 - val_y_start_categorical_accuracy: 0.6985 - val_y_end_categorical_accuracy: 0.6974 - lr: 1.9635e-05
# Epoch 19/70
# 687/687 - 139s - loss: 0.1719 - y_start_loss: 0.0940 - y_end_loss: 0.0779 - y_start_categorical_accuracy: 0.9662 - y_end_categorical_accuracy: 0.9716 - val_loss: 3.8576 - val_y_start_loss: 1.9745 - val_y_end_loss: 1.8831 - val_y_start_categorical_accuracy: 0.6865 - val_y_end_categorical_accuracy: 0.7065 - lr: 1.0365e-05
# Epoch 20/70
# 687/687 - 139s - loss: 0.1278 - y_start_loss: 0.0706 - y_end_loss: 0.0573 - y_start_categorical_accuracy: 0.9754 - y_end_categorical_accuracy: 0.9792 - val_loss: 4.0577 - val_y_start_loss: 2.0652 - val_y_end_loss: 1.9925 - val_y_start_categorical_accuracy: 0.6892 - val_y_end_categorical_accuracy: 0.7054 - lr: 2.8647e-06
# Epoch 21/70
# 687/687 - 139s - loss: 0.2539 - y_start_loss: 0.1351 - y_end_loss: 0.1188 - y_start_categorical_accuracy: 0.9514 - y_end_categorical_accuracy: 0.9557 - val_loss: 3.5540 - val_y_start_loss: 1.8040 - val_y_end_loss: 1.7499 - val_y_start_categorical_accuracy: 0.6872 - val_y_end_categorical_accuracy: 0.7023 - lr: 3.0000e-05
# Epoch 22/70
# 687/687 - 139s - loss: 0.2188 - y_start_loss: 0.1196 - y_end_loss: 0.0992 - y_start_categorical_accuracy: 0.9586 - y_end_categorical_accuracy: 0.9638 - val_loss: 4.0703 - val_y_start_loss: 2.0457 - val_y_end_loss: 2.0246 - val_y_start_categorical_accuracy: 0.6841 - val_y_end_categorical_accuracy: 0.6952 - lr: 2.7135e-05
# Epoch 23/70
# 687/687 - 139s - loss: 0.1578 - y_start_loss: 0.0864 - y_end_loss: 0.0714 - y_start_categorical_accuracy: 0.9685 - y_end_categorical_accuracy: 0.9748 - val_loss: 4.1934 - val_y_start_loss: 2.1775 - val_y_end_loss: 2.0159 - val_y_start_categorical_accuracy: 0.6889 - val_y_end_categorical_accuracy: 0.6989 - lr: 1.9635e-05
# Epoch 24/70
# 687/687 - 139s - loss: 0.1086 - y_start_loss: 0.0594 - y_end_loss: 0.0492 - y_start_categorical_accuracy: 0.9785 - y_end_categorical_accuracy: 0.9828 - val_loss: 4.2295 - val_y_start_loss: 2.1835 - val_y_end_loss: 2.0460 - val_y_start_categorical_accuracy: 0.6832 - val_y_end_categorical_accuracy: 0.6992 - lr: 1.0365e-05
# Epoch 25/70
# 687/687 - 139s - loss: 0.0770 - y_start_loss: 0.0411 - y_end_loss: 0.0359 - y_start_categorical_accuracy: 0.9856 - y_end_categorical_accuracy: 0.9872 - val_loss: 4.4487 - val_y_start_loss: 2.2717 - val_y_end_loss: 2.1770 - val_y_start_categorical_accuracy: 0.6867 - val_y_end_categorical_accuracy: 0.7009 - lr: 2.8647e-06
# Epoch 26/70
# 687/687 - 139s - loss: 0.1730 - y_start_loss: 0.0927 - y_end_loss: 0.0803 - y_start_categorical_accuracy: 0.9674 - y_end_categorical_accuracy: 0.9725 - val_loss: 3.9985 - val_y_start_loss: 2.0807 - val_y_end_loss: 1.9178 - val_y_start_categorical_accuracy: 0.6770 - val_y_end_categorical_accuracy: 0.6941 - lr: 3.0000e-05
# Epoch 27/70
# 687/687 - 139s - loss: 0.1691 - y_start_loss: 0.0910 - y_end_loss: 0.0781 - y_start_categorical_accuracy: 0.9683 - y_end_categorical_accuracy: 0.9726 - val_loss: 4.0375 - val_y_start_loss: 2.1453 - val_y_end_loss: 1.8922 - val_y_start_categorical_accuracy: 0.6810 - val_y_end_categorical_accuracy: 0.6901 - lr: 2.7135e-05
# Epoch 28/70
# 687/687 - 139s - loss: 0.1130 - y_start_loss: 0.0607 - y_end_loss: 0.0523 - y_start_categorical_accuracy: 0.9791 - y_end_categorical_accuracy: 0.9824 - val_loss: 4.3458 - val_y_start_loss: 2.2263 - val_y_end_loss: 2.1195 - val_y_start_categorical_accuracy: 0.6834 - val_y_end_categorical_accuracy: 0.6961 - lr: 1.9635e-05
# Epoch 29/70
# 687/687 - 139s - loss: 0.0754 - y_start_loss: 0.0387 - y_end_loss: 0.0367 - y_start_categorical_accuracy: 0.9861 - y_end_categorical_accuracy: 0.9865 - val_loss: 4.6968 - val_y_start_loss: 2.4424 - val_y_end_loss: 2.2544 - val_y_start_categorical_accuracy: 0.6907 - val_y_end_categorical_accuracy: 0.6949 - lr: 1.0365e-05
# Epoch 30/70
# 687/687 - 139s - loss: 0.0603 - y_start_loss: 0.0307 - y_end_loss: 0.0296 - y_start_categorical_accuracy: 0.9892 - y_end_categorical_accuracy: 0.9892 - val_loss: 4.7500 - val_y_start_loss: 2.4807 - val_y_end_loss: 2.2693 - val_y_start_categorical_accuracy: 0.6867 - val_y_end_categorical_accuracy: 0.7018 - lr: 2.8647e-06
# Epoch 31/70
# 687/687 - 139s - loss: 0.1398 - y_start_loss: 0.0746 - y_end_loss: 0.0651 - y_start_categorical_accuracy: 0.9743 - y_end_categorical_accuracy: 0.9759 - val_loss: 4.0047 - val_y_start_loss: 2.0358 - val_y_end_loss: 1.9690 - val_y_start_categorical_accuracy: 0.6818 - val_y_end_categorical_accuracy: 0.6949 - lr: 3.0000e-05
# Epoch 32/70
# 687/687 - 139s - loss: 0.1397 - y_start_loss: 0.0712 - y_end_loss: 0.0685 - y_start_categorical_accuracy: 0.9749 - y_end_categorical_accuracy: 0.9767 - val_loss: 4.3953 - val_y_start_loss: 2.3107 - val_y_end_loss: 2.0846 - val_y_start_categorical_accuracy: 0.6801 - val_y_end_categorical_accuracy: 0.6932 - lr: 2.7135e-05
# Epoch 33/70
# 687/687 - 139s - loss: 0.0850 - y_start_loss: 0.0423 - y_end_loss: 0.0428 - y_start_categorical_accuracy: 0.9860 - y_end_categorical_accuracy: 0.9847 - val_loss: 4.6655 - val_y_start_loss: 2.4621 - val_y_end_loss: 2.2034 - val_y_start_categorical_accuracy: 0.6834 - val_y_end_categorical_accuracy: 0.7067 - lr: 1.9635e-05
# Epoch 34/70
# 687/687 - 139s - loss: 0.0574 - y_start_loss: 0.0289 - y_end_loss: 0.0284 - y_start_categorical_accuracy: 0.9902 - y_end_categorical_accuracy: 0.9892 - val_loss: 4.7844 - val_y_start_loss: 2.5145 - val_y_end_loss: 2.2698 - val_y_start_categorical_accuracy: 0.6776 - val_y_end_categorical_accuracy: 0.6969 - lr: 1.0365e-05
# Epoch 35/70
# 687/687 - 139s - loss: 0.0461 - y_start_loss: 0.0230 - y_end_loss: 0.0231 - y_start_categorical_accuracy: 0.9927 - y_end_categorical_accuracy: 0.9921 - val_loss: 4.9433 - val_y_start_loss: 2.5762 - val_y_end_loss: 2.3671 - val_y_start_categorical_accuracy: 0.6801 - val_y_end_categorical_accuracy: 0.6989 - lr: 2.8647e-06
# Epoch 36/70
# 687/687 - 140s - loss: 0.1170 - y_start_loss: 0.0622 - y_end_loss: 0.0548 - y_start_categorical_accuracy: 0.9776 - y_end_categorical_accuracy: 0.9815 - val_loss: 4.3320 - val_y_start_loss: 2.2846 - val_y_end_loss: 2.0474 - val_y_start_categorical_accuracy: 0.6796 - val_y_end_categorical_accuracy: 0.6934 - lr: 3.0000e-05
# Epoch 37/70
# 687/687 - 139s - loss: 0.1038 - y_start_loss: 0.0547 - y_end_loss: 0.0491 - y_start_categorical_accuracy: 0.9813 - y_end_categorical_accuracy: 0.9827 - val_loss: 4.5304 - val_y_start_loss: 2.3535 - val_y_end_loss: 2.1769 - val_y_start_categorical_accuracy: 0.6836 - val_y_end_categorical_accuracy: 0.7040 - lr: 2.7135e-05
# Epoch 38/70
# 687/687 - 139s - loss: 0.0739 - y_start_loss: 0.0372 - y_end_loss: 0.0367 - y_start_categorical_accuracy: 0.9865 - y_end_categorical_accuracy: 0.9876 - val_loss: 4.8474 - val_y_start_loss: 2.5307 - val_y_end_loss: 2.3167 - val_y_start_categorical_accuracy: 0.6841 - val_y_end_categorical_accuracy: 0.6923 - lr: 1.9635e-05
# Epoch 39/70
# 687/687 - 139s - loss: 0.0503 - y_start_loss: 0.0268 - y_end_loss: 0.0235 - y_start_categorical_accuracy: 0.9914 - y_end_categorical_accuracy: 0.9914 - val_loss: 5.0446 - val_y_start_loss: 2.5833 - val_y_end_loss: 2.4614 - val_y_start_categorical_accuracy: 0.6812 - val_y_end_categorical_accuracy: 0.6949 - lr: 1.0365e-05
# Epoch 40/70
# 687/687 - 139s - loss: 0.0379 - y_start_loss: 0.0189 - y_end_loss: 0.0189 - y_start_categorical_accuracy: 0.9932 - y_end_categorical_accuracy: 0.9930 - val_loss: 5.1794 - val_y_start_loss: 2.6480 - val_y_end_loss: 2.5314 - val_y_start_categorical_accuracy: 0.6845 - val_y_end_categorical_accuracy: 0.6985 - lr: 2.8647e-06
# Epoch 41/70
# 687/687 - 139s - loss: 0.1038 - y_start_loss: 0.0519 - y_end_loss: 0.0518 - y_start_categorical_accuracy: 0.9829 - y_end_categorical_accuracy: 0.9824 - val_loss: 4.4012 - val_y_start_loss: 2.3037 - val_y_end_loss: 2.0975 - val_y_start_categorical_accuracy: 0.6663 - val_y_end_categorical_accuracy: 0.6889 - lr: 3.0000e-05
# Epoch 42/70
# 687/687 - 139s - loss: 0.0998 - y_start_loss: 0.0481 - y_end_loss: 0.0516 - y_start_categorical_accuracy: 0.9838 - y_end_categorical_accuracy: 0.9821 - val_loss: 4.2131 - val_y_start_loss: 2.2671 - val_y_end_loss: 1.9461 - val_y_start_categorical_accuracy: 0.6770 - val_y_end_categorical_accuracy: 0.6963 - lr: 2.7135e-05
# Epoch 43/70
# 687/687 - 140s - loss: 0.0612 - y_start_loss: 0.0318 - y_end_loss: 0.0293 - y_start_categorical_accuracy: 0.9899 - y_end_categorical_accuracy: 0.9895 - val_loss: 4.7739 - val_y_start_loss: 2.4918 - val_y_end_loss: 2.2821 - val_y_start_categorical_accuracy: 0.6847 - val_y_end_categorical_accuracy: 0.7009 - lr: 1.9635e-05
# Epoch 44/70
# 687/687 - 140s - loss: 0.0378 - y_start_loss: 0.0193 - y_end_loss: 0.0185 - y_start_categorical_accuracy: 0.9934 - y_end_categorical_accuracy: 0.9943 - val_loss: 5.0946 - val_y_start_loss: 2.6793 - val_y_end_loss: 2.4153 - val_y_start_categorical_accuracy: 0.6814 - val_y_end_categorical_accuracy: 0.7040 - lr: 1.0365e-05
# Epoch 45/70
# 687/687 - 140s - loss: 0.0301 - y_start_loss: 0.0153 - y_end_loss: 0.0148 - y_start_categorical_accuracy: 0.9947 - y_end_categorical_accuracy: 0.9948 - val_loss: 5.1323 - val_y_start_loss: 2.7142 - val_y_end_loss: 2.4182 - val_y_start_categorical_accuracy: 0.6841 - val_y_end_categorical_accuracy: 0.7045 - lr: 2.8647e-06
# Epoch 46/70
# 687/687 - 140s - loss: 0.0845 - y_start_loss: 0.0392 - y_end_loss: 0.0453 - y_start_categorical_accuracy: 0.9866 - y_end_categorical_accuracy: 0.9845 - val_loss: 4.9939 - val_y_start_loss: 2.6298 - val_y_end_loss: 2.3640 - val_y_start_categorical_accuracy: 0.6889 - val_y_end_categorical_accuracy: 0.6996 - lr: 3.0000e-05
# Epoch 47/70
# 687/687 - 140s - loss: 0.0820 - y_start_loss: 0.0431 - y_end_loss: 0.0388 - y_start_categorical_accuracy: 0.9851 - y_end_categorical_accuracy: 0.9862 - val_loss: 4.6552 - val_y_start_loss: 2.4145 - val_y_end_loss: 2.2407 - val_y_start_categorical_accuracy: 0.6898 - val_y_end_categorical_accuracy: 0.7003 - lr: 2.7135e-05
# Epoch 48/70
# 687/687 - 140s - loss: 0.0586 - y_start_loss: 0.0296 - y_end_loss: 0.0290 - y_start_categorical_accuracy: 0.9898 - y_end_categorical_accuracy: 0.9901 - val_loss: 5.0764 - val_y_start_loss: 2.6031 - val_y_end_loss: 2.4733 - val_y_start_categorical_accuracy: 0.6845 - val_y_end_categorical_accuracy: 0.6945 - lr: 1.9635e-05
# Epoch 49/70
# 687/687 - 139s - loss: 0.0368 - y_start_loss: 0.0172 - y_end_loss: 0.0196 - y_start_categorical_accuracy: 0.9945 - y_end_categorical_accuracy: 0.9935 - val_loss: 5.3080 - val_y_start_loss: 2.8178 - val_y_end_loss: 2.4902 - val_y_start_categorical_accuracy: 0.6872 - val_y_end_categorical_accuracy: 0.7020 - lr: 1.0365e-05
# Epoch 50/70
# 687/687 - 140s - loss: 0.0240 - y_start_loss: 0.0115 - y_end_loss: 0.0125 - y_start_categorical_accuracy: 0.9959 - y_end_categorical_accuracy: 0.9955 - val_loss: 5.3478 - val_y_start_loss: 2.8452 - val_y_end_loss: 2.5027 - val_y_start_categorical_accuracy: 0.6885 - val_y_end_categorical_accuracy: 0.7007 - lr: 2.8647e-06
# Epoch 51/70
# 687/687 - 140s - loss: 0.0825 - y_start_loss: 0.0436 - y_end_loss: 0.0390 - y_start_categorical_accuracy: 0.9855 - y_end_categorical_accuracy: 0.9868 - val_loss: 4.7613 - val_y_start_loss: 2.4997 - val_y_end_loss: 2.2616 - val_y_start_categorical_accuracy: 0.6840 - val_y_end_categorical_accuracy: 0.7020 - lr: 3.0000e-05
# Epoch 52/70
# 687/687 - 140s - loss: 0.0762 - y_start_loss: 0.0375 - y_end_loss: 0.0387 - y_start_categorical_accuracy: 0.9878 - y_end_categorical_accuracy: 0.9872 - val_loss: 4.7125 - val_y_start_loss: 2.4474 - val_y_end_loss: 2.2651 - val_y_start_categorical_accuracy: 0.6852 - val_y_end_categorical_accuracy: 0.6965 - lr: 2.7135e-05
# Epoch 53/70
# 687/687 - 140s - loss: 0.0491 - y_start_loss: 0.0252 - y_end_loss: 0.0239 - y_start_categorical_accuracy: 0.9915 - y_end_categorical_accuracy: 0.9922 - val_loss: 5.0486 - val_y_start_loss: 2.6913 - val_y_end_loss: 2.3573 - val_y_start_categorical_accuracy: 0.6841 - val_y_end_categorical_accuracy: 0.6972 - lr: 1.9635e-05
# Epoch 54/70
# 687/687 - 140s - loss: 0.0310 - y_start_loss: 0.0164 - y_end_loss: 0.0145 - y_start_categorical_accuracy: 0.9944 - y_end_categorical_accuracy: 0.9952 - val_loss: 5.2697 - val_y_start_loss: 2.7467 - val_y_end_loss: 2.5230 - val_y_start_categorical_accuracy: 0.6901 - val_y_end_categorical_accuracy: 0.6961 - lr: 1.0365e-05
# Epoch 55/70
# 687/687 - 139s - loss: 0.0219 - y_start_loss: 0.0114 - y_end_loss: 0.0105 - y_start_categorical_accuracy: 0.9965 - y_end_categorical_accuracy: 0.9968 - val_loss: 5.3838 - val_y_start_loss: 2.7635 - val_y_end_loss: 2.6202 - val_y_start_categorical_accuracy: 0.6856 - val_y_end_categorical_accuracy: 0.6967 - lr: 2.8647e-06
# Epoch 56/70
# 687/687 - 139s - loss: 0.0746 - y_start_loss: 0.0400 - y_end_loss: 0.0346 - y_start_categorical_accuracy: 0.9859 - y_end_categorical_accuracy: 0.9882 - val_loss: 4.8087 - val_y_start_loss: 2.4572 - val_y_end_loss: 2.3515 - val_y_start_categorical_accuracy: 0.6847 - val_y_end_categorical_accuracy: 0.6930 - lr: 3.0000e-05
# Epoch 57/70
# 687/687 - 139s - loss: 0.0663 - y_start_loss: 0.0354 - y_end_loss: 0.0309 - y_start_categorical_accuracy: 0.9879 - y_end_categorical_accuracy: 0.9896 - val_loss: 4.8200 - val_y_start_loss: 2.4720 - val_y_end_loss: 2.3480 - val_y_start_categorical_accuracy: 0.6799 - val_y_end_categorical_accuracy: 0.6980 - lr: 2.7135e-05
# Epoch 58/70
# 687/687 - 139s - loss: 0.0415 - y_start_loss: 0.0217 - y_end_loss: 0.0198 - y_start_categorical_accuracy: 0.9928 - y_end_categorical_accuracy: 0.9934 - val_loss: 5.0810 - val_y_start_loss: 2.6465 - val_y_end_loss: 2.4345 - val_y_start_categorical_accuracy: 0.6789 - val_y_end_categorical_accuracy: 0.6967 - lr: 1.9635e-05
# Epoch 59/70
# 687/687 - 139s - loss: 0.0281 - y_start_loss: 0.0144 - y_end_loss: 0.0137 - y_start_categorical_accuracy: 0.9952 - y_end_categorical_accuracy: 0.9954 - val_loss: 5.3090 - val_y_start_loss: 2.7371 - val_y_end_loss: 2.5719 - val_y_start_categorical_accuracy: 0.6903 - val_y_end_categorical_accuracy: 0.7016 - lr: 1.0365e-05
# Epoch 60/70
# 687/687 - 139s - loss: 0.0206 - y_start_loss: 0.0100 - y_end_loss: 0.0107 - y_start_categorical_accuracy: 0.9966 - y_end_categorical_accuracy: 0.9963 - val_loss: 5.3170 - val_y_start_loss: 2.7395 - val_y_end_loss: 2.5776 - val_y_start_categorical_accuracy: 0.6874 - val_y_end_categorical_accuracy: 0.7025 - lr: 2.8647e-06
# Epoch 61/70
# 687/687 - 139s - loss: 0.0654 - y_start_loss: 0.0332 - y_end_loss: 0.0322 - y_start_categorical_accuracy: 0.9892 - y_end_categorical_accuracy: 0.9892 - val_loss: 4.6947 - val_y_start_loss: 2.4533 - val_y_end_loss: 2.2414 - val_y_start_categorical_accuracy: 0.6790 - val_y_end_categorical_accuracy: 0.6936 - lr: 3.0000e-05
# Epoch 62/70
# 687/687 - 139s - loss: 0.0590 - y_start_loss: 0.0297 - y_end_loss: 0.0293 - y_start_categorical_accuracy: 0.9904 - y_end_categorical_accuracy: 0.9902 - val_loss: 5.2056 - val_y_start_loss: 2.7038 - val_y_end_loss: 2.5018 - val_y_start_categorical_accuracy: 0.6834 - val_y_end_categorical_accuracy: 0.7049 - lr: 2.7135e-05
# Epoch 63/70
# 687/687 - 139s - loss: 0.0370 - y_start_loss: 0.0176 - y_end_loss: 0.0194 - y_start_categorical_accuracy: 0.9937 - y_end_categorical_accuracy: 0.9935 - val_loss: 5.4041 - val_y_start_loss: 2.8224 - val_y_end_loss: 2.5817 - val_y_start_categorical_accuracy: 0.6843 - val_y_end_categorical_accuracy: 0.7040 - lr: 1.9635e-05
# Epoch 64/70
# 687/687 - 139s - loss: 0.0256 - y_start_loss: 0.0131 - y_end_loss: 0.0125 - y_start_categorical_accuracy: 0.9955 - y_end_categorical_accuracy: 0.9960 - val_loss: 5.6175 - val_y_start_loss: 2.9247 - val_y_end_loss: 2.6929 - val_y_start_categorical_accuracy: 0.6838 - val_y_end_categorical_accuracy: 0.7036 - lr: 1.0365e-05
# Epoch 65/70
# 687/687 - 139s - loss: 0.0172 - y_start_loss: 0.0074 - y_end_loss: 0.0098 - y_start_categorical_accuracy: 0.9977 - y_end_categorical_accuracy: 0.9967 - val_loss: 5.6665 - val_y_start_loss: 2.9825 - val_y_end_loss: 2.6839 - val_y_start_categorical_accuracy: 0.6854 - val_y_end_categorical_accuracy: 0.7045 - lr: 2.8647e-06
# Epoch 66/70
# 687/687 - 139s - loss: 0.0584 - y_start_loss: 0.0279 - y_end_loss: 0.0305 - y_start_categorical_accuracy: 0.9908 - y_end_categorical_accuracy: 0.9900 - val_loss: 4.8743 - val_y_start_loss: 2.5767 - val_y_end_loss: 2.2976 - val_y_start_categorical_accuracy: 0.6759 - val_y_end_categorical_accuracy: 0.6938 - lr: 3.0000e-05
# Epoch 67/70
# 687/687 - 139s - loss: 0.0561 - y_start_loss: 0.0273 - y_end_loss: 0.0288 - y_start_categorical_accuracy: 0.9914 - y_end_categorical_accuracy: 0.9897 - val_loss: 5.2299 - val_y_start_loss: 2.7532 - val_y_end_loss: 2.4766 - val_y_start_categorical_accuracy: 0.6836 - val_y_end_categorical_accuracy: 0.6890 - lr: 2.7135e-05
# Epoch 68/70
# 687/687 - 139s - loss: 0.0363 - y_start_loss: 0.0175 - y_end_loss: 0.0188 - y_start_categorical_accuracy: 0.9939 - y_end_categorical_accuracy: 0.9938 - val_loss: 5.5299 - val_y_start_loss: 2.8841 - val_y_end_loss: 2.6458 - val_y_start_categorical_accuracy: 0.6903 - val_y_end_categorical_accuracy: 0.7045 - lr: 1.9635e-05
# Epoch 69/70
# 687/687 - 139s - loss: 0.0224 - y_start_loss: 0.0110 - y_end_loss: 0.0114 - y_start_categorical_accuracy: 0.9961 - y_end_categorical_accuracy: 0.9959 - val_loss: 5.6147 - val_y_start_loss: 2.9546 - val_y_end_loss: 2.6602 - val_y_start_categorical_accuracy: 0.6820 - val_y_end_categorical_accuracy: 0.7029 - lr: 1.0365e-05
# Epoch 70/70
# 687/687 - 139s - loss: 0.0155 - y_start_loss: 0.0076 - y_end_loss: 0.0079 - y_start_categorical_accuracy: 0.9976 - y_end_categorical_accuracy: 0.9975 - val_loss: 5.5982 - val_y_start_loss: 2.9450 - val_y_end_loss: 2.6532 - val_y_start_categorical_accuracy: 0.6814 - val_y_end_categorical_accuracy: 0.7041 - lr: 2.8647e-06

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col1 {
#             color:  orange;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col2 {
#             color:  orange;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row3_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row3_col1 {
#             color:  orange;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row3_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row6_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row6_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row7_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row7_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row7_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row7_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row7_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row8_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row8_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row8_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row8_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row8_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row9_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row9_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row9_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row9_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row9_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row10_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row10_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row10_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row10_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row10_col4 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row11_col0 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row11_col1 {
#             color:  black;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row11_col2 {
#             color:  red;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row11_col3 {
#             color:  green;
#         }    #T_59ec64e4_926f_11ea_94cc_0242ac1c0002row11_col4 {
#             color:  black;
#         }</style><table id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col0" class="data row0 col0" >0.950193</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col1" class="data row0 col1" >0.682601</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col2" class="data row0 col2" >0.267592</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col3" class="data row0 col3" >0.950193</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row0_col4" class="data row0 col4" >0.682601</td>
#             </tr>
#             <tr>
#                         <th id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002level0_row1" class="row_heading level0 row1" >Sentiment negative</th>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col0" class="data row1 col0" >0.924250</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col1" class="data row1 col1" >0.493398</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col2" class="data row1 col2" >0.430852</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col3" class="data row1 col3" >0.924250</td>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row1_col4" class="data row1 col4" >0.493398</td>
#             </tr>
#             <tr>
#                         <th id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002level0_row2" class="row_heading level0 row2" >Sentiment neutral</th>
#                         <td id="T_59ec64e4_926f_11ea_94cc_0242ac1c0002row2_col0" class="data row2 col0" >0.991970</td>
#                         <td id="T_59ec64e4_926f_1

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_1
# 0                 i`d have responded, if i were going  ...            1.0
# 1       sooo sad i will miss you here in san diego!!!  ...            0.5
# 2                           my boss is bullying me...  ...            1.0
# 3                      what interview! leave me alone  ...            1.0
# 4   sons of ****, why couldn`t they put them on th...  ...            1.0
# 5   http://www.dothebouncy.com/smf - some shameles...  ...            1.0
# 6   2am feedings for the baby are fun when he is a...  ...            1.0
# 7                                          soooo high  ...            1.0
# 8                                         both of you  ...            1.0
# 9   journey!? wow... u just became cooler.  hehe.....  ...            1.0
# 10  as much as i love to be hopeful, i reckon the ...  ...            1.0
# 11  i really really like the song love story by ta...  ...            1.0
# 12       my sharpie is running dangerously low on ink  ...            1.0
# 13  i want to go to music tonight but i lost my vo...  ...            1.0
# 14                         test test from the lg env2  ...            1.0
#
# [15 rows x 5 columns]
