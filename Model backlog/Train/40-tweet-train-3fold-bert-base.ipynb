# %% [markdown]
# ## Dependencies

# %%
import json
from tweet_utility_scripts import *
from transformers import TFBertModel, BertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-bert-uncased-160/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        36                 35
# 1                             sooo sad  negative        46                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        31                 14
# 4                        sons of ****,  negative        75                 13
#
#        fold_1      fold_2      fold_3      fold_4 fold_5
# 0       train       train       train  validation  train
# 1  validation       train       train       train  train
# 2       train  validation       train       train  train
# 3       train  validation       train       train  train
# 4       train       train  validation       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_valid.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_valid.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_valid.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy

# %% [markdown]
# # Model parameters

# %%
tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/bert/'

config = {
  "MAX_LEN": 160,
  "BATCH_SIZE": 16,
  "EPOCHS": 5,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 3,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'bert-base-uncased-tf_model.h5',
  "config_path": base_path + 'bert-base-uncased-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = BertConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFBertModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='softmax', name='y_start')(x)     
    y_end = Dense(MAX_LEN, activation='softmax', name='y_end')(x)        
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)
tokenizer.save('./')
# Out:
# ['./vocab.txt']

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    model = model_fn(config['MAX_LEN'])
    tb_callback = TensorBoard(log_dir='./')
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'start_fold_%d' % (n_fold+1)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'end_fold_%d' % (n_fold+1)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'start_fold_%d' % (n_fold+1)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'end_fold_%d' % (n_fold+1)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold+1)] = k_fold['end_fold_%d' % (n_fold+1)].astype(int)
    k_fold['start_fold_%d' % (n_fold+1)] = k_fold['start_fold_%d' % (n_fold+1)].astype(int)
    k_fold['end_fold_%d' % (n_fold+1)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold+1)].clip(0, k_fold['end_fold_%d' % (n_fold+1)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold+1)], x['end_fold_%d' % (n_fold+1)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold+1)].fillna('', inplace=True)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 516s - loss: 3.8088 - y_start_loss: 1.5924 - y_end_loss: 2.2164 - y_start_categorical_accuracy: 0.5749 - y_end_categorical_accuracy: 0.3696 - val_loss: 2.7966 - val_y_start_loss: 1.3289 - val_y_end_loss: 1.4687 - val_y_start_categorical_accuracy: 0.5904 - val_y_end_categorical_accuracy: 0.5855
# Epoch 2/5
# 21984/21984 - 499s - loss: 2.5547 - y_start_loss: 1.2231 - y_end_loss: 1.3316 - y_start_categorical_accuracy: 0.6159 - y_end_categorical_accuracy: 0.6133 - val_loss: 2.5198 - val_y_start_loss: 1.2148 - val_y_end_loss: 1.3056 - val_y_start_categorical_accuracy: 0.6234 - val_y_end_categorical_accuracy: 0.6146
# Epoch 3/5
# 21984/21984 - 498s - loss: 2.1321 - y_start_loss: 1.0351 - y_end_loss: 1.0970 - y_start_categorical_accuracy: 0.6593 - y_end_categorical_accuracy: 0.6676 - val_loss: 2.4687 - val_y_start_loss: 1.2011 - val_y_end_loss: 1.2668 - val_y_start_categorical_accuracy: 0.6332 - val_y_end_categorical_accuracy: 0.6405
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 497s - loss: 1.7341 - y_start_loss: 0.8487 - y_end_loss: 0.8854 - y_start_categorical_accuracy: 0.7082 - y_end_categorical_accuracy: 0.7207 - val_loss: 2.5481 - val_y_start_loss: 1.2245 - val_y_end_loss: 1.3224 - val_y_start_categorical_accuracy: 0.6426 - val_y_end_categorical_accuracy: 0.6461
# Epoch 00004: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 515s - loss: 3.7127 - y_start_loss: 1.5353 - y_end_loss: 2.1774 - y_start_categorical_accuracy: 0.5832 - y_end_categorical_accuracy: 0.3681 - val_loss: 2.9192 - val_y_start_loss: 1.3788 - val_y_end_loss: 1.5384 - val_y_start_categorical_accuracy: 0.5846 - val_y_end_categorical_accuracy: 0.5562
# Epoch 2/5
# 21984/21984 - 499s - loss: 2.4538 - y_start_loss: 1.1781 - y_end_loss: 1.2758 - y_start_categorical_accuracy: 0.6307 - y_end_categorical_accuracy: 0.6253 - val_loss: 2.5642 - val_y_start_loss: 1.2326 - val_y_end_loss: 1.3297 - val_y_start_categorical_accuracy: 0.6143 - val_y_end_categorical_accuracy: 0.6164
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 499s - loss: 2.0071 - y_start_loss: 0.9807 - y_end_loss: 1.0264 - y_start_categorical_accuracy: 0.6770 - y_end_categorical_accuracy: 0.6847 - val_loss: 2.5911 - val_y_start_loss: 1.2691 - val_y_end_loss: 1.3213 - val_y_start_categorical_accuracy: 0.6168 - val_y_end_categorical_accuracy: 0.6275
# Epoch 00003: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 515s - loss: 3.6514 - y_start_loss: 1.5472 - y_end_loss: 2.1042 - y_start_categorical_accuracy: 0.5838 - y_end_categorical_accuracy: 0.4124 - val_loss: 2.7783 - val_y_start_loss: 1.2951 - val_y_end_loss: 1.4838 - val_y_start_categorical_accuracy: 0.6017 - val_y_end_categorical_accuracy: 0.5668
# Epoch 2/5
# 21984/21984 - 499s - loss: 2.4716 - y_start_loss: 1.1915 - y_end_loss: 1.2801 - y_start_categorical_accuracy: 0.6226 - y_end_categorical_accuracy: 0.6252 - val_loss: 2.5087 - val_y_start_loss: 1.1971 - val_y_end_loss: 1.3119 - val_y_start_categorical_accuracy: 0.6306 - val_y_end_categorical_accuracy: 0.6281
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 498s - loss: 2.0601 - y_start_loss: 1.0083 - y_end_loss: 1.0518 - y_start_categorical_accuracy: 0.6645 - y_end_categorical_accuracy: 0.6756 - val_loss: 2.5193 - val_y_start_loss: 1.2183 - val_y_end_loss: 1.3022 - val_y_start_categorical_accuracy: 0.6301 - val_y_end_categorical_accuracy: 0.6474
# Epoch 00003: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-13_21-38-22/
# train/plugins/profile/2020-04-13_21-38-22/local.trace
# train/plugins/profile/2020-04-13_21-10-03/
# train/plugins/profile/2020-04-13_21-10-03/local.trace
# train/plugins/profile/2020-04-13_20-33-29/
# train/plugins/profile/2020-04-13_20-33-29/local.trace
# train/events.out.tfevents.1586812189.1d159df478b6.13.115032.v2
# train/events.out.tfevents.1586813887.1d159df478b6.13.203127.v2
# train/events.out.tfevents.1586810009.1d159df478b6.profile-empty
# train/events.out.tfevents.1586809995.1d159df478b6.13.10628.v2
# validation/
# validation/events.out.tfevents.1586812705.1d159df478b6.13.152188.v2
# validation/events.out.tfevents.1586810511.1d159df478b6.13.47784.v2
# validation/events.out.tfevents.1586814403.1d159df478b6.13.240283.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 
                                       'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col1 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col4 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col6 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col7 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row0_col8 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col0 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col1 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col3 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col4 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col5 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col6 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col7 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row1_col8 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col1 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col4 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col5 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col6 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col7 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row2_col8 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col1 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col4 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col5 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col6 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col7 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row3_col8 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col0 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col1 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col3 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col4 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col6 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col7 {
#             color:  green;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row4_col8 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col1 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col4 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col6 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col7 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row5_col8 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col1 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col4 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col6 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col7 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row6_col8 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col1 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col4 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col6 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col7 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row7_col8 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col1 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col4 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col6 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col7 {
#             color:  orange;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row8_col8 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col0 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col1 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col2 {
#             color:  red;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col3 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col4 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col5 {
#             color:  black;
#         }    #T_07ee55e0_7dd3_11ea_9b69_c5389ab0aa23row9_col6 {
#             co

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold.head(15))
# Out:
#         textID                                               text  \
# 0   cb774db0d1                i`d have responded, if i were going
# 1   549e992a42      sooo sad i will miss you here in san diego!!!
# 2   088c60f138                          my boss is bullying me...
# 3   9642c003ef                     what interview! leave me alone
# 4   358bd9e861   sons of ****, why couldn`t they put them on t...
# 5   28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 6   6e0c6d75b1  2am feedings for the baby are fun when he is a...
# 7   50e14c0bb8                                         soooo high
# 8   e050245fbd                                        both of you
# 9   fc2cbefa9d   journey!? wow... u just became cooler.  hehe....
# 10  2339a9b08b   as much as i love to be hopeful, i reckon the...
# 11  16fab9f95b  i really really like the song love story by ta...
# 12  74a76f6e0a       my sharpie is running dangerously low on ink
# 13  04dd1d2e34  i want to go to music tonight but i lost my vo...
# 14  bbe3cbf620                         test test from the lg env2
#
#                                         selected_text sentiment  text_len  \
# 0                 i`d have responded, if i were going   neutral        36
# 1                                            sooo sad  negative        46
# 2                                         bullying me  negative        25
# 3                                      leave me alone  negative        31
# 4                                       sons of ****,  negative        75
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral        92
# 6                                                 fun  positive        64
# 7                                          soooo high   neutral        10
# 8                                         both of you   neutral        12
# 9                        wow... u just became cooler.  positive        69
# 10  as much as i love to be hopeful, i reckon the ...   neutral       107
# 11                                               like  positive        56
# 12                                        dangerously  negative        44
# 13                                               lost  negative        50
# 14                         test test from the lg env2   neutral        26
#
#     selected_text_len      fold_1      fold_2      fold_3      fold_4  \
# 0                  35       train       train       train  validation
# 1                   8  validation       train       train       train
# 2                  11       train  validation       train       train
# 3                  14       train  validation       train       train
# 4                  13       train       train  validation       train
# 5                  92       train       train       train  validation
# 6                   3       train       train       train       train
# 7                  10       train       train       train       train
# 8                  11       train  validation       train       train
# 9                  28       train  validation       train       train
# 10                106       train  validation       train       train
# 11                  4       train       train       train  validation
# 12                 11       train       train       train  validation
# 13                  4       train       train       train  validation
# 14                 26       train       train  validation       train
#
#         fold_5  start_fold_1  end_fold_1  \
# 0        train             4          13
# 1        train             6           6
# 2        train             7           8
# 3        train             7           9
# 4        train             4          10
# 5        train             4          32
# 6   validation            11          12
# 7   validation             4           6
# 8        train             4           6
# 9        train             7          15
# 10       train             4          30
# 11       train             7           7
# 12       train             9           9
# 13       train            12          16
# 14       train             4          12
#
#                                     prediction_fold_1  start_fold_2  \
# 0                 i`d have responded, if i were going             4
# 1                                                 sad             6
# 2                                         bullying me             7
# 3                                      leave me alone             8
# 4                                       sons of ****,             4
# 5   http://www.dothebouncy.com/smf - some shameles...             4
# 6                                             are fun            11
# 7                                          soooo high             4
# 8                                         both of you             4
# 9                        wow... u just became cooler.             8
# 10  as much as i love to be hopeful, i reckon the ...             4
# 11                                               like             7
# 12                                        dangerously             8
# 13                                   i lost my voice.            11
# 14                         test test from the lg env2             4
#
#     end_fold_2                                  prediction_fold_2  \
# 0           13                i`d have responded, if i were going
# 1            6                                                sad
# 2            8                                        bullying me
# 3            9                                           me alone
# 4           11                                  sons of ****, why
# 5           32  http://www.dothebouncy.com/smf - some shameles...
# 6           13                                       are fun when
# 7            6                                         soooo high
# 8            6                                        both of you
# 9            8                                                  .
# 10          30  as much as i love to be hopeful, i reckon the ...
# 11           7                                               like
# 12           9                                running dangerously
# 13          16                               but i lost my voice.
# 14          12                         test test from the lg env2
#
#     start_fold_3  end_fold_3  \
# 0              4          13
# 1              4           6
# 2              7          11
# 3              7           9
# 4              4          10
# 5              4          32
# 6             12          13
# 7              4           6
# 8              4           6
# 9              7          27
# 10             4          30
# 11             4          10
# 12            10          10
# 13            13          14
# 14             4          12
#
#                                     prediction_fold_3
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                            fun when
# 7                                          soooo high
# 8                                         both of you
# 9   wow... u just became cooler.  hehe... (is that...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                 i really really like the song love
# 12                                                low
# 13                                            lost my
# 14                         test test from the lg env2
