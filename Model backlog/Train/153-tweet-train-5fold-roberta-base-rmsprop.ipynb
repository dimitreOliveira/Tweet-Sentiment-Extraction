# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
# fold_1/
# fold_1/y_valid.npy
# fold_1/x_valid_aux.npy
# fold_1/y_train_mask.npy
# fold_1/x_train_aux.npy
# fold_1/x_valid.npy
# fold_1/x_valid_aux2.npy
# fold_1/y_valid_aux.npy
# fold_1/y_train.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_mask.npy
# fold_1/x_train.npy
# fold_1/x_train_aux2.npy
# fold_2/
# fold_2/y_valid.npy
# fold_2/x_valid_aux.npy
# fold_2/y_train_mask.npy
# fold_2/x_train_aux.npy
# fold_2/x_valid.npy
# fold_2/x_valid_aux2.npy
# fold_2/y_valid_aux.npy
# fold_2/y_train.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_mask.npy
# fold_2/x_train.npy
# fold_2/x_train_aux2.npy
# fold_3/
# fold_3/y_valid.npy
# fold_3/x_valid_aux.npy
# fold_3/y_train_mask.npy
# fold_3/x_train_aux.npy
# fold_3/x_valid.npy
# fold_3/x_valid_aux2.npy
# fold_3/y_valid_aux.npy
# fold_3/y_train.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_mask.npy
# fold_3/x_train.npy
# fold_3/x_train_aux2.npy
# fold_4/
# fold_4/y_valid.npy
# fold_4/x_valid_aux.npy
# fold_4/y_train_mask.npy
# fold_4/x_train_aux.npy
# fold_4/x_valid.npy
# fold_4/x_valid_aux2.npy
# fold_4/y_valid_aux.npy
# fold_4/y_train.npy
# fold_4/y_train_aux.npy
# fold_4/y_valid_mask.npy
# fold_4/x_train.npy
# fold_4/x_train_aux2.npy
# fold_5/
# fold_5/y_valid.npy
# fold_5/x_valid_aux.npy
# fold_5/y_train_mask.npy
# fold_5/x_train_aux.npy
# fold_5/x_valid.npy
# fold_5/x_valid_aux2.npy
# fold_5/y_valid_aux.npy
# fold_5/y_train.npy
# fold_5/y_train_aux.npy
# fold_5/y_valid_mask.npy
# fold_5/x_train.npy
# fold_5/x_train_aux2.npy

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
step_size = len(k_fold[k_fold['fold_1'] == 'train']) // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.98e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn_end(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.RMSprop(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                          warmup_steps=1, lr_start=lr_max, 
                                                                                          lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy

    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end, }
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    history_list.append(history)
    model.load_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 287.6s loss: 4.3734 loss_start: 2.1743 loss_end: 2.1991 val_loss: 1.9895 val_loss_start: 1.0242 val_loss_end: 0.9653
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/4
# time: 269.4s loss: 4.0130 loss_start: 2.0141 loss_end: 1.9989 val_loss: 1.8793 val_loss_start: 0.9769 val_loss_end: 0.9024
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/4
# time: 269.2s loss: 3.9020 loss_start: 1.9641 loss_end: 1.9379 val_loss: 1.8684 val_loss_start: 0.9547 val_loss_end: 0.9137
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 4/4
# time: 269.2s loss: 3.8508 loss_start: 1.9425 loss_end: 1.9083 val_loss: 1.8870 val_loss_start: 0.9667 val_loss_end: 0.9203
# Training finished saved model weights at "last_model_fold_1.h5"
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 286.4s loss: 4.3825 loss_start: 2.1756 loss_end: 2.2069 val_loss: 2.0656 val_loss_start: 1.0546 val_loss_end: 1.0110
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/4
# time: 269.5s loss: 3.9820 loss_start: 2.0088 loss_end: 1.9732 val_loss: 1.9144 val_loss_start: 0.9887 val_loss_end: 0.9257
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 3/4
# time: 269.8s loss: 3.8869 loss_start: 1.9628 loss_end: 1.9241 val_loss: 1.9612 val_loss_start: 1.0198 val_loss_end: 0.9414
#
# EPOCH 4/4
# time: 268.3s loss: 3.8345 loss_start: 1.9368 loss_end: 1.8977 val_loss: 1.9578 val_loss_start: 0.9967 val_loss_end: 0.9612
# Training finished saved model weights at "last_model_fold_2.h5"
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 286.7s loss: 4.4871 loss_start: 2.2328 loss_end: 2.2543 val_loss: 2.0399 val_loss_start: 0.9857 val_loss_end: 1.0541
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/4
# time: 269.2s loss: 4.0537 loss_start: 2.0382 loss_end: 2.0156 val_loss: 1.9127 val_loss_start: 0.9675 val_loss_end: 0.9453
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/4
# time: 269.6s loss: 3.9297 loss_start: 1.9831 loss_end: 1.9466 val_loss: 1.8890 val_loss_start: 0.9632 val_loss_end: 0.9258
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 4/4
# time: 269.5s loss: 3.8774 loss_start: 1.9583 loss_end: 1.9191 val_loss: 1.8945 val_loss_start: 0.9686 val_loss_end: 0.9259
# Training finished saved model weights at "last_model_fold_3.h5"
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 287.3s loss: 4.3719 loss_start: 2.1888 loss_end: 2.1831 val_loss: 1.9354 val_loss_start: 1.0078 val_loss_end: 0.9277
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/4
# time: 269.5s loss: 3.9885 loss_start: 2.0117 loss_end: 1.9768 val_loss: 1.8549 val_loss_start: 0.9686 val_loss_end: 0.8862
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 3/4
# time: 269.6s loss: 3.8937 loss_start: 1.9670 loss_end: 1.9266 val_loss: 1.8492 val_loss_start: 0.9740 val_loss_end: 0.8753
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 4/4
# time: 269.6s loss: 3.8435 loss_start: 1.9400 loss_end: 1.9035 val_loss: 1.8523 val_loss_start: 0.9849 val_loss_end: 0.8674
# Training finished saved model weights at "last_model_fold_4.h5"
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 286.9s loss: 4.3933 loss_start: 2.1956 loss_end: 2.1977 val_loss: 1.9998 val_loss_start: 1.0071 val_loss_end: 0.9927
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/4
# time: 269.6s loss: 3.9996 loss_start: 2.0097 loss_end: 1.9898 val_loss: 1.9164 val_loss_start: 0.9739 val_loss_end: 0.9425
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 3/4
# time: 269.8s loss: 3.9037 loss_start: 1.9611 loss_end: 1.9426 val_loss: 1.9309 val_loss_start: 0.9851 val_loss_end: 0.9458
#
# EPOCH 4/4
# time: 268.6s loss: 3.8464 loss_start: 1.9385 loss_end: 1.9079 val_loss: 1.9123 val_loss_start: 0.9778 val_loss_end: 0.9346
# Training finished saved model weights at "last_model_fold_5.h5"

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_20d59b4c_9730_11ea_a212_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
