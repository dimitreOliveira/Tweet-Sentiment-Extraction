# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/y_train.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/y_train.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/y_train.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 3,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Conv1D(1, 1)(last_state)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Dense(MAX_LEN, activation='softmax', name='y_start')(x_start)   

    x_end = layers.Conv1D(1, 1)(last_state)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Dense(MAX_LEN, activation='softmax', name='y_end')(x_end) 
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True, verbose=1)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'start_fold_%d' % (n_fold+1)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'end_fold_%d' % (n_fold+1)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'start_fold_%d' % (n_fold+1)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'end_fold_%d' % (n_fold+1)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold+1)] = k_fold['end_fold_%d' % (n_fold+1)].astype(int)
    k_fold['start_fold_%d' % (n_fold+1)] = k_fold['start_fold_%d' % (n_fold+1)].astype(int)
    k_fold['end_fold_%d' % (n_fold+1)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold+1)].clip(0, k_fold['end_fold_%d' % (n_fold+1)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold+1)], x['end_fold_%d' % (n_fold+1)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold+1)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold+1)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/3
#
# Epoch 00001: val_loss improved from inf to 3.73141, saving model to model_fold_1.h5
# 21984/21984 - 291s - loss: 5.8473 - y_start_loss: 2.2638 - y_end_loss: 3.5836 - y_start_categorical_accuracy: 0.5276 - y_end_categorical_accuracy: 0.1618 - val_loss: 3.7314 - val_y_start_loss: 1.6331 - val_y_end_loss: 2.0976 - val_y_start_categorical_accuracy: 0.5717 - val_y_end_categorical_accuracy: 0.4531
# Epoch 2/3
#
# Epoch 00002: val_loss improved from 3.73141 to 2.74215, saving model to model_fold_1.h5
# 21984/21984 - 274s - loss: 3.3894 - y_start_loss: 1.5340 - y_end_loss: 1.8554 - y_start_categorical_accuracy: 0.5849 - y_end_categorical_accuracy: 0.4973 - val_loss: 2.7422 - val_y_start_loss: 1.3152 - val_y_end_loss: 1.4266 - val_y_start_categorical_accuracy: 0.6126 - val_y_end_categorical_accuracy: 0.6266
# Epoch 3/3
#
# Epoch 00003: val_loss improved from 2.74215 to 2.54182, saving model to model_fold_1.h5
# 21984/21984 - 274s - loss: 2.6842 - y_start_loss: 1.2999 - y_end_loss: 1.3844 - y_start_categorical_accuracy: 0.6217 - y_end_categorical_accuracy: 0.6234 - val_loss: 2.5418 - val_y_start_loss: 1.2490 - val_y_end_loss: 1.2921 - val_y_start_categorical_accuracy: 0.6368 - val_y_end_categorical_accuracy: 0.6672
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/3
#
# Epoch 00001: val_loss improved from inf to 4.64557, saving model to model_fold_2.h5
# 21984/21984 - 289s - loss: 6.0722 - y_start_loss: 2.3143 - y_end_loss: 3.7578 - y_start_categorical_accuracy: 0.5254 - y_end_categorical_accuracy: 0.1028 - val_loss: 4.6456 - val_y_start_loss: 1.8642 - val_y_end_loss: 2.7819 - val_y_start_categorical_accuracy: 0.5693 - val_y_end_categorical_accuracy: 0.2707
# Epoch 2/3
#
# Epoch 00002: val_loss improved from 4.64557 to 3.03551, saving model to model_fold_2.h5
# 21984/21984 - 274s - loss: 3.7418 - y_start_loss: 1.5924 - y_end_loss: 2.1494 - y_start_categorical_accuracy: 0.5805 - y_end_categorical_accuracy: 0.4216 - val_loss: 3.0355 - val_y_start_loss: 1.4136 - val_y_end_loss: 1.6213 - val_y_start_categorical_accuracy: 0.5992 - val_y_end_categorical_accuracy: 0.5737
# Epoch 3/3
#
# Epoch 00003: val_loss improved from 3.03551 to 2.70688, saving model to model_fold_2.h5
# 21984/21984 - 274s - loss: 2.8309 - y_start_loss: 1.3321 - y_end_loss: 1.4988 - y_start_categorical_accuracy: 0.6096 - y_end_categorical_accuracy: 0.5923 - val_loss: 2.7069 - val_y_start_loss: 1.3028 - val_y_end_loss: 1.4034 - val_y_start_categorical_accuracy: 0.6245 - val_y_end_categorical_accuracy: 0.6381
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/3
#
# Epoch 00001: val_loss improved from inf to 4.36692, saving model to model_fold_3.h5
# 21984/21984 - 288s - loss: 6.0047 - y_start_loss: 2.2655 - y_end_loss: 3.7392 - y_start_categorical_accuracy: 0.5363 - y_end_categorical_accuracy: 0.1179 - val_loss: 4.3669 - val_y_start_loss: 1.7756 - val_y_end_loss: 2.5920 - val_y_start_categorical_accuracy: 0.5660 - val_y_end_categorical_accuracy: 0.2828
# Epoch 2/3
#
# Epoch 00002: val_loss improved from 4.36692 to 3.18747, saving model to model_fold_3.h5
# 21984/21984 - 274s - loss: 3.6832 - y_start_loss: 1.6353 - y_end_loss: 2.0480 - y_start_categorical_accuracy: 0.5782 - y_end_categorical_accuracy: 0.4472 - val_loss: 3.1875 - val_y_start_loss: 1.4703 - val_y_end_loss: 1.7165 - val_y_start_categorical_accuracy: 0.5855 - val_y_end_categorical_accuracy: 0.5833
# Epoch 3/3
#
# Epoch 00003: val_loss improved from 3.18747 to 2.69650, saving model to model_fold_3.h5
# 21984/21984 - 274s - loss: 2.8864 - y_start_loss: 1.4107 - y_end_loss: 1.4757 - y_start_categorical_accuracy: 0.6032 - y_end_categorical_accuracy: 0.6148 - val_loss: 2.6965 - val_y_start_loss: 1.3104 - val_y_end_loss: 1.3857 - val_y_start_categorical_accuracy: 0.6237 - val_y_end_categorical_accuracy: 0.6654

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history)
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col1 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col4 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col6 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col7 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row0_col8 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col0 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col1 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col3 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col4 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col5 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col6 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col7 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row1_col8 {
#             color:  green;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col0 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col1 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col4 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col5 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col6 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col7 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row2_col8 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col0 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col1 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col4 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col5 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col6 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col7 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row3_col8 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col1 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col4 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col6 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col7 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row4_col8 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col1 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col4 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col6 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col7 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row5_col8 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col1 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col4 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col6 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col7 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row6_col8 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col1 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col4 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col6 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col7 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row7_col8 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col1 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col4 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col6 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col7 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row8_col8 {
#             color:  orange;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col0 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col1 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col2 {
#             color:  red;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col3 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col4 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col5 {
#             color:  black;
#         }    #T_8c363c0a_8120_11ea_86fa_49b23f02b041row9_col6 {

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold.head(15))
# Out:
#         textID                                               text  \
# 0   cb774db0d1                i`d have responded, if i were going
# 1   549e992a42      sooo sad i will miss you here in san diego!!!
# 2   088c60f138                          my boss is bullying me...
# 3   9642c003ef                     what interview! leave me alone
# 4   358bd9e861  sons of ****, why couldn`t they put them on th...
# 5   28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 6   6e0c6d75b1  2am feedings for the baby are fun when he is a...
# 7   50e14c0bb8                                         soooo high
# 8   e050245fbd                                        both of you
# 9   fc2cbefa9d  journey!? wow... u just became cooler.  hehe.....
# 10  2339a9b08b  as much as i love to be hopeful, i reckon the ...
# 11  16fab9f95b  i really really like the song love story by ta...
# 12  74a76f6e0a       my sharpie is running dangerously low on ink
# 13  04dd1d2e34  i want to go to music tonight but i lost my vo...
# 14  bbe3cbf620                         test test from the lg env2
#
#                                         selected_text sentiment  text_len  \
# 0                 i`d have responded, if i were going   neutral        35
# 1                                            sooo sad  negative        45
# 2                                         bullying me  negative        25
# 3                                      leave me alone  negative        30
# 4                                       sons of ****,  negative        74
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral        92
# 6                                                 fun  positive        64
# 7                                          soooo high   neutral        10
# 8                                         both of you   neutral        11
# 9                        wow... u just became cooler.  positive        68
# 10  as much as i love to be hopeful, i reckon the ...   neutral       106
# 11                                               like  positive        56
# 12                                        dangerously  negative        44
# 13                                               lost  negative        50
# 14                         test test from the lg env2   neutral        26
#
#     selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                  35             7                      7       train
# 1                   8            10                      2  validation
# 2                  11             5                      2       train
# 3                  14             5                      3       train
# 4                  13            14                      3       train
# 5                  92            12                     12       train
# 6                   3            14                      1       train
# 7                  10             2                      2       train
# 8                  11             3                      3       train
# 9                  28            11                      5       train
# 10                106            23                     23       train
# 11                  4            11                      1       train
# 12                 11             8                      1       train
# 13                  4            12                      1       train
# 14                 26             6                      6       train
#
#         fold_2  ...                                  prediction_fold_1  \
# 0        train  ...                i`d have responded, if i were going
# 1        train  ...                                                sad
# 2   validation  ...                                     bullying me...
# 3   validation  ...                                     leave me alone
# 4        train  ...                                              ****,
# 5        train  ...  http://www.dothebouncy.com/smf - some shameles...
# 6        train  ...                                                fun
# 7        train  ...                                         soooo high
# 8   validation  ...                                        both of you
# 9   validation  ...                       wow... u just became cooler.
# 10  validation  ...  as much as i love to be hopeful, i reckon the ...
# 11       train  ...                                               like
# 12       train  ...                                        dangerously
# 13       train  ...                                     lost my voice.
# 14       train  ...                         test test from the lg env2
#
#    jaccard_fold_1 start_fold_2  end_fold_2  \
# 0        1.000000            4          13
# 1        0.100000            6           6
# 2        0.400000            7           9
# 3        0.600000            7           9
# 4        0.071429            6           7
# 5        1.000000            4          30
# 6        0.071429           12          12
# 7        1.000000            4           6
# 8        1.000000            4           6
# 9        0.500000            6           7
# 10       1.000000            4          30
# 11       0.100000            7           7
# 12       0.125000            9          10
# 13       0.300000           13          13
# 14       1.000000            4          11
#
#                                     prediction_fold_2 jaccard_fold_2  \
# 0                 i`d have responded, if i were going       1.000000
# 1                                                 sad       0.100000
# 2                                      bullying me...       0.400000
# 3                                      leave me alone       0.600000
# 4                                               ****,       0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...       1.000000
# 6                                                 fun       0.071429
# 7                                          soooo high       1.000000
# 8                                         both of you       1.000000
# 9                                              wow...       0.100000
# 10  as much as i love to be hopeful, i reckon the ...       1.000000
# 11                                               like       0.100000
# 12                                    dangerously low       0.250000
# 13                                               lost       0.100000
# 14                         test test from the lg env2       1.000000
#
#     start_fold_3  end_fold_3  \
# 0              4          13
# 1              4           6
# 2              4           9
# 3              4           9
# 4              4           7
# 5              4          30
# 6             12          12
# 7              4           6
# 8              4           6
# 9             11          12
# 10             4          30
# 11             4           7
# 12             9          10
# 13            13          13
# 14             4          11
#
#                                     prediction_fold_3 jaccard_fold_3
# 0                 i`d have responded, if i were going       1.000000
# 1                                            sooo sad       0.200000
# 2                           my boss is bullying me...       1.000000
# 3                      what interview! leave me alone       1.000000
# 4                                       sons of ****,       0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...       1.000000
# 6                                                 fun       0.071429
# 7                                          soooo high       1.000000
# 8                                         both of you       1.000000
# 9                                             cooler.       0.100000
# 10  as much as i love to be hopeful, i reckon the ...       1.000000
# 11                               i really really like       0.300000
# 12                                    dangerously low       0.250000
# 13                                               lost       0.100000
# 14                         test test from the lg env2       1.000000
#
# [15 rows x 25 columns]
