# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 16,
  "EPOCHS": 5,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(0.1)(last_state) 
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Dense(MAX_LEN, activation='softmax', name='y_start')(x_start)   

    x_end = layers.Dropout(0.1)(last_state) 
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Dense(MAX_LEN, activation='softmax', name='y_end')(x_end) 
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    batch_size=config['BATCH_SIZE'], 
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 318s - loss: 5.4343 - y_start_loss: 2.0289 - y_end_loss: 3.4054 - y_start_categorical_accuracy: 0.5504 - y_end_categorical_accuracy: 0.1334 - val_loss: 3.9501 - val_y_start_loss: 1.5841 - val_y_end_loss: 2.3668 - val_y_start_categorical_accuracy: 0.5702 - val_y_end_categorical_accuracy: 0.3861
# Epoch 2/5
# 21984/21984 - 300s - loss: 3.5084 - y_start_loss: 1.4913 - y_end_loss: 2.0172 - y_start_categorical_accuracy: 0.5873 - y_end_categorical_accuracy: 0.4665 - val_loss: 2.9861 - val_y_start_loss: 1.4008 - val_y_end_loss: 1.5857 - val_y_start_categorical_accuracy: 0.6052 - val_y_end_categorical_accuracy: 0.6059
# Epoch 3/5
# 21984/21984 - 300s - loss: 2.8684 - y_start_loss: 1.3256 - y_end_loss: 1.5428 - y_start_categorical_accuracy: 0.6157 - y_end_categorical_accuracy: 0.6073 - val_loss: 2.6196 - val_y_start_loss: 1.2522 - val_y_end_loss: 1.3679 - val_y_start_categorical_accuracy: 0.6334 - val_y_end_categorical_accuracy: 0.6643
# Epoch 4/5
# 21984/21984 - 300s - loss: 2.4635 - y_start_loss: 1.1935 - y_end_loss: 1.2699 - y_start_categorical_accuracy: 0.6459 - y_end_categorical_accuracy: 0.6743 - val_loss: 2.4956 - val_y_start_loss: 1.1759 - val_y_end_loss: 1.3190 - val_y_start_categorical_accuracy: 0.6619 - val_y_end_categorical_accuracy: 0.6745
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 299s - loss: 2.2054 - y_start_loss: 1.0880 - y_end_loss: 1.1174 - y_start_categorical_accuracy: 0.6707 - y_end_categorical_accuracy: 0.7099 - val_loss: 2.5388 - val_y_start_loss: 1.1718 - val_y_end_loss: 1.3656 - val_y_start_categorical_accuracy: 0.6650 - val_y_end_categorical_accuracy: 0.6943
# Epoch 00005: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 316s - loss: 5.4898 - y_start_loss: 2.0841 - y_end_loss: 3.4056 - y_start_categorical_accuracy: 0.5417 - y_end_categorical_accuracy: 0.1425 - val_loss: 3.7935 - val_y_start_loss: 1.5339 - val_y_end_loss: 2.2571 - val_y_start_categorical_accuracy: 0.5822 - val_y_end_categorical_accuracy: 0.4030
# Epoch 2/5
# 21984/21984 - 301s - loss: 3.2687 - y_start_loss: 1.4378 - y_end_loss: 1.8309 - y_start_categorical_accuracy: 0.5930 - y_end_categorical_accuracy: 0.5038 - val_loss: 2.8197 - val_y_start_loss: 1.3398 - val_y_end_loss: 1.4774 - val_y_start_categorical_accuracy: 0.6048 - val_y_end_categorical_accuracy: 0.6281
# Epoch 3/5
# 21984/21984 - 301s - loss: 2.6392 - y_start_loss: 1.2597 - y_end_loss: 1.3795 - y_start_categorical_accuracy: 0.6218 - y_end_categorical_accuracy: 0.6380 - val_loss: 2.6771 - val_y_start_loss: 1.2889 - val_y_end_loss: 1.3859 - val_y_start_categorical_accuracy: 0.6139 - val_y_end_categorical_accuracy: 0.6334
# Epoch 4/5
# 21984/21984 - 300s - loss: 2.3240 - y_start_loss: 1.1453 - y_end_loss: 1.1787 - y_start_categorical_accuracy: 0.6459 - y_end_categorical_accuracy: 0.6852 - val_loss: 2.5332 - val_y_start_loss: 1.2356 - val_y_end_loss: 1.2955 - val_y_start_categorical_accuracy: 0.6363 - val_y_end_categorical_accuracy: 0.6714
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 299s - loss: 2.0696 - y_start_loss: 1.0399 - y_end_loss: 1.0298 - y_start_categorical_accuracy: 0.6726 - y_end_categorical_accuracy: 0.7193 - val_loss: 2.6074 - val_y_start_loss: 1.2490 - val_y_end_loss: 1.3561 - val_y_start_categorical_accuracy: 0.6441 - val_y_end_categorical_accuracy: 0.6654
# Epoch 00005: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 317s - loss: 5.2214 - y_start_loss: 2.0128 - y_end_loss: 3.2086 - y_start_categorical_accuracy: 0.5511 - y_end_categorical_accuracy: 0.1908 - val_loss: 3.7330 - val_y_start_loss: 1.6001 - val_y_end_loss: 2.1356 - val_y_start_categorical_accuracy: 0.5686 - val_y_end_categorical_accuracy: 0.4285
# Epoch 2/5
# 21984/21984 - 301s - loss: 3.2559 - y_start_loss: 1.5012 - y_end_loss: 1.7547 - y_start_categorical_accuracy: 0.5833 - y_end_categorical_accuracy: 0.5281 - val_loss: 2.9337 - val_y_start_loss: 1.3902 - val_y_end_loss: 1.5441 - val_y_start_categorical_accuracy: 0.5899 - val_y_end_categorical_accuracy: 0.6012
# Epoch 3/5
# 21984/21984 - 301s - loss: 2.7031 - y_start_loss: 1.3285 - y_end_loss: 1.3746 - y_start_categorical_accuracy: 0.6108 - y_end_categorical_accuracy: 0.6385 - val_loss: 2.7153 - val_y_start_loss: 1.3138 - val_y_end_loss: 1.4022 - val_y_start_categorical_accuracy: 0.6268 - val_y_end_categorical_accuracy: 0.6519
# Epoch 4/5
# 21984/21984 - 301s - loss: 2.3763 - y_start_loss: 1.1954 - y_end_loss: 1.1809 - y_start_categorical_accuracy: 0.6423 - y_end_categorical_accuracy: 0.6869 - val_loss: 2.4950 - val_y_start_loss: 1.2121 - val_y_end_loss: 1.2840 - val_y_start_categorical_accuracy: 0.6345 - val_y_end_categorical_accuracy: 0.6845
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 300s - loss: 2.0757 - y_start_loss: 1.0702 - y_end_loss: 1.0055 - y_start_categorical_accuracy: 0.6704 - y_end_categorical_accuracy: 0.7259 - val_loss: 2.5144 - val_y_start_loss: 1.2249 - val_y_end_loss: 1.2914 - val_y_start_categorical_accuracy: 0.6447 - val_y_end_categorical_accuracy: 0.6870
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col6 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row0_col8 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col0 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col1 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col3 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col4 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col5 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col6 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col7 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row1_col8 {
#             color:  green;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col1 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col4 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col6 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row2_col8 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col1 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col4 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col6 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row3_col8 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col6 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row4_col8 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col6 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row5_col8 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col6 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row6_col8 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col6 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row7_col8 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col6 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col7 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row8_col8 {
#             color:  orange;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col0 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col1 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col2 {
#             color:  red;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col3 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col4 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col5 {
#             color:  black;
#         }    #T_e3d5c13a_81f0_11ea_85a6_31cc418c0c32row9_col6 {

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        0.200000
# 2                                            bullying        0.200000
# 3                                      leave me alone        0.600000
# 4                                               ****,        0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        0.500000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        0.100000
# 12       my sharpie is running dangerously low on ink        1.000000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        0.200000
# 2                                      bullying me...        0.400000
# 3                                      leave me alone        0.600000
# 4                                       sons of ****,        0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9              journey!? wow... u just became cooler.        0.600000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        0.100000
# 12                                    dangerously low        0.250000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.100000
# 2                           my boss is bullying me...        1.000000
# 3                                            me alone        0.400000
# 4                                       sons of ****,        0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9              journey!? wow... u just became cooler.        0.600000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                     running dangerously low on ink        0.625000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
