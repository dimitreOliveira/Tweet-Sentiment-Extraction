# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
# fold_1/
# fold_1/y_valid.npy
# fold_1/x_valid_aux.npy
# fold_1/y_train_mask.npy
# fold_1/x_train_aux.npy
# fold_1/x_valid.npy
# fold_1/x_valid_aux2.npy
# fold_1/y_valid_aux.npy
# fold_1/y_train.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_mask.npy
# fold_1/x_train.npy
# fold_1/x_train_aux2.npy
# fold_2/
# fold_2/y_valid.npy
# fold_2/x_valid_aux.npy
# fold_2/y_train_mask.npy
# fold_2/x_train_aux.npy
# fold_2/x_valid.npy
# fold_2/x_valid_aux2.npy
# fold_2/y_valid_aux.npy
# fold_2/y_train.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_mask.npy
# fold_2/x_train.npy
# fold_2/x_train_aux2.npy
# fold_3/
# fold_3/y_valid.npy
# fold_3/x_valid_aux.npy
# fold_3/y_train_mask.npy
# fold_3/x_train_aux.npy
# fold_3/x_valid.npy
# fold_3/x_valid_aux2.npy
# fold_3/y_valid_aux.npy
# fold_3/y_train.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_mask.npy
# fold_3/x_train.npy
# fold_3/x_train_aux2.npy
# fold_4/
# fold_4/y_valid.npy
# fold_4/x_valid_aux.npy
# fold_4/y_train_mask.npy
# fold_4/x_train_aux.npy
# fold_4/x_valid.npy
# fold_4/x_valid_aux2.npy
# fold_4/y_valid_aux.npy
# fold_4/y_train.npy
# fold_4/y_train_aux.npy
# fold_4/y_valid_mask.npy
# fold_4/x_train.npy
# fold_4/x_train_aux2.npy
# fold_5/
# fold_5/y_valid.npy
# fold_5/x_valid_aux.npy
# fold_5/y_train_mask.npy
# fold_5/x_train_aux.npy
# fold_5/x_valid.npy
# fold_5/x_valid_aux2.npy
# fold_5/y_valid_aux.npy
# fold_5/y_train.npy
# fold_5/y_train_aux.npy
# fold_5/y_valid_mask.npy
# fold_5/x_train.npy
# fold_5/x_train_aux2.npy

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
step_size = len(k_fold[k_fold['fold_1'] == 'train']) // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.98e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h12 = hidden_states[-1]
    h11 = hidden_states[-2]
    h10 = hidden_states[-3]
    h09 = hidden_states[-4]

    
    x_start_09 = layers.Dropout(.1)(h09) 
    x_start_09 = layers.Dense(1)(x_start_09)
    x_start_09 = layers.Flatten()(x_start_09)
    y_start_09 = layers.Activation('softmax', name='y_start_09')(x_start_09)
    
    x_start_10 = layers.Dropout(.1)(h10) 
    x_start_10 = layers.Dense(1)(x_start_10)
    x_start_10 = layers.Flatten()(x_start_10)
    y_start_10 = layers.Activation('softmax', name='y_start_10')(x_start_10)
    
    x_start_11 = layers.Dropout(.1)(h11) 
    x_start_11 = layers.Dense(1)(x_start_11)
    x_start_11 = layers.Flatten()(x_start_11)
    y_start_11 = layers.Activation('softmax', name='y_start_11')(x_start_11)
    
    x_start_12 = layers.Dropout(.1)(h12) 
    x_start_12 = layers.Dense(1)(x_start_12)
    x_start_12 = layers.Flatten()(x_start_12)
    y_start_12 = layers.Activation('softmax', name='y_start_12')(x_start_12)

    y_start = layers.Maximum(name='y_start')([y_start_12, y_start_11, y_start_10, y_start_09])


    x_end_09 = layers.Dropout(.1)(h09) 
    x_end_09 = layers.Dense(1)(x_end_09)
    x_end_09 = layers.Flatten()(x_end_09)
    y_end_09 = layers.Activation('softmax', name='y_end_09')(x_end_09)

    x_end_10 = layers.Dropout(.1)(h10) 
    x_end_10 = layers.Dense(1)(x_end_10)
    x_end_10 = layers.Flatten()(x_end_10)
    y_end_10 = layers.Activation('softmax', name='y_end_10')(x_end_10)

    x_end_11 = layers.Dropout(.1)(h11) 
    x_end_11 = layers.Dense(1)(x_end_11)
    x_end_11 = layers.Flatten()(x_end_11)
    y_end_11 = layers.Activation('softmax', name='y_end_11')(x_end_11)

    x_end_12 = layers.Dropout(.1)(h12) 
    x_end_12 = layers.Dense(1)(x_end_12)
    x_end_12 = layers.Flatten()(x_end_12)
    y_end_12 = layers.Activation('softmax', name='y_end_12')(x_end_12)

    y_end = layers.Maximum(name='y_end')([y_end_12, y_end_11, y_end_10, y_end_09])
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn_end(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy

    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end, }
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    history_list.append(history)
    model.load_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 281.3s loss: 4.5044 loss_start: 2.2203 loss_end: 2.2841 val_loss: 1.9538 val_loss_start: 0.9792 val_loss_end: 0.9746
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/4
# time: 265.5s loss: 4.0631 loss_start: 2.0293 loss_end: 2.0337 val_loss: 1.9481 val_loss_start: 0.9750 val_loss_end: 0.9731
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/4
# time: 265.7s loss: 3.9694 loss_start: 1.9857 loss_end: 1.9837 val_loss: 1.9537 val_loss_start: 0.9837 val_loss_end: 0.9701
#
# EPOCH 4/4
# time: 264.6s loss: 3.9207 loss_start: 1.9652 loss_end: 1.9555 val_loss: 1.9383 val_loss_start: 0.9743 val_loss_end: 0.9640
# Training finished saved model weights at "last_model_fold_1.h5"
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 281.9s loss: 4.4747 loss_start: 2.2321 loss_end: 2.2426 val_loss: 2.0149 val_loss_start: 1.0156 val_loss_end: 0.9993
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/4
# time: 266.9s loss: 4.0180 loss_start: 2.0344 loss_end: 1.9836 val_loss: 1.9228 val_loss_start: 0.9795 val_loss_end: 0.9433
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 3/4
# time: 267.1s loss: 3.9323 loss_start: 1.9941 loss_end: 1.9381 val_loss: 1.9779 val_loss_start: 1.0165 val_loss_end: 0.9615
#
# EPOCH 4/4
# time: 266.0s loss: 3.8804 loss_start: 1.9691 loss_end: 1.9113 val_loss: 1.9586 val_loss_start: 0.9877 val_loss_end: 0.9709
# Training finished saved model weights at "last_model_fold_2.h5"
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 279.8s loss: 4.5469 loss_start: 2.2416 loss_end: 2.3052 val_loss: 2.0300 val_loss_start: 1.0082 val_loss_end: 1.0218
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/4
# time: 265.4s loss: 4.0656 loss_start: 2.0458 loss_end: 2.0198 val_loss: 1.9055 val_loss_start: 0.9741 val_loss_end: 0.9313
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/4
# time: 265.9s loss: 3.9770 loss_start: 2.0074 loss_end: 1.9696 val_loss: 1.8668 val_loss_start: 0.9647 val_loss_end: 0.9022
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 4/4
# time: 265.7s loss: 3.9417 loss_start: 1.9901 loss_end: 1.9516 val_loss: 1.9064 val_loss_start: 0.9842 val_loss_end: 0.9222
# Training finished saved model weights at "last_model_fold_3.h5"
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 280.9s loss: 4.4883 loss_start: 2.2329 loss_end: 2.2554 val_loss: 1.9788 val_loss_start: 1.0429 val_loss_end: 0.9359
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/4
# time: 266.1s loss: 4.0229 loss_start: 2.0321 loss_end: 1.9907 val_loss: 1.9401 val_loss_start: 1.0149 val_loss_end: 0.9252
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 3/4
# time: 266.4s loss: 3.9354 loss_start: 1.9914 loss_end: 1.9440 val_loss: 1.9109 val_loss_start: 1.0021 val_loss_end: 0.9087
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 4/4
# time: 266.7s loss: 3.8854 loss_start: 1.9652 loss_end: 1.9202 val_loss: 1.9183 val_loss_start: 1.0186 val_loss_end: 0.8997
# Training finished saved model weights at "last_model_fold_4.h5"
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/4
# time: 281.5s loss: 4.4949 loss_start: 2.2336 loss_end: 2.2612 val_loss: 1.9628 val_loss_start: 1.0085 val_loss_end: 0.9543
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/4
# time: 265.9s loss: 4.0161 loss_start: 2.0285 loss_end: 1.9876 val_loss: 1.9338 val_loss_start: 0.9977 val_loss_end: 0.9361
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 3/4
# time: 266.3s loss: 3.9282 loss_start: 1.9889 loss_end: 1.9393 val_loss: 1.9019 val_loss_start: 0.9940 val_loss_end: 0.9079
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 4/4
# time: 266.3s loss: 3.8747 loss_start: 1.9662 loss_end: 1.9085 val_loss: 1.8940 val_loss_start: 0.9889 val_loss_end: 0.9050
# Training finished saved model weights at "last_model_fold_5.h5"

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_85b5549a_972f_11ea_9ee6_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12       my sharpie is running dangerously low on ink        0.125000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
