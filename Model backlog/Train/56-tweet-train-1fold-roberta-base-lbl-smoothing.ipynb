# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 1,
  "smooth_factor": .1,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(.1)(last_state) 
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('sigmoid', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_state) 
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('sigmoid', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
def smooth_labels(y, smooth_factor=config['smooth_factor']):
    y *= 1 - smooth_factor
    y += smooth_factor / y.shape[0]
    
    return y

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy').astype('float')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy').astype('float')
    
    np.apply_along_axis(smooth_labels, -1, y_train)
    np.apply_along_axis(smooth_labels, -1, y_valid)
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    batch_size=config['BATCH_SIZE'], 
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 288s - loss: 0.0613 - y_start_loss: 0.0305 - y_end_loss: 0.0308 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0452 - val_y_start_loss: 0.0224 - val_y_end_loss: 0.0228 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 2/5
# 21984/21984 - 271s - loss: 0.0447 - y_start_loss: 0.0226 - y_end_loss: 0.0222 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0438 - val_y_start_loss: 0.0220 - val_y_end_loss: 0.0217 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 3/5
# 21984/21984 - 270s - loss: 0.0429 - y_start_loss: 0.0218 - y_end_loss: 0.0211 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0433 - val_y_start_loss: 0.0218 - val_y_end_loss: 0.0214 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 0.0412 - y_start_loss: 0.0210 - y_end_loss: 0.0203 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0435 - val_y_start_loss: 0.0221 - val_y_end_loss: 0.0214 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col0 {
#             color:  green;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col1 {
#             color:  green;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col3 {
#             color:  green;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col4 {
#             color:  green;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow2_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow2_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow2_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow2_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow2_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow3_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow3_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow3_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow3_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow3_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow4_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow4_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow4_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow4_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow4_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow5_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow5_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow5_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow5_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow5_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow6_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow6_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow6_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow6_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow6_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow7_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow7_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow7_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow7_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow7_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow8_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow8_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow8_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow8_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow8_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow9_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow9_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow9_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow9_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow9_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow10_col0 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow10_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow10_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow10_col3 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow10_col4 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow11_col0 {
#             color:  green;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow11_col1 {
#             color:  black;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow11_col2 {
#             color:  red;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow11_col3 {
#             color:  green;
#         }    #T_3e04b4f2_8301_11ea_9230_3999b125f19drow11_col4 {
#             color:  black;
#         }</style><table id="T_3e04b4f2_8301_11ea_9230_3999b125f19d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e04b4f2_8301_11ea_9230_3999b125f19dlevel0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col0" class="data row0 col0" >0.743106</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col1" class="data row0 col1" >0.699319</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col2" class="data row0 col2" >0.043787</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col3" class="data row0 col3" >0.743106</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow0_col4" class="data row0 col4" >0.699319</td>
#             </tr>
#             <tr>
#                         <th id="T_3e04b4f2_8301_11ea_9230_3999b125f19dlevel0_row1" class="row_heading level0 row1" >Sentiment neutral</th>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col0" class="data row1 col0" >0.973317</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col1" class="data row1 col1" >0.97387</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col2" class="data row1 col2" >-0.000553365</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col3" class="data row1 col3" >0.973317</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow1_col4" class="data row1 col4" >0.97387</td>
#             </tr>
#             <tr>
#                         <th id="T_3e04b4f2_8301_11ea_9230_3999b125f19dlevel0_row2" class="row_heading level0 row2" >Sentiment negative</th>
#                         <td id="T_3e04b4f2_8301_11ea_9230_3999b125f19drow2_col0" class="data row2 col0" >0.59588</td>
#                         <td id="T_3e04b4f2_8301_11ea_9230_

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
