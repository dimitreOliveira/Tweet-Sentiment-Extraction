# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %% [markdown]
# # Load data

# %%
# !ls /kaggle/input/
# Out:
# qa-transformers			       tweet-sentiment-extraction
# tweet-dataset-10fold-roberta-96-clean

# %%
database_base_path = '/kaggle/input/tweet-dataset-10fold-roberta-96-clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_5.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_6.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_7.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_8.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_9.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-96-clean/fold_10.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  ...  \
# 0             7             10                 35                      7  ...
# 1            10             13                  8                      2  ...
# 2             5              6                 11                      2  ...
# 3             5              6                 14                      3  ...
# 4            14             17                 13                      3  ...
#
#    fold_2 fold_3      fold_4 fold_5 fold_6      fold_7 fold_8 fold_9 fold_10  \
# 0   train  train  validation  train  train       train  train  train   train
# 1   train  train       train  train  train       train  train  train   train
# 2   train  train       train  train  train  validation  train  train   train
# 3   train  train       train  train  train  validation  train  train   train
# 4   train  train       train  train  train  validation  train  train   train
#
#   imputed
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
#
# [5 rows x 22 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 2,
  "LEARNING_RATE": 1e-4,
  "ES_PATIENCE": 2,
  "N_FOLDS": 10,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %%
# pre-process
k_fold['jaccard'] = k_fold.apply(lambda x: jaccard(x['text'], x['selected_text']), axis=1)
k_fold['text_tokenCnt'] = k_fold['text'].apply(lambda x : len(tokenizer.encode(x).ids))
k_fold['selected_text_tokenCnt'] = k_fold['selected_text'].apply(lambda x : len(tokenizer.encode(x).ids))

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size # total_steps * 0.1

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [one_cycle_schedule(tf.cast(x, tf.float32), total_steps=total_steps, 
                        lr_start=lr_start, lr_max=lr_max) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 9.84e-05 to 8.47e-07

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, use_bias=False, name='qa_outputs')(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    lr = lambda: one_cycle_schedule(tf.cast(optimizer.iterations, tf.float32), 
                                    total_steps=total_steps, lr_start=lr_start, 
                                    lr_max=lr_max)
    
    optimizer = optimizers.Adam(learning_rate=lr)
    
    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Epoch 1/2
# 756/756 - 281s - loss: 4.6353 - tf_op_layer_Squeeze_loss: 2.2924 - tf_op_layer_Squeeze_1_loss: 2.3429 - val_loss: 4.0734 - val_tf_op_layer_Squeeze_loss: 2.0698 - val_tf_op_layer_Squeeze_1_loss: 2.0036
# Epoch 2/2
# 756/756 - 280s - loss: 3.9844 - tf_op_layer_Squeeze_loss: 2.0082 - tf_op_layer_Squeeze_1_loss: 1.9763 - val_loss: 3.9494 - val_tf_op_layer_Squeeze_loss: 2.0175 - val_tf_op_layer_Squeeze_1_loss: 1.9319
#
# FOLD: 2
# Epoch 1/2
# 756/756 - 281s - loss: 4.6085 - tf_op_layer_Squeeze_2_loss: 2.2873 - tf_op_layer_Squeeze_3_loss: 2.3212 - val_loss: 4.0585 - val_tf_op_layer_Squeeze_2_loss: 2.0655 - val_tf_op_layer_Squeeze_3_loss: 1.9930
# Epoch 2/2
# 756/756 - 280s - loss: 3.9373 - tf_op_layer_Squeeze_2_loss: 1.9915 - tf_op_layer_Squeeze_3_loss: 1.9459 - val_loss: 3.9717 - val_tf_op_layer_Squeeze_2_loss: 2.0100 - val_tf_op_layer_Squeeze_3_loss: 1.9616
#
# FOLD: 3
# Epoch 1/2
# 756/756 - 281s - loss: 4.6016 - tf_op_layer_Squeeze_4_loss: 2.2828 - tf_op_layer_Squeeze_5_loss: 2.3188 - val_loss: 4.0908 - val_tf_op_layer_Squeeze_4_loss: 2.0663 - val_tf_op_layer_Squeeze_5_loss: 2.0245
# Epoch 2/2
# 756/756 - 280s - loss: 3.9502 - tf_op_layer_Squeeze_4_loss: 1.9957 - tf_op_layer_Squeeze_5_loss: 1.9545 - val_loss: 3.9657 - val_tf_op_layer_Squeeze_4_loss: 2.0106 - val_tf_op_layer_Squeeze_5_loss: 1.9550
#
# FOLD: 4
# Epoch 1/2
# 756/756 - 281s - loss: 4.6452 - tf_op_layer_Squeeze_6_loss: 2.3076 - tf_op_layer_Squeeze_7_loss: 2.3376 - val_loss: 4.1125 - val_tf_op_layer_Squeeze_6_loss: 2.0386 - val_tf_op_layer_Squeeze_7_loss: 2.0738
# Epoch 2/2
# 756/756 - 280s - loss: 3.9868 - tf_op_layer_Squeeze_6_loss: 2.0087 - tf_op_layer_Squeeze_7_loss: 1.9781 - val_loss: 3.9144 - val_tf_op_layer_Squeeze_6_loss: 1.9817 - val_tf_op_layer_Squeeze_7_loss: 1.9327
#
# FOLD: 5
# Epoch 1/2
# 756/756 - 282s - loss: 4.6286 - tf_op_layer_Squeeze_8_loss: 2.2957 - tf_op_layer_Squeeze_9_loss: 2.3329 - val_loss: 4.0914 - val_tf_op_layer_Squeeze_8_loss: 2.0629 - val_tf_op_layer_Squeeze_9_loss: 2.0284
# Epoch 2/2
# 756/756 - 280s - loss: 3.9400 - tf_op_layer_Squeeze_8_loss: 1.9912 - tf_op_layer_Squeeze_9_loss: 1.9487 - val_loss: 3.9780 - val_tf_op_layer_Squeeze_8_loss: 2.0209 - val_tf_op_layer_Squeeze_9_loss: 1.9571
#
# FOLD: 6
# Epoch 1/2
# 756/756 - 281s - loss: 4.6346 - tf_op_layer_Squeeze_10_loss: 2.3004 - tf_op_layer_Squeeze_11_loss: 2.3341 - val_loss: 4.0599 - val_tf_op_layer_Squeeze_10_loss: 2.0591 - val_tf_op_layer_Squeeze_11_loss: 2.0007
# Epoch 2/2
# 756/756 - 280s - loss: 3.9548 - tf_op_layer_Squeeze_10_loss: 1.9999 - tf_op_layer_Squeeze_11_loss: 1.9550 - val_loss: 3.8886 - val_tf_op_layer_Squeeze_10_loss: 1.9740 - val_tf_op_layer_Squeeze_11_loss: 1.9147
#
# FOLD: 7
# Epoch 1/2
# 756/756 - 281s - loss: 4.6595 - tf_op_layer_Squeeze_12_loss: 2.3184 - tf_op_layer_Squeeze_13_loss: 2.3411 - val_loss: 4.0422 - val_tf_op_layer_Squeeze_12_loss: 2.0398 - val_tf_op_layer_Squeeze_13_loss: 2.0024
# Epoch 2/2
# 756/756 - 280s - loss: 3.9295 - tf_op_layer_Squeeze_12_loss: 1.9881 - tf_op_layer_Squeeze_13_loss: 1.9414 - val_loss: 3.9456 - val_tf_op_layer_Squeeze_12_loss: 1.9995 - val_tf_op_layer_Squeeze_13_loss: 1.9460
#
# FOLD: 8
# Epoch 1/2
# 756/756 - 281s - loss: 4.6627 - tf_op_layer_Squeeze_14_loss: 2.3103 - tf_op_layer_Squeeze_15_loss: 2.3524 - val_loss: 4.0278 - val_tf_op_layer_Squeeze_14_loss: 2.0355 - val_tf_op_layer_Squeeze_15_loss: 1.9923
# Epoch 2/2
# 756/756 - 280s - loss: 3.9421 - tf_op_layer_Squeeze_14_loss: 1.9944 - tf_op_layer_Squeeze_15_loss: 1.9477 - val_loss: 3.9020 - val_tf_op_layer_Squeeze_14_loss: 1.9568 - val_tf_op_layer_Squeeze_15_loss: 1.9452
#
# FOLD: 9
# Epoch 1/2
# 756/756 - 281s - loss: 4.7823 - tf_op_layer_Squeeze_16_loss: 2.3483 - tf_op_layer_Squeeze_17_loss: 2.4339 - val_loss: 4.1098 - val_tf_op_layer_Squeeze_16_loss: 2.0653 - val_tf_op_layer_Squeeze_17_loss: 2.0445
# Epoch 2/2
# 756/756 - 280s - loss: 3.9802 - tf_op_layer_Squeeze_16_loss: 2.0098 - tf_op_layer_Squeeze_17_loss: 1.9704 - val_loss: 3.9435 - val_tf_op_layer_Squeeze_16_loss: 1.9869 - val_tf_op_layer_Squeeze_17_loss: 1.9566
#
# FOLD: 10
# Epoch 1/2
# 756/756 - 282s - loss: 4.6432 - tf_op_layer_Squeeze_18_loss: 2.3093 - tf_op_layer_Squeeze_19_loss: 2.3340 - val_loss: 4.0236 - val_tf_op_layer_Squeeze_18_loss: 2.0243 - val_tf_op_layer_Squeeze_19_loss: 1.9992
# Epoch 2/2
# 756/756 - 280s - loss: 3.9534 - tf_op_layer_Squeeze_18_loss: 1.9975 - tf_op_layer_Squeeze_19_loss: 1.9559 - val_loss: 3.9223 - val_tf_op_layer_Squeeze_18_loss: 1.9728 - val_tf_op_layer_Squeeze_19_loss: 1.9495

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
# Fold: 10

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1900254e_af1e_11ea_a140_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col13 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col14 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col15 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col16 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col17 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col18 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col19 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col20 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col21 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row0_col22 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col13 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col14 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col15 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col16 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col17 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col18 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col19 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col20 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col21 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row1_col22 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col13 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col14 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col15 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col16 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col17 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col18 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col19 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col20 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col21 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row2_col22 {
#             color:  green;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col13 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col14 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col15 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col16 {
#             color:  black;
#         }    #T_1900254e_af1e_11ea_a140_0242ac130202row3_col17 {
#             color:  black;
#         }    #T_1900254e_af

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              10                      10  1.000000      1.000000
# 1              13                       3  0.200000      1.000000
# 2               6                       2  0.166667      0.333333
# 3               6                       3  0.600000      1.000000
# 4              17                       4  0.214286      1.000000
# 5              27                      27  1.000000      0.933333
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              19                       7  0.500000      0.840000
# 10             27                      27  1.000000      1.000000
# 11             12                       1  0.100000      0.400000
# 12              9                       1  0.125000      0.725000
# 13             13                       1  0.100000      0.600000
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_2  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                    dangerously low
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_3  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_4  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_5  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_6  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_7  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_8  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_9  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                           my boss is bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                    prediction_fold_10
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
