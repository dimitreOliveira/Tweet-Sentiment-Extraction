# %% [markdown]
# ## Dependencies

# %%
import json
from tweet_utility_scripts import *
from transformers import TFBertModel, BertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-bert-uncased-160/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-bert-uncased-160/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        36                 35
# 1                             sooo sad  negative        46                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        31                 14
# 4                        sons of ****,  negative        75                 13
#
#        fold_1      fold_2      fold_3      fold_4 fold_5
# 0       train       train       train  validation  train
# 1  validation       train       train       train  train
# 2       train  validation       train       train  train
# 3       train  validation       train       train  train
# 4       train       train  validation       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_valid.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy

# %% [markdown]
# # Model parameters

# %%
tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/bert/'

config = {
  "MAX_LEN": 160,
  "BATCH_SIZE": 16,
  "EPOCHS": 5,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 3,
  "N_FOLDS": 1,
  "base_model_path": base_path + 'bert-base-uncased-tf_model.h5',
  "config_path": base_path + 'bert-base-uncased-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = BertConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFBertModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='softmax', name='y_start')(x)     
    y_end = Dense(MAX_LEN, activation='softmax', name='y_end')(x)        
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)
tokenizer.save('./')
# Out:
# ['./vocab.txt']

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    model = model_fn(config['MAX_LEN'])
    tb_callback = TensorBoard(log_dir='./')
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'start_fold_%d' % (n_fold+1)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'end_fold_%d' % (n_fold+1)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'start_fold_%d' % (n_fold+1)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'end_fold_%d' % (n_fold+1)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold+1)] = k_fold['end_fold_%d' % (n_fold+1)].astype(int)
    k_fold['start_fold_%d' % (n_fold+1)] = k_fold['start_fold_%d' % (n_fold+1)].astype(int)
    k_fold['end_fold_%d' % (n_fold+1)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold+1)].clip(0, k_fold['end_fold_%d' % (n_fold+1)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold+1)], x['end_fold_%d' % (n_fold+1)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold+1)].fillna('', inplace=True)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 512s - loss: 3.8121 - y_start_loss: 1.5907 - y_end_loss: 2.2213 - y_start_categorical_accuracy: 0.5787 - y_end_categorical_accuracy: 0.3639 - val_loss: 2.7939 - val_y_start_loss: 1.3106 - val_y_end_loss: 1.4839 - val_y_start_categorical_accuracy: 0.5999 - val_y_end_categorical_accuracy: 0.5755
# Epoch 2/5
# 21984/21984 - 497s - loss: 2.5365 - y_start_loss: 1.2145 - y_end_loss: 1.3220 - y_start_categorical_accuracy: 0.6170 - y_end_categorical_accuracy: 0.6152 - val_loss: 2.5161 - val_y_start_loss: 1.2042 - val_y_end_loss: 1.3125 - val_y_start_categorical_accuracy: 0.6246 - val_y_end_categorical_accuracy: 0.6157
# Epoch 3/5
# 21984/21984 - 497s - loss: 2.1037 - y_start_loss: 1.0263 - y_end_loss: 1.0774 - y_start_categorical_accuracy: 0.6595 - y_end_categorical_accuracy: 0.6709 - val_loss: 2.4394 - val_y_start_loss: 1.1932 - val_y_end_loss: 1.2450 - val_y_start_categorical_accuracy: 0.6341 - val_y_end_categorical_accuracy: 0.6439
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 497s - loss: 1.7105 - y_start_loss: 0.8474 - y_end_loss: 0.8630 - y_start_categorical_accuracy: 0.7090 - y_end_categorical_accuracy: 0.7291 - val_loss: 2.5708 - val_y_start_loss: 1.2379 - val_y_end_loss: 1.3316 - val_y_start_categorical_accuracy: 0.6505 - val_y_end_categorical_accuracy: 0.6416
# Epoch 00004: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-13_16-19-08/
# train/plugins/profile/2020-04-13_16-19-08/local.trace
# train/events.out.tfevents.1586794748.31b1425ae4a9.profile-empty
# train/events.out.tfevents.1586794735.31b1425ae4a9.13.10628.v2
# validation/
# validation/events.out.tfevents.1586795248.31b1425ae4a9.13.47784.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 
                                       'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col0 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col1 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col3 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col4 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row2_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row2_col1 {
#             color:  orange;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row2_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row2_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row2_col4 {
#             color:  orange;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row3_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row3_col1 {
#             color:  orange;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row3_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row3_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row3_col4 {
#             color:  orange;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row4_col0 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row4_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row4_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row4_col3 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row4_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row5_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row5_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row5_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row5_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row5_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row6_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row6_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row6_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row6_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row6_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row7_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row7_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row7_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row7_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row7_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row8_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row8_col1 {
#             color:  orange;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row8_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row8_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row8_col4 {
#             color:  orange;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row9_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row9_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row9_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row9_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row9_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row10_col0 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row10_col1 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row10_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row10_col3 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row10_col4 {
#             color:  black;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row11_col0 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row11_col1 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row11_col2 {
#             color:  red;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row11_col3 {
#             color:  green;
#         }    #T_90250b42_7da7_11ea_ac37_bd274c2a1a95row11_col4 {
#             color:  green;
#         }</style><table id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col0" class="data row0 col0" >0.737581</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col1" class="data row0 col1" >0.644404</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col2" class="data row0 col2" >0.093177</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col3" class="data row0 col3" >0.737581</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row0_col4" class="data row0 col4" >0.644404</td>
#             </tr>
#             <tr>
#                         <th id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95level0_row1" class="row_heading level0 row1" >Sentiment neutral</th>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col0" class="data row1 col0" >0.975282</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col1" class="data row1 col1" >0.972668</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col2" class="data row1 col2" >0.00261399</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col3" class="data row1 col3" >0.975282</td>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row1_col4" class="data row1 col4" >0.972668</td>
#             </tr>
#             <tr>
#                         <th id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95level0_row2" class="row_heading level0 row2" >Sentiment negative</th>
#                         <td id="T_90250b42_7da7_11ea_ac37_bd274c2a1a95row2_col0" class="data row2 col0" >0.578794</td>
#                         <td id="T_90250b42_7da7_11e

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold.head(15))
# Out:
#         textID                                               text  \
# 0   cb774db0d1                i`d have responded, if i were going
# 1   549e992a42      sooo sad i will miss you here in san diego!!!
# 2   088c60f138                          my boss is bullying me...
# 3   9642c003ef                     what interview! leave me alone
# 4   358bd9e861   sons of ****, why couldn`t they put them on t...
# 5   28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 6   6e0c6d75b1  2am feedings for the baby are fun when he is a...
# 7   50e14c0bb8                                         soooo high
# 8   e050245fbd                                        both of you
# 9   fc2cbefa9d   journey!? wow... u just became cooler.  hehe....
# 10  2339a9b08b   as much as i love to be hopeful, i reckon the...
# 11  16fab9f95b  i really really like the song love story by ta...
# 12  74a76f6e0a       my sharpie is running dangerously low on ink
# 13  04dd1d2e34  i want to go to music tonight but i lost my vo...
# 14  bbe3cbf620                         test test from the lg env2
#
#                                         selected_text sentiment  text_len  \
# 0                 i`d have responded, if i were going   neutral        36
# 1                                            sooo sad  negative        46
# 2                                         bullying me  negative        25
# 3                                      leave me alone  negative        31
# 4                                       sons of ****,  negative        75
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral        92
# 6                                                 fun  positive        64
# 7                                          soooo high   neutral        10
# 8                                         both of you   neutral        12
# 9                        wow... u just became cooler.  positive        69
# 10  as much as i love to be hopeful, i reckon the ...   neutral       107
# 11                                               like  positive        56
# 12                                        dangerously  negative        44
# 13                                               lost  negative        50
# 14                         test test from the lg env2   neutral        26
#
#     selected_text_len      fold_1      fold_2      fold_3      fold_4  \
# 0                  35       train       train       train  validation
# 1                   8  validation       train       train       train
# 2                  11       train  validation       train       train
# 3                  14       train  validation       train       train
# 4                  13       train       train  validation       train
# 5                  92       train       train       train  validation
# 6                   3       train       train       train       train
# 7                  10       train       train       train       train
# 8                  11       train  validation       train       train
# 9                  28       train  validation       train       train
# 10                106       train  validation       train       train
# 11                  4       train       train       train  validation
# 12                 11       train       train       train  validation
# 13                  4       train       train       train  validation
# 14                 26       train       train  validation       train
#
#         fold_5  start_fold_1  end_fold_1  \
# 0        train             4          13
# 1        train             6           6
# 2        train             7           7
# 3        train             7           9
# 4        train             4          11
# 5        train             4          32
# 6   validation            12          12
# 7   validation             4           6
# 8        train             4           6
# 9        train             7          15
# 10       train             4          30
# 11       train             7           7
# 12       train             8           8
# 13       train            12          16
# 14       train             4          12
#
#                                     prediction_fold_1
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                   sons of ****, why
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                                            running
# 13                                   i lost my voice.
# 14                         test test from the lg env2
