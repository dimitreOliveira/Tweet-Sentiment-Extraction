# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_5.tar.gz

# balanced files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/balanced_fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 2,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .998

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 2.04e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
#     x_train = np.load(base_data_path + 'x_train.npy')
#     y_train = np.load(base_data_path + 'y_train.npy')
    x_train = np.load('balanced_' + base_data_path + 'x_train.npy')
    y_train = np.load('balanced_' + base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    #################### Fine-tune on balanced set ####################
    # Load data
#     x_train_fine = np.load('balanced_' + base_data_path + 'x_train.npy')
#     y_train_fine = np.load('balanced_' + base_data_path + 'y_train.npy')
    x_train_fine = np.load(base_data_path + 'x_train.npy')
    y_train_fine = np.load(base_data_path + 'y_train.npy')
    
    step_size_fine = x_train_fine.shape[1] // config['BATCH_SIZE']
    
    # Build TF datasets
    train_dist_ds_fine = strategy.experimental_distribute_dataset(get_training_dataset(x_train_fine, y_train_fine, config['BATCH_SIZE'], AUTO, seed=SEED))
    train_data_iter_fine = iter(train_dist_ds_fine)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))
            
    # New optimizer
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))

    history_fine = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter_fine, valid_data_iter, 
                              step_size_fine, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                              model_path, save_last=True)
    # Join history
    for key in history_fine.keys():
        history[key] += history_fine[key]
    history_list.append(history)
    
    # Make predictions (last model)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(model_path)
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
    shutil.rmtree('balanced_' + base_data_path)
# Out:
# FOLD: 1
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 244.0s loss: 4.6377 loss_start: 2.2976 loss_end: 2.3401 val_loss: 1.9556 val_loss_start: 1.0036 val_loss_end: 0.9520
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/2
# time: 229.6s loss: 4.1923 loss_start: 2.1133 loss_end: 2.0789 val_loss: 1.8935 val_loss_start: 0.9904 val_loss_end: 0.9032
# Saved model weights at "model_fold_1.h5"
# Training finished saved model weights at "last_model_fold_1.h5"
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 242.2s loss: 3.4522 loss_start: 1.7331 loss_end: 1.7191 val_loss: 1.8889 val_loss_start: 0.9685 val_loss_end: 0.9204
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/2
# time: 230.5s loss: 3.3288 loss_start: 1.6786 loss_end: 1.6502 val_loss: 1.8545 val_loss_start: 0.9585 val_loss_end: 0.8960
# Saved model weights at "model_fold_1.h5"
# Training finished saved model weights at "last_model_fold_1.h5"
#
# FOLD: 2
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 244.1s loss: 4.6498 loss_start: 2.3076 loss_end: 2.3422 val_loss: 1.9986 val_loss_start: 1.0235 val_loss_end: 0.9751
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/2
# time: 230.4s loss: 4.1696 loss_start: 2.1055 loss_end: 2.0640 val_loss: 1.9395 val_loss_start: 0.9948 val_loss_end: 0.9448
# Saved model weights at "model_fold_2.h5"
# Training finished saved model weights at "last_model_fold_2.h5"
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 242.5s loss: 3.4228 loss_start: 1.7235 loss_end: 1.6993 val_loss: 1.9998 val_loss_start: 1.0450 val_loss_end: 0.9548
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/2
# time: 230.6s loss: 3.2874 loss_start: 1.6604 loss_end: 1.6270 val_loss: 1.9526 val_loss_start: 0.9938 val_loss_end: 0.9588
# Saved model weights at "model_fold_2.h5"
# Training finished saved model weights at "last_model_fold_2.h5"
#
# FOLD: 3
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 244.3s loss: 4.6131 loss_start: 2.2964 loss_end: 2.3167 val_loss: 1.9830 val_loss_start: 1.0096 val_loss_end: 0.9733
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/2
# time: 230.1s loss: 4.1997 loss_start: 2.1234 loss_end: 2.0763 val_loss: 1.8965 val_loss_start: 0.9739 val_loss_end: 0.9226
# Saved model weights at "model_fold_3.h5"
# Training finished saved model weights at "last_model_fold_3.h5"
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 241.5s loss: 3.4349 loss_start: 1.7384 loss_end: 1.6965 val_loss: 1.8686 val_loss_start: 0.9555 val_loss_end: 0.9131
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/2
# time: 229.6s loss: 3.3083 loss_start: 1.6773 loss_end: 1.6311 val_loss: 1.8713 val_loss_start: 0.9614 val_loss_end: 0.9099
# Training finished saved model weights at "last_model_fold_3.h5"
#
# FOLD: 4
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 244.7s loss: 4.6761 loss_start: 2.3147 loss_end: 2.3614 val_loss: 1.9401 val_loss_start: 1.0211 val_loss_end: 0.9190
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/2
# time: 230.1s loss: 4.1853 loss_start: 2.1053 loss_end: 2.0800 val_loss: 1.9278 val_loss_start: 0.9940 val_loss_end: 0.9337
# Saved model weights at "model_fold_4.h5"
# Training finished saved model weights at "last_model_fold_4.h5"
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 242.0s loss: 3.4294 loss_start: 1.7306 loss_end: 1.6988 val_loss: 1.8875 val_loss_start: 0.9790 val_loss_end: 0.9085
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/2
# time: 229.3s loss: 3.3077 loss_start: 1.6675 loss_end: 1.6402 val_loss: 1.8873 val_loss_start: 0.9950 val_loss_end: 0.8923
# Saved model weights at "model_fold_4.h5"
# Training finished saved model weights at "last_model_fold_4.h5"
#
# FOLD: 5
# Train for 583 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 244.6s loss: 4.6105 loss_start: 2.2958 loss_end: 2.3147 val_loss: 1.9881 val_loss_start: 1.0123 val_loss_end: 0.9758
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/2
# time: 230.2s loss: 4.1611 loss_start: 2.1025 loss_end: 2.0585 val_loss: 1.9184 val_loss_start: 0.9847 val_loss_end: 0.9337
# Saved model weights at "model_fold_5.h5"
# Training finished saved model weights at "last_model_fold_5.h5"
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/2
# time: 241.9s loss: 3.4379 loss_start: 1.7275 loss_end: 1.7105 val_loss: 1.9515 val_loss_start: 1.0153 val_loss_end: 0.9362
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/2
# time: 230.6s loss: 3.3111 loss_start: 1.6684 loss_end: 1.6427 val_loss: 1.8741 val_loss_start: 0.9662 val_loss_end: 0.9079
# Saved model weights at "model_fold_5.h5"
# Training finished saved model weights at "last_model_fold_5.h5"

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_60439094_9b8c_11ea_bf07_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_6434db4a_9b8c_11ea_bf07_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  \
# 0              10                      10
# 1              13                       3
# 2               6                       2
# 3               6                       3
# 4              17                       4
# 5              27                      27
# 6              17                       1
# 7               3                       3
# 8               3                       3
# 9              19                       7
# 10             27                      27
# 11             12                       1
# 12              9                       1
# 13             13                       1
# 14              8                       8
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going            1.00
# 1                                            sooo sad            1.00
# 2                                            bullying            0.50
# 3                                      leave me alone            1.00
# 4                                       sons of ****,            1.00
# 5   http://www.dothebouncy.com/smf - some shameles...            1.00
# 6                                                 fun            1.00
# 7                                          soooo high            1.00
# 8                                         both of you            1.00
# 9                                              wow...            0.20
# 10  as much as i love to be hopeful, i reckon the ...            1.00
# 11                                               like            1.00
# 12                             dangerously low on ink            0.25
# 13                                               lost            1.00
# 14                         test test from the lg env2            1.00
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
