# %%
# !nvidia-smi
# Out:
# Sun May 24 23:47:45 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 2.7MB/s
#      |████████████████████████████████| 890kB 12.9MB/s
#      |████████████████████████████████| 1.1MB 12.7MB/s
#      |████████████████████████████████| 3.8MB 20.9MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/187-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 4,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 4,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]
    
    x = layers.Dropout(.1)(h11)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), warmup_steps=1, 
                                                                                       lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    # Make predictions (best model)
    model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 166s - loss: 4.1731 - y_start_loss: 2.0752 - y_end_loss: 2.0979 - val_loss: 3.8122 - val_y_start_loss: 1.9306 - val_y_end_loss: 1.8815
# Epoch 2/4
# 687/687 - 167s - loss: 3.8120 - y_start_loss: 1.9209 - y_end_loss: 1.8911 - val_loss: 3.7763 - val_y_start_loss: 1.9138 - val_y_end_loss: 1.8625
# Epoch 3/4
# 687/687 - 167s - loss: 3.7421 - y_start_loss: 1.8885 - y_end_loss: 1.8536 - val_loss: 3.7699 - val_y_start_loss: 1.9091 - val_y_end_loss: 1.8607
# Epoch 4/4
# 687/687 - 162s - loss: 3.7169 - y_start_loss: 1.8786 - y_end_loss: 1.8383 - val_loss: 3.7712 - val_y_start_loss: 1.9088 - val_y_end_loss: 1.8625
#
# FOLD: 2
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 166s - loss: 4.1600 - y_start_loss: 2.0707 - y_end_loss: 2.0893 - val_loss: 3.8707 - val_y_start_loss: 1.9485 - val_y_end_loss: 1.9222
# Epoch 2/4
# 687/687 - 167s - loss: 3.8018 - y_start_loss: 1.9170 - y_end_loss: 1.8848 - val_loss: 3.8449 - val_y_start_loss: 1.9404 - val_y_end_loss: 1.9045
# Epoch 3/4
# 687/687 - 167s - loss: 3.7409 - y_start_loss: 1.8873 - y_end_loss: 1.8536 - val_loss: 3.8324 - val_y_start_loss: 1.9286 - val_y_end_loss: 1.9038
# Epoch 4/4
# 687/687 - 167s - loss: 3.7109 - y_start_loss: 1.8738 - y_end_loss: 1.8372 - val_loss: 3.8159 - val_y_start_loss: 1.9243 - val_y_end_loss: 1.8916
#
# FOLD: 3
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 167s - loss: 4.2131 - y_start_loss: 2.1116 - y_end_loss: 2.1015 - val_loss: 3.8546 - val_y_start_loss: 1.9350 - val_y_end_loss: 1.9196
# Epoch 2/4
# 687/687 - 167s - loss: 3.8327 - y_start_loss: 1.9435 - y_end_loss: 1.8892 - val_loss: 3.7818 - val_y_start_loss: 1.9044 - val_y_end_loss: 1.8774
# Epoch 3/4
# 687/687 - 167s - loss: 3.7474 - y_start_loss: 1.9013 - y_end_loss: 1.8461 - val_loss: 3.7784 - val_y_start_loss: 1.9054 - val_y_end_loss: 1.8730
# Epoch 4/4
# 687/687 - 168s - loss: 3.7351 - y_start_loss: 1.8958 - y_end_loss: 1.8394 - val_loss: 3.7683 - val_y_start_loss: 1.8969 - val_y_end_loss: 1.8714
#
# FOLD: 4
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 167s - loss: 4.3562 - y_start_loss: 2.1260 - y_end_loss: 2.2302 - val_loss: 3.8904 - val_y_start_loss: 1.9596 - val_y_end_loss: 1.9308
# Epoch 2/4
# 687/687 - 167s - loss: 3.9326 - y_start_loss: 1.9527 - y_end_loss: 1.9799 - val_loss: 3.8504 - val_y_start_loss: 1.9426 - val_y_end_loss: 1.9078
# Epoch 3/4
# 687/687 - 167s - loss: 3.8453 - y_start_loss: 1.9253 - y_end_loss: 1.9199 - val_loss: 3.8278 - val_y_start_loss: 1.9389 - val_y_end_loss: 1.8888
# Epoch 4/4
# 687/687 - 167s - loss: 3.8079 - y_start_loss: 1.9098 - y_end_loss: 1.8982 - val_loss: 3.8115 - val_y_start_loss: 1.9311 - val_y_end_loss: 1.8804
#
# FOLD: 5
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 167s - loss: 4.1653 - y_start_loss: 2.0779 - y_end_loss: 2.0875 - val_loss: 3.7957 - val_y_start_loss: 1.9109 - val_y_end_loss: 1.8848
# Epoch 2/4
# 687/687 - 167s - loss: 3.7949 - y_start_loss: 1.9155 - y_end_loss: 1.8793 - val_loss: 3.7787 - val_y_start_loss: 1.9057 - val_y_end_loss: 1.8729
# Epoch 3/4
# 687/687 - 163s - loss: 3.7282 - y_start_loss: 1.8851 - y_end_loss: 1.8431 - val_loss: 3.7825 - val_y_start_loss: 1.9104 - val_y_end_loss: 1.8720
# Epoch 4/4
# 687/687 - 163s - loss: 3.6924 - y_start_loss: 1.8675 - y_end_loss: 1.8250 - val_loss: 3.7843 - val_y_start_loss: 1.9103 - val_y_end_loss: 1.8740

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_1c62c9e0_9e24_11ea_9425_0242ac1c0002row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_2017c4fa_9e24_11ea_9425_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       1.000000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       0.333333
# 12       my sharpie is running dangerously low on ink  ...       0.250000
# 13  i want to go to music tonight but i lost my vo...  ...       0.333333
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 17 columns]
