# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(get_training_dataset(x_train, y_train, batch_size=config['BATCH_SIZE'], buffer_size=AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, seed=SEED)),
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/6
# 687/687 - 284s - loss: 4.4127 - y_start_loss: 2.1932 - y_end_loss: 2.2194 - y_start_categorical_accuracy: 0.6566 - y_end_categorical_accuracy: 0.6611 - val_loss: 4.0552 - val_y_start_loss: 2.0384 - val_y_end_loss: 2.0168 - val_y_start_categorical_accuracy: 0.6944 - val_y_end_categorical_accuracy: 0.7173
# Epoch 2/6
# 687/687 - 269s - loss: 3.9859 - y_start_loss: 2.0084 - y_end_loss: 1.9775 - y_start_categorical_accuracy: 0.7122 - y_end_categorical_accuracy: 0.7315 - val_loss: 3.9805 - val_y_start_loss: 2.0163 - val_y_end_loss: 1.9642 - val_y_start_categorical_accuracy: 0.7160 - val_y_end_categorical_accuracy: 0.7301
# Epoch 3/6
# 687/687 - 268s - loss: 3.8650 - y_start_loss: 1.9496 - y_end_loss: 1.9154 - y_start_categorical_accuracy: 0.7308 - y_end_categorical_accuracy: 0.7521 - val_loss: 3.9635 - val_y_start_loss: 2.0064 - val_y_end_loss: 1.9571 - val_y_start_categorical_accuracy: 0.7082 - val_y_end_categorical_accuracy: 0.7321
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 267s - loss: 3.7937 - y_start_loss: 1.9206 - y_end_loss: 1.8731 - y_start_categorical_accuracy: 0.7437 - y_end_categorical_accuracy: 0.7734 - val_loss: 3.9725 - val_y_start_loss: 2.0076 - val_y_end_loss: 1.9649 - val_y_start_categorical_accuracy: 0.7122 - val_y_end_categorical_accuracy: 0.7304
# Epoch 00004: early stopping
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/6
# 687/687 - 281s - loss: 4.3701 - y_start_loss: 2.1923 - y_end_loss: 2.1779 - y_start_categorical_accuracy: 0.6564 - y_end_categorical_accuracy: 0.6700 - val_loss: 4.0503 - val_y_start_loss: 2.0455 - val_y_end_loss: 2.0049 - val_y_start_categorical_accuracy: 0.6999 - val_y_end_categorical_accuracy: 0.7127
# Epoch 2/6
# 687/687 - 268s - loss: 3.9404 - y_start_loss: 1.9959 - y_end_loss: 1.9445 - y_start_categorical_accuracy: 0.7112 - y_end_categorical_accuracy: 0.7415 - val_loss: 4.0241 - val_y_start_loss: 2.0372 - val_y_end_loss: 1.9869 - val_y_start_categorical_accuracy: 0.7063 - val_y_end_categorical_accuracy: 0.7208
# Epoch 3/6
# 687/687 - 267s - loss: 3.8440 - y_start_loss: 1.9467 - y_end_loss: 1.8973 - y_start_categorical_accuracy: 0.7359 - y_end_categorical_accuracy: 0.7590 - val_loss: 4.0235 - val_y_start_loss: 2.0320 - val_y_end_loss: 1.9916 - val_y_start_categorical_accuracy: 0.7082 - val_y_end_categorical_accuracy: 0.7272
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 266s - loss: 3.7708 - y_start_loss: 1.9114 - y_end_loss: 1.8594 - y_start_categorical_accuracy: 0.7466 - y_end_categorical_accuracy: 0.7756 - val_loss: 4.0445 - val_y_start_loss: 2.0425 - val_y_end_loss: 2.0020 - val_y_start_categorical_accuracy: 0.7067 - val_y_end_categorical_accuracy: 0.7220
# Epoch 00004: early stopping
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/6
# 687/687 - 280s - loss: 4.4331 - y_start_loss: 2.2186 - y_end_loss: 2.2145 - y_start_categorical_accuracy: 0.6477 - y_end_categorical_accuracy: 0.6551 - val_loss: 4.0660 - val_y_start_loss: 2.0399 - val_y_end_loss: 2.0261 - val_y_start_categorical_accuracy: 0.6988 - val_y_end_categorical_accuracy: 0.7039
# Epoch 2/6
# 687/687 - 268s - loss: 3.9985 - y_start_loss: 2.0249 - y_end_loss: 1.9736 - y_start_categorical_accuracy: 0.7028 - y_end_categorical_accuracy: 0.7283 - val_loss: 3.9670 - val_y_start_loss: 2.0021 - val_y_end_loss: 1.9649 - val_y_start_categorical_accuracy: 0.7200 - val_y_end_categorical_accuracy: 0.7352
# Epoch 3/6
# 687/687 - 268s - loss: 3.8830 - y_start_loss: 1.9696 - y_end_loss: 1.9134 - y_start_categorical_accuracy: 0.7285 - y_end_categorical_accuracy: 0.7505 - val_loss: 3.9602 - val_y_start_loss: 2.0030 - val_y_end_loss: 1.9572 - val_y_start_categorical_accuracy: 0.7111 - val_y_end_categorical_accuracy: 0.7387
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 267s - loss: 3.8232 - y_start_loss: 1.9376 - y_end_loss: 1.8856 - y_start_categorical_accuracy: 0.7375 - y_end_categorical_accuracy: 0.7614 - val_loss: 3.9736 - val_y_start_loss: 2.0063 - val_y_end_loss: 1.9674 - val_y_start_categorical_accuracy: 0.7171 - val_y_end_categorical_accuracy: 0.7372
# Epoch 00004: early stopping
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/6
# 687/687 - 280s - loss: 4.4947 - y_start_loss: 2.2094 - y_end_loss: 2.2853 - y_start_categorical_accuracy: 0.6537 - y_end_categorical_accuracy: 0.6396 - val_loss: 4.1011 - val_y_start_loss: 2.0572 - val_y_end_loss: 2.0438 - val_y_start_categorical_accuracy: 0.6944 - val_y_end_categorical_accuracy: 0.7107
# Epoch 2/6
# 687/687 - 268s - loss: 4.0269 - y_start_loss: 2.0262 - y_end_loss: 2.0007 - y_start_categorical_accuracy: 0.7046 - y_end_categorical_accuracy: 0.7225 - val_loss: 4.0104 - val_y_start_loss: 2.0331 - val_y_end_loss: 1.9773 - val_y_start_categorical_accuracy: 0.6963 - val_y_end_categorical_accuracy: 0.7255
# Epoch 3/6
# 687/687 - 267s - loss: 3.9225 - y_start_loss: 1.9790 - y_end_loss: 1.9435 - y_start_categorical_accuracy: 0.7203 - y_end_categorical_accuracy: 0.7425 - val_loss: 3.9984 - val_y_start_loss: 2.0329 - val_y_end_loss: 1.9655 - val_y_start_categorical_accuracy: 0.6997 - val_y_end_categorical_accuracy: 0.7308
# Epoch 4/6
# 687/687 - 268s - loss: 3.8542 - y_start_loss: 1.9427 - y_end_loss: 1.9115 - y_start_categorical_accuracy: 0.7387 - y_end_categorical_accuracy: 0.7561 - val_loss: 3.9910 - val_y_start_loss: 2.0277 - val_y_end_loss: 1.9633 - val_y_start_categorical_accuracy: 0.7029 - val_y_end_categorical_accuracy: 0.7304
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 266s - loss: 3.8102 - y_start_loss: 1.9233 - y_end_loss: 1.8870 - y_start_categorical_accuracy: 0.7426 - y_end_categorical_accuracy: 0.7663 - val_loss: 4.0042 - val_y_start_loss: 2.0360 - val_y_end_loss: 1.9682 - val_y_start_categorical_accuracy: 0.7018 - val_y_end_categorical_accuracy: 0.7304
# Epoch 00005: early stopping
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/6
# 687/687 - 280s - loss: 4.4572 - y_start_loss: 2.2145 - y_end_loss: 2.2427 - y_start_categorical_accuracy: 0.6546 - y_end_categorical_accuracy: 0.6464 - val_loss: 4.0398 - val_y_start_loss: 2.0329 - val_y_end_loss: 2.0069 - val_y_start_categorical_accuracy: 0.7014 - val_y_end_categorical_accuracy: 0.7292
# Epoch 2/6
# 687/687 - 268s - loss: 4.0067 - y_start_loss: 2.0193 - y_end_loss: 1.9873 - y_start_categorical_accuracy: 0.7076 - y_end_categorical_accuracy: 0.7249 - val_loss: 3.9906 - val_y_start_loss: 2.0126 - val_y_end_loss: 1.9780 - val_y_start_categorical_accuracy: 0.7065 - val_y_end_categorical_accuracy: 0.7275
# Epoch 3/6
# Restoring model weights from the end of the best epoch.
# 687/687 - 267s - loss: 3.9140 - y_start_loss: 1.9762 - y_end_loss: 1.9378 - y_start_categorical_accuracy: 0.7246 - y_end_categorical_accuracy: 0.7435 - val_loss: 4.0011 - val_y_start_loss: 2.0284 - val_y_end_loss: 1.9727 - val_y_start_categorical_accuracy: 0.7085 - val_y_end_categorical_accuracy: 0.7290
# Epoch 00003: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_34387ddc_9210_11ea_a0a7_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12       my sharpie is running dangerously low on ink        0.125000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
