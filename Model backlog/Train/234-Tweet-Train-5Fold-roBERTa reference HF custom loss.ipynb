# %%
# !nvidia-smi
# Out:
# Tue Jun  2 21:48:57 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 675kB 5.0MB/s
#      |████████████████████████████████| 890kB 22.9MB/s
#      |████████████████████████████████| 1.1MB 45.4MB/s
#      |████████████████████████████████| 3.8MB 49.7MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/234-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 2.96e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, name="qa_outputs")(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
from tensorflow.keras import backend

def Custom_loss(label_smoothing=0., from_logits=False, weight=0.):
    def custom_loss(y_true, y_pred):
        cce = losses.CategoricalCrossentropy(label_smoothing=label_smoothing, from_logits=from_logits)
        y_true_pos = backend.cast(tf.math.argmax(y_true, axis=-1), 'float32')
        y_pred_pos = backend.cast(tf.math.argmax(y_pred, axis=-1), 'float32')

        loss = cce(y_true, y_pred)
        gap = tf.math.reduce_mean(tf.math.sqrt(tf.math.pow(tf.math.subtract(y_true_pos, y_pred_pos), 2)))
        gap = tf.math.multiply(gap, weight)
        loss = tf.math.add(loss, gap)

        return loss
    return custom_loss

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    # model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
    #                                losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    model.compile(optimizer, loss=[Custom_loss(label_smoothing=0.2, from_logits=True, weight=0.5),
                                   Custom_loss(label_smoothing=0.2, from_logits=True, weight=0.5)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    # model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 176s - loss: 8.7079 - tf_op_layer_Squeeze_12_loss: 4.2228 - tf_op_layer_Squeeze_13_loss: 4.4851 - val_loss: 5.6391 - val_tf_op_layer_Squeeze_12_loss: 2.8247 - val_tf_op_layer_Squeeze_13_loss: 2.8144
# Epoch 2/7
# 672/672 - 178s - loss: 5.5293 - tf_op_layer_Squeeze_12_loss: 2.7183 - tf_op_layer_Squeeze_13_loss: 2.8110 - val_loss: 5.5150 - val_tf_op_layer_Squeeze_12_loss: 2.7510 - val_tf_op_layer_Squeeze_13_loss: 2.7640
# Epoch 3/7
# 672/672 - 175s - loss: 5.2648 - tf_op_layer_Squeeze_12_loss: 2.5987 - tf_op_layer_Squeeze_13_loss: 2.6662 - val_loss: 5.5137 - val_tf_op_layer_Squeeze_12_loss: 2.7610 - val_tf_op_layer_Squeeze_13_loss: 2.7527
# Epoch 4/7
# 672/672 - 176s - loss: 5.1447 - tf_op_layer_Squeeze_12_loss: 2.5598 - tf_op_layer_Squeeze_13_loss: 2.5849 - val_loss: 5.4954 - val_tf_op_layer_Squeeze_12_loss: 2.7389 - val_tf_op_layer_Squeeze_13_loss: 2.7566
# Epoch 5/7
# 672/672 - 171s - loss: 5.0572 - tf_op_layer_Squeeze_12_loss: 2.4991 - tf_op_layer_Squeeze_13_loss: 2.5581 - val_loss: 5.4956 - val_tf_op_layer_Squeeze_12_loss: 2.7350 - val_tf_op_layer_Squeeze_13_loss: 2.7606
# Epoch 6/7
# 672/672 - 175s - loss: 5.0796 - tf_op_layer_Squeeze_12_loss: 2.5175 - tf_op_layer_Squeeze_13_loss: 2.5621 - val_loss: 5.4826 - val_tf_op_layer_Squeeze_12_loss: 2.7331 - val_tf_op_layer_Squeeze_13_loss: 2.7495
# Epoch 7/7
# 672/672 - 171s - loss: 5.0147 - tf_op_layer_Squeeze_12_loss: 2.4885 - tf_op_layer_Squeeze_13_loss: 2.5262 - val_loss: 5.4831 - val_tf_op_layer_Squeeze_12_loss: 2.7241 - val_tf_op_layer_Squeeze_13_loss: 2.7589
#
# FOLD: 2
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 181s - loss: 8.2908 - tf_op_layer_Squeeze_14_loss: 3.8546 - tf_op_layer_Squeeze_15_loss: 4.4361 - val_loss: 5.7423 - val_tf_op_layer_Squeeze_14_loss: 2.7932 - val_tf_op_layer_Squeeze_15_loss: 2.9490
# Epoch 2/7
# 672/672 - 175s - loss: 5.5812 - tf_op_layer_Squeeze_14_loss: 2.7261 - tf_op_layer_Squeeze_15_loss: 2.8551 - val_loss: 5.5266 - val_tf_op_layer_Squeeze_14_loss: 2.7323 - val_tf_op_layer_Squeeze_15_loss: 2.7943
# Epoch 3/7
# 672/672 - 175s - loss: 5.2764 - tf_op_layer_Squeeze_14_loss: 2.6019 - tf_op_layer_Squeeze_15_loss: 2.6745 - val_loss: 5.4582 - val_tf_op_layer_Squeeze_14_loss: 2.6976 - val_tf_op_layer_Squeeze_15_loss: 2.7606
# Epoch 4/7
# 672/672 - 171s - loss: 5.1613 - tf_op_layer_Squeeze_14_loss: 2.5541 - tf_op_layer_Squeeze_15_loss: 2.6071 - val_loss: 5.4677 - val_tf_op_layer_Squeeze_14_loss: 2.7105 - val_tf_op_layer_Squeeze_15_loss: 2.7572
# Epoch 5/7
# 672/672 - 175s - loss: 5.1091 - tf_op_layer_Squeeze_14_loss: 2.5348 - tf_op_layer_Squeeze_15_loss: 2.5743 - val_loss: 5.4491 - val_tf_op_layer_Squeeze_14_loss: 2.7101 - val_tf_op_layer_Squeeze_15_loss: 2.7391
# Epoch 6/7
# 672/672 - 171s - loss: 5.0969 - tf_op_layer_Squeeze_14_loss: 2.5295 - tf_op_layer_Squeeze_15_loss: 2.5673 - val_loss: 5.4724 - val_tf_op_layer_Squeeze_14_loss: 2.7051 - val_tf_op_layer_Squeeze_15_loss: 2.7672
# Epoch 7/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 5.0455 - tf_op_layer_Squeeze_14_loss: 2.5098 - tf_op_layer_Squeeze_15_loss: 2.5358 - val_loss: 5.4660 - val_tf_op_layer_Squeeze_14_loss: 2.7065 - val_tf_op_layer_Squeeze_15_loss: 2.7595
# Epoch 00007: early stopping
#
# FOLD: 3
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 181s - loss: 8.8207 - tf_op_layer_Squeeze_16_loss: 4.3897 - tf_op_layer_Squeeze_17_loss: 4.4310 - val_loss: 5.8082 - val_tf_op_layer_Squeeze_16_loss: 2.8280 - val_tf_op_layer_Squeeze_17_loss: 2.9802
# Epoch 2/7
# 672/672 - 176s - loss: 5.6131 - tf_op_layer_Squeeze_16_loss: 2.7586 - tf_op_layer_Squeeze_17_loss: 2.8545 - val_loss: 5.4774 - val_tf_op_layer_Squeeze_16_loss: 2.7088 - val_tf_op_layer_Squeeze_17_loss: 2.7686
# Epoch 3/7
# 672/672 - 175s - loss: 5.3700 - tf_op_layer_Squeeze_16_loss: 2.6523 - tf_op_layer_Squeeze_17_loss: 2.7177 - val_loss: 5.4410 - val_tf_op_layer_Squeeze_16_loss: 2.6885 - val_tf_op_layer_Squeeze_17_loss: 2.7525
# Epoch 4/7
# 672/672 - 175s - loss: 5.2780 - tf_op_layer_Squeeze_16_loss: 2.6128 - tf_op_layer_Squeeze_17_loss: 2.6652 - val_loss: 5.4263 - val_tf_op_layer_Squeeze_16_loss: 2.6942 - val_tf_op_layer_Squeeze_17_loss: 2.7321
# Epoch 5/7
# 672/672 - 171s - loss: 5.1718 - tf_op_layer_Squeeze_16_loss: 2.5576 - tf_op_layer_Squeeze_17_loss: 2.6142 - val_loss: 5.4292 - val_tf_op_layer_Squeeze_16_loss: 2.6918 - val_tf_op_layer_Squeeze_17_loss: 2.7374
# Epoch 6/7
# 672/672 - 175s - loss: 5.2082 - tf_op_layer_Squeeze_16_loss: 2.5801 - tf_op_layer_Squeeze_17_loss: 2.6282 - val_loss: 5.4075 - val_tf_op_layer_Squeeze_16_loss: 2.6784 - val_tf_op_layer_Squeeze_17_loss: 2.7291
# Epoch 7/7
# 672/672 - 171s - loss: 5.1695 - tf_op_layer_Squeeze_16_loss: 2.5534 - tf_op_layer_Squeeze_17_loss: 2.6162 - val_loss: 5.4102 - val_tf_op_layer_Squeeze_16_loss: 2.6865 - val_tf_op_layer_Squeeze_17_loss: 2.7238
#
# FOLD: 4
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 8.1588 - tf_op_layer_Squeeze_18_loss: 4.0927 - tf_op_layer_Squeeze_19_loss: 4.0661 - val_loss: 5.5694 - val_tf_op_layer_Squeeze_18_loss: 2.7093 - val_tf_op_layer_Squeeze_19_loss: 2.8601
# Epoch 2/7
# 672/672 - 176s - loss: 5.5035 - tf_op_layer_Squeeze_18_loss: 2.7195 - tf_op_layer_Squeeze_19_loss: 2.7840 - val_loss: 5.4534 - val_tf_op_layer_Squeeze_18_loss: 2.6744 - val_tf_op_layer_Squeeze_19_loss: 2.7791
# Epoch 3/7
# 672/672 - 176s - loss: 5.2565 - tf_op_layer_Squeeze_18_loss: 2.6036 - tf_op_layer_Squeeze_19_loss: 2.6530 - val_loss: 5.3893 - val_tf_op_layer_Squeeze_18_loss: 2.6429 - val_tf_op_layer_Squeeze_19_loss: 2.7463
# Epoch 4/7
# 672/672 - 171s - loss: 5.1370 - tf_op_layer_Squeeze_18_loss: 2.5541 - tf_op_layer_Squeeze_19_loss: 2.5828 - val_loss: 5.4005 - val_tf_op_layer_Squeeze_18_loss: 2.6499 - val_tf_op_layer_Squeeze_19_loss: 2.7506
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 172s - loss: 5.0853 - tf_op_layer_Squeeze_18_loss: 2.5300 - tf_op_layer_Squeeze_19_loss: 2.5552 - val_loss: 5.4017 - val_tf_op_layer_Squeeze_18_loss: 2.6472 - val_tf_op_layer_Squeeze_19_loss: 2.7545
# Epoch 00005: early stopping
#
# FOLD: 5
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 8.3704 - tf_op_layer_Squeeze_20_loss: 4.2083 - tf_op_layer_Squeeze_21_loss: 4.1621 - val_loss: 5.7983 - val_tf_op_layer_Squeeze_20_loss: 2.7657 - val_tf_op_layer_Squeeze_21_loss: 3.0327
# Epoch 2/7
# 672/672 - 176s - loss: 5.6517 - tf_op_layer_Squeeze_20_loss: 2.7385 - tf_op_layer_Squeeze_21_loss: 2.9132 - val_loss: 5.5041 - val_tf_op_layer_Squeeze_20_loss: 2.6574 - val_tf_op_layer_Squeeze_21_loss: 2.8467
# Epoch 3/7
# 672/672 - 171s - loss: 5.3585 - tf_op_layer_Squeeze_20_loss: 2.6030 - tf_op_layer_Squeeze_21_loss: 2.7555 - val_loss: 5.5244 - val_tf_op_layer_Squeeze_20_loss: 2.6477 - val_tf_op_layer_Squeeze_21_loss: 2.8766
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 5.2304 - tf_op_layer_Squeeze_20_loss: 2.5273 - tf_op_layer_Squeeze_21_loss: 2.7031 - val_loss: 5.5271 - val_tf_op_layer_Squeeze_20_loss: 2.6481 - val_tf_op_layer_Squeeze_21_loss: 2.8789
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_de7708ec_a532_11ea_80b5_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_5
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                              bullying me...
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                                      wow...
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                                        like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                      dangerously low on ink
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                              lost my voice.
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
