# %%
# !nvidia-smi
# Out:
# Sun May 24 13:56:19 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 8.8MB/s
#      |████████████████████████████████| 1.1MB 26.8MB/s
#      |████████████████████████████████| 890kB 38kB/s
#      |████████████████████████████████| 3.8MB 12.6MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/182-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 16 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 4,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 4,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Conv1D(32, 3, padding='same', activation='relu')(last_hidden_state)
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(.1)(x)
    
    x_start = layers.TimeDistributed(layers.Dense(1))(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.TimeDistributed(layers.Dense(1))(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), warmup_steps=1, 
                                                                                       lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])

    # Make predictions (best model)
    model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 278s - loss: 2.5668 - y_start_loss: 1.3071 - y_end_loss: 1.2597 - val_loss: 1.6619 - val_y_start_loss: 0.8600 - val_y_end_loss: 0.8019
# Epoch 2/4
# 687/687 - 278s - loss: 1.6319 - y_start_loss: 0.8423 - y_end_loss: 0.7896 - val_loss: 1.6166 - val_y_start_loss: 0.8410 - val_y_end_loss: 0.7755
# Epoch 3/4
# 687/687 - 279s - loss: 1.5134 - y_start_loss: 0.7859 - y_end_loss: 0.7275 - val_loss: 1.6018 - val_y_start_loss: 0.8333 - val_y_end_loss: 0.7685
# Epoch 4/4
# 687/687 - 278s - loss: 1.4755 - y_start_loss: 0.7709 - y_end_loss: 0.7046 - val_loss: 1.6017 - val_y_start_loss: 0.8319 - val_y_end_loss: 0.7698
#
# FOLD: 2
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 280s - loss: 2.5208 - y_start_loss: 1.2317 - y_end_loss: 1.2891 - val_loss: 1.7556 - val_y_start_loss: 0.8923 - val_y_end_loss: 0.8633
# Epoch 2/4
# 687/687 - 277s - loss: 1.6153 - y_start_loss: 0.8296 - y_end_loss: 0.7857 - val_loss: 1.7033 - val_y_start_loss: 0.8693 - val_y_end_loss: 0.8339
# Epoch 3/4
# 687/687 - 277s - loss: 1.5030 - y_start_loss: 0.7745 - y_end_loss: 0.7286 - val_loss: 1.6915 - val_y_start_loss: 0.8562 - val_y_end_loss: 0.8353
# Epoch 4/4
# 687/687 - 278s - loss: 1.4568 - y_start_loss: 0.7524 - y_end_loss: 0.7044 - val_loss: 1.6671 - val_y_start_loss: 0.8501 - val_y_end_loss: 0.8170
#
# FOLD: 3
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 277s - loss: 2.5647 - y_start_loss: 1.2772 - y_end_loss: 1.2875 - val_loss: 1.7131 - val_y_start_loss: 0.8605 - val_y_end_loss: 0.8526
# Epoch 2/4
# 687/687 - 279s - loss: 1.6385 - y_start_loss: 0.8541 - y_end_loss: 0.7844 - val_loss: 1.5927 - val_y_start_loss: 0.8226 - val_y_end_loss: 0.7701
# Epoch 3/4
# 687/687 - 278s - loss: 1.5090 - y_start_loss: 0.7898 - y_end_loss: 0.7192 - val_loss: 1.5871 - val_y_start_loss: 0.8224 - val_y_end_loss: 0.7647
# Epoch 4/4
# 687/687 - 277s - loss: 1.4797 - y_start_loss: 0.7744 - y_end_loss: 0.7053 - val_loss: 1.5750 - val_y_start_loss: 0.8073 - val_y_end_loss: 0.7677
#
# FOLD: 4
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 277s - loss: 2.4081 - y_start_loss: 1.2070 - y_end_loss: 1.2012 - val_loss: 1.6952 - val_y_start_loss: 0.8805 - val_y_end_loss: 0.8146
# Epoch 2/4
# 687/687 - 279s - loss: 1.6213 - y_start_loss: 0.8290 - y_end_loss: 0.7923 - val_loss: 1.6197 - val_y_start_loss: 0.8530 - val_y_end_loss: 0.7667
# Epoch 3/4
# 687/687 - 280s - loss: 1.5209 - y_start_loss: 0.7873 - y_end_loss: 0.7337 - val_loss: 1.6039 - val_y_start_loss: 0.8435 - val_y_end_loss: 0.7604
# Epoch 4/4
# 687/687 - 281s - loss: 1.4844 - y_start_loss: 0.7683 - y_end_loss: 0.7160 - val_loss: 1.5801 - val_y_start_loss: 0.8313 - val_y_end_loss: 0.7488
#
# FOLD: 5
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 277s - loss: 2.5483 - y_start_loss: 1.2713 - y_end_loss: 1.2770 - val_loss: 1.6789 - val_y_start_loss: 0.8623 - val_y_end_loss: 0.8166
# Epoch 2/4
# 687/687 - 278s - loss: 1.6308 - y_start_loss: 0.8433 - y_end_loss: 0.7875 - val_loss: 1.6199 - val_y_start_loss: 0.8425 - val_y_end_loss: 0.7774
# Epoch 3/4
# 687/687 - 273s - loss: 1.5346 - y_start_loss: 0.7985 - y_end_loss: 0.7361 - val_loss: 1.6254 - val_y_start_loss: 0.8449 - val_y_end_loss: 0.7805
# Epoch 4/4
# 687/687 - 278s - loss: 1.4812 - y_start_loss: 0.7742 - y_end_loss: 0.7070 - val_loss: 1.6169 - val_y_start_loss: 0.8388 - val_y_end_loss: 0.7781

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_8625f2d8_9ddb_11ea_b35d_0242ac1c0002row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_8860f2e6_9ddb_11ea_b35d_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       0.500000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       0.250000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 16 columns]
