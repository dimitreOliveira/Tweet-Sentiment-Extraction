# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/y_train.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/y_train.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/y_train.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 16,
  "EPOCHS": 7,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
#     sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Conv1D(1, 1)(last_state)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Dense(MAX_LEN, activation='softmax', name='y_start')(x_start)   

    x_end = layers.Conv1D(1, 1)(last_state)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Dense(MAX_LEN, activation='softmax', name='y_end')(x_end) 
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    model = model_fn(config['MAX_LEN'])
    tb_callback = TensorBoard(log_dir='./')
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True, verbose=1)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[checkpoint, es, tb_callback],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'start_fold_%d' % (n_fold+1)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'end_fold_%d' % (n_fold+1)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'start_fold_%d' % (n_fold+1)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'end_fold_%d' % (n_fold+1)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold+1)] = k_fold['end_fold_%d' % (n_fold+1)].astype(int)
    k_fold['start_fold_%d' % (n_fold+1)] = k_fold['start_fold_%d' % (n_fold+1)].astype(int)
    k_fold['end_fold_%d' % (n_fold+1)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold+1)].clip(0, k_fold['end_fold_%d' % (n_fold+1)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold+1)], x['end_fold_%d' % (n_fold+1)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold+1)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold+1)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/7
#
# Epoch 00001: val_loss improved from inf to 3.39534, saving model to model_fold_1.h5
# 21984/21984 - 316s - loss: 5.1021 - y_start_loss: 2.0683 - y_end_loss: 3.0338 - y_start_categorical_accuracy: 0.5470 - y_end_categorical_accuracy: 0.2403 - val_loss: 3.3953 - val_y_start_loss: 1.5405 - val_y_end_loss: 1.8557 - val_y_start_categorical_accuracy: 0.5830 - val_y_end_categorical_accuracy: 0.5317
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.39534 to 2.72839, saving model to model_fold_1.h5
# 21984/21984 - 298s - loss: 3.1667 - y_start_loss: 1.5023 - y_end_loss: 1.6644 - y_start_categorical_accuracy: 0.5845 - y_end_categorical_accuracy: 0.5534 - val_loss: 2.7284 - val_y_start_loss: 1.3374 - val_y_end_loss: 1.3914 - val_y_start_categorical_accuracy: 0.6143 - val_y_end_categorical_accuracy: 0.6288
# Epoch 3/7
#
# Epoch 00003: val_loss improved from 2.72839 to 2.51336, saving model to model_fold_1.h5
# 21984/21984 - 298s - loss: 2.6603 - y_start_loss: 1.3122 - y_end_loss: 1.3481 - y_start_categorical_accuracy: 0.6162 - y_end_categorical_accuracy: 0.6356 - val_loss: 2.5134 - val_y_start_loss: 1.2519 - val_y_end_loss: 1.2603 - val_y_start_categorical_accuracy: 0.6350 - val_y_end_categorical_accuracy: 0.6563
# Epoch 4/7
#
# Epoch 00004: val_loss improved from 2.51336 to 2.47747, saving model to model_fold_1.h5
# 21984/21984 - 299s - loss: 2.3517 - y_start_loss: 1.1812 - y_end_loss: 1.1705 - y_start_categorical_accuracy: 0.6480 - y_end_categorical_accuracy: 0.6789 - val_loss: 2.4775 - val_y_start_loss: 1.2175 - val_y_end_loss: 1.2588 - val_y_start_categorical_accuracy: 0.6519 - val_y_end_categorical_accuracy: 0.6747
# Epoch 5/7
#
# Epoch 00005: val_loss improved from 2.47747 to 2.38278, saving model to model_fold_1.h5
# 21984/21984 - 299s - loss: 2.0646 - y_start_loss: 1.0586 - y_end_loss: 1.0061 - y_start_categorical_accuracy: 0.6727 - y_end_categorical_accuracy: 0.7186 - val_loss: 2.3828 - val_y_start_loss: 1.1456 - val_y_end_loss: 1.2359 - val_y_start_categorical_accuracy: 0.6668 - val_y_end_categorical_accuracy: 0.6865
# Epoch 6/7
#
# Epoch 00006: val_loss did not improve from 2.38278
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 298s - loss: 1.8302 - y_start_loss: 0.9596 - y_end_loss: 0.8706 - y_start_categorical_accuracy: 0.6984 - y_end_categorical_accuracy: 0.7485 - val_loss: 2.4417 - val_y_start_loss: 1.1796 - val_y_end_loss: 1.2607 - val_y_start_categorical_accuracy: 0.6661 - val_y_end_categorical_accuracy: 0.6832
# Epoch 00006: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/7
#
# Epoch 00001: val_loss improved from inf to 3.52831, saving model to model_fold_2.h5
# 21984/21984 - 315s - loss: 5.3612 - y_start_loss: 2.0722 - y_end_loss: 3.2890 - y_start_categorical_accuracy: 0.5462 - y_end_categorical_accuracy: 0.1588 - val_loss: 3.5283 - val_y_start_loss: 1.5125 - val_y_end_loss: 2.0140 - val_y_start_categorical_accuracy: 0.5833 - val_y_end_categorical_accuracy: 0.4489
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.52831 to 2.76389, saving model to model_fold_2.h5
# 21984/21984 - 301s - loss: 3.1680 - y_start_loss: 1.4090 - y_end_loss: 1.7590 - y_start_categorical_accuracy: 0.5981 - y_end_categorical_accuracy: 0.5165 - val_loss: 2.7639 - val_y_start_loss: 1.3115 - val_y_end_loss: 1.4498 - val_y_start_categorical_accuracy: 0.6183 - val_y_end_categorical_accuracy: 0.6032
# Epoch 3/7
#
# Epoch 00003: val_loss improved from 2.76389 to 2.55958, saving model to model_fold_2.h5
# 21984/21984 - 301s - loss: 2.6154 - y_start_loss: 1.2303 - y_end_loss: 1.3851 - y_start_categorical_accuracy: 0.6267 - y_end_categorical_accuracy: 0.6222 - val_loss: 2.5596 - val_y_start_loss: 1.2334 - val_y_end_loss: 1.3237 - val_y_start_categorical_accuracy: 0.6314 - val_y_end_categorical_accuracy: 0.6421
# Epoch 4/7
#
# Epoch 00004: val_loss did not improve from 2.55958
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 299s - loss: 2.2377 - y_start_loss: 1.0900 - y_end_loss: 1.1477 - y_start_categorical_accuracy: 0.6612 - y_end_categorical_accuracy: 0.6764 - val_loss: 2.6927 - val_y_start_loss: 1.2665 - val_y_end_loss: 1.4237 - val_y_start_categorical_accuracy: 0.6339 - val_y_end_categorical_accuracy: 0.6548
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/7
#
# Epoch 00001: val_loss improved from inf to 3.62059, saving model to model_fold_3.h5
# 21984/21984 - 315s - loss: 5.1209 - y_start_loss: 2.0010 - y_end_loss: 3.1200 - y_start_categorical_accuracy: 0.5500 - y_end_categorical_accuracy: 0.2034 - val_loss: 3.6206 - val_y_start_loss: 1.6051 - val_y_end_loss: 2.0168 - val_y_start_categorical_accuracy: 0.5624 - val_y_end_categorical_accuracy: 0.4345
# Epoch 2/7
#
# Epoch 00002: val_loss improved from 3.62059 to 2.98550, saving model to model_fold_3.h5
# 21984/21984 - 300s - loss: 3.2905 - y_start_loss: 1.5171 - y_end_loss: 1.7735 - y_start_categorical_accuracy: 0.5827 - y_end_categorical_accuracy: 0.5155 - val_loss: 2.9855 - val_y_start_loss: 1.4076 - val_y_end_loss: 1.5779 - val_y_start_categorical_accuracy: 0.5906 - val_y_end_categorical_accuracy: 0.5928
# Epoch 3/7
#
# Epoch 00003: val_loss improved from 2.98550 to 2.82411, saving model to model_fold_3.h5
# 21984/21984 - 300s - loss: 2.7220 - y_start_loss: 1.3312 - y_end_loss: 1.3908 - y_start_categorical_accuracy: 0.6099 - y_end_categorical_accuracy: 0.6301 - val_loss: 2.8241 - val_y_start_loss: 1.3005 - val_y_end_loss: 1.5248 - val_y_start_categorical_accuracy: 0.6197 - val_y_end_categorical_accuracy: 0.6246
# Epoch 4/7
#
# Epoch 00004: val_loss improved from 2.82411 to 2.56338, saving model to model_fold_3.h5
# 21984/21984 - 300s - loss: 2.3764 - y_start_loss: 1.1911 - y_end_loss: 1.1852 - y_start_categorical_accuracy: 0.6415 - y_end_categorical_accuracy: 0.6843 - val_loss: 2.5634 - val_y_start_loss: 1.2364 - val_y_end_loss: 1.3290 - val_y_start_categorical_accuracy: 0.6292 - val_y_end_categorical_accuracy: 0.6823
# Epoch 5/7
#
# Epoch 00005: val_loss did not improve from 2.56338
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 298s - loss: 2.1547 - y_start_loss: 1.0890 - y_end_loss: 1.0658 - y_start_categorical_accuracy: 0.6661 - y_end_categorical_accuracy: 0.7091 - val_loss: 2.5959 - val_y_start_loss: 1.2414 - val_y_end_loss: 1.3571 - val_y_start_categorical_accuracy: 0.6483 - val_y_end_categorical_accuracy: 0.6545
# Epoch 00005: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1587068430.57dd7b77e9fc.13.149723.v2
# train/events.out.tfevents.1587069766.57dd7b77e9fc.13.255287.v2
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-16_20-43-00/
# train/plugins/profile/2020-04-16_20-43-00/local.trace
# train/plugins/profile/2020-04-16_20-20-43/
# train/plugins/profile/2020-04-16_20-20-43/local.trace
# train/plugins/profile/2020-04-16_19-48-35/
# train/plugins/profile/2020-04-16_19-48-35/local.trace
# train/events.out.tfevents.1587066515.57dd7b77e9fc.profile-empty
# train/events.out.tfevents.1587066500.57dd7b77e9fc.13.10697.v2
# validation/
# validation/events.out.tfevents.1587068746.57dd7b77e9fc.13.187473.v2
# validation/events.out.tfevents.1587066816.57dd7b77e9fc.13.48447.v2
# validation/events.out.tfevents.1587070082.57dd7b77e9fc.13.293037.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 
                                       'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col1 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col6 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row0_col8 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col0 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col1 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col3 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col4 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col5 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col6 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col7 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row1_col8 {
#             color:  green;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col1 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col4 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col6 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row2_col8 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col1 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col4 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col6 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row3_col8 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col1 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col6 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row4_col8 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col1 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col6 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row5_col8 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col1 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col6 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row6_col8 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col1 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col6 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row7_col8 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col1 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col6 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col7 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row8_col8 {
#             color:  orange;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col0 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col1 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col2 {
#             color:  red;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col3 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col4 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col5 {
#             color:  black;
#         }    #T_a44bc648_8026_11ea_bbb1_e92d9d3b8300row9_col6 {

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold.head(15))
# Out:
#         textID                                               text  \
# 0   cb774db0d1                i`d have responded, if i were going
# 1   549e992a42      sooo sad i will miss you here in san diego!!!
# 2   088c60f138                          my boss is bullying me...
# 3   9642c003ef                     what interview! leave me alone
# 4   358bd9e861  sons of ****, why couldn`t they put them on th...
# 5   28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 6   6e0c6d75b1  2am feedings for the baby are fun when he is a...
# 7   50e14c0bb8                                         soooo high
# 8   e050245fbd                                        both of you
# 9   fc2cbefa9d  journey!? wow... u just became cooler.  hehe.....
# 10  2339a9b08b  as much as i love to be hopeful, i reckon the ...
# 11  16fab9f95b  i really really like the song love story by ta...
# 12  74a76f6e0a       my sharpie is running dangerously low on ink
# 13  04dd1d2e34  i want to go to music tonight but i lost my vo...
# 14  bbe3cbf620                         test test from the lg env2
#
#                                         selected_text sentiment  text_len  \
# 0                 i`d have responded, if i were going   neutral        35
# 1                                            sooo sad  negative        45
# 2                                         bullying me  negative        25
# 3                                      leave me alone  negative        30
# 4                                       sons of ****,  negative        74
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral        92
# 6                                                 fun  positive        64
# 7                                          soooo high   neutral        10
# 8                                         both of you   neutral        11
# 9                        wow... u just became cooler.  positive        68
# 10  as much as i love to be hopeful, i reckon the ...   neutral       106
# 11                                               like  positive        56
# 12                                        dangerously  negative        44
# 13                                               lost  negative        50
# 14                         test test from the lg env2   neutral        26
#
#     selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                  35             7                      7       train
# 1                   8            10                      2  validation
# 2                  11             5                      2       train
# 3                  14             5                      3       train
# 4                  13            14                      3       train
# 5                  92            12                     12       train
# 6                   3            14                      1       train
# 7                  10             2                      2       train
# 8                  11             3                      3       train
# 9                  28            11                      5       train
# 10                106            23                     23       train
# 11                  4            11                      1       train
# 12                 11             8                      1       train
# 13                  4            12                      1       train
# 14                 26             6                      6       train
#
#         fold_2  ...                                  prediction_fold_1  \
# 0        train  ...                i`d have responded, if i were going
# 1        train  ...                                                sad
# 2   validation  ...                                     bullying me...
# 3   validation  ...                                     leave me alone
# 4        train  ...                                      sons of ****,
# 5        train  ...  http://www.dothebouncy.com/smf - some shameles...
# 6        train  ...                                            are fun
# 7        train  ...                                         soooo high
# 8   validation  ...                                        both of you
# 9   validation  ...             journey!? wow... u just became cooler.
# 10  validation  ...  as much as i love to be hopeful, i reckon the ...
# 11       train  ...                               i really really like
# 12       train  ...                                        dangerously
# 13       train  ...                                     lost my voice.
# 14       train  ...                         test test from the lg env2
#
#    jaccard_fold_1 start_fold_2  end_fold_2  \
# 0        1.000000            4          13
# 1        0.100000            6           6
# 2        0.400000            7           9
# 3        0.600000            7           9
# 4        0.214286            6           7
# 5        1.000000            4          30
# 6        0.142857           12          12
# 7        1.000000            4           6
# 8        1.000000            4           6
# 9        0.600000            6           7
# 10       1.000000            4          30
# 11       0.300000            7           7
# 12       0.125000            9          10
# 13       0.300000           12          16
# 14       1.000000            4          11
#
#                                     prediction_fold_2 jaccard_fold_2  \
# 0                 i`d have responded, if i were going       1.000000
# 1                                                 sad       0.100000
# 2                                      bullying me...       0.400000
# 3                                      leave me alone       0.600000
# 4                                               ****,       0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...       1.000000
# 6                                                 fun       0.071429
# 7                                          soooo high       1.000000
# 8                                         both of you       1.000000
# 9                                              wow...       0.100000
# 10  as much as i love to be hopeful, i reckon the ...       1.000000
# 11                                               like       0.100000
# 12                                    dangerously low       0.250000
# 13                                   i lost my voice.       0.400000
# 14                         test test from the lg env2       1.000000
#
#     start_fold_3  end_fold_3  \
# 0              4          13
# 1              4           6
# 2              4           9
# 3              7           9
# 4              6           7
# 5              4          30
# 6             11          12
# 7              4           6
# 8              4           6
# 9              4           7
# 10             4          30
# 11             4           7
# 12             9           9
# 13            13          13
# 14             4          11
#
#                                     prediction_fold_3 jaccard_fold_3
# 0                 i`d have responded, if i were going       1.000000
# 1                                            sooo sad       0.200000
# 2                           my boss is bullying me...       1.000000
# 3                                      leave me alone       0.600000
# 4                                               ****,       0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...       1.000000
# 6                                             are fun       0.142857
# 7                                          soooo high       1.000000
# 8                                         both of you       1.000000
# 9                                    journey!? wow...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...       1.000000
# 11                               i really really like       0.300000
# 12                                        dangerously       0.125000
# 13                                               lost       0.100000
# 14                         test test from the lg env2       1.000000
#
# [15 rows x 25 columns]
