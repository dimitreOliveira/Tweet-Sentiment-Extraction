# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 26882
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2 fold_3      fold_4 fold_5  \
# 0                      10       train  validation  train       train  train
# 1                       3  validation       train  train       train  train
# 2                       2       train       train  train  validation  train
# 3                       3       train       train  train  validation  train
# 4                       4       train       train  train  validation  train
#
#    imputed
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.96e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, name="qa_outputs")(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
# Datasets
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_test_dataset(x_test, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices({'input_ids': x_test[0], 'attention_mask': x_test[1]})
    dataset = dataset.batch(batch_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    
    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 188s - loss: 4.6146 - tf_op_layer_Squeeze_loss: 2.2726 - tf_op_layer_Squeeze_1_loss: 2.3420 - val_loss: 3.8393 - val_tf_op_layer_Squeeze_loss: 1.9444 - val_tf_op_layer_Squeeze_1_loss: 1.8949
# Epoch 2/7
# 672/672 - 176s - loss: 3.7726 - tf_op_layer_Squeeze_loss: 1.9030 - tf_op_layer_Squeeze_1_loss: 1.8696 - val_loss: 3.7747 - val_tf_op_layer_Squeeze_loss: 1.9169 - val_tf_op_layer_Squeeze_1_loss: 1.8578
# Epoch 3/7
# 672/672 - 174s - loss: 3.6602 - tf_op_layer_Squeeze_loss: 1.8493 - tf_op_layer_Squeeze_1_loss: 1.8109 - val_loss: 3.7764 - val_tf_op_layer_Squeeze_loss: 1.9169 - val_tf_op_layer_Squeeze_1_loss: 1.8595
# Epoch 4/7
# 672/672 - 176s - loss: 3.6176 - tf_op_layer_Squeeze_loss: 1.8296 - tf_op_layer_Squeeze_1_loss: 1.7880 - val_loss: 3.7733 - val_tf_op_layer_Squeeze_loss: 1.9181 - val_tf_op_layer_Squeeze_1_loss: 1.8553
# Epoch 5/7
# 672/672 - 174s - loss: 3.5974 - tf_op_layer_Squeeze_loss: 1.8189 - tf_op_layer_Squeeze_1_loss: 1.7785 - val_loss: 3.7737 - val_tf_op_layer_Squeeze_loss: 1.9172 - val_tf_op_layer_Squeeze_1_loss: 1.8565
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 175s - loss: 3.5925 - tf_op_layer_Squeeze_loss: 1.8173 - tf_op_layer_Squeeze_1_loss: 1.7752 - val_loss: 3.7805 - val_tf_op_layer_Squeeze_loss: 1.9210 - val_tf_op_layer_Squeeze_1_loss: 1.8594
# Epoch 00006: early stopping
#
# FOLD: 2
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 189s - loss: 4.6023 - tf_op_layer_Squeeze_2_loss: 2.2677 - tf_op_layer_Squeeze_3_loss: 2.3346 - val_loss: 3.8129 - val_tf_op_layer_Squeeze_2_loss: 1.9266 - val_tf_op_layer_Squeeze_3_loss: 1.8863
# Epoch 2/7
# 672/672 - 176s - loss: 3.7539 - tf_op_layer_Squeeze_2_loss: 1.8985 - tf_op_layer_Squeeze_3_loss: 1.8554 - val_loss: 3.7510 - val_tf_op_layer_Squeeze_2_loss: 1.8972 - val_tf_op_layer_Squeeze_3_loss: 1.8538
# Epoch 3/7
# 672/672 - 174s - loss: 3.6494 - tf_op_layer_Squeeze_2_loss: 1.8466 - tf_op_layer_Squeeze_3_loss: 1.8028 - val_loss: 3.7629 - val_tf_op_layer_Squeeze_2_loss: 1.9043 - val_tf_op_layer_Squeeze_3_loss: 1.8586
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 175s - loss: 3.5959 - tf_op_layer_Squeeze_2_loss: 1.8208 - tf_op_layer_Squeeze_3_loss: 1.7751 - val_loss: 3.7701 - val_tf_op_layer_Squeeze_2_loss: 1.9083 - val_tf_op_layer_Squeeze_3_loss: 1.8618
# Epoch 00004: early stopping
#
# FOLD: 3
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 187s - loss: 4.6451 - tf_op_layer_Squeeze_4_loss: 2.2608 - tf_op_layer_Squeeze_5_loss: 2.3843 - val_loss: 3.8456 - val_tf_op_layer_Squeeze_4_loss: 1.9289 - val_tf_op_layer_Squeeze_5_loss: 1.9167
# Epoch 2/7
# 672/672 - 176s - loss: 3.8706 - tf_op_layer_Squeeze_4_loss: 1.9207 - tf_op_layer_Squeeze_5_loss: 1.9498 - val_loss: 3.8271 - val_tf_op_layer_Squeeze_4_loss: 1.9066 - val_tf_op_layer_Squeeze_5_loss: 1.9205
# Epoch 3/7
# 672/672 - 176s - loss: 3.7683 - tf_op_layer_Squeeze_4_loss: 1.8811 - tf_op_layer_Squeeze_5_loss: 1.8873 - val_loss: 3.8052 - val_tf_op_layer_Squeeze_4_loss: 1.9000 - val_tf_op_layer_Squeeze_5_loss: 1.9051
# Epoch 4/7
# 672/672 - 176s - loss: 3.7079 - tf_op_layer_Squeeze_4_loss: 1.8586 - tf_op_layer_Squeeze_5_loss: 1.8493 - val_loss: 3.7839 - val_tf_op_layer_Squeeze_4_loss: 1.9039 - val_tf_op_layer_Squeeze_5_loss: 1.8800
# Epoch 5/7
# 672/672 - 174s - loss: 3.6755 - tf_op_layer_Squeeze_4_loss: 1.8473 - tf_op_layer_Squeeze_5_loss: 1.8282 - val_loss: 3.7855 - val_tf_op_layer_Squeeze_4_loss: 1.9029 - val_tf_op_layer_Squeeze_5_loss: 1.8826
# Epoch 6/7
# 672/672 - 176s - loss: 3.6854 - tf_op_layer_Squeeze_4_loss: 1.8499 - tf_op_layer_Squeeze_5_loss: 1.8355 - val_loss: 3.7788 - val_tf_op_layer_Squeeze_4_loss: 1.9022 - val_tf_op_layer_Squeeze_5_loss: 1.8766
# Epoch 7/7
# 672/672 - 174s - loss: 3.6750 - tf_op_layer_Squeeze_4_loss: 1.8440 - tf_op_layer_Squeeze_5_loss: 1.8310 - val_loss: 3.7804 - val_tf_op_layer_Squeeze_4_loss: 1.9035 - val_tf_op_layer_Squeeze_5_loss: 1.8770
#
# FOLD: 4
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 188s - loss: 4.6332 - tf_op_layer_Squeeze_6_loss: 2.2884 - tf_op_layer_Squeeze_7_loss: 2.3448 - val_loss: 3.8128 - val_tf_op_layer_Squeeze_6_loss: 1.9309 - val_tf_op_layer_Squeeze_7_loss: 1.8819
# Epoch 2/7
# 672/672 - 176s - loss: 3.7711 - tf_op_layer_Squeeze_6_loss: 1.9087 - tf_op_layer_Squeeze_7_loss: 1.8625 - val_loss: 3.7423 - val_tf_op_layer_Squeeze_6_loss: 1.8902 - val_tf_op_layer_Squeeze_7_loss: 1.8520
# Epoch 3/7
# 672/672 - 174s - loss: 3.6680 - tf_op_layer_Squeeze_6_loss: 1.8551 - tf_op_layer_Squeeze_7_loss: 1.8129 - val_loss: 3.7423 - val_tf_op_layer_Squeeze_6_loss: 1.8864 - val_tf_op_layer_Squeeze_7_loss: 1.8559
# Epoch 4/7
# 672/672 - 176s - loss: 3.6253 - tf_op_layer_Squeeze_6_loss: 1.8388 - tf_op_layer_Squeeze_7_loss: 1.7864 - val_loss: 3.7372 - val_tf_op_layer_Squeeze_6_loss: 1.8855 - val_tf_op_layer_Squeeze_7_loss: 1.8517
# Epoch 5/7
# 672/672 - 174s - loss: 3.5991 - tf_op_layer_Squeeze_6_loss: 1.8219 - tf_op_layer_Squeeze_7_loss: 1.7771 - val_loss: 3.7448 - val_tf_op_layer_Squeeze_6_loss: 1.8906 - val_tf_op_layer_Squeeze_7_loss: 1.8542
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 174s - loss: 3.5923 - tf_op_layer_Squeeze_6_loss: 1.8204 - tf_op_layer_Squeeze_7_loss: 1.7719 - val_loss: 3.7409 - val_tf_op_layer_Squeeze_6_loss: 1.8908 - val_tf_op_layer_Squeeze_7_loss: 1.8501
# Epoch 00006: early stopping
#
# FOLD: 5
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 187s - loss: 4.6321 - tf_op_layer_Squeeze_8_loss: 2.2738 - tf_op_layer_Squeeze_9_loss: 2.3583 - val_loss: 3.8912 - val_tf_op_layer_Squeeze_8_loss: 1.9372 - val_tf_op_layer_Squeeze_9_loss: 1.9540
# Epoch 2/7
# 672/672 - 176s - loss: 3.8103 - tf_op_layer_Squeeze_8_loss: 1.9125 - tf_op_layer_Squeeze_9_loss: 1.8978 - val_loss: 3.7659 - val_tf_op_layer_Squeeze_8_loss: 1.8898 - val_tf_op_layer_Squeeze_9_loss: 1.8760
# Epoch 3/7
# 672/672 - 174s - loss: 3.7112 - tf_op_layer_Squeeze_8_loss: 1.8625 - tf_op_layer_Squeeze_9_loss: 1.8487 - val_loss: 3.7812 - val_tf_op_layer_Squeeze_8_loss: 1.8907 - val_tf_op_layer_Squeeze_9_loss: 1.8905
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 174s - loss: 3.6650 - tf_op_layer_Squeeze_8_loss: 1.8409 - tf_op_layer_Squeeze_9_loss: 1.8241 - val_loss: 3.7659 - val_tf_op_layer_Squeeze_8_loss: 1.8903 - val_tf_op_layer_Squeeze_9_loss: 1.8756
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col10 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_c9caacfa_a3b1_11ea_a056_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              10                      10  1.000000      1.000000
# 1              13                       3  0.200000      0.900000
# 2               6                       2  0.166667      0.333333
# 3               6                       3  0.600000      1.000000
# 4              17                       4  0.214286      1.000000
# 5              27                      27  1.000000      0.966667
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              19                       7  0.500000      0.680000
# 10             27                      27  1.000000      1.000000
# 11             12                       1  0.100000      0.466667
# 12              9                       1  0.125000      0.400000
# 13             13                       1  0.100000      0.866667
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_2  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_3  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_4  \
# 0                 i`d have responded, if i were going
# 1                                            sooo sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_5
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                             dangerously low on ink
# 13                                               lost
# 14                         test test from the lg env2
