# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-split/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-split/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-split/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-split/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-split/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean-split/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 27375
#        textID                                               text  \
# 0  cb774db0d1              i`d have responded ,  if i were going
# 1  549e992a42  sooo sad i will miss you here in san diego !  ...
# 2  088c60f138                    my boss is bullying me .  .  .
# 3  9642c003ef                   what interview !  leave me alone
# 4  358bd9e861  sons of  *  *  *  *  ,  why couldn`t they put ...
#
#                            selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded ,  if i were going   neutral  1.000000        37
# 1                               sooo sad  negative  0.181818        51
# 2                            bullying me  negative  0.333333        31
# 3                         leave me alone  negative  0.500000        32
# 4                sons of  *  *  *  *  ,   negative  0.266667        84
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             9             11                 37                      9
# 1            16             18                  8                      2
# 2            11             11                 11                      2
# 3             7              7                 14                      3
# 4            24             26                 23                     13
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3 fold_4  \
# 0                      11       train  validation       train  train
# 1                       3       train       train  validation  train
# 2                       2  validation       train       train  train
# 3                       3  validation       train       train  train
# 4                      13       train       train       train  train
#
#        fold_5  imputed
# 0       train    False
# 1       train    False
# 2       train    False
# 3       train    False
# 4  validation    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 1,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]

    x = layers.Dropout(.1)(h11)
    
    start_logits = layers.Dense(1, name="start_logit", use_bias=False)(x)
    start_logits = layers.Flatten()(start_logits)

    end_logits = layers.Dense(1, name="end_logit", use_bias=False)(x)
    end_logits = layers.Flatten()(end_logits)
    

    start_probs = layers.Activation('softmax', name='y_start')(start_logits)
    end_probs = layers.Activation('softmax', name='y_end')(end_logits)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_probs, end_probs])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()})
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 684 steps, validate for 171 steps
# Epoch 1/7
# 684/684 - 179s - loss: 2.8319 - y_start_loss: 1.3794 - y_end_loss: 1.4525 - val_loss: 1.7144 - val_y_start_loss: 0.8451 - val_y_end_loss: 0.8693
# Epoch 2/7
# 684/684 - 166s - loss: 1.6750 - y_start_loss: 0.8416 - y_end_loss: 0.8334 - val_loss: 1.6331 - val_y_start_loss: 0.8109 - val_y_end_loss: 0.8222
# Epoch 3/7
# 684/684 - 165s - loss: 1.4965 - y_start_loss: 0.7596 - y_end_loss: 0.7369 - val_loss: 1.6490 - val_y_start_loss: 0.8173 - val_y_end_loss: 0.8317
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 684/684 - 165s - loss: 1.3778 - y_start_loss: 0.7035 - y_end_loss: 0.6744 - val_loss: 1.6859 - val_y_start_loss: 0.8361 - val_y_end_loss: 0.8498
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_172e4a60_a349_11ea_a892_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row7_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row7_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row7_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row7_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row7_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row8_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row8_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row8_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row8_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row8_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row9_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row9_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row9_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row9_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row9_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row10_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row10_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row10_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row10_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row10_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row11_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row11_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row11_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row11_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row11_col4 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row12_col0 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row12_col1 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row12_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row12_col3 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row12_col4 {
#             color:  green;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row13_col0 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row13_col1 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row13_col2 {
#             color:  red;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row13_col3 {
#             color:  black;
#         }    #T_172e4a60_a349_11ea_a892_0242ac130202row13_col4 {
#             color:  black;
#         }</style><table id="T_172e4a60_a349_11ea_a892_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_172e4a60_a349_11ea_a892_0242ac130202level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_172e4a60_a349_11ea_a892_0242ac130202row0_col0" class="data row0 col0" >0.756152</td>
#                         <td id="T_172e4a60_a349_11ea_a892_0242ac130202row0_col1" class="data row0 col1" >0.723301</td>
#                         <td id="T_172e4a60_a349_11ea_a892_0242ac130202row0_col2" class="data row0 col2" >0.032851</td>
#                         <td id="T_172e4a60_a349_11ea_a892_0242ac130202row0_col3" class="data row0 col3" >0.756152</td>
#                         <td id="T_172e4a60_a349_11ea_a892_0242ac130202row0_col4" class="data row0 col4" >0.723301</td>
#             </tr>
#             <tr>
#                         <th id="T_172e4a60_a349_11ea_a892_0242ac130202level0_row1" class="row_heading level0 row1" >Sentiment negative</th>
#                         <td id=

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0               i`d have responded ,  if i were going
# 1   sooo sad i will miss you here in san diego !  ...
# 2                     my boss is bullying me .  .  .
# 3                    what interview !  leave me alone
# 4   sons of  *  *  *  *  ,  why couldn`t they put ...
# 5   http :  /  / www . dothebouncy . com / smf  - ...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey !  ?  wow .  .  .  u just became coole...
# 10  as much as i love to be hopeful ,  i reckon th...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0               i`d have responded ,  if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                             sons of  *  *  *  *  ,   negative
# 5   http :  /  / www . dothebouncy . com / smf  - ...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                wow .  .  .  u just became cooler .   positive
# 10  as much as i love to be hopeful ,  i reckon th...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              11                      11  1.000000      1.000000
# 1              18                       3  0.181818      0.500000
# 2              11                       2  0.333333      0.666667
# 3               7                       3  0.500000      1.000000
# 4              26                      13  0.266667      1.000000
# 5              33                      33  1.000000      1.000000
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              38                      13  0.400000      1.000000
# 10             29                      29  1.000000      1.000000
# 11             12                       1  0.100000      0.333333
# 12              9                       1  0.125000      0.250000
# 13             14                       1  0.090909      0.250000
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1
# 0               i`d have responded ,  if i were going
# 1                                                 sad
# 2                                bullying me .  .  .
# 3                                      leave me alone
# 4                             sons of  *  *  *  *  ,
# 5   http :  /  / www . dothebouncy . com / smf  - ...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                wow .  .  .  u just became cooler .
# 10  as much as i love to be hopeful ,  i reckon th...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                   lost my voice .
# 14                         test test from the lg env2
