# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 5,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 1,
  'question_size': 4,
  'N_FOLDS': 5,
  'smooth_factor': .5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
import scipy
dist = [pow(config['smooth_factor'], i) for i in range(1, config['MAX_LEN'])]

def smooth_labels_dist_start(y, dist=dist):
    center = y.argmax()
    y[center+1:] = dist[1:len(y[center:])]
    y[:center] = dist[::-1][-len(y[:center]):]
    # Re-scale
    y = y / np.sum(y)
    
    return y

def smooth_labels_dist_end(y, dist=dist):
    center = y.argmax()
    y[center+1:] = dist[:len(y[center+1:])]
    y[:center] = dist[:0:-1][-len(y[:center]):]
    # Re-scale
    y = y / np.sum(y)
    
    return y

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    # Apply custom smoothing
    np.apply_along_axis(smooth_labels_dist_start, -1, y_train[0])
    np.apply_along_axis(smooth_labels_dist_end, -1, y_train[1])
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0])
                loss_end = loss_fn_end(y['y_end'], probabilities[1])
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_acc_start.update_state(y['y_start'], probabilities)
            train_acc_end.update_state(y['y_end'], probabilities)
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_acc_start.update_state(y['y_start'], probabilities)
            valid_acc_end.update_state(y['y_end'], probabilities)
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32)//step_size))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy

    train_acc_start = metrics.CategoricalAccuracy()
    valid_acc_start = metrics.CategoricalAccuracy()
    train_acc_end = metrics.CategoricalAccuracy()
    valid_acc_end = metrics.CategoricalAccuracy()
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'acc_start': train_acc_start, 'acc_end': train_acc_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end, 
                    'val_acc_start': valid_acc_start, 'val_acc_end': valid_acc_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], model_path)
    
    history_list.append(history)
    model.load_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 283.3s loss: 2.1145 loss_start: 1.0687 loss_end: 1.0458 acc_start: 0.3818 acc_end: 0.3914 val_loss: 1.6115 val_loss_start: 0.8319 val_loss_end: 0.7796 val_acc_start: 0.4235 val_acc_end: 0.4255
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/5
# time: 267.2s loss: 1.5517 loss_start: 0.8032 loss_end: 0.7484 acc_start: 0.4237 acc_end: 0.4328 val_loss: 1.5457 val_loss_start: 0.8167 val_loss_end: 0.7290 val_acc_start: 0.4322 val_acc_end: 0.4487
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/5
# time: 267.8s loss: 1.3854 loss_start: 0.7240 loss_end: 0.6614 acc_start: 0.4382 acc_end: 0.4489 val_loss: 1.5732 val_loss_start: 0.8212 val_loss_end: 0.7520 val_acc_start: 0.4297 val_acc_end: 0.4258
# Epoch 00003: early stopping
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 281.3s loss: 2.1198 loss_start: 1.0404 loss_end: 1.0794 acc_start: 0.3872 acc_end: 0.3883 val_loss: 1.7466 val_loss_start: 0.8804 val_loss_end: 0.8662 val_acc_start: 0.3889 val_acc_end: 0.3949
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/5
# time: 266.9s loss: 1.5600 loss_start: 0.8019 loss_end: 0.7581 acc_start: 0.4274 acc_end: 0.4362 val_loss: 1.6280 val_loss_start: 0.8554 val_loss_end: 0.7726 val_acc_start: 0.4288 val_acc_end: 0.4444
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 3/5
# time: 267.3s loss: 1.4292 loss_start: 0.7411 loss_end: 0.6881 acc_start: 0.4384 acc_end: 0.4464 val_loss: 1.6477 val_loss_start: 0.8601 val_loss_end: 0.7876 val_acc_start: 0.4207 val_acc_end: 0.4225
# Epoch 00003: early stopping
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 281.7s loss: 2.1900 loss_start: 1.0804 loss_end: 1.1095 acc_start: 0.3780 acc_end: 0.3800 val_loss: 1.7386 val_loss_start: 0.8468 val_loss_end: 0.8918 val_acc_start: 0.3819 val_acc_end: 0.3959
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/5
# time: 267.1s loss: 1.5914 loss_start: 0.8308 loss_end: 0.7606 acc_start: 0.4176 acc_end: 0.4306 val_loss: 1.5661 val_loss_start: 0.8101 val_loss_end: 0.7561 val_acc_start: 0.4190 val_acc_end: 0.4342
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/5
# time: 267.5s loss: 1.4230 loss_start: 0.7456 loss_end: 0.6774 acc_start: 0.4322 acc_end: 0.4422 val_loss: 1.5397 val_loss_start: 0.8133 val_loss_end: 0.7263 val_acc_start: 0.4297 val_acc_end: 0.4342
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 4/5
# time: 267.3s loss: 1.3391 loss_start: 0.7031 loss_end: 0.6360 acc_start: 0.4400 acc_end: 0.4516 val_loss: 1.5903 val_loss_start: 0.8265 val_loss_end: 0.7637 val_acc_start: 0.4269 val_acc_end: 0.4341
# Epoch 00004: early stopping
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 280.1s loss: 2.1516 loss_start: 1.0626 loss_end: 1.0890 acc_start: 0.3862 acc_end: 0.3853 val_loss: 1.6543 val_loss_start: 0.8625 val_loss_end: 0.7918 val_acc_start: 0.4302 val_acc_end: 0.4308
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/5
# time: 266.3s loss: 1.5871 loss_start: 0.8161 loss_end: 0.7710 acc_start: 0.4244 acc_end: 0.4330 val_loss: 1.6121 val_loss_start: 0.8366 val_loss_end: 0.7754 val_acc_start: 0.4121 val_acc_end: 0.4189
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 3/5
# time: 266.6s loss: 1.4531 loss_start: 0.7543 loss_end: 0.6987 acc_start: 0.4336 acc_end: 0.4425 val_loss: 1.6025 val_loss_start: 0.8457 val_loss_end: 0.7569 val_acc_start: 0.4279 val_acc_end: 0.4190
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 4/5
# time: 266.6s loss: 1.3690 loss_start: 0.7095 loss_end: 0.6595 acc_start: 0.4429 acc_end: 0.4490 val_loss: 1.5885 val_loss_start: 0.8495 val_loss_end: 0.7390 val_acc_start: 0.4266 val_acc_end: 0.4387
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 5/5
# time: 266.3s loss: 1.3157 loss_start: 0.6838 loss_end: 0.6319 acc_start: 0.4481 acc_end: 0.4556 val_loss: 1.5965 val_loss_start: 0.8357 val_loss_end: 0.7608 val_acc_start: 0.4296 val_acc_end: 0.4301
# Training finished saved model weights at "model_fold_4.h5"
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 281.1s loss: 2.1610 loss_start: 1.0659 loss_end: 1.0950 acc_start: 0.3871 acc_end: 0.3822 val_loss: 1.7057 val_loss_start: 0.8428 val_loss_end: 0.8629 val_acc_start: 0.4298 val_acc_end: 0.4202
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/5
# time: 266.8s loss: 1.6123 loss_start: 0.8193 loss_end: 0.7930 acc_start: 0.4258 acc_end: 0.4294 val_loss: 1.5918 val_loss_start: 0.8096 val_loss_end: 0.7822 val_acc_start: 0.4200 val_acc_end: 0.4303
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 3/5
# time: 267.0s loss: 1.4463 loss_start: 0.7493 loss_end: 0.6970 acc_start: 0.4353 acc_end: 0.4432 val_loss: 1.6151 val_loss_start: 0.8367 val_loss_end: 0.7784 val_acc_start: 0.4211 val_acc_end: 0.4282
# Epoch 00003: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_025ffa80_9312_11ea_b9f8_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
