# %%
# !nvidia-smi
# Out:
# Mon May 25 12:47:56 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 4.6MB/s
#      |████████████████████████████████| 3.8MB 24.1MB/s
#      |████████████████████████████████| 1.1MB 43.7MB/s
#      |████████████████████████████████| 890kB 60.0MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/195-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 3,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size * 1
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.95e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]
    
    x = layers.Dropout(.1)(h11)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    # Make predictions (best model)
    model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 165s - loss: 4.9356 - y_start_loss: 2.3945 - y_end_loss: 2.5412 - val_loss: 3.8688 - val_y_start_loss: 1.9580 - val_y_end_loss: 1.9107
# Epoch 2/7
# 687/687 - 165s - loss: 3.8640 - y_start_loss: 1.9454 - y_end_loss: 1.9187 - val_loss: 3.7872 - val_y_start_loss: 1.9248 - val_y_end_loss: 1.8624
# Epoch 3/7
# 687/687 - 164s - loss: 3.7192 - y_start_loss: 1.8768 - y_end_loss: 1.8423 - val_loss: 3.7725 - val_y_start_loss: 1.9113 - val_y_end_loss: 1.8611
# Epoch 4/7
# 687/687 - 164s - loss: 3.6420 - y_start_loss: 1.8437 - y_end_loss: 1.7983 - val_loss: 3.7713 - val_y_start_loss: 1.9099 - val_y_end_loss: 1.8614
# Epoch 5/7
# 687/687 - 165s - loss: 3.5920 - y_start_loss: 1.8167 - y_end_loss: 1.7753 - val_loss: 3.7619 - val_y_start_loss: 1.9065 - val_y_end_loss: 1.8554
# Epoch 6/7
# 687/687 - 161s - loss: 3.5648 - y_start_loss: 1.8054 - y_end_loss: 1.7594 - val_loss: 3.7835 - val_y_start_loss: 1.9099 - val_y_end_loss: 1.8737
# Epoch 7/7
# 687/687 - 161s - loss: 3.5503 - y_start_loss: 1.7962 - y_end_loss: 1.7541 - val_loss: 3.7952 - val_y_start_loss: 1.9208 - val_y_end_loss: 1.8744
#
# FOLD: 2
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 165s - loss: 4.7686 - y_start_loss: 2.3536 - y_end_loss: 2.4149 - val_loss: 3.9271 - val_y_start_loss: 1.9799 - val_y_end_loss: 1.9471
# Epoch 2/7
# 687/687 - 165s - loss: 3.8183 - y_start_loss: 1.9329 - y_end_loss: 1.8854 - val_loss: 3.8167 - val_y_start_loss: 1.9348 - val_y_end_loss: 1.8819
# Epoch 3/7
# 687/687 - 165s - loss: 3.6872 - y_start_loss: 1.8682 - y_end_loss: 1.8190 - val_loss: 3.8033 - val_y_start_loss: 1.9177 - val_y_end_loss: 1.8856
# Epoch 4/7
# 687/687 - 162s - loss: 3.6031 - y_start_loss: 1.8263 - y_end_loss: 1.7768 - val_loss: 3.8205 - val_y_start_loss: 1.9294 - val_y_end_loss: 1.8910
# Epoch 5/7
# 687/687 - 162s - loss: 3.5592 - y_start_loss: 1.8062 - y_end_loss: 1.7530 - val_loss: 3.8218 - val_y_start_loss: 1.9338 - val_y_end_loss: 1.8880
# Epoch 6/7
# 687/687 - 161s - loss: 3.5211 - y_start_loss: 1.7849 - y_end_loss: 1.7362 - val_loss: 3.8416 - val_y_start_loss: 1.9380 - val_y_end_loss: 1.9035
# Epoch 00006: early stopping
#
# FOLD: 3
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 164s - loss: 4.8777 - y_start_loss: 2.4102 - y_end_loss: 2.4675 - val_loss: 3.9320 - val_y_start_loss: 1.9648 - val_y_end_loss: 1.9672
# Epoch 2/7
# 687/687 - 164s - loss: 3.8753 - y_start_loss: 1.9721 - y_end_loss: 1.9032 - val_loss: 3.7653 - val_y_start_loss: 1.8988 - val_y_end_loss: 1.8665
# Epoch 3/7
# 687/687 - 165s - loss: 3.7269 - y_start_loss: 1.8956 - y_end_loss: 1.8313 - val_loss: 3.7551 - val_y_start_loss: 1.8982 - val_y_end_loss: 1.8568
# Epoch 4/7
# 687/687 - 165s - loss: 3.6607 - y_start_loss: 1.8600 - y_end_loss: 1.8007 - val_loss: 3.7550 - val_y_start_loss: 1.8893 - val_y_end_loss: 1.8657
# Epoch 5/7
# 687/687 - 161s - loss: 3.6090 - y_start_loss: 1.8340 - y_end_loss: 1.7751 - val_loss: 3.7749 - val_y_start_loss: 1.9053 - val_y_end_loss: 1.8697
# Epoch 6/7
# 687/687 - 161s - loss: 3.5898 - y_start_loss: 1.8231 - y_end_loss: 1.7667 - val_loss: 3.7731 - val_y_start_loss: 1.9083 - val_y_end_loss: 1.8648
# Epoch 7/7
# 687/687 - 161s - loss: 3.5727 - y_start_loss: 1.8144 - y_end_loss: 1.7583 - val_loss: 3.7598 - val_y_start_loss: 1.8955 - val_y_end_loss: 1.8643
# Epoch 00007: early stopping
#
# FOLD: 4
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 164s - loss: 4.9776 - y_start_loss: 2.4085 - y_end_loss: 2.5691 - val_loss: 3.9325 - val_y_start_loss: 1.9959 - val_y_end_loss: 1.9366
# Epoch 2/7
# 687/687 - 164s - loss: 3.9210 - y_start_loss: 1.9664 - y_end_loss: 1.9546 - val_loss: 3.8302 - val_y_start_loss: 1.9461 - val_y_end_loss: 1.8841
# Epoch 3/7
# 687/687 - 164s - loss: 3.7584 - y_start_loss: 1.8950 - y_end_loss: 1.8634 - val_loss: 3.7926 - val_y_start_loss: 1.9291 - val_y_end_loss: 1.8636
# Epoch 4/7
# 687/687 - 164s - loss: 3.6833 - y_start_loss: 1.8572 - y_end_loss: 1.8261 - val_loss: 3.7834 - val_y_start_loss: 1.9254 - val_y_end_loss: 1.8580
# Epoch 5/7
# 687/687 - 161s - loss: 3.6297 - y_start_loss: 1.8344 - y_end_loss: 1.7952 - val_loss: 3.8010 - val_y_start_loss: 1.9351 - val_y_end_loss: 1.8659
# Epoch 6/7
# 687/687 - 161s - loss: 3.6070 - y_start_loss: 1.8214 - y_end_loss: 1.7857 - val_loss: 3.8053 - val_y_start_loss: 1.9368 - val_y_end_loss: 1.8686
# Epoch 7/7
# 687/687 - 161s - loss: 3.5927 - y_start_loss: 1.8167 - y_end_loss: 1.7761 - val_loss: 3.8007 - val_y_start_loss: 1.9280 - val_y_end_loss: 1.8726
# Epoch 00007: early stopping
#
# FOLD: 5
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 164s - loss: 4.8326 - y_start_loss: 2.3672 - y_end_loss: 2.4654 - val_loss: 3.8866 - val_y_start_loss: 1.9447 - val_y_end_loss: 1.9418
# Epoch 2/7
# 687/687 - 165s - loss: 3.8575 - y_start_loss: 1.9459 - y_end_loss: 1.9116 - val_loss: 3.7812 - val_y_start_loss: 1.9076 - val_y_end_loss: 1.8736
# Epoch 3/7
# 687/687 - 161s - loss: 3.7159 - y_start_loss: 1.8785 - y_end_loss: 1.8373 - val_loss: 3.7840 - val_y_start_loss: 1.9216 - val_y_end_loss: 1.8625
# Epoch 4/7
# 687/687 - 161s - loss: 3.6317 - y_start_loss: 1.8372 - y_end_loss: 1.7945 - val_loss: 3.8131 - val_y_start_loss: 1.9344 - val_y_end_loss: 1.8788
# Epoch 5/7
# 687/687 - 161s - loss: 3.5895 - y_start_loss: 1.8168 - y_end_loss: 1.7727 - val_loss: 3.8056 - val_y_start_loss: 1.9322 - val_y_end_loss: 1.8734
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_d1ba610c_9e94_11ea_a227_0242ac1c0002row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_d4025104_9e94_11ea_a227_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       0.333333
# 12       my sharpie is running dangerously low on ink  ...       0.250000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 17 columns]
