# %% [markdown]
# ## Dependencies

# %%
import os, random, warnings
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from transformers import TFDistilBertModel
from tokenizers import BertWordPieceTokenizer
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, Concatenate

def seed_everything(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %%
# Auxiliary functions
def plot_metrics(history, metric_list):
    fig, axes = plt.subplots(len(metric_list), 1, sharex='col', figsize=(20, len(metric_list) * 5))
    axes = axes.flatten()
    
    for index, metric in enumerate(metric_list):
        axes[index].plot(history[metric], label='Train %s' % metric)
        axes[index].plot(history['val_%s' % metric], label='Validation %s' % metric)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric)

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

def evaluate_model(train_set, validation_set):
    train_set['jaccard'] = train_set.apply(lambda x: jaccard(x['selected_text'], x['prediction']), axis=1)
    validation_set['jaccard'] = validation_set.apply(lambda x: jaccard(x['selected_text'], x['prediction']), axis=1)

    print('Train set Jaccard: %.3f' % train_set['jaccard'].mean())
    print('Validation set Jaccard: %.3f' % validation_set['jaccard'].mean())

    print('\nMetric by sentiment')
    for sentiment in train_df['sentiment'].unique():
        print('\nSentiment == %s' % sentiment)
        print('Train set Jaccard: %.3f' % train_set[train_set['sentiment'] == sentiment]['jaccard'].mean())
        print('Validation set Jaccard: %.3f' % validation_set[validation_set['sentiment'] == sentiment]['jaccard'].mean())
        
# Transformer inputs
def get_start_end(text, selected_text, offsets, max_seq_len):
    # find the intersection between text and selected text
    idx_start, idx_end = None, None
    for index in (i for i, c in enumerate(text) if c == selected_text[0]):
        if text[index:index + len(selected_text)] == selected_text:
            idx_start = index
            idx_end = index + len(selected_text)
            break
    
    intersection = [0] * len(text)
    if idx_start != None and idx_end != None:
        for char_idx in range(idx_start, idx_end):
            intersection[char_idx] = 1
            
            
    targets = np.zeros(len(offsets))
    for i, (o1, o2) in enumerate(offsets):
        if sum(intersection[o1:o2]) > 0:
            targets[i] = 1
            
    # OHE targets
    target_start = np.zeros(len(offsets))
    target_end = np.zeros(len(offsets))
    targets_nonzero = np.nonzero(targets)[0]
    if len(targets_nonzero) > 0: 
        target_start[targets_nonzero[0]] = 1
        target_end[targets_nonzero[-1]] = 1
    
    return target_start, target_end

def preprocess(text, selected_text, context, tokenizer, max_seq_len):
    context_encoded = tokenizer.encode(context)
    context_encoded = context_encoded.ids[1:-1]
    
    encoded = tokenizer.encode(text)
    encoded.pad(max_seq_len)
    encoded.truncate(max_seq_len)
    input_ids = encoded.ids
    offsets = encoded.offsets
    attention_mask = encoded.attention_mask
    token_type_ids = ([0] * 3) + ([1] * (max_seq_len - 3))
    
    input_ids = [101] + context_encoded + [102] + input_ids
    # update input ids and attentions masks size
    input_ids = input_ids[:-3]
    attention_mask = [1] * 3 + attention_mask[:-3]
    
    target_start, target_end = get_start_end(text, selected_text, offsets, max_seq_len)
    
    x = [np.asarray(input_ids, dtype=np.int32), 
         np.asarray(attention_mask, dtype=np.int32), 
         np.asarray(token_type_ids, dtype=np.int32)]
    
    y = [np.asarray(target_start, dtype=np.int32), 
         np.asarray(target_end, dtype=np.int32)]
    
    
    return (x, y)

def get_data(df, tokenizer, MAX_LEN):
    x_input_ids = []
    x_attention_masks = []
    x_token_type_ids = []
    y_start = []
    y_end = []
    for row in df.itertuples(): 
        x, y = preprocess(getattr(row, "text"), getattr(row, "selected_text"), getattr(row, "sentiment"), tokenizer, MAX_LEN)
        x_input_ids.append(x[0])
        x_attention_masks.append(x[1])
        x_token_type_ids.append(x[2])

        y_start.append(y[0])
        y_end.append(y[1])

    x_train = [np.asarray(x_input_ids), np.asarray(x_attention_masks), np.asarray(x_token_type_ids)]
    y_train = [np.asarray(y_start), np.asarray(y_end)]
    return x_train, y_train

def decode(pred_start, pred_end, text, tokenizer):
    offset = tokenizer.encode(text).offsets
    
    if pred_end >= len(offset):
        pred_end = len(offset)-1
        
    decoded_text = ""
    for i in range(pred_start, pred_end+1):
        decoded_text += text[offset[i][0]:offset[i][1]]
        if (i+1) < len(offset) and offset[i][1] < offset[i+1][0]:
            decoded_text += " "
    return decoded_text

# %% [markdown]
# # Load data

# %%
train_df = pd.read_csv('/kaggle/input/tweet-sentiment-extraction/train.csv')

print('Train samples: %s' % len(train_df))
display(train_df.head())
# Out:
# Train samples: 27486
#        textID                                               text  \
# 0  a3d0a7d5ad  Spent the entire morning in a meeting w/ a ven...
# 1  251b6a6766      Oh! Good idea about putting them on ice cream
# 2  c9e8d1ef1c  says good (or should i say bad?) afternoon!  h...
# 3  f14f087215         i dont think you can vote anymore! i tried
# 4  bf7473b12d             haha better drunken tweeting you mean?
#
#                                  selected_text sentiment
# 0  my boss was not happy w/ them. Lots of fun.   neutral
# 1                                         Good  positive
# 2  says good (or should i say bad?) afternoon!   neutral
# 3           i dont think you can vote anymore!  negative
# 4                                       better  positive

# %% [markdown]
# # Pre process

# %%
train_df['text'].fillna('', inplace=True)
train_df['selected_text'].fillna('', inplace=True)
train_df["text"] = train_df["text"].apply(lambda x: x.lower())
train_df["selected_text"] = train_df["selected_text"].apply(lambda x: x.lower())

train_df['text'] = train_df['text'].astype(str)
train_df['selected_text'] = train_df['selected_text'].astype(str)

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 128
BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 1e-5
ES_PATIENCE = 3

base_path = '/kaggle/input/qa-transformers/distilbert/'
base_model_path = base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5'
config_path = base_path + 'distilbert-base-uncased-distilled-squad-config.json'
vocab_path = base_path + 'bert-large-uncased-vocab.txt'
model_path = 'model.h5'
log_path = './'

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(vocab_path, lowercase=True)
tokenizer.save('./')
# Out:
# ['./vocab.txt']

# %% [markdown]
# # Train/validation split

# %%
train, validation = train_test_split(train_df, test_size=0.2, random_state=SEED)

x_train, y_train = get_data(train, tokenizer, MAX_LEN)
x_valid, y_valid = get_data(validation, tokenizer, MAX_LEN)

print('Train set size: %s' % len(x_train[0]))
print('Validation set size: %s' % len(x_valid[0]))
# Out:
# Train set size: 21988
# Validation set size: 5498

# %% [markdown]
# # Model

# %%
def model_fn():
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(base_model_path, config=config_path, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='sigmoid', name='y_start')(x)
    y_end = Dense(MAX_LEN, activation='sigmoid', name='y_end')(x)
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

model = model_fn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir=log_path)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)

history = model.fit(x_train, y_train,
                    validation_data=(x_valid, y_valid),
                    callbacks=[es, tb_callback],
                    epochs=EPOCHS, 
                    verbose=1).history

model.save_weights(model_path)
# Out:
# Train on 21988 samples, validate on 5498 samples
# Epoch 1/20
# 21988/21988 [==============================] - 192s 9ms/sample - loss: 0.3037 - y_start_loss: 0.1425 - y_end_loss: 0.1610 - y_start_categorical_accuracy: 0.5302 - y_end_categorical_accuracy: 0.0412 - val_loss: 0.1278 - val_y_start_loss: 0.0564 - val_y_end_loss: 0.0714 - val_y_start_categorical_accuracy: 0.5828 - val_y_end_categorical_accuracy: 0.0498
# Epoch 2/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0970 - y_start_loss: 0.0413 - y_end_loss: 0.0556 - y_start_categorical_accuracy: 0.5773 - y_end_categorical_accuracy: 0.0514 - val_loss: 0.0763 - val_y_start_loss: 0.0309 - val_y_end_loss: 0.0454 - val_y_start_categorical_accuracy: 0.5828 - val_y_end_categorical_accuracy: 0.0606
# Epoch 3/20
# 21988/21988 [==============================] - 182s 8ms/sample - loss: 0.0687 - y_start_loss: 0.0275 - y_end_loss: 0.0412 - y_start_categorical_accuracy: 0.5773 - y_end_categorical_accuracy: 0.0777 - val_loss: 0.0611 - val_y_start_loss: 0.0240 - val_y_end_loss: 0.0371 - val_y_start_categorical_accuracy: 0.5828 - val_y_end_categorical_accuracy: 0.1173
# Epoch 4/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0568 - y_start_loss: 0.0223 - y_end_loss: 0.0345 - y_start_categorical_accuracy: 0.5788 - y_end_categorical_accuracy: 0.1673 - val_loss: 0.0515 - val_y_start_loss: 0.0201 - val_y_end_loss: 0.0314 - val_y_start_categorical_accuracy: 0.5857 - val_y_end_categorical_accuracy: 0.2417
# Epoch 5/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0486 - y_start_loss: 0.0191 - y_end_loss: 0.0295 - y_start_categorical_accuracy: 0.5869 - y_end_categorical_accuracy: 0.2781 - val_loss: 0.0451 - val_y_start_loss: 0.0179 - val_y_end_loss: 0.0272 - val_y_start_categorical_accuracy: 0.5929 - val_y_end_categorical_accuracy: 0.3327
# Epoch 6/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0428 - y_start_loss: 0.0170 - y_end_loss: 0.0257 - y_start_categorical_accuracy: 0.6000 - y_end_categorical_accuracy: 0.3640 - val_loss: 0.0409 - val_y_start_loss: 0.0167 - val_y_end_loss: 0.0242 - val_y_start_categorical_accuracy: 0.5977 - val_y_end_categorical_accuracy: 0.4296
# Epoch 7/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0385 - y_start_loss: 0.0156 - y_end_loss: 0.0229 - y_start_categorical_accuracy: 0.6177 - y_end_categorical_accuracy: 0.4348 - val_loss: 0.0380 - val_y_start_loss: 0.0157 - val_y_end_loss: 0.0222 - val_y_start_categorical_accuracy: 0.6142 - val_y_end_categorical_accuracy: 0.4642
# Epoch 8/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0352 - y_start_loss: 0.0145 - y_end_loss: 0.0207 - y_start_categorical_accuracy: 0.6346 - y_end_categorical_accuracy: 0.4864 - val_loss: 0.0358 - val_y_start_loss: 0.0151 - val_y_end_loss: 0.0206 - val_y_start_categorical_accuracy: 0.5995 - val_y_end_categorical_accuracy: 0.5115
# Epoch 9/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0326 - y_start_loss: 0.0137 - y_end_loss: 0.0189 - y_start_categorical_accuracy: 0.6500 - y_end_categorical_accuracy: 0.5311 - val_loss: 0.0343 - val_y_start_loss: 0.0148 - val_y_end_loss: 0.0195 - val_y_start_categorical_accuracy: 0.6159 - val_y_end_categorical_accuracy: 0.5256
# Epoch 10/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0304 - y_start_loss: 0.0130 - y_end_loss: 0.0174 - y_start_categorical_accuracy: 0.6630 - y_end_categorical_accuracy: 0.5716 - val_loss: 0.0333 - val_y_start_loss: 0.0146 - val_y_end_loss: 0.0187 - val_y_start_categorical_accuracy: 0.6215 - val_y_end_categorical_accuracy: 0.5497
# Epoch 11/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0285 - y_start_loss: 0.0124 - y_end_loss: 0.0162 - y_start_categorical_accuracy: 0.6761 - y_end_categorical_accuracy: 0.5983 - val_loss: 0.0327 - val_y_start_loss: 0.0144 - val_y_end_loss: 0.0183 - val_y_start_categorical_accuracy: 0.6235 - val_y_end_categorical_accuracy: 0.5377
# Epoch 12/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0268 - y_start_loss: 0.0118 - y_end_loss: 0.0149 - y_start_categorical_accuracy: 0.6915 - y_end_categorical_accuracy: 0.6346 - val_loss: 0.0324 - val_y_start_loss: 0.0146 - val_y_end_loss: 0.0178 - val_y_start_categorical_accuracy: 0.6255 - val_y_end_categorical_accuracy: 0.5817
# Epoch 13/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0252 - y_start_loss: 0.0113 - y_end_loss: 0.0139 - y_start_categorical_accuracy: 0.7056 - y_end_categorical_accuracy: 0.6595 - val_loss: 0.0323 - val_y_start_loss: 0.0146 - val_y_end_loss: 0.0178 - val_y_start_categorical_accuracy: 0.6235 - val_y_end_categorical_accuracy: 0.5737
# Epoch 14/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0238 - y_start_loss: 0.0108 - y_end_loss: 0.0130 - y_start_categorical_accuracy: 0.7183 - y_end_categorical_accuracy: 0.6872 - val_loss: 0.0322 - val_y_start_loss: 0.0148 - val_y_end_loss: 0.0174 - val_y_start_categorical_accuracy: 0.6202 - val_y_end_categorical_accuracy: 0.5882
# Epoch 15/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0224 - y_start_loss: 0.0103 - y_end_loss: 0.0121 - y_start_categorical_accuracy: 0.7324 - y_end_categorical_accuracy: 0.7103 - val_loss: 0.0325 - val_y_start_loss: 0.0150 - val_y_end_loss: 0.0174 - val_y_start_categorical_accuracy: 0.6253 - val_y_end_categorical_accuracy: 0.5946
# Epoch 16/20
# 21988/21988 [==============================] - 181s 8ms/sample - loss: 0.0211 - y_start_loss: 0.0099 - y_end_loss: 0.0113 - y_start_categorical_accuracy: 0.7449 - y_end_categorical_accuracy: 0.7349 - val_loss: 0.0326 - val_y_start_loss: 0.0149 - val_y_end_loss: 0.0176 - val_y_start_categorical_accuracy: 0.6242 - val_y_end_categorical_accuracy: 0.5880
# Epoch 17/20
# 14080/21988 [==================>...........] - ETA: 59s - loss: 0.0199 - y_start_loss: 0.0094 - y_end_loss: 0.0105 - y_start_categorical_accuracy: 0.7580 - y_end_categorical_accuracy: 0.7577

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
import shutil
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586094759.392f752e1e2c.12.5434.v2
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-05_13-52-48/
# train/plugins/profile/2020-04-05_13-52-48/local.trace
# train/events.out.tfevents.1586094768.392f752e1e2c.profile-empty
# validation/
# validation/events.out.tfevents.1586094951.392f752e1e2c.12.28139.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(x_train)
valid_preds = model.predict(x_valid)

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], tokenizer), axis=1)
train["prediction"] = train["prediction"].apply(lambda x: '.' if x.strip() == '' else x)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], tokenizer), axis=1)
validation["prediction"] = validation["prediction"].apply(lambda x: '.' if x.strip() == '' else x)

evaluate_model(train, validation)
# Out:
# Train set Jaccard: 0.769
# Validation set Jaccard: 0.633
#
# Metric by sentiment
#
# Sentiment == neutral
# Train set Jaccard: 0.972
# Validation set Jaccard: 0.965
#
# Sentiment == positive
# Train set Jaccard: 0.624
# Validation set Jaccard: 0.416
#
# Sentiment == negative
# Train set Jaccard: 0.641
# Validation set Jaccard: 0.382

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#            textID                                               text  \
# 2288   809b2b787d  man with a kickin' top hat just left. invited ...
# 19804  a25ea87900  well dnt really knw wot to do stay wit some 1 ...
# 12673  4144306c53  id be happy thats its friday if i didnt have t...
# 2528   65711a3401                                       _chick hello
# 4046   69a4e7a6f5                               ouch, i'm sorry then
# 22096  011809f662   and no i didn't burn the eggs.  we had a blas...
# 18600  7c07e5d4a3   dude.  you're a hax0r!!!1!  you should put fi...
# 3866   89cdcbfb73  everyone's abandoning the office... i still ha...
# 19535  e4db70af7f  _berra happy bday stevie bee...and if u want f...
# 23788  67cc48a34f   boom, and if you will, boom! saw the movie la...
#
#                                            selected_text sentiment  start  \
# 2288                               man with a kickin' to  positive      1
# 19804                      well dnt really knw wot to do  negative      1
# 12673  id be happy thats its friday if i didnt have t...   neutral      1
# 2528                                        _chick hello   neutral      1
# 4046                                               sorry  negative      1
# 22096                                     we had a blast  positive      1
# 18600  dude.  you're a hax0r!!!1!  you should put fin...   neutral      1
# 3866   everyone's abandoning the office... i still ha...   neutral      1
# 19535                               y babies r the best!  positive     27
# 23788                                            enjoyed  positive     17
#
#        end                                         prediction   jaccard
# 2288     7                            man with a kickin' top   0.666667
# 19804    7                             well dnt really knw wo  0.500000
# 12673   16  id be happy thats its friday if i didnt have t...  1.000000
# 2528     3                                       _chick hello  1.000000
# 4046     7                                   ouch, i'm sorry   0.333333
# 22096   27  and no i didn't burn the eggs. we had a blast ...  0.210526
# 18600   30  dude. you're a hax0r!!!1! you should put final...  1.000000
# 3866    16  everyone's abandoning the office... i still ha...  1.000000
# 19535   32                            may babies r the best!   0.666667
# 23788   18                                         enjoyed it  0.500000
# Validation set
#            textID                                               text  \
# 7321   37dc843ad5   yay!!  i was supposed to be there next weeken...
# 3075   751762b290                     doing okay. how are you doing?
# 25268  ebeea1f86c  am hating my life at the moment. there's only ...
# 18745  2012705b97    and it's only downhill from now until labor ...
# 21804  3d465939ee                  okay for your mom and my mom too!
# 19847  bd085c659b                                           g'night!
# 8456   254254dfec  thanks to the forever 21 curse that makes you ...
# 700    7dfebebd27                    in the university with hungry!!
# 12131  9ee143d387  going to program now  haven't programmed for a...
# 2122   f4df0a8b35  thinks that my friends lifes go around with wh...
#
#                            selected_text sentiment  start  end  \
# 7321                               yay!!  positive      1    3
# 3075                         doing okay.   neutral      1    8
# 25268                             hating  negative      2    2
# 18745                         y downhill  negative      1   12
# 21804  okay for your mom and my mom too!   neutral      1    9
# 19847                            g'night   neutral      1    4
# 8456      thanks to the forever 21 curse  negative      1    6
# 700      in the university with hungry!!   neutral      1    7
# 12131                 haven't programmed  negative      5   13
# 2122               not time for us girls  negative      1   22
#
#                                               prediction   jaccard
# 7321                                                yay!  0.000000
# 3075                      doing okay. how are you doing?  0.333333
# 25268                                            hating   1.000000
# 18745   and it's only downhill from now until labor day!  0.100000
# 21804                  okay for your mom and my mom too!  1.000000
# 19847                                           g'night!  0.000000
# 8456                     thanks to the forever 21 curse   1.000000
# 700                      in the university with hungry!!  1.000000
# 12131             haven't programmed for a long time now  0.285714
# 2122   thinks that my friends lifes go around with wh...  0.200000
