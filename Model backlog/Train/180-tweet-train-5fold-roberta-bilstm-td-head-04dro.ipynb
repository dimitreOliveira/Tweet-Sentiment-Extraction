# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'N_FOLDS': 5,
  "question_size": 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(last_hidden_state)
    x = layers.Dropout(.4)(x)
    
    x_start = layers.TimeDistributed(layers.Dense(1))(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.TimeDistributed(layers.Dense(1))(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights('last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])

    # Make predictions (best model)
    model.load_weights(model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 299s - loss: 2.2158 - y_start_loss: 1.0886 - y_end_loss: 1.1272 - val_loss: 1.6371 - val_y_start_loss: 0.8502 - val_y_end_loss: 0.7869
# Epoch 2/4
# 687/687 - 281s - loss: 1.6518 - y_start_loss: 0.8474 - y_end_loss: 0.8043 - val_loss: 1.5795 - val_y_start_loss: 0.8255 - val_y_end_loss: 0.7540
# Epoch 3/4
# 687/687 - 281s - loss: 1.5535 - y_start_loss: 0.7979 - y_end_loss: 0.7555 - val_loss: 1.5671 - val_y_start_loss: 0.8178 - val_y_end_loss: 0.7493
# Epoch 4/4
# 687/687 - 280s - loss: 1.5135 - y_start_loss: 0.7872 - y_end_loss: 0.7263 - val_loss: 1.5704 - val_y_start_loss: 0.8187 - val_y_end_loss: 0.7517
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 296s - loss: 2.1991 - y_start_loss: 1.0885 - y_end_loss: 1.1106 - val_loss: 1.7247 - val_y_start_loss: 0.8777 - val_y_end_loss: 0.8470
# Epoch 2/4
# 687/687 - 280s - loss: 1.6316 - y_start_loss: 0.8435 - y_end_loss: 0.7882 - val_loss: 1.6670 - val_y_start_loss: 0.8566 - val_y_end_loss: 0.8103
# Epoch 3/4
# 687/687 - 279s - loss: 1.5306 - y_start_loss: 0.7929 - y_end_loss: 0.7377 - val_loss: 1.6685 - val_y_start_loss: 0.8490 - val_y_end_loss: 0.8195
# Epoch 4/4
# 687/687 - 280s - loss: 1.4915 - y_start_loss: 0.7731 - y_end_loss: 0.7184 - val_loss: 1.6421 - val_y_start_loss: 0.8409 - val_y_end_loss: 0.8012
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 295s - loss: 2.2229 - y_start_loss: 1.1030 - y_end_loss: 1.1200 - val_loss: 1.6683 - val_y_start_loss: 0.8307 - val_y_end_loss: 0.8377
# Epoch 2/4
# 687/687 - 280s - loss: 1.6611 - y_start_loss: 0.8521 - y_end_loss: 0.8090 - val_loss: 1.5878 - val_y_start_loss: 0.8126 - val_y_end_loss: 0.7752
# Epoch 3/4
# 687/687 - 279s - loss: 1.5491 - y_start_loss: 0.8024 - y_end_loss: 0.7467 - val_loss: 1.5893 - val_y_start_loss: 0.8145 - val_y_end_loss: 0.7748
# Epoch 4/4
# 687/687 - 280s - loss: 1.5328 - y_start_loss: 0.7959 - y_end_loss: 0.7369 - val_loss: 1.5755 - val_y_start_loss: 0.7965 - val_y_end_loss: 0.7790
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 294s - loss: 2.2082 - y_start_loss: 1.0915 - y_end_loss: 1.1167 - val_loss: 1.6698 - val_y_start_loss: 0.8707 - val_y_end_loss: 0.7990
# Epoch 2/4
# 687/687 - 280s - loss: 1.6433 - y_start_loss: 0.8364 - y_end_loss: 0.8069 - val_loss: 1.6097 - val_y_start_loss: 0.8459 - val_y_end_loss: 0.7637
# Epoch 3/4
# 687/687 - 280s - loss: 1.5411 - y_start_loss: 0.7920 - y_end_loss: 0.7490 - val_loss: 1.5972 - val_y_start_loss: 0.8398 - val_y_end_loss: 0.7574
# Epoch 4/4
# 687/687 - 280s - loss: 1.4953 - y_start_loss: 0.7666 - y_end_loss: 0.7287 - val_loss: 1.5926 - val_y_start_loss: 0.8392 - val_y_end_loss: 0.7534
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 295s - loss: 2.2734 - y_start_loss: 1.1312 - y_end_loss: 1.1422 - val_loss: 1.6871 - val_y_start_loss: 0.8547 - val_y_end_loss: 0.8325
# Epoch 2/4
# 687/687 - 280s - loss: 1.6492 - y_start_loss: 0.8466 - y_end_loss: 0.8027 - val_loss: 1.6034 - val_y_start_loss: 0.8303 - val_y_end_loss: 0.7732
# Epoch 3/4
# 687/687 - 279s - loss: 1.5558 - y_start_loss: 0.7962 - y_end_loss: 0.7596 - val_loss: 1.6125 - val_y_start_loss: 0.8327 - val_y_end_loss: 0.7798
# Epoch 4/4
# 687/687 - 279s - loss: 1.5012 - y_start_loss: 0.7772 - y_end_loss: 0.7240 - val_loss: 1.6168 - val_y_start_loss: 0.8309 - val_y_end_loss: 0.7859

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_fe5fa508_9d74_11ea_b283_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_02265ef2_9d75_11ea_b283_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  \
# 0              10                      10
# 1              13                       3
# 2               6                       2
# 3               6                       3
# 4              17                       4
# 5              27                      27
# 6              17                       1
# 7               3                       3
# 8               3                       3
# 9              19                       7
# 10             27                      27
# 11             12                       1
# 12              9                       1
# 13             13                       1
# 14              8                       8
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                           my boss is bullying me...        0.166667
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
