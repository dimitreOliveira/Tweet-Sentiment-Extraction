# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 1,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(0.1)(last_state) 
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(0.1)(last_state) 
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    batch_size=config['BATCH_SIZE'], 
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 291s - loss: 2.1959 - y_start_loss: 1.0736 - y_end_loss: 1.1223 - y_start_categorical_accuracy: 0.6484 - y_end_categorical_accuracy: 0.6419 - val_loss: 2.2459 - val_y_start_loss: 0.8956 - val_y_end_loss: 1.3506 - val_y_start_categorical_accuracy: 0.7063 - val_y_end_categorical_accuracy: 0.5882
# Epoch 2/5
# 21984/21984 - 274s - loss: 1.7612 - y_start_loss: 0.8633 - y_end_loss: 0.8979 - y_start_categorical_accuracy: 0.6972 - y_end_categorical_accuracy: 0.6814 - val_loss: 1.5710 - val_y_start_loss: 0.8027 - val_y_end_loss: 0.7677 - val_y_start_categorical_accuracy: 0.7125 - val_y_end_categorical_accuracy: 0.7194
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 1.5171 - y_start_loss: 0.7792 - y_end_loss: 0.7379 - y_start_categorical_accuracy: 0.7147 - y_end_categorical_accuracy: 0.7287 - val_loss: 1.5832 - val_y_start_loss: 0.8225 - val_y_end_loss: 0.7601 - val_y_start_categorical_accuracy: 0.6971 - val_y_end_categorical_accuracy: 0.7276
# Epoch 00003: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col0 {
#             color:  green;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col1 {
#             color:  green;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col3 {
#             color:  green;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col4 {
#             color:  green;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow2_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow2_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow2_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow2_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow2_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow3_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow3_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow3_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow3_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow3_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow4_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow4_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow4_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow4_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow4_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow5_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow5_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow5_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow5_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow5_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow6_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow6_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow6_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow6_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow6_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow7_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow7_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow7_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow7_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow7_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow8_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow8_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow8_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow8_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow8_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow9_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow9_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow9_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow9_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow9_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow10_col0 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow10_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow10_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow10_col3 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow10_col4 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow11_col0 {
#             color:  green;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow11_col1 {
#             color:  black;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow11_col2 {
#             color:  red;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow11_col3 {
#             color:  green;
#         }    #T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow11_col4 {
#             color:  black;
#         }</style><table id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfblevel0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col0" class="data row0 col0" >0.73053</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col1" class="data row0 col1" >0.700871</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col2" class="data row0 col2" >0.0296584</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col3" class="data row0 col3" >0.73053</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow0_col4" class="data row0 col4" >0.700871</td>
#             </tr>
#             <tr>
#                         <th id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfblevel0_row1" class="row_heading level0 row1" >Sentiment neutral</th>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col0" class="data row1 col0" >0.973921</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col1" class="data row1 col1" >0.974183</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col2" class="data row1 col2" >-0.000261839</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col3" class="data row1 col3" >0.973921</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow1_col4" class="data row1 col4" >0.974183</td>
#             </tr>
#             <tr>
#                         <th id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfblevel0_row2" class="row_heading level0 row2" >Sentiment negative</th>
#                         <td id="T_45df9f0e_824b_11ea_b9ae_0b0511eb9cfbrow2_col0" class="data row2 col0" >0.57068</td>
#                         <td id="T_45df9f0e_824b_11ea_b9ae

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.100000
# 2                                      bullying me...        0.400000
# 3                                      leave me alone        0.600000
# 4                                       sons of ****,        0.214286
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        0.500000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                                    dangerously low        0.250000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
