# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 16,
  "EPOCHS": 5,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Conv1D(1, 1)(last_state)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Dense(MAX_LEN, activation='softmax', name='y_start')(x_start)   

    x_end = layers.Conv1D(1, 1)(last_state)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Dense(MAX_LEN, activation='softmax', name='y_end')(x_end) 
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'start_fold_%d' % (n_fold+1)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'end_fold_%d' % (n_fold+1)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'start_fold_%d' % (n_fold+1)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'end_fold_%d' % (n_fold+1)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold+1)] = k_fold['end_fold_%d' % (n_fold+1)].astype(int)
    k_fold['start_fold_%d' % (n_fold+1)] = k_fold['start_fold_%d' % (n_fold+1)].astype(int)
    k_fold['end_fold_%d' % (n_fold+1)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold+1)].clip(0, k_fold['end_fold_%d' % (n_fold+1)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold+1)], x['end_fold_%d' % (n_fold+1)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold+1)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold+1)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 315s - loss: 6.1011 - y_start_loss: 2.3530 - y_end_loss: 3.7481 - y_start_categorical_accuracy: 0.5350 - y_end_categorical_accuracy: 0.0424 - val_loss: 5.4254 - val_y_start_loss: 1.8001 - val_y_end_loss: 3.6255 - val_y_start_categorical_accuracy: 0.5813 - val_y_end_categorical_accuracy: 0.0566
# Epoch 2/5
# 21984/21984 - 299s - loss: 5.2504 - y_start_loss: 1.8641 - y_end_loss: 3.3863 - y_start_categorical_accuracy: 0.5773 - y_end_categorical_accuracy: 0.0454 - val_loss: 5.4119 - val_y_start_loss: 1.8128 - val_y_end_loss: 3.5994 - val_y_start_categorical_accuracy: 0.5813 - val_y_end_categorical_accuracy: 0.0475
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 297s - loss: 5.1605 - y_start_loss: 1.8109 - y_end_loss: 3.3496 - y_start_categorical_accuracy: 0.5773 - y_end_categorical_accuracy: 0.0488 - val_loss: 5.5385 - val_y_start_loss: 1.9040 - val_y_end_loss: 3.6347 - val_y_start_categorical_accuracy: 0.5813 - val_y_end_categorical_accuracy: 0.0402
# Epoch 00003: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 315s - loss: 5.9485 - y_start_loss: 2.2160 - y_end_loss: 3.7324 - y_start_categorical_accuracy: 0.5517 - y_end_categorical_accuracy: 0.0452 - val_loss: 5.2377 - val_y_start_loss: 1.8930 - val_y_end_loss: 3.3436 - val_y_start_categorical_accuracy: 0.5739 - val_y_end_categorical_accuracy: 0.0491
# Epoch 2/5
# 21984/21984 - 299s - loss: 4.9895 - y_start_loss: 1.7239 - y_end_loss: 3.2656 - y_start_categorical_accuracy: 0.5786 - y_end_categorical_accuracy: 0.0523 - val_loss: 4.9196 - val_y_start_loss: 1.6944 - val_y_end_loss: 3.2240 - val_y_start_categorical_accuracy: 0.5739 - val_y_end_categorical_accuracy: 0.0493
# Epoch 3/5
# 21984/21984 - 299s - loss: 4.9317 - y_start_loss: 1.7062 - y_end_loss: 3.2255 - y_start_categorical_accuracy: 0.5781 - y_end_categorical_accuracy: 0.0504 - val_loss: 4.8886 - val_y_start_loss: 1.6742 - val_y_end_loss: 3.2133 - val_y_start_categorical_accuracy: 0.5739 - val_y_end_categorical_accuracy: 0.0517
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 297s - loss: 4.8510 - y_start_loss: 1.6584 - y_end_loss: 3.1926 - y_start_categorical_accuracy: 0.5781 - y_end_categorical_accuracy: 0.0537 - val_loss: 4.9058 - val_y_start_loss: 1.6628 - val_y_end_loss: 3.2420 - val_y_start_categorical_accuracy: 0.5739 - val_y_end_categorical_accuracy: 0.0546
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 314s - loss: 5.2024 - y_start_loss: 2.0035 - y_end_loss: 3.1989 - y_start_categorical_accuracy: 0.5456 - y_end_categorical_accuracy: 0.1845 - val_loss: 3.7405 - val_y_start_loss: 1.6303 - val_y_end_loss: 2.1114 - val_y_start_categorical_accuracy: 0.5659 - val_y_end_categorical_accuracy: 0.4130
# Epoch 2/5
# 21984/21984 - 300s - loss: 3.2983 - y_start_loss: 1.5054 - y_end_loss: 1.7929 - y_start_categorical_accuracy: 0.5812 - y_end_categorical_accuracy: 0.5137 - val_loss: 2.9308 - val_y_start_loss: 1.3754 - val_y_end_loss: 1.5563 - val_y_start_categorical_accuracy: 0.5886 - val_y_end_categorical_accuracy: 0.5975
# Epoch 3/5
# 21984/21984 - 300s - loss: 2.6961 - y_start_loss: 1.3188 - y_end_loss: 1.3773 - y_start_categorical_accuracy: 0.6083 - y_end_categorical_accuracy: 0.6347 - val_loss: 2.6411 - val_y_start_loss: 1.2407 - val_y_end_loss: 1.4013 - val_y_start_categorical_accuracy: 0.6379 - val_y_end_categorical_accuracy: 0.6612
# Epoch 4/5
# 21984/21984 - 300s - loss: 2.3540 - y_start_loss: 1.1838 - y_end_loss: 1.1702 - y_start_categorical_accuracy: 0.6421 - y_end_categorical_accuracy: 0.6860 - val_loss: 2.4767 - val_y_start_loss: 1.1928 - val_y_end_loss: 1.2853 - val_y_start_categorical_accuracy: 0.6397 - val_y_end_categorical_accuracy: 0.6805
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 299s - loss: 2.0902 - y_start_loss: 1.0771 - y_end_loss: 1.0131 - y_start_categorical_accuracy: 0.6646 - y_end_categorical_accuracy: 0.7245 - val_loss: 2.4860 - val_y_start_loss: 1.1955 - val_y_end_loss: 1.2916 - val_y_start_categorical_accuracy: 0.6490 - val_y_end_categorical_accuracy: 0.6701
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col0 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col1 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow0_col8 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col0 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col1 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col7 {
#             color:  green;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow1_col8 {
#             color:  green;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col0 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col1 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow2_col8 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col0 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col1 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow3_col8 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col0 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col1 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col3 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col4 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col5 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col6 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow4_col8 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col0 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col1 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col3 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col4 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow5_col8 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col0 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col1 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow6_col8 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col0 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col1 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow7_col8 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col0 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col1 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col3 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col4 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col7 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow8_col8 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col0 {
#             color:  black;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col1 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col2 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col3 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col4 {
#             color:  orange;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col5 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col6 {
#             color:  red;
#         }    #T_442213e0_81c9_11ea_b8ba_555c8a2bba9frow9_col7 {

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#              prediction_fold_1  jaccard_fold_1      prediction_fold_2  \
# 0                          i`d        0.142857               i`d have
# 1                     sooo sad        0.200000             sooo sad i
# 2    my boss is bullying me...        1.000000    my boss is bullying
# 3              what interview!        0.400000  what interview! leave
# 4                 sons of ****        0.133333          sons of ****,
# 5                   http://www        0.000000            http://www.
# 6                     2am feed        0.066667           2am feedings
# 7                   soooo high        1.000000             soooo high
# 8                  both of you        1.000000            both of you
# 9                journey!? wow        0.090909       journey!? wow...
# 10                  as much as        0.095238           as much as i
# 11             i really really        0.200000   i really really like
# 12                  my sharpie        0.250000          my sharpie is
# 13                   i want to        0.300000           i want to go
# 14  test test from the lg env2        1.000000     test test from the
#
#     jaccard_fold_2                                  prediction_fold_3  \
# 0         0.285714                i`d have responded, if i were going
# 1         0.300000                                           sooo sad
# 2         0.800000                                     bullying me...
# 3         0.600000                                     leave me alone
# 4         0.214286                                              ****,
# 5         0.000000  http://www.dothebouncy.com/smf - some shameles...
# 6         0.142857                                                fun
# 7         1.000000                                         soooo high
# 8         1.000000                                        both of you
# 9         0.200000                       wow... u just became cooler.
# 10        0.142857  as much as i love to be hopeful, i reckon the ...
# 11        0.300000                               i really really like
# 12        0.375000                  my sharpie is running dangerously
# 13        0.400000                                     lost my voice.
# 14        0.600000                         test test from the lg env2
#
#     jaccard_fold_3
# 0         1.000000
# 1         0.200000
# 2         0.400000
# 3         0.600000
# 4         0.071429
# 5         1.000000
# 6         0.071429
# 7         1.000000
# 8         1.000000
# 9         0.500000
# 10        1.000000
# 11        0.300000
# 12        0.625000
# 13        0.300000
# 14        1.000000
