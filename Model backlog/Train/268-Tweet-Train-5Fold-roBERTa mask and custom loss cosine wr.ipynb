# %%
# !nvidia-smi
# Out:
# Wed Jun 10 13:21:58 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 675kB 4.7MB/s
#      |████████████████████████████████| 1.1MB 19.5MB/s
#      |████████████████████████████████| 890kB 29.4MB/s
#      |████████████████████████████████| 3.8MB 44.7MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/268-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 1e-4,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size
num_cycles = 6

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [cosine_with_hard_restarts_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                                    warmup_steps=warmup_steps, lr_start=lr_start, 
                                                    lr_max=lr_max, lr_min=lr_min, num_cycles=num_cycles) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 0.0001 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(3, use_bias=False, name='qa_outputs')(last_hidden_state)

    start_logits, end_logits, mask_logits = tf.split(logits, 3, axis=-1, name='logits')
    start_logits = tf.squeeze(start_logits, axis=-1, name='y_start')
    end_logits = tf.squeeze(end_logits, axis=-1, name='y_end')
    mask_logits = tf.squeeze(mask_logits, axis=-1, name='y_mask')

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits, mask_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1], y_train[2])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1], y_valid[2])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
from tensorflow.keras import backend

def Custom_loss(label_smoothing=0., from_logits=False, weight=0.):
    def custom_loss(y_true, y_pred):
        cce = losses.CategoricalCrossentropy(label_smoothing=label_smoothing, from_logits=from_logits)
        y_true_pos = backend.cast(tf.math.argmax(y_true, axis=-1), 'float32')
        y_pred_pos = backend.cast(tf.math.argmax(y_pred, axis=-1), 'float32')

        loss = cce(y_true, y_pred)
        gap = tf.math.reduce_mean(tf.math.sqrt(tf.math.pow(tf.math.subtract(y_true_pos, y_pred_pos), 2)))
        gap = tf.math.multiply(gap, weight)
        loss = tf.math.add(loss, gap)

        return loss
    return custom_loss

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print(f'\nFOLD: {n_fold}')
    
    # Load data
    base_data_path = f'fold_{n_fold}/'
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    y_train_mask = np.load(base_data_path + 'y_train_mask.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    y_valid_mask = np.load(base_data_path + 'y_valid_mask.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = f'model_fold_{n_fold}.h5'
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    lr = lambda: cosine_with_hard_restarts_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                total_steps=total_steps, warmup_steps=warmup_steps, 
                                                                lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, 
                                                                num_cycles=num_cycles)
    
    optimizer = optimizers.Adam(learning_rate=lr)
    
    model.compile(optimizer, loss=[Custom_loss(label_smoothing=0.2, from_logits=True, weight=0.5),
                                   Custom_loss(label_smoothing=0.2, from_logits=True, weight=0.5),
                                   losses.BinaryCrossentropy(from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, (*y_train, y_train_mask), config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, (*y_valid, y_valid_mask), config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 7.7843 - tf_op_layer_y_start_1_loss: 3.8349 - tf_op_layer_y_end_1_loss: 3.7763 - tf_op_layer_y_mask_1_loss: 0.1731 - val_loss: 5.8314 - val_tf_op_layer_y_start_1_loss: 2.8872 - val_tf_op_layer_y_end_1_loss: 2.8489 - val_tf_op_layer_y_mask_1_loss: 0.0953
# Epoch 2/7
# 672/672 - 175s - loss: 5.5129 - tf_op_layer_y_start_1_loss: 2.6797 - tf_op_layer_y_end_1_loss: 2.7407 - tf_op_layer_y_mask_1_loss: 0.0924 - val_loss: 5.5654 - val_tf_op_layer_y_start_1_loss: 2.7283 - val_tf_op_layer_y_end_1_loss: 2.7452 - val_tf_op_layer_y_mask_1_loss: 0.0919
# Epoch 3/7
# 672/672 - 171s - loss: 5.2846 - tf_op_layer_y_start_1_loss: 2.5631 - tf_op_layer_y_end_1_loss: 2.6327 - tf_op_layer_y_mask_1_loss: 0.0889 - val_loss: 5.5832 - val_tf_op_layer_y_start_1_loss: 2.7483 - val_tf_op_layer_y_end_1_loss: 2.7434 - val_tf_op_layer_y_mask_1_loss: 0.0914
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 5.0657 - tf_op_layer_y_start_1_loss: 2.4468 - tf_op_layer_y_end_1_loss: 2.5343 - tf_op_layer_y_mask_1_loss: 0.0846 - val_loss: 5.5954 - val_tf_op_layer_y_start_1_loss: 2.7482 - val_tf_op_layer_y_end_1_loss: 2.7557 - val_tf_op_layer_y_mask_1_loss: 0.0915
# Epoch 00004: early stopping
#
# FOLD: 2
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 7.9666 - tf_op_layer_y_start_2_loss: 3.9137 - tf_op_layer_y_end_2_loss: 3.8846 - tf_op_layer_y_mask_2_loss: 0.1683 - val_loss: 5.7290 - val_tf_op_layer_y_start_2_loss: 2.7819 - val_tf_op_layer_y_end_2_loss: 2.8496 - val_tf_op_layer_y_mask_2_loss: 0.0975
# Epoch 2/7
# 672/672 - 175s - loss: 5.6961 - tf_op_layer_y_start_2_loss: 2.7486 - tf_op_layer_y_end_2_loss: 2.8509 - tf_op_layer_y_mask_2_loss: 0.0967 - val_loss: 5.5767 - val_tf_op_layer_y_start_2_loss: 2.7128 - val_tf_op_layer_y_end_2_loss: 2.7725 - val_tf_op_layer_y_mask_2_loss: 0.0914
# Epoch 3/7
# 672/672 - 176s - loss: 5.3759 - tf_op_layer_y_start_2_loss: 2.6162 - tf_op_layer_y_end_2_loss: 2.6693 - tf_op_layer_y_mask_2_loss: 0.0904 - val_loss: 5.5359 - val_tf_op_layer_y_start_2_loss: 2.6883 - val_tf_op_layer_y_end_2_loss: 2.7579 - val_tf_op_layer_y_mask_2_loss: 0.0897
# Epoch 4/7
# 672/672 - 171s - loss: 5.1714 - tf_op_layer_y_start_2_loss: 2.5148 - tf_op_layer_y_end_2_loss: 2.5696 - tf_op_layer_y_mask_2_loss: 0.0870 - val_loss: 5.5780 - val_tf_op_layer_y_start_2_loss: 2.7145 - val_tf_op_layer_y_end_2_loss: 2.7744 - val_tf_op_layer_y_mask_2_loss: 0.0891
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 4.9786 - tf_op_layer_y_start_2_loss: 2.4217 - tf_op_layer_y_end_2_loss: 2.4737 - tf_op_layer_y_mask_2_loss: 0.0832 - val_loss: 5.6355 - val_tf_op_layer_y_start_2_loss: 2.7515 - val_tf_op_layer_y_end_2_loss: 2.7939 - val_tf_op_layer_y_mask_2_loss: 0.0901
# Epoch 00005: early stopping
#
# FOLD: 3
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 175s - loss: 7.7990 - tf_op_layer_y_start_3_loss: 3.7955 - tf_op_layer_y_end_3_loss: 3.8302 - tf_op_layer_y_mask_3_loss: 0.1732 - val_loss: 5.9347 - val_tf_op_layer_y_start_3_loss: 2.8201 - val_tf_op_layer_y_end_3_loss: 3.0151 - val_tf_op_layer_y_mask_3_loss: 0.0995
# Epoch 2/7
# 672/672 - 174s - loss: 5.5455 - tf_op_layer_y_start_3_loss: 2.6745 - tf_op_layer_y_end_3_loss: 2.7770 - tf_op_layer_y_mask_3_loss: 0.0939 - val_loss: 5.5086 - val_tf_op_layer_y_start_3_loss: 2.6733 - val_tf_op_layer_y_end_3_loss: 2.7428 - val_tf_op_layer_y_mask_3_loss: 0.0926
# Epoch 3/7
# 672/672 - 170s - loss: 5.3732 - tf_op_layer_y_start_3_loss: 2.5682 - tf_op_layer_y_end_3_loss: 2.7140 - tf_op_layer_y_mask_3_loss: 0.0910 - val_loss: 5.6378 - val_tf_op_layer_y_start_3_loss: 2.7078 - val_tf_op_layer_y_end_3_loss: 2.8366 - val_tf_op_layer_y_mask_3_loss: 0.0934
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 5.1305 - tf_op_layer_y_start_3_loss: 2.4780 - tf_op_layer_y_end_3_loss: 2.5665 - tf_op_layer_y_mask_3_loss: 0.0860 - val_loss: 5.5868 - val_tf_op_layer_y_start_3_loss: 2.7356 - val_tf_op_layer_y_end_3_loss: 2.7596 - val_tf_op_layer_y_mask_3_loss: 0.0916
# Epoch 00004: early stopping
#
# FOLD: 4
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 174s - loss: 7.6382 - tf_op_layer_y_start_4_loss: 3.5675 - tf_op_layer_y_end_4_loss: 3.9124 - tf_op_layer_y_mask_4_loss: 0.1582 - val_loss: 5.7866 - val_tf_op_layer_y_start_4_loss: 2.7806 - val_tf_op_layer_y_end_4_loss: 2.9081 - val_tf_op_layer_y_mask_4_loss: 0.0980
# Epoch 2/7
# 672/672 - 175s - loss: 5.5095 - tf_op_layer_y_start_4_loss: 2.6958 - tf_op_layer_y_end_4_loss: 2.7203 - tf_op_layer_y_mask_4_loss: 0.0934 - val_loss: 5.4607 - val_tf_op_layer_y_start_4_loss: 2.6258 - val_tf_op_layer_y_end_4_loss: 2.7456 - val_tf_op_layer_y_mask_4_loss: 0.0893
# Epoch 3/7
# 672/672 - 171s - loss: 5.2535 - tf_op_layer_y_start_4_loss: 2.5536 - tf_op_layer_y_end_4_loss: 2.6114 - tf_op_layer_y_mask_4_loss: 0.0886 - val_loss: 5.4795 - val_tf_op_layer_y_start_4_loss: 2.6411 - val_tf_op_layer_y_end_4_loss: 2.7498 - val_tf_op_layer_y_mask_4_loss: 0.0886
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 5.0487 - tf_op_layer_y_start_4_loss: 2.4654 - tf_op_layer_y_end_4_loss: 2.4982 - tf_op_layer_y_mask_4_loss: 0.0850 - val_loss: 5.5384 - val_tf_op_layer_y_start_4_loss: 2.6804 - val_tf_op_layer_y_end_4_loss: 2.7692 - val_tf_op_layer_y_mask_4_loss: 0.0889
# Epoch 00004: early stopping
#
# FOLD: 5
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 174s - loss: 7.4436 - tf_op_layer_y_start_5_loss: 3.5339 - tf_op_layer_y_end_5_loss: 3.7362 - tf_op_layer_y_mask_5_loss: 0.1734 - val_loss: 5.8684 - val_tf_op_layer_y_start_5_loss: 2.7772 - val_tf_op_layer_y_end_5_loss: 2.9952 - val_tf_op_layer_y_mask_5_loss: 0.0960
# Epoch 2/7
# 672/672 - 175s - loss: 5.6253 - tf_op_layer_y_start_5_loss: 2.7345 - tf_op_layer_y_end_5_loss: 2.7939 - tf_op_layer_y_mask_5_loss: 0.0969 - val_loss: 5.4914 - val_tf_op_layer_y_start_5_loss: 2.6583 - val_tf_op_layer_y_end_5_loss: 2.7471 - val_tf_op_layer_y_mask_5_loss: 0.0861
# Epoch 3/7
# 672/672 - 171s - loss: 5.3359 - tf_op_layer_y_start_5_loss: 2.6026 - tf_op_layer_y_end_5_loss: 2.6424 - tf_op_layer_y_mask_5_loss: 0.0909 - val_loss: 5.5020 - val_tf_op_layer_y_start_5_loss: 2.6643 - val_tf_op_layer_y_end_5_loss: 2.7521 - val_tf_op_layer_y_mask_5_loss: 0.0857
# Epoch 4/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 171s - loss: 5.2207 - tf_op_layer_y_start_5_loss: 2.5473 - tf_op_layer_y_end_5_loss: 2.5846 - tf_op_layer_y_mask_5_loss: 0.0888 - val_loss: 5.5688 - val_tf_op_layer_y_start_5_loss: 2.7021 - val_tf_op_layer_y_end_5_loss: 2.7803 - val_tf_op_layer_y_mask_5_loss: 0.0864
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_3b1602ca_ab27_11ea_80ae_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_5
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                   my boss is bullying me...
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                                                 some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                                      wow...
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                        i really really like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                      dangerously low on ink
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                              lost my voice.
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
