# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 291s - loss: 4.4924 - y_start_loss: 2.2196 - y_end_loss: 2.2728 - y_start_categorical_accuracy: 0.6465 - y_end_categorical_accuracy: 0.6388 - val_loss: 4.0493 - val_y_start_loss: 2.0426 - val_y_end_loss: 2.0063 - val_y_start_categorical_accuracy: 0.7087 - val_y_end_categorical_accuracy: 0.7180
# Epoch 2/6
# 21984/21984 - 273s - loss: 4.0270 - y_start_loss: 2.0225 - y_end_loss: 2.0046 - y_start_categorical_accuracy: 0.7083 - y_end_categorical_accuracy: 0.7205 - val_loss: 4.0291 - val_y_start_loss: 2.0058 - val_y_end_loss: 2.0229 - val_y_start_categorical_accuracy: 0.7154 - val_y_end_categorical_accuracy: 0.7034
# Epoch 3/6
# 21984/21984 - 273s - loss: 3.9478 - y_start_loss: 1.9808 - y_end_loss: 1.9670 - y_start_categorical_accuracy: 0.7218 - y_end_categorical_accuracy: 0.7293 - val_loss: 3.9765 - val_y_start_loss: 2.0045 - val_y_end_loss: 1.9716 - val_y_start_categorical_accuracy: 0.7165 - val_y_end_categorical_accuracy: 0.7243
# Epoch 4/6
# 21984/21984 - 273s - loss: 3.8686 - y_start_loss: 1.9487 - y_end_loss: 1.9199 - y_start_categorical_accuracy: 0.7354 - y_end_categorical_accuracy: 0.7481 - val_loss: 3.9663 - val_y_start_loss: 1.9978 - val_y_end_loss: 1.9681 - val_y_start_categorical_accuracy: 0.7176 - val_y_end_categorical_accuracy: 0.7236
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 272s - loss: 3.8381 - y_start_loss: 1.9353 - y_end_loss: 1.9028 - y_start_categorical_accuracy: 0.7359 - y_end_categorical_accuracy: 0.7559 - val_loss: 3.9830 - val_y_start_loss: 2.0079 - val_y_end_loss: 1.9747 - val_y_start_categorical_accuracy: 0.7152 - val_y_end_categorical_accuracy: 0.7234
# Epoch 00005: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 287s - loss: 4.3775 - y_start_loss: 2.1870 - y_end_loss: 2.1905 - y_start_categorical_accuracy: 0.6582 - y_end_categorical_accuracy: 0.6598 - val_loss: 4.0554 - val_y_start_loss: 2.0397 - val_y_end_loss: 2.0154 - val_y_start_categorical_accuracy: 0.7025 - val_y_end_categorical_accuracy: 0.7200
# Epoch 2/6
# 21984/21984 - 274s - loss: 3.9435 - y_start_loss: 1.9970 - y_end_loss: 1.9465 - y_start_categorical_accuracy: 0.7131 - y_end_categorical_accuracy: 0.7408 - val_loss: 4.0080 - val_y_start_loss: 2.0209 - val_y_end_loss: 1.9868 - val_y_start_categorical_accuracy: 0.6960 - val_y_end_categorical_accuracy: 0.7220
# Epoch 3/6
# 21984/21984 - 274s - loss: 3.8396 - y_start_loss: 1.9455 - y_end_loss: 1.8942 - y_start_categorical_accuracy: 0.7334 - y_end_categorical_accuracy: 0.7572 - val_loss: 3.9970 - val_y_start_loss: 2.0181 - val_y_end_loss: 1.9785 - val_y_start_categorical_accuracy: 0.7096 - val_y_end_categorical_accuracy: 0.7245
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 272s - loss: 3.7718 - y_start_loss: 1.9104 - y_end_loss: 1.8614 - y_start_categorical_accuracy: 0.7485 - y_end_categorical_accuracy: 0.7741 - val_loss: 4.0201 - val_y_start_loss: 2.0288 - val_y_end_loss: 1.9910 - val_y_start_categorical_accuracy: 0.7089 - val_y_end_categorical_accuracy: 0.7245
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 290s - loss: 4.3849 - y_start_loss: 2.2048 - y_end_loss: 2.1801 - y_start_categorical_accuracy: 0.6550 - y_end_categorical_accuracy: 0.6649 - val_loss: 4.0780 - val_y_start_loss: 2.0693 - val_y_end_loss: 2.0087 - val_y_start_categorical_accuracy: 0.6996 - val_y_end_categorical_accuracy: 0.7260
# Epoch 2/6
# 21984/21984 - 275s - loss: 3.9895 - y_start_loss: 2.0232 - y_end_loss: 1.9663 - y_start_categorical_accuracy: 0.7034 - y_end_categorical_accuracy: 0.7321 - val_loss: 3.9754 - val_y_start_loss: 2.0150 - val_y_end_loss: 1.9600 - val_y_start_categorical_accuracy: 0.7065 - val_y_end_categorical_accuracy: 0.7373
# Epoch 3/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 3.8676 - y_start_loss: 1.9624 - y_end_loss: 1.9052 - y_start_categorical_accuracy: 0.7268 - y_end_categorical_accuracy: 0.7533 - val_loss: 3.9825 - val_y_start_loss: 2.0151 - val_y_end_loss: 1.9671 - val_y_start_categorical_accuracy: 0.7138 - val_y_end_categorical_accuracy: 0.7340
# Epoch 00003: early stopping
#
# FOLD: 4
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 290s - loss: 4.4685 - y_start_loss: 2.2229 - y_end_loss: 2.2456 - y_start_categorical_accuracy: 0.6527 - y_end_categorical_accuracy: 0.6505 - val_loss: 4.0763 - val_y_start_loss: 2.0603 - val_y_end_loss: 2.0155 - val_y_start_categorical_accuracy: 0.7043 - val_y_end_categorical_accuracy: 0.7254
# Epoch 2/6
# 21984/21984 - 274s - loss: 4.0150 - y_start_loss: 2.0221 - y_end_loss: 1.9929 - y_start_categorical_accuracy: 0.7075 - y_end_categorical_accuracy: 0.7256 - val_loss: 3.9999 - val_y_start_loss: 2.0246 - val_y_end_loss: 1.9750 - val_y_start_categorical_accuracy: 0.7083 - val_y_end_categorical_accuracy: 0.7291
# Epoch 3/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 3.9088 - y_start_loss: 1.9725 - y_end_loss: 1.9363 - y_start_categorical_accuracy: 0.7227 - y_end_categorical_accuracy: 0.7429 - val_loss: 4.0044 - val_y_start_loss: 2.0309 - val_y_end_loss: 1.9730 - val_y_start_categorical_accuracy: 0.7034 - val_y_end_categorical_accuracy: 0.7338
# Epoch 00003: early stopping
#
# FOLD: 5
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 291s - loss: 4.4667 - y_start_loss: 2.2219 - y_end_loss: 2.2448 - y_start_categorical_accuracy: 0.6497 - y_end_categorical_accuracy: 0.6432 - val_loss: 4.0860 - val_y_start_loss: 2.0415 - val_y_end_loss: 2.0450 - val_y_start_categorical_accuracy: 0.7003 - val_y_end_categorical_accuracy: 0.7087
# Epoch 2/6
# 21984/21984 - 274s - loss: 4.0162 - y_start_loss: 2.0271 - y_end_loss: 1.9890 - y_start_categorical_accuracy: 0.7068 - y_end_categorical_accuracy: 0.7239 - val_loss: 4.0104 - val_y_start_loss: 2.0265 - val_y_end_loss: 1.9847 - val_y_start_categorical_accuracy: 0.7052 - val_y_end_categorical_accuracy: 0.7278
# Epoch 3/6
# 21984/21984 - 274s - loss: 3.9075 - y_start_loss: 1.9766 - y_end_loss: 1.9310 - y_start_categorical_accuracy: 0.7226 - y_end_categorical_accuracy: 0.7445 - val_loss: 3.9742 - val_y_start_loss: 2.0063 - val_y_end_loss: 1.9685 - val_y_start_categorical_accuracy: 0.7074 - val_y_end_categorical_accuracy: 0.7333
# Epoch 4/6
# 21984/21984 - 274s - loss: 3.8527 - y_start_loss: 1.9502 - y_end_loss: 1.9026 - y_start_categorical_accuracy: 0.7332 - y_end_categorical_accuracy: 0.7570 - val_loss: 3.9708 - val_y_start_loss: 2.0043 - val_y_end_loss: 1.9671 - val_y_start_categorical_accuracy: 0.7094 - val_y_end_categorical_accuracy: 0.7338
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 3.8196 - y_start_loss: 1.9319 - y_end_loss: 1.8876 - y_start_categorical_accuracy: 0.7388 - y_end_categorical_accuracy: 0.7625 - val_loss: 3.9710 - val_y_start_loss: 2.0096 - val_y_end_loss: 1.9619 - val_y_start_categorical_accuracy: 0.7056 - val_y_end_categorical_accuracy: 0.7349
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_93139808_8e20_11ea_b91a_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col4 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col6 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col8 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col11 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row1_col12 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col9 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col10 {
#             color:  green;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_93139808_8e20_11ea_b91a_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
