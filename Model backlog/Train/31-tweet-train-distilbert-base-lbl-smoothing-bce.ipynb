# %% [markdown]
# ## Dependencies

# %%
import json
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

y_train = y_train.astype('float')
y_valid = y_valid.astype('float')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
#
#    selected_text_len    set
# 0                 95  train
# 1                 10  train
# 2                 23  train
# 3                  9  train
# 4                 41  train
# hold_out/
# hold_out/y_valid.npy
# hold_out/x_train.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
model_path = 'model.h5'

config = {
  "MAX_LEN": 128,
  "BATCH_SIZE": 64,
  "EPOCHS": 20,
  "LEARNING_RATE": 1e-5,
  "ES_PATIENCE": 3,
  "question_size": 3,
  "smooth_factor": .1,
  "base_model_path": base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5',
  "config_path": base_path + 'distilbert-base-uncased-distilled-squad-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %%
def smooth_labels(y, smooth_factor=config['smooth_factor']):
    y *= 1 - smooth_factor
    y += smooth_factor / y.shape[0]
    
    return y

np.apply_along_axis(smooth_labels, -1, y_train)
np.apply_along_axis(smooth_labels, -1, y_valid)
# Out:
# array([[[0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         ...,
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125]],
#
#        [[0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         ...,
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125],
#         [0.00078125, 0.00078125, 0.00078125, ..., 0.00078125,
#          0.00078125, 0.00078125]]])

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='sigmoid', name='y_start')(x)     
    y_end = Dense(MAX_LEN, activation='sigmoid', name='y_end')(x)        
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

model = model_fn(config['MAX_LEN'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir='./')
es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/20
# 21984/21984 - 176s - loss: 0.4389 - y_start_loss: 0.2090 - y_end_loss: 0.2296 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.2298 - val_y_start_loss: 0.1072 - val_y_end_loss: 0.1226 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 2/20
# 21984/21984 - 166s - loss: 0.1758 - y_start_loss: 0.0810 - y_end_loss: 0.0948 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.1318 - val_y_start_loss: 0.0594 - val_y_end_loss: 0.0724 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 3/20
# 21984/21984 - 165s - loss: 0.1129 - y_start_loss: 0.0501 - y_end_loss: 0.0628 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0965 - val_y_start_loss: 0.0420 - val_y_end_loss: 0.0545 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 4/20
# 21984/21984 - 165s - loss: 0.0884 - y_start_loss: 0.0380 - y_end_loss: 0.0504 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0808 - val_y_start_loss: 0.0343 - val_y_end_loss: 0.0465 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 5/20
# 21984/21984 - 165s - loss: 0.0765 - y_start_loss: 0.0321 - y_end_loss: 0.0444 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0721 - val_y_start_loss: 0.0300 - val_y_end_loss: 0.0421 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 6/20
# 21984/21984 - 166s - loss: 0.0694 - y_start_loss: 0.0288 - y_end_loss: 0.0406 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0661 - val_y_start_loss: 0.0275 - val_y_end_loss: 0.0385 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 7/20
# 21984/21984 - 165s - loss: 0.0640 - y_start_loss: 0.0266 - y_end_loss: 0.0373 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0611 - val_y_start_loss: 0.0256 - val_y_end_loss: 0.0355 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 8/20
# 21984/21984 - 165s - loss: 0.0593 - y_start_loss: 0.0249 - y_end_loss: 0.0344 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0569 - val_y_start_loss: 0.0240 - val_y_end_loss: 0.0329 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 9/20
# 21984/21984 - 166s - loss: 0.0553 - y_start_loss: 0.0234 - y_end_loss: 0.0319 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0535 - val_y_start_loss: 0.0229 - val_y_end_loss: 0.0305 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 10/20
# 21984/21984 - 166s - loss: 0.0518 - y_start_loss: 0.0224 - y_end_loss: 0.0294 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0504 - val_y_start_loss: 0.0222 - val_y_end_loss: 0.0282 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 11/20
# 21984/21984 - 166s - loss: 0.0484 - y_start_loss: 0.0215 - y_end_loss: 0.0269 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0477 - val_y_start_loss: 0.0217 - val_y_end_loss: 0.0259 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 12/20
# 21984/21984 - 166s - loss: 0.0455 - y_start_loss: 0.0208 - y_end_loss: 0.0247 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0452 - val_y_start_loss: 0.0212 - val_y_end_loss: 0.0240 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 13/20
# 21984/21984 - 166s - loss: 0.0429 - y_start_loss: 0.0201 - y_end_loss: 0.0228 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0439 - val_y_start_loss: 0.0210 - val_y_end_loss: 0.0229 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 14/20
# 21984/21984 - 166s - loss: 0.0409 - y_start_loss: 0.0196 - y_end_loss: 0.0213 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0427 - val_y_start_loss: 0.0207 - val_y_end_loss: 0.0220 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 15/20
# 21984/21984 - 166s - loss: 0.0393 - y_start_loss: 0.0191 - y_end_loss: 0.0202 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0421 - val_y_start_loss: 0.0205 - val_y_end_loss: 0.0216 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 16/20
# 21984/21984 - 165s - loss: 0.0380 - y_start_loss: 0.0186 - y_end_loss: 0.0194 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0417 - val_y_start_loss: 0.0204 - val_y_end_loss: 0.0213 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 17/20
# 21984/21984 - 166s - loss: 0.0369 - y_start_loss: 0.0183 - y_end_loss: 0.0186 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0415 - val_y_start_loss: 0.0203 - val_y_end_loss: 0.0212 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 18/20
# 21984/21984 - 166s - loss: 0.0359 - y_start_loss: 0.0179 - y_end_loss: 0.0180 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0412 - val_y_start_loss: 0.0202 - val_y_end_loss: 0.0210 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 19/20
# 21984/21984 - 165s - loss: 0.0349 - y_start_loss: 0.0175 - y_end_loss: 0.0175 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0416 - val_y_start_loss: 0.0205 - val_y_end_loss: 0.0211 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 20/20
# 21984/21984 - 165s - loss: 0.0341 - y_start_loss: 0.0172 - y_end_loss: 0.0170 - y_start_binary_accuracy: 0.0000e+00 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.0415 - val_y_start_loss: 0.0204 - val_y_end_loss: 0.0211 - val_y_start_binary_accuracy: 0.0000e+00 - val_y_end_binary_accuracy: 0.0000e+00

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586631985.c1488956fcc1.profile-empty
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-11_19-06-25/
# train/plugins/profile/2020-04-11_19-06-25/local.trace
# train/events.out.tfevents.1586631975.c1488956fcc1.12.5436.v2
# validation/
# validation/events.out.tfevents.1586632151.c1488956fcc1.12.24191.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 
                                   'y_start_binary_accuracy', 'y_start_binary_accuracy'])

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)
tokenizer.save('./')
# Out:
# ['./vocab.txt']

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train["end"].clip(0, train["text_len"], inplace=True)
train["start"].clip(0, train["end"], inplace=True)

train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], config['question_size'], tokenizer), axis=1)
train["prediction"].fillna('', inplace=True)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation["end"].clip(0, validation["text_len"], inplace=True)
validation["start"].clip(0, validation["end"], inplace=True)

validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], config['question_size'], tokenizer), axis=1)
validation["prediction"].fillna('', inplace=True)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.789861    0.640194          21984
# Sentiment neutral            0.976168    0.968837           8842
# Sentiment negative           0.665926    0.412383           6258
# Sentiment positive           0.663226    0.404207           6884
# 0 <= text < 10               0.931034    0.837500            203
# 10 <= text < 50              0.862042    0.733589           7823
# 50 <= text < 100             0.766332    0.609024           8858
# 100 <= text < 200            0.714388    0.547875           5100
# 0 <= selected text < 10      0.731144    0.436935           6326
# 10 <= selected text < 50     0.742467    0.622653           9575
# 50 <= selected text < 100    0.911870    0.850481           4075
# 100 <= selected text < 200   0.953231    0.891097           2008
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5496
# Sentiment neutral                          2275
# Sentiment negative                         1523
# Sentiment positive                         1698
# 0 <= text < 10                               40
# 10 <= text < 50                            1945
# 50 <= text < 100                           2201
# 100 <= text < 200                          1310
# 0 <= selected text < 10                    1492
# 10 <= selected text < 50                   2455
# 50 <= selected text < 100                  1042
# 100 <= selected text < 200                  507

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
# 5  cb280b3adb  _ kk`s  have fun eating lol, remember shaun lo...
# 6  8dd41515ff                                   definitley miley
# 7  60fa8ea66e         just going to shower. brb in 10 mins or so
# 8  bb4ac6eb31              back to work.. with no distractions..
# 9  2f858c20c3   cool, i used to live 5 houses to the left of ...
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
# 5                                                fun  positive        58
# 6                                   definitley miley   neutral        17
# 7         just going to shower. brb in 10 mins or so   neutral        42
# 8              back to work.. with no distractions..  positive        37
# 9                                              cool,  positive        86
#
#    selected_text_len    set  start  end  \
# 0                 95  train      4   39
# 1                 10  train      4    6
# 2                 23  train      4   11
# 3                  9  train     10   15
# 4                 41  train      4   17
# 5                  3  train     10   10
# 6                 16  train      4    8
# 7                 42  train      4   16
# 8                 37  train     10   14
# 9                  5  train      4    5
#
#                                           prediction   jaccard
# 0  cant stop playin` in my head  -- pussycat doll...  1.000000
# 1                                         i hate you  1.000000
# 2                            starbucks i`m lovin` it  1.000000
# 3                                         yummmmy!!!  0.000000
# 4          wow.. purple leopard skin.  fieeerrceee..  1.000000
# 5                                                fun  1.000000
# 6                                   definitley miley  1.000000
# 7         just going to shower. brb in 10 mins or so  1.000000
# 8                                  no distractions..  0.333333
# 9                                              cool,  1.000000
# Validation set
#            textID                                               text  \
# 21984  3391184efc              loves the nice weather and 7:30 exams
# 21985  b35daf9677  okay, this weather isn`t 'cute sundress' frien...
# 21986  06e5249859                          woo hoo!! congratulations
# 21987  3cd4960670   thanks   got a hold of someone there who knew...
# 21988  92b75314ca  got back and putting in the laundry. we got in...
# 21989  7438c9c09a                    congrats on graduating college!
# 21990  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 21991  a4ede54987  it`s the weekend but 9 year old is grounded wh...
# 21992  35124a7481   it`s been fine for me for like, a week, but n...
# 21993  e4b6c9a295                      ntah, i really wanna be there
#
#                                            selected_text sentiment  text_len  \
# 21984                                              loves  positive        37
# 21985  okay, this weather isn`t 'cute sundress' frien...   neutral       130
# 21986                                    congratulations  positive        26
# 21987                                             thanks  positive        68
# 21988  got back and putting in the laundry. we got in...   neutral        95
# 21989                                           congrats  positive        32
# 21990  can you get me a sub from subway when ur on yo...   neutral        58
# 21991  it`s the weekend but 9 year old is grounded wh...   neutral        71
# 21992  it`s been fine for me for like, a week, but no...   neutral        68
# 21993                                              wanna  positive        30
#
#        selected_text_len         set  start  end  \
# 21984                  5  validation      4    4
# 21985                130  validation      4   38
# 21986                 15  validation      4    9
# 21987                  6  validation      4    4
# 21988                 95  validation      4   29
# 21989                  8  validation      4    5
# 21990                 58  validation      4   18
# 21991                 71  validation      4   19
# 21992                 67  validation      4   25
# 21993                  5  validation      4   11
#
#                                               prediction   jaccard
# 21984                                              loves  1.000000
# 21985  okay, this weather isn`t 'cute sundress' frien...  1.000000
# 21986                          woo hoo!! congratulations  0.333333
# 21987                                             thanks  1.000000
# 21988  got back and putting in the laundry. we got in...  1.000000
# 21989                                            congrat  0.000000
# 21990  can you get me a sub from subway when ur on yo...  1.000000
# 21991  it`s the weekend but 9 year old is grounded wh...  1.000000
# 21992  it`s been fine for me for like, a week, but no...  1.000000
# 21993                      ntah, i really wanna be there  0.166667
