# %% [markdown]
# ## Dependencies

# %%
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
#
#    selected_text_len    set
# 0                 95  train
# 1                 10  train
# 2                 23  train
# 3                  9  train
# 4                 41  train
# hold_out/
# hold_out/y_valid.npy
# hold_out/x_train.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 128
BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 1e-5
ES_PATIENCE = 3
question_size = 3

tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
base_model_path = base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5'
config_path = base_path + 'distilbert-base-uncased-distilled-squad-config.json'
model_path = 'model.h5'
log_path = './'

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config_path, output_hidden_states=False)

def model_fn():
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(base_model_path, config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='sigmoid', name='y_start')(x)
    y_end = Dense(MAX_LEN, activation='sigmoid', name='y_end')(x)
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

model = model_fn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir=log_path)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=EPOCHS, 
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/20
# 21984/21984 - 179s - loss: 0.3077 - y_start_loss: 0.1446 - y_end_loss: 0.1631 - y_start_binary_accuracy: 0.9833 - y_end_binary_accuracy: 0.9799 - val_loss: 0.1302 - val_y_start_loss: 0.0578 - val_y_end_loss: 0.0724 - val_y_start_binary_accuracy: 0.9952 - val_y_end_binary_accuracy: 0.9922
# Epoch 2/20
# 21984/21984 - 172s - loss: 0.0983 - y_start_loss: 0.0419 - y_end_loss: 0.0564 - y_start_binary_accuracy: 0.9952 - y_end_binary_accuracy: 0.9922 - val_loss: 0.0774 - val_y_start_loss: 0.0315 - val_y_end_loss: 0.0459 - val_y_start_binary_accuracy: 0.9953 - val_y_end_binary_accuracy: 0.9922
# Epoch 3/20
# 21984/21984 - 171s - loss: 0.0692 - y_start_loss: 0.0275 - y_end_loss: 0.0417 - y_start_binary_accuracy: 0.9954 - y_end_binary_accuracy: 0.9922 - val_loss: 0.0620 - val_y_start_loss: 0.0242 - val_y_end_loss: 0.0378 - val_y_start_binary_accuracy: 0.9955 - val_y_end_binary_accuracy: 0.9922
# Epoch 4/20
# 21984/21984 - 171s - loss: 0.0574 - y_start_loss: 0.0224 - y_end_loss: 0.0350 - y_start_binary_accuracy: 0.9955 - y_end_binary_accuracy: 0.9922 - val_loss: 0.0525 - val_y_start_loss: 0.0205 - val_y_end_loss: 0.0320 - val_y_start_binary_accuracy: 0.9955 - val_y_end_binary_accuracy: 0.9922
# Epoch 5/20
# 21984/21984 - 171s - loss: 0.0491 - y_start_loss: 0.0192 - y_end_loss: 0.0299 - y_start_binary_accuracy: 0.9956 - y_end_binary_accuracy: 0.9922 - val_loss: 0.0452 - val_y_start_loss: 0.0179 - val_y_end_loss: 0.0273 - val_y_start_binary_accuracy: 0.9955 - val_y_end_binary_accuracy: 0.9924
# Epoch 6/20
# 21984/21984 - 171s - loss: 0.0426 - y_start_loss: 0.0172 - y_end_loss: 0.0255 - y_start_binary_accuracy: 0.9957 - y_end_binary_accuracy: 0.9927 - val_loss: 0.0400 - val_y_start_loss: 0.0168 - val_y_end_loss: 0.0232 - val_y_start_binary_accuracy: 0.9956 - val_y_end_binary_accuracy: 0.9934
# Epoch 7/20
# 21984/21984 - 171s - loss: 0.0372 - y_start_loss: 0.0158 - y_end_loss: 0.0214 - y_start_binary_accuracy: 0.9957 - y_end_binary_accuracy: 0.9937 - val_loss: 0.0357 - val_y_start_loss: 0.0159 - val_y_end_loss: 0.0198 - val_y_start_binary_accuracy: 0.9956 - val_y_end_binary_accuracy: 0.9945
# Epoch 8/20
# 21984/21984 - 171s - loss: 0.0328 - y_start_loss: 0.0146 - y_end_loss: 0.0182 - y_start_binary_accuracy: 0.9958 - y_end_binary_accuracy: 0.9947 - val_loss: 0.0331 - val_y_start_loss: 0.0152 - val_y_end_loss: 0.0178 - val_y_start_binary_accuracy: 0.9956 - val_y_end_binary_accuracy: 0.9949
# Epoch 9/20
# 21984/21984 - 171s - loss: 0.0297 - y_start_loss: 0.0137 - y_end_loss: 0.0159 - y_start_binary_accuracy: 0.9958 - y_end_binary_accuracy: 0.9953 - val_loss: 0.0314 - val_y_start_loss: 0.0148 - val_y_end_loss: 0.0166 - val_y_start_binary_accuracy: 0.9955 - val_y_end_binary_accuracy: 0.9953
# Epoch 10/20
# 21984/21984 - 171s - loss: 0.0273 - y_start_loss: 0.0130 - y_end_loss: 0.0143 - y_start_binary_accuracy: 0.9959 - y_end_binary_accuracy: 0.9957 - val_loss: 0.0307 - val_y_start_loss: 0.0146 - val_y_end_loss: 0.0161 - val_y_start_binary_accuracy: 0.9956 - val_y_end_binary_accuracy: 0.9952
# Epoch 11/20
# 21984/21984 - 171s - loss: 0.0254 - y_start_loss: 0.0122 - y_end_loss: 0.0131 - y_start_binary_accuracy: 0.9961 - y_end_binary_accuracy: 0.9960 - val_loss: 0.0302 - val_y_start_loss: 0.0145 - val_y_end_loss: 0.0157 - val_y_start_binary_accuracy: 0.9955 - val_y_end_binary_accuracy: 0.9953
# Epoch 12/20
# 21984/21984 - 171s - loss: 0.0237 - y_start_loss: 0.0116 - y_end_loss: 0.0121 - y_start_binary_accuracy: 0.9962 - y_end_binary_accuracy: 0.9962 - val_loss: 0.0302 - val_y_start_loss: 0.0145 - val_y_end_loss: 0.0157 - val_y_start_binary_accuracy: 0.9955 - val_y_end_binary_accuracy: 0.9953
# Epoch 13/20
# 21984/21984 - 171s - loss: 0.0223 - y_start_loss: 0.0111 - y_end_loss: 0.0113 - y_start_binary_accuracy: 0.9963 - y_end_binary_accuracy: 0.9964 - val_loss: 0.0301 - val_y_start_loss: 0.0146 - val_y_end_loss: 0.0155 - val_y_start_binary_accuracy: 0.9954 - val_y_end_binary_accuracy: 0.9953
# Epoch 14/20
# 21984/21984 - 171s - loss: 0.0209 - y_start_loss: 0.0105 - y_end_loss: 0.0104 - y_start_binary_accuracy: 0.9965 - y_end_binary_accuracy: 0.9967 - val_loss: 0.0304 - val_y_start_loss: 0.0147 - val_y_end_loss: 0.0157 - val_y_start_binary_accuracy: 0.9954 - val_y_end_binary_accuracy: 0.9953
# Epoch 15/20
# 21984/21984 - 171s - loss: 0.0195 - y_start_loss: 0.0099 - y_end_loss: 0.0096 - y_start_binary_accuracy: 0.9966 - y_end_binary_accuracy: 0.9969 - val_loss: 0.0311 - val_y_start_loss: 0.0150 - val_y_end_loss: 0.0161 - val_y_start_binary_accuracy: 0.9953 - val_y_end_binary_accuracy: 0.9951
# Epoch 16/20
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 171s - loss: 0.0183 - y_start_loss: 0.0094 - y_end_loss: 0.0089 - y_start_binary_accuracy: 0.9967 - y_end_binary_accuracy: 0.9971 - val_loss: 0.0313 - val_y_start_loss: 0.0151 - val_y_end_loss: 0.0162 - val_y_start_binary_accuracy: 0.9954 - val_y_end_binary_accuracy: 0.9951
# Epoch 00016: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586521163.f3ba4226ee93.12.5431.v2
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-10_12-19-30/
# train/plugins/profile/2020-04-10_12-19-30/local.trace
# train/events.out.tfevents.1586521170.f3ba4226ee93.profile-empty
# validation/
# validation/events.out.tfevents.1586521343.f3ba4226ee93.12.24608.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4f8c4c1d607e> in <module>
#       1 sns.set(style="whitegrid")
# ----> 2 plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])
#
# /kaggle/usr/lib/tweet_utility_scripts/tweet_utility_scripts.py in plot_metrics(history, metric_list)
#      20
#      21     for index, metric in enumerate(metric_list):
# ---> 22         axes[index].plot(history[metric], label='Train %s' % metric)
#      23         axes[index].plot(history['val_%s' % metric], label='Validation %s' % metric)
#      24         axes[index].legend(loc='best', fontsize=16)
#
# KeyError: 'y_start_categorical_accuracy'

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], question_size, tokenizer), axis=1)
train["prediction"] = train["prediction"].apply(lambda x: '.' if x.strip() == '' else x)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], question_size, tokenizer), axis=1)
validation["prediction"] = validation["prediction"].apply(lambda x: '.' if x.strip() == '' else x)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.782712    0.647011          21984
# Sentiment neutral            0.976308    0.971245           8842
# Sentiment negative           0.647728    0.417730           6258
# Sentiment positive           0.656760    0.418251           6884
# 0 <= text < 10               0.980296    0.962500            203
# 10 <= text < 50              0.854482    0.742524           7823
# 50 <= text < 100             0.756284    0.613024           8858
# 100 <= text < 200            0.710658    0.552671           5100
# 0 <= selected text < 10      0.703564    0.417026           6326
# 10 <= selected text < 50     0.742064    0.642905           9575
# 50 <= selected text < 100    0.915906    0.860323           4075
# 100 <= selected text < 200   0.955580    0.905289           2008
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5496
# Sentiment neutral                          2275
# Sentiment negative                         1523
# Sentiment positive                         1698
# 0 <= text < 10                               40
# 10 <= text < 50                            1945
# 50 <= text < 100                           2201
# 100 <= text < 200                          1310
# 0 <= selected text < 10                    1492
# 10 <= selected text < 50                   2455
# 50 <= selected text < 100                  1042
# 100 <= selected text < 200                  507

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
# 5  cb280b3adb  _ kk`s  have fun eating lol, remember shaun lo...
# 6  8dd41515ff                                   definitley miley
# 7  60fa8ea66e         just going to shower. brb in 10 mins or so
# 8  bb4ac6eb31              back to work.. with no distractions..
# 9  2f858c20c3   cool, i used to live 5 houses to the left of ...
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
# 5                                                fun  positive        58
# 6                                   definitley miley   neutral        17
# 7         just going to shower. brb in 10 mins or so   neutral        42
# 8              back to work.. with no distractions..  positive        37
# 9                                              cool,  positive        86
#
#    selected_text_len    set  start  end  \
# 0                 95  train      4   39
# 1                 10  train      4    6
# 2                 23  train      4   11
# 3                  9  train      9   15
# 4                 41  train      4   17
# 5                  3  train     10   10
# 6                 16  train      4    8
# 7                 42  train      4   16
# 8                 37  train      4   14
# 9                  5  train      4    5
#
#                                           prediction  jaccard
# 0  cant stop playin` in my head  -- pussycat doll...      1.0
# 1                                         i hate you      1.0
# 2                            starbucks i`m lovin` it      1.0
# 3                                        .yummmmy!!!      0.0
# 4          wow.. purple leopard skin.  fieeerrceee..      1.0
# 5                                                fun      1.0
# 6                                   definitley miley      1.0
# 7         just going to shower. brb in 10 mins or so      1.0
# 8              back to work.. with no distractions..      1.0
# 9                                              cool,      1.0
# Validation set
#            textID                                               text  \
# 21984  3391184efc              loves the nice weather and 7:30 exams
# 21985  b35daf9677  okay, this weather isn`t 'cute sundress' frien...
# 21986  06e5249859                          woo hoo!! congratulations
# 21987  3cd4960670   thanks   got a hold of someone there who knew...
# 21988  92b75314ca  got back and putting in the laundry. we got in...
# 21989  7438c9c09a                    congrats on graduating college!
# 21990  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 21991  a4ede54987  it`s the weekend but 9 year old is grounded wh...
# 21992  35124a7481   it`s been fine for me for like, a week, but n...
# 21993  e4b6c9a295                      ntah, i really wanna be there
#
#                                            selected_text sentiment  text_len  \
# 21984                                              loves  positive        37
# 21985  okay, this weather isn`t 'cute sundress' frien...   neutral       130
# 21986                                    congratulations  positive        26
# 21987                                             thanks  positive        68
# 21988  got back and putting in the laundry. we got in...   neutral        95
# 21989                                           congrats  positive        32
# 21990  can you get me a sub from subway when ur on yo...   neutral        58
# 21991  it`s the weekend but 9 year old is grounded wh...   neutral        71
# 21992  it`s been fine for me for like, a week, but no...   neutral        68
# 21993                                              wanna  positive        30
#
#        selected_text_len         set  start  end  \
# 21984                  5  validation      4    4
# 21985                130  validation      4   38
# 21986                 15  validation      4    9
# 21987                  6  validation      4    4
# 21988                 95  validation      4   29
# 21989                  8  validation      4    6
# 21990                 58  validation      4   18
# 21991                 71  validation      4   19
# 21992                 67  validation      4   25
# 21993                  5  validation      4   11
#
#                                               prediction   jaccard
# 21984                                              loves  1.000000
# 21985  okay, this weather isn`t 'cute sundress' frien...  1.000000
# 21986                          woo hoo!! congratulations  0.333333
# 21987                                             thanks  1.000000
# 21988  got back and putting in the laundry. we got in...  1.000000
# 21989                                           congrats  1.000000
# 21990  can you get me a sub from subway when ur on yo...  1.000000
# 21991  it`s the weekend but 9 year old is grounded wh...  1.000000
# 21992  it`s been fine for me for like, a week, but no...  1.000000
# 21993                      ntah, i really wanna be there  0.166667
