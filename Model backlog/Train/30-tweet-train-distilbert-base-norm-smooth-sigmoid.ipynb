# %% [markdown]
# ## Dependencies

# %%
import json
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

y_train = y_train.astype('float')
y_valid = y_valid.astype('float')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
#
#    selected_text_len    set
# 0                 95  train
# 1                 10  train
# 2                 23  train
# 3                  9  train
# 4                 41  train
# hold_out/
# hold_out/y_valid.npy
# hold_out/x_train.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
model_path = 'model.h5'

config = {
  "MAX_LEN": 128,
  "BATCH_SIZE": 64,
  "EPOCHS": 20,
  "LEARNING_RATE": 1e-5,
  "ES_PATIENCE": 3,
  "question_size": 3,
  "smooth_factor": .25,
  "base_model_path": base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5',
  "config_path": base_path + 'distilbert-base-uncased-distilled-squad-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %%
dist = [pow(config['smooth_factor'], i) for i in range(1, config['MAX_LEN'])]
def smooth_labels_dist(y, dist=dist):
    center = y.argmax()
    y[center+1:] = dist[:len(y)-center-1]
    y[:center] = dist[::-1][-center:]
    
    return y

np.apply_along_axis(smooth_labels_dist, -1, y_train)
np.apply_along_axis(smooth_labels_dist, -1, y_valid)
# Out:
# array([[[3.90625000e-03, 1.56250000e-02, 6.25000000e-02, ...,
#          1.41494986e-73, 3.53737464e-74, 8.84343660e-75],
#         [3.90625000e-03, 1.56250000e-02, 6.25000000e-02, ...,
#          1.41494986e-73, 3.53737464e-74, 8.84343660e-75],
#         [3.81469727e-06, 1.52587891e-05, 6.10351562e-05, ...,
#          1.44890865e-70, 3.62227163e-71, 9.05567908e-72],
#         ...,
#         [8.27180613e-25, 3.30872245e-24, 1.32348898e-23, ...,
#          6.68191178e-52, 1.67047794e-52, 4.17619486e-53],
#         [3.90625000e-03, 1.56250000e-02, 6.25000000e-02, ...,
#          1.41494986e-73, 3.53737464e-74, 8.84343660e-75],
#         [6.10351562e-05, 2.44140625e-04, 9.76562500e-04, ...,
#          9.05567908e-72, 2.26391977e-72, 5.65979942e-73]],
#
#        [[3.90625000e-03, 1.56250000e-02, 6.25000000e-02, ...,
#          1.41494986e-73, 3.53737464e-74, 8.84343660e-75],
#         [1.32348898e-23, 5.29395592e-23, 2.11758237e-22, ...,
#          4.17619486e-53, 1.04404871e-53, 2.61012179e-54],
#         [3.81469727e-06, 1.52587891e-05, 6.10351562e-05, ...,
#          1.44890865e-70, 3.62227163e-71, 9.05567908e-72],
#         ...,
#         [2.06795153e-25, 8.27180613e-25, 3.30872245e-24, ...,
#          2.67276471e-51, 6.68191178e-52, 1.67047794e-52],
#         [2.27373675e-13, 9.09494702e-13, 3.63797881e-12, ...,
#          2.43086534e-63, 6.07716336e-64, 1.51929084e-64],
#         [6.10351562e-05, 2.44140625e-04, 9.76562500e-04, ...,
#          9.05567908e-72, 2.26391977e-72, 5.65979942e-73]]])

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='sigmoid', name='y_start')(x)     
    y_end = Dense(MAX_LEN, activation='sigmoid', name='y_end')(x)        
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

model = model_fn(config['MAX_LEN'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir='./')
es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/20
# 21984/21984 - 179s - loss: 0.4545 - y_start_loss: 0.2168 - y_end_loss: 0.2374 - y_start_binary_accuracy: 0.4289 - y_end_binary_accuracy: 0.3557 - val_loss: 0.2510 - val_y_start_loss: 0.1174 - val_y_end_loss: 0.1336 - val_y_start_binary_accuracy: 0.4387 - val_y_end_binary_accuracy: 0.3628
# Epoch 2/20
# 21984/21984 - 166s - loss: 0.1993 - y_start_loss: 0.0920 - y_end_loss: 0.1073 - y_start_binary_accuracy: 0.4390 - y_end_binary_accuracy: 0.3648 - val_loss: 0.1569 - val_y_start_loss: 0.0710 - val_y_end_loss: 0.0859 - val_y_start_binary_accuracy: 0.4377 - val_y_end_binary_accuracy: 0.3628
# Epoch 3/20
# 21984/21984 - 166s - loss: 0.1385 - y_start_loss: 0.0621 - y_end_loss: 0.0765 - y_start_binary_accuracy: 0.4386 - y_end_binary_accuracy: 0.3648 - val_loss: 0.1222 - val_y_start_loss: 0.0540 - val_y_end_loss: 0.0681 - val_y_start_binary_accuracy: 0.4376 - val_y_end_binary_accuracy: 0.3628
# Epoch 4/20
# 21984/21984 - 166s - loss: 0.1137 - y_start_loss: 0.0500 - y_end_loss: 0.0637 - y_start_binary_accuracy: 0.4388 - y_end_binary_accuracy: 0.3648 - val_loss: 0.1050 - val_y_start_loss: 0.0461 - val_y_end_loss: 0.0589 - val_y_start_binary_accuracy: 0.4377 - val_y_end_binary_accuracy: 0.3628
# Epoch 5/20
# 21984/21984 - 166s - loss: 0.0990 - y_start_loss: 0.0435 - y_end_loss: 0.0555 - y_start_binary_accuracy: 0.4389 - y_end_binary_accuracy: 0.3648 - val_loss: 0.0920 - val_y_start_loss: 0.0408 - val_y_end_loss: 0.0513 - val_y_start_binary_accuracy: 0.4380 - val_y_end_binary_accuracy: 0.3628
# Epoch 6/20
# 21984/21984 - 166s - loss: 0.0879 - y_start_loss: 0.0390 - y_end_loss: 0.0488 - y_start_binary_accuracy: 0.4390 - y_end_binary_accuracy: 0.3648 - val_loss: 0.0828 - val_y_start_loss: 0.0372 - val_y_end_loss: 0.0456 - val_y_start_binary_accuracy: 0.4380 - val_y_end_binary_accuracy: 0.3629
# Epoch 7/20
# 21984/21984 - 166s - loss: 0.0795 - y_start_loss: 0.0358 - y_end_loss: 0.0437 - y_start_binary_accuracy: 0.4390 - y_end_binary_accuracy: 0.3649 - val_loss: 0.0760 - val_y_start_loss: 0.0348 - val_y_end_loss: 0.0412 - val_y_start_binary_accuracy: 0.4379 - val_y_end_binary_accuracy: 0.3635
# Epoch 8/20
# 21984/21984 - 167s - loss: 0.0730 - y_start_loss: 0.0336 - y_end_loss: 0.0395 - y_start_binary_accuracy: 0.4390 - y_end_binary_accuracy: 0.3654 - val_loss: 0.0709 - val_y_start_loss: 0.0328 - val_y_end_loss: 0.0380 - val_y_start_binary_accuracy: 0.4380 - val_y_end_binary_accuracy: 0.3641
# Epoch 9/20
# 21984/21984 - 167s - loss: 0.0681 - y_start_loss: 0.0317 - y_end_loss: 0.0364 - y_start_binary_accuracy: 0.4390 - y_end_binary_accuracy: 0.3660 - val_loss: 0.0675 - val_y_start_loss: 0.0317 - val_y_end_loss: 0.0358 - val_y_start_binary_accuracy: 0.4380 - val_y_end_binary_accuracy: 0.3649
# Epoch 10/20
# 21984/21984 - 167s - loss: 0.0645 - y_start_loss: 0.0303 - y_end_loss: 0.0341 - y_start_binary_accuracy: 0.4391 - y_end_binary_accuracy: 0.3668 - val_loss: 0.0652 - val_y_start_loss: 0.0309 - val_y_end_loss: 0.0343 - val_y_start_binary_accuracy: 0.4382 - val_y_end_binary_accuracy: 0.3657
# Epoch 11/20
# 21984/21984 - 166s - loss: 0.0615 - y_start_loss: 0.0291 - y_end_loss: 0.0324 - y_start_binary_accuracy: 0.4392 - y_end_binary_accuracy: 0.3676 - val_loss: 0.0634 - val_y_start_loss: 0.0303 - val_y_end_loss: 0.0331 - val_y_start_binary_accuracy: 0.4381 - val_y_end_binary_accuracy: 0.3664
# Epoch 12/20
# 21984/21984 - 167s - loss: 0.0590 - y_start_loss: 0.0281 - y_end_loss: 0.0309 - y_start_binary_accuracy: 0.4392 - y_end_binary_accuracy: 0.3682 - val_loss: 0.0619 - val_y_start_loss: 0.0297 - val_y_end_loss: 0.0322 - val_y_start_binary_accuracy: 0.4383 - val_y_end_binary_accuracy: 0.3666
# Epoch 13/20
# 21984/21984 - 166s - loss: 0.0569 - y_start_loss: 0.0273 - y_end_loss: 0.0296 - y_start_binary_accuracy: 0.4394 - y_end_binary_accuracy: 0.3686 - val_loss: 0.0612 - val_y_start_loss: 0.0294 - val_y_end_loss: 0.0318 - val_y_start_binary_accuracy: 0.4383 - val_y_end_binary_accuracy: 0.3667
# Epoch 14/20
# 21984/21984 - 166s - loss: 0.0551 - y_start_loss: 0.0265 - y_end_loss: 0.0285 - y_start_binary_accuracy: 0.4395 - y_end_binary_accuracy: 0.3690 - val_loss: 0.0605 - val_y_start_loss: 0.0293 - val_y_end_loss: 0.0313 - val_y_start_binary_accuracy: 0.4383 - val_y_end_binary_accuracy: 0.3669
# Epoch 15/20
# 21984/21984 - 166s - loss: 0.0536 - y_start_loss: 0.0259 - y_end_loss: 0.0276 - y_start_binary_accuracy: 0.4396 - y_end_binary_accuracy: 0.3692 - val_loss: 0.0602 - val_y_start_loss: 0.0292 - val_y_end_loss: 0.0310 - val_y_start_binary_accuracy: 0.4384 - val_y_end_binary_accuracy: 0.3672
# Epoch 16/20
# 21984/21984 - 166s - loss: 0.0521 - y_start_loss: 0.0253 - y_end_loss: 0.0268 - y_start_binary_accuracy: 0.4397 - y_end_binary_accuracy: 0.3694 - val_loss: 0.0598 - val_y_start_loss: 0.0291 - val_y_end_loss: 0.0307 - val_y_start_binary_accuracy: 0.4385 - val_y_end_binary_accuracy: 0.3673
# Epoch 17/20
# 21984/21984 - 166s - loss: 0.0508 - y_start_loss: 0.0247 - y_end_loss: 0.0260 - y_start_binary_accuracy: 0.4399 - y_end_binary_accuracy: 0.3696 - val_loss: 0.0596 - val_y_start_loss: 0.0291 - val_y_end_loss: 0.0306 - val_y_start_binary_accuracy: 0.4385 - val_y_end_binary_accuracy: 0.3673
# Epoch 18/20
# 21984/21984 - 166s - loss: 0.0496 - y_start_loss: 0.0242 - y_end_loss: 0.0253 - y_start_binary_accuracy: 0.4400 - y_end_binary_accuracy: 0.3698 - val_loss: 0.0595 - val_y_start_loss: 0.0291 - val_y_end_loss: 0.0304 - val_y_start_binary_accuracy: 0.4385 - val_y_end_binary_accuracy: 0.3674
# Epoch 19/20
# 21984/21984 - 166s - loss: 0.0484 - y_start_loss: 0.0237 - y_end_loss: 0.0247 - y_start_binary_accuracy: 0.4401 - y_end_binary_accuracy: 0.3700 - val_loss: 0.0599 - val_y_start_loss: 0.0295 - val_y_end_loss: 0.0304 - val_y_start_binary_accuracy: 0.4387 - val_y_end_binary_accuracy: 0.3673
# Epoch 20/20
# 21984/21984 - 166s - loss: 0.0474 - y_start_loss: 0.0233 - y_end_loss: 0.0241 - y_start_binary_accuracy: 0.4403 - y_end_binary_accuracy: 0.3701 - val_loss: 0.0598 - val_y_start_loss: 0.0293 - val_y_end_loss: 0.0305 - val_y_start_binary_accuracy: 0.4386 - val_y_end_binary_accuracy: 0.3675

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586631899.9e7c0c181b02.13.5436.v2
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-11_19-05-10/
# train/plugins/profile/2020-04-11_19-05-10/local.trace
# train/events.out.tfevents.1586631910.9e7c0c181b02.profile-empty
# validation/
# validation/events.out.tfevents.1586632077.9e7c0c181b02.13.24191.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 
                                   'y_start_binary_accuracy', 'y_start_binary_accuracy'])

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)
tokenizer.save('./')
# Out:
# ['./vocab.txt']

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train["end"].clip(0, train["text_len"], inplace=True)
train["start"].clip(0, train["end"], inplace=True)

train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], config['question_size'], tokenizer), axis=1)
train["prediction"].fillna('', inplace=True)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation["end"].clip(0, validation["text_len"], inplace=True)
validation["start"].clip(0, validation["end"], inplace=True)

validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], config['question_size'], tokenizer), axis=1)
validation["prediction"].fillna('', inplace=True)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.792795    0.629759          21984
# Sentiment neutral            0.977127    0.968337           8842
# Sentiment negative           0.676719    0.393211           6258
# Sentiment positive           0.661554    0.388296           6884
# 0 <= text < 10               0.926929    0.820833            203
# 10 <= text < 50              0.848220    0.723243           7823
# 50 <= text < 100             0.775689    0.598981           8858
# 100 <= text < 200            0.732149    0.536837           5100
# 0 <= selected text < 10      0.698863    0.402030           6326
# 10 <= selected text < 50     0.763191    0.622239           9575
# 50 <= selected text < 100    0.925361    0.848486           4075
# 100 <= selected text < 200   0.960855    0.886796           2008
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5496
# Sentiment neutral                          2275
# Sentiment negative                         1523
# Sentiment positive                         1698
# 0 <= text < 10                               40
# 10 <= text < 50                            1945
# 50 <= text < 100                           2201
# 100 <= text < 200                          1310
# 0 <= selected text < 10                    1492
# 10 <= selected text < 50                   2455
# 50 <= selected text < 100                  1042
# 100 <= selected text < 200                  507

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
# 5  cb280b3adb  _ kk`s  have fun eating lol, remember shaun lo...
# 6  8dd41515ff                                   definitley miley
# 7  60fa8ea66e         just going to shower. brb in 10 mins or so
# 8  bb4ac6eb31              back to work.. with no distractions..
# 9  2f858c20c3   cool, i used to live 5 houses to the left of ...
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
# 5                                                fun  positive        58
# 6                                   definitley miley   neutral        17
# 7         just going to shower. brb in 10 mins or so   neutral        42
# 8              back to work.. with no distractions..  positive        37
# 9                                              cool,  positive        86
#
#    selected_text_len    set  start  end  \
# 0                 95  train      4   39
# 1                 10  train      4    6
# 2                 23  train      4   11
# 3                  9  train     10   15
# 4                 41  train      4   17
# 5                  3  train     10   10
# 6                 16  train      4    8
# 7                 42  train      4   16
# 8                 37  train      4   14
# 9                  5  train      4    5
#
#                                           prediction  jaccard
# 0  cant stop playin` in my head  -- pussycat doll...      1.0
# 1                                         i hate you      1.0
# 2                            starbucks i`m lovin` it      1.0
# 3                                         yummmmy!!!      0.0
# 4          wow.. purple leopard skin.  fieeerrceee..      1.0
# 5                                                fun      1.0
# 6                                   definitley miley      1.0
# 7         just going to shower. brb in 10 mins or so      1.0
# 8              back to work.. with no distractions..      1.0
# 9                                              cool,      1.0
# Validation set
#            textID                                               text  \
# 21984  3391184efc              loves the nice weather and 7:30 exams
# 21985  b35daf9677  okay, this weather isn`t 'cute sundress' frien...
# 21986  06e5249859                          woo hoo!! congratulations
# 21987  3cd4960670   thanks   got a hold of someone there who knew...
# 21988  92b75314ca  got back and putting in the laundry. we got in...
# 21989  7438c9c09a                    congrats on graduating college!
# 21990  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 21991  a4ede54987  it`s the weekend but 9 year old is grounded wh...
# 21992  35124a7481   it`s been fine for me for like, a week, but n...
# 21993  e4b6c9a295                      ntah, i really wanna be there
#
#                                            selected_text sentiment  text_len  \
# 21984                                              loves  positive        37
# 21985  okay, this weather isn`t 'cute sundress' frien...   neutral       130
# 21986                                    congratulations  positive        26
# 21987                                             thanks  positive        68
# 21988  got back and putting in the laundry. we got in...   neutral        95
# 21989                                           congrats  positive        32
# 21990  can you get me a sub from subway when ur on yo...   neutral        58
# 21991  it`s the weekend but 9 year old is grounded wh...   neutral        71
# 21992  it`s been fine for me for like, a week, but no...   neutral        68
# 21993                                              wanna  positive        30
#
#        selected_text_len         set  start  end  \
# 21984                  5  validation      4    5
# 21985                130  validation      4   38
# 21986                 15  validation      8    9
# 21987                  6  validation      4    4
# 21988                 95  validation      4   29
# 21989                  8  validation      4    6
# 21990                 58  validation      4   18
# 21991                 71  validation      4   19
# 21992                 67  validation      4   25
# 21993                  5  validation      4   11
#
#                                               prediction   jaccard
# 21984                                          loves the  0.500000
# 21985  okay, this weather isn`t 'cute sundress' frien...  1.000000
# 21986                                  ! congratulations  0.500000
# 21987                                             thanks  1.000000
# 21988  got back and putting in the laundry. we got in...  1.000000
# 21989                                           congrats  1.000000
# 21990  can you get me a sub from subway when ur on yo...  1.000000
# 21991  it`s the weekend but 9 year old is grounded wh...  1.000000
# 21992  it`s been fine for me for like, a week, but no...  1.000000
# 21993                      ntah, i really wanna be there  0.166667
