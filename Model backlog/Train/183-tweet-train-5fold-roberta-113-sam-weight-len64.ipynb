# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 27480
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5  imputed
# 0  train    False
# 1  train    False
# 2  train    False
# 3  train    False
# 4  train    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_start = 1e-4
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
warmup_steps=0
hold_max_steps=0
num_cycles=0.5
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [cosine_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, warmup_steps=warmup_steps, 
                                 hold_max_steps=hold_max_steps, lr_start=lr_start, lr_max=lr_max, 
                                 lr_min=lr_min, num_cycles=num_cycles) for x in rng]

sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print('Learning rate schedule: {:.3g} to {:.3g} to {:.3g}'.format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.52e-05

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, sample_weights, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  {'y_start': y_train[0], 'y_end': y_train[1]}, 
                                                  (sample_weights, sample_weights)))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []
get_sample_weights = lambda x: 1 if  x == 1 else 2

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_train_aux = np.load(base_data_path + 'x_train_aux.npy')[0]
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    # Train sample weights
    x_train_weights = np.array([get_sample_weights(x) for x in x_train_aux])
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: cosine_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), total_steps=total_steps, 
                                                                                  warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
                                                                                  lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, 
                                                                                  num_cycles=num_cycles))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, x_train_weights, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights('last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])

    # Make predictions (best model)
    model.load_weights(model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 193s - loss: 4.0615 - y_start_loss: 2.0118 - y_end_loss: 2.0498 - val_loss: 1.7125 - val_y_start_loss: 0.8553 - val_y_end_loss: 0.8572
# Epoch 2/4
# 687/687 - 180s - loss: 3.1105 - y_start_loss: 1.5930 - y_end_loss: 1.5175 - val_loss: 1.6049 - val_y_start_loss: 0.8302 - val_y_end_loss: 0.7747
# Epoch 3/4
# 687/687 - 179s - loss: 2.9165 - y_start_loss: 1.4556 - y_end_loss: 1.4608 - val_loss: 1.7425 - val_y_start_loss: 0.8529 - val_y_end_loss: 0.8896
# Epoch 4/4
# 687/687 - 179s - loss: 2.6595 - y_start_loss: 1.3319 - y_end_loss: 1.3276 - val_loss: 1.7129 - val_y_start_loss: 0.8482 - val_y_end_loss: 0.8647
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 193s - loss: 4.0715 - y_start_loss: 2.0207 - y_end_loss: 2.0508 - val_loss: 1.7132 - val_y_start_loss: 0.8697 - val_y_end_loss: 0.8435
# Epoch 2/4
# 687/687 - 180s - loss: 2.9803 - y_start_loss: 1.5497 - y_end_loss: 1.4306 - val_loss: 1.6371 - val_y_start_loss: 0.8527 - val_y_end_loss: 0.7844
# Epoch 3/4
# 687/687 - 179s - loss: 2.6596 - y_start_loss: 1.3835 - y_end_loss: 1.2761 - val_loss: 1.6772 - val_y_start_loss: 0.8555 - val_y_end_loss: 0.8217
# Epoch 4/4
# 687/687 - 179s - loss: 2.3114 - y_start_loss: 1.2171 - y_end_loss: 1.0942 - val_loss: 1.8246 - val_y_start_loss: 0.9240 - val_y_end_loss: 0.9007
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 191s - loss: 4.0893 - y_start_loss: 2.0405 - y_end_loss: 2.0488 - val_loss: 1.6805 - val_y_start_loss: 0.8302 - val_y_end_loss: 0.8503
# Epoch 2/4
# 687/687 - 180s - loss: 3.1473 - y_start_loss: 1.6224 - y_end_loss: 1.5249 - val_loss: 1.6373 - val_y_start_loss: 0.8403 - val_y_end_loss: 0.7970
# Epoch 3/4
# 687/687 - 180s - loss: 2.7624 - y_start_loss: 1.4459 - y_end_loss: 1.3166 - val_loss: 1.5952 - val_y_start_loss: 0.8209 - val_y_end_loss: 0.7743
# Epoch 4/4
# 687/687 - 179s - loss: 2.4797 - y_start_loss: 1.3033 - y_end_loss: 1.1764 - val_loss: 1.6386 - val_y_start_loss: 0.8421 - val_y_end_loss: 0.7966
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 192s - loss: 4.1425 - y_start_loss: 2.0119 - y_end_loss: 2.1306 - val_loss: 1.7243 - val_y_start_loss: 0.8826 - val_y_end_loss: 0.8417
# Epoch 2/4
# 687/687 - 180s - loss: 3.1853 - y_start_loss: 1.6159 - y_end_loss: 1.5695 - val_loss: 1.6191 - val_y_start_loss: 0.8426 - val_y_end_loss: 0.7765
# Epoch 3/4
# 687/687 - 179s - loss: 2.8609 - y_start_loss: 1.4852 - y_end_loss: 1.3757 - val_loss: 1.6392 - val_y_start_loss: 0.8642 - val_y_end_loss: 0.7750
# Epoch 4/4
# 687/687 - 180s - loss: 2.6316 - y_start_loss: 1.3651 - y_end_loss: 1.2665 - val_loss: 1.6135 - val_y_start_loss: 0.8472 - val_y_end_loss: 0.7663
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 192s - loss: 4.0033 - y_start_loss: 1.9845 - y_end_loss: 2.0188 - val_loss: 1.7048 - val_y_start_loss: 0.8472 - val_y_end_loss: 0.8575
# Epoch 2/4
# 687/687 - 180s - loss: 3.0604 - y_start_loss: 1.5600 - y_end_loss: 1.5005 - val_loss: 1.6353 - val_y_start_loss: 0.8232 - val_y_end_loss: 0.8121
# Epoch 3/4
# 687/687 - 179s - loss: 2.7363 - y_start_loss: 1.4214 - y_end_loss: 1.3149 - val_loss: 1.6531 - val_y_start_loss: 0.8746 - val_y_end_loss: 0.7785
# Epoch 4/4
# 687/687 - 179s - loss: 2.4040 - y_start_loss: 1.2538 - y_end_loss: 1.1502 - val_loss: 1.7498 - val_y_start_loss: 0.9362 - val_y_end_loss: 0.8136

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_77069042_9e07_11ea_b3ac_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_7addec2e_9e07_11ea_b3ac_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  imputed  \
# 0              10                      10    False
# 1              13                       3    False
# 2               6                       2    False
# 3               6                       3    False
# 4              17                       4    False
# 5              27                      27    False
# 6              17                       1    False
# 7               3                       3    False
# 8               3                       3    False
# 9              19                       7    False
# 10             27                      27    False
# 11             12                       1    False
# 12              9                       1    False
# 13             13                       1    False
# 14              8                       8    False
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
