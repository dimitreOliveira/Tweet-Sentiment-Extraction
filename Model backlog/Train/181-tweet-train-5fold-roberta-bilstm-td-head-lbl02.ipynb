# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'N_FOLDS': 5,
  "question_size": 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(last_hidden_state)
    x = layers.Dropout(.1)(x)
    
    x_start = layers.TimeDistributed(layers.Dense(1))(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.TimeDistributed(layers.Dense(1))(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights('last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])

    # Make predictions (best model)
    model.load_weights(model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 298s - loss: 4.3533 - y_start_loss: 2.1775 - y_end_loss: 2.1757 - val_loss: 4.0103 - val_y_start_loss: 2.0296 - val_y_end_loss: 1.9807
# Epoch 2/4
# 687/687 - 280s - loss: 3.9932 - y_start_loss: 2.0133 - y_end_loss: 1.9799 - val_loss: 3.9766 - val_y_start_loss: 2.0150 - val_y_end_loss: 1.9616
# Epoch 3/4
# 687/687 - 280s - loss: 3.9208 - y_start_loss: 1.9774 - y_end_loss: 1.9434 - val_loss: 3.9766 - val_y_start_loss: 2.0156 - val_y_end_loss: 1.9610
# Epoch 4/4
# 687/687 - 280s - loss: 3.8909 - y_start_loss: 1.9667 - y_end_loss: 1.9243 - val_loss: 3.9764 - val_y_start_loss: 2.0134 - val_y_end_loss: 1.9631
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 296s - loss: 4.3727 - y_start_loss: 2.1788 - y_end_loss: 2.1940 - val_loss: 4.0921 - val_y_start_loss: 2.0567 - val_y_end_loss: 2.0354
# Epoch 2/4
# 687/687 - 280s - loss: 3.9851 - y_start_loss: 2.0117 - y_end_loss: 1.9734 - val_loss: 4.0499 - val_y_start_loss: 2.0468 - val_y_end_loss: 2.0031
# Epoch 3/4
# 687/687 - 279s - loss: 3.9122 - y_start_loss: 1.9751 - y_end_loss: 1.9371 - val_loss: 4.0563 - val_y_start_loss: 2.0416 - val_y_end_loss: 2.0146
# Epoch 4/4
# 687/687 - 280s - loss: 3.8849 - y_start_loss: 1.9630 - y_end_loss: 1.9220 - val_loss: 4.0383 - val_y_start_loss: 2.0375 - val_y_end_loss: 2.0008
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 295s - loss: 4.3591 - y_start_loss: 2.1709 - y_end_loss: 2.1881 - val_loss: 4.0527 - val_y_start_loss: 2.0262 - val_y_end_loss: 2.0265
# Epoch 2/4
# 687/687 - 280s - loss: 3.9992 - y_start_loss: 2.0175 - y_end_loss: 1.9817 - val_loss: 3.9906 - val_y_start_loss: 2.0085 - val_y_end_loss: 1.9822
# Epoch 3/4
# 687/687 - 279s - loss: 3.9230 - y_start_loss: 1.9818 - y_end_loss: 1.9412 - val_loss: 3.9912 - val_y_start_loss: 2.0091 - val_y_end_loss: 1.9821
# Epoch 4/4
# 687/687 - 280s - loss: 3.9046 - y_start_loss: 1.9729 - y_end_loss: 1.9317 - val_loss: 3.9798 - val_y_start_loss: 1.9970 - val_y_end_loss: 1.9829
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 296s - loss: 4.3481 - y_start_loss: 2.1642 - y_end_loss: 2.1839 - val_loss: 4.0400 - val_y_start_loss: 2.0483 - val_y_end_loss: 1.9918
# Epoch 2/4
# 687/687 - 280s - loss: 4.0092 - y_start_loss: 2.0091 - y_end_loss: 2.0001 - val_loss: 4.0094 - val_y_start_loss: 2.0329 - val_y_end_loss: 1.9765
# Epoch 3/4
# 687/687 - 280s - loss: 3.9455 - y_start_loss: 1.9830 - y_end_loss: 1.9625 - val_loss: 3.9903 - val_y_start_loss: 2.0259 - val_y_end_loss: 1.9644
# Epoch 4/4
# 687/687 - 280s - loss: 3.9126 - y_start_loss: 1.9675 - y_end_loss: 1.9451 - val_loss: 3.9823 - val_y_start_loss: 2.0221 - val_y_end_loss: 1.9602
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 296s - loss: 4.3677 - y_start_loss: 2.1879 - y_end_loss: 2.1798 - val_loss: 4.0332 - val_y_start_loss: 2.0220 - val_y_end_loss: 2.0112
# Epoch 2/4
# 687/687 - 281s - loss: 3.9815 - y_start_loss: 2.0104 - y_end_loss: 1.9711 - val_loss: 3.9907 - val_y_start_loss: 2.0136 - val_y_end_loss: 1.9770
# Epoch 3/4
# 687/687 - 279s - loss: 3.9144 - y_start_loss: 1.9753 - y_end_loss: 1.9391 - val_loss: 4.0164 - val_y_start_loss: 2.0264 - val_y_end_loss: 1.9901
# Epoch 4/4
# 687/687 - 279s - loss: 3.8850 - y_start_loss: 1.9634 - y_end_loss: 1.9216 - val_loss: 4.0142 - val_y_start_loss: 2.0217 - val_y_end_loss: 1.9925

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_41e82976_9d75_11ea_9b86_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_45ff6d08_9d75_11ea_9b86_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  \
# 0              10                      10
# 1              13                       3
# 2               6                       2
# 3               6                       3
# 4              17                       4
# 5              27                      27
# 6              17                       1
# 7               3                       3
# 8               3                       3
# 9              19                       7
# 10             27                      27
# 11             12                       1
# 12              9                       1
# 13             13                       1
# 14              8                       8
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
