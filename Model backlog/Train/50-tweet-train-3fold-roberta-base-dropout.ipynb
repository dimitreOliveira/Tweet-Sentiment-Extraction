# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 16,
  "EPOCHS": 5,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(0.1)(last_state) 
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Dense(MAX_LEN, activation='softmax', name='y_start')(x_start)   

    x_end = layers.Dropout(0.1)(last_state) 
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Dense(MAX_LEN, activation='softmax', name='y_end')(x_end) 
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO),
                    validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO)),
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    steps_per_epoch=step_size,
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE'], AUTO))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE'], AUTO))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 1374 steps, validate for 343 steps
# Epoch 1/5
# 1374/1374 - 310s - loss: 5.3831 - y_start_loss: 2.0378 - y_end_loss: 3.3453 - y_start_categorical_accuracy: 0.5495 - y_end_categorical_accuracy: 0.1521 - val_loss: 3.9197 - val_y_start_loss: 1.5303 - val_y_end_loss: 2.3893 - val_y_start_categorical_accuracy: 0.5825 - val_y_end_categorical_accuracy: 0.3712
# Epoch 2/5
# 1374/1374 - 293s - loss: 3.4818 - y_start_loss: 1.5139 - y_end_loss: 1.9678 - y_start_categorical_accuracy: 0.5816 - y_end_categorical_accuracy: 0.4890 - val_loss: 3.0230 - val_y_start_loss: 1.4007 - val_y_end_loss: 1.6223 - val_y_start_categorical_accuracy: 0.6015 - val_y_end_categorical_accuracy: 0.6009
# Epoch 3/5
# 1374/1374 - 292s - loss: 2.8777 - y_start_loss: 1.3501 - y_end_loss: 1.5276 - y_start_categorical_accuracy: 0.6097 - y_end_categorical_accuracy: 0.6102 - val_loss: 2.7825 - val_y_start_loss: 1.3351 - val_y_end_loss: 1.4475 - val_y_start_categorical_accuracy: 0.6097 - val_y_end_categorical_accuracy: 0.6368
# Epoch 4/5
# 1374/1374 - 292s - loss: 2.5026 - y_start_loss: 1.2170 - y_end_loss: 1.2856 - y_start_categorical_accuracy: 0.6341 - y_end_categorical_accuracy: 0.6706 - val_loss: 2.5746 - val_y_start_loss: 1.2327 - val_y_end_loss: 1.3419 - val_y_start_categorical_accuracy: 0.6445 - val_y_end_categorical_accuracy: 0.6742
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 1374/1374 - 291s - loss: 2.2206 - y_start_loss: 1.1175 - y_end_loss: 1.1031 - y_start_categorical_accuracy: 0.6619 - y_end_categorical_accuracy: 0.7130 - val_loss: 2.5853 - val_y_start_loss: 1.2243 - val_y_end_loss: 1.3610 - val_y_start_categorical_accuracy: 0.6452 - val_y_end_categorical_accuracy: 0.6709
# Epoch 00005: early stopping
#
# FOLD: 2
# Train for 1374 steps, validate for 343 steps
# Epoch 1/5
# 1374/1374 - 308s - loss: 5.5154 - y_start_loss: 2.1250 - y_end_loss: 3.3904 - y_start_categorical_accuracy: 0.5399 - y_end_categorical_accuracy: 0.1294 - val_loss: 3.8888 - val_y_start_loss: 1.6521 - val_y_end_loss: 2.2366 - val_y_start_categorical_accuracy: 0.5738 - val_y_end_categorical_accuracy: 0.4060
# Epoch 2/5
# 1374/1374 - 293s - loss: 3.4891 - y_start_loss: 1.5371 - y_end_loss: 1.9520 - y_start_categorical_accuracy: 0.5806 - y_end_categorical_accuracy: 0.4671 - val_loss: 3.0837 - val_y_start_loss: 1.4422 - val_y_end_loss: 1.6415 - val_y_start_categorical_accuracy: 0.5827 - val_y_end_categorical_accuracy: 0.5926
# Epoch 3/5
# 1374/1374 - 292s - loss: 2.8113 - y_start_loss: 1.3504 - y_end_loss: 1.4609 - y_start_categorical_accuracy: 0.5997 - y_end_categorical_accuracy: 0.6129 - val_loss: 2.8239 - val_y_start_loss: 1.3326 - val_y_end_loss: 1.4914 - val_y_start_categorical_accuracy: 0.6148 - val_y_end_categorical_accuracy: 0.6440
# Epoch 4/5
# 1374/1374 - 292s - loss: 2.4486 - y_start_loss: 1.2189 - y_end_loss: 1.2297 - y_start_categorical_accuracy: 0.6289 - y_end_categorical_accuracy: 0.6740 - val_loss: 2.7371 - val_y_start_loss: 1.3178 - val_y_end_loss: 1.4192 - val_y_start_categorical_accuracy: 0.6241 - val_y_end_categorical_accuracy: 0.6485
# Epoch 5/5
# 1374/1374 - 292s - loss: 2.1509 - y_start_loss: 1.1022 - y_end_loss: 1.0487 - y_start_categorical_accuracy: 0.6569 - y_end_categorical_accuracy: 0.7167 - val_loss: 2.7079 - val_y_start_loss: 1.3128 - val_y_end_loss: 1.3951 - val_y_start_categorical_accuracy: 0.6266 - val_y_end_categorical_accuracy: 0.6512
#
# FOLD: 3
# Train for 1374 steps, validate for 343 steps
# Epoch 1/5
# 1374/1374 - 307s - loss: 6.0371 - y_start_loss: 2.3113 - y_end_loss: 3.7258 - y_start_categorical_accuracy: 0.5468 - y_end_categorical_accuracy: 0.0529 - val_loss: 6.1534 - val_y_start_loss: 2.2470 - val_y_end_loss: 3.9064 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0583
# Epoch 2/5
# 1374/1374 - 293s - loss: 5.4532 - y_start_loss: 2.0369 - y_end_loss: 3.4163 - y_start_categorical_accuracy: 0.5783 - y_end_categorical_accuracy: 0.0481 - val_loss: 5.1422 - val_y_start_loss: 1.8514 - val_y_end_loss: 3.2908 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0426
# Epoch 3/5
# 1374/1374 - 292s - loss: 5.0581 - y_start_loss: 1.7631 - y_end_loss: 3.2950 - y_start_categorical_accuracy: 0.5805 - y_end_categorical_accuracy: 0.0498 - val_loss: 4.9311 - val_y_start_loss: 1.7050 - val_y_end_loss: 3.2261 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0381
# Epoch 4/5
# 1374/1374 - 293s - loss: 4.9413 - y_start_loss: 1.7003 - y_end_loss: 3.2410 - y_start_categorical_accuracy: 0.5776 - y_end_categorical_accuracy: 0.0484 - val_loss: 4.8706 - val_y_start_loss: 1.6865 - val_y_end_loss: 3.1842 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0430
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 1374/1374 - 291s - loss: 5.0112 - y_start_loss: 1.7478 - y_end_loss: 3.2634 - y_start_categorical_accuracy: 0.5794 - y_end_categorical_accuracy: 0.0501 - val_loss: 4.9242 - val_y_start_loss: 1.7107 - val_y_end_loss: 3.2135 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0403
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col0 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col1 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col6 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col7 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow0_col8 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col0 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col1 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col3 {
#             color:  green;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col4 {
#             color:  green;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col5 {
#             color:  green;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col6 {
#             color:  green;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col7 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow1_col8 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col0 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col1 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col4 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col6 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col7 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow2_col8 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col0 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col1 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col4 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col6 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col7 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow3_col8 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col0 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col1 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col6 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col7 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow4_col8 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col0 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col1 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col6 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col7 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow5_col8 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col0 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col1 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col6 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col7 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow6_col8 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col0 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col1 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col6 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col7 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow7_col8 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col0 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col1 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col6 {
#             color:  orange;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col7 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow8_col8 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col0 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col1 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col2 {
#             color:  red;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col3 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col4 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col5 {
#             color:  black;
#         }    #T_fd49a152_81e3_11ea_8507_e39e3a83375arow9_col6 {
#             color:  black;
#         }

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        0.200000
# 2                                            bullying        0.200000
# 3                                      leave me alone        0.600000
# 4                                       sons of ****,        0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                           when he is all smiles and        0.428571
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                    journey!? wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                                running dangerously        0.250000
# 13                                             i lost        0.200000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.100000
# 2                                      bullying me...        0.400000
# 3                                      leave me alone        0.600000
# 4                                       sons of ****,        0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9             journey!? wow... u just became cooler.         0.600000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.300000
# 12                                        dangerously        0.125000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
#
#                         prediction_fold_3  jaccard_fold_3
# 0                  i`d have responded, if        0.571429
# 1                sooo sad i will miss you        0.600000
# 2               my boss is bullying me...        1.000000
# 3          what interview! leave me alone        1.000000
# 4               sons of ****, why couldn`        0.266667
# 5           http://www.dothebouncy.com/sm        0.000000
# 6               2am feedings for the baby        0.357143
# 7                              soooo high        1.000000
# 8                             both of you        1.000000
# 9          journey!? wow... u just became        0.500000
# 10                as much as i love to be        0.285714
# 11     i really really like the song love        0.600000
# 12  my sharpie is running dangerously low        0.750000
# 13          i want to go to music tonight        0.600000
# 14              test test from the lg env        0.666667
