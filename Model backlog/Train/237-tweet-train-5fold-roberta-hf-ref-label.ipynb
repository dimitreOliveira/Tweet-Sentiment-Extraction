# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean2/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean2/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean2/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean2/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean2/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean2/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 26882
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2 fold_3      fold_4 fold_5  \
# 0                      10       train  validation  train       train  train
# 1                       3  validation       train  train       train  train
# 2                       2       train       train  train  validation  train
# 3                       3       train       train  train  validation  train
# 4                       4       train       train  train  validation  train
#
#    imputed
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 5,
  'question_size': 0,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.96e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, name="qa_outputs")(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
# Datasets
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    
    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 189s - loss: 5.2201 - tf_op_layer_Squeeze_loss: 2.5001 - tf_op_layer_Squeeze_1_loss: 2.7200 - val_loss: 4.0202 - val_tf_op_layer_Squeeze_loss: 2.0246 - val_tf_op_layer_Squeeze_1_loss: 1.9956
# Epoch 2/7
# 672/672 - 176s - loss: 3.9325 - tf_op_layer_Squeeze_loss: 1.9742 - tf_op_layer_Squeeze_1_loss: 1.9583 - val_loss: 3.8827 - val_tf_op_layer_Squeeze_loss: 1.9650 - val_tf_op_layer_Squeeze_1_loss: 1.9176
# Epoch 3/7
# 672/672 - 176s - loss: 3.7939 - tf_op_layer_Squeeze_loss: 1.9123 - tf_op_layer_Squeeze_1_loss: 1.8816 - val_loss: 3.8718 - val_tf_op_layer_Squeeze_loss: 1.9571 - val_tf_op_layer_Squeeze_1_loss: 1.9147
# Epoch 4/7
# 672/672 - 176s - loss: 3.7445 - tf_op_layer_Squeeze_loss: 1.8921 - tf_op_layer_Squeeze_1_loss: 1.8524 - val_loss: 3.8619 - val_tf_op_layer_Squeeze_loss: 1.9614 - val_tf_op_layer_Squeeze_1_loss: 1.9004
# Epoch 5/7
# 672/672 - 176s - loss: 3.7201 - tf_op_layer_Squeeze_loss: 1.8792 - tf_op_layer_Squeeze_1_loss: 1.8409 - val_loss: 3.8597 - val_tf_op_layer_Squeeze_loss: 1.9599 - val_tf_op_layer_Squeeze_1_loss: 1.8998
# Epoch 6/7
# 672/672 - 174s - loss: 3.7122 - tf_op_layer_Squeeze_loss: 1.8778 - tf_op_layer_Squeeze_1_loss: 1.8344 - val_loss: 3.8645 - val_tf_op_layer_Squeeze_loss: 1.9624 - val_tf_op_layer_Squeeze_1_loss: 1.9021
# Epoch 7/7
# 672/672 - 176s - loss: 3.6962 - tf_op_layer_Squeeze_loss: 1.8670 - tf_op_layer_Squeeze_1_loss: 1.8292 - val_loss: 3.8485 - val_tf_op_layer_Squeeze_loss: 1.9540 - val_tf_op_layer_Squeeze_1_loss: 1.8945
#
# FOLD: 2
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 188s - loss: 5.2177 - tf_op_layer_Squeeze_2_loss: 2.5008 - tf_op_layer_Squeeze_3_loss: 2.7169 - val_loss: 4.0138 - val_tf_op_layer_Squeeze_2_loss: 2.0031 - val_tf_op_layer_Squeeze_3_loss: 2.0106
# Epoch 2/7
# 672/672 - 176s - loss: 3.9352 - tf_op_layer_Squeeze_2_loss: 1.9778 - tf_op_layer_Squeeze_3_loss: 1.9574 - val_loss: 3.8784 - val_tf_op_layer_Squeeze_2_loss: 1.9512 - val_tf_op_layer_Squeeze_3_loss: 1.9272
# Epoch 3/7
# 672/672 - 176s - loss: 3.8026 - tf_op_layer_Squeeze_2_loss: 1.9194 - tf_op_layer_Squeeze_3_loss: 1.8832 - val_loss: 3.8459 - val_tf_op_layer_Squeeze_2_loss: 1.9368 - val_tf_op_layer_Squeeze_3_loss: 1.9091
# Epoch 4/7
# 672/672 - 174s - loss: 3.7450 - tf_op_layer_Squeeze_2_loss: 1.8938 - tf_op_layer_Squeeze_3_loss: 1.8512 - val_loss: 3.8576 - val_tf_op_layer_Squeeze_2_loss: 1.9467 - val_tf_op_layer_Squeeze_3_loss: 1.9109
# Epoch 5/7
# 672/672 - 176s - loss: 3.7313 - tf_op_layer_Squeeze_2_loss: 1.8838 - tf_op_layer_Squeeze_3_loss: 1.8475 - val_loss: 3.8398 - val_tf_op_layer_Squeeze_2_loss: 1.9379 - val_tf_op_layer_Squeeze_3_loss: 1.9019
# Epoch 6/7
# 672/672 - 176s - loss: 3.7228 - tf_op_layer_Squeeze_2_loss: 1.8815 - tf_op_layer_Squeeze_3_loss: 1.8413 - val_loss: 3.8343 - val_tf_op_layer_Squeeze_2_loss: 1.9372 - val_tf_op_layer_Squeeze_3_loss: 1.8971
# Epoch 7/7
# 672/672 - 174s - loss: 3.6996 - tf_op_layer_Squeeze_2_loss: 1.8746 - tf_op_layer_Squeeze_3_loss: 1.8250 - val_loss: 3.8349 - val_tf_op_layer_Squeeze_2_loss: 1.9365 - val_tf_op_layer_Squeeze_3_loss: 1.8984
#
# FOLD: 3
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 187s - loss: 5.2516 - tf_op_layer_Squeeze_4_loss: 2.5286 - tf_op_layer_Squeeze_5_loss: 2.7230 - val_loss: 4.0166 - val_tf_op_layer_Squeeze_4_loss: 1.9987 - val_tf_op_layer_Squeeze_5_loss: 2.0179
# Epoch 2/7
# 672/672 - 176s - loss: 3.9556 - tf_op_layer_Squeeze_4_loss: 1.9772 - tf_op_layer_Squeeze_5_loss: 1.9784 - val_loss: 3.8523 - val_tf_op_layer_Squeeze_4_loss: 1.9420 - val_tf_op_layer_Squeeze_5_loss: 1.9103
# Epoch 3/7
# 672/672 - 176s - loss: 3.8112 - tf_op_layer_Squeeze_4_loss: 1.9173 - tf_op_layer_Squeeze_5_loss: 1.8940 - val_loss: 3.8190 - val_tf_op_layer_Squeeze_4_loss: 1.9330 - val_tf_op_layer_Squeeze_5_loss: 1.8860
# Epoch 4/7
# 672/672 - 176s - loss: 3.7555 - tf_op_layer_Squeeze_4_loss: 1.8914 - tf_op_layer_Squeeze_5_loss: 1.8641 - val_loss: 3.8163 - val_tf_op_layer_Squeeze_4_loss: 1.9332 - val_tf_op_layer_Squeeze_5_loss: 1.8832
# Epoch 5/7
# 672/672 - 174s - loss: 3.7209 - tf_op_layer_Squeeze_4_loss: 1.8769 - tf_op_layer_Squeeze_5_loss: 1.8440 - val_loss: 3.8243 - val_tf_op_layer_Squeeze_4_loss: 1.9370 - val_tf_op_layer_Squeeze_5_loss: 1.8873
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 175s - loss: 3.7301 - tf_op_layer_Squeeze_4_loss: 1.8820 - tf_op_layer_Squeeze_5_loss: 1.8482 - val_loss: 3.8202 - val_tf_op_layer_Squeeze_4_loss: 1.9332 - val_tf_op_layer_Squeeze_5_loss: 1.8870
# Epoch 00006: early stopping
#
# FOLD: 4
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 189s - loss: 5.2763 - tf_op_layer_Squeeze_6_loss: 2.5417 - tf_op_layer_Squeeze_7_loss: 2.7345 - val_loss: 4.0187 - val_tf_op_layer_Squeeze_6_loss: 2.0122 - val_tf_op_layer_Squeeze_7_loss: 2.0065
# Epoch 2/7
# 672/672 - 176s - loss: 3.9573 - tf_op_layer_Squeeze_6_loss: 1.9832 - tf_op_layer_Squeeze_7_loss: 1.9741 - val_loss: 3.8772 - val_tf_op_layer_Squeeze_6_loss: 1.9519 - val_tf_op_layer_Squeeze_7_loss: 1.9253
# Epoch 3/7
# 672/672 - 176s - loss: 3.8160 - tf_op_layer_Squeeze_6_loss: 1.9197 - tf_op_layer_Squeeze_7_loss: 1.8964 - val_loss: 3.8506 - val_tf_op_layer_Squeeze_6_loss: 1.9430 - val_tf_op_layer_Squeeze_7_loss: 1.9077
# Epoch 4/7
# 672/672 - 176s - loss: 3.7697 - tf_op_layer_Squeeze_6_loss: 1.9038 - tf_op_layer_Squeeze_7_loss: 1.8659 - val_loss: 3.8353 - val_tf_op_layer_Squeeze_6_loss: 1.9343 - val_tf_op_layer_Squeeze_7_loss: 1.9010
# Epoch 5/7
# 672/672 - 174s - loss: 3.7433 - tf_op_layer_Squeeze_6_loss: 1.8896 - tf_op_layer_Squeeze_7_loss: 1.8537 - val_loss: 3.8478 - val_tf_op_layer_Squeeze_6_loss: 1.9414 - val_tf_op_layer_Squeeze_7_loss: 1.9063
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 174s - loss: 3.7329 - tf_op_layer_Squeeze_6_loss: 1.8855 - tf_op_layer_Squeeze_7_loss: 1.8473 - val_loss: 3.8412 - val_tf_op_layer_Squeeze_6_loss: 1.9382 - val_tf_op_layer_Squeeze_7_loss: 1.9029
# Epoch 00006: early stopping
#
# FOLD: 5
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 187s - loss: 5.2128 - tf_op_layer_Squeeze_8_loss: 2.5034 - tf_op_layer_Squeeze_9_loss: 2.7095 - val_loss: 4.0752 - val_tf_op_layer_Squeeze_8_loss: 2.0352 - val_tf_op_layer_Squeeze_9_loss: 2.0400
# Epoch 2/7
# 672/672 - 176s - loss: 3.9791 - tf_op_layer_Squeeze_8_loss: 1.9965 - tf_op_layer_Squeeze_9_loss: 1.9826 - val_loss: 3.8684 - val_tf_op_layer_Squeeze_8_loss: 1.9470 - val_tf_op_layer_Squeeze_9_loss: 1.9214
# Epoch 3/7
# 672/672 - 176s - loss: 3.8238 - tf_op_layer_Squeeze_8_loss: 1.9267 - tf_op_layer_Squeeze_9_loss: 1.8971 - val_loss: 3.8498 - val_tf_op_layer_Squeeze_8_loss: 1.9367 - val_tf_op_layer_Squeeze_9_loss: 1.9130
# Epoch 4/7
# 672/672 - 176s - loss: 3.7703 - tf_op_layer_Squeeze_8_loss: 1.9042 - tf_op_layer_Squeeze_9_loss: 1.8661 - val_loss: 3.8376 - val_tf_op_layer_Squeeze_8_loss: 1.9329 - val_tf_op_layer_Squeeze_9_loss: 1.9047
# Epoch 5/7
# 672/672 - 176s - loss: 3.7531 - tf_op_layer_Squeeze_8_loss: 1.8949 - tf_op_layer_Squeeze_9_loss: 1.8582 - val_loss: 3.8349 - val_tf_op_layer_Squeeze_8_loss: 1.9302 - val_tf_op_layer_Squeeze_9_loss: 1.9047
# Epoch 6/7
# 672/672 - 176s - loss: 3.7344 - tf_op_layer_Squeeze_8_loss: 1.8844 - tf_op_layer_Squeeze_9_loss: 1.8500 - val_loss: 3.8313 - val_tf_op_layer_Squeeze_8_loss: 1.9277 - val_tf_op_layer_Squeeze_9_loss: 1.9035
# Epoch 7/7
# 672/672 - 176s - loss: 3.7379 - tf_op_layer_Squeeze_8_loss: 1.8878 - tf_op_layer_Squeeze_9_loss: 1.8501 - val_loss: 3.8295 - val_tf_op_layer_Squeeze_8_loss: 1.9292 - val_tf_op_layer_Squeeze_9_loss: 1.9003

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col10 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_fd86a83a_a54d_11ea_b786_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              10                      10  1.000000      1.000000
# 1              13                       3  0.200000      0.500000
# 2               6                       2  0.166667      0.400000
# 3               6                       3  0.600000      1.000000
# 4              17                       4  0.214286      1.000000
# 5              27                      27  1.000000      0.966667
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              19                       7  0.500000      0.840000
# 10             27                      27  1.000000      1.000000
# 11             12                       1  0.100000      0.466667
# 12              9                       1  0.125000      0.750000
# 13             13                       1  0.100000      1.000000
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_2  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_3  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                             dangerously low on ink
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_4  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                    dangerously low
# 13                                               lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_5
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
