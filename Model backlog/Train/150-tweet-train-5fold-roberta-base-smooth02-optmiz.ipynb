# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
# fold_1/
# fold_1/y_valid.npy
# fold_1/x_valid_aux.npy
# fold_1/y_train_mask.npy
# fold_1/x_train_aux.npy
# fold_1/x_valid.npy
# fold_1/x_valid_aux2.npy
# fold_1/y_valid_aux.npy
# fold_1/y_train.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_mask.npy
# fold_1/x_train.npy
# fold_1/x_train_aux2.npy
# fold_2/
# fold_2/y_valid.npy
# fold_2/x_valid_aux.npy
# fold_2/y_train_mask.npy
# fold_2/x_train_aux.npy
# fold_2/x_valid.npy
# fold_2/x_valid_aux2.npy
# fold_2/y_valid_aux.npy
# fold_2/y_train.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_mask.npy
# fold_2/x_train.npy
# fold_2/x_train_aux2.npy
# fold_3/
# fold_3/y_valid.npy
# fold_3/x_valid_aux.npy
# fold_3/y_train_mask.npy
# fold_3/x_train_aux.npy
# fold_3/x_valid.npy
# fold_3/x_valid_aux2.npy
# fold_3/y_valid_aux.npy
# fold_3/y_train.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_mask.npy
# fold_3/x_train.npy
# fold_3/x_train_aux2.npy
# fold_4/
# fold_4/y_valid.npy
# fold_4/x_valid_aux.npy
# fold_4/y_train_mask.npy
# fold_4/x_train_aux.npy
# fold_4/x_valid.npy
# fold_4/x_valid_aux2.npy
# fold_4/y_valid_aux.npy
# fold_4/y_train.npy
# fold_4/y_train_aux.npy
# fold_4/y_valid_mask.npy
# fold_4/x_train.npy
# fold_4/x_train_aux2.npy
# fold_5/
# fold_5/y_valid.npy
# fold_5/x_valid_aux.npy
# fold_5/y_train_mask.npy
# fold_5/x_train_aux.npy
# fold_5/x_valid.npy
# fold_5/x_valid_aux2.npy
# fold_5/y_valid_aux.npy
# fold_5/y_train.npy
# fold_5/y_train_aux.npy
# fold_5/y_valid_mask.npy
# fold_5/x_train.npy
# fold_5/x_train_aux2.npy

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 5,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 1,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn_end(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32)//step_size))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy

    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end, }
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=True)
    
    history_list.append(history)
    model.load_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 282.6s loss: 4.4447 loss_start: 2.2114 loss_end: 2.2332 val_loss: 1.9583 val_loss_start: 1.0040 val_loss_end: 0.9543
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/5
# time: 267.0s loss: 4.0104 loss_start: 2.0179 loss_end: 1.9925 val_loss: 1.8876 val_loss_start: 0.9837 val_loss_end: 0.9040
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/5
# time: 267.1s loss: 3.9030 loss_start: 1.9681 loss_end: 1.9350 val_loss: 1.8472 val_loss_start: 0.9503 val_loss_end: 0.8969
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 4/5
# time: 267.3s loss: 3.8427 loss_start: 1.9436 loss_end: 1.8991 val_loss: 1.8670 val_loss_start: 0.9643 val_loss_end: 0.9027
# Epoch 00004: early stopping
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 281.5s loss: 4.4398 loss_start: 2.2081 loss_end: 2.2317 val_loss: 2.0004 val_loss_start: 1.0102 val_loss_end: 0.9902
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/5
# time: 267.7s loss: 3.9958 loss_start: 2.0185 loss_end: 1.9773 val_loss: 1.8871 val_loss_start: 0.9733 val_loss_end: 0.9138
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 3/5
# time: 267.3s loss: 3.8999 loss_start: 1.9725 loss_end: 1.9274 val_loss: 1.9527 val_loss_start: 1.0181 val_loss_end: 0.9346
# Epoch 00003: early stopping
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 280.7s loss: 4.5266 loss_start: 2.2516 loss_end: 2.2750 val_loss: 1.9524 val_loss_start: 0.9792 val_loss_end: 0.9732
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/5
# time: 266.4s loss: 4.0443 loss_start: 2.0425 loss_end: 2.0018 val_loss: 1.8887 val_loss_start: 0.9575 val_loss_end: 0.9312
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/5
# time: 266.9s loss: 3.9361 loss_start: 1.9904 loss_end: 1.9457 val_loss: 1.8308 val_loss_start: 0.9415 val_loss_end: 0.8893
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 4/5
# time: 266.6s loss: 3.8822 loss_start: 1.9631 loss_end: 1.9191 val_loss: 1.8618 val_loss_start: 0.9654 val_loss_end: 0.8964
# Epoch 00004: early stopping
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 280.3s loss: 4.4573 loss_start: 2.1973 loss_end: 2.2600 val_loss: 1.9711 val_loss_start: 1.0087 val_loss_end: 0.9624
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/5
# time: 266.6s loss: 4.0333 loss_start: 2.0086 loss_end: 2.0247 val_loss: 1.9149 val_loss_start: 0.9782 val_loss_end: 0.9367
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 3/5
# time: 266.7s loss: 3.9099 loss_start: 1.9615 loss_end: 1.9485 val_loss: 1.8925 val_loss_start: 0.9910 val_loss_end: 0.9015
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 4/5
# time: 266.8s loss: 3.8365 loss_start: 1.9279 loss_end: 1.9085 val_loss: 1.8967 val_loss_start: 1.0010 val_loss_end: 0.8957
# Epoch 00004: early stopping
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 280.2s loss: 4.4030 loss_start: 2.2000 loss_end: 2.2030 val_loss: 2.0426 val_loss_start: 1.0120 val_loss_end: 1.0306
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/5
# time: 266.6s loss: 4.0071 loss_start: 2.0039 loss_end: 2.0032 val_loss: 1.9091 val_loss_start: 0.9770 val_loss_end: 0.9321
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 3/5
# time: 267.0s loss: 3.8906 loss_start: 1.9611 loss_end: 1.9295 val_loss: 1.9020 val_loss_start: 0.9800 val_loss_end: 0.9220
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 4/5
# time: 266.6s loss: 3.8338 loss_start: 1.9384 loss_end: 1.8954 val_loss: 1.8925 val_loss_start: 0.9872 val_loss_end: 0.9053
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 5/5
# time: 266.6s loss: 3.8114 loss_start: 1.9271 loss_end: 1.8843 val_loss: 1.8972 val_loss_start: 0.9841 val_loss_end: 0.9131
# Training finished saved model weights at "last_model_fold_5.h5"

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_695270b0_96fa_11ea_a102_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_695270b0_96fa_11ea_a102_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                           my boss is bullying me...        0.166667
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
