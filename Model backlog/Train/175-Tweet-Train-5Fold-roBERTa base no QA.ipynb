# %%
# !nvidia-smi
# Out:
# Fri May 22 14:55:01 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 645kB 5.9MB/s
#      |████████████████████████████████| 1.1MB 16.7MB/s
#      |████████████████████████████████| 890kB 33.8MB/s
#      |████████████████████████████████| 3.8MB 40.7MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/167-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
import tweet_utility_preprocess_roberta_scripts_text as preprocess_text
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_96/no_qa_fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 16 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 5,
  "question_size": 0,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train']) *2
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9993

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)

    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    base_data_path = 'fold_%d/' % (n_fold)

    # Load data
    x_train = np.load('no_qa_' + base_data_path + 'x_train.npy')
    y_train = np.load('no_qa_' + base_data_path + 'y_train.npy')
    x_valid = np.load('no_qa_' + base_data_path + 'x_valid.npy')
    y_valid = np.load('no_qa_' + base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0])
                loss_end = loss_fn(y['y_end'], probabilities[1])
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32)//step_size, warmup_steps=1, 
                                                                                       lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         (MODEL_BASE_PATH + model_path), save_last=False)
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions (last model)
    x_train = np.load('no_qa_' + base_data_path + 'x_train.npy')
    x_valid = np.load('no_qa_' + base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: preprocess_text.decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(MODEL_BASE_PATH + model_path)
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: preprocess_text.decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:From <ipython-input-14-8a8b90ffa159>:42: StrategyBase.experimental_run_v2 (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# renamed to `run`
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 281.2s loss: 2.6211 loss_start: 1.2927 loss_end: 1.3284 val_loss: 2.1568 val_loss_start: 1.0774 val_loss_end: 1.0794
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_1.h5"
#
# EPOCH 2/5
# time: 268.3s loss: 2.0956 loss_start: 1.0544 loss_end: 1.0412 val_loss: 2.0446 val_loss_start: 1.0514 val_loss_end: 0.9932
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_1.h5"
#
# EPOCH 3/5
# time: 271.0s loss: 1.8510 loss_start: 0.9460 loss_end: 0.9050 val_loss: 2.2133 val_loss_start: 1.1348 val_loss_end: 1.0784
#
# EPOCH 4/5
# time: 266.3s loss: 1.6078 loss_start: 0.8377 loss_end: 0.7701 val_loss: 2.0830 val_loss_start: 1.0686 val_loss_end: 1.0143
#
# EPOCH 5/5
# time: 266.4s loss: 1.3839 loss_start: 0.7259 loss_end: 0.6580 val_loss: 2.3356 val_loss_start: 1.2185 val_loss_end: 1.1171
# Training finished
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 280.9s loss: 2.5490 loss_start: 1.2548 loss_end: 1.2942 val_loss: 2.2410 val_loss_start: 1.1384 val_loss_end: 1.1026
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_2.h5"
#
# EPOCH 2/5
# time: 268.2s loss: 2.0384 loss_start: 1.0350 loss_end: 1.0034 val_loss: 2.1394 val_loss_start: 1.1017 val_loss_end: 1.0377
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_2.h5"
#
# EPOCH 3/5
# time: 270.7s loss: 1.7879 loss_start: 0.9260 loss_end: 0.8619 val_loss: 2.1372 val_loss_start: 1.0998 val_loss_end: 1.0374
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_2.h5"
#
# EPOCH 4/5
# time: 270.6s loss: 1.5594 loss_start: 0.8233 loss_end: 0.7361 val_loss: 2.3140 val_loss_start: 1.1172 val_loss_end: 1.1968
#
# EPOCH 5/5
# time: 266.0s loss: 1.3465 loss_start: 0.7161 loss_end: 0.6305 val_loss: 2.3082 val_loss_start: 1.1900 val_loss_end: 1.1182
# Training finished
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 282.6s loss: 2.5883 loss_start: 1.2860 loss_end: 1.3023 val_loss: 2.1927 val_loss_start: 1.0759 val_loss_end: 1.1168
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_3.h5"
#
# EPOCH 2/5
# time: 268.8s loss: 2.0806 loss_start: 1.0603 loss_end: 1.0203 val_loss: 2.0757 val_loss_start: 1.0345 val_loss_end: 1.0412
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_3.h5"
#
# EPOCH 3/5
# time: 271.5s loss: 1.8223 loss_start: 0.9442 loss_end: 0.8782 val_loss: 2.1038 val_loss_start: 1.1071 val_loss_end: 0.9967
#
# EPOCH 4/5
# time: 266.5s loss: 1.6052 loss_start: 0.8420 loss_end: 0.7632 val_loss: 2.3004 val_loss_start: 1.1663 val_loss_end: 1.1341
#
# EPOCH 5/5
# time: 266.4s loss: 1.3715 loss_start: 0.7296 loss_end: 0.6419 val_loss: 2.4087 val_loss_start: 1.2020 val_loss_end: 1.2067
# Training finished
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 281.6s loss: 2.5577 loss_start: 1.2537 loss_end: 1.3040 val_loss: 2.1868 val_loss_start: 1.1090 val_loss_end: 1.0778
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_4.h5"
#
# EPOCH 2/5
# time: 268.1s loss: 2.1023 loss_start: 1.0527 loss_end: 1.0496 val_loss: 2.1483 val_loss_start: 1.0961 val_loss_end: 1.0522
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_4.h5"
#
# EPOCH 3/5
# time: 271.0s loss: 1.8295 loss_start: 0.9397 loss_end: 0.8898 val_loss: 2.0679 val_loss_start: 1.0726 val_loss_end: 0.9953
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_4.h5"
#
# EPOCH 4/5
# time: 270.9s loss: 1.6170 loss_start: 0.8386 loss_end: 0.7784 val_loss: 2.2251 val_loss_start: 1.1857 val_loss_end: 1.0393
#
# EPOCH 5/5
# time: 265.7s loss: 1.4004 loss_start: 0.7324 loss_end: 0.6680 val_loss: 2.2885 val_loss_start: 1.1943 val_loss_end: 1.0942
# Training finished
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 281.0s loss: 2.5624 loss_start: 1.2578 loss_end: 1.3046 val_loss: 2.1118 val_loss_start: 1.0502 val_loss_end: 1.0616
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_5.h5"
#
# EPOCH 2/5
# time: 267.5s loss: 2.0468 loss_start: 1.0343 loss_end: 1.0124 val_loss: 2.0705 val_loss_start: 1.0550 val_loss_end: 1.0155
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/167-roBERTa_base/model_fold_5.h5"
#
# EPOCH 3/5
# time: 269.8s loss: 1.8051 loss_start: 0.9263 loss_end: 0.8788 val_loss: 2.1500 val_loss_start: 1.1308 val_loss_end: 1.0192
#
# EPOCH 4/5
# time: 265.2s loss: 1.5833 loss_start: 0.8296 loss_end: 0.7537 val_loss: 2.1550 val_loss_start: 1.1267 val_loss_end: 1.0282
#
# EPOCH 5/5
# time: 265.2s loss: 1.3712 loss_start: 0.7218 loss_end: 0.6493 val_loss: 2.3376 val_loss_start: 1.2212 val_loss_end: 1.1165
# Training finished

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col1 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col6 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col8 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col10 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row1_col12 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col1 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col6 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_08b30e8a_9c50_11ea_b4ec_0242ac1c00

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col1 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col4 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col6 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col8 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col10 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row1_col12 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col1 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col6 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col7 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_0c067e5a_9c50_11ea_b4ec_0242ac1c0

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       0.500000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       1.000000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       1.000000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 16 columns]
