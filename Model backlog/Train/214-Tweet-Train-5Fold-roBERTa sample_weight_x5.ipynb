# %%
# !nvidia-smi
# Out:
# Sat May 30 12:15:33 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 4.7MB/s
#      |████████████████████████████████| 3.8MB 25.5MB/s
#      |████████████████████████████████| 890kB 61.6MB/s
#      |████████████████████████████████| 1.1MB 54.2MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/214-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size * 1
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]
    
    x = layers.Dropout(.1)(h11)
    
    start_logits = layers.Dense(1, name="start_logit", use_bias=False)(x)
    start_logits = layers.Flatten()(start_logits)

    end_logits = layers.Dense(1, name="end_logit", use_bias=False)(x)
    end_logits = layers.Flatten()(end_logits)

    start_probs = layers.Activation('softmax', name='y_start')(start_logits)
    end_probs = layers.Activation('softmax', name='y_end')(end_logits)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_probs, end_probs])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, sample_weights, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  {'y_start': y_train[0], 'y_end': y_train[1]}, 
                                                  (sample_weights, sample_weights)))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []
get_sample_weights = lambda x: 1 if  x == 1 else 5

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    x_train_aux = np.load(base_data_path + 'x_train_aux.npy')[0]
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    # Train sample weights
    x_train_weights = np.array([get_sample_weights(x) for x in x_train_aux])

    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    
    history = model.fit(get_training_dataset(x_train, y_train, x_train_weights, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    # model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 162s - loss: 15.7840 - y_start_loss: 7.8208 - y_end_loss: 7.9632 - val_loss: 3.9455 - val_y_start_loss: 1.9651 - val_y_end_loss: 1.9804
# Epoch 2/7
# 672/672 - 162s - loss: 14.3374 - y_start_loss: 7.1693 - y_end_loss: 7.1681 - val_loss: 3.8668 - val_y_start_loss: 1.9364 - val_y_end_loss: 1.9303
# Epoch 3/7
# 672/672 - 158s - loss: 14.0009 - y_start_loss: 6.9921 - y_end_loss: 7.0088 - val_loss: 3.8958 - val_y_start_loss: 1.9407 - val_y_end_loss: 1.9551
# Epoch 4/7
# 672/672 - 161s - loss: 13.7375 - y_start_loss: 6.9112 - y_end_loss: 6.8263 - val_loss: 3.8373 - val_y_start_loss: 1.9337 - val_y_end_loss: 1.9036
# Epoch 5/7
# 672/672 - 161s - loss: 13.5508 - y_start_loss: 6.8380 - y_end_loss: 6.7128 - val_loss: 3.8299 - val_y_start_loss: 1.9290 - val_y_end_loss: 1.9009
# Epoch 6/7
# 672/672 - 158s - loss: 13.5585 - y_start_loss: 6.8380 - y_end_loss: 6.7204 - val_loss: 3.8303 - val_y_start_loss: 1.9329 - val_y_end_loss: 1.8975
# Epoch 7/7
# 672/672 - 162s - loss: 13.4440 - y_start_loss: 6.7853 - y_end_loss: 6.6587 - val_loss: 3.8243 - val_y_start_loss: 1.9301 - val_y_end_loss: 1.8942
#
# FOLD: 2
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 161s - loss: 15.6467 - y_start_loss: 7.8183 - y_end_loss: 7.8284 - val_loss: 3.8913 - val_y_start_loss: 1.9488 - val_y_end_loss: 1.9425
# Epoch 2/7
# 672/672 - 162s - loss: 14.1542 - y_start_loss: 7.1902 - y_end_loss: 6.9640 - val_loss: 3.7961 - val_y_start_loss: 1.9096 - val_y_end_loss: 1.8865
# Epoch 3/7
# 672/672 - 161s - loss: 13.7538 - y_start_loss: 7.0018 - y_end_loss: 6.7520 - val_loss: 3.7846 - val_y_start_loss: 1.9101 - val_y_end_loss: 1.8745
# Epoch 4/7
# 672/672 - 157s - loss: 13.5492 - y_start_loss: 6.8926 - y_end_loss: 6.6567 - val_loss: 3.7952 - val_y_start_loss: 1.9171 - val_y_end_loss: 1.8781
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 158s - loss: 13.4257 - y_start_loss: 6.8375 - y_end_loss: 6.5882 - val_loss: 3.7966 - val_y_start_loss: 1.9178 - val_y_end_loss: 1.8788
# Epoch 00005: early stopping
#
# FOLD: 3
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 161s - loss: 15.8233 - y_start_loss: 7.9653 - y_end_loss: 7.8580 - val_loss: 3.8695 - val_y_start_loss: 1.9494 - val_y_end_loss: 1.9200
# Epoch 2/7
# 672/672 - 161s - loss: 14.1898 - y_start_loss: 7.2143 - y_end_loss: 6.9755 - val_loss: 3.7830 - val_y_start_loss: 1.9105 - val_y_end_loss: 1.8725
# Epoch 3/7
# 672/672 - 162s - loss: 13.8165 - y_start_loss: 7.0420 - y_end_loss: 6.7745 - val_loss: 3.7725 - val_y_start_loss: 1.9092 - val_y_end_loss: 1.8633
# Epoch 4/7
# 672/672 - 157s - loss: 13.5653 - y_start_loss: 6.9088 - y_end_loss: 6.6565 - val_loss: 3.7771 - val_y_start_loss: 1.9141 - val_y_end_loss: 1.8630
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 157s - loss: 13.3772 - y_start_loss: 6.8297 - y_end_loss: 6.5475 - val_loss: 3.7759 - val_y_start_loss: 1.9097 - val_y_end_loss: 1.8662
# Epoch 00005: early stopping
#
# FOLD: 4
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 161s - loss: 16.0388 - y_start_loss: 7.9667 - y_end_loss: 8.0722 - val_loss: 3.9040 - val_y_start_loss: 1.9458 - val_y_end_loss: 1.9582
# Epoch 2/7
# 672/672 - 161s - loss: 14.3876 - y_start_loss: 7.2418 - y_end_loss: 7.1458 - val_loss: 3.8291 - val_y_start_loss: 1.9158 - val_y_end_loss: 1.9133
# Epoch 3/7
# 672/672 - 161s - loss: 13.9201 - y_start_loss: 7.0141 - y_end_loss: 6.9061 - val_loss: 3.8143 - val_y_start_loss: 1.9188 - val_y_end_loss: 1.8955
# Epoch 4/7
# 672/672 - 161s - loss: 13.6093 - y_start_loss: 6.8978 - y_end_loss: 6.7115 - val_loss: 3.7995 - val_y_start_loss: 1.9134 - val_y_end_loss: 1.8861
# Epoch 5/7
# 672/672 - 157s - loss: 13.4746 - y_start_loss: 6.8300 - y_end_loss: 6.6446 - val_loss: 3.8079 - val_y_start_loss: 1.9150 - val_y_end_loss: 1.8929
# Epoch 6/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 158s - loss: 13.3867 - y_start_loss: 6.7925 - y_end_loss: 6.5943 - val_loss: 3.8080 - val_y_start_loss: 1.9146 - val_y_end_loss: 1.8933
# Epoch 00006: early stopping
#
# FOLD: 5
# Epoch 1/7
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 162s - loss: 15.5738 - y_start_loss: 7.7885 - y_end_loss: 7.7854 - val_loss: 3.8835 - val_y_start_loss: 1.9296 - val_y_end_loss: 1.9539
# Epoch 2/7
# 672/672 - 162s - loss: 14.0899 - y_start_loss: 7.1294 - y_end_loss: 6.9605 - val_loss: 3.7734 - val_y_start_loss: 1.8997 - val_y_end_loss: 1.8737
# Epoch 3/7
# 672/672 - 162s - loss: 13.6008 - y_start_loss: 6.9164 - y_end_loss: 6.6844 - val_loss: 3.7697 - val_y_start_loss: 1.8992 - val_y_end_loss: 1.8705
# Epoch 4/7
# 672/672 - 158s - loss: 13.3246 - y_start_loss: 6.7601 - y_end_loss: 6.5644 - val_loss: 3.7732 - val_y_start_loss: 1.9004 - val_y_end_loss: 1.8728
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 158s - loss: 13.1740 - y_start_loss: 6.7056 - y_end_loss: 6.4684 - val_loss: 3.7757 - val_y_start_loss: 1.9006 - val_y_end_loss: 1.8750
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_fabc130e_a27a_11ea_a8a0_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = (k_fold['jaccard_fold_1'] + k_fold['jaccard_fold_2'] + 
                          k_fold['jaccard_fold_3'] + k_fold['jaccard_fold_4'] + 
                          k_fold['jaccard_fold_4']) / 5

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean']].head(15))
# Out:
#                                                                                                           text  ... jaccard_mean
# 0                                                                          i`d have responded, if i were going  ...     1.000000
# 1                                                                sooo sad i will miss you here in san diego!!!  ...     0.800000
# 2                                                                                    my boss is bullying me...  ...     0.366667
# 3                                                                               what interview! leave me alone  ...     1.000000
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...     0.866667
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...     1.000000
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...     1.000000
# 7                                                                                                   soooo high  ...     1.000000
# 8                                                                                                  both of you  ...     1.000000
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...     0.680000
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...     1.000000
# 11                                                    i really really like the song love story by taylor swift  ...     0.600000
# 12                                                                my sharpie is running dangerously low on ink  ...     0.400000
# 13                                                          i want to go to music tonight but i lost my voice.  ...     0.733333
# 14                                                                                  test test from the lg env2  ...     1.000000
#
# [15 rows x 7 columns]
