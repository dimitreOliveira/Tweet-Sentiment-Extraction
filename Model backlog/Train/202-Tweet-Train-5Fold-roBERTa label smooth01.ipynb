# %%
# !nvidia-smi
# Out:
# Thu May 28 00:01:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 2.8MB/s
#      |████████████████████████████████| 1.1MB 8.8MB/s
#      |████████████████████████████████| 890kB 16.8MB/s
#      |████████████████████████████████| 3.8MB 25.4MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/202-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 64,
  "EPOCHS": 4,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size * 1
decay = .997

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 4.76e-05 to 2.93e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    start_logits = layers.Dense(1, name="start_logit", use_bias=False)(last_hidden_state)
    start_logits = layers.Flatten()(start_logits)

    end_logits = layers.Dense(1, name="end_logit", use_bias=False)(last_hidden_state)
    end_logits = layers.Flatten()(end_logits)

    start_probs = layers.Activation('softmax', name='y_start')(start_logits)
    end_probs = layers.Activation('softmax', name='y_end')(end_logits)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_probs, end_probs])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.1),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.1)})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    # model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 336/336 - 165s - loss: 4.0541 - y_start_loss: 1.9445 - y_end_loss: 2.1095 - val_loss: 2.9437 - val_y_start_loss: 1.4837 - val_y_end_loss: 1.4599
# Epoch 2/4
# 336/336 - 166s - loss: 2.8644 - y_start_loss: 1.4369 - y_end_loss: 1.4274 - val_loss: 2.8110 - val_y_start_loss: 1.4349 - val_y_end_loss: 1.3762
# Epoch 3/4
# 336/336 - 166s - loss: 2.6800 - y_start_loss: 1.3560 - y_end_loss: 1.3240 - val_loss: 2.8040 - val_y_start_loss: 1.4331 - val_y_end_loss: 1.3709
# Epoch 4/4
# Restoring model weights from the end of the best epoch.
# 336/336 - 161s - loss: 2.6011 - y_start_loss: 1.3206 - y_end_loss: 1.2806 - val_loss: 2.8131 - val_y_start_loss: 1.4404 - val_y_end_loss: 1.3726
# Epoch 00004: early stopping
#
# FOLD: 2
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 336/336 - 165s - loss: 3.9645 - y_start_loss: 1.9229 - y_end_loss: 2.0417 - val_loss: 2.9165 - val_y_start_loss: 1.4721 - val_y_end_loss: 1.4445
# Epoch 2/4
# 336/336 - 166s - loss: 2.8409 - y_start_loss: 1.4355 - y_end_loss: 1.4054 - val_loss: 2.8121 - val_y_start_loss: 1.4193 - val_y_end_loss: 1.3929
# Epoch 3/4
# 336/336 - 167s - loss: 2.6678 - y_start_loss: 1.3546 - y_end_loss: 1.3132 - val_loss: 2.8061 - val_y_start_loss: 1.4273 - val_y_end_loss: 1.3788
# Epoch 4/4
# Restoring model weights from the end of the best epoch.
# 336/336 - 160s - loss: 2.5906 - y_start_loss: 1.3179 - y_end_loss: 1.2728 - val_loss: 2.8207 - val_y_start_loss: 1.4372 - val_y_end_loss: 1.3836
# Epoch 00004: early stopping
#
# FOLD: 3
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 336/336 - 165s - loss: 3.9736 - y_start_loss: 1.9374 - y_end_loss: 2.0362 - val_loss: 2.8872 - val_y_start_loss: 1.4736 - val_y_end_loss: 1.4136
# Epoch 2/4
# 336/336 - 166s - loss: 2.8544 - y_start_loss: 1.4357 - y_end_loss: 1.4187 - val_loss: 2.7888 - val_y_start_loss: 1.4255 - val_y_end_loss: 1.3632
# Epoch 3/4
# 336/336 - 166s - loss: 2.6821 - y_start_loss: 1.3652 - y_end_loss: 1.3170 - val_loss: 2.7673 - val_y_start_loss: 1.4140 - val_y_end_loss: 1.3533
# Epoch 4/4
# Restoring model weights from the end of the best epoch.
# 336/336 - 161s - loss: 2.6088 - y_start_loss: 1.3282 - y_end_loss: 1.2806 - val_loss: 2.7704 - val_y_start_loss: 1.4193 - val_y_end_loss: 1.3510
# Epoch 00004: early stopping
#
# FOLD: 4
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 336/336 - 165s - loss: 3.9835 - y_start_loss: 1.9639 - y_end_loss: 2.0195 - val_loss: 2.8732 - val_y_start_loss: 1.4513 - val_y_end_loss: 1.4219
# Epoch 2/4
# 336/336 - 166s - loss: 2.8217 - y_start_loss: 1.4350 - y_end_loss: 1.3868 - val_loss: 2.7575 - val_y_start_loss: 1.3995 - val_y_end_loss: 1.3580
# Epoch 3/4
# Restoring model weights from the end of the best epoch.
# 336/336 - 161s - loss: 2.6533 - y_start_loss: 1.3514 - y_end_loss: 1.3018 - val_loss: 2.7643 - val_y_start_loss: 1.4034 - val_y_end_loss: 1.3609
# Epoch 00003: early stopping
#
# FOLD: 5
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 336/336 - 165s - loss: 4.0625 - y_start_loss: 1.9752 - y_end_loss: 2.0873 - val_loss: 2.9985 - val_y_start_loss: 1.4783 - val_y_end_loss: 1.5201
# Epoch 2/4
# 336/336 - 166s - loss: 2.8777 - y_start_loss: 1.4470 - y_end_loss: 1.4307 - val_loss: 2.8253 - val_y_start_loss: 1.4126 - val_y_end_loss: 1.4128
# Epoch 3/4
# 336/336 - 166s - loss: 2.6903 - y_start_loss: 1.3592 - y_end_loss: 1.3311 - val_loss: 2.8156 - val_y_start_loss: 1.4110 - val_y_end_loss: 1.4046
# Epoch 4/4
# 336/336 - 166s - loss: 2.6099 - y_start_loss: 1.3193 - y_end_loss: 1.2906 - val_loss: 2.8124 - val_y_start_loss: 1.4148 - val_y_end_loss: 1.3976

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_59d40f20_a07f_11ea_814b_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = (k_fold['jaccard_fold_1'] + k_fold['jaccard_fold_2'] + 
                          k_fold['jaccard_fold_3'] + k_fold['jaccard_fold_4'] + 
                          k_fold['jaccard_fold_4']) / 5

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean']].head(15))
# Out:
#                                                                                                           text  ... jaccard_mean
# 0                                                                          i`d have responded, if i were going  ...     1.000000
# 1                                                                sooo sad i will miss you here in san diego!!!  ...     0.700000
# 2                                                                                    my boss is bullying me...  ...     0.266667
# 3                                                                               what interview! leave me alone  ...     1.000000
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...     1.000000
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...     1.000000
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...     1.000000
# 7                                                                                                   soooo high  ...     1.000000
# 8                                                                                                  both of you  ...     1.000000
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...     0.680000
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...     1.000000
# 11                                                    i really really like the song love story by taylor swift  ...     0.466667
# 12                                                                my sharpie is running dangerously low on ink  ...     0.550000
# 13                                                          i want to go to music tonight but i lost my voice.  ...     0.733333
# 14                                                                                  test test from the lg env2  ...     1.000000
#
# [15 rows x 7 columns]
