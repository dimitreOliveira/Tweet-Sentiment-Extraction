# %%
# !nvidia-smi
# Out:
# Wed May 27 11:46:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 2.8MB/s
#      |████████████████████████████████| 1.1MB 13.8MB/s
#      |████████████████████████████████| 890kB 13.0MB/s
#      |████████████████████████████████| 3.8MB 23.5MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/199-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 128,
  "EPOCHS": 14,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 3,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size * 1
decay = .998

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.52e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]
    
    x = layers.Dropout(.1)(h11)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        validation_steps=valid_step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/14
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 4.01421, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_1.h5
# 168/168 - 148s - loss: 5.4831 - y_start_loss: 2.6128 - y_end_loss: 2.8703 - val_loss: 4.0142 - val_y_start_loss: 2.0092 - val_y_end_loss: 2.0050
# Epoch 2/14
#
# Epoch 00002: val_loss improved from 4.01421 to 3.83026, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_1.h5
# 168/168 - 144s - loss: 3.9619 - y_start_loss: 1.9749 - y_end_loss: 1.9870 - val_loss: 3.8303 - val_y_start_loss: 1.9318 - val_y_end_loss: 1.8985
# Epoch 3/14
#
# Epoch 00003: val_loss improved from 3.83026 to 3.82066, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_1.h5
# 168/168 - 144s - loss: 3.8044 - y_start_loss: 1.9059 - y_end_loss: 1.8985 - val_loss: 3.8207 - val_y_start_loss: 1.9355 - val_y_end_loss: 1.8852
# Epoch 4/14
#
# Epoch 00004: val_loss improved from 3.82066 to 3.78918, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_1.h5
# 168/168 - 143s - loss: 3.7333 - y_start_loss: 1.8766 - y_end_loss: 1.8567 - val_loss: 3.7892 - val_y_start_loss: 1.9161 - val_y_end_loss: 1.8731
# Epoch 5/14
#
# Epoch 00005: val_loss did not improve from 3.78918
# 168/168 - 139s - loss: 3.6768 - y_start_loss: 1.8474 - y_end_loss: 1.8294 - val_loss: 3.7987 - val_y_start_loss: 1.9265 - val_y_end_loss: 1.8723
# Epoch 6/14
#
# Epoch 00006: val_loss did not improve from 3.78918
# 168/168 - 139s - loss: 3.6425 - y_start_loss: 1.8331 - y_end_loss: 1.8094 - val_loss: 3.7963 - val_y_start_loss: 1.9200 - val_y_end_loss: 1.8763
# Epoch 7/14
#
# Epoch 00007: val_loss did not improve from 3.78918
# 168/168 - 139s - loss: 3.6115 - y_start_loss: 1.8162 - y_end_loss: 1.7954 - val_loss: 3.8034 - val_y_start_loss: 1.9269 - val_y_end_loss: 1.8765
# Epoch 00007: early stopping
#
# FOLD: 2
# Epoch 1/14
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 4.13289, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_2.h5
# 168/168 - 151s - loss: 5.3632 - y_start_loss: 2.6022 - y_end_loss: 2.7610 - val_loss: 4.1329 - val_y_start_loss: 2.0429 - val_y_end_loss: 2.0900
# Epoch 2/14
#
# Epoch 00002: val_loss improved from 4.13289 to 3.81246, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_2.h5
# 168/168 - 144s - loss: 3.9407 - y_start_loss: 1.9776 - y_end_loss: 1.9630 - val_loss: 3.8125 - val_y_start_loss: 1.9249 - val_y_end_loss: 1.8875
# Epoch 3/14
#
# Epoch 00003: val_loss improved from 3.81246 to 3.78540, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_2.h5
# 168/168 - 143s - loss: 3.7817 - y_start_loss: 1.9122 - y_end_loss: 1.8695 - val_loss: 3.7854 - val_y_start_loss: 1.9148 - val_y_end_loss: 1.8706
# Epoch 4/14
#
# Epoch 00004: val_loss improved from 3.78540 to 3.78478, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_2.h5
# 168/168 - 144s - loss: 3.7073 - y_start_loss: 1.8762 - y_end_loss: 1.8310 - val_loss: 3.7848 - val_y_start_loss: 1.9169 - val_y_end_loss: 1.8679
# Epoch 5/14
#
# Epoch 00005: val_loss did not improve from 3.78478
# 168/168 - 140s - loss: 3.6578 - y_start_loss: 1.8513 - y_end_loss: 1.8064 - val_loss: 3.7963 - val_y_start_loss: 1.9296 - val_y_end_loss: 1.8667
# Epoch 6/14
#
# Epoch 00006: val_loss did not improve from 3.78478
# 168/168 - 139s - loss: 3.6227 - y_start_loss: 1.8339 - y_end_loss: 1.7888 - val_loss: 3.7858 - val_y_start_loss: 1.9208 - val_y_end_loss: 1.8650
# Epoch 7/14
#
# Epoch 00007: val_loss did not improve from 3.78478
# 168/168 - 140s - loss: 3.5835 - y_start_loss: 1.8179 - y_end_loss: 1.7656 - val_loss: 3.8010 - val_y_start_loss: 1.9214 - val_y_end_loss: 1.8796
# Epoch 00007: early stopping
#
# FOLD: 3
# Epoch 1/14
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 4.01632, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_3.h5
# 168/168 - 149s - loss: 5.4544 - y_start_loss: 2.6577 - y_end_loss: 2.7967 - val_loss: 4.0163 - val_y_start_loss: 2.0307 - val_y_end_loss: 1.9856
# Epoch 2/14
#
# Epoch 00002: val_loss improved from 4.01632 to 3.80368, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_3.h5
# 168/168 - 144s - loss: 3.9368 - y_start_loss: 1.9974 - y_end_loss: 1.9394 - val_loss: 3.8037 - val_y_start_loss: 1.9253 - val_y_end_loss: 1.8784
# Epoch 3/14
#
# Epoch 00003: val_loss improved from 3.80368 to 3.79834, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_3.h5
# 168/168 - 144s - loss: 3.8059 - y_start_loss: 1.9386 - y_end_loss: 1.8673 - val_loss: 3.7983 - val_y_start_loss: 1.9223 - val_y_end_loss: 1.8761
# Epoch 4/14
#
# Epoch 00004: val_loss improved from 3.79834 to 3.75978, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_3.h5
# 168/168 - 144s - loss: 3.7301 - y_start_loss: 1.8998 - y_end_loss: 1.8304 - val_loss: 3.7598 - val_y_start_loss: 1.9006 - val_y_end_loss: 1.8592
# Epoch 5/14
#
# Epoch 00005: val_loss did not improve from 3.75978
# 168/168 - 140s - loss: 3.6706 - y_start_loss: 1.8718 - y_end_loss: 1.7988 - val_loss: 3.7697 - val_y_start_loss: 1.9131 - val_y_end_loss: 1.8566
# Epoch 6/14
#
# Epoch 00006: val_loss did not improve from 3.75978
# 168/168 - 140s - loss: 3.6337 - y_start_loss: 1.8489 - y_end_loss: 1.7847 - val_loss: 3.7722 - val_y_start_loss: 1.9126 - val_y_end_loss: 1.8596
# Epoch 7/14
#
# Epoch 00007: val_loss improved from 3.75978 to 3.75785, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_3.h5
# 168/168 - 143s - loss: 3.6065 - y_start_loss: 1.8336 - y_end_loss: 1.7730 - val_loss: 3.7579 - val_y_start_loss: 1.9120 - val_y_end_loss: 1.8459
# Epoch 8/14
#
# Epoch 00008: val_loss did not improve from 3.75785
# 168/168 - 140s - loss: 3.5740 - y_start_loss: 1.8214 - y_end_loss: 1.7525 - val_loss: 3.7744 - val_y_start_loss: 1.9184 - val_y_end_loss: 1.8560
# Epoch 9/14
#
# Epoch 00009: val_loss did not improve from 3.75785
# 168/168 - 140s - loss: 3.5643 - y_start_loss: 1.8130 - y_end_loss: 1.7513 - val_loss: 3.7785 - val_y_start_loss: 1.9186 - val_y_end_loss: 1.8600
# Epoch 10/14
#
# Epoch 00010: val_loss did not improve from 3.75785
# 168/168 - 140s - loss: 3.5432 - y_start_loss: 1.8018 - y_end_loss: 1.7414 - val_loss: 3.7772 - val_y_start_loss: 1.9143 - val_y_end_loss: 1.8628
# Epoch 00010: early stopping
#
# FOLD: 4
# Epoch 1/14
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 4.07716, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_4.h5
# 168/168 - 149s - loss: 5.5056 - y_start_loss: 2.6424 - y_end_loss: 2.8632 - val_loss: 4.0772 - val_y_start_loss: 2.0389 - val_y_end_loss: 2.0383
# Epoch 2/14
#
# Epoch 00002: val_loss improved from 4.07716 to 3.82297, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_4.h5
# 168/168 - 144s - loss: 4.0183 - y_start_loss: 2.0174 - y_end_loss: 2.0009 - val_loss: 3.8230 - val_y_start_loss: 1.9199 - val_y_end_loss: 1.9030
# Epoch 3/14
#
# Epoch 00003: val_loss improved from 3.82297 to 3.79146, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_4.h5
# 168/168 - 144s - loss: 3.8473 - y_start_loss: 1.9372 - y_end_loss: 1.9101 - val_loss: 3.7915 - val_y_start_loss: 1.9150 - val_y_end_loss: 1.8765
# Epoch 4/14
#
# Epoch 00004: val_loss improved from 3.79146 to 3.76140, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_4.h5
# 168/168 - 144s - loss: 3.7687 - y_start_loss: 1.9040 - y_end_loss: 1.8647 - val_loss: 3.7614 - val_y_start_loss: 1.8961 - val_y_end_loss: 1.8653
# Epoch 5/14
#
# Epoch 00005: val_loss did not improve from 3.76140
# 168/168 - 140s - loss: 3.7135 - y_start_loss: 1.8743 - y_end_loss: 1.8392 - val_loss: 3.7767 - val_y_start_loss: 1.9005 - val_y_end_loss: 1.8762
# Epoch 6/14
#
# Epoch 00006: val_loss did not improve from 3.76140
# 168/168 - 140s - loss: 3.6722 - y_start_loss: 1.8551 - y_end_loss: 1.8171 - val_loss: 3.7654 - val_y_start_loss: 1.8970 - val_y_end_loss: 1.8684
# Epoch 7/14
#
# Epoch 00007: val_loss did not improve from 3.76140
# 168/168 - 140s - loss: 3.6414 - y_start_loss: 1.8412 - y_end_loss: 1.8002 - val_loss: 3.7795 - val_y_start_loss: 1.9046 - val_y_end_loss: 1.8748
# Epoch 00007: early stopping
#
# FOLD: 5
# Epoch 1/14
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# Epoch 00001: val_loss improved from inf to 3.95503, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_5.h5
# 168/168 - 143s - loss: 5.3963 - y_start_loss: 2.6033 - y_end_loss: 2.7930 - val_loss: 3.9550 - val_y_start_loss: 1.9724 - val_y_end_loss: 1.9826
# Epoch 2/14
#
# Epoch 00002: val_loss improved from 3.95503 to 3.78873, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_5.h5
# 168/168 - 146s - loss: 3.9292 - y_start_loss: 1.9760 - y_end_loss: 1.9532 - val_loss: 3.7887 - val_y_start_loss: 1.9061 - val_y_end_loss: 1.8826
# Epoch 3/14
#
# Epoch 00003: val_loss improved from 3.78873 to 3.75871, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_5.h5
# 168/168 - 144s - loss: 3.7731 - y_start_loss: 1.9091 - y_end_loss: 1.8640 - val_loss: 3.7587 - val_y_start_loss: 1.8930 - val_y_end_loss: 1.8657
# Epoch 4/14
#
# Epoch 00004: val_loss improved from 3.75871 to 3.74516, saving model to /content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/199-roBERTa_base/model_fold_5.h5
# 168/168 - 144s - loss: 3.7027 - y_start_loss: 1.8732 - y_end_loss: 1.8295 - val_loss: 3.7452 - val_y_start_loss: 1.8920 - val_y_end_loss: 1.8532
# Epoch 5/14
#
# Epoch 00005: val_loss did not improve from 3.74516
# 168/168 - 140s - loss: 3.6534 - y_start_loss: 1.8516 - y_end_loss: 1.8019 - val_loss: 3.7513 - val_y_start_loss: 1.8940 - val_y_end_loss: 1.8574
# Epoch 6/14
#
# Epoch 00006: val_loss did not improve from 3.74516
# 168/168 - 140s - loss: 3.6103 - y_start_loss: 1.8290 - y_end_loss: 1.7813 - val_loss: 3.7522 - val_y_start_loss: 1.8923 - val_y_end_loss: 1.8599
# Epoch 7/14
#
# Epoch 00007: val_loss did not improve from 3.74516
# 168/168 - 140s - loss: 3.5879 - y_start_loss: 1.8182 - y_end_loss: 1.7697 - val_loss: 3.7639 - val_y_start_loss: 1.8952 - val_y_end_loss: 1.8688
# Epoch 00007: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_e5d7511a_a01d_11ea_8f31_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = (k_fold['jaccard_fold_1'] + k_fold['jaccard_fold_2'] + 
                          k_fold['jaccard_fold_3'] + k_fold['jaccard_fold_4'] + 
                          k_fold['jaccard_fold_4']) / 5

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean']].head(15))
# Out:
#                                                                                                           text  ... jaccard_mean
# 0                                                                          i`d have responded, if i were going  ...     1.000000
# 1                                                                sooo sad i will miss you here in san diego!!!  ...     1.000000
# 2                                                                                    my boss is bullying me...  ...     0.400000
# 3                                                                               what interview! leave me alone  ...     1.000000
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...     1.000000
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...     0.966667
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...     1.000000
# 7                                                                                                   soooo high  ...     1.000000
# 8                                                                                                  both of you  ...     1.000000
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...     0.680000
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...     1.000000
# 11                                                    i really really like the song love story by taylor swift  ...     0.466667
# 12                                                                my sharpie is running dangerously low on ink  ...     0.400000
# 13                                                          i want to go to music tonight but i lost my voice.  ...     0.733333
# 14                                                                                  test test from the lg env2  ...     1.000000
#
# [15 rows x 7 columns]
