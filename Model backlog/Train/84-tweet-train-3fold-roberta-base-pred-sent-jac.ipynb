# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_aux.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_aux.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_aux.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    cls_token = last_hidden_state[:, 0, :]
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
#     x_sentiment = layers.GlobalAveragePooling1D()(last_hidden_state)
    x_sentiment = layers.Dropout(.1)(cls_token) 
    y_sentiment = layers.Dense(3, activation='softmax', name='y_sentiment')(x_sentiment) 
    
    x_jaccard = layers.Dropout(.1)(cls_token) 
    y_jaccard = layers.Dense(1, activation='linear', name='y_jaccard')(x_jaccard) 
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end, y_sentiment, y_jaccard])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy(),
                                   'y_sentiment': losses.SparseCategoricalCrossentropy(),
                                   'y_jaccard': losses.MeanSquaredError()}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy(),
                                      'y_sentiment': metrics.SparseCategoricalCrossentropy(),
                                      'y_jaccard': metrics.RootMeanSquaredError()})
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    y_train_aux = np.load(base_data_path + 'y_train_aux.npy')
    y_valid_aux = np.load(base_data_path + 'y_valid_aux.npy')
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list([y_train[0], y_train[1], y_train_aux[1], y_train_aux[0]]),
                        validation_data=(list(x_valid),  list([y_valid[0], y_valid[1], y_valid_aux[1], y_valid_aux[0]])),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 288s - loss: 2.5749 - y_start_loss: 1.0730 - y_end_loss: 1.1323 - y_sentiment_loss: 0.2259 - y_jaccard_loss: 0.1437 - y_start_categorical_accuracy: 0.6468 - y_end_categorical_accuracy: 0.6442 - y_sentiment_sparse_categorical_crossentropy: 0.2259 - y_jaccard_root_mean_squared_error: 0.3790 - val_loss: 1.7727 - val_y_start_loss: 0.8654 - val_y_end_loss: 0.8475 - val_y_sentiment_loss: 0.0021 - val_y_jaccard_loss: 0.0571 - val_y_start_categorical_accuracy: 0.7087 - val_y_end_categorical_accuracy: 0.7103 - val_y_sentiment_sparse_categorical_crossentropy: 0.0021 - val_y_jaccard_root_mean_squared_error: 0.2390
# Epoch 2/5
# 21984/21984 - 273s - loss: 1.7161 - y_start_loss: 0.8256 - y_end_loss: 0.7960 - y_sentiment_loss: 0.0042 - y_jaccard_loss: 0.0902 - y_start_categorical_accuracy: 0.7033 - y_end_categorical_accuracy: 0.7216 - y_sentiment_sparse_categorical_crossentropy: 0.0042 - y_jaccard_root_mean_squared_error: 0.3004 - val_loss: 1.6234 - val_y_start_loss: 0.7959 - val_y_end_loss: 0.7681 - val_y_sentiment_loss: 0.0014 - val_y_jaccard_loss: 0.0574 - val_y_start_categorical_accuracy: 0.7158 - val_y_end_categorical_accuracy: 0.7258 - val_y_sentiment_sparse_categorical_crossentropy: 0.0014 - val_y_jaccard_root_mean_squared_error: 0.2395
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.5426 - y_start_loss: 0.7529 - y_end_loss: 0.7054 - y_sentiment_loss: 0.0033 - y_jaccard_loss: 0.0809 - y_start_categorical_accuracy: 0.7215 - y_end_categorical_accuracy: 0.7433 - y_sentiment_sparse_categorical_crossentropy: 0.0033 - y_jaccard_root_mean_squared_error: 0.2845 - val_loss: 1.6397 - val_y_start_loss: 0.8150 - val_y_end_loss: 0.7676 - val_y_sentiment_loss: 8.7435e-04 - val_y_jaccard_loss: 0.0556 - val_y_start_categorical_accuracy: 0.7136 - val_y_end_categorical_accuracy: 0.7254 - val_y_sentiment_sparse_categorical_crossentropy: 8.7418e-04 - val_y_jaccard_root_mean_squared_error: 0.2359
# Epoch 00003: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 288s - loss: 2.3941 - y_start_loss: 1.0565 - y_end_loss: 1.0691 - y_sentiment_loss: 0.1470 - y_jaccard_loss: 0.1215 - y_start_categorical_accuracy: 0.6526 - y_end_categorical_accuracy: 0.6570 - y_sentiment_sparse_categorical_crossentropy: 0.1470 - y_jaccard_root_mean_squared_error: 0.3485 - val_loss: 1.8040 - val_y_start_loss: 0.8993 - val_y_end_loss: 0.8336 - val_y_sentiment_loss: 0.0019 - val_y_jaccard_loss: 0.0688 - val_y_start_categorical_accuracy: 0.6941 - val_y_end_categorical_accuracy: 0.7171 - val_y_sentiment_sparse_categorical_crossentropy: 0.0019 - val_y_jaccard_root_mean_squared_error: 0.2622
# Epoch 2/5
# 21984/21984 - 273s - loss: 1.6664 - y_start_loss: 0.8144 - y_end_loss: 0.7642 - y_sentiment_loss: 0.0041 - y_jaccard_loss: 0.0837 - y_start_categorical_accuracy: 0.7070 - y_end_categorical_accuracy: 0.7259 - y_sentiment_sparse_categorical_crossentropy: 0.0041 - y_jaccard_root_mean_squared_error: 0.2892 - val_loss: 1.7140 - val_y_start_loss: 0.8461 - val_y_end_loss: 0.8081 - val_y_sentiment_loss: 9.1003e-04 - val_y_jaccard_loss: 0.0585 - val_y_start_categorical_accuracy: 0.6932 - val_y_end_categorical_accuracy: 0.7213 - val_y_sentiment_sparse_categorical_crossentropy: 9.0936e-04 - val_y_jaccard_root_mean_squared_error: 0.2419
# Epoch 3/5
# 21984/21984 - 272s - loss: 1.4979 - y_start_loss: 0.7413 - y_end_loss: 0.6778 - y_sentiment_loss: 0.0028 - y_jaccard_loss: 0.0761 - y_start_categorical_accuracy: 0.7255 - y_end_categorical_accuracy: 0.7509 - y_sentiment_sparse_categorical_crossentropy: 0.0028 - y_jaccard_root_mean_squared_error: 0.2758 - val_loss: 1.7062 - val_y_start_loss: 0.8416 - val_y_end_loss: 0.8065 - val_y_sentiment_loss: 0.0011 - val_y_jaccard_loss: 0.0567 - val_y_start_categorical_accuracy: 0.6983 - val_y_end_categorical_accuracy: 0.7233 - val_y_sentiment_sparse_categorical_crossentropy: 0.0011 - val_y_jaccard_root_mean_squared_error: 0.2381
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.4104 - y_start_loss: 0.7014 - y_end_loss: 0.6335 - y_sentiment_loss: 0.0026 - y_jaccard_loss: 0.0730 - y_start_categorical_accuracy: 0.7339 - y_end_categorical_accuracy: 0.7641 - y_sentiment_sparse_categorical_crossentropy: 0.0026 - y_jaccard_root_mean_squared_error: 0.2701 - val_loss: 1.7128 - val_y_start_loss: 0.8485 - val_y_end_loss: 0.8066 - val_y_sentiment_loss: 7.9374e-04 - val_y_jaccard_loss: 0.0567 - val_y_start_categorical_accuracy: 0.7049 - val_y_end_categorical_accuracy: 0.7216 - val_y_sentiment_sparse_categorical_crossentropy: 7.9335e-04 - val_y_jaccard_root_mean_squared_error: 0.2381
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 286s - loss: 2.4642 - y_start_loss: 1.0539 - y_end_loss: 1.0458 - y_sentiment_loss: 0.2022 - y_jaccard_loss: 0.1623 - y_start_categorical_accuracy: 0.6538 - y_end_categorical_accuracy: 0.6622 - y_sentiment_sparse_categorical_crossentropy: 0.2022 - y_jaccard_root_mean_squared_error: 0.4028 - val_loss: 1.7106 - val_y_start_loss: 0.8607 - val_y_end_loss: 0.7909 - val_y_sentiment_loss: 8.6299e-04 - val_y_jaccard_loss: 0.0576 - val_y_start_categorical_accuracy: 0.7051 - val_y_end_categorical_accuracy: 0.7223 - val_y_sentiment_sparse_categorical_crossentropy: 8.6291e-04 - val_y_jaccard_root_mean_squared_error: 0.2399
# Epoch 2/5
# 21984/21984 - 271s - loss: 1.6472 - y_start_loss: 0.8043 - y_end_loss: 0.7360 - y_sentiment_loss: 0.0037 - y_jaccard_loss: 0.1032 - y_start_categorical_accuracy: 0.7055 - y_end_categorical_accuracy: 0.7307 - y_sentiment_sparse_categorical_crossentropy: 0.0037 - y_jaccard_root_mean_squared_error: 0.3213 - val_loss: 1.6017 - val_y_start_loss: 0.8048 - val_y_end_loss: 0.7399 - val_y_sentiment_loss: 5.1734e-04 - val_y_jaccard_loss: 0.0559 - val_y_start_categorical_accuracy: 0.7094 - val_y_end_categorical_accuracy: 0.7334 - val_y_sentiment_sparse_categorical_crossentropy: 5.1732e-04 - val_y_jaccard_root_mean_squared_error: 0.2364
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 1.4784 - y_start_loss: 0.7245 - y_end_loss: 0.6570 - y_sentiment_loss: 0.0027 - y_jaccard_loss: 0.0942 - y_start_categorical_accuracy: 0.7263 - y_end_categorical_accuracy: 0.7533 - y_sentiment_sparse_categorical_crossentropy: 0.0027 - y_jaccard_root_mean_squared_error: 0.3070 - val_loss: 1.6171 - val_y_start_loss: 0.8069 - val_y_end_loss: 0.7555 - val_y_sentiment_loss: 3.0905e-04 - val_y_jaccard_loss: 0.0537 - val_y_start_categorical_accuracy: 0.7145 - val_y_end_categorical_accuracy: 0.7336 - val_y_sentiment_sparse_categorical_crossentropy: 3.0901e-04 - val_y_jaccard_root_mean_squared_error: 0.2316
# Epoch 00003: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col0 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col1 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col4 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col6 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row1_col8 {
#             color:  green;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row7_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col6 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col7 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row8_col8 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col0 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col1 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col2 {
#             color:  red;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col3 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col4 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col5 {
#             color:  black;
#         }    #T_8819a0b2_8bb6_11ea_b04b_0242ac130202row9_col6 {
#             color:  bl

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
