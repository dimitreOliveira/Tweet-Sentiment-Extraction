# %%
# !nvidia-smi

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/117-distilroBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/distilroberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/distilroberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 70,
  "LEARNING_RATE": 3e-5,
  # "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 1,
  "base_model_path": base_path + 'distilroberta-base-tf_model.h5',
  "config_path": base_path + 'distilroberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-7
LR_MAX = config['LEARNING_RATE']
lr_start=1e-4
warmup_epochs=0
hold_max_epochs=0
num_cycles=0.5
total_epochs = config['EPOCHS']

# @tf.function
def lrfn(epoch):
    if epoch < warmup_epochs:
        lr = (LR_MAX - lr_start) / warmup_epochs * epoch + lr_start
    elif epoch < warmup_epochs + hold_max_epochs:
        lr = LR_MAX
    else:
        progress = (epoch - warmup_epochs - hold_max_epochs) / (total_epochs - warmup_epochs - hold_max_epochs)
        lr = LR_MAX * (0.5 * (1.0 + np.cos(np.pi * num_cycles * 2.0 * progress)))
        if LR_MIN is not None:
            lr = max(LR_MIN, lr)
            
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-07

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x = layers.Dropout(.1)(last_hidden_state)
    
    x_start = layers.Dense(1)(x)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dense(1)(x)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    # Train model
    model_path = 'model_fold_%d_{epoch:02d}.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    # es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
    #                    restore_best_weights=True, verbose=1)
    # checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
    #                              save_best_only=True, save_weights_only=True)
    checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        # callbacks=[checkpoint, es, lr_schedule],
                        callbacks=[checkpoint, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH + model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Epoch 1/70
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 - 141s - loss: 2.1984 - y_start_loss: 1.1070 - y_end_loss: 1.0914 - y_start_categorical_accuracy: 0.6387 - y_end_categorical_accuracy: 0.6482 - val_loss: 1.6212 - val_y_start_loss: 0.8421 - val_y_end_loss: 0.7791 - val_y_start_categorical_accuracy: 0.6991 - val_y_end_categorical_accuracy: 0.7222 - lr: 3.0000e-05
# Epoch 2/70
# 687/687 - 140s - loss: 1.6485 - y_start_loss: 0.8482 - y_end_loss: 0.8003 - y_start_categorical_accuracy: 0.6962 - y_end_categorical_accuracy: 0.7180 - val_loss: 1.6043 - val_y_start_loss: 0.8214 - val_y_end_loss: 0.7829 - val_y_start_categorical_accuracy: 0.7027 - val_y_end_categorical_accuracy: 0.7207 - lr: 2.9985e-05
# Epoch 3/70
# 687/687 - 140s - loss: 1.4640 - y_start_loss: 0.7636 - y_end_loss: 0.7004 - y_start_categorical_accuracy: 0.7196 - y_end_categorical_accuracy: 0.7447 - val_loss: 1.5980 - val_y_start_loss: 0.8212 - val_y_end_loss: 0.7768 - val_y_start_categorical_accuracy: 0.7094 - val_y_end_categorical_accuracy: 0.7198 - lr: 2.9940e-05
# Epoch 4/70
# 687/687 - 139s - loss: 1.2943 - y_start_loss: 0.6799 - y_end_loss: 0.6144 - y_start_categorical_accuracy: 0.7432 - y_end_categorical_accuracy: 0.7699 - val_loss: 1.6239 - val_y_start_loss: 0.8524 - val_y_end_loss: 0.7715 - val_y_start_categorical_accuracy: 0.7047 - val_y_end_categorical_accuracy: 0.7143 - lr: 2.9864e-05
# Epoch 5/70
# 687/687 - 139s - loss: 1.1284 - y_start_loss: 0.5989 - y_end_loss: 0.5295 - y_start_categorical_accuracy: 0.7686 - y_end_categorical_accuracy: 0.7974 - val_loss: 1.8160 - val_y_start_loss: 0.9207 - val_y_end_loss: 0.8953 - val_y_start_categorical_accuracy: 0.7018 - val_y_end_categorical_accuracy: 0.7143 - lr: 2.9759e-05
# Epoch 6/70
# 687/687 - 139s - loss: 0.9279 - y_start_loss: 0.4946 - y_end_loss: 0.4333 - y_start_categorical_accuracy: 0.8043 - y_end_categorical_accuracy: 0.8298 - val_loss: 2.0559 - val_y_start_loss: 1.0641 - val_y_end_loss: 0.9917 - val_y_start_categorical_accuracy: 0.6885 - val_y_end_categorical_accuracy: 0.7049 - lr: 2.9624e-05
# Epoch 7/70
# 687/687 - 139s - loss: 0.7832 - y_start_loss: 0.4196 - y_end_loss: 0.3635 - y_start_categorical_accuracy: 0.8338 - y_end_categorical_accuracy: 0.8568 - val_loss: 2.1723 - val_y_start_loss: 1.0934 - val_y_end_loss: 1.0789 - val_y_start_categorical_accuracy: 0.6805 - val_y_end_categorical_accuracy: 0.7087 - lr: 2.9459e-05
# Epoch 8/70
# 687/687 - 139s - loss: 0.6281 - y_start_loss: 0.3415 - y_end_loss: 0.2866 - y_start_categorical_accuracy: 0.8673 - y_end_categorical_accuracy: 0.8876 - val_loss: 2.4487 - val_y_start_loss: 1.2835 - val_y_end_loss: 1.1652 - val_y_start_categorical_accuracy: 0.6834 - val_y_end_categorical_accuracy: 0.6951 - lr: 2.9266e-05
# Epoch 9/70
# 687/687 - 139s - loss: 0.5107 - y_start_loss: 0.2790 - y_end_loss: 0.2317 - y_start_categorical_accuracy: 0.8902 - y_end_categorical_accuracy: 0.9108 - val_loss: 2.7463 - val_y_start_loss: 1.4264 - val_y_end_loss: 1.3199 - val_y_start_categorical_accuracy: 0.6832 - val_y_end_categorical_accuracy: 0.7005 - lr: 2.9044e-05
# Epoch 10/70
# 687/687 - 139s - loss: 0.4221 - y_start_loss: 0.2309 - y_end_loss: 0.1912 - y_start_categorical_accuracy: 0.9105 - y_end_categorical_accuracy: 0.9259 - val_loss: 3.1334 - val_y_start_loss: 1.6280 - val_y_end_loss: 1.5054 - val_y_start_categorical_accuracy: 0.6754 - val_y_end_categorical_accuracy: 0.7031 - lr: 2.8793e-05
# Epoch 11/70
# 687/687 - 139s - loss: 0.3415 - y_start_loss: 0.1904 - y_end_loss: 0.1512 - y_start_categorical_accuracy: 0.9288 - y_end_categorical_accuracy: 0.9432 - val_loss: 3.2122 - val_y_start_loss: 1.6318 - val_y_end_loss: 1.5805 - val_y_start_categorical_accuracy: 0.6847 - val_y_end_categorical_accuracy: 0.6978 - lr: 2.8515e-05
# Epoch 12/70
# 687/687 - 139s - loss: 0.2912 - y_start_loss: 0.1562 - y_end_loss: 0.1350 - y_start_categorical_accuracy: 0.9422 - y_end_categorical_accuracy: 0.9501 - val_loss: 3.3444 - val_y_start_loss: 1.7474 - val_y_end_loss: 1.5970 - val_y_start_categorical_accuracy: 0.6747 - val_y_end_categorical_accuracy: 0.7009 - lr: 2.8209e-05
# Epoch 13/70
# 687/687 - 139s - loss: 0.2512 - y_start_loss: 0.1387 - y_end_loss: 0.1125 - y_start_categorical_accuracy: 0.9484 - y_end_categorical_accuracy: 0.9591 - val_loss: 3.5965 - val_y_start_loss: 1.9208 - val_y_end_loss: 1.6757 - val_y_start_categorical_accuracy: 0.6661 - val_y_end_categorical_accuracy: 0.6947 - lr: 2.7877e-05
# Epoch 14/70
# 687/687 - 139s - loss: 0.2212 - y_start_loss: 0.1234 - y_end_loss: 0.0978 - y_start_categorical_accuracy: 0.9539 - y_end_categorical_accuracy: 0.9637 - val_loss: 3.9280 - val_y_start_loss: 1.9657 - val_y_end_loss: 1.9623 - val_y_start_categorical_accuracy: 0.6787 - val_y_end_categorical_accuracy: 0.7016 - lr: 2.7519e-05
# Epoch 15/70
# 687/687 - 139s - loss: 0.1924 - y_start_loss: 0.0980 - y_end_loss: 0.0943 - y_start_categorical_accuracy: 0.9634 - y_end_categorical_accuracy: 0.9662 - val_loss: 3.9922 - val_y_start_loss: 2.1297 - val_y_end_loss: 1.8625 - val_y_start_categorical_accuracy: 0.6719 - val_y_end_categorical_accuracy: 0.7020 - lr: 2.7135e-05
# Epoch 16/70
# 687/687 - 139s - loss: 0.1768 - y_start_loss: 0.0989 - y_end_loss: 0.0779 - y_start_categorical_accuracy: 0.9630 - y_end_categorical_accuracy: 0.9725 - val_loss: 3.8425 - val_y_start_loss: 1.9443 - val_y_end_loss: 1.8982 - val_y_start_categorical_accuracy: 0.6832 - val_y_end_categorical_accuracy: 0.6938 - lr: 2.6727e-05
# Epoch 17/70
# 687/687 - 139s - loss: 0.1514 - y_start_loss: 0.0806 - y_end_loss: 0.0708 - y_start_categorical_accuracy: 0.9723 - y_end_categorical_accuracy: 0.9747 - val_loss: 3.9882 - val_y_start_loss: 2.0361 - val_y_end_loss: 1.9521 - val_y_start_categorical_accuracy: 0.6701 - val_y_end_categorical_accuracy: 0.6863 - lr: 2.6296e-05
# Epoch 18/70
# 687/687 - 139s - loss: 0.1404 - y_start_loss: 0.0743 - y_end_loss: 0.0661 - y_start_categorical_accuracy: 0.9729 - y_end_categorical_accuracy: 0.9767 - val_loss: 4.1302 - val_y_start_loss: 2.1273 - val_y_end_loss: 2.0029 - val_y_start_categorical_accuracy: 0.6927 - val_y_end_categorical_accuracy: 0.6980 - lr: 2.5842e-05
# Epoch 19/70
# 687/687 - 139s - loss: 0.1268 - y_start_loss: 0.0686 - y_end_loss: 0.0581 - y_start_categorical_accuracy: 0.9753 - y_end_categorical_accuracy: 0.9792 - val_loss: 4.0149 - val_y_start_loss: 2.0803 - val_y_end_loss: 1.9347 - val_y_start_categorical_accuracy: 0.6670 - val_y_end_categorical_accuracy: 0.6920 - lr: 2.5366e-05
# Epoch 20/70
# 687/687 - 139s - loss: 0.1088 - y_start_loss: 0.0555 - y_end_loss: 0.0532 - y_start_categorical_accuracy: 0.9807 - y_end_categorical_accuracy: 0.9806 - val_loss: 4.6683 - val_y_start_loss: 2.4107 - val_y_end_loss: 2.2576 - val_y_start_categorical_accuracy: 0.6738 - val_y_end_categorical_accuracy: 0.6938 - lr: 2.4869e-05
# Epoch 21/70
# 687/687 - 139s - loss: 0.1073 - y_start_loss: 0.0536 - y_end_loss: 0.0537 - y_start_categorical_accuracy: 0.9803 - y_end_categorical_accuracy: 0.9811 - val_loss: 4.3355 - val_y_start_loss: 2.2938 - val_y_end_loss: 2.0416 - val_y_start_categorical_accuracy: 0.6818 - val_y_end_categorical_accuracy: 0.6921 - lr: 2.4352e-05
# Epoch 22/70
# 687/687 - 139s - loss: 0.1028 - y_start_loss: 0.0529 - y_end_loss: 0.0499 - y_start_categorical_accuracy: 0.9817 - y_end_categorical_accuracy: 0.9824 - val_loss: 4.6617 - val_y_start_loss: 2.4164 - val_y_end_loss: 2.2454 - val_y_start_categorical_accuracy: 0.6869 - val_y_end_categorical_accuracy: 0.6998 - lr: 2.3817e-05
# Epoch 23/70
# 687/687 - 139s - loss: 0.0929 - y_start_loss: 0.0483 - y_end_loss: 0.0445 - y_start_categorical_accuracy: 0.9824 - y_end_categorical_accuracy: 0.9846 - val_loss: 4.5916 - val_y_start_loss: 2.4323 - val_y_end_loss: 2.1593 - val_y_start_categorical_accuracy: 0.6796 - val_y_end_categorical_accuracy: 0.6978 - lr: 2.3263e-05
# Epoch 24/70
# 687/687 - 139s - loss: 0.0822 - y_start_loss: 0.0421 - y_end_loss: 0.0401 - y_start_categorical_accuracy: 0.9862 - y_end_categorical_accuracy: 0.9868 - val_loss: 4.8595 - val_y_start_loss: 2.4959 - val_y_end_loss: 2.3636 - val_y_start_categorical_accuracy: 0.6761 - val_y_end_categorical_accuracy: 0.6898 - lr: 2.2693e-05
# Epoch 25/70
# 687/687 - 139s - loss: 0.0765 - y_start_loss: 0.0383 - y_end_loss: 0.0382 - y_start_categorical_accuracy: 0.9865 - y_end_categorical_accuracy: 0.9868 - val_loss: 4.8174 - val_y_start_loss: 2.5140 - val_y_end_loss: 2.3033 - val_y_start_categorical_accuracy: 0.6801 - val_y_end_categorical_accuracy: 0.6951 - lr: 2.2108e-05
# Epoch 26/70
# 687/687 - 139s - loss: 0.0702 - y_start_loss: 0.0351 - y_end_loss: 0.0352 - y_start_categorical_accuracy: 0.9879 - y_end_categorical_accuracy: 0.9877 - val_loss: 4.9384 - val_y_start_loss: 2.5199 - val_y_end_loss: 2.4184 - val_y_start_categorical_accuracy: 0.6807 - val_y_end_categorical_accuracy: 0.6951 - lr: 2.1508e-05
# Epoch 27/70
# 687/687 - 139s - loss: 0.0656 - y_start_loss: 0.0353 - y_end_loss: 0.0303 - y_start_categorical_accuracy: 0.9886 - y_end_categorical_accuracy: 0.9889 - val_loss: 4.7967 - val_y_start_loss: 2.3969 - val_y_end_loss: 2.3998 - val_y_start_categorical_accuracy: 0.6761 - val_y_end_categorical_accuracy: 0.6987 - lr: 2.0895e-05
# Epoch 28/70
# 687/687 - 139s - loss: 0.0613 - y_start_loss: 0.0323 - y_end_loss: 0.0290 - y_start_categorical_accuracy: 0.9898 - y_end_categorical_accuracy: 0.9896 - val_loss: 5.0532 - val_y_start_loss: 2.5314 - val_y_end_loss: 2.5218 - val_y_start_categorical_accuracy: 0.6790 - val_y_end_categorical_accuracy: 0.6994 - lr: 2.0271e-05
# Epoch 29/70
# 687/687 - 139s - loss: 0.0583 - y_start_loss: 0.0296 - y_end_loss: 0.0287 - y_start_categorical_accuracy: 0.9894 - y_end_categorical_accuracy: 0.9899 - val_loss: 5.0147 - val_y_start_loss: 2.5709 - val_y_end_loss: 2.4438 - val_y_start_categorical_accuracy: 0.6798 - val_y_end_categorical_accuracy: 0.6961 - lr: 1.9635e-05
# Epoch 30/70
# 687/687 - 139s - loss: 0.0573 - y_start_loss: 0.0280 - y_end_loss: 0.0293 - y_start_categorical_accuracy: 0.9907 - y_end_categorical_accuracy: 0.9904 - val_loss: 5.0141 - val_y_start_loss: 2.5567 - val_y_end_loss: 2.4575 - val_y_start_categorical_accuracy: 0.6829 - val_y_end_categorical_accuracy: 0.6907 - lr: 1.8991e-05
# Epoch 31/70
# 687/687 - 139s - loss: 0.0502 - y_start_loss: 0.0265 - y_end_loss: 0.0238 - y_start_categorical_accuracy: 0.9915 - y_end_categorical_accuracy: 0.9912 - val_loss: 5.0963 - val_y_start_loss: 2.6058 - val_y_end_loss: 2.4905 - val_y_start_categorical_accuracy: 0.6749 - val_y_end_categorical_accuracy: 0.6998 - lr: 1.8338e-05
# Epoch 32/70
# 687/687 - 139s - loss: 0.0450 - y_start_loss: 0.0228 - y_end_loss: 0.0223 - y_start_categorical_accuracy: 0.9918 - y_end_categorical_accuracy: 0.9917 - val_loss: 5.1871 - val_y_start_loss: 2.6891 - val_y_end_loss: 2.4980 - val_y_start_categorical_accuracy: 0.6707 - val_y_end_categorical_accuracy: 0.6981 - lr: 1.7678e-05
# Epoch 33/70
# 687/687 - 139s - loss: 0.0457 - y_start_loss: 0.0226 - y_end_loss: 0.0231 - y_start_categorical_accuracy: 0.9924 - y_end_categorical_accuracy: 0.9920 - val_loss: 5.0565 - val_y_start_loss: 2.5852 - val_y_end_loss: 2.4713 - val_y_start_categorical_accuracy: 0.6741 - val_y_end_categorical_accuracy: 0.6987 - lr: 1.7013e-05
# Epoch 34/70
# 687/687 - 139s - loss: 0.0391 - y_start_loss: 0.0200 - y_end_loss: 0.0192 - y_start_categorical_accuracy: 0.9933 - y_end_categorical_accuracy: 0.9935 - val_loss: 5.4597 - val_y_start_loss: 2.7704 - val_y_end_loss: 2.6893 - val_y_start_categorical_accuracy: 0.6841 - val_y_end_categorical_accuracy: 0.7021 - lr: 1.6345e-05
# Epoch 35/70
# 687/687 - 139s - loss: 0.0389 - y_start_loss: 0.0192 - y_end_loss: 0.0197 - y_start_categorical_accuracy: 0.9935 - y_end_categorical_accuracy: 0.9928 - val_loss: 5.3608 - val_y_start_loss: 2.7563 - val_y_end_loss: 2.6044 - val_y_start_categorical_accuracy: 0.6836 - val_y_end_categorical_accuracy: 0.6974 - lr: 1.5673e-05
# Epoch 36/70
# 687/687 - 139s - loss: 0.0345 - y_start_loss: 0.0161 - y_end_loss: 0.0184 - y_start_categorical_accuracy: 0.9949 - y_end_categorical_accuracy: 0.9935 - val_loss: 5.4933 - val_y_start_loss: 2.8668 - val_y_end_loss: 2.6266 - val_y_start_categorical_accuracy: 0.6823 - val_y_end_categorical_accuracy: 0.7047 - lr: 1.5000e-05
# Epoch 37/70
# 687/687 - 139s - loss: 0.0313 - y_start_loss: 0.0164 - y_end_loss: 0.0149 - y_start_categorical_accuracy: 0.9948 - y_end_categorical_accuracy: 0.9950 - val_loss: 5.6239 - val_y_start_loss: 2.8588 - val_y_end_loss: 2.7651 - val_y_start_categorical_accuracy: 0.6756 - val_y_end_categorical_accuracy: 0.7018 - lr: 1.4327e-05
# Epoch 38/70
# 687/687 - 139s - loss: 0.0302 - y_start_loss: 0.0152 - y_end_loss: 0.0150 - y_start_categorical_accuracy: 0.9945 - y_end_categorical_accuracy: 0.9949 - val_loss: 5.6322 - val_y_start_loss: 2.8252 - val_y_end_loss: 2.8070 - val_y_start_categorical_accuracy: 0.6794 - val_y_end_categorical_accuracy: 0.7001 - lr: 1.3655e-05
# Epoch 39/70
# 687/687 - 139s - loss: 0.0368 - y_start_loss: 0.0173 - y_end_loss: 0.0196 - y_start_categorical_accuracy: 0.9942 - y_end_categorical_accuracy: 0.9937 - val_loss: 5.3481 - val_y_start_loss: 2.7676 - val_y_end_loss: 2.5805 - val_y_start_categorical_accuracy: 0.6838 - val_y_end_categorical_accuracy: 0.7007 - lr: 1.2987e-05
# Epoch 40/70
# 687/687 - 139s - loss: 0.0281 - y_start_loss: 0.0151 - y_end_loss: 0.0130 - y_start_categorical_accuracy: 0.9956 - y_end_categorical_accuracy: 0.9956 - val_loss: 5.5198 - val_y_start_loss: 2.7422 - val_y_end_loss: 2.7776 - val_y_start_categorical_accuracy: 0.6765 - val_y_end_categorical_accuracy: 0.7052 - lr: 1.2322e-05
# Epoch 41/70
# 687/687 - 139s - loss: 0.0248 - y_start_loss: 0.0126 - y_end_loss: 0.0123 - y_start_categorical_accuracy: 0.9961 - y_end_categorical_accuracy: 0.9956 - val_loss: 5.5657 - val_y_start_loss: 2.8002 - val_y_end_loss: 2.7655 - val_y_start_categorical_accuracy: 0.6849 - val_y_end_categorical_accuracy: 0.7047 - lr: 1.1662e-05
# Epoch 42/70
# 687/687 - 139s - loss: 0.0227 - y_start_loss: 0.0104 - y_end_loss: 0.0123 - y_start_categorical_accuracy: 0.9970 - y_end_categorical_accuracy: 0.9959 - val_loss: 5.8050 - val_y_start_loss: 3.0013 - val_y_end_loss: 2.8038 - val_y_start_categorical_accuracy: 0.6867 - val_y_end_categorical_accuracy: 0.7041 - lr: 1.1009e-05
# Epoch 43/70
# 687/687 - 139s - loss: 0.0224 - y_start_loss: 0.0102 - y_end_loss: 0.0122 - y_start_categorical_accuracy: 0.9966 - y_end_categorical_accuracy: 0.9956 - val_loss: 5.8622 - val_y_start_loss: 3.0431 - val_y_end_loss: 2.8191 - val_y_start_categorical_accuracy: 0.6769 - val_y_end_categorical_accuracy: 0.7054 - lr: 1.0365e-05
# Epoch 44/70
# 687/687 - 139s - loss: 0.0177 - y_start_loss: 0.0083 - y_end_loss: 0.0094 - y_start_categorical_accuracy: 0.9969 - y_end_categorical_accuracy: 0.9968 - val_loss: 5.7328 - val_y_start_loss: 3.0083 - val_y_end_loss: 2.7244 - val_y_start_categorical_accuracy: 0.6750 - val_y_end_categorical_accuracy: 0.6998 - lr: 9.7294e-06
# Epoch 45/70
# 687/687 - 139s - loss: 0.0177 - y_start_loss: 0.0090 - y_end_loss: 0.0086 - y_start_categorical_accuracy: 0.9968 - y_end_categorical_accuracy: 0.9971 - val_loss: 5.9555 - val_y_start_loss: 3.0387 - val_y_end_loss: 2.9169 - val_y_start_categorical_accuracy: 0.6854 - val_y_end_categorical_accuracy: 0.6989 - lr: 9.1046e-06
# Epoch 46/70
# 687/687 - 139s - loss: 0.0188 - y_start_loss: 0.0088 - y_end_loss: 0.0100 - y_start_categorical_accuracy: 0.9969 - y_end_categorical_accuracy: 0.9968 - val_loss: 5.8605 - val_y_start_loss: 2.9817 - val_y_end_loss: 2.8788 - val_y_start_categorical_accuracy: 0.6783 - val_y_end_categorical_accuracy: 0.6980 - lr: 8.4917e-06
# Epoch 47/70
# 687/687 - 139s - loss: 0.0177 - y_start_loss: 0.0083 - y_end_loss: 0.0094 - y_start_categorical_accuracy: 0.9969 - y_end_categorical_accuracy: 0.9971 - val_loss: 5.8970 - val_y_start_loss: 3.0252 - val_y_end_loss: 2.8718 - val_y_start_categorical_accuracy: 0.6779 - val_y_end_categorical_accuracy: 0.7029 - lr: 7.8920e-06
# Epoch 48/70
# 687/687 - 139s - loss: 0.0152 - y_start_loss: 0.0073 - y_end_loss: 0.0078 - y_start_categorical_accuracy: 0.9973 - y_end_categorical_accuracy: 0.9974 - val_loss: 5.9411 - val_y_start_loss: 3.0479 - val_y_end_loss: 2.8932 - val_y_start_categorical_accuracy: 0.6818 - val_y_end_categorical_accuracy: 0.7027 - lr: 7.3065e-06
# Epoch 49/70
# 687/687 - 139s - loss: 0.0152 - y_start_loss: 0.0077 - y_end_loss: 0.0075 - y_start_categorical_accuracy: 0.9975 - y_end_categorical_accuracy: 0.9972 - val_loss: 6.0815 - val_y_start_loss: 3.0891 - val_y_end_loss: 2.9923 - val_y_start_categorical_accuracy: 0.6809 - val_y_end_categorical_accuracy: 0.7025 - lr: 6.7365e-06
# Epoch 50/70
# 687/687 - 139s - loss: 0.0120 - y_start_loss: 0.0059 - y_end_loss: 0.0061 - y_start_categorical_accuracy: 0.9981 - y_end_categorical_accuracy: 0.9977 - val_loss: 6.0789 - val_y_start_loss: 3.0963 - val_y_end_loss: 2.9826 - val_y_start_categorical_accuracy: 0.6847 - val_y_end_categorical_accuracy: 0.7049 - lr: 6.1832e-06
# Epoch 51/70
# 687/687 - 139s - loss: 0.0135 - y_start_loss: 0.0063 - y_end_loss: 0.0072 - y_start_categorical_accuracy: 0.9979 - y_end_categorical_accuracy: 0.9976 - val_loss: 6.0451 - val_y_start_loss: 3.0683 - val_y_end_loss: 2.9768 - val_y_start_categorical_accuracy: 0.6785 - val_y_end_categorical_accuracy: 0.6994 - lr: 5.6477e-06
# Epoch 52/70
# 687/687 - 139s - loss: 0.0114 - y_start_loss: 0.0048 - y_end_loss: 0.0066 - y_start_categorical_accuracy: 0.9984 - y_end_categorical_accuracy: 0.9976 - val_loss: 6.1108 - val_y_start_loss: 3.1293 - val_y_end_loss: 2.9815 - val_y_start_categorical_accuracy: 0.6812 - val_y_end_categorical_accuracy: 0.7036 - lr: 5.1309e-06
# Epoch 53/70
# 687/687 - 139s - loss: 0.0134 - y_start_loss: 0.0066 - y_end_loss: 0.0069 - y_start_categorical_accuracy: 0.9978 - y_end_categorical_accuracy: 0.9979 - val_loss: 6.0342 - val_y_start_loss: 3.0913 - val_y_end_loss: 2.9429 - val_y_start_categorical_accuracy: 0.6860 - val_y_end_categorical_accuracy: 0.7029 - lr: 4.6341e-06
# Epoch 54/70
# 687/687 - 139s - loss: 0.0103 - y_start_loss: 0.0040 - y_end_loss: 0.0063 - y_start_categorical_accuracy: 0.9987 - y_end_categorical_accuracy: 0.9977 - val_loss: 6.0965 - val_y_start_loss: 3.1338 - val_y_end_loss: 2.9627 - val_y_start_categorical_accuracy: 0.6854 - val_y_end_categorical_accuracy: 0.7060 - lr: 4.1581e-06
# Epoch 55/70
# 687/687 - 139s - loss: 0.0099 - y_start_loss: 0.0048 - y_end_loss: 0.0050 - y_start_categorical_accuracy: 0.9982 - y_end_categorical_accuracy: 0.9986 - val_loss: 6.1763 - val_y_start_loss: 3.1524 - val_y_end_loss: 3.0239 - val_y_start_categorical_accuracy: 0.6785 - val_y_end_categorical_accuracy: 0.7034 - lr: 3.7039e-06
# Epoch 56/70
# 687/687 - 139s - loss: 0.0093 - y_start_loss: 0.0046 - y_end_loss: 0.0047 - y_start_categorical_accuracy: 0.9985 - y_end_categorical_accuracy: 0.9983 - val_loss: 6.1381 - val_y_start_loss: 3.1287 - val_y_end_loss: 3.0094 - val_y_start_categorical_accuracy: 0.6818 - val_y_end_categorical_accuracy: 0.7049 - lr: 3.2725e-06
# Epoch 57/70
# 687/687 - 139s - loss: 0.0081 - y_start_loss: 0.0038 - y_end_loss: 0.0043 - y_start_categorical_accuracy: 0.9988 - y_end_categorical_accuracy: 0.9985 - val_loss: 6.2133 - val_y_start_loss: 3.1651 - val_y_end_loss: 3.0481 - val_y_start_categorical_accuracy: 0.6829 - val_y_end_categorical_accuracy: 0.7049 - lr: 2.8647e-06
# Epoch 58/70
# 687/687 - 139s - loss: 0.0087 - y_start_loss: 0.0042 - y_end_loss: 0.0045 - y_start_categorical_accuracy: 0.9986 - y_end_categorical_accuracy: 0.9984 - val_loss: 6.2100 - val_y_start_loss: 3.1655 - val_y_end_loss: 3.0444 - val_y_start_categorical_accuracy: 0.6823 - val_y_end_categorical_accuracy: 0.7032 - lr: 2.4814e-06
# Epoch 59/70
# 687/687 - 139s - loss: 0.0074 - y_start_loss: 0.0034 - y_end_loss: 0.0039 - y_start_categorical_accuracy: 0.9988 - y_end_categorical_accuracy: 0.9987 - val_loss: 6.1758 - val_y_start_loss: 3.1436 - val_y_end_loss: 3.0322 - val_y_start_categorical_accuracy: 0.6825 - val_y_end_categorical_accuracy: 0.7060 - lr: 2.1233e-06
# Epoch 60/70
# 687/687 - 139s - loss: 0.0069 - y_start_loss: 0.0029 - y_end_loss: 0.0040 - y_start_categorical_accuracy: 0.9990 - y_end_categorical_accuracy: 0.9986 - val_loss: 6.2587 - val_y_start_loss: 3.1803 - val_y_end_loss: 3.0784 - val_y_start_categorical_accuracy: 0.6852 - val_y_end_categorical_accuracy: 0.7069 - lr: 1.7911e-06
# Epoch 61/70
# 687/687 - 139s - loss: 0.0069 - y_start_loss: 0.0027 - y_end_loss: 0.0042 - y_start_categorical_accuracy: 0.9991 - y_end_categorical_accuracy: 0.9987 - val_loss: 6.2673 - val_y_start_loss: 3.1894 - val_y_end_loss: 3.0779 - val_y_start_categorical_accuracy: 0.6850 - val_y_end_categorical_accuracy: 0.7060 - lr: 1.4855e-06
# Epoch 62/70
# 687/687 - 139s - loss: 0.0062 - y_start_loss: 0.0026 - y_end_loss: 0.0037 - y_start_categorical_accuracy: 0.9990 - y_end_categorical_accuracy: 0.9987 - val_loss: 6.2964 - val_y_start_loss: 3.2102 - val_y_end_loss: 3.0862 - val_y_start_categorical_accuracy: 0.6863 - val_y_end_categorical_accuracy: 0.7063 - lr: 1.2071e-06
# Epoch 63/70
# 687/687 - 139s - loss: 0.0077 - y_start_loss: 0.0030 - y_end_loss: 0.0047 - y_start_categorical_accuracy: 0.9991 - y_end_categorical_accuracy: 0.9982 - val_loss: 6.2841 - val_y_start_loss: 3.2098 - val_y_end_loss: 3.0742 - val_y_start_categorical_accuracy: 0.6840 - val_y_end_categorical_accuracy: 0.7058 - lr: 9.5648e-07
# Epoch 64/70
# 687/687 - 139s - loss: 0.0063 - y_start_loss: 0.0029 - y_end_loss: 0.0034 - y_start_categorical_accuracy: 0.9991 - y_end_categorical_accuracy: 0.9986 - val_loss: 6.3035 - val_y_start_loss: 3.2222 - val_y_end_loss: 3.0813 - val_y_start_categorical_accuracy: 0.6849 - val_y_end_categorical_accuracy: 0.7054 - lr: 7.3415e-07
# Epoch 65/70
# 687/687 - 139s - loss: 0.0056 - y_start_loss: 0.0022 - y_end_loss: 0.0034 - y_start_categorical_accuracy: 0.9993 - y_end_categorical_accuracy: 0.9987 - val_loss: 6.3350 - val_y_start_loss: 3.2393 - val_y_end_loss: 3.0957 - val_y_start_categorical_accuracy: 0.6838 - val_y_end_categorical_accuracy: 0.7058 - lr: 5.4056e-07
# Epoch 66/70
# 687/687 - 139s - loss: 0.0054 - y_start_loss: 0.0022 - y_end_loss: 0.0032 - y_start_categorical_accuracy: 0.9993 - y_end_categorical_accuracy: 0.9988 - val_loss: 6.3411 - val_y_start_loss: 3.2377 - val_y_end_loss: 3.1034 - val_y_start_categorical_accuracy: 0.6834 - val_y_end_categorical_accuracy: 0.7045 - lr: 3.7608e-07
# Epoch 67/70
# 687/687 - 139s - loss: 0.0053 - y_start_loss: 0.0021 - y_end_loss: 0.0032 - y_start_categorical_accuracy: 0.9992 - y_end_categorical_accuracy: 0.9988 - val_loss: 6.3667 - val_y_start_loss: 3.2514 - val_y_end_loss: 3.1153 - val_y_start_categorical_accuracy: 0.6840 - val_y_end_categorical_accuracy: 0.7049 - lr: 2.4106e-07
# Epoch 68/70
# 687/687 - 139s - loss: 0.0060 - y_start_loss: 0.0021 - y_end_loss: 0.0040 - y_start_categorical_accuracy: 0.9996 - y_end_categorical_accuracy: 0.9985 - val_loss: 6.3654 - val_y_start_loss: 3.2528 - val_y_end_loss: 3.1126 - val_y_start_categorical_accuracy: 0.6843 - val_y_end_categorical_accuracy: 0.7054 - lr: 1.3575e-07
# Epoch 69/70
# 687/687 - 139s - loss: 0.0055 - y_start_loss: 0.0025 - y_end_loss: 0.0030 - y_start_categorical_accuracy: 0.9990 - y_end_categorical_accuracy: 0.9988 - val_loss: 6.3626 - val_y_start_loss: 3.2533 - val_y_end_loss: 3.1093 - val_y_start_categorical_accuracy: 0.6838 - val_y_end_categorical_accuracy: 0.7054 - lr: 1.0000e-07
# Epoch 70/70
# 687/687 - 139s - loss: 0.0053 - y_start_loss: 0.0019 - y_end_loss: 0.0034 - y_start_categorical_accuracy: 0.9995 - y_end_categorical_accuracy: 0.9989 - val_loss: 6.3667 - val_y_start_loss: 3.2560 - val_y_end_loss: 3.1107 - val_y_start_categorical_accuracy: 0.6849 - val_y_end_categorical_accuracy: 0.7054 - lr: 1.0000e-07

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col2 {
#             color:  orange;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row3_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row3_col1 {
#             color:  orange;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row3_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row6_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row6_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row7_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row7_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row7_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row7_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row7_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row8_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row8_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row8_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row8_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row8_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row9_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row9_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row9_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row9_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row9_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row10_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row10_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row10_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row10_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row10_col4 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row11_col0 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row11_col1 {
#             color:  black;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row11_col2 {
#             color:  red;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row11_col3 {
#             color:  green;
#         }    #T_12b0c192_9256_11ea_9a0c_0242ac1c0002row11_col4 {
#             color:  black;
#         }</style><table id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col0" class="data row0 col0" >0.950197</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col1" class="data row0 col1" >0.686683</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col2" class="data row0 col2" >0.263514</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col3" class="data row0 col3" >0.950197</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row0_col4" class="data row0 col4" >0.686683</td>
#             </tr>
#             <tr>
#                         <th id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002level0_row1" class="row_heading level0 row1" >Sentiment negative</th>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col0" class="data row1 col0" >0.924229</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col1" class="data row1 col1" >0.500448</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col2" class="data row1 col2" >0.423781</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col3" class="data row1 col3" >0.924229</td>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row1_col4" class="data row1 col4" >0.500448</td>
#             </tr>
#             <tr>
#                         <th id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002level0_row2" class="row_heading level0 row2" >Sentiment neutral</th>
#                         <td id="T_12b0c192_9256_11ea_9a0c_0242ac1c0002row2_col0" class="data row2 col0" >0.991970</td>
#                         <td id="T_12b0c192_9256_11e

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_1
# 0                 i`d have responded, if i were going  ...            1.0
# 1       sooo sad i will miss you here in san diego!!!  ...            0.5
# 2                           my boss is bullying me...  ...            1.0
# 3                      what interview! leave me alone  ...            1.0
# 4   sons of ****, why couldn`t they put them on th...  ...            1.0
# 5   http://www.dothebouncy.com/smf - some shameles...  ...            1.0
# 6   2am feedings for the baby are fun when he is a...  ...            1.0
# 7                                          soooo high  ...            1.0
# 8                                         both of you  ...            1.0
# 9   journey!? wow... u just became cooler.  hehe.....  ...            1.0
# 10  as much as i love to be hopeful, i reckon the ...  ...            1.0
# 11  i really really like the song love story by ta...  ...            1.0
# 12       my sharpie is running dangerously low on ink  ...            1.0
# 13  i want to go to music tonight but i lost my vo...  ...            1.0
# 14                         test test from the lg env2  ...            1.0
#
# [15 rows x 5 columns]
