# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 16,
  "EPOCHS": 5,
  "LEARNING_RATE": 5e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Conv1D(1, 1)(last_state)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Dense(MAX_LEN, activation='softmax', name='y_start')(x_start)   

    x_end = layers.Conv1D(1, 1)(last_state)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Dense(MAX_LEN, activation='softmax', name='y_end')(x_end) 
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO),
                    validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO)),
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    steps_per_epoch=step_size,
                    verbose=2).history
    history_list.append(history)

    
    # Make predictions
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE'], AUTO))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE'], AUTO))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'start_fold_%d' % (n_fold+1)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'end_fold_%d' % (n_fold+1)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'start_fold_%d' % (n_fold+1)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'end_fold_%d' % (n_fold+1)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold+1)] = k_fold['end_fold_%d' % (n_fold+1)].astype(int)
    k_fold['start_fold_%d' % (n_fold+1)] = k_fold['start_fold_%d' % (n_fold+1)].astype(int)
    k_fold['end_fold_%d' % (n_fold+1)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold+1)].clip(0, k_fold['end_fold_%d' % (n_fold+1)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold+1)], x['end_fold_%d' % (n_fold+1)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold+1)].fillna('', inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold+1)] = k_fold.apply(lambda x: jaccard(x['text'], x['prediction_fold_%d' % (n_fold+1)]), axis=1)
# Out:
# FOLD: 1
# Train for 1374 steps, validate for 343 steps
# Epoch 1/5
# 1374/1374 - 311s - loss: 5.3016 - y_start_loss: 1.9945 - y_end_loss: 3.3071 - y_start_categorical_accuracy: 0.5516 - y_end_categorical_accuracy: 0.1611 - val_loss: 3.8308 - val_y_start_loss: 1.4971 - val_y_end_loss: 2.3337 - val_y_start_categorical_accuracy: 0.5862 - val_y_end_categorical_accuracy: 0.3737
# Epoch 2/5
# 1374/1374 - 293s - loss: 4.1677 - y_start_loss: 1.6415 - y_end_loss: 2.5261 - y_start_categorical_accuracy: 0.5799 - y_end_categorical_accuracy: 0.3037 - val_loss: 3.3488 - val_y_start_loss: 1.4351 - val_y_end_loss: 1.9138 - val_y_start_categorical_accuracy: 0.5960 - val_y_end_categorical_accuracy: 0.4792
# Epoch 3/5
# 1374/1374 - 292s - loss: 3.0137 - y_start_loss: 1.3760 - y_end_loss: 1.6377 - y_start_categorical_accuracy: 0.6063 - y_end_categorical_accuracy: 0.5767 - val_loss: 2.7477 - val_y_start_loss: 1.2899 - val_y_end_loss: 1.4578 - val_y_start_categorical_accuracy: 0.6212 - val_y_end_categorical_accuracy: 0.6387
# Epoch 4/5
# 1374/1374 - 292s - loss: 2.5757 - y_start_loss: 1.2366 - y_end_loss: 1.3391 - y_start_categorical_accuracy: 0.6359 - y_end_categorical_accuracy: 0.6531 - val_loss: 2.5166 - val_y_start_loss: 1.1932 - val_y_end_loss: 1.3234 - val_y_start_categorical_accuracy: 0.6485 - val_y_end_categorical_accuracy: 0.6687
# Epoch 5/5
# 1374/1374 - 292s - loss: 2.3045 - y_start_loss: 1.1367 - y_end_loss: 1.1678 - y_start_categorical_accuracy: 0.6588 - y_end_categorical_accuracy: 0.6908 - val_loss: 2.4546 - val_y_start_loss: 1.1697 - val_y_end_loss: 1.2849 - val_y_start_categorical_accuracy: 0.6627 - val_y_end_categorical_accuracy: 0.6780
#
# FOLD: 2
# Train for 1374 steps, validate for 343 steps
# Epoch 1/5
# 1374/1374 - 305s - loss: 5.3539 - y_start_loss: 2.0861 - y_end_loss: 3.2678 - y_start_categorical_accuracy: 0.5438 - y_end_categorical_accuracy: 0.1684 - val_loss: 3.8274 - val_y_start_loss: 1.6481 - val_y_end_loss: 2.1793 - val_y_start_categorical_accuracy: 0.5645 - val_y_end_categorical_accuracy: 0.4049
# Epoch 2/5
# 1374/1374 - 292s - loss: 3.3773 - y_start_loss: 1.4887 - y_end_loss: 1.8885 - y_start_categorical_accuracy: 0.5887 - y_end_categorical_accuracy: 0.4894 - val_loss: 2.9128 - val_y_start_loss: 1.3684 - val_y_end_loss: 1.5443 - val_y_start_categorical_accuracy: 0.6142 - val_y_end_categorical_accuracy: 0.6199
# Epoch 3/5
# 1374/1374 - 293s - loss: 2.7296 - y_start_loss: 1.3059 - y_end_loss: 1.4237 - y_start_categorical_accuracy: 0.6169 - y_end_categorical_accuracy: 0.6278 - val_loss: 2.7672 - val_y_start_loss: 1.3327 - val_y_end_loss: 1.4346 - val_y_start_categorical_accuracy: 0.6172 - val_y_end_categorical_accuracy: 0.6392
# Epoch 4/5
# 1374/1374 - 293s - loss: 2.3941 - y_start_loss: 1.1820 - y_end_loss: 1.2120 - y_start_categorical_accuracy: 0.6406 - y_end_categorical_accuracy: 0.6808 - val_loss: 2.6220 - val_y_start_loss: 1.2917 - val_y_end_loss: 1.3304 - val_y_start_categorical_accuracy: 0.6317 - val_y_end_categorical_accuracy: 0.6613
# Epoch 5/5
# 1374/1374 - 294s - loss: 2.1024 - y_start_loss: 1.0654 - y_end_loss: 1.0370 - y_start_categorical_accuracy: 0.6690 - y_end_categorical_accuracy: 0.7211 - val_loss: 2.6111 - val_y_start_loss: 1.2724 - val_y_end_loss: 1.3387 - val_y_start_categorical_accuracy: 0.6392 - val_y_end_categorical_accuracy: 0.6722
#
# FOLD: 3
# Train for 1374 steps, validate for 343 steps
# Epoch 1/5
# 1374/1374 - 308s - loss: 5.6817 - y_start_loss: 2.1703 - y_end_loss: 3.5114 - y_start_categorical_accuracy: 0.5484 - y_end_categorical_accuracy: 0.0815 - val_loss: 5.6177 - val_y_start_loss: 2.0661 - val_y_end_loss: 3.5516 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0583
# Epoch 2/5
# 1374/1374 - 293s - loss: 5.5304 - y_start_loss: 2.0143 - y_end_loss: 3.5161 - y_start_categorical_accuracy: 0.5783 - y_end_categorical_accuracy: 0.0479 - val_loss: 5.1872 - val_y_start_loss: 1.8054 - val_y_end_loss: 3.3818 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0466
# Epoch 3/5
# 1374/1374 - 294s - loss: 4.9687 - y_start_loss: 1.7351 - y_end_loss: 3.2336 - y_start_categorical_accuracy: 0.5803 - y_end_categorical_accuracy: 0.0575 - val_loss: 4.8403 - val_y_start_loss: 1.6963 - val_y_end_loss: 3.1440 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.0762
# Epoch 4/5
# 1374/1374 - 293s - loss: 4.6333 - y_start_loss: 1.6908 - y_end_loss: 2.9425 - y_start_categorical_accuracy: 0.5776 - y_end_categorical_accuracy: 0.1095 - val_loss: 4.4665 - val_y_start_loss: 1.6896 - val_y_end_loss: 2.7769 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.1605
# Epoch 5/5
# 1374/1374 - 294s - loss: 4.2589 - y_start_loss: 1.6491 - y_end_loss: 2.6097 - y_start_categorical_accuracy: 0.5779 - y_end_categorical_accuracy: 0.2023 - val_loss: 4.0292 - val_y_start_loss: 1.6237 - val_y_end_loss: 2.4055 - val_y_start_categorical_accuracy: 0.5747 - val_y_end_categorical_accuracy: 0.2657

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col0 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col1 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col6 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col7 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row0_col8 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col0 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col1 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col3 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col4 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col5 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col6 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col7 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row1_col8 {
#             color:  green;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col0 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col1 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col4 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col6 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col7 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row2_col8 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col0 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col1 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col4 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col6 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col7 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row3_col8 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col0 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col1 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col6 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col7 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row4_col8 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col0 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col1 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col6 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col7 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row5_col8 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col0 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col1 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col6 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col7 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row6_col8 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col0 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col1 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col6 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col7 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row7_col8 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col0 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col1 {
#             color:  orange;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col6 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col7 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row8_col8 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col0 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col1 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col2 {
#             color:  red;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col3 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col4 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col5 {
#             color:  black;
#         }    #T_319eb752_81d6_11ea_bcbf_79755d775526row9_col6 {
#             color:  bla

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.100000
# 2                                      bullying me...        0.400000
# 3                                      leave me alone        0.600000
# 4                                               ****,        0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        0.500000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        0.100000
# 12                                        dangerously        0.125000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.100000
# 2                                            bullying        0.200000
# 3                                               leave        0.200000
# 4                                               ****,        0.071429
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        0.071429
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.100000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        0.100000
# 12                                        dangerously        0.125000
# 13                                               lost        0.100000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3
# 0                 i`d have responded, if i were going        1.000000
# 1                                                sooo        0.100000
# 2                                             my boss        0.400000
# 3                                      what interview        0.166667
# 4                                             sons of        0.142857
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 2am        0.071429
# 7                                               soooo        0.500000
# 8                                             both of        0.666667
# 9                                           journey!?        0.100000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                           i really        0.200000
# 12                                           my sharp        0.111111
# 13                                             i want        0.200000
# 14                         test test from the lg env2        1.000000
