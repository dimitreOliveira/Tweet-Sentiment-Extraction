# %%
# !nvidia-smi
# Out:
# Tue Jun  9 22:13:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 675kB 9.4MB/s
#      |████████████████████████████████| 3.8MB 24.5MB/s
#      |████████████████████████████████| 1.1MB 52.0MB/s
#      |████████████████████████████████| 890kB 60.0MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/267-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 2,
  "LEARNING_RATE": 1e-4,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [one_cycle_schedule(tf.cast(x, tf.float32), total_steps=total_steps, 
                        lr_start=lr_min, lr_max=lr_max) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-06 to 0.0001 to 3.81e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(3, use_bias=False, name='qa_outputs')(last_hidden_state)

    start_logits, end_logits, mask_logits = tf.split(logits, 3, axis=-1, name='logits')
    start_logits = tf.squeeze(start_logits, axis=-1, name='y_start')
    end_logits = tf.squeeze(end_logits, axis=-1, name='y_end')
    mask_logits = tf.squeeze(mask_logits, axis=-1, name='y_mask')

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits, mask_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1], y_train[2])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1], y_valid[2])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
from tensorflow.keras import backend

def Custom_loss(label_smoothing=0., from_logits=False, weight=0.):
    def custom_loss(y_true, y_pred):
        cce = losses.CategoricalCrossentropy(label_smoothing=label_smoothing, from_logits=from_logits)
        y_true_pos = backend.cast(tf.math.argmax(y_true, axis=-1), 'float32')
        y_pred_pos = backend.cast(tf.math.argmax(y_pred, axis=-1), 'float32')

        loss = cce(y_true, y_pred)
        gap = tf.math.reduce_mean(tf.math.sqrt(tf.math.pow(tf.math.subtract(y_true_pos, y_pred_pos), 2)))
        gap = tf.math.multiply(gap, weight)
        loss = tf.math.add(loss, gap)

        return loss
    return custom_loss

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print(f'\nFOLD: {n_fold}')
    
    # Load data
    base_data_path = f'fold_{n_fold}/'
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    y_train_mask = np.load(base_data_path + 'y_train_mask.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    y_valid_mask = np.load(base_data_path + 'y_valid_mask.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = f'model_fold_{n_fold}.h5'
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    lr = lambda: one_cycle_schedule(tf.cast(optimizer.iterations, tf.float32), 
                                    total_steps=total_steps, lr_start=lr_min, 
                                    lr_max=lr_max)
    
    optimizer = optimizers.Adam(learning_rate=lr)
    
    model.compile(optimizer, loss=[Custom_loss(label_smoothing=0.2, from_logits=True, weight=0.5),
                                   Custom_loss(label_smoothing=0.2, from_logits=True, weight=0.5),
                                   losses.BinaryCrossentropy(from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, (*y_train, y_train_mask), config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, (*y_valid, y_valid_mask), config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 178s - loss: 7.6343 - tf_op_layer_y_start_14_loss: 3.5867 - tf_op_layer_y_end_14_loss: 3.8819 - tf_op_layer_y_mask_5_loss: 0.1658 - val_loss: 5.7443 - val_tf_op_layer_y_start_14_loss: 2.8358 - val_tf_op_layer_y_end_14_loss: 2.8120 - val_tf_op_layer_y_mask_5_loss: 0.0965
# Epoch 2/2
# 672/672 - 175s - loss: 5.5006 - tf_op_layer_y_start_14_loss: 2.6707 - tf_op_layer_y_end_14_loss: 2.7377 - tf_op_layer_y_mask_5_loss: 0.0922 - val_loss: 5.5687 - val_tf_op_layer_y_start_14_loss: 2.7301 - val_tf_op_layer_y_end_14_loss: 2.7464 - val_tf_op_layer_y_mask_5_loss: 0.0922
#
# FOLD: 2
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 179s - loss: 7.8332 - tf_op_layer_y_start_15_loss: 3.7667 - tf_op_layer_y_end_15_loss: 3.8868 - tf_op_layer_y_mask_6_loss: 0.1796 - val_loss: 5.7491 - val_tf_op_layer_y_start_15_loss: 2.7950 - val_tf_op_layer_y_end_15_loss: 2.8587 - val_tf_op_layer_y_mask_6_loss: 0.0953
# Epoch 2/2
# 672/672 - 176s - loss: 5.5871 - tf_op_layer_y_start_15_loss: 2.7128 - tf_op_layer_y_end_15_loss: 2.7796 - tf_op_layer_y_mask_6_loss: 0.0946 - val_loss: 5.5407 - val_tf_op_layer_y_start_15_loss: 2.6880 - val_tf_op_layer_y_end_15_loss: 2.7623 - val_tf_op_layer_y_mask_6_loss: 0.0904
#
# FOLD: 3
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 177s - loss: 7.8318 - tf_op_layer_y_start_16_loss: 3.8077 - tf_op_layer_y_end_16_loss: 3.8619 - tf_op_layer_y_mask_7_loss: 0.1622 - val_loss: 5.8587 - val_tf_op_layer_y_start_16_loss: 2.8038 - val_tf_op_layer_y_end_16_loss: 2.9506 - val_tf_op_layer_y_mask_7_loss: 0.1043
# Epoch 2/2
# 672/672 - 175s - loss: 5.7056 - tf_op_layer_y_start_16_loss: 2.7461 - tf_op_layer_y_end_16_loss: 2.8627 - tf_op_layer_y_mask_7_loss: 0.0968 - val_loss: 5.5148 - val_tf_op_layer_y_start_16_loss: 2.6699 - val_tf_op_layer_y_end_16_loss: 2.7527 - val_tf_op_layer_y_mask_7_loss: 0.0922
#
# FOLD: 4
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 177s - loss: 7.7504 - tf_op_layer_y_start_17_loss: 3.7219 - tf_op_layer_y_end_17_loss: 3.8506 - tf_op_layer_y_mask_8_loss: 0.1779 - val_loss: 5.9056 - val_tf_op_layer_y_start_17_loss: 2.8384 - val_tf_op_layer_y_end_17_loss: 2.9642 - val_tf_op_layer_y_mask_8_loss: 0.1030
# Epoch 2/2
# 672/672 - 176s - loss: 5.5330 - tf_op_layer_y_start_17_loss: 2.7123 - tf_op_layer_y_end_17_loss: 2.7268 - tf_op_layer_y_mask_8_loss: 0.0939 - val_loss: 5.4667 - val_tf_op_layer_y_start_17_loss: 2.6332 - val_tf_op_layer_y_end_17_loss: 2.7440 - val_tf_op_layer_y_mask_8_loss: 0.0895
#
# FOLD: 5
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-35-0a1b5158a53a> in <module>()
#      41                         steps_per_epoch=step_size,
#      42                         callbacks=[checkpoint, es],
# ---> 43                         verbose=2).history
#      44
#      45     history_list.append(history)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted:  OOM when allocating tensor with shape[32,64,768] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model_18/base_model/roberta/encoder/layer_._11/output/LayerNorm/batchnorm/mul_2 (defined at /usr/local/lib/python3.6/dist-packages/transformers/modeling_tf_bert.py:340) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[gradient_tape/model_18/base_model/roberta/embeddings/position_embeddings/embedding_lookup/Reshape/_52]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted:  OOM when allocating tensor with shape[32,64,768] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model_18/base_model/roberta/encoder/layer_._11/output/LayerNorm/batchnorm/mul_2 (defined at /usr/local/lib/python3.6/dist-packages/transformers/modeling_tf_bert.py:340) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_647119]
#
# Function call stack:
# train_function -> train_function

# %%
# Out:
# FOLD: 5
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 177s - loss: 7.3085 - tf_op_layer_y_start_loss: 3.4819 - tf_op_layer_y_end_loss: 3.6726 - tf_op_layer_y_mask_loss: 0.1539 - val_loss: 5.7816 - val_tf_op_layer_y_start_loss: 2.8261 - val_tf_op_layer_y_end_loss: 2.8561 - val_tf_op_layer_y_mask_loss: 0.0994
# Epoch 2/2
# 672/672 - 176s - loss: 5.5872 - tf_op_layer_y_start_loss: 2.7298 - tf_op_layer_y_end_loss: 2.7614 - tf_op_layer_y_mask_loss: 0.0960 - val_loss: 5.4881 - val_tf_op_layer_y_start_loss: 2.6620 - val_tf_op_layer_y_end_loss: 2.7392 - val_tf_op_layer_y_mask_loss: 0.0869

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-79524e36fb29> in <module>()
#       2 for n_fold in range(config['N_FOLDS']):
#       3     print('Fold: %d' % (n_fold+1))
# ----> 4     plot_metrics(history_list[n_fold])
#
# IndexError: list index out of range

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_42c418d8_aab2_11ea_ad9f_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_4
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                                    bullying
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                                                 some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                                      wow...
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                        i really really like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                             dangerously low
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                                        lost
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
