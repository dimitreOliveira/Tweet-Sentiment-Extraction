# %%
# !nvidia-smi

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 645kB 4.9MB/s
#      |████████████████████████████████| 3.8MB 21.6MB/s
#      |████████████████████████████████| 1.0MB 61.5MB/s
#      |████████████████████████████████| 890kB 54.9MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/125-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 8,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7fe6956d47b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn_end(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32)//step_size))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy

    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         (MODEL_BASE_PATH + model_path), save_last=False)
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    model.load_weights(MODEL_BASE_PATH + model_path)

    
    # Make predictions
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 2748 steps, validate for 687 steps
# WARNING:tensorflow:From <ipython-input-13-8934f9dbd22b>:40: StrategyBase.experimental_run_v2 (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# renamed to `run`
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:6 out of the last 6 calls to <function lrfn at 0x7fe6956d47b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 344.4s loss: 4.3847 loss_start: 2.1882 loss_end: 2.1966 val_loss: 1.9988 val_loss_start: 1.0135 val_loss_end: 0.9853
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_1.h5"
#
# EPOCH 2/5
# time: 336.9s loss: 4.0194 loss_start: 2.0176 loss_end: 2.0018 val_loss: 1.8347 val_loss_start: 0.9618 val_loss_end: 0.8729
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_1.h5"
#
# EPOCH 3/5
# time: 339.0s loss: 3.8748 loss_start: 1.9528 loss_end: 1.9219 val_loss: 1.8800 val_loss_start: 0.9550 val_loss_end: 0.9250
# Epoch 00003: early stopping
#
# FOLD: 2
# Train for 2748 steps, validate for 687 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 346.5s loss: 4.2895 loss_start: 2.1562 loss_end: 2.1333 val_loss: 1.9991 val_loss_start: 1.0226 val_loss_end: 0.9766
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_2.h5"
#
# EPOCH 2/5
# time: 336.0s loss: 3.9163 loss_start: 1.9845 loss_end: 1.9318 val_loss: 1.8702 val_loss_start: 0.9589 val_loss_end: 0.9113
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_2.h5"
#
# EPOCH 3/5
# time: 338.3s loss: 3.7626 loss_start: 1.9044 loss_end: 1.8582 val_loss: 2.0098 val_loss_start: 1.0274 val_loss_end: 0.9824
# Epoch 00003: early stopping
#
# FOLD: 3
# Train for 2748 steps, validate for 687 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 347.2s loss: 4.2992 loss_start: 2.1682 loss_end: 2.1310 val_loss: 2.0566 val_loss_start: 1.0062 val_loss_end: 1.0504
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_3.h5"
#
# EPOCH 2/5
# time: 337.3s loss: 3.9317 loss_start: 1.9916 loss_end: 1.9401 val_loss: 1.9130 val_loss_start: 0.9931 val_loss_end: 0.9199
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_3.h5"
#
# EPOCH 3/5
# time: 339.1s loss: 3.7539 loss_start: 1.9013 loss_end: 1.8526 val_loss: 1.8739 val_loss_start: 0.9833 val_loss_end: 0.8906
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_3.h5"
#
# EPOCH 4/5
# time: 339.2s loss: 3.6370 loss_start: 1.8418 loss_end: 1.7952 val_loss: 1.9919 val_loss_start: 1.0309 val_loss_end: 0.9610
# Epoch 00004: early stopping
#
# FOLD: 4
# Train for 2748 steps, validate for 687 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 346.2s loss: 4.3608 loss_start: 2.1653 loss_end: 2.1955 val_loss: 1.9689 val_loss_start: 0.9989 val_loss_end: 0.9700
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_4.h5"
#
# EPOCH 2/5
# time: 335.5s loss: 4.0033 loss_start: 1.9970 loss_end: 2.0063 val_loss: 1.9255 val_loss_start: 0.9781 val_loss_end: 0.9474
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_4.h5"
#
# EPOCH 3/5
# time: 337.6s loss: 3.8711 loss_start: 1.9380 loss_end: 1.9331 val_loss: 1.9349 val_loss_start: 1.0043 val_loss_end: 0.9305
# Epoch 00003: early stopping
#
# FOLD: 5
# Train for 2748 steps, validate for 687 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/5
# time: 345.8s loss: 4.5014 loss_start: 2.2101 loss_end: 2.2913 val_loss: 2.1365 val_loss_start: 1.0330 val_loss_end: 1.1034
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_5.h5"
#
# EPOCH 2/5
# time: 335.7s loss: 4.1199 loss_start: 2.0484 loss_end: 2.0715 val_loss: 1.9858 val_loss_start: 1.0101 val_loss_end: 0.9757
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/125-roBERTa_base/model_fold_5.h5"
#
# EPOCH 3/5
# time: 337.2s loss: 3.9765 loss_start: 1.9951 loss_end: 1.9813 val_loss: 1.9945 val_loss_start: 1.0159 val_loss_end: 0.9786
# Epoch 00003: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col10 {
#             color:  orange;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_18bb962c_93d5_11ea_aa96_0242ac1c0002row6_co

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       0.500000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       0.333333
# 12       my sharpie is running dangerously low on ink  ...       0.250000
# 13  i want to go to music tonight but i lost my vo...  ...       0.333333
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 13 columns]
