# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
# fold_1/
# fold_1/y_valid_mask.npy
# fold_1/y_valid_aux.npy
# fold_1/x_valid.npy
# fold_1/x_train.npy
# fold_1/x_valid_aux.npy
# fold_1/y_train.npy
# fold_1/x_valid_aux2.npy
# fold_1/x_train_aux2.npy
# fold_1/y_train_mask.npy
# fold_1/y_train_aux.npy
# fold_1/x_train_aux.npy
# fold_1/y_valid.npy
# fold_2/
# fold_2/y_valid_mask.npy
# fold_2/y_valid_aux.npy
# fold_2/x_valid.npy
# fold_2/x_train.npy
# fold_2/x_valid_aux.npy
# fold_2/y_train.npy
# fold_2/x_valid_aux2.npy
# fold_2/x_train_aux2.npy
# fold_2/y_train_mask.npy
# fold_2/y_train_aux.npy
# fold_2/x_train_aux.npy
# fold_2/y_valid.npy
# fold_3/
# fold_3/y_valid_mask.npy
# fold_3/y_valid_aux.npy
# fold_3/x_valid.npy
# fold_3/x_train.npy
# fold_3/x_valid_aux.npy
# fold_3/y_train.npy
# fold_3/x_valid_aux2.npy
# fold_3/x_train_aux2.npy
# fold_3/y_train_mask.npy
# fold_3/y_train_aux.npy
# fold_3/x_train_aux.npy
# fold_3/y_valid.npy
# fold_4/
# fold_4/y_valid_mask.npy
# fold_4/y_valid_aux.npy
# fold_4/x_valid.npy
# fold_4/x_train.npy
# fold_4/x_valid_aux.npy
# fold_4/y_train.npy
# fold_4/x_valid_aux2.npy
# fold_4/x_train_aux2.npy
# fold_4/y_train_mask.npy
# fold_4/y_train_aux.npy
# fold_4/x_train_aux.npy
# fold_4/y_valid.npy
# fold_5/
# fold_5/y_valid_mask.npy
# fold_5/y_valid_aux.npy
# fold_5/x_valid.npy
# fold_5/x_train.npy
# fold_5/x_valid_aux.npy
# fold_5/y_train.npy
# fold_5/x_valid_aux2.npy
# fold_5/x_train_aux2.npy
# fold_5/y_train_mask.npy
# fold_5/y_train_aux.npy
# fold_5/x_train_aux.npy
# fold_5/y_valid.npy

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 5,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 1,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    x_wrdCnt = layers.GlobalAveragePooling1D()(last_hidden_state)
    x_wrdCnt = layers.Dropout(.1)(x_wrdCnt) 
    y_wrdCnt = layers.Dense(1, activation='linear', name='y_wrdCnt')(x_wrdCnt)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end, y_wrdCnt])
    
    return model

# %% [markdown]
# # Train

# %%
# Datasets
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0],'attention_mask': x_train[1]}, 
                                                  {'y_start': y_train[0],'y_end': y_train[1],'y_wrdCnt': y_train[2]}))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0],'attention_mask': x_valid[1]}, 
                                                  {'y_start': y_valid[0],'y_end': y_valid[1],'y_wrdCnt': y_valid[2]}))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    y_train_wrdCnt = np.load(base_data_path + 'x_train_aux.npy')[1]
    y_valid_wrdCnt = np.load(base_data_path + 'x_valid_aux.npy')[1]
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, (*y_train, y_train_wrdCnt), config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, (*y_valid, y_valid_wrdCnt), config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn_start(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn_end(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss_wrdCnt = loss_fn_wrdCnt(y['y_wrdCnt'], probabilities[2])
                loss = tf.math.add(loss_start, loss_end)
                loss = tf.math.add(loss, loss_wrdCnt)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
            train_loss_wrdCnt.update_state(loss_wrdCnt)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn_start(y['y_start'], probabilities[0])
            loss_end = loss_fn_end(y['y_end'], probabilities[1])
            loss_wrdCnt = loss_fn_wrdCnt(y['y_wrdCnt'], probabilities[2])
            loss = tf.math.add(loss_start, loss_end)
            loss = tf.math.add(loss, loss_wrdCnt)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
            valid_loss_wrdCnt.update_state(loss_wrdCnt)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32)//step_size))
    loss_fn_start = losses.categorical_crossentropy
    loss_fn_end = losses.categorical_crossentropy
    loss_fn_wrdCnt = losses.mean_absolute_error

    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
    train_loss_wrdCnt = metrics.Sum()
    valid_loss_wrdCnt = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 
                    'loss_end': train_loss_end, 'loss_wrdCnt': train_loss_wrdCnt, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 
                    'val_loss_end': valid_loss_end, 'val_loss_wrdCnt': valid_loss_wrdCnt}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], model_path)
    
    history_list.append(history)
    model.load_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 282.4s loss: 9.8116 loss_start: 2.2140 loss_end: 2.2445 loss_wrdCnt: 5.3531 val_loss: 7.3324 val_loss_start: 0.9990 val_loss_end: 0.9386 val_loss_wrdCnt: 5.3949
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/5
# time: 267.6s loss: 9.3143 loss_start: 2.0157 loss_end: 1.9774 loss_wrdCnt: 5.3212 val_loss: 7.3163 val_loss_start: 0.9837 val_loss_end: 0.9025 val_loss_wrdCnt: 5.4302
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/5
# time: 268.0s loss: 9.1961 loss_start: 1.9634 loss_end: 1.9202 loss_wrdCnt: 5.3126 val_loss: 7.2916 val_loss_start: 0.9663 val_loss_end: 0.9131 val_loss_wrdCnt: 5.4121
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 4/5
# time: 267.9s loss: 9.1298 loss_start: 1.9366 loss_end: 1.8846 loss_wrdCnt: 5.3086 val_loss: 7.2571 val_loss_start: 0.9756 val_loss_end: 0.9072 val_loss_wrdCnt: 5.3744
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 5/5
# time: 268.0s loss: 9.1109 loss_start: 1.9136 loss_end: 1.8654 loss_wrdCnt: 5.3319 val_loss: 7.2465 val_loss_start: 0.9697 val_loss_end: 0.9132 val_loss_wrdCnt: 5.3636
# Training finished saved model weights at "model_fold_1.h5"
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 282.7s loss: 9.8527 loss_start: 2.2276 loss_end: 2.2584 loss_wrdCnt: 5.3666 val_loss: 7.3378 val_loss_start: 1.0040 val_loss_end: 0.9708 val_loss_wrdCnt: 5.3630
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/5
# time: 268.0s loss: 9.3183 loss_start: 2.0102 loss_end: 1.9717 loss_wrdCnt: 5.3364 val_loss: 7.3704 val_loss_start: 0.9800 val_loss_end: 0.9184 val_loss_wrdCnt: 5.4720
# Epoch 00002: early stopping
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 283.2s loss: 9.8207 loss_start: 2.2204 loss_end: 2.2355 loss_wrdCnt: 5.3648 val_loss: 7.2753 val_loss_start: 0.9799 val_loss_end: 1.0327 val_loss_wrdCnt: 5.2627
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/5
# time: 268.1s loss: 9.3952 loss_start: 2.0231 loss_end: 2.0099 loss_wrdCnt: 5.3622 val_loss: 7.2168 val_loss_start: 0.9726 val_loss_end: 0.9304 val_loss_wrdCnt: 5.3138
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/5
# time: 268.5s loss: 9.2196 loss_start: 1.9636 loss_end: 1.9272 loss_wrdCnt: 5.3287 val_loss: 7.2684 val_loss_start: 0.9625 val_loss_end: 0.9149 val_loss_wrdCnt: 5.3911
# Epoch 00003: early stopping
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 282.8s loss: 9.7996 loss_start: 2.2025 loss_end: 2.2203 loss_wrdCnt: 5.3768 val_loss: 7.3501 val_loss_start: 1.0391 val_loss_end: 0.9881 val_loss_wrdCnt: 5.3228
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/5
# time: 268.6s loss: 9.3575 loss_start: 2.0205 loss_end: 1.9878 loss_wrdCnt: 5.3492 val_loss: 7.1536 val_loss_start: 0.9705 val_loss_end: 0.9033 val_loss_wrdCnt: 5.2798
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 3/5
# time: 268.6s loss: 9.2462 loss_start: 1.9711 loss_end: 1.9283 loss_wrdCnt: 5.3469 val_loss: 7.2019 val_loss_start: 0.9949 val_loss_end: 0.8984 val_loss_wrdCnt: 5.3086
# Epoch 00003: early stopping
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
#
# EPOCH 1/5
# time: 281.6s loss: 9.9156 loss_start: 2.2471 loss_end: 2.3082 loss_wrdCnt: 5.3603 val_loss: 7.2713 val_loss_start: 0.9636 val_loss_end: 0.9689 val_loss_wrdCnt: 5.3388
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/5
# time: 267.4s loss: 9.3862 loss_start: 2.0368 loss_end: 2.0063 loss_wrdCnt: 5.3430 val_loss: 7.2512 val_loss_start: 0.9589 val_loss_end: 0.9060 val_loss_wrdCnt: 5.3862
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 3/5
# time: 267.4s loss: 9.2927 loss_start: 1.9888 loss_end: 1.9510 loss_wrdCnt: 5.3529 val_loss: 7.1204 val_loss_start: 0.9629 val_loss_end: 0.9077 val_loss_wrdCnt: 5.2498
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 4/5
# time: 267.5s loss: 9.1825 loss_start: 1.9594 loss_end: 1.9087 loss_wrdCnt: 5.3144 val_loss: 7.3109 val_loss_start: 0.9675 val_loss_end: 0.8956 val_loss_wrdCnt: 5.4478
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_5c2c2b72_93a0_11ea_a67c_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
