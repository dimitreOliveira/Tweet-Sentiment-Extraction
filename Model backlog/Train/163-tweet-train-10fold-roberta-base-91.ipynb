# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_5.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_6.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_7.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_8.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_9.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/fold_10.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-10fold-roberta-base-96-complete/'
k_fold = pd.read_csv(database_base_path + '10-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  ...  \
# 0             7             10                 35                      7  ...
# 1            10             13                  8                      2  ...
# 2             5              6                 11                      2  ...
# 3             5              6                 14                      3  ...
# 4            14             17                 13                      3  ...
#
#        fold_1 fold_2 fold_3      fold_4 fold_5      fold_6      fold_7 fold_8  \
# 0       train  train  train       train  train       train  validation  train
# 1  validation  train  train       train  train       train       train  train
# 2       train  train  train  validation  train       train       train  train
# 3       train  train  train  validation  train       train       train  train
# 4       train  train  train       train  train  validation       train  train
#
#   fold_9 fold_10
# 0  train   train
# 1  train   train
# 2  train   train
# 3  train   train
# 4  train   train
#
# [5 rows x 21 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 5,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 1,
  'question_size': 4,
  'N_FOLDS': 10,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})

    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0], label_smoothing=0.2)
                loss_end = loss_fn(y['y_end'], probabilities[1], label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: lrfn(tf.cast(optimizer.iterations, tf.float32) // step_size))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end, }
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         model_path, save_last=False)
    
    history_list.append(history)
    
#     # Make predictions (last model)
#     x_train = np.load(base_data_path + 'x_train.npy')
#     x_valid = np.load(base_data_path + 'x_valid.npy')
#     train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
#     valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
#     k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
#     k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
#     k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
#     k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
#     k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
#     k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
#     k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
#     k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
#     k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
#     k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
#     k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)

    # Make predictions (best model)
    model.load_weights(model_path)
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 301.8s loss: 4.4083 loss_start: 2.1836 loss_end: 2.2247 val_loss: 1.9189 val_loss_start: 0.9921 val_loss_end: 0.9267
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 2/5
# time: 286.9s loss: 3.9684 loss_start: 2.0033 loss_end: 1.9651 val_loss: 1.8533 val_loss_start: 0.9467 val_loss_end: 0.9066
# Saved model weights at "model_fold_1.h5"
#
# EPOCH 3/5
# time: 287.3s loss: 3.8505 loss_start: 1.9445 loss_end: 1.9061 val_loss: 1.8582 val_loss_start: 0.9377 val_loss_end: 0.9205
# Epoch 00003: early stopping
#
# FOLD: 2
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 302.4s loss: 4.3622 loss_start: 2.1817 loss_end: 2.1806 val_loss: 1.9681 val_loss_start: 1.0406 val_loss_end: 0.9275
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 2/5
# time: 287.0s loss: 3.9622 loss_start: 2.0012 loss_end: 1.9610 val_loss: 1.8973 val_loss_start: 0.9698 val_loss_end: 0.9275
# Saved model weights at "model_fold_2.h5"
#
# EPOCH 3/5
# time: 287.5s loss: 3.8603 loss_start: 1.9514 loss_end: 1.9089 val_loss: 1.9085 val_loss_start: 0.9983 val_loss_end: 0.9101
# Epoch 00003: early stopping
#
# FOLD: 3
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 301.7s loss: 4.4025 loss_start: 2.1955 loss_end: 2.2070 val_loss: 1.9595 val_loss_start: 0.9924 val_loss_end: 0.9671
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 2/5
# time: 287.6s loss: 3.9817 loss_start: 2.0168 loss_end: 1.9649 val_loss: 1.8961 val_loss_start: 0.9815 val_loss_end: 0.9146
# Saved model weights at "model_fold_3.h5"
#
# EPOCH 3/5
# time: 287.6s loss: 3.8721 loss_start: 1.9622 loss_end: 1.9099 val_loss: 1.9815 val_loss_start: 1.0068 val_loss_end: 0.9747
# Epoch 00003: early stopping
#
# FOLD: 4
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 301.6s loss: 4.4905 loss_start: 2.2200 loss_end: 2.2705 val_loss: 1.9314 val_loss_start: 0.9879 val_loss_end: 0.9435
# Saved model weights at "model_fold_4.h5"
#
# EPOCH 2/5
# time: 287.6s loss: 4.0909 loss_start: 2.0394 loss_end: 2.0515 val_loss: 1.9855 val_loss_start: 1.0045 val_loss_end: 0.9809
# Epoch 00002: early stopping
#
# FOLD: 5
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 301.9s loss: 4.3931 loss_start: 2.1821 loss_end: 2.2110 val_loss: 1.8379 val_loss_start: 0.9244 val_loss_end: 0.9134
# Saved model weights at "model_fold_5.h5"
#
# EPOCH 2/5
# time: 288.0s loss: 3.9677 loss_start: 1.9991 loss_end: 1.9687 val_loss: 1.9335 val_loss_start: 0.9902 val_loss_end: 0.9433
# Epoch 00002: early stopping
#
# FOLD: 6
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 302.0s loss: 4.3779 loss_start: 2.1835 loss_end: 2.1944 val_loss: 1.9154 val_loss_start: 0.9921 val_loss_end: 0.9232
# Saved model weights at "model_fold_6.h5"
#
# EPOCH 2/5
# time: 287.2s loss: 3.9631 loss_start: 2.0020 loss_end: 1.9611 val_loss: 1.8833 val_loss_start: 0.9611 val_loss_end: 0.9222
# Saved model weights at "model_fold_6.h5"
#
# EPOCH 3/5
# time: 287.3s loss: 3.8566 loss_start: 1.9530 loss_end: 1.9036 val_loss: 1.8155 val_loss_start: 0.9467 val_loss_end: 0.8687
# Saved model weights at "model_fold_6.h5"
#
# EPOCH 4/5
# time: 287.3s loss: 3.7876 loss_start: 1.9162 loss_end: 1.8714 val_loss: 1.8382 val_loss_start: 0.9498 val_loss_end: 0.8884
# Epoch 00004: early stopping
#
# FOLD: 7
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 301.2s loss: 4.4421 loss_start: 2.1963 loss_end: 2.2458 val_loss: 1.9479 val_loss_start: 1.0057 val_loss_end: 0.9422
# Saved model weights at "model_fold_7.h5"
#
# EPOCH 2/5
# time: 287.6s loss: 4.0016 loss_start: 2.0216 loss_end: 1.9800 val_loss: 1.9150 val_loss_start: 0.9907 val_loss_end: 0.9244
# Saved model weights at "model_fold_7.h5"
#
# EPOCH 3/5
# time: 287.8s loss: 3.8929 loss_start: 1.9667 loss_end: 1.9262 val_loss: 1.9137 val_loss_start: 0.9991 val_loss_end: 0.9146
# Saved model weights at "model_fold_7.h5"
#
# EPOCH 4/5
# time: 288.1s loss: 3.8279 loss_start: 1.9370 loss_end: 1.8909 val_loss: 1.8939 val_loss_start: 0.9732 val_loss_end: 0.9207
# Saved model weights at "model_fold_7.h5"
#
# EPOCH 5/5
# time: 288.0s loss: 3.7916 loss_start: 1.9182 loss_end: 1.8734 val_loss: 1.8586 val_loss_start: 0.9565 val_loss_end: 0.9021
# Training finished
#
# FOLD: 8
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 302.2s loss: 4.4481 loss_start: 2.1974 loss_end: 2.2507 val_loss: 1.8921 val_loss_start: 0.9829 val_loss_end: 0.9093
# Saved model weights at "model_fold_8.h5"
#
# EPOCH 2/5
# time: 288.5s loss: 4.0891 loss_start: 2.0282 loss_end: 2.0609 val_loss: 1.8283 val_loss_start: 0.9453 val_loss_end: 0.8830
# Saved model weights at "model_fold_8.h5"
#
# EPOCH 3/5
# time: 288.3s loss: 3.9355 loss_start: 1.9799 loss_end: 1.9557 val_loss: 1.8153 val_loss_start: 0.9603 val_loss_end: 0.8550
# Saved model weights at "model_fold_8.h5"
#
# EPOCH 4/5
# time: 288.4s loss: 3.8916 loss_start: 1.9634 loss_end: 1.9283 val_loss: 1.7408 val_loss_start: 0.9168 val_loss_end: 0.8240
# Saved model weights at "model_fold_8.h5"
#
# EPOCH 5/5
# time: 288.2s loss: 3.8633 loss_start: 1.9497 loss_end: 1.9136 val_loss: 1.8388 val_loss_start: 0.9896 val_loss_end: 0.8491
# Training finished
#
# FOLD: 9
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 302.3s loss: 4.4007 loss_start: 2.1878 loss_end: 2.2130 val_loss: 1.8894 val_loss_start: 0.9446 val_loss_end: 0.9447
# Saved model weights at "model_fold_9.h5"
#
# EPOCH 2/5
# time: 288.0s loss: 3.9759 loss_start: 2.0017 loss_end: 1.9742 val_loss: 1.7839 val_loss_start: 0.9079 val_loss_end: 0.8760
# Saved model weights at "model_fold_9.h5"
#
# EPOCH 3/5
# time: 287.7s loss: 3.8676 loss_start: 1.9509 loss_end: 1.9166 val_loss: 1.8634 val_loss_start: 0.9719 val_loss_end: 0.8915
# Epoch 00003: early stopping
#
# FOLD: 10
# Train for 772 steps, validate for 85 steps
#
# EPOCH 1/5
# time: 300.8s loss: 4.3829 loss_start: 2.1783 loss_end: 2.2047 val_loss: 1.9621 val_loss_start: 0.9974 val_loss_end: 0.9647
# Saved model weights at "model_fold_10.h5"
#
# EPOCH 2/5
# time: 287.1s loss: 3.9901 loss_start: 2.0140 loss_end: 1.9761 val_loss: 1.8751 val_loss_start: 0.9781 val_loss_end: 0.8970
# Saved model weights at "model_fold_10.h5"
#
# EPOCH 3/5
# time: 287.7s loss: 3.9974 loss_start: 1.9902 loss_end: 2.0073 val_loss: 2.1529 val_loss_start: 1.0474 val_loss_end: 1.1055
# Epoch 00003: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
# Fold: 10

# %% [markdown]
# # Model evaluation (last model)

# %%
# display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col13 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col14 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col15 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col16 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col17 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col18 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col19 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col20 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col21 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row0_col22 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col10 {
#             color:  orange;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col13 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col14 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col15 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col16 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col17 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col18 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col19 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col20 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col21 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row1_col22 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col13 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col14 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col15 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col16 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col17 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col18 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col19 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col20 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col21 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row2_col22 {
#             color:  green;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col10 {
#             color:  orange;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col13 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col14 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col15 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col16 {
#             color:  black;
#         }    #T_54b8ecc0_9ad2_11ea_b120_0242ac130202row3_col17 {
#             color:  black;
#         }    #T_54b8ecc0_

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt
# 0              10                      10
# 1              13                       3
# 2               6                       2
# 3               6                       3
# 4              17                       4
# 5              27                      27
# 6              17                       1
# 7               3                       3
# 8               3                       3
# 9              19                       7
# 10             27                      27
# 11             12                       1
# 12              9                       1
# 13             13                       1
# 14              8                       8
