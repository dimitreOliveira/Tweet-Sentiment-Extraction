# %%
# !nvidia-smi
# Out:
# Fri Jun  5 11:28:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 675kB 8.5MB/s
#      |████████████████████████████████| 890kB 23.1MB/s
#      |████████████████████████████████| 1.1MB 51.7MB/s
#      |████████████████████████████████| 3.8MB 55.3MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/243-roBERTa_base/'

import os
# os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 7,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = step_size # total_steps * 0.1
num_cycles = 6

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [cosine_with_hard_restarts_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                                    warmup_steps=warmup_steps, lr_start=lr_start, 
                                                    lr_max=lr_max, lr_min=lr_min, num_cycles=num_cycles) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [cosine_with_hard_restarts_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                                    warmup_steps=1, lr_start=lr_start, 
                                                    lr_max=lr_max, lr_min=lr_min, num_cycles=.7) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 3e-05 to 1e-06
# Learning rate schedule: 0 to 3e-05 to 6.37e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, name="qa_outputs", use_bias=False)(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
import tensorflow_addons as tfa

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []
strategy = tf.distribute.get_strategy()

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y[0], probabilities[0], from_logits=True, label_smoothing=0.2)
                loss_end = loss_fn(y[1], probabilities[1], from_logits=True, label_smoothing=0.2)
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y[0], probabilities[0], from_logits=True, label_smoothing=0.2)
            loss_end = loss_fn(y[1], probabilities[1], from_logits=True, label_smoothing=0.2)
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    lr = lambda: cosine_with_hard_restarts_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                total_steps=total_steps, warmup_steps=warmup_steps, 
                                                                lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, 
                                                                num_cycles=num_cycles)
    wd = lambda: cosine_with_hard_restarts_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                total_steps=total_steps, warmup_steps=1, 
                                                                lr_start=lr_start, lr_max=lr_max, lr_min=lr_min, 
                                                                num_cycles=.7)
    
    optimizer = tfa.optimizers.AdamW(learning_rate=lr, weight_decay=wd)
    optimizer.weight_decay=wd # Making sure Wdecay is used

    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
    
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], (MODEL_BASE_PATH + model_path))

    history_list.append(history)
    
    # Make predictions
    model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/7
# time: 232.0s loss: 4.8349 loss_start: 2.3688 loss_end: 2.4661 val_loss: 3.8571 val_loss_start: 1.9475 val_loss_end: 1.9097
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_1.h5"
#
# EPOCH 2/7
# time: 218.5s loss: 3.8101 loss_start: 1.9200 loss_end: 1.8901 val_loss: 3.7852 val_loss_start: 1.9149 val_loss_end: 1.8704
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_1.h5"
#
# EPOCH 3/7
# time: 220.0s loss: 3.7118 loss_start: 1.8759 loss_end: 1.8359 val_loss: 3.7537 val_loss_start: 1.9114 val_loss_end: 1.8422
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_1.h5"
#
# EPOCH 4/7
# time: 219.7s loss: 3.6478 loss_start: 1.8458 loss_end: 1.8020 val_loss: 3.7433 val_loss_start: 1.9009 val_loss_end: 1.8423
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_1.h5"
#
# EPOCH 5/7
# time: 220.0s loss: 3.5875 loss_start: 1.8155 loss_end: 1.7720 val_loss: 3.7568 val_loss_start: 1.9134 val_loss_end: 1.8435
#
# EPOCH 6/7
# time: 215.2s loss: 3.5201 loss_start: 1.7819 loss_end: 1.7382 val_loss: 3.7953 val_loss_start: 1.9224 val_loss_end: 1.8729
# Epoch 00006: early stopping
#
# FOLD: 2
# Train for 672 steps, validate for 168 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/7
# time: 232.3s loss: 4.7977 loss_start: 2.3515 loss_end: 2.4462 val_loss: 3.9265 val_loss_start: 1.9492 val_loss_end: 1.9773
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_2.h5"
#
# EPOCH 2/7
# time: 218.1s loss: 3.8074 loss_start: 1.9138 loss_end: 1.8936 val_loss: 3.7711 val_loss_start: 1.9061 val_loss_end: 1.8649
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_2.h5"
#
# EPOCH 3/7
# time: 220.3s loss: 3.7138 loss_start: 1.8731 loss_end: 1.8407 val_loss: 3.7595 val_loss_start: 1.9055 val_loss_end: 1.8540
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_2.h5"
#
# EPOCH 4/7
# time: 219.7s loss: 3.6426 loss_start: 1.8396 loss_end: 1.8029 val_loss: 3.7879 val_loss_start: 1.9146 val_loss_end: 1.8732
#
# EPOCH 5/7
# time: 215.2s loss: 3.5825 loss_start: 1.8112 loss_end: 1.7714 val_loss: 3.7649 val_loss_start: 1.9089 val_loss_end: 1.8560
# Epoch 00005: early stopping
#
# FOLD: 3
# Train for 672 steps, validate for 168 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/7
# time: 232.1s loss: 4.7799 loss_start: 2.3552 loss_end: 2.4248 val_loss: 3.8706 val_loss_start: 1.9552 val_loss_end: 1.9155
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_3.h5"
#
# EPOCH 2/7
# time: 218.2s loss: 3.8320 loss_start: 1.9164 loss_end: 1.9157 val_loss: 3.7613 val_loss_start: 1.9024 val_loss_end: 1.8589
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_3.h5"
#
# EPOCH 3/7
# time: 220.6s loss: 3.7339 loss_start: 1.8780 loss_end: 1.8559 val_loss: 3.7352 val_loss_start: 1.8894 val_loss_end: 1.8458
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_3.h5"
#
# EPOCH 4/7
# time: 220.8s loss: 3.6688 loss_start: 1.8508 loss_end: 1.8180 val_loss: 3.7498 val_loss_start: 1.8952 val_loss_end: 1.8545
#
# EPOCH 5/7
# time: 215.9s loss: 3.5993 loss_start: 1.8188 loss_end: 1.7805 val_loss: 3.7482 val_loss_start: 1.9000 val_loss_end: 1.8482
# Epoch 00005: early stopping
#
# FOLD: 4
# Train for 672 steps, validate for 168 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/7
# time: 232.5s loss: 4.7788 loss_start: 2.3576 loss_end: 2.4212 val_loss: 3.8615 val_loss_start: 1.9332 val_loss_end: 1.9283
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_4.h5"
#
# EPOCH 2/7
# time: 218.5s loss: 3.8554 loss_start: 1.9200 loss_end: 1.9354 val_loss: 3.7835 val_loss_start: 1.8884 val_loss_end: 1.8951
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_4.h5"
#
# EPOCH 3/7
# time: 220.8s loss: 3.7582 loss_start: 1.8771 loss_end: 1.8811 val_loss: 3.7565 val_loss_start: 1.8833 val_loss_end: 1.8732
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_4.h5"
#
# EPOCH 4/7
# time: 220.3s loss: 3.6710 loss_start: 1.8461 loss_end: 1.8249 val_loss: 3.7757 val_loss_start: 1.9033 val_loss_end: 1.8724
#
# EPOCH 5/7
# time: 215.7s loss: 3.6171 loss_start: 1.8203 loss_end: 1.7968 val_loss: 3.7667 val_loss_start: 1.9001 val_loss_end: 1.8666
# Epoch 00005: early stopping
#
# FOLD: 5
# Train for 672 steps, validate for 168 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/7
# time: 232.6s loss: 4.7455 loss_start: 2.3207 loss_end: 2.4248 val_loss: 3.9164 val_loss_start: 1.9448 val_loss_end: 1.9716
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_5.h5"
#
# EPOCH 2/7
# time: 219.0s loss: 3.8565 loss_start: 1.9252 loss_end: 1.9313 val_loss: 3.8078 val_loss_start: 1.8836 val_loss_end: 1.9243
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_5.h5"
#
# EPOCH 3/7
# time: 220.1s loss: 3.7588 loss_start: 1.8953 loss_end: 1.8635 val_loss: 3.7358 val_loss_start: 1.8774 val_loss_end: 1.8584
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_5.h5"
#
# EPOCH 4/7
# time: 220.1s loss: 3.6768 loss_start: 1.8577 loss_end: 1.8191 val_loss: 3.7271 val_loss_start: 1.8814 val_loss_end: 1.8457
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/243-roBERTa_base/model_fold_5.h5"
#
# EPOCH 5/7
# time: 220.8s loss: 3.6589 loss_start: 1.8424 loss_end: 1.8165 val_loss: 3.7507 val_loss_start: 1.8870 val_loss_end: 1.8636
#
# EPOCH 6/7
# time: 215.6s loss: 3.5661 loss_start: 1.8026 loss_end: 1.7636 val_loss: 3.7634 val_loss_start: 1.8976 val_loss_end: 1.8658
# Epoch 00006: early stopping

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_44535560_a742_11ea_869c_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_44535560_a742_11ea_869c_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_5
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                              bullying me...
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                                                 some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                        i really really like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                      dangerously low on ink
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                                        lost
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
