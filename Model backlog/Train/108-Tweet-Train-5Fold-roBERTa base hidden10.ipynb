# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers|
# Out:
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/108-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7f2f5666d730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function lrfn at 0x7f2f5666d730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h12 = hidden_states[-1]
    h11 = hidden_states[-2]
    h10 = hidden_states[-3]
    h09 = hidden_states[-4]
    
    x_start = layers.Dropout(.1)(h10) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(h10) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH + 'last_' + model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
#
# FOLD: 2
#
# FOLD: 3
#
# FOLD: 4
#
# FOLD: 5

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-08267ab4a503> in <module>()
#       2 for n_fold in range(config['N_FOLDS']):
#       3     print('Fold: %d' % (n_fold+1))
# ----> 4     plot_metrics(history_list[n_fold])
#
# IndexError: list index out of range

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col4 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col5 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col6 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col7 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col8 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col11 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row1_col12 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col9 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col10 {
#             color:  green;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_be79a1c8_8fd7_11ea_a580_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_3
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       1.000000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 13 columns]
