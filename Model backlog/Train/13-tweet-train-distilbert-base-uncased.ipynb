# %% [markdown]
# ## Dependencies

# %%
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  69a4e7a6f5                               ouch, i'm sorry then
# 1  8022534fc2     thankyou, yes. off to a pre-wedding party now.
# 2  f7beb13214                            this is how we do itttt
# 3  89cdcbfb73  everyone's abandoning the office... i still ha...
# 4  29a4bb11d9  acquiring a centos live cd, now where did i pu...
#
#                                        selected_text sentiment  text_len  \
# 0                                              sorry  negative        21
# 1                                          Thankyou,  positive        47
# 2                            this is how we do itttt   neutral        23
# 3  everyone's abandoning the office... I still ha...   neutral        62
# 4  I would like to boot from that. I wonder if I ...   neutral       126
#
#    selected_text_len    set
# 0                  5  train
# 1                  9  train
# 2                 23  train
# 3                 62  train
# 4                 61  train
# hold_out/
# hold_out/y_train.npy
# hold_out/x_train.npy
# hold_out/y_valid.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 128
BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 1e-5
ES_PATIENCE = 3

tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
base_model_path = base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5'
config_path = base_path + 'distilbert-base-uncased-distilled-squad-config.json'
model_path = 'model.h5'
log_path = './'

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config_path, output_hidden_states=False)

def model_fn():
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(base_model_path, config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='softmax', name='y_start')(x)
    y_end = Dense(MAX_LEN, activation='softmax', name='y_end')(x)
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
                  loss=losses.CategoricalCrossentropy(), 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

model = model_fn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir=log_path)
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=EPOCHS, 
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21988 samples, validate on 5497 samples
# Epoch 1/20
# 21988/21988 - 191s - loss: 3.3044 - y_start_loss: 1.4702 - y_end_loss: 1.8357 - y_start_categorical_accuracy: 0.1881 - y_end_categorical_accuracy: 0.0300 - val_loss: 3.0925 - val_y_start_loss: 1.3674 - val_y_end_loss: 1.7251 - val_y_start_categorical_accuracy: 0.1903 - val_y_end_categorical_accuracy: 0.0367
# Epoch 2/20
# 21988/21988 - 180s - loss: 2.9764 - y_start_loss: 1.3201 - y_end_loss: 1.6570 - y_start_categorical_accuracy: 0.1896 - y_end_categorical_accuracy: 0.0442 - val_loss: 2.9413 - val_y_start_loss: 1.3151 - val_y_end_loss: 1.6264 - val_y_start_categorical_accuracy: 0.1919 - val_y_end_categorical_accuracy: 0.0531
# Epoch 3/20
# 21988/21988 - 180s - loss: 2.6453 - y_start_loss: 1.1691 - y_end_loss: 1.4764 - y_start_categorical_accuracy: 0.2002 - y_end_categorical_accuracy: 0.0880 - val_loss: 2.5128 - val_y_start_loss: 1.0872 - val_y_end_loss: 1.4258 - val_y_start_categorical_accuracy: 0.2112 - val_y_end_categorical_accuracy: 0.1152
# Epoch 4/20
# 21988/21988 - 180s - loss: 2.3730 - y_start_loss: 1.0425 - y_end_loss: 1.3312 - y_start_categorical_accuracy: 0.2264 - y_end_categorical_accuracy: 0.1310 - val_loss: 2.4376 - val_y_start_loss: 1.0863 - val_y_end_loss: 1.3514 - val_y_start_categorical_accuracy: 0.2416 - val_y_end_categorical_accuracy: 0.1454
# Epoch 5/20
# 21988/21988 - 180s - loss: 2.2082 - y_start_loss: 0.9688 - y_end_loss: 1.2384 - y_start_categorical_accuracy: 0.2420 - y_end_categorical_accuracy: 0.1623 - val_loss: 2.2862 - val_y_start_loss: 1.0056 - val_y_end_loss: 1.2807 - val_y_start_categorical_accuracy: 0.2494 - val_y_end_categorical_accuracy: 0.1612
# Epoch 6/20
# 21988/21988 - 180s - loss: 2.0621 - y_start_loss: 0.9042 - y_end_loss: 1.1595 - y_start_categorical_accuracy: 0.2557 - y_end_categorical_accuracy: 0.1832 - val_loss: 2.2464 - val_y_start_loss: 0.9904 - val_y_end_loss: 1.2561 - val_y_start_categorical_accuracy: 0.2449 - val_y_end_categorical_accuracy: 0.1683
# Epoch 7/20
# 21988/21988 - 180s - loss: 1.9290 - y_start_loss: 0.8481 - y_end_loss: 1.0808 - y_start_categorical_accuracy: 0.2664 - y_end_categorical_accuracy: 0.2057 - val_loss: 2.3095 - val_y_start_loss: 1.0130 - val_y_end_loss: 1.2964 - val_y_start_categorical_accuracy: 0.2378 - val_y_end_categorical_accuracy: 0.1655
# Epoch 8/20
# 21988/21988 - 180s - loss: 1.8185 - y_start_loss: 0.7984 - y_end_loss: 1.0200 - y_start_categorical_accuracy: 0.2770 - y_end_categorical_accuracy: 0.2196 - val_loss: 2.3552 - val_y_start_loss: 1.0451 - val_y_end_loss: 1.3100 - val_y_start_categorical_accuracy: 0.2341 - val_y_end_categorical_accuracy: 0.1721
# Epoch 9/20
# Restoring model weights from the end of the best epoch.
# 21988/21988 - 180s - loss: 1.7111 - y_start_loss: 0.7576 - y_end_loss: 0.9582 - y_start_categorical_accuracy: 0.2849 - y_end_categorical_accuracy: 0.2344 - val_loss: 2.2955 - val_y_start_loss: 1.0123 - val_y_end_loss: 1.2831 - val_y_start_categorical_accuracy: 0.2387 - val_y_end_categorical_accuracy: 0.1761
# Epoch 00009: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/events.out.tfevents.1586305719.7199e9c41607.12.5418.v2
# train/events.out.tfevents.1586305728.7199e9c41607.profile-empty
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-08_00-28-48/
# train/plugins/profile/2020-04-08_00-28-48/local.trace
# validation/
# validation/events.out.tfevents.1586305909.7199e9c41607.12.28047.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 'y_start_categorical_accuracy', 'y_end_categorical_accuracy'])

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], tokenizer), axis=1)
train["prediction"] = train["prediction"].apply(lambda x: '.' if x.strip() == '' else x)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], tokenizer), axis=1)
validation["prediction"] = validation["prediction"].apply(lambda x: '.' if x.strip() == '' else x)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.505423    0.454979          21988
# Sentiment negative           0.430474    0.344570           6142
# Sentiment positive           0.420342    0.352170           6948
# Sentiment neutral            0.623594    0.612484           8898
# 0 <= text < 10               0.927083    0.950980            192
# 10 <= text < 50              0.709915    0.657669           7776
# 50 <= text < 100             0.459430    0.402682           8816
# 100 <= text < 200            0.262224    0.222222           5204
# 0 <= selected text < 10      0.486951    0.386629           6190
# 10 <= selected text < 50     0.575990    0.543982           9712
# 50 <= selected text < 100    0.493627    0.475958           4084
# 100 <= selected text < 200   0.244274    0.222139           2002
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5497
# Sentiment negative                         1644
# Sentiment positive                         1634
# Sentiment neutral                          2219
# 0 <= text < 10                               51
# 10 <= text < 50                            1947
# 50 <= text < 100                           2186
# 100 <= text < 200                          1313
# 0 <= selected text < 10                    1602
# 10 <= selected text < 50                   2345
# 50 <= selected text < 100                  1031
# 100 <= selected text < 200                  519

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  69a4e7a6f5                               ouch, i'm sorry then
# 1  8022534fc2     thankyou, yes. off to a pre-wedding party now.
# 2  f7beb13214                            this is how we do itttt
# 3  89cdcbfb73  everyone's abandoning the office... i still ha...
# 4  29a4bb11d9  acquiring a centos live cd, now where did i pu...
# 5  b456369c87   alough i will hold you to your word now for w...
# 6  4e815dd602                       im not at litle oven tonight
# 7  3ef24ff6fa                           tgif. i don't feel good.
# 8  f3b0e2db98  twenty20 cricket, beer and sunshine very good....
# 9  bb97edb997                       off to bed, night every onee
#
#                                        selected_text sentiment  text_len  \
# 0                                              sorry  negative        21
# 1                                          Thankyou,  positive        47
# 2                            this is how we do itttt   neutral        23
# 3  everyone's abandoning the office... I still ha...   neutral        62
# 4  I would like to boot from that. I wonder if I ...   neutral       126
# 5  Alough I will hold you to your word now for wh...   neutral        61
# 6                       im not at litle oven tonight   neutral        29
# 7                                   don't feel good.  negative        24
# 8  Twenty20 cricket, beer and sunshine very good....  positive        93
# 9                       off to bed, night every onee   neutral        28
#
#    selected_text_len    set  start  end  \
# 0                  5  train      6    8
# 1                  9  train      1    1
# 2                 23  train      1    8
# 3                 62  train      1    6
# 4                 61  train      1    3
# 5                 60  train      1   11
# 6                 28  train      1    8
# 7                 16  train      1   11
# 8                 93  train      8    9
# 9                 28  train      1    8
#
#                                      prediction   jaccard
# 0                                  m sorry then  0.333333
# 1                                         thank  0.000000
# 2                       this is how we do itttt  1.000000
# 3              everyone's abandoning the office  0.250000
# 4                              acquiring a cent  0.000000
# 5  alough i will hold you to your word now for   0.769231
# 6                  im not at litle oven tonight  1.000000
# 7                      tgif. i don't feel good.  0.600000
# 8                                        good.   0.066667
# 9                  off to bed, night every onee  1.000000
# Validation set
#            textID                                               text  \
# 21988  e45d640ba0     is sooo stressed about everything i have to do
# 21989  dfa0d5ca14                            i just dyededed my hair
# 21990  051f106b59  at the pub with the dog but seems to have misp...
# 21991  4c1897aa51  ugh, still sick. this calgary cold has lasted ...
# 21992  daf57be394  rt  #barcampbkk3 for entertainment at night, b...
# 21993  1381ed35a5    you two are hilaaaaarious, i love it. vernae...
# 21994  424754c08d                        _iain well my team couldn't
# 21995  981713769d  gotta drop off some car parts for a buddy to p...
# 21996  8aef9288d8       just read up on your mom   hope she's okay!!
# 21997  db5005c4d5      that's sad. trauma... future serial killer...
#
#                                            selected_text sentiment  text_len  \
# 21988     is sooo stressed about everything I have to do  negative        46
# 21989                            I just dyededed my hair   neutral        23
# 21990  At the pub with the dog but seems to have misp...   neutral        70
# 21991  Ugh, still sick. This Calgary cold has lasted ...  negative        54
# 21992                                              enjoy  positive       123
# 21993              you two are hilaaaaarious, I love it.  positive        69
# 21994                        _iain well my team couldn't   neutral        27
# 21995  Gotta drop off some car parts for a buddy to p...   neutral       103
# 21996                                   Hope she's okay!  positive        45
# 21997                                              s sad  negative        47
#
#        selected_text_len         set  start  end  \
# 21988                 46  validation      4    4
# 21989                 23  validation      1    6
# 21990                 70  validation      1   13
# 21991                 54  validation      1    5
# 21992                  5  validation     24   24
# 21993                 37  validation      9   11
# 21994                 27  validation      1    8
# 21995                103  validation      1    6
# 21996                 16  validation      7    8
# 21997                  5  validation      1    5
#
#                                               prediction   jaccard
# 21988                                          stressed   0.111111
# 21989                            i just dyededed my hair  1.000000
# 21990  at the pub with the dog but seems to have misp...  0.916667
# 21991                                    ugh, still sick  0.200000
# 21992                                               way   0.000000
# 21993                                          , i love   0.250000
# 21994                        _iain well my team couldn't  1.000000
# 21995                     gotta drop off some car parts   0.375000
# 21996                                           hope she  0.250000
# 21997                                       that's sad.   0.000000
