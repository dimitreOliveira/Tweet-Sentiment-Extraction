# %%
# !nvidia-smi
# Out:
# Sun Jun  7 01:23:54 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/256-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 2,
  "LEARNING_RATE": 1e-4,
  "ES_PATIENCE": 2,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [one_cycle_schedule(tf.cast(x, tf.float32), total_steps=total_steps, 
                        lr_start=lr_min, lr_max=lr_max) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-06 to 0.0001 to 3.81e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name='base_model')
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, use_bias=False, name='qa_outputs')(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1, name='y_start')
    end_logits = tf.squeeze(end_logits, axis=-1, name='y_end')
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print(f'\nFOLD: {n_fold}')
    
    # Load data
    base_data_path = f'fold_{n_fold}/'
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = f'model_fold_{n_fold}.h5'
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    lr = lambda: one_cycle_schedule(tf.cast(optimizer.iterations, tf.float32), 
                                    total_steps=total_steps, lr_start=lr_min, 
                                    lr_max=lr_max)
    
    optimizer = optimizers.Adam(learning_rate=lr)
    
    model.compile(optimizer, loss=[losses.BinaryCrossentropy(from_logits=True),
                                   losses.BinaryCrossentropy(from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 173s - loss: 0.1165 - tf_op_layer_y_start_loss: 0.0659 - tf_op_layer_y_end_loss: 0.0507 - val_loss: 0.0421 - val_tf_op_layer_y_start_loss: 0.0216 - val_tf_op_layer_y_end_loss: 0.0205
# Epoch 2/2
# 672/672 - 173s - loss: 0.0388 - tf_op_layer_y_start_loss: 0.0199 - tf_op_layer_y_end_loss: 0.0189 - val_loss: 0.0389 - val_tf_op_layer_y_start_loss: 0.0201 - val_tf_op_layer_y_end_loss: 0.0188
#
# FOLD: 2
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 174s - loss: 0.1114 - tf_op_layer_y_start_1_loss: 0.0671 - tf_op_layer_y_end_1_loss: 0.0443 - val_loss: 0.0445 - val_tf_op_layer_y_start_1_loss: 0.0222 - val_tf_op_layer_y_end_1_loss: 0.0223
# Epoch 2/2
# 672/672 - 172s - loss: 0.0397 - tf_op_layer_y_start_1_loss: 0.0203 - tf_op_layer_y_end_1_loss: 0.0194 - val_loss: 0.0386 - val_tf_op_layer_y_start_1_loss: 0.0201 - val_tf_op_layer_y_end_1_loss: 0.0186
#
# FOLD: 3
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 172s - loss: 0.0883 - tf_op_layer_y_start_2_loss: 0.0427 - tf_op_layer_y_end_2_loss: 0.0457 - val_loss: 0.0420 - val_tf_op_layer_y_start_2_loss: 0.0214 - val_tf_op_layer_y_end_2_loss: 0.0206
# Epoch 2/2
# 672/672 - 173s - loss: 0.0392 - tf_op_layer_y_start_2_loss: 0.0201 - tf_op_layer_y_end_2_loss: 0.0192 - val_loss: 0.0383 - val_tf_op_layer_y_start_2_loss: 0.0198 - val_tf_op_layer_y_end_2_loss: 0.0185
#
# FOLD: 4
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 172s - loss: 0.1611 - tf_op_layer_y_start_3_loss: 0.0793 - tf_op_layer_y_end_3_loss: 0.0818 - val_loss: 0.0428 - val_tf_op_layer_y_start_3_loss: 0.0214 - val_tf_op_layer_y_end_3_loss: 0.0214
# Epoch 2/2
# 672/672 - 173s - loss: 0.0402 - tf_op_layer_y_start_3_loss: 0.0205 - tf_op_layer_y_end_3_loss: 0.0196 - val_loss: 0.0379 - val_tf_op_layer_y_start_3_loss: 0.0193 - val_tf_op_layer_y_end_3_loss: 0.0186
#
# FOLD: 5
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 672/672 - 172s - loss: 0.0899 - tf_op_layer_y_start_4_loss: 0.0434 - tf_op_layer_y_end_4_loss: 0.0465 - val_loss: 0.0429 - val_tf_op_layer_y_start_4_loss: 0.0217 - val_tf_op_layer_y_end_4_loss: 0.0212
# Epoch 2/2
# 672/672 - 172s - loss: 0.0394 - tf_op_layer_y_start_4_loss: 0.0203 - tf_op_layer_y_end_4_loss: 0.0192 - val_loss: 0.0376 - val_tf_op_layer_y_start_4_loss: 0.0191 - val_tf_op_layer_y_end_4_loss: 0.0185

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_7619dd7e_a866_11ea_84d2_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                                                                           text  ...                                                                                           prediction_fold_5
# 0                                                                          i`d have responded, if i were going  ...                                                                         i`d have responded, if i were going
# 1                                                                sooo sad i will miss you here in san diego!!!  ...                                                                                                    sooo sad
# 2                                                                                    my boss is bullying me...  ...                                                                                                    bullying
# 3                                                                               what interview! leave me alone  ...                                                                                              leave me alone
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...                                                                                               sons of ****,
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...                                                 some shameless plugging for the best rangers forum on earth
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...                                                                                                         fun
# 7                                                                                                   soooo high  ...                                                                                                  soooo high
# 8                                                                                                  both of you  ...                                                                                                 both of you
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...                                                                                                      wow...
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff
# 11                                                    i really really like the song love story by taylor swift  ...                                                                                        i really really like
# 12                                                                my sharpie is running dangerously low on ink  ...                                                                                      dangerously low on ink
# 13                                                          i want to go to music tonight but i lost my voice.  ...                                                                                                        lost
# 14                                                                                  test test from the lg env2  ...                                                                                  test test from the lg env2
#
# [15 rows x 12 columns]
