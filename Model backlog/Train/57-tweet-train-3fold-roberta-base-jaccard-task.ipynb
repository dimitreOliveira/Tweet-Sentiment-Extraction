# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')

k_fold['jaccard'] = k_fold.apply(lambda x: jaccard(x['text'], x['selected_text']), axis=1)

display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5   jaccard
# 0  validation  train  1.000000
# 1       train  train  0.200000
# 2       train  train  0.166667
# 3       train  train  0.600000
# 4       train  train  0.214286
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(0.1)(last_state) 
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(0.1)(last_state) 
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    x_jaccard = layers.GlobalAveragePooling1D()(last_state)
    y_jaccard = layers.Dense(1, activation='linear', name='y_jac')(x_jaccard)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end, y_jaccard])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=[losses.CategoricalCrossentropy(), 
                        losses.CategoricalCrossentropy(), 
                        losses.MeanSquaredError()], 
                  metrics=[metrics.CategoricalAccuracy()])
    
    return model

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# # Train

# %%
history_list = []
AUTO = tf.data.experimental.AUTOTUNE

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    y_train_jac = k_fold[k_fold['fold_%d' % (n_fold)] == 'train']['jaccard'].values.reshape(1, y_train.shape[1])
    y_valid_jac = k_fold[k_fold['fold_%d' % (n_fold)] == 'validation']['jaccard'].values.reshape(1, y_valid.shape[1])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)

    history = model.fit(list(x_train), list(y_train) + list(y_train_jac),
                    validation_data=(list(x_valid), list(y_valid) + list(y_valid_jac)),
                    batch_size=config['BATCH_SIZE'], 
                    callbacks=[checkpoint, es],
                    epochs=config['EPOCHS'], 
                    verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 293s - loss: 2.3062 - y_start_loss: 1.0831 - y_end_loss: 1.1406 - y_jac_loss: 0.0825 - y_start_categorical_accuracy: 0.6482 - y_end_categorical_accuracy: 0.6374 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.7325 - val_y_start_loss: 0.8578 - val_y_end_loss: 0.8048 - val_y_jac_loss: 0.0693 - val_y_start_categorical_accuracy: 0.7043 - val_y_end_categorical_accuracy: 0.7216 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 2/5
# 21984/21984 - 274s - loss: 1.7346 - y_start_loss: 0.8454 - y_end_loss: 0.8263 - y_jac_loss: 0.0629 - y_start_categorical_accuracy: 0.6999 - y_end_categorical_accuracy: 0.7108 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6612 - val_y_start_loss: 0.8072 - val_y_end_loss: 0.7758 - val_y_jac_loss: 0.0775 - val_y_start_categorical_accuracy: 0.7123 - val_y_end_categorical_accuracy: 0.7242 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 3/5
# 21984/21984 - 275s - loss: 1.5353 - y_start_loss: 0.7649 - y_end_loss: 0.7100 - y_jac_loss: 0.0604 - y_start_categorical_accuracy: 0.7195 - y_end_categorical_accuracy: 0.7419 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6250 - val_y_start_loss: 0.8042 - val_y_end_loss: 0.7509 - val_y_jac_loss: 0.0693 - val_y_start_categorical_accuracy: 0.7052 - val_y_end_categorical_accuracy: 0.7229 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 1.4092 - y_start_loss: 0.6927 - y_end_loss: 0.6597 - y_jac_loss: 0.0568 - y_start_categorical_accuracy: 0.7416 - y_end_categorical_accuracy: 0.7546 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6854 - val_y_start_loss: 0.8620 - val_y_end_loss: 0.7591 - val_y_jac_loss: 0.0638 - val_y_start_categorical_accuracy: 0.7051 - val_y_end_categorical_accuracy: 0.7240 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 00004: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 290s - loss: 2.1891 - y_start_loss: 1.0454 - y_end_loss: 1.0646 - y_jac_loss: 0.0791 - y_start_categorical_accuracy: 0.6571 - y_end_categorical_accuracy: 0.6563 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.7828 - val_y_start_loss: 0.8799 - val_y_end_loss: 0.8395 - val_y_jac_loss: 0.0628 - val_y_start_categorical_accuracy: 0.6976 - val_y_end_categorical_accuracy: 0.7191 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 2/5
# 21984/21984 - 275s - loss: 1.6607 - y_start_loss: 0.8272 - y_end_loss: 0.7686 - y_jac_loss: 0.0648 - y_start_categorical_accuracy: 0.7031 - y_end_categorical_accuracy: 0.7265 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.7133 - val_y_start_loss: 0.8423 - val_y_end_loss: 0.8117 - val_y_jac_loss: 0.0588 - val_y_start_categorical_accuracy: 0.6963 - val_y_end_categorical_accuracy: 0.7182 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 3/5
# 21984/21984 - 274s - loss: 1.4728 - y_start_loss: 0.7389 - y_end_loss: 0.6743 - y_jac_loss: 0.0596 - y_start_categorical_accuracy: 0.7250 - y_end_categorical_accuracy: 0.7497 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6975 - val_y_start_loss: 0.8411 - val_y_end_loss: 0.7978 - val_y_jac_loss: 0.0581 - val_y_start_categorical_accuracy: 0.7007 - val_y_end_categorical_accuracy: 0.7182 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 1.3173 - y_start_loss: 0.6627 - y_end_loss: 0.5971 - y_jac_loss: 0.0575 - y_start_categorical_accuracy: 0.7468 - y_end_categorical_accuracy: 0.7752 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.7775 - val_y_start_loss: 0.8802 - val_y_end_loss: 0.8402 - val_y_jac_loss: 0.0567 - val_y_start_categorical_accuracy: 0.6949 - val_y_end_categorical_accuracy: 0.7085 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 291s - loss: 2.2849 - y_start_loss: 1.0802 - y_end_loss: 1.1233 - y_jac_loss: 0.0814 - y_start_categorical_accuracy: 0.6493 - y_end_categorical_accuracy: 0.6431 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.7854 - val_y_start_loss: 0.8749 - val_y_end_loss: 0.8430 - val_y_jac_loss: 0.0669 - val_y_start_categorical_accuracy: 0.7031 - val_y_end_categorical_accuracy: 0.7196 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 2/5
# 21984/21984 - 275s - loss: 1.7186 - y_start_loss: 0.8494 - y_end_loss: 0.8024 - y_jac_loss: 0.0668 - y_start_categorical_accuracy: 0.6989 - y_end_categorical_accuracy: 0.7179 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6621 - val_y_start_loss: 0.8288 - val_y_end_loss: 0.7769 - val_y_jac_loss: 0.0561 - val_y_start_categorical_accuracy: 0.7018 - val_y_end_categorical_accuracy: 0.7193 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 3/5
# 21984/21984 - 275s - loss: 1.5571 - y_start_loss: 0.7719 - y_end_loss: 0.7217 - y_jac_loss: 0.0635 - y_start_categorical_accuracy: 0.7174 - y_end_categorical_accuracy: 0.7399 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6521 - val_y_start_loss: 0.8218 - val_y_end_loss: 0.7625 - val_y_jac_loss: 0.0672 - val_y_start_categorical_accuracy: 0.7021 - val_y_end_categorical_accuracy: 0.7342 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 273s - loss: 1.4276 - y_start_loss: 0.7131 - y_end_loss: 0.6531 - y_jac_loss: 0.0614 - y_start_categorical_accuracy: 0.7331 - y_end_categorical_accuracy: 0.7548 - y_jac_categorical_accuracy: 1.0000 - val_loss: 1.6586 - val_y_start_loss: 0.8299 - val_y_end_loss: 0.7672 - val_y_jac_loss: 0.0611 - val_y_start_categorical_accuracy: 0.7083 - val_y_end_categorical_accuracy: 0.7338 - val_y_jac_categorical_accuracy: 1.0000
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow0_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col0 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col1 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col3 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col4 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col5 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col6 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col7 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow1_col8 {
#             color:  green;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow2_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col4 {
#             color:  orange;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow3_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow4_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow5_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow6_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow7_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col6 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col7 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow8_col8 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col0 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col1 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col2 {
#             color:  red;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col3 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col4 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col5 {
#             color:  black;
#         }    #T_94a9bcee_8306_11ea_9691_274dfe43bb0erow9_col6 {
#             color:  b

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                           my boss is bullying me...        0.166667
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                           my boss is bullying me...        0.166667
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                             cooler.        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12              my sharpie is running dangerously low        0.166667
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
