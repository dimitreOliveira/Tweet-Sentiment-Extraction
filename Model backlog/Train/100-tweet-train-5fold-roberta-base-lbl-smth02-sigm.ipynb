# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96/fold_5.tar.gz
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment  text_len  selected_text_len  \
# 0  i`d have responded, if i were going   neutral        35                 35
# 1                             sooo sad  negative        45                  8
# 2                          bullying me  negative        25                 11
# 3                       leave me alone  negative        30                 14
# 4                        sons of ****,  negative        74                 13
#
#    text_wordCnt  selected_text_wordCnt      fold_1      fold_2      fold_3  \
# 0             7                      7       train       train       train
# 1            10                      2  validation       train       train
# 2             5                      2       train  validation       train
# 3             5                      3       train  validation       train
# 4            14                      3       train       train  validation
#
#        fold_4 fold_5
# 0  validation  train
# 1       train  train
# 2       train  train
# 3       train  train
# 4       train  train
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('sigmoid', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('sigmoid', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 284s - loss: 4.4440 - y_start_loss: 2.2100 - y_end_loss: 2.2340 - y_start_categorical_accuracy: 0.6539 - y_end_categorical_accuracy: 0.6518 - val_loss: 4.0333 - val_y_start_loss: 2.0438 - val_y_end_loss: 1.9890 - val_y_start_categorical_accuracy: 0.7049 - val_y_end_categorical_accuracy: 0.7227
# Epoch 2/6
# 21984/21984 - 270s - loss: 3.9805 - y_start_loss: 2.0067 - y_end_loss: 1.9738 - y_start_categorical_accuracy: 0.7120 - y_end_categorical_accuracy: 0.7337 - val_loss: 3.9704 - val_y_start_loss: 2.0085 - val_y_end_loss: 1.9615 - val_y_start_categorical_accuracy: 0.7140 - val_y_end_categorical_accuracy: 0.7296
# Epoch 3/6
# 21984/21984 - 269s - loss: 3.8724 - y_start_loss: 1.9569 - y_end_loss: 1.9155 - y_start_categorical_accuracy: 0.7295 - y_end_categorical_accuracy: 0.7520 - val_loss: 3.9557 - val_y_start_loss: 1.9978 - val_y_end_loss: 1.9575 - val_y_start_categorical_accuracy: 0.7163 - val_y_end_categorical_accuracy: 0.7320
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 269s - loss: 3.8086 - y_start_loss: 1.9243 - y_end_loss: 1.8843 - y_start_categorical_accuracy: 0.7429 - y_end_categorical_accuracy: 0.7673 - val_loss: 3.9728 - val_y_start_loss: 2.0119 - val_y_end_loss: 1.9606 - val_y_start_categorical_accuracy: 0.7189 - val_y_end_categorical_accuracy: 0.7302
# Epoch 00004: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 283s - loss: 4.4999 - y_start_loss: 2.2229 - y_end_loss: 2.2770 - y_start_categorical_accuracy: 0.6500 - y_end_categorical_accuracy: 0.6303 - val_loss: 4.0934 - val_y_start_loss: 2.0553 - val_y_end_loss: 2.0377 - val_y_start_categorical_accuracy: 0.6936 - val_y_end_categorical_accuracy: 0.7098
# Epoch 2/6
# 21984/21984 - 270s - loss: 4.0120 - y_start_loss: 2.0148 - y_end_loss: 1.9972 - y_start_categorical_accuracy: 0.7095 - y_end_categorical_accuracy: 0.7233 - val_loss: 4.0546 - val_y_start_loss: 2.0440 - val_y_end_loss: 2.0103 - val_y_start_categorical_accuracy: 0.6985 - val_y_end_categorical_accuracy: 0.7233
# Epoch 3/6
# 21984/21984 - 269s - loss: 3.9065 - y_start_loss: 1.9671 - y_end_loss: 1.9394 - y_start_categorical_accuracy: 0.7249 - y_end_categorical_accuracy: 0.7443 - val_loss: 4.0199 - val_y_start_loss: 2.0258 - val_y_end_loss: 1.9937 - val_y_start_categorical_accuracy: 0.7074 - val_y_end_categorical_accuracy: 0.7213
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 268s - loss: 3.8445 - y_start_loss: 1.9373 - y_end_loss: 1.9072 - y_start_categorical_accuracy: 0.7372 - y_end_categorical_accuracy: 0.7561 - val_loss: 4.0320 - val_y_start_loss: 2.0287 - val_y_end_loss: 2.0030 - val_y_start_categorical_accuracy: 0.7054 - val_y_end_categorical_accuracy: 0.7185
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 284s - loss: 4.4154 - y_start_loss: 2.2189 - y_end_loss: 2.1965 - y_start_categorical_accuracy: 0.6520 - y_end_categorical_accuracy: 0.6616 - val_loss: 4.0452 - val_y_start_loss: 2.0383 - val_y_end_loss: 2.0066 - val_y_start_categorical_accuracy: 0.7047 - val_y_end_categorical_accuracy: 0.7243
# Epoch 2/6
# 21984/21984 - 270s - loss: 3.9858 - y_start_loss: 2.0167 - y_end_loss: 1.9692 - y_start_categorical_accuracy: 0.7089 - y_end_categorical_accuracy: 0.7299 - val_loss: 3.9800 - val_y_start_loss: 2.0034 - val_y_end_loss: 1.9762 - val_y_start_categorical_accuracy: 0.7120 - val_y_end_categorical_accuracy: 0.7389
# Epoch 3/6
# 21984/21984 - 270s - loss: 3.8835 - y_start_loss: 1.9674 - y_end_loss: 1.9161 - y_start_categorical_accuracy: 0.7197 - y_end_categorical_accuracy: 0.7488 - val_loss: 3.9754 - val_y_start_loss: 2.0018 - val_y_end_loss: 1.9731 - val_y_start_categorical_accuracy: 0.7134 - val_y_end_categorical_accuracy: 0.7384
# Epoch 4/6
# 21984/21984 - 269s - loss: 3.8220 - y_start_loss: 1.9367 - y_end_loss: 1.8854 - y_start_categorical_accuracy: 0.7373 - y_end_categorical_accuracy: 0.7596 - val_loss: 3.9728 - val_y_start_loss: 2.0031 - val_y_end_loss: 1.9692 - val_y_start_categorical_accuracy: 0.7152 - val_y_end_categorical_accuracy: 0.7418
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 268s - loss: 3.7859 - y_start_loss: 1.9159 - y_end_loss: 1.8700 - y_start_categorical_accuracy: 0.7424 - y_end_categorical_accuracy: 0.7671 - val_loss: 3.9756 - val_y_start_loss: 2.0065 - val_y_end_loss: 1.9687 - val_y_start_categorical_accuracy: 0.7149 - val_y_end_categorical_accuracy: 0.7398
# Epoch 00005: early stopping
#
# FOLD: 4
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 284s - loss: 4.4277 - y_start_loss: 2.2117 - y_end_loss: 2.2160 - y_start_categorical_accuracy: 0.6551 - y_end_categorical_accuracy: 0.6537 - val_loss: 4.0696 - val_y_start_loss: 2.0663 - val_y_end_loss: 2.0029 - val_y_start_categorical_accuracy: 0.6980 - val_y_end_categorical_accuracy: 0.7236
# Epoch 2/6
# 21984/21984 - 270s - loss: 4.0049 - y_start_loss: 2.0226 - y_end_loss: 1.9823 - y_start_categorical_accuracy: 0.7085 - y_end_categorical_accuracy: 0.7298 - val_loss: 3.9988 - val_y_start_loss: 2.0253 - val_y_end_loss: 1.9733 - val_y_start_categorical_accuracy: 0.7020 - val_y_end_categorical_accuracy: 0.7285
# Epoch 3/6
# 21984/21984 - 269s - loss: 3.9116 - y_start_loss: 1.9774 - y_end_loss: 1.9342 - y_start_categorical_accuracy: 0.7207 - y_end_categorical_accuracy: 0.7432 - val_loss: 3.9884 - val_y_start_loss: 2.0255 - val_y_end_loss: 1.9625 - val_y_start_categorical_accuracy: 0.7032 - val_y_end_categorical_accuracy: 0.7325
# Epoch 4/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 269s - loss: 3.8584 - y_start_loss: 1.9513 - y_end_loss: 1.9071 - y_start_categorical_accuracy: 0.7325 - y_end_categorical_accuracy: 0.7542 - val_loss: 3.9902 - val_y_start_loss: 2.0326 - val_y_end_loss: 1.9571 - val_y_start_categorical_accuracy: 0.7051 - val_y_end_categorical_accuracy: 0.7334
# Epoch 00004: early stopping
#
# FOLD: 5
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/6
# 21984/21984 - 283s - loss: 4.5171 - y_start_loss: 2.2444 - y_end_loss: 2.2726 - y_start_categorical_accuracy: 0.6454 - y_end_categorical_accuracy: 0.6370 - val_loss: 4.1027 - val_y_start_loss: 2.0500 - val_y_end_loss: 2.0532 - val_y_start_categorical_accuracy: 0.7009 - val_y_end_categorical_accuracy: 0.7218
# Epoch 2/6
# 21984/21984 - 270s - loss: 4.0201 - y_start_loss: 2.0245 - y_end_loss: 1.9956 - y_start_categorical_accuracy: 0.7072 - y_end_categorical_accuracy: 0.7233 - val_loss: 3.9984 - val_y_start_loss: 2.0189 - val_y_end_loss: 1.9800 - val_y_start_categorical_accuracy: 0.7043 - val_y_end_categorical_accuracy: 0.7296
# Epoch 3/6
# 21984/21984 - 269s - loss: 3.9090 - y_start_loss: 1.9728 - y_end_loss: 1.9362 - y_start_categorical_accuracy: 0.7220 - y_end_categorical_accuracy: 0.7433 - val_loss: 3.9822 - val_y_start_loss: 2.0076 - val_y_end_loss: 1.9750 - val_y_start_categorical_accuracy: 0.7078 - val_y_end_categorical_accuracy: 0.7283
# Epoch 4/6
# 21984/21984 - 270s - loss: 3.8555 - y_start_loss: 1.9461 - y_end_loss: 1.9094 - y_start_categorical_accuracy: 0.7363 - y_end_categorical_accuracy: 0.7543 - val_loss: 3.9747 - val_y_start_loss: 2.0028 - val_y_end_loss: 1.9723 - val_y_start_categorical_accuracy: 0.7127 - val_y_end_categorical_accuracy: 0.7287
# Epoch 5/6
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 268s - loss: 3.8231 - y_start_loss: 1.9288 - y_end_loss: 1.8942 - y_start_categorical_accuracy: 0.7443 - y_end_categorical_accuracy: 0.7595 - val_loss: 3.9816 - val_y_start_loss: 2.0092 - val_y_end_loss: 1.9728 - val_y_start_categorical_accuracy: 0.7096 - val_y_end_categorical_accuracy: 0.7314
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col4 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col6 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col8 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col11 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row1_col12 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col9 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col10 {
#             color:  green;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_5b011088_8dbe_11ea_9b64_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
