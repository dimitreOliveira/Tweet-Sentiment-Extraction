# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers|
# Out:
#      |████████████████████████████████| 573kB 6.7MB/s
#      |████████████████████████████████| 1.0MB 17.2MB/s
#      |████████████████████████████████| 3.7MB 43.3MB/s
#      |████████████████████████████████| 890kB 44.7MB/s
#   Building wheel for sacremoses (setup.py) ... done
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/107-roBERTa_base/'

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())

# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/fold_5.tar.gz'
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 13 columns]
# fold_1/
# fold_1/y_train.npy
# fold_1/x_train.npy
# fold_1/y_valid.npy
# fold_1/x_valid.npy
# fold_2/
# fold_2/y_train.npy
# fold_2/x_train.npy
# fold_2/y_valid.npy
# fold_2/x_valid.npy
# fold_3/
# fold_3/y_train.npy
# fold_3/x_train.npy
# fold_3/y_valid.npy
# fold_3/x_valid.npy
# fold_4/
# fold_4/y_train.npy
# fold_4/x_train.npy
# fold_4/y_valid.npy
# fold_4/x_valid.npy
# fold_5/
# fold_5/y_train.npy
# fold_5/x_train.npy
# fold_5/y_valid.npy
# fold_5/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
# vocab_path = database_base_path + 'vocab.json'
# merges_path = database_base_path + 'merges.txt'
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 6,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "question_size": 4,
  "N_FOLDS": 5,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
# tokenizer.save('./')

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7f2149fc1730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function lrfn at 0x7f2149fc1730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Learning rate schedule: 3e-05 to 3e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h12 = hidden_states[-1]
    h11 = hidden_states[-2]
    h10 = hidden_states[-3]
    h09 = hidden_states[-4]
    
    x_start = layers.Dropout(.1)(h11) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(h11) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)}, 
                             metrics={'y_start': metrics.CategoricalAccuracy(),
                                      'y_end': metrics.CategoricalAccuracy()})
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    ### Delete data dir
    # shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(MODEL_BASE_PATH + model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH + 'last_' + model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 [==============================] - 777s 1s/step - loss: 4.3973 - y_start_loss: 2.1976 - y_end_loss: 2.1997 - y_start_categorical_accuracy: 0.6530 - y_end_categorical_accuracy: 0.6633 - val_loss: 3.9821 - val_y_start_loss: 2.0107 - val_y_end_loss: 1.9714 - val_y_start_categorical_accuracy: 0.7078 - val_y_end_categorical_accuracy: 0.7285 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 [==============================] - 784s 1s/step - loss: 3.9678 - y_start_loss: 2.0020 - y_end_loss: 1.9658 - y_start_categorical_accuracy: 0.7117 - y_end_categorical_accuracy: 0.7369 - val_loss: 3.9644 - val_y_start_loss: 1.9988 - val_y_end_loss: 1.9655 - val_y_start_categorical_accuracy: 0.7114 - val_y_end_categorical_accuracy: 0.7265 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 [==============================] - 783s 1s/step - loss: 3.8530 - y_start_loss: 1.9472 - y_end_loss: 1.9058 - y_start_categorical_accuracy: 0.7330 - y_end_categorical_accuracy: 0.7573 - val_loss: 3.9522 - val_y_start_loss: 1.9933 - val_y_end_loss: 1.9589 - val_y_start_categorical_accuracy: 0.7154 - val_y_end_categorical_accuracy: 0.7289 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 [==============================] - 780s 1s/step - loss: 3.7837 - y_start_loss: 1.9143 - y_end_loss: 1.8695 - y_start_categorical_accuracy: 0.7486 - y_end_categorical_accuracy: 0.7722 - val_loss: 3.9463 - val_y_start_loss: 1.9929 - val_y_end_loss: 1.9535 - val_y_start_categorical_accuracy: 0.7211 - val_y_end_categorical_accuracy: 0.7265 - lr: 3.7500e-06
# Epoch 5/6
# 687/687 [==============================] - ETA: 0s - loss: 3.7433 - y_start_loss: 1.8949 - y_end_loss: 1.8484 - y_start_categorical_accuracy: 0.7560 - y_end_categorical_accuracy: 0.7818Restoring model weights from the end of the best epoch.
# 687/687 [==============================] - 773s 1s/step - loss: 3.7433 - y_start_loss: 1.8949 - y_end_loss: 1.8484 - y_start_categorical_accuracy: 0.7560 - y_end_categorical_accuracy: 0.7818 - val_loss: 3.9724 - val_y_start_loss: 2.0051 - val_y_end_loss: 1.9672 - val_y_start_categorical_accuracy: 0.7183 - val_y_end_categorical_accuracy: 0.7253 - lr: 1.8750e-06
# Epoch 00005: early stopping
#
# FOLD: 2
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 [==============================] - 773s 1s/step - loss: 4.3354 - y_start_loss: 2.1638 - y_end_loss: 2.1716 - y_start_categorical_accuracy: 0.6668 - y_end_categorical_accuracy: 0.6735 - val_loss: 4.0505 - val_y_start_loss: 2.0410 - val_y_end_loss: 2.0095 - val_y_start_categorical_accuracy: 0.6932 - val_y_end_categorical_accuracy: 0.7105 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 [==============================] - 774s 1s/step - loss: 3.9422 - y_start_loss: 1.9884 - y_end_loss: 1.9538 - y_start_categorical_accuracy: 0.7195 - y_end_categorical_accuracy: 0.7376 - val_loss: 4.0434 - val_y_start_loss: 2.0270 - val_y_end_loss: 2.0164 - val_y_start_categorical_accuracy: 0.7009 - val_y_end_categorical_accuracy: 0.7183 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 [==============================] - 773s 1s/step - loss: 3.8379 - y_start_loss: 1.9354 - y_end_loss: 1.9025 - y_start_categorical_accuracy: 0.7411 - y_end_categorical_accuracy: 0.7644 - val_loss: 4.0333 - val_y_start_loss: 2.0347 - val_y_end_loss: 1.9986 - val_y_start_categorical_accuracy: 0.7071 - val_y_end_categorical_accuracy: 0.7236 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 [==============================] - ETA: 0s - loss: 3.7588 - y_start_loss: 1.9022 - y_end_loss: 1.8566 - y_start_categorical_accuracy: 0.7546 - y_end_categorical_accuracy: 0.7813Restoring model weights from the end of the best epoch.
# 687/687 [==============================] - 768s 1s/step - loss: 3.7588 - y_start_loss: 1.9022 - y_end_loss: 1.8566 - y_start_categorical_accuracy: 0.7546 - y_end_categorical_accuracy: 0.7813 - val_loss: 4.0438 - val_y_start_loss: 2.0363 - val_y_end_loss: 2.0075 - val_y_start_categorical_accuracy: 0.7058 - val_y_end_categorical_accuracy: 0.7234 - lr: 3.7500e-06
# Epoch 00004: early stopping
#
# FOLD: 3
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 [==============================] - 775s 1s/step - loss: 4.3981 - y_start_loss: 2.2070 - y_end_loss: 2.1911 - y_start_categorical_accuracy: 0.6577 - y_end_categorical_accuracy: 0.6618 - val_loss: 4.0073 - val_y_start_loss: 2.0230 - val_y_end_loss: 1.9843 - val_y_start_categorical_accuracy: 0.7091 - val_y_end_categorical_accuracy: 0.7283 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 [==============================] - 778s 1s/step - loss: 3.9630 - y_start_loss: 2.0104 - y_end_loss: 1.9526 - y_start_categorical_accuracy: 0.7122 - y_end_categorical_accuracy: 0.7381 - val_loss: 3.9494 - val_y_start_loss: 1.9939 - val_y_end_loss: 1.9555 - val_y_start_categorical_accuracy: 0.7136 - val_y_end_categorical_accuracy: 0.7374 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 [==============================] - 778s 1s/step - loss: 3.8615 - y_start_loss: 1.9545 - y_end_loss: 1.9070 - y_start_categorical_accuracy: 0.7347 - y_end_categorical_accuracy: 0.7552 - val_loss: 3.9449 - val_y_start_loss: 1.9946 - val_y_end_loss: 1.9503 - val_y_start_categorical_accuracy: 0.7147 - val_y_end_categorical_accuracy: 0.7331 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 [==============================] - ETA: 0s - loss: 3.7890 - y_start_loss: 1.9223 - y_end_loss: 1.8667 - y_start_categorical_accuracy: 0.7474 - y_end_categorical_accuracy: 0.7737Restoring model weights from the end of the best epoch.
# 687/687 [==============================] - 774s 1s/step - loss: 3.7890 - y_start_loss: 1.9223 - y_end_loss: 1.8667 - y_start_categorical_accuracy: 0.7474 - y_end_categorical_accuracy: 0.7737 - val_loss: 3.9561 - val_y_start_loss: 1.9981 - val_y_end_loss: 1.9581 - val_y_start_categorical_accuracy: 0.7171 - val_y_end_categorical_accuracy: 0.7364 - lr: 3.7500e-06
# Epoch 00004: early stopping
#
# FOLD: 4
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 [==============================] - 780s 1s/step - loss: 4.4932 - y_start_loss: 2.2158 - y_end_loss: 2.2774 - y_start_categorical_accuracy: 0.6506 - y_end_categorical_accuracy: 0.6406 - val_loss: 4.0647 - val_y_start_loss: 2.0565 - val_y_end_loss: 2.0083 - val_y_start_categorical_accuracy: 0.6969 - val_y_end_categorical_accuracy: 0.7214 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 [==============================] - 773s 1s/step - loss: 3.9956 - y_start_loss: 2.0091 - y_end_loss: 1.9865 - y_start_categorical_accuracy: 0.7142 - y_end_categorical_accuracy: 0.7314 - val_loss: 4.0263 - val_y_start_loss: 2.0449 - val_y_end_loss: 1.9814 - val_y_start_categorical_accuracy: 0.6971 - val_y_end_categorical_accuracy: 0.7298 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 [==============================] - 775s 1s/step - loss: 3.8781 - y_start_loss: 1.9533 - y_end_loss: 1.9249 - y_start_categorical_accuracy: 0.7359 - y_end_categorical_accuracy: 0.7552 - val_loss: 4.0038 - val_y_start_loss: 2.0283 - val_y_end_loss: 1.9755 - val_y_start_categorical_accuracy: 0.7016 - val_y_end_categorical_accuracy: 0.7296 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 [==============================] - ETA: 0s - loss: 3.8080 - y_start_loss: 1.9178 - y_end_loss: 1.8902 - y_start_categorical_accuracy: 0.7486 - y_end_categorical_accuracy: 0.7687Restoring model weights from the end of the best epoch.
# 687/687 [==============================] - 771s 1s/step - loss: 3.8080 - y_start_loss: 1.9178 - y_end_loss: 1.8902 - y_start_categorical_accuracy: 0.7486 - y_end_categorical_accuracy: 0.7687 - val_loss: 4.0198 - val_y_start_loss: 2.0353 - val_y_end_loss: 1.9844 - val_y_start_categorical_accuracy: 0.6960 - val_y_end_categorical_accuracy: 0.7269 - lr: 3.7500e-06
# Epoch 00004: early stopping
#
# FOLD: 5
# Epoch 1/6
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/encoder/layer_._11/attention/self/query/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/query/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/key/bias:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/self/value/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/attention/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/intermediate/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/dense/kernel:0', 'base_model/roberta/encoder/layer_._11/output/dense/bias:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0', 'base_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0', 'base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 687/687 [==============================] - 774s 1s/step - loss: 4.3148 - y_start_loss: 2.1621 - y_end_loss: 2.1527 - y_start_categorical_accuracy: 0.6654 - y_end_categorical_accuracy: 0.6741 - val_loss: 4.0093 - val_y_start_loss: 2.0157 - val_y_end_loss: 1.9936 - val_y_start_categorical_accuracy: 0.7012 - val_y_end_categorical_accuracy: 0.7278 - lr: 3.0000e-05
# Epoch 2/6
# 687/687 [==============================] - 773s 1s/step - loss: 3.9383 - y_start_loss: 1.9901 - y_end_loss: 1.9482 - y_start_categorical_accuracy: 0.7163 - y_end_categorical_accuracy: 0.7394 - val_loss: 3.9749 - val_y_start_loss: 2.0074 - val_y_end_loss: 1.9675 - val_y_start_categorical_accuracy: 0.7071 - val_y_end_categorical_accuracy: 0.7373 - lr: 1.5000e-05
# Epoch 3/6
# 687/687 [==============================] - 773s 1s/step - loss: 3.8254 - y_start_loss: 1.9369 - y_end_loss: 1.8885 - y_start_categorical_accuracy: 0.7379 - y_end_categorical_accuracy: 0.7622 - val_loss: 3.9748 - val_y_start_loss: 2.0095 - val_y_end_loss: 1.9653 - val_y_start_categorical_accuracy: 0.7102 - val_y_end_categorical_accuracy: 0.7309 - lr: 7.5000e-06
# Epoch 4/6
# 687/687 [==============================] - ETA: 0s - loss: 3.7574 - y_start_loss: 1.9028 - y_end_loss: 1.8546 - y_start_categorical_accuracy: 0.7523 - y_end_categorical_accuracy: 0.7766Restoring model weights from the end of the best epoch.
# 687/687 [==============================] - 773s 1s/step - loss: 3.7574 - y_start_loss: 1.9028 - y_end_loss: 1.8546 - y_start_categorical_accuracy: 0.7523 - y_end_categorical_accuracy: 0.7766 - val_loss: 3.9812 - val_y_start_loss: 2.0112 - val_y_end_loss: 1.9700 - val_y_start_categorical_accuracy: 0.7083 - val_y_end_categorical_accuracy: 0.7331 - lr: 3.7500e-06
# Epoch 00004: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col4 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col5 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col6 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col7 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col8 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col11 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row1_col12 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col9 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col10 {
#             color:  green;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_2d94477c_8fb8_11ea_b382_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_5
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       0.833333
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       1.000000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       1.000000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 13 columns]
