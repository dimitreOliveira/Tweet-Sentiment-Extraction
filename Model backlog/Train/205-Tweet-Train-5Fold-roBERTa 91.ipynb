# %%
# !nvidia-smi
# Out:
# Thu May 28 15:10:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 665kB 8.7MB/s
#      |████████████████████████████████| 890kB 22.5MB/s
#      |████████████████████████████████| 3.8MB 44.7MB/s
#      |████████████████████████████████| 1.1MB 56.9MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/205-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
pd.set_option('max_colwidth', 120)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_1.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_2.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_3.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_4.tar.gz'
# !tar -xf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete_64_clean/fold_5.tar.gz'

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete_64_clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training samples: 26882
#        textID  ... imputed
# 0  cb774db0d1  ...   False
# 1  549e992a42  ...   False
# 2  088c60f138  ...   False
# 3  9642c003ef  ...   False
# 4  358bd9e861  ...   False
#
# [5 rows x 17 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 64,
  "BATCH_SIZE": 32,
  "EPOCHS": 5,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 1,
  "N_FOLDS": 5,
  "question_size": 4,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function lrfn at 0x7f92637c1840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(.1)(last_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)
    
    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    # model.load_weights(MODEL_BASE_PATH + model_path)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
# Out:
# FOLD: 1
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 673/673 - 188s - loss: 4.1800 - y_start_loss: 2.0721 - y_end_loss: 2.1079 - val_loss: 3.8028 - val_y_start_loss: 1.9281 - val_y_end_loss: 1.8747 - lr: 3.0000e-05
# Epoch 2/5
# 673/673 - 188s - loss: 3.7497 - y_start_loss: 1.8886 - y_end_loss: 1.8611 - val_loss: 3.7753 - val_y_start_loss: 1.9089 - val_y_end_loss: 1.8664 - lr: 1.5000e-05
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 673/673 - 184s - loss: 3.6387 - y_start_loss: 1.8367 - y_end_loss: 1.8019 - val_loss: 3.7766 - val_y_start_loss: 1.9150 - val_y_end_loss: 1.8615 - lr: 7.5000e-06
# Epoch 00003: early stopping
#
# FOLD: 2
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 673/673 - 188s - loss: 4.1705 - y_start_loss: 2.0607 - y_end_loss: 2.1099 - val_loss: 3.8514 - val_y_start_loss: 1.9356 - val_y_end_loss: 1.9158 - lr: 3.0000e-05
# Epoch 2/5
# 673/673 - 188s - loss: 3.7621 - y_start_loss: 1.8967 - y_end_loss: 1.8654 - val_loss: 3.7778 - val_y_start_loss: 1.9121 - val_y_end_loss: 1.8657 - lr: 1.5000e-05
# Epoch 3/5
# 673/673 - 188s - loss: 3.6504 - y_start_loss: 1.8474 - y_end_loss: 1.8030 - val_loss: 3.7475 - val_y_start_loss: 1.8963 - val_y_end_loss: 1.8513 - lr: 7.5000e-06
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 673/673 - 183s - loss: 3.5953 - y_start_loss: 1.8190 - y_end_loss: 1.7763 - val_loss: 3.7522 - val_y_start_loss: 1.8999 - val_y_end_loss: 1.8523 - lr: 3.7500e-06
# Epoch 00004: early stopping
#
# FOLD: 3
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 673/673 - 184s - loss: 4.2210 - y_start_loss: 2.0947 - y_end_loss: 2.1264 - val_loss: 3.8098 - val_y_start_loss: 1.9216 - val_y_end_loss: 1.8882 - lr: 3.0000e-05
# Epoch 2/5
# 673/673 - 186s - loss: 3.8028 - y_start_loss: 1.9171 - y_end_loss: 1.8857 - val_loss: 3.7958 - val_y_start_loss: 1.9281 - val_y_end_loss: 1.8677 - lr: 1.5000e-05
# Epoch 3/5
# 673/673 - 186s - loss: 3.6765 - y_start_loss: 1.8601 - y_end_loss: 1.8165 - val_loss: 3.7564 - val_y_start_loss: 1.9005 - val_y_end_loss: 1.8559 - lr: 7.5000e-06
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 673/673 - 181s - loss: 3.6127 - y_start_loss: 1.8289 - y_end_loss: 1.7839 - val_loss: 3.7682 - val_y_start_loss: 1.9097 - val_y_end_loss: 1.8585 - lr: 3.7500e-06
# Epoch 00004: early stopping
#
# FOLD: 4
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 673/673 - 185s - loss: 4.1805 - y_start_loss: 2.0806 - y_end_loss: 2.0998 - val_loss: 3.8717 - val_y_start_loss: 1.9514 - val_y_end_loss: 1.9203 - lr: 3.0000e-05
# Epoch 2/5
# 673/673 - 185s - loss: 3.7649 - y_start_loss: 1.9026 - y_end_loss: 1.8622 - val_loss: 3.7653 - val_y_start_loss: 1.9007 - val_y_end_loss: 1.8646 - lr: 1.5000e-05
# Epoch 3/5
# 673/673 - 186s - loss: 3.6588 - y_start_loss: 1.8508 - y_end_loss: 1.8080 - val_loss: 3.7560 - val_y_start_loss: 1.8947 - val_y_end_loss: 1.8613 - lr: 7.5000e-06
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 673/673 - 181s - loss: 3.5930 - y_start_loss: 1.8191 - y_end_loss: 1.7739 - val_loss: 3.7611 - val_y_start_loss: 1.8989 - val_y_end_loss: 1.8622 - lr: 3.7500e-06
# Epoch 00004: early stopping
#
# FOLD: 5
# Epoch 1/5
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# 673/673 - 184s - loss: 4.2061 - y_start_loss: 2.0868 - y_end_loss: 2.1192 - val_loss: 3.8771 - val_y_start_loss: 1.9186 - val_y_end_loss: 1.9584 - lr: 3.0000e-05
# Epoch 2/5
# 673/673 - 186s - loss: 3.8169 - y_start_loss: 1.9082 - y_end_loss: 1.9087 - val_loss: 3.8057 - val_y_start_loss: 1.8954 - val_y_end_loss: 1.9103 - lr: 1.5000e-05
# Epoch 3/5
# 673/673 - 186s - loss: 3.7024 - y_start_loss: 1.8560 - y_end_loss: 1.8464 - val_loss: 3.7878 - val_y_start_loss: 1.8892 - val_y_end_loss: 1.8986 - lr: 7.5000e-06
# Epoch 4/5
# 673/673 - 185s - loss: 3.6464 - y_start_loss: 1.8315 - y_end_loss: 1.8149 - val_loss: 3.7739 - val_y_start_loss: 1.8905 - val_y_end_loss: 1.8834 - lr: 3.7500e-06
# Epoch 5/5
# 673/673 - 186s - loss: 3.5988 - y_start_loss: 1.8120 - y_end_loss: 1.7868 - val_loss: 3.7640 - val_y_start_loss: 1.8898 - val_y_end_loss: 1.8743 - lr: 1.8750e-06

# %% [markdown]
# # Model loss graph

# %%
#@title
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col9 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col10 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row2_col12 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col0 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col1 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col3 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col4 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col6 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col8 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col9 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col10 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row4_col12 {
#             color:  green;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_77319760_a0ff_11ea_83f1_0242ac1c0002row6_col9

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['jaccard_mean'] = (k_fold['jaccard_fold_1'] + k_fold['jaccard_fold_2'] + 
                          k_fold['jaccard_fold_3'] + k_fold['jaccard_fold_4'] + 
                          k_fold['jaccard_fold_4']) / 5

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean']].head(15))
# Out:
#                                                                                                           text  ... jaccard_mean
# 0                                                                          i`d have responded, if i were going  ...     1.000000
# 1                                                                sooo sad i will miss you here in san diego!!!  ...     0.900000
# 2                                                                                    my boss is bullying me...  ...     0.266667
# 3                                                                               what interview! leave me alone  ...     1.000000
# 4                                   sons of ****, why couldn`t they put them on the releases we already bought  ...     0.866667
# 5                 http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth  ...     0.900000
# 6                                             2am feedings for the baby are fun when he is all smiles and coos  ...     1.000000
# 7                                                                                                   soooo high  ...     1.000000
# 8                                                                                                  both of you  ...     1.000000
# 9                                         journey!? wow... u just became cooler.  hehe... (is that possible!?)  ...     0.520000
# 10  as much as i love to be hopeful, i reckon the chances are minimal =p i`m never gonna get my cake and stuff  ...     1.000000
# 11                                                    i really really like the song love story by taylor swift  ...     0.333333
# 12                                                                my sharpie is running dangerously low on ink  ...     0.350000
# 13                                                          i want to go to music tonight but i lost my voice.  ...     0.466667
# 14                                                                                  test test from the lg env2  ...     1.000000
#
# [15 rows x 7 columns]
