# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_1.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_2.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_3.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_4.tar.gz
# !tar -xvf /kaggle/input/tweet-dataset-split-roberta-base-96-aux/fold_5.tar.gz
# Out:
# fold_1/
# fold_1/y_valid.npy
# fold_1/x_valid_aux.npy
# fold_1/y_train_mask.npy
# fold_1/x_train_aux.npy
# fold_1/x_valid.npy
# fold_1/x_valid_aux2.npy
# fold_1/y_valid_aux.npy
# fold_1/y_train.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_mask.npy
# fold_1/x_train.npy
# fold_1/x_train_aux2.npy
# fold_2/
# fold_2/y_valid.npy
# fold_2/x_valid_aux.npy
# fold_2/y_train_mask.npy
# fold_2/x_train_aux.npy
# fold_2/x_valid.npy
# fold_2/x_valid_aux2.npy
# fold_2/y_valid_aux.npy
# fold_2/y_train.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_mask.npy
# fold_2/x_train.npy
# fold_2/x_train_aux2.npy
# fold_3/
# fold_3/y_valid.npy
# fold_3/x_valid_aux.npy
# fold_3/y_train_mask.npy
# fold_3/x_train_aux.npy
# fold_3/x_valid.npy
# fold_3/x_valid_aux2.npy
# fold_3/y_valid_aux.npy
# fold_3/y_train.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_mask.npy
# fold_3/x_train.npy
# fold_3/x_train_aux2.npy
# fold_4/
# fold_4/y_valid.npy
# fold_4/x_valid_aux.npy
# fold_4/y_train_mask.npy
# fold_4/x_train_aux.npy
# fold_4/x_valid.npy
# fold_4/x_valid_aux2.npy
# fold_4/y_valid_aux.npy
# fold_4/y_train.npy
# fold_4/y_train_aux.npy
# fold_4/y_valid_mask.npy
# fold_4/x_train.npy
# fold_4/x_train_aux2.npy
# fold_5/
# fold_5/y_valid.npy
# fold_5/x_valid_aux.npy
# fold_5/y_train_mask.npy
# fold_5/x_train_aux.npy
# fold_5/x_valid.npy
# fold_5/x_valid_aux2.npy
# fold_5/y_valid_aux.npy
# fold_5/y_train.npy
# fold_5/y_train_aux.npy
# fold_5/y_valid_mask.npy
# fold_5/x_train.npy
# fold_5/x_train_aux2.npy

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-roberta-base-96-aux/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    selected_text_len  text_wordCnt  selected_text_wordCnt      fold_1  \
# 0                 35             7                      7       train
# 1                  8            10                      2  validation
# 2                 11             5                      2       train
# 3                 14             5                      3       train
# 4                 13            14                      3       train
#
#        fold_2      fold_3      fold_4 fold_5
# 0       train       train  validation  train
# 1       train       train       train  train
# 2  validation       train       train  train
# 3  validation       train       train  train
# 4       train  validation       train  train

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 96,
  'BATCH_SIZE': 32,
  'EPOCHS': 5,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 1,
  'question_size': 4,
  'N_FOLDS': 5,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
LR_MIN = 1e-6
LR_MAX = config['LEARNING_RATE']
LR_EXP_DECAY = .5

@tf.function
def lrfn(epoch):
    lr = LR_MAX * LR_EXP_DECAY**epoch
    if lr < LR_MIN:
        lr = LR_MIN
    return lr
    
rng = [i for i in range(config['EPOCHS'])]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.87e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_hidden_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    optimizer = optimizers.Adam(lr=config['LEARNING_RATE'])
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']
    
    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    lr_schedule = LearningRateScheduler(lrfn)

    history = model.fit(list(x_train), list(y_train),
                        validation_data=(list(x_valid), list(y_valid)),
                        batch_size=config['BATCH_SIZE'], 
                        callbacks=[checkpoint, es, lr_schedule],
                        epochs=config['EPOCHS'], 
                        verbose=2).history
    
    history_list.append(history)
    model.load_weights(model_path)
    
    # Make predictions
    train_preds = model.predict(list(x_train))
    valid_preds = model.predict(list(x_valid))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 286s - loss: 4.4381 - y_start_loss: 2.2179 - y_end_loss: 2.2203 - val_loss: 4.0038 - val_y_start_loss: 2.0251 - val_y_end_loss: 1.9784
# Epoch 2/5
# 21984/21984 - 272s - loss: 3.9724 - y_start_loss: 2.0076 - y_end_loss: 1.9648 - val_loss: 3.9585 - val_y_start_loss: 2.0006 - val_y_end_loss: 1.9575
# Epoch 3/5
# 21984/21984 - 271s - loss: 3.8626 - y_start_loss: 1.9552 - y_end_loss: 1.9075 - val_loss: 3.9479 - val_y_start_loss: 1.9954 - val_y_end_loss: 1.9520
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.7913 - y_start_loss: 1.9191 - y_end_loss: 1.8722 - val_loss: 3.9543 - val_y_start_loss: 1.9994 - val_y_end_loss: 1.9545
# Epoch 00004: early stopping
#
# FOLD: 2
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 285s - loss: 4.4081 - y_start_loss: 2.1902 - y_end_loss: 2.2179 - val_loss: 4.0981 - val_y_start_loss: 2.0582 - val_y_end_loss: 2.0396
# Epoch 2/5
# 21984/21984 - 272s - loss: 3.9882 - y_start_loss: 2.0092 - y_end_loss: 1.9790 - val_loss: 4.0413 - val_y_start_loss: 2.0299 - val_y_end_loss: 2.0110
# Epoch 3/5
# 21984/21984 - 271s - loss: 3.8938 - y_start_loss: 1.9584 - y_end_loss: 1.9354 - val_loss: 4.0306 - val_y_start_loss: 2.0269 - val_y_end_loss: 2.0034
# Epoch 4/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.8257 - y_start_loss: 1.9294 - y_end_loss: 1.8962 - val_loss: 4.0395 - val_y_start_loss: 2.0350 - val_y_end_loss: 2.0042
# Epoch 00004: early stopping
#
# FOLD: 3
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 285s - loss: 4.3959 - y_start_loss: 2.2078 - y_end_loss: 2.1881 - val_loss: 4.0376 - val_y_start_loss: 2.0429 - val_y_end_loss: 1.9945
# Epoch 2/5
# 21984/21984 - 272s - loss: 3.9758 - y_start_loss: 2.0176 - y_end_loss: 1.9582 - val_loss: 3.9678 - val_y_start_loss: 2.0096 - val_y_end_loss: 1.9579
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.8607 - y_start_loss: 1.9588 - y_end_loss: 1.9019 - val_loss: 3.9729 - val_y_start_loss: 2.0085 - val_y_end_loss: 1.9639
# Epoch 00003: early stopping
#
# FOLD: 4
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 285s - loss: 4.4462 - y_start_loss: 2.2091 - y_end_loss: 2.2372 - val_loss: 4.0548 - val_y_start_loss: 2.0547 - val_y_end_loss: 1.9996
# Epoch 2/5
# 21984/21984 - 272s - loss: 3.9923 - y_start_loss: 2.0150 - y_end_loss: 1.9773 - val_loss: 4.0075 - val_y_start_loss: 2.0328 - val_y_end_loss: 1.9743
# Epoch 3/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 271s - loss: 3.8861 - y_start_loss: 1.9631 - y_end_loss: 1.9229 - val_loss: 4.0096 - val_y_start_loss: 2.0381 - val_y_end_loss: 1.9709
# Epoch 00003: early stopping
#
# FOLD: 5
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/5
# 21984/21984 - 284s - loss: 4.4627 - y_start_loss: 2.2111 - y_end_loss: 2.2517 - val_loss: 4.0869 - val_y_start_loss: 2.0465 - val_y_end_loss: 2.0410
# Epoch 2/5
# 21984/21984 - 271s - loss: 4.0235 - y_start_loss: 2.0191 - y_end_loss: 2.0044 - val_loss: 4.0018 - val_y_start_loss: 2.0123 - val_y_end_loss: 1.9901
# Epoch 3/5
# 21984/21984 - 271s - loss: 3.9105 - y_start_loss: 1.9662 - y_end_loss: 1.9443 - val_loss: 3.9986 - val_y_start_loss: 2.0127 - val_y_end_loss: 1.9863
# Epoch 4/5
# 21984/21984 - 272s - loss: 3.8494 - y_start_loss: 1.9386 - y_end_loss: 1.9108 - val_loss: 3.9870 - val_y_start_loss: 2.0086 - val_y_end_loss: 1.9788
# Epoch 5/5
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 270s - loss: 3.8149 - y_start_loss: 1.9201 - y_end_loss: 1.8947 - val_loss: 3.9941 - val_y_start_loss: 2.0161 - val_y_end_loss: 1.9785
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_df9a6dee_96fb_11ea_a1be_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                        dangerously        1.000000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                            bullying        0.500000
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
