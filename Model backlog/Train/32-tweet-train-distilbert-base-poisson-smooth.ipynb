# %% [markdown]
# ## Dependencies

# %%
import json
from tweet_utility_scripts import *
from transformers import TFDistilBertModel, DistilBertConfig
from tokenizers import BertWordPieceTokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/tweet-dataset-split-distilbert-uncased-128/'
hold_out = pd.read_csv(database_base_path + 'hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
display(hold_out.head())

# Unzip files
# !tar -xvf /kaggle/input/tweet-dataset-split-distilbert-uncased-128/hold_out.tar.gz

base_data_path = 'hold_out/'
x_train = np.load(base_data_path + 'x_train.npy')
y_train = np.load(base_data_path + 'y_train.npy')
x_valid = np.load(base_data_path + 'x_valid.npy')
y_valid = np.load(base_data_path + 'y_valid.npy')

y_train = y_train.astype('float')
y_valid = y_valid.astype('float')

# Delete data dir
shutil.rmtree(base_data_path)
# Out:
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
#
#    selected_text_len    set
# 0                 95  train
# 1                 10  train
# 2                 23  train
# 3                  9  train
# 4                 41  train
# hold_out/
# hold_out/y_valid.npy
# hold_out/x_train.npy
# hold_out/y_train.npy
# hold_out/x_valid.npy

# %% [markdown]
# # Model parameters

# %%
tokenizer_path = database_base_path + 'vocab.txt'
base_path = '/kaggle/input/qa-transformers/distilbert/'
model_path = 'model.h5'

config = {
  "MAX_LEN": 128,
  "BATCH_SIZE": 64,
  "EPOCHS": 20,
  "LEARNING_RATE": 1e-5,
  "ES_PATIENCE": 3,
  "question_size": 3,
  "smooth_factor": .5,
  "base_model_path": base_path + 'distilbert-base-uncased-distilled-squad-tf_model.h5',
  "config_path": base_path + 'distilbert-base-uncased-distilled-squad-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %%
dist = [pow(config['smooth_factor'], i) for i in range(1, config['MAX_LEN'])]
def smooth_labels_dist_start(y, dist=dist):
    center = y.argmax()
    y[center+1:] = dist[1:len(y[center:])]
    y[:center] = dist[::-1][-len(y[:center]):]
    
    return y

def smooth_labels_dist_end(y, dist=dist):
    center = y.argmax()
    y[center+1:] = dist[:len(y[center+1:])]
    y[:center] = dist[:0:-1][-len(y[:center]):]
    
    return y
 
np.apply_along_axis(smooth_labels_dist_start, -1, y_train[0])
np.apply_along_axis(smooth_labels_dist_end, -1, y_train[1])
np.apply_along_axis(smooth_labels_dist_start, -1, y_valid[0])
np.apply_along_axis(smooth_labels_dist_end, -1, y_valid[1])
# Out:
# array([[3.12500000e-02, 6.25000000e-02, 1.25000000e-01, ...,
#         3.76158192e-37, 1.88079096e-37, 9.40395481e-38],
#        [1.81898940e-12, 3.63797881e-12, 7.27595761e-12, ...,
#         6.46234854e-27, 3.23117427e-27, 1.61558713e-27],
#        [9.76562500e-04, 1.95312500e-03, 3.90625000e-03, ...,
#         1.20370622e-35, 6.01853108e-36, 3.00926554e-36],
#        ...,
#        [2.27373675e-13, 4.54747351e-13, 9.09494702e-13, ...,
#         5.16987883e-26, 2.58493941e-26, 1.29246971e-26],
#        [2.38418579e-07, 4.76837158e-07, 9.53674316e-07, ...,
#         4.93038066e-32, 2.46519033e-32, 1.23259516e-32],
#        [3.90625000e-03, 7.81250000e-03, 1.56250000e-02, ...,
#         3.00926554e-36, 1.50463277e-36, 7.52316385e-37]])

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    token_type_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='token_type_ids')
    
    base_model = TFDistilBertModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask, 'token_type_ids': token_type_ids})
    last_state = sequence_output[0]
    
    x = GlobalAveragePooling1D()(last_state)
    
    y_start = Dense(MAX_LEN, activation='sigmoid', name='y_start')(x)     
    y_end = Dense(MAX_LEN, activation='sigmoid', name='y_end')(x)        
    
    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=[y_start, y_end])
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy()])
    
    return model

model = model_fn(config['MAX_LEN'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# attention_mask (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# input_ids (InputLayer)          [(None, 128)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 128)]        0
# __________________________________________________________________________________________________
# base_model (TFDistilBertModel)  ((None, 128, 768),)  66362880    attention_mask[0][0]
#                                                                  input_ids[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           base_model[0][0]
# __________________________________________________________________________________________________
# y_start (Dense)                 (None, 128)          98432       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# y_end (Dense)                   (None, 128)          98432       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 66,559,744
# Trainable params: 66,559,744
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train

# %%
tb_callback = TensorBoard(log_dir='./')
es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                   restore_best_weights=True, verbose=1)

history = model.fit(list(x_train), list(y_train),
                    validation_data=(list(x_valid), list(y_valid)),
                    callbacks=[es, tb_callback],
                    epochs=config['EPOCHS'], 
                    batch_size=config['BATCH_SIZE'],
                    verbose=2).history

model.save_weights(model_path)
# Out:
# Train on 21984 samples, validate on 5496 samples
# Epoch 1/20
# 21984/21984 - 177s - loss: 0.4727 - y_start_loss: 0.2257 - y_end_loss: 0.2467 - y_start_binary_accuracy: 0.0040 - y_end_binary_accuracy: 2.1429e-04 - val_loss: 0.2755 - val_y_start_loss: 0.1289 - val_y_end_loss: 0.1466 - val_y_start_binary_accuracy: 0.0045 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 2/20
# 21984/21984 - 166s - loss: 0.2262 - y_start_loss: 0.1046 - y_end_loss: 0.1216 - y_start_binary_accuracy: 0.0039 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.1854 - val_y_start_loss: 0.0847 - val_y_end_loss: 0.1008 - val_y_start_binary_accuracy: 0.0038 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 3/20
# 21984/21984 - 166s - loss: 0.1675 - y_start_loss: 0.0760 - y_end_loss: 0.0915 - y_start_binary_accuracy: 0.0037 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.1507 - val_y_start_loss: 0.0682 - val_y_end_loss: 0.0825 - val_y_start_binary_accuracy: 0.0037 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 4/20
# 21984/21984 - 166s - loss: 0.1407 - y_start_loss: 0.0638 - y_end_loss: 0.0769 - y_start_binary_accuracy: 0.0039 - y_end_binary_accuracy: 0.0000e+00 - val_loss: 0.1297 - val_y_start_loss: 0.0592 - val_y_end_loss: 0.0705 - val_y_start_binary_accuracy: 0.0038 - val_y_end_binary_accuracy: 0.0000e+00
# Epoch 5/20
# 21984/21984 - 166s - loss: 0.1232 - y_start_loss: 0.0563 - y_end_loss: 0.0669 - y_start_binary_accuracy: 0.0040 - y_end_binary_accuracy: 7.4628e-06 - val_loss: 0.1157 - val_y_start_loss: 0.0533 - val_y_end_loss: 0.0624 - val_y_start_binary_accuracy: 0.0040 - val_y_end_binary_accuracy: 7.2496e-05
# Epoch 6/20
# 21984/21984 - 166s - loss: 0.1116 - y_start_loss: 0.0516 - y_end_loss: 0.0600 - y_start_binary_accuracy: 0.0040 - y_end_binary_accuracy: 9.0975e-05 - val_loss: 0.1071 - val_y_start_loss: 0.0499 - val_y_end_loss: 0.0571 - val_y_start_binary_accuracy: 0.0040 - val_y_end_binary_accuracy: 8.2020e-04
# Epoch 7/20
# 21984/21984 - 166s - loss: 0.1034 - y_start_loss: 0.0483 - y_end_loss: 0.0551 - y_start_binary_accuracy: 0.0040 - y_end_binary_accuracy: 5.8601e-04 - val_loss: 0.1010 - val_y_start_loss: 0.0475 - val_y_end_loss: 0.0535 - val_y_start_binary_accuracy: 0.0039 - val_y_end_binary_accuracy: 0.0018
# Epoch 8/20
# 21984/21984 - 166s - loss: 0.0976 - y_start_loss: 0.0459 - y_end_loss: 0.0517 - y_start_binary_accuracy: 0.0040 - y_end_binary_accuracy: 0.0014 - val_loss: 0.0971 - val_y_start_loss: 0.0457 - val_y_end_loss: 0.0514 - val_y_start_binary_accuracy: 0.0040 - val_y_end_binary_accuracy: 0.0021
# Epoch 9/20
# 21984/21984 - 166s - loss: 0.0934 - y_start_loss: 0.0441 - y_end_loss: 0.0493 - y_start_binary_accuracy: 0.0041 - y_end_binary_accuracy: 0.0021 - val_loss: 0.0944 - val_y_start_loss: 0.0447 - val_y_end_loss: 0.0498 - val_y_start_binary_accuracy: 0.0040 - val_y_end_binary_accuracy: 0.0032
# Epoch 10/20
# 21984/21984 - 167s - loss: 0.0901 - y_start_loss: 0.0426 - y_end_loss: 0.0475 - y_start_binary_accuracy: 0.0041 - y_end_binary_accuracy: 0.0028 - val_loss: 0.0928 - val_y_start_loss: 0.0440 - val_y_end_loss: 0.0487 - val_y_start_binary_accuracy: 0.0042 - val_y_end_binary_accuracy: 0.0035
# Epoch 11/20
# 21984/21984 - 166s - loss: 0.0874 - y_start_loss: 0.0414 - y_end_loss: 0.0459 - y_start_binary_accuracy: 0.0042 - y_end_binary_accuracy: 0.0033 - val_loss: 0.0912 - val_y_start_loss: 0.0434 - val_y_end_loss: 0.0478 - val_y_start_binary_accuracy: 0.0041 - val_y_end_binary_accuracy: 0.0039
# Epoch 12/20
# 21984/21984 - 166s - loss: 0.0852 - y_start_loss: 0.0405 - y_end_loss: 0.0447 - y_start_binary_accuracy: 0.0043 - y_end_binary_accuracy: 0.0037 - val_loss: 0.0902 - val_y_start_loss: 0.0430 - val_y_end_loss: 0.0473 - val_y_start_binary_accuracy: 0.0043 - val_y_end_binary_accuracy: 0.0040
# Epoch 13/20
# 21984/21984 - 166s - loss: 0.0832 - y_start_loss: 0.0396 - y_end_loss: 0.0436 - y_start_binary_accuracy: 0.0045 - y_end_binary_accuracy: 0.0041 - val_loss: 0.0900 - val_y_start_loss: 0.0428 - val_y_end_loss: 0.0472 - val_y_start_binary_accuracy: 0.0043 - val_y_end_binary_accuracy: 0.0039
# Epoch 14/20
# 21984/21984 - 166s - loss: 0.0816 - y_start_loss: 0.0389 - y_end_loss: 0.0427 - y_start_binary_accuracy: 0.0046 - y_end_binary_accuracy: 0.0043 - val_loss: 0.0894 - val_y_start_loss: 0.0427 - val_y_end_loss: 0.0467 - val_y_start_binary_accuracy: 0.0044 - val_y_end_binary_accuracy: 0.0043
# Epoch 15/20
# 21984/21984 - 166s - loss: 0.0802 - y_start_loss: 0.0383 - y_end_loss: 0.0419 - y_start_binary_accuracy: 0.0047 - y_end_binary_accuracy: 0.0045 - val_loss: 0.0892 - val_y_start_loss: 0.0427 - val_y_end_loss: 0.0465 - val_y_start_binary_accuracy: 0.0045 - val_y_end_binary_accuracy: 0.0045
# Epoch 16/20
# 21984/21984 - 166s - loss: 0.0789 - y_start_loss: 0.0377 - y_end_loss: 0.0411 - y_start_binary_accuracy: 0.0048 - y_end_binary_accuracy: 0.0047 - val_loss: 0.0888 - val_y_start_loss: 0.0426 - val_y_end_loss: 0.0463 - val_y_start_binary_accuracy: 0.0045 - val_y_end_binary_accuracy: 0.0045
# Epoch 17/20
# 21984/21984 - 166s - loss: 0.0775 - y_start_loss: 0.0371 - y_end_loss: 0.0404 - y_start_binary_accuracy: 0.0050 - y_end_binary_accuracy: 0.0049 - val_loss: 0.0890 - val_y_start_loss: 0.0428 - val_y_end_loss: 0.0462 - val_y_start_binary_accuracy: 0.0046 - val_y_end_binary_accuracy: 0.0045
# Epoch 18/20
# 21984/21984 - 166s - loss: 0.0763 - y_start_loss: 0.0365 - y_end_loss: 0.0398 - y_start_binary_accuracy: 0.0051 - y_end_binary_accuracy: 0.0051 - val_loss: 0.0891 - val_y_start_loss: 0.0430 - val_y_end_loss: 0.0462 - val_y_start_binary_accuracy: 0.0047 - val_y_end_binary_accuracy: 0.0047
# Epoch 19/20
# Restoring model weights from the end of the best epoch.
# 21984/21984 - 166s - loss: 0.0753 - y_start_loss: 0.0361 - y_end_loss: 0.0392 - y_start_binary_accuracy: 0.0052 - y_end_binary_accuracy: 0.0052 - val_loss: 0.0891 - val_y_start_loss: 0.0431 - val_y_end_loss: 0.0461 - val_y_start_binary_accuracy: 0.0047 - val_y_end_binary_accuracy: 0.0046
# Epoch 00019: early stopping

# %%
# Compress logs dir
# !tar -cvzf train.tar.gz train
# !tar -cvzf validation.tar.gz validation

# Delete logs dir
if os.path.exists('/kaggle/working/train/'):
    shutil.rmtree('/kaggle/working/train/')
if os.path.exists('/kaggle/working/validation/'):
    shutil.rmtree('/kaggle/working/validation/')
# Out:
# train/
# train/plugins/
# train/plugins/profile/
# train/plugins/profile/2020-04-11_21-52-52/
# train/plugins/profile/2020-04-11_21-52-52/local.trace
# train/events.out.tfevents.1586641961.4217fe361c2b.13.5436.v2
# train/events.out.tfevents.1586641972.4217fe361c2b.profile-empty
# validation/
# validation/events.out.tfevents.1586642139.4217fe361c2b.13.24191.v2

# %% [markdown]
# # Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'y_start_loss', 'y_end_loss', 
                                   'y_start_binary_accuracy', 'y_start_binary_accuracy'])

# %% [markdown]
# # Tokenizer

# %%
tokenizer = BertWordPieceTokenizer(tokenizer_path , lowercase=True)
tokenizer.save('./')
# Out:
# ['./vocab.txt']

# %% [markdown]
# # Model evaluation

# %%
train_preds = model.predict(list(x_train))
valid_preds = model.predict(list(x_valid))

train['start'] = train_preds[0].argmax(axis=-1)
train['end'] = train_preds[1].argmax(axis=-1)
train["end"].clip(0, train["text_len"], inplace=True)
train["start"].clip(0, train["end"], inplace=True)

train['prediction'] = train.apply(lambda x: decode(x['start'], x['end'], x['text'], config['question_size'], tokenizer), axis=1)
train["prediction"].fillna('', inplace=True)

validation['start'] = valid_preds[0].argmax(axis=-1)
validation['end'] = valid_preds[1].argmax(axis=-1)
validation["end"].clip(0, validation["text_len"], inplace=True)
validation["start"].clip(0, validation["end"], inplace=True)

validation['prediction'] = validation.apply(lambda x: decode(x['start'], x['end'], x['text'], config['question_size'], tokenizer), axis=1)
validation["prediction"].fillna('', inplace=True)
  
display(evaluate_model(train, validation))
# Out:
#                                 Train  Validation  Train samples  \
# Metric/Jaccard
# Overall                      0.701808    0.597750          21984
# Sentiment neutral            0.935159    0.917097           8842
# Sentiment negative           0.551074    0.369987           6258
# Sentiment positive           0.539114    0.374175           6884
# 0 <= text < 10               0.748768    0.620833            203
# 10 <= text < 50              0.772821    0.707796           7823
# 50 <= text < 100             0.670503    0.555256           8858
# 100 <= text < 200            0.645386    0.505054           5100
# 0 <= selected text < 10      0.489481    0.327448           6326
# 10 <= selected text < 50     0.735548    0.635103           9575
# 50 <= selected text < 100    0.855097    0.789321           4075
# 100 <= selected text < 200   0.898758    0.818603           2008
#
#                              Validation samples
# Metric/Jaccard
# Overall                                    5496
# Sentiment neutral                          2275
# Sentiment negative                         1523
# Sentiment positive                         1698
# 0 <= text < 10                               40
# 10 <= text < 50                            1945
# 50 <= text < 100                           2201
# 100 <= text < 200                          1310
# 0 <= selected text < 10                    1492
# 10 <= selected text < 50                   2455
# 50 <= selected text < 100                  1042
# 100 <= selected text < 200                  507

# %% [markdown]
# # Visualize predictions

# %%
print('Train set')
display(train.head(10))

print('Validation set')
display(validation.head(10))
# Out:
# Train set
#        textID                                               text  \
# 0  a5ca70509c  cant stop playin` in my head  -- pussycat doll...
# 1  f18b75e863                                         i hate you
# 2  649e31adcc                            starbucks i`m lovin` it
# 3  8891d08a8c                         ben and jerry...yummmmy!!!
# 4  7fb24b4a56          wow.. purple leopard skin.  fieeerrceee..
# 5  cb280b3adb  _ kk`s  have fun eating lol, remember shaun lo...
# 6  8dd41515ff                                   definitley miley
# 7  60fa8ea66e         just going to shower. brb in 10 mins or so
# 8  bb4ac6eb31              back to work.. with no distractions..
# 9  2f858c20c3   cool, i used to live 5 houses to the left of ...
#
#                                        selected_text sentiment  text_len  \
# 0  cant stop playin` in my head  -- pussycat doll...   neutral        95
# 1                                         i hate you  negative        11
# 2                            starbucks i`m lovin` it  positive        23
# 3                                          .yummmmy!  positive        27
# 4          wow.. purple leopard skin.  fieeerrceee..   neutral        42
# 5                                                fun  positive        58
# 6                                   definitley miley   neutral        17
# 7         just going to shower. brb in 10 mins or so   neutral        42
# 8              back to work.. with no distractions..  positive        37
# 9                                              cool,  positive        86
#
#    selected_text_len    set  start  end  \
# 0                 95  train      4   39
# 1                 10  train      4    6
# 2                 23  train      4   11
# 3                  9  train     10   14
# 4                 41  train      4   17
# 5                  3  train      9   10
# 6                 16  train      4    8
# 7                 42  train      4   16
# 8                 37  train      4   14
# 9                  5  train      4    5
#
#                                           prediction  jaccard
# 0  cant stop playin` in my head  -- pussycat doll...      1.0
# 1                                         i hate you      1.0
# 2                            starbucks i`m lovin` it      1.0
# 3                                          yummmmy!!      0.0
# 4          wow.. purple leopard skin.  fieeerrceee..      1.0
# 5                                           have fun      0.5
# 6                                   definitley miley      1.0
# 7         just going to shower. brb in 10 mins or so      1.0
# 8              back to work.. with no distractions..      1.0
# 9                                              cool,      1.0
# Validation set
#            textID                                               text  \
# 21984  3391184efc              loves the nice weather and 7:30 exams
# 21985  b35daf9677  okay, this weather isn`t 'cute sundress' frien...
# 21986  06e5249859                          woo hoo!! congratulations
# 21987  3cd4960670   thanks   got a hold of someone there who knew...
# 21988  92b75314ca  got back and putting in the laundry. we got in...
# 21989  7438c9c09a                    congrats on graduating college!
# 21990  fa042d9ad5  can you get me a sub from subway when ur on yo...
# 21991  a4ede54987  it`s the weekend but 9 year old is grounded wh...
# 21992  35124a7481   it`s been fine for me for like, a week, but n...
# 21993  e4b6c9a295                      ntah, i really wanna be there
#
#                                            selected_text sentiment  text_len  \
# 21984                                              loves  positive        37
# 21985  okay, this weather isn`t 'cute sundress' frien...   neutral       130
# 21986                                    congratulations  positive        26
# 21987                                             thanks  positive        68
# 21988  got back and putting in the laundry. we got in...   neutral        95
# 21989                                           congrats  positive        32
# 21990  can you get me a sub from subway when ur on yo...   neutral        58
# 21991  it`s the weekend but 9 year old is grounded wh...   neutral        71
# 21992  it`s been fine for me for like, a week, but no...   neutral        68
# 21993                                              wanna  positive        30
#
#        selected_text_len         set  start  end  \
# 21984                  5  validation      4    6
# 21985                130  validation      4   38
# 21986                 15  validation      4    9
# 21987                  6  validation      4    4
# 21988                 95  validation      4   29
# 21989                  8  validation      4    6
# 21990                 58  validation      4   18
# 21991                 71  validation      4   19
# 21992                 67  validation      4   25
# 21993                  5  validation      4   11
#
#                                               prediction   jaccard
# 21984                                     loves the nice  0.333333
# 21985  okay, this weather isn`t 'cute sundress' frien...  1.000000
# 21986                          woo hoo!! congratulations  0.333333
# 21987                                             thanks  1.000000
# 21988  got back and putting in the laundry. we got in...  1.000000
# 21989                                           congrats  1.000000
# 21990  can you get me a sub from subway when ur on yo...  1.000000
# 21991  it`s the weekend but 9 year old is grounded wh...  1.000000
# 21992  it`s been fine for me for like, a week, but no...  1.000000
# 21993                      ntah, i really wanna be there  0.166667
