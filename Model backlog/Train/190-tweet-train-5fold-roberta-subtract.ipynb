# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 27480
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5  imputed
# 0  train    False
# 1  train    False
# 2  train    False
# 3  train    False
# 4  train    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.94e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    
    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    
    y_start = layers.Subtract()([x_start, x_end])
    y_start = layers.Activation('softmax', name='y_start')(x_start)
    
    y_end = layers.Subtract()([x_end, x_start])
    y_end = layers.Activation('softmax', name='y_end')(x_end)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights('last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])

    # Make predictions (best model)
    model.load_weights(model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 196s - loss: 2.7092 - y_start_loss: 1.3046 - y_end_loss: 1.4046 - val_loss: 1.6519 - val_y_start_loss: 0.8534 - val_y_end_loss: 0.7985
# Epoch 2/4
# 687/687 - 181s - loss: 1.6774 - y_start_loss: 0.8454 - y_end_loss: 0.8320 - val_loss: 1.5963 - val_y_start_loss: 0.8175 - val_y_end_loss: 0.7788
# Epoch 3/4
# 687/687 - 181s - loss: 1.5404 - y_start_loss: 0.7876 - y_end_loss: 0.7528 - val_loss: 1.5717 - val_y_start_loss: 0.8148 - val_y_end_loss: 0.7569
# Epoch 4/4
# 687/687 - 181s - loss: 1.4851 - y_start_loss: 0.7675 - y_end_loss: 0.7176 - val_loss: 1.5620 - val_y_start_loss: 0.8108 - val_y_end_loss: 0.7512
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 194s - loss: 2.6092 - y_start_loss: 1.2773 - y_end_loss: 1.3319 - val_loss: 1.6593 - val_y_start_loss: 0.8542 - val_y_end_loss: 0.8051
# Epoch 2/4
# 687/687 - 181s - loss: 1.5733 - y_start_loss: 0.8222 - y_end_loss: 0.7511 - val_loss: 1.6167 - val_y_start_loss: 0.8396 - val_y_end_loss: 0.7771
# Epoch 3/4
# 687/687 - 181s - loss: 1.4533 - y_start_loss: 0.7607 - y_end_loss: 0.6926 - val_loss: 1.6029 - val_y_start_loss: 0.8261 - val_y_end_loss: 0.7769
# Epoch 4/4
# 687/687 - 180s - loss: 1.3986 - y_start_loss: 0.7312 - y_end_loss: 0.6674 - val_loss: 1.6105 - val_y_start_loss: 0.8308 - val_y_end_loss: 0.7797
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 192s - loss: 2.6582 - y_start_loss: 1.2964 - y_end_loss: 1.3618 - val_loss: 1.6828 - val_y_start_loss: 0.8504 - val_y_end_loss: 0.8323
# Epoch 2/4
# 687/687 - 181s - loss: 1.6593 - y_start_loss: 0.8615 - y_end_loss: 0.7978 - val_loss: 1.5832 - val_y_start_loss: 0.8080 - val_y_end_loss: 0.7753
# Epoch 3/4
# 687/687 - 179s - loss: 1.5154 - y_start_loss: 0.7894 - y_end_loss: 0.7261 - val_loss: 1.5897 - val_y_start_loss: 0.8140 - val_y_end_loss: 0.7757
# Epoch 4/4
# 687/687 - 180s - loss: 1.4792 - y_start_loss: 0.7688 - y_end_loss: 0.7105 - val_loss: 1.5657 - val_y_start_loss: 0.8053 - val_y_end_loss: 0.7603
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 193s - loss: 2.7124 - y_start_loss: 1.3137 - y_end_loss: 1.3987 - val_loss: 1.7165 - val_y_start_loss: 0.8782 - val_y_end_loss: 0.8382
# Epoch 2/4
# 687/687 - 181s - loss: 1.6389 - y_start_loss: 0.8318 - y_end_loss: 0.8071 - val_loss: 1.6306 - val_y_start_loss: 0.8495 - val_y_end_loss: 0.7811
# Epoch 3/4
# 687/687 - 181s - loss: 1.5103 - y_start_loss: 0.7744 - y_end_loss: 0.7359 - val_loss: 1.6160 - val_y_start_loss: 0.8424 - val_y_end_loss: 0.7736
# Epoch 4/4
# 687/687 - 180s - loss: 1.4654 - y_start_loss: 0.7566 - y_end_loss: 0.7088 - val_loss: 1.6055 - val_y_start_loss: 0.8354 - val_y_end_loss: 0.7701
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 193s - loss: 2.6683 - y_start_loss: 1.3195 - y_end_loss: 1.3488 - val_loss: 1.6469 - val_y_start_loss: 0.8409 - val_y_end_loss: 0.8060
# Epoch 2/4
# 687/687 - 181s - loss: 1.6093 - y_start_loss: 0.8330 - y_end_loss: 0.7763 - val_loss: 1.5749 - val_y_start_loss: 0.8131 - val_y_end_loss: 0.7617
# Epoch 3/4
# 687/687 - 180s - loss: 1.4898 - y_start_loss: 0.7789 - y_end_loss: 0.7109 - val_loss: 1.5715 - val_y_start_loss: 0.8172 - val_y_end_loss: 0.7543
# Epoch 4/4
# 687/687 - 179s - loss: 1.4176 - y_start_loss: 0.7424 - y_end_loss: 0.6752 - val_loss: 1.5849 - val_y_start_loss: 0.8236 - val_y_end_loss: 0.7613

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_a8099404_9e2b_11ea_8039_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_abdfb9e6_9e2b_11ea_8039_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  imputed  \
# 0              10                      10    False
# 1              13                       3    False
# 2               6                       2    False
# 3               6                       3    False
# 4              17                       4    False
# 5              27                      27    False
# 6              17                       1    False
# 7               3                       3    False
# 8               3                       3    False
# 9              19                       7    False
# 10             27                      27    False
# 11             12                       1    False
# 12              9                       1    False
# 13             13                       1    False
# 14              8                       8    False
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                                 sad        0.500000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                     lost my voice.        0.333333
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
