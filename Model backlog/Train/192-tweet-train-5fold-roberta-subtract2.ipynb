# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 27480
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2      fold_3      fold_4  \
# 0                      10       train       train       train  validation
# 1                       3  validation       train       train       train
# 2                       2       train  validation       train       train
# 3                       3       train  validation       train       train
# 4                       4       train       train  validation       train
#
#   fold_5  imputed
# 0  train    False
# 1  train    False
# 2  train    False
# 3  train    False
# 4  train    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 4,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 4,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.94e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _ = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    x_start = layers.Dropout(.1)(last_hidden_state)
    x_start = layers.Conv1D(1, 1)(x_start)
    x_start = layers.Flatten()(x_start)
    
    x_end = layers.Dropout(.1)(last_hidden_state)
    x_end = layers.Conv1D(1, 1)(x_end)
    x_end = layers.Flatten()(x_end)
    
    y_start_sub = layers.Subtract()([x_start, x_end])
    y_start_avg = layers.Average()([x_start, y_start_sub])
    y_start = layers.Activation('softmax', name='y_start')(y_start_avg)
    
    y_end_sub = layers.Subtract()([x_end, x_start])
    y_end_avg = layers.Average()([x_end, y_end_sub])
    y_end = layers.Activation('softmax', name='y_end')(y_end_avg)

    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
k_fold_best = k_fold.copy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(),
                                   'y_end': losses.CategoricalCrossentropy()})
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=False, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    model.save_weights('last_' + model_path)
    
    # Make predictions (last model)
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])

    # Make predictions (best model)
    model.load_weights(model_path)
    predict_eval_df(k_fold_best, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 196s - loss: 2.7749 - y_start_loss: 1.3501 - y_end_loss: 1.4248 - val_loss: 1.6083 - val_y_start_loss: 0.8415 - val_y_end_loss: 0.7669
# Epoch 2/4
# 687/687 - 181s - loss: 1.6668 - y_start_loss: 0.8578 - y_end_loss: 0.8089 - val_loss: 1.5639 - val_y_start_loss: 0.8089 - val_y_end_loss: 0.7550
# Epoch 3/4
# 687/687 - 181s - loss: 1.5505 - y_start_loss: 0.7953 - y_end_loss: 0.7552 - val_loss: 1.5637 - val_y_start_loss: 0.8146 - val_y_end_loss: 0.7491
# Epoch 4/4
# 687/687 - 181s - loss: 1.4930 - y_start_loss: 0.7699 - y_end_loss: 0.7231 - val_loss: 1.5478 - val_y_start_loss: 0.8052 - val_y_end_loss: 0.7427
#
# FOLD: 2
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 193s - loss: 2.7267 - y_start_loss: 1.3217 - y_end_loss: 1.4050 - val_loss: 1.6842 - val_y_start_loss: 0.8531 - val_y_end_loss: 0.8311
# Epoch 2/4
# 687/687 - 180s - loss: 1.6054 - y_start_loss: 0.8219 - y_end_loss: 0.7835 - val_loss: 1.6375 - val_y_start_loss: 0.8529 - val_y_end_loss: 0.7846
# Epoch 3/4
# 687/687 - 180s - loss: 1.4703 - y_start_loss: 0.7593 - y_end_loss: 0.7110 - val_loss: 1.6258 - val_y_start_loss: 0.8277 - val_y_end_loss: 0.7982
# Epoch 4/4
# 687/687 - 179s - loss: 1.4169 - y_start_loss: 0.7336 - y_end_loss: 0.6833 - val_loss: 1.6285 - val_y_start_loss: 0.8354 - val_y_end_loss: 0.7931
#
# FOLD: 3
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 191s - loss: 2.7980 - y_start_loss: 1.3656 - y_end_loss: 1.4324 - val_loss: 1.6787 - val_y_start_loss: 0.8486 - val_y_end_loss: 0.8301
# Epoch 2/4
# 687/687 - 181s - loss: 1.6692 - y_start_loss: 0.8681 - y_end_loss: 0.8011 - val_loss: 1.5725 - val_y_start_loss: 0.8067 - val_y_end_loss: 0.7657
# Epoch 3/4
# 687/687 - 180s - loss: 1.5231 - y_start_loss: 0.7962 - y_end_loss: 0.7269 - val_loss: 1.5693 - val_y_start_loss: 0.8103 - val_y_end_loss: 0.7590
# Epoch 4/4
# 687/687 - 180s - loss: 1.4821 - y_start_loss: 0.7741 - y_end_loss: 0.7079 - val_loss: 1.5619 - val_y_start_loss: 0.8065 - val_y_end_loss: 0.7554
#
# FOLD: 4
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 194s - loss: 2.8100 - y_start_loss: 1.3675 - y_end_loss: 1.4425 - val_loss: 1.7630 - val_y_start_loss: 0.8865 - val_y_end_loss: 0.8765
# Epoch 2/4
# 687/687 - 180s - loss: 1.6956 - y_start_loss: 0.8602 - y_end_loss: 0.8354 - val_loss: 1.6446 - val_y_start_loss: 0.8523 - val_y_end_loss: 0.7923
# Epoch 3/4
# 687/687 - 180s - loss: 1.5664 - y_start_loss: 0.8016 - y_end_loss: 0.7648 - val_loss: 1.6357 - val_y_start_loss: 0.8440 - val_y_end_loss: 0.7916
# Epoch 4/4
# 687/687 - 180s - loss: 1.5178 - y_start_loss: 0.7833 - y_end_loss: 0.7345 - val_loss: 1.6164 - val_y_start_loss: 0.8385 - val_y_end_loss: 0.7779
#
# FOLD: 5
# Train for 687 steps, validate for 171 steps
# Epoch 1/4
# 687/687 - 192s - loss: 2.8077 - y_start_loss: 1.3728 - y_end_loss: 1.4349 - val_loss: 1.7034 - val_y_start_loss: 0.8452 - val_y_end_loss: 0.8582
# Epoch 2/4
# 687/687 - 181s - loss: 1.6557 - y_start_loss: 0.8372 - y_end_loss: 0.8185 - val_loss: 1.6115 - val_y_start_loss: 0.8192 - val_y_end_loss: 0.7923
# Epoch 3/4
# 687/687 - 180s - loss: 1.5185 - y_start_loss: 0.7851 - y_end_loss: 0.7334 - val_loss: 1.6026 - val_y_start_loss: 0.8298 - val_y_end_loss: 0.7728
# Epoch 4/4
# 687/687 - 179s - loss: 1.4454 - y_start_loss: 0.7524 - y_end_loss: 0.6930 - val_loss: 1.6152 - val_y_start_loss: 0.8365 - val_y_end_loss: 0.7787

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation (best model)

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_d3f30d78_9e37_11ea_b1bc_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_d7b194ac_9e37_11ea_b1bc_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment   jaccard  \
# 0                 i`d have responded, if i were going   neutral  1.000000
# 1                                            sooo sad  negative  0.200000
# 2                                         bullying me  negative  0.166667
# 3                                      leave me alone  negative  0.600000
# 4                                       sons of ****,  negative  0.214286
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral  1.000000
# 6                                                 fun  positive  0.071429
# 7                                          soooo high   neutral  1.000000
# 8                                         both of you   neutral  1.000000
# 9                        wow... u just became cooler.  positive  0.500000
# 10  as much as i love to be hopeful, i reckon the ...   neutral  1.000000
# 11                                               like  positive  0.100000
# 12                                        dangerously  negative  0.125000
# 13                                               lost  negative  0.100000
# 14                         test test from the lg env2   neutral  1.000000
#
#     text_tokenCnt  selected_text_tokenCnt  imputed  \
# 0              10                      10    False
# 1              13                       3    False
# 2               6                       2    False
# 3               6                       3    False
# 4              17                       4    False
# 5              27                      27    False
# 6              17                       1    False
# 7               3                       3    False
# 8               3                       3    False
# 9              19                       7    False
# 10             27                      27    False
# 11             12                       1    False
# 12              9                       1    False
# 13             13                       1    False
# 14              8                       8    False
#
#                                     prediction_fold_1  jaccard_fold_1  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                        wow... u just became cooler.        1.000000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                    dangerously low        0.500000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_2  jaccard_fold_2  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                                        dangerously        1.000000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_3  jaccard_fold_3  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                               i really really like        0.333333
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_4  jaccard_fold_4  \
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                               ****,        0.333333
# 5   http://www.dothebouncy.com/smf - some shameles...        1.000000
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
#
#                                     prediction_fold_5  jaccard_fold_5
# 0                 i`d have responded, if i were going        1.000000
# 1                                            sooo sad        1.000000
# 2                                      bullying me...        0.333333
# 3                                      leave me alone        1.000000
# 4                                       sons of ****,        1.000000
# 5   some shameless plugging for the best rangers f...        0.833333
# 6                                                 fun        1.000000
# 7                                          soooo high        1.000000
# 8                                         both of you        1.000000
# 9                                              wow...        0.200000
# 10  as much as i love to be hopeful, i reckon the ...        1.000000
# 11                                               like        1.000000
# 12                             dangerously low on ink        0.250000
# 13                                               lost        1.000000
# 14                         test test from the lg env2        1.000000
