# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
# from tweet_utility_preprocess_roberta_scripts_aux import *
from tweet_utility_preprocess_roberta_scripts_word import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-word2/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-word2/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-word2/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-word2/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean-word2/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean-word2/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 26882
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                             bullying  negative  0.200000        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                  8                      1
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2 fold_3      fold_4 fold_5  \
# 0                      10       train  validation  train       train  train
# 1                       3  validation       train  train       train  train
# 2                       1       train       train  train  validation  train
# 3                       3       train       train  train  validation  train
# 4                       4       train       train  train  validation  train
#
#    imputed
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 5,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-base-tf_model.h5',
  'config_path': base_path + 'roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .999

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.97e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=True)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    _, _, hidden_states = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    h11 = hidden_states[-2]

    x = layers.Dropout(.1)(h11)
    
    start_logits = layers.Dense(1, name="start_logit", use_bias=False)(x)
    start_logits = layers.Flatten()(start_logits)

    end_logits = layers.Dense(1, name="end_logit", use_bias=False)(x)
    end_logits = layers.Flatten()(end_logits)
    

    start_probs = layers.Activation('softmax', name='y_start')(start_logits)
    end_probs = layers.Activation('softmax', name='y_end')(end_logits)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_probs, end_probs])
    
    return model

# %% [markdown]
# # Train

# %%
def predict_eval_df(df, model, x_train, x_valid, dataset_fn, decode_fn, n_fold, tokenizer, config, question_size=None):
    fold_col = f'fold_{n_fold}'
    end_col = f'end_fold_{n_fold}'
    start_col = f'start_fold_{n_fold}'
    pred_col = f'prediction_fold_{n_fold}'
    jaccard_col = f'jaccard_fold_{n_fold}'
    
    train_preds = model.predict(dataset_fn(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(dataset_fn(x_valid, config['BATCH_SIZE']))
    
    df.loc[df[fold_col] == 'train', start_col] = train_preds[0].argmax(axis=-1)
    df.loc[df[fold_col] == 'train', end_col] = train_preds[1].argmax(axis=-1)
    df.loc[df[fold_col] == 'validation', start_col] = valid_preds[0].argmax(axis=-1)
    df.loc[df[fold_col] == 'validation', end_col] = valid_preds[1].argmax(axis=-1)
    
    df[end_col] = df[end_col].astype(int)
    df[start_col] = df[start_col].astype(int)
    df[pred_col] = df.apply(lambda x: decode_fn(x[start_col], x[end_col], x['text']), axis=1)
        
    df[pred_col] = df.apply(lambda x: x['text'] if (x[pred_col] == '') else x[pred_col], axis=1)
    df[pred_col].fillna(df['text'], inplace=True)
    df[jaccard_col] = df.apply(lambda x: jaccard(x['selected_text'], x[pred_col]), axis=1)

# %%
AUTO = tf.data.experimental.AUTOTUNE
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    model.compile(optimizer, loss={'y_start': losses.CategoricalCrossentropy(label_smoothing=0.2),
                                   'y_end': losses.CategoricalCrossentropy(label_smoothing=0.2)})
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 176s - loss: 5.8242 - y_start_loss: 2.6259 - y_end_loss: 3.1982 - val_loss: 4.5073 - val_y_start_loss: 2.1006 - val_y_end_loss: 2.4067
# Epoch 2/7
# 672/672 - 164s - loss: 4.3925 - y_start_loss: 2.0635 - y_end_loss: 2.3289 - val_loss: 4.1127 - val_y_start_loss: 1.9992 - val_y_end_loss: 2.1135
# Epoch 3/7
# 672/672 - 163s - loss: 4.0845 - y_start_loss: 1.9786 - y_end_loss: 2.1059 - val_loss: 4.0428 - val_y_start_loss: 1.9789 - val_y_end_loss: 2.0639
# Epoch 4/7
# 672/672 - 163s - loss: 3.9610 - y_start_loss: 1.9410 - y_end_loss: 2.0200 - val_loss: 4.0097 - val_y_start_loss: 1.9674 - val_y_end_loss: 2.0423
# Epoch 5/7
# 672/672 - 163s - loss: 3.8909 - y_start_loss: 1.9169 - y_end_loss: 1.9740 - val_loss: 3.9560 - val_y_start_loss: 1.9578 - val_y_end_loss: 1.9982
# Epoch 6/7
# 672/672 - 162s - loss: 3.8510 - y_start_loss: 1.9051 - y_end_loss: 1.9459 - val_loss: 3.9561 - val_y_start_loss: 1.9612 - val_y_end_loss: 1.9949
# Epoch 7/7
# 672/672 - 163s - loss: 3.8348 - y_start_loss: 1.8940 - y_end_loss: 1.9409 - val_loss: 3.9488 - val_y_start_loss: 1.9581 - val_y_end_loss: 1.9907
#
# FOLD: 2
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 174s - loss: 5.6608 - y_start_loss: 2.5504 - y_end_loss: 3.1103 - val_loss: 4.4677 - val_y_start_loss: 2.0875 - val_y_end_loss: 2.3802
# Epoch 2/7
# 672/672 - 163s - loss: 4.3836 - y_start_loss: 2.0538 - y_end_loss: 2.3298 - val_loss: 4.2019 - val_y_start_loss: 2.0288 - val_y_end_loss: 2.1730
# Epoch 3/7
# 672/672 - 163s - loss: 4.0864 - y_start_loss: 1.9748 - y_end_loss: 2.1116 - val_loss: 4.0210 - val_y_start_loss: 1.9721 - val_y_end_loss: 2.0489
# Epoch 4/7
# 672/672 - 163s - loss: 3.9472 - y_start_loss: 1.9352 - y_end_loss: 2.0120 - val_loss: 4.0125 - val_y_start_loss: 1.9765 - val_y_end_loss: 2.0360
# Epoch 5/7
# 672/672 - 163s - loss: 3.8832 - y_start_loss: 1.9101 - y_end_loss: 1.9730 - val_loss: 3.9782 - val_y_start_loss: 1.9601 - val_y_end_loss: 2.0181
# Epoch 6/7
# 672/672 - 163s - loss: 3.8493 - y_start_loss: 1.8995 - y_end_loss: 1.9499 - val_loss: 3.9516 - val_y_start_loss: 1.9542 - val_y_end_loss: 1.9974
# Epoch 7/7
# 672/672 - 163s - loss: 3.8306 - y_start_loss: 1.8925 - y_end_loss: 1.9380 - val_loss: 3.9509 - val_y_start_loss: 1.9575 - val_y_end_loss: 1.9934
#
# FOLD: 3
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 176s - loss: 5.7587 - y_start_loss: 2.6213 - y_end_loss: 3.1374 - val_loss: 4.5367 - val_y_start_loss: 2.0923 - val_y_end_loss: 2.4444
# Epoch 2/7
# 672/672 - 163s - loss: 4.4042 - y_start_loss: 2.0867 - y_end_loss: 2.3175 - val_loss: 4.0864 - val_y_start_loss: 1.9867 - val_y_end_loss: 2.0997
# Epoch 3/7
# 672/672 - 164s - loss: 4.1124 - y_start_loss: 1.9965 - y_end_loss: 2.1160 - val_loss: 4.0120 - val_y_start_loss: 1.9671 - val_y_end_loss: 2.0449
# Epoch 4/7
# 672/672 - 164s - loss: 3.9733 - y_start_loss: 1.9494 - y_end_loss: 2.0239 - val_loss: 3.9441 - val_y_start_loss: 1.9541 - val_y_end_loss: 1.9900
# Epoch 5/7
# 672/672 - 163s - loss: 3.8964 - y_start_loss: 1.9242 - y_end_loss: 1.9723 - val_loss: 3.9222 - val_y_start_loss: 1.9467 - val_y_end_loss: 1.9755
# Epoch 6/7
# 672/672 - 164s - loss: 3.8773 - y_start_loss: 1.9184 - y_end_loss: 1.9589 - val_loss: 3.9133 - val_y_start_loss: 1.9446 - val_y_end_loss: 1.9687
# Epoch 7/7
# 672/672 - 162s - loss: 3.8651 - y_start_loss: 1.9162 - y_end_loss: 1.9488 - val_loss: 3.9180 - val_y_start_loss: 1.9432 - val_y_end_loss: 1.9748
#
# FOLD: 4
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 176s - loss: 5.7418 - y_start_loss: 2.5746 - y_end_loss: 3.1671 - val_loss: 4.5273 - val_y_start_loss: 2.1003 - val_y_end_loss: 2.4271
# Epoch 2/7
# 672/672 - 164s - loss: 4.4814 - y_start_loss: 2.1037 - y_end_loss: 2.3777 - val_loss: 4.2086 - val_y_start_loss: 2.0076 - val_y_end_loss: 2.2011
# Epoch 3/7
# 672/672 - 164s - loss: 4.1737 - y_start_loss: 2.0114 - y_end_loss: 2.1623 - val_loss: 4.0868 - val_y_start_loss: 1.9951 - val_y_end_loss: 2.0917
# Epoch 4/7
# 672/672 - 164s - loss: 4.0412 - y_start_loss: 1.9721 - y_end_loss: 2.0691 - val_loss: 4.0130 - val_y_start_loss: 1.9746 - val_y_end_loss: 2.0384
# Epoch 5/7
# 672/672 - 164s - loss: 3.9715 - y_start_loss: 1.9473 - y_end_loss: 2.0242 - val_loss: 3.9966 - val_y_start_loss: 1.9707 - val_y_end_loss: 2.0259
# Epoch 6/7
# 672/672 - 164s - loss: 3.9338 - y_start_loss: 1.9360 - y_end_loss: 1.9978 - val_loss: 3.9837 - val_y_start_loss: 1.9674 - val_y_end_loss: 2.0163
# Epoch 7/7
# 672/672 - 163s - loss: 3.9210 - y_start_loss: 1.9316 - y_end_loss: 1.9893 - val_loss: 3.9797 - val_y_start_loss: 1.9651 - val_y_end_loss: 2.0146
#
# FOLD: 5
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 176s - loss: 5.7370 - y_start_loss: 2.5662 - y_end_loss: 3.1708 - val_loss: 4.5625 - val_y_start_loss: 2.1363 - val_y_end_loss: 2.4262
# Epoch 2/7
# 672/672 - 164s - loss: 4.4270 - y_start_loss: 2.0865 - y_end_loss: 2.3405 - val_loss: 4.1880 - val_y_start_loss: 2.0094 - val_y_end_loss: 2.1787
# Epoch 3/7
# 672/672 - 163s - loss: 4.1167 - y_start_loss: 1.9956 - y_end_loss: 2.1210 - val_loss: 4.0202 - val_y_start_loss: 1.9679 - val_y_end_loss: 2.0523
# Epoch 4/7
# 672/672 - 164s - loss: 3.9780 - y_start_loss: 1.9542 - y_end_loss: 2.0239 - val_loss: 3.9870 - val_y_start_loss: 1.9603 - val_y_end_loss: 2.0267
# Epoch 5/7
# 672/672 - 163s - loss: 3.9174 - y_start_loss: 1.9324 - y_end_loss: 1.9849 - val_loss: 3.9474 - val_y_start_loss: 1.9472 - val_y_end_loss: 2.0002
# Epoch 6/7
# 672/672 - 162s - loss: 3.8689 - y_start_loss: 1.9146 - y_end_loss: 1.9542 - val_loss: 3.9494 - val_y_start_loss: 1.9461 - val_y_end_loss: 2.0033
# Epoch 7/7
# 672/672 - 164s - loss: 3.8650 - y_start_loss: 1.9119 - y_end_loss: 1.9531 - val_loss: 3.9405 - val_y_start_loss: 1.9453 - val_y_end_loss: 1.9952

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col6 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col8 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col10 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row2_col12 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col6 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col8 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col10 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row4_col12 {
#             color:  green;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_54b7ac5c_a374_11ea_97bb_0242ac130202row6_col9

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                            bullying  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              10                      10  1.000000      1.000000
# 1              13                       3  0.200000      0.500000
# 2               6                       1  0.200000      0.900000
# 3               6                       3  0.600000      1.000000
# 4              17                       4  0.214286      0.466667
# 5              27                      27  1.000000      0.933333
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              19                       7  0.500000      0.680000
# 10             27                      27  1.000000      1.000000
# 11             12                       1  0.100000      0.733333
# 12              9                       1  0.125000      1.000000
# 13             13                       1  0.100000      0.500000
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_2  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                               ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                                        dangerously
# 13                                             i lost
# 14                         test test from the lg env2
#
#                                     prediction_fold_3  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                               ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                             cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_4  \
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                               ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                                              wow...
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
#
#                                     prediction_fold_5
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                            bullying
# 3                                      leave me alone
# 4                                               ****,
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                                               like
# 12                                        dangerously
# 13                                               lost
# 14                         test test from the lg env2
