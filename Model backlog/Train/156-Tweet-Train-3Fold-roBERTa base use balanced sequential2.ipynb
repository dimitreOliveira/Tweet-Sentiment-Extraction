# %%
# !nvidia-smi

# %%
# !pip --quiet install transformers
# !pip --quiet install tokenizers
# Out:
#      |████████████████████████████████| 645kB 6.8MB/s
#      |████████████████████████████████| 1.1MB 23.5MB/s
#      |████████████████████████████████| 890kB 29.7MB/s
#      |████████████████████████████████| 3.8MB 40.1MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/'
MODEL_BASE_PATH = COLAB_BASE_PATH + 'Models/Files/156-roBERTa_base/'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from scripts_step_lr_schedulers import *
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/fold_5.tar.gz'


# Unzip files (balanced)
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/balanced_fold_1.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/balanced_fold_2.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/balanced_fold_3.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/balanced_fold_4.tar.gz'
# !tar -xvf '/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Data/complete/balanced_fold_5.tar.gz'
# Out:
# fold_1/
# fold_1/x_train.npy
# fold_1/y_train_mask.npy
# fold_1/x_train_aux2.npy
# fold_1/x_train_aux.npy
# fold_1/x_valid.npy
# fold_1/y_valid_aux.npy
# fold_1/x_valid_aux2.npy
# fold_1/y_train.npy
# fold_1/x_valid_aux.npy
# fold_1/y_train_aux.npy
# fold_1/y_valid_mask.npy
# fold_1/y_valid.npy
# fold_2/
# fold_2/x_train.npy
# fold_2/y_train_mask.npy
# fold_2/x_train_aux2.npy
# fold_2/x_train_aux.npy
# fold_2/x_valid.npy
# fold_2/y_valid_aux.npy
# fold_2/x_valid_aux2.npy
# fold_2/y_train.npy
# fold_2/x_valid_aux.npy
# fold_2/y_train_aux.npy
# fold_2/y_valid_mask.npy
# fold_2/y_valid.npy
# fold_3/
# fold_3/x_train.npy
# fold_3/y_train_mask.npy
# fold_3/x_train_aux2.npy
# fold_3/x_train_aux.npy
# fold_3/x_valid.npy
# fold_3/y_valid_aux.npy
# fold_3/x_valid_aux2.npy
# fold_3/y_train.npy
# fold_3/x_valid_aux.npy
# fold_3/y_train_aux.npy
# fold_3/y_valid_mask.npy
# fold_3/y_valid.npy
# balanced_fold_1/
# balanced_fold_1/x_train.npy
# balanced_fold_1/y_train_mask.npy
# balanced_fold_1/x_train_aux2.npy
# balanced_fold_1/x_train_aux.npy
# balanced_fold_1/x_valid.npy
# balanced_fold_1/y_valid_aux.npy
# balanced_fold_1/x_valid_aux2.npy
# balanced_fold_1/y_train.npy
# balanced_fold_1/x_valid_aux.npy
# balanced_fold_1/y_train_aux.npy
# balanced_fold_1/y_valid_mask.npy
# balanced_fold_1/y_valid.npy
# balanced_fold_2/
# balanced_fold_2/x_train.npy
# balanced_fold_2/y_train_mask.npy
# balanced_fold_2/x_train_aux2.npy
# balanced_fold_2/x_train_aux.npy
# balanced_fold_2/x_valid.npy
# balanced_fold_2/y_valid_aux.npy
# balanced_fold_2/x_valid_aux2.npy
# balanced_fold_2/y_train.npy
# balanced_fold_2/x_valid_aux.npy
# balanced_fold_2/y_train_aux.npy
# balanced_fold_2/y_valid_mask.npy
# balanced_fold_2/y_valid.npy
# balanced_fold_3/
# balanced_fold_3/x_train.npy
# balanced_fold_3/y_train_mask.npy
# balanced_fold_3/x_train_aux2.npy
# balanced_fold_3/x_train_aux.npy
# balanced_fold_3/x_valid.npy
# balanced_fold_3/y_valid_aux.npy
# balanced_fold_3/x_valid_aux2.npy
# balanced_fold_3/y_train.npy
# balanced_fold_3/x_valid_aux.npy
# balanced_fold_3/y_train_aux.npy
# balanced_fold_3/y_valid_mask.npy
# balanced_fold_3/y_valid.npy

# %%
database_base_path = COLAB_BASE_PATH + 'Data/complete/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
display(k_fold.head())
# Out:
#        textID  ... fold_5
# 0  cb774db0d1  ...  train
# 1  549e992a42  ...  train
# 2  088c60f138  ...  train
# 3  9642c003ef  ...  train
# 4  358bd9e861  ...  train
#
# [5 rows x 14 columns]

# %% [markdown]
# # Model parameters

# %%
vocab_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-vocab.json'
merges_path = COLAB_BASE_PATH + 'qa-transformers/roberta/roberta-base-merges.txt'
base_path = COLAB_BASE_PATH + 'qa-transformers/roberta/'

config = {
  "MAX_LEN": 96,
  "BATCH_SIZE": 32,
  "EPOCHS": 3,
  "LEARNING_RATE": 3e-5,
  "ES_PATIENCE": 3,
  "question_size": 4,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'roberta-base-tf_model.h5',
  "config_path": base_path + 'roberta-base-config.json'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train']) *2
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
decay = .9993

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=1, lr_start=lr_max, lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 3e-05 to 3e-05 to 1.71e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    last_state = sequence_output[0]
    
    x_start = layers.Dropout(.1)(last_state) 
    x_start = layers.Dense(1)(x_start)
    x_start = layers.Flatten()(x_start)
    y_start = layers.Activation('softmax', name='y_start')(x_start)

    x_end = layers.Dropout(.1)(last_state) 
    x_end = layers.Dense(1)(x_end)
    x_end = layers.Flatten()(x_end)
    y_end = layers.Activation('softmax', name='y_end')(x_end)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=[y_start, y_end])
    
    return model

# %% [markdown]
# # Train

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')

    # Load data (balanced)
    x_train = np.hstack([x_train, np.load('balanced_' + base_data_path + 'x_train.npy')])
    y_train = np.hstack([y_train, np.load('balanced_' + base_data_path + 'y_train.npy')]) 
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']
    valid_step_size = x_valid.shape[1] // config['BATCH_SIZE']

    # Build TF datasets
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    valid_dist_ds = strategy.experimental_distribute_dataset(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=True, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    valid_data_iter = iter(valid_dist_ds)

    # Build TF datasets (balanced)
    train_dist_ds = strategy.experimental_distribute_dataset(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED))
    train_data_iter = iter(train_dist_ds)
    
    
    # Step functions
    @tf.function
    def train_step(data_iter):
        def train_step_fn(x, y):
            with tf.GradientTape() as tape:
                probabilities = model(x, training=True)
                loss_start = loss_fn(y['y_start'], probabilities[0])
                loss_end = loss_fn(y['y_end'], probabilities[1])
                loss = tf.math.add(loss_start, loss_end)
            grads = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))
            # update metrics
            train_loss.update_state(loss)
            train_loss_start.update_state(loss_start)
            train_loss_end.update_state(loss_end)
        for _ in tf.range(step_size):
            strategy.experimental_run_v2(train_step_fn, next(data_iter))

    @tf.function
    def valid_step(data_iter):
        def valid_step_fn(x, y):
            probabilities = model(x, training=False)
            loss_start = loss_fn(y['y_start'], probabilities[0])
            loss_end = loss_fn(y['y_end'], probabilities[1])
            loss = tf.math.add(loss_start, loss_end)
            # update metrics
            valid_loss.update_state(loss)
            valid_loss_start.update_state(loss_start)
            valid_loss_end.update_state(loss_end)
        for _ in tf.range(valid_step_size):
            strategy.experimental_run_v2(valid_step_fn, next(data_iter))

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=1, lr_start=lr_max, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    loss_fn = losses.categorical_crossentropy
    train_loss = metrics.Sum()
    valid_loss = metrics.Sum()
    train_loss_start = metrics.Sum()
    valid_loss_start = metrics.Sum()
    train_loss_end = metrics.Sum()
    valid_loss_end = metrics.Sum()
        
    metrics_dict = {'loss': train_loss, 'loss_start': train_loss_start, 'loss_end': train_loss_end, 
                    'val_loss': valid_loss, 'val_loss_start': valid_loss_start, 'val_loss_end': valid_loss_end}
        
    history = custom_fit(model, metrics_dict, train_step, valid_step, train_data_iter, valid_data_iter, 
                         step_size, valid_step_size, config['BATCH_SIZE'], config['EPOCHS'], config['ES_PATIENCE'], 
                         (MODEL_BASE_PATH + model_path), save_last=False)
    
    history_list.append(history)
    model.save_weights(MODEL_BASE_PATH +'last_' + model_path)
    
    # Make predictions
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold.loc[k_fold['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold['end_fold_%d' % (n_fold)] = k_fold['end_fold_%d' % (n_fold)].astype(int)
    k_fold['start_fold_%d' % (n_fold)] = k_fold['start_fold_%d' % (n_fold)].astype(int)
    k_fold['end_fold_%d' % (n_fold)].clip(0, k_fold['text_len'], inplace=True)
    k_fold['start_fold_%d' % (n_fold)].clip(0, k_fold['end_fold_%d' % (n_fold)], inplace=True)
    k_fold['prediction_fold_%d' % (n_fold)] = k_fold.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold['prediction_fold_%d' % (n_fold)].fillna(k_fold["text"], inplace=True)
    k_fold['jaccard_fold_%d' % (n_fold)] = k_fold.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
# Train for 1270 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/3
# time: 490.4s loss: 1.9424 loss_start: 0.9952 loss_end: 0.9472 val_loss: 1.5779 val_loss_start: 0.8190 val_loss_end: 0.7590
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/156-roBERTa_base/model_fold_1.h5"
#
# EPOCH 2/3
# time: 481.4s loss: 1.4543 loss_start: 0.7648 loss_end: 0.6895 val_loss: 1.5777 val_loss_start: 0.8314 val_loss_end: 0.7463
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/156-roBERTa_base/model_fold_1.h5"
#
# EPOCH 3/3
# time: 481.4s loss: 1.2817 loss_start: 0.6777 loss_end: 0.6039 val_loss: 1.6216 val_loss_start: 0.8406 val_loss_end: 0.7811
# Training finished
#
# FOLD: 2
# Train for 1270 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/3
# time: 490.5s loss: 1.9452 loss_start: 0.9826 loss_end: 0.9625 val_loss: 1.6156 val_loss_start: 0.8359 val_loss_end: 0.7797
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/156-roBERTa_base/model_fold_2.h5"
#
# EPOCH 2/3
# time: 477.7s loss: 1.4192 loss_start: 0.7473 loss_end: 0.6719 val_loss: 1.6660 val_loss_start: 0.8680 val_loss_end: 0.7980
#
# EPOCH 3/3
# time: 475.1s loss: 1.2550 loss_start: 0.6648 loss_end: 0.5902 val_loss: 1.7828 val_loss_start: 0.9326 val_loss_end: 0.8501
# Training finished
#
# FOLD: 3
# Train for 1270 steps, validate for 171 steps
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['base_model/roberta/pooler/dense/kernel:0', 'base_model/roberta/pooler/dense/bias:0'] when minimizing the loss.
#
# EPOCH 1/3
# time: 489.7s loss: 1.9420 loss_start: 0.9861 loss_end: 0.9559 val_loss: 1.5593 val_loss_start: 0.7976 val_loss_end: 0.7617
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Tweet Sentiment Extraction/Models/Files/156-roBERTa_base/model_fold_3.h5"
#
# EPOCH 2/3
# time: 477.2s loss: 1.4741 loss_start: 0.7714 loss_end: 0.7026 val_loss: 1.5679 val_loss_start: 0.8189 val_loss_end: 0.7489
#
# EPOCH 3/3
# time: 475.1s loss: 1.3207 loss_start: 0.6949 loss_end: 0.6257 val_loss: 1.5802 val_loss_start: 0.8284 val_loss_end: 0.7518
# Training finished

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation (last model)

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row7_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col6 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col7 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row8_col8 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col0 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col1 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col2 {
#             color:  red;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col3 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col4 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col5 {
#             color:  black;
#         }    #T_3c0ba94a_9863_11ea_b374_0242ac1c0002row9_col6 {
#             color:  bl

# %% [markdown]
# # Model evaluation (best model)

# %%
k_fold_best = k_fold.copy()
for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))

    # Load weights
    base_data_path = 'fold_%d/' % (n_fold)
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    model.load_weights(MODEL_BASE_PATH + model_path)
    
    # Make predictions
    x_train = np.load(base_data_path + 'x_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE']))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE']))
    
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'start_fold_%d' % (n_fold)] = train_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'train', 'end_fold_%d' % (n_fold)] = train_preds[1].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'start_fold_%d' % (n_fold)] = valid_preds[0].argmax(axis=-1)
    k_fold_best.loc[k_fold_best['fold_%d' % (n_fold)] == 'validation', 'end_fold_%d' % (n_fold)] = valid_preds[1].argmax(axis=-1)
    
    k_fold_best['end_fold_%d' % (n_fold)] = k_fold_best['end_fold_%d' % (n_fold)].astype(int)
    k_fold_best['start_fold_%d' % (n_fold)] = k_fold_best['start_fold_%d' % (n_fold)].astype(int)
    k_fold_best['end_fold_%d' % (n_fold)].clip(0, k_fold_best['text_len'], inplace=True)
    k_fold_best['start_fold_%d' % (n_fold)].clip(0, k_fold_best['end_fold_%d' % (n_fold)], inplace=True)
    k_fold_best['prediction_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: decode(x['start_fold_%d' % (n_fold)], x['end_fold_%d' % (n_fold)], x['text'], config['question_size'], tokenizer), axis=1)
    k_fold_best['prediction_fold_%d' % (n_fold)].fillna(k_fold_best["text"], inplace=True)
    k_fold_best['jaccard_fold_%d' % (n_fold)] = k_fold_best.apply(lambda x: jaccard(x['selected_text'], x['prediction_fold_%d' % (n_fold)]), axis=1)
# Out:
# FOLD: 1
#
# FOLD: 2
#
# FOLD: 3

# %%
display(evaluate_model_kfold(k_fold_best, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col0 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col1 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col3 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col4 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col5 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col6 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row2_col8 {
#             color:  green;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row7_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col6 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col7 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row8_col8 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col0 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col1 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col2 {
#             color:  red;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col3 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col4 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col5 {
#             color:  black;
#         }    #T_eb0eacfc_9864_11ea_b374_0242ac1c0002row9_col6 {
#             color:  bl

# %% [markdown]
# # Visualize predictions

# %%
display(k_fold[[c for c in k_fold.columns if not (c.startswith('textID') or 
                                                  c.startswith('text_len') or 
                                                  c.startswith('selected_text_len') or 
                                                  c.startswith('text_wordCnt') or 
                                                  c.startswith('selected_text_wordCnt') or 
                                                  c.startswith('fold_') or 
                                                  c.startswith('start_fold_') or 
                                                  c.startswith('end_fold_'))]].head(15))
# Out:
#                                                  text  ... jaccard_fold_3
# 0                 i`d have responded, if i were going  ...       1.000000
# 1       sooo sad i will miss you here in san diego!!!  ...       1.000000
# 2                           my boss is bullying me...  ...       0.333333
# 3                      what interview! leave me alone  ...       1.000000
# 4   sons of ****, why couldn`t they put them on th...  ...       1.000000
# 5   http://www.dothebouncy.com/smf - some shameles...  ...       1.000000
# 6   2am feedings for the baby are fun when he is a...  ...       1.000000
# 7                                          soooo high  ...       1.000000
# 8                                         both of you  ...       1.000000
# 9   journey!? wow... u just became cooler.  hehe.....  ...       0.200000
# 10  as much as i love to be hopeful, i reckon the ...  ...       1.000000
# 11  i really really like the song love story by ta...  ...       1.000000
# 12       my sharpie is running dangerously low on ink  ...       1.000000
# 13  i want to go to music tonight but i lost my vo...  ...       1.000000
# 14                         test test from the lg env2  ...       1.000000
#
# [15 rows x 10 columns]
