# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from tweet_utility_scripts import *
from tweet_utility_preprocess_roberta_scripts_aux import *
from transformers import TFRobertaModel, RobertaConfig
from tokenizers import ByteLevelBPETokenizer
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from scripts_step_lr_schedulers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
# Unzip files
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_1.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_2.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_3.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_4.tar.gz
# !tar -xf /kaggle/input/tweet-dataset-5fold-roberta-64-clean/fold_5.tar.gz

# %%
database_base_path = '/kaggle/input/tweet-dataset-5fold-roberta-64-clean/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
print(f'Training set samples: {len(k_fold)}')
display(k_fold.head())
# Out:
# Training set samples: 26882
#        textID                                               text  \
# 0  cb774db0d1                i`d have responded, if i were going
# 1  549e992a42      sooo sad i will miss you here in san diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861  sons of ****, why couldn`t they put them on th...
#
#                          selected_text sentiment   jaccard  text_len  \
# 0  i`d have responded, if i were going   neutral  1.000000        35
# 1                             sooo sad  negative  0.200000        45
# 2                          bullying me  negative  0.166667        25
# 3                       leave me alone  negative  0.600000        30
# 4                        sons of ****,  negative  0.214286        74
#
#    text_wordCnt  text_tokenCnt  selected_text_len  selected_text_wordCnt  \
# 0             7             10                 35                      7
# 1            10             13                  8                      2
# 2             5              6                 11                      2
# 3             5              6                 14                      3
# 4            14             17                 13                      3
#
#    selected_text_tokenCnt      fold_1      fold_2 fold_3      fold_4 fold_5  \
# 0                      10       train  validation  train       train  train
# 1                       3  validation       train  train       train  train
# 2                       2       train       train  train  validation  train
# 3                       3       train       train  train  validation  train
# 4                       4       train       train  train  validation  train
#
#    imputed
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# # Model parameters

# %%
vocab_path = database_base_path + 'vocab.json'
merges_path = database_base_path + 'merges.txt'
base_path = '/kaggle/input/qa-transformers/roberta/'

config = {
  'MAX_LEN': 64,
  'BATCH_SIZE': 32,
  'EPOCHS': 7,
  'LEARNING_RATE': 3e-5,
  'ES_PATIENCE': 2,
  'N_FOLDS': 1,
  'question_size': 4,
  'base_model_path': base_path + 'roberta-large-tf_model.h5',
  'config_path': base_path + 'roberta-large-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Tokenizer

# %%
tokenizer = ByteLevelBPETokenizer(vocab_file=vocab_path, merges_file=merges_path, 
                                  lowercase=True, add_prefix_space=True)
tokenizer.save('./')
# Out:
# ['./vocab.json', './merges.txt']

# %% [markdown]
# ## Learning rate schedule

# %%
lr_min = 1e-6
lr_start = 1e-7
lr_max = config['LEARNING_RATE']
train_size = len(k_fold[k_fold['fold_1'] == 'train'])
step_size = train_size // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
warmup_steps = total_steps * 0.1
decay = .9985

rng = [i for i in range(0, total_steps, config['BATCH_SIZE'])]
y = [exponential_schedule_with_warmup(tf.cast(x, tf.float32), warmup_steps=warmup_steps, lr_start=lr_start, 
                                      lr_max=lr_max, lr_min=lr_min, decay=decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-07 to 2.96e-05 to 1e-06

# %% [markdown]
# # Model

# %%
module_config = RobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    
    base_model = TFRobertaModel.from_pretrained(config['base_model_path'], config=module_config, name="base_model")
    last_hidden_state, _  = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    logits = layers.Dense(2, name="qa_outputs")(last_hidden_state)
    
    start_logits, end_logits = tf.split(logits, 2, axis=-1)
    start_logits = tf.squeeze(start_logits, axis=-1)
    end_logits = tf.squeeze(end_logits, axis=-1)

    model = Model(inputs=[input_ids, attention_mask], outputs=[start_logits, end_logits])
    
    return model

# %% [markdown]
# # Train

# %%
# Datasets
def get_training_dataset(x_train, y_train, batch_size, buffer_size, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_train[0], 'attention_mask': x_train[1]}, 
                                                  (y_train[0], y_train[1])))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_validation_dataset(x_valid, y_valid, batch_size, buffer_size, repeated=False, seed=0):
    dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': x_valid[0], 'attention_mask': x_valid[1]}, 
                                                  (y_valid[0], y_valid[1])))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048, seed=seed)
    dataset = dataset.batch(batch_size, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %%
AUTO = tf.data.experimental.AUTOTUNE
strategy = tf.distribute.get_strategy()
history_list = []

for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    y_valid = np.load(base_data_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    model = model_fn(config['MAX_LEN'])
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    optimizer = optimizers.Adam(learning_rate=lambda: exponential_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                                                       warmup_steps=warmup_steps, lr_start=lr_start, 
                                                                                       lr_max=lr_max, lr_min=lr_min, decay=decay))
    
    model.compile(optimizer, loss=[losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True),
                                   losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)])
    
    history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO, seed=SEED),
                        validation_data=(get_validation_dataset(x_valid, y_valid, config['BATCH_SIZE'], AUTO, repeated=False, seed=SEED)),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)

    # Make predictions
    predict_eval_df(k_fold, model, x_train, x_valid, get_test_dataset, decode, n_fold, tokenizer, config, config['question_size'])
    
    ### Delete data dir
    shutil.rmtree(base_data_path)
# Out:
# FOLD: 1
# Train for 672 steps, validate for 168 steps
# Epoch 1/7
# 672/672 - 596s - loss: 4.7861 - tf_op_layer_Squeeze_loss: 2.3607 - tf_op_layer_Squeeze_1_loss: 2.4254 - val_loss: 3.8837 - val_tf_op_layer_Squeeze_loss: 1.9710 - val_tf_op_layer_Squeeze_1_loss: 1.9127
# Epoch 2/7
# 672/672 - 570s - loss: 3.8466 - tf_op_layer_Squeeze_loss: 1.9315 - tf_op_layer_Squeeze_1_loss: 1.9151 - val_loss: 3.8809 - val_tf_op_layer_Squeeze_loss: 1.9327 - val_tf_op_layer_Squeeze_1_loss: 1.9482
# Epoch 3/7
# 672/672 - 569s - loss: 3.7066 - tf_op_layer_Squeeze_loss: 1.8635 - tf_op_layer_Squeeze_1_loss: 1.8431 - val_loss: 3.7935 - val_tf_op_layer_Squeeze_loss: 1.9262 - val_tf_op_layer_Squeeze_1_loss: 1.8673
# Epoch 4/7
# 672/672 - 565s - loss: 3.6349 - tf_op_layer_Squeeze_loss: 1.8345 - tf_op_layer_Squeeze_1_loss: 1.8004 - val_loss: 3.8033 - val_tf_op_layer_Squeeze_loss: 1.9368 - val_tf_op_layer_Squeeze_1_loss: 1.8664
# Epoch 5/7
# Restoring model weights from the end of the best epoch.
# 672/672 - 566s - loss: 3.5990 - tf_op_layer_Squeeze_loss: 1.8187 - tf_op_layer_Squeeze_1_loss: 1.7803 - val_loss: 3.8038 - val_tf_op_layer_Squeeze_loss: 1.9357 - val_tf_op_layer_Squeeze_1_loss: 1.8681
# Epoch 00005: early stopping

# %% [markdown]
# # Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model_kfold(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row2_col1 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row2_col4 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row4_col0 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row4_col1 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row4_col4 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row7_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row7_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row7_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row7_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row7_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row8_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row8_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row8_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row8_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row8_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row9_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row9_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row9_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row9_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row9_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row10_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row10_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row10_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row10_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row10_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row11_col0 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row11_col1 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row11_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row11_col3 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row11_col4 {
#             color:  black;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row12_col0 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row12_col1 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row12_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row12_col3 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row12_col4 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row13_col0 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row13_col1 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row13_col2 {
#             color:  red;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row13_col3 {
#             color:  green;
#         }    #T_94982cc8_a5fb_11ea_adf5_0242ac130202row13_col4 {
#             color:  green;
#         }</style><table id="T_94982cc8_a5fb_11ea_adf5_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>    </tr>    <tr>        <th class="index_name level0" >Metric/Jaccard</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94982cc8_a5fb_11ea_adf5_0242ac130202level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col0" class="data row0 col0" >0.761508</td>
#                         <td id="T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col1" class="data row0 col1" >0.724407</td>
#                         <td id="T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col2" class="data row0 col2" >0.037101</td>
#                         <td id="T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col3" class="data row0 col3" >0.761508</td>
#                         <td id="T_94982cc8_a5fb_11ea_adf5_0242ac130202row0_col4" class="data row0 col4" >0.724407</td>
#             </tr>
#             <tr>
#                         <th id="T_94982cc8_a5fb_11ea_adf5_0242ac130202level0_row1" class="row_heading level0 row1" >Sentiment negative</th>
#                         <td id=

# %% [markdown]
# # Visualize predictions

# %%
k_fold['jaccard_mean'] = 0

for n in range(config['N_FOLDS']):
    k_fold['jaccard_mean'] += k_fold[f'jaccard_fold_{n+1}'] / config['N_FOLDS']

display(k_fold[['text', 'selected_text', 'sentiment', 'text_tokenCnt', 
                'selected_text_tokenCnt', 'jaccard', 'jaccard_mean'] + [c for c in k_fold.columns if (c.startswith('prediction_fold'))]].head(15))
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 1       sooo sad i will miss you here in san diego!!!
# 2                           my boss is bullying me...
# 3                      what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on th...
# 5   http://www.dothebouncy.com/smf - some shameles...
# 6   2am feedings for the baby are fun when he is a...
# 7                                          soooo high
# 8                                         both of you
# 9   journey!? wow... u just became cooler.  hehe.....
# 10  as much as i love to be hopeful, i reckon the ...
# 11  i really really like the song love story by ta...
# 12       my sharpie is running dangerously low on ink
# 13  i want to go to music tonight but i lost my vo...
# 14                         test test from the lg env2
#
#                                         selected_text sentiment  \
# 0                 i`d have responded, if i were going   neutral
# 1                                            sooo sad  negative
# 2                                         bullying me  negative
# 3                                      leave me alone  negative
# 4                                       sons of ****,  negative
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 6                                                 fun  positive
# 7                                          soooo high   neutral
# 8                                         both of you   neutral
# 9                        wow... u just became cooler.  positive
# 10  as much as i love to be hopeful, i reckon the ...   neutral
# 11                                               like  positive
# 12                                        dangerously  negative
# 13                                               lost  negative
# 14                         test test from the lg env2   neutral
#
#     text_tokenCnt  selected_text_tokenCnt   jaccard  jaccard_mean  \
# 0              10                      10  1.000000      1.000000
# 1              13                       3  0.200000      0.500000
# 2               6                       2  0.166667      0.333333
# 3               6                       3  0.600000      1.000000
# 4              17                       4  0.214286      1.000000
# 5              27                      27  1.000000      0.833333
# 6              17                       1  0.071429      1.000000
# 7               3                       3  1.000000      1.000000
# 8               3                       3  1.000000      1.000000
# 9              19                       7  0.500000      1.000000
# 10             27                      27  1.000000      1.000000
# 11             12                       1  0.100000      0.333333
# 12              9                       1  0.125000      1.000000
# 13             13                       1  0.100000      0.333333
# 14              8                       8  1.000000      1.000000
#
#                                     prediction_fold_1
# 0                 i`d have responded, if i were going
# 1                                                 sad
# 2                                      bullying me...
# 3                                      leave me alone
# 4                                       sons of ****,
# 5   some shameless plugging for the best rangers f...
# 6                                                 fun
# 7                                          soooo high
# 8                                         both of you
# 9                        wow... u just became cooler.
# 10  as much as i love to be hopeful, i reckon the ...
# 11                               i really really like
# 12                                        dangerously
# 13                                     lost my voice.
# 14                         test test from the lg env2
